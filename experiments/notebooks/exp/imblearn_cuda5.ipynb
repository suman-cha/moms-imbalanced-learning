# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

import os
import warnings
from imblearn.datasets import fetch_datasets
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from experiment import run_exp

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "5"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Save path 
save_path = "/data4/oldrain123/oldrain123/results/real_results"

# %%
data = fetch_datasets()
methods = ["GAMO", "MGVAE"]
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}

kernel_type = 'GAMO_MGVAE'

# %%
# scene
data_name = 'scene'
maj_target_name = -1

n_epochs = 1000
hidden_dims = [32, 64, 128, 256]
latent_dim = 512
lr = 0.005
beta = 0.001

final_res = run_exp(
    data=data, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    kernel_type=kernel_type,
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    maj_target_name=maj_target_name,
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded: scene
# X shape : (2407, 294)
# target : Counter({0: 2230, 1: 177})
# IR: 12.6
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.6815
#     G-mean: 0.2290
#     MCC: 0.0424
#     F1-score: 0.0886
#     mAP: 0.1466
#   [GAMO - DecisionTree]
#     AUROC: 0.5000
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0735
#   [GAMO - kNN]
#     AUROC: 0.6626
#     G-mean: 0.1706
#     MCC: 0.1292
#     F1-score: 0.1026
#     mAP: 0.1946
#   [GAMO - MLP]
#     AUROC: 0.7275
#     G-mean: 0.3779
#     MCC: 0.1254
#     F1-score: 0.1813
#     mAP: 0.1910
#   [GAMO - RandomForest]
#     AUROC: 0.7772
#     G-mean: 0.1487
#     MCC: 0.1330
#     F1-score: 0.0816
#     mAP: 0.3282
#   [MGVAE - SVM]
#     AUROC: 0.7849
#     G-mean: 0.1630
#     MCC: 0.1267
#     F1-score: 0.0816
#     mAP: 0.2914
#   [MGVAE - DecisionTree]
#     AUROC: 0.6584
#     G-mean: 0.3815
#     MCC: 0.1739
#     F1-score: 0.2103
#     mAP: 0.1670
#   [MGVAE - kNN]
#     AUROC: 0.6997
#     G-mean: 0.5255
#     MCC: 0.1742
#     F1-score: 0.2432
#     mAP: 0.1505
#   [MGVAE - MLP]
#     AUROC: 0.7376
#     G-mean: 0.3414
#     MCC: 0.1399
#     F1-score: 0.1837
#     mAP: 0.2252
#   [MGVAE - RandomForest]
#     AUROC: 0.7752
#     G-mean: 0.1487
#     MCC: 0.1330
#     F1-score: 0.0816
#     mAP: 0.3289
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.6803
#     G-mean: 0.1985
#     MCC: 0.0330
#     F1-score: 0.0819
#     mAP: 0.1496
#   [GAMO - DecisionTree]
#     AUROC: 0.4922
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0733
#   [GAMO - kNN]
#     AUROC: 0.6610
#     G-mean: 0.1812
#     MCC: 0.1362
#     F1-score: 0.1047
#     mAP: 0.1891
#   [GAMO - MLP]
#     AUROC: 0.7297
#     G-mean: 0.3825
#     MCC: 0.1296
#     F1-score: 0.1837
#     mAP: 0.2006
#   [GAMO - RandomForest]
#     AUROC: 0.7725
#     G-mean: 0.1371
#     MCC: 0.1228
#     F1-score: 0.0766
#     mAP: 0.3219
#   [MGVAE - SVM]
#     AUROC: 0.7843
#     G-mean: 0.1578
#     MCC: 0.1264
#     F1-score: 0.0771
#     mAP: 0.3002
#   [MGVAE - DecisionTree]
#     AUROC: 0.6662
#     G-mean: 0.3659
#     MCC: 0.1647
#     F1-score: 0.1987
#     mAP: 0.1667
#   [MGVAE - kNN]
#     AUROC: 0.7000
#     G-mean: 0.5222
#     MCC: 0.1744
#     F1-score: 0.2425
#     mAP: 0.1518
#   [MGVAE - MLP]
#     AUROC: 0.7392
#     G-mean: 0.4022
#     MCC: 0.1770
#     F1-score: 0.2222
#     mAP: 0.2388
#   [MGVAE - RandomForest]
#     AUROC: 0.7731
#     G-mean: 0.1321
#     MCC: 0.1179
#     F1-score: 0.0717
#     mAP: 0.3216
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.6800
#     G-mean: 0.2089
#     MCC: 0.0366
#     F1-score: 0.0849
#     mAP: 0.1525
#   [GAMO - DecisionTree]
#     AUROC: 0.4896
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0730
#   [GAMO - kNN]
#     AUROC: 0.6624
#     G-mean: 0.1995
#     MCC: 0.1486
#     F1-score: 0.1119
#     mAP: 0.1911
#   [GAMO - MLP]
#     AUROC: 0.7302
#     G-mean: 0.3667
#     MCC: 0.1189
#     F1-score: 0.1736
#     mAP: 0.2035
#   [GAMO - RandomForest]
#     AUROC: 0.7744
#     G-mean: 0.1504
#     MCC: 0.1330
#     F1-score: 0.0792
#     mAP: 0.3162
#   [MGVAE - SVM]
#     AUROC: 0.7817
#     G-mean: 0.1596
#     MCC: 0.1333
#     F1-score: 0.0792
#     mAP: 0.3007
#   [MGVAE - DecisionTree]
#     AUROC: 0.6715
#     G-mean: 0.3571
#     MCC: 0.1668
#     F1-score: 0.1979
#     mAP: 0.1737
#   [MGVAE - kNN]
#     AUROC: 0.6998
#     G-mean: 0.5231
#     MCC: 0.1763
#     F1-score: 0.2445
#     mAP: 0.1526
#   [MGVAE - MLP]
#     AUROC: 0.7387
#     G-mean: 0.4000
#     MCC: 0.1769
#     F1-score: 0.2209
#     mAP: 0.2416
#   [MGVAE - RandomForest]
#     AUROC: 0.7725
#     G-mean: 0.1470
#     MCC: 0.1297
#     F1-score: 0.0759
#     mAP: 0.3199
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.6803
#     G-mean: 0.2008
#     MCC: 0.0341
#     F1-score: 0.0831
#     mAP: 0.1512
#   [GAMO - DecisionTree]
#     AUROC: 0.4899
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0730
#   [GAMO - kNN]
#     AUROC: 0.6607
#     G-mean: 0.2063
#     MCC: 0.1517
#     F1-score: 0.1157
#     mAP: 0.1886
#   [GAMO - MLP]
#     AUROC: 0.7313
#     G-mean: 0.3740
#     MCC: 0.1207
#     F1-score: 0.1759
#     mAP: 0.2047
#   [GAMO - RandomForest]
#     AUROC: 0.7725
#     G-mean: 0.1438
#     MCC: 0.1260
#     F1-score: 0.0767
#     mAP: 0.3091
#   [MGVAE - SVM]
#     AUROC: 0.7804
#     G-mean: 0.1603
#     MCC: 0.1359
#     F1-score: 0.0798
#     mAP: 0.2981
#   [MGVAE - DecisionTree]
#     AUROC: 0.6681
#     G-mean: 0.3488
#     MCC: 0.1561
#     F1-score: 0.1881
#     mAP: 0.1668
#   [MGVAE - kNN]
#     AUROC: 0.6974
#     G-mean: 0.5245
#     MCC: 0.1780
#     F1-score: 0.2460
#     mAP: 0.1533
#   [MGVAE - MLP]
#     AUROC: 0.7420
#     G-mean: 0.3954
#     MCC: 0.1723
#     F1-score: 0.2144
#     mAP: 0.2445
#   [MGVAE - RandomForest]
#     AUROC: 0.7729
#     G-mean: 0.1389
#     MCC: 0.1218
#     F1-score: 0.0722
#     mAP: 0.3119
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.6803
#     G-mean: 0.2068
#     MCC: 0.0367
#     F1-score: 0.0852
#     mAP: 0.1502
#   [GAMO - DecisionTree]
#     AUROC: 0.4911
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0730
#   [GAMO - kNN]
#     AUROC: 0.6610
#     G-mean: 0.1973
#     MCC: 0.1455
#     F1-score: 0.1111
#     mAP: 0.1869
#   [GAMO - MLP]
#     AUROC: 0.7316
#     G-mean: 0.3683
#     MCC: 0.1187
#     F1-score: 0.1737
#     mAP: 0.2037
#   [GAMO - RandomForest]
#     AUROC: 0.7724
#     G-mean: 0.1387
#     MCC: 0.1228
#     F1-score: 0.0720
#     mAP: 0.3083
#   [MGVAE - SVM]
#     AUROC: 0.7823
#     G-mean: 0.1493
#     MCC: 0.1250
#     F1-score: 0.0741
#     mAP: 0.2987
#   [MGVAE - DecisionTree]
#     AUROC: 0.6619
#     G-mean: 0.3418
#     MCC: 0.1436
#     F1-score: 0.1777
#     mAP: 0.1600
#   [MGVAE - kNN]
#     AUROC: 0.6979
#     G-mean: 0.5223
#     MCC: 0.1777
#     F1-score: 0.2459
#     mAP: 0.1554
#   [MGVAE - MLP]
#     AUROC: 0.7454
#     G-mean: 0.4001
#     MCC: 0.1778
#     F1-score: 0.2174
#     mAP: 0.2494
#   [MGVAE - RandomForest]
#     AUROC: 0.7729
#     G-mean: 0.1301
#     MCC: 0.1133
#     F1-score: 0.0662
#     mAP: 0.3090
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.6809
#     G-mean: 0.2028
#     MCC: 0.0349
#     F1-score: 0.0834
#     mAP: 0.1494
#   [GAMO - DecisionTree]
#     AUROC: 0.4926
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0731
#   [GAMO - kNN]
#     AUROC: 0.6609
#     G-mean: 0.2039
#     MCC: 0.1511
#     F1-score: 0.1138
#     mAP: 0.1884
#   [GAMO - MLP]
#     AUROC: 0.7333
#     G-mean: 0.3761
#     MCC: 0.1248
#     F1-score: 0.1795
#     mAP: 0.2070
#   [GAMO - RandomForest]
#     AUROC: 0.7724
#     G-mean: 0.1426
#     MCC: 0.1242
#     F1-score: 0.0734
#     mAP: 0.3099
#   [MGVAE - SVM]
#     AUROC: 0.7850
#     G-mean: 0.1547
#     MCC: 0.1309
#     F1-score: 0.0786
#     mAP: 0.3026
#   [MGVAE - DecisionTree]
#     AUROC: 0.6605
#     G-mean: 0.3412
#     MCC: 0.1426
#     F1-score: 0.1757
#     mAP: 0.1604
#   [MGVAE - kNN]
#     AUROC: 0.6970
#     G-mean: 0.5232
#     MCC: 0.1791
#     F1-score: 0.2473
#     mAP: 0.1567
#   [MGVAE - MLP]
#     AUROC: 0.7466
#     G-mean: 0.4047
#     MCC: 0.1821
#     F1-score: 0.2212
#     mAP: 0.2500
#   [MGVAE - RandomForest]
#     AUROC: 0.7736
#     G-mean: 0.1354
#     MCC: 0.1174
#     F1-score: 0.0687
#     mAP: 0.3115
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.6813
#     G-mean: 0.2036
#     MCC: 0.0348
#     F1-score: 0.0833
#     mAP: 0.1496
#   [GAMO - DecisionTree]
#     AUROC: 0.4936
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0731
#   [GAMO - kNN]
#     AUROC: 0.6622
#     G-mean: 0.2033
#     MCC: 0.1497
#     F1-score: 0.1123
#     mAP: 0.1883
#   [GAMO - MLP]
#     AUROC: 0.7361
#     G-mean: 0.3838
#     MCC: 0.1318
#     F1-score: 0.1859
#     mAP: 0.2109
#   [GAMO - RandomForest]
#     AUROC: 0.7712
#     G-mean: 0.1474
#     MCC: 0.1282
#     F1-score: 0.0748
#     mAP: 0.3093
#   [MGVAE - SVM]
#     AUROC: 0.7848
#     G-mean: 0.1571
#     MCC: 0.1344
#     F1-score: 0.0804
#     mAP: 0.3014
#   [MGVAE - DecisionTree]
#     AUROC: 0.6579
#     G-mean: 0.3394
#     MCC: 0.1407
#     F1-score: 0.1740
#     mAP: 0.1604
#   [MGVAE - kNN]
#     AUROC: 0.6966
#     G-mean: 0.5229
#     MCC: 0.1793
#     F1-score: 0.2474
#     mAP: 0.1564
#   [MGVAE - MLP]
#     AUROC: 0.7487
#     G-mean: 0.4068
#     MCC: 0.1844
#     F1-score: 0.2231
#     mAP: 0.2531
#   [MGVAE - RandomForest]
#     AUROC: 0.7733
#     G-mean: 0.1412
#     MCC: 0.1224
#     F1-score: 0.0708
#     mAP: 0.3118
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.6817
#     G-mean: 0.2047
#     MCC: 0.0353
#     F1-score: 0.0836
#     mAP: 0.1497
#   [GAMO - DecisionTree]
#     AUROC: 0.4936
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0731
#   [GAMO - kNN]
#     AUROC: 0.6616
#     G-mean: 0.2050
#     MCC: 0.1493
#     F1-score: 0.1116
#     mAP: 0.1876
#   [GAMO - MLP]
#     AUROC: 0.7352
#     G-mean: 0.3829
#     MCC: 0.1305
#     F1-score: 0.1846
#     mAP: 0.2098
#   [GAMO - RandomForest]
#     AUROC: 0.7723
#     G-mean: 0.1476
#     MCC: 0.1281
#     F1-score: 0.0757
#     mAP: 0.3110
#   [MGVAE - SVM]
#     AUROC: 0.7853
#     G-mean: 0.1589
#     MCC: 0.1368
#     F1-score: 0.0820
#     mAP: 0.3019
#   [MGVAE - DecisionTree]
#     AUROC: 0.6606
#     G-mean: 0.3417
#     MCC: 0.1410
#     F1-score: 0.1747
#     mAP: 0.1609
#   [MGVAE - kNN]
#     AUROC: 0.6947
#     G-mean: 0.5242
#     MCC: 0.1804
#     F1-score: 0.2482
#     mAP: 0.1553
#   [MGVAE - MLP]
#     AUROC: 0.7483
#     G-mean: 0.4100
#     MCC: 0.1859
#     F1-score: 0.2249
#     mAP: 0.2536
#   [MGVAE - RandomForest]
#     AUROC: 0.7734
#     G-mean: 0.1422
#     MCC: 0.1230
#     F1-score: 0.0721
#     mAP: 0.3119
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.6817
#     G-mean: 0.2088
#     MCC: 0.0370
#     F1-score: 0.0852
#     mAP: 0.1500
#   [GAMO - DecisionTree]
#     AUROC: 0.4943
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0732
#   [GAMO - kNN]
#     AUROC: 0.6625
#     G-mean: 0.2075
#     MCC: 0.1502
#     F1-score: 0.1123
#     mAP: 0.1885
#   [GAMO - MLP]
#     AUROC: 0.7352
#     G-mean: 0.3867
#     MCC: 0.1327
#     F1-score: 0.1866
#     mAP: 0.2100
#   [GAMO - RandomForest]
#     AUROC: 0.7724
#     G-mean: 0.1508
#     MCC: 0.1313
#     F1-score: 0.0766
#     mAP: 0.3104
#   [MGVAE - SVM]
#     AUROC: 0.7858
#     G-mean: 0.1631
#     MCC: 0.1409
#     F1-score: 0.0843
#     mAP: 0.3034
#   [MGVAE - DecisionTree]
#     AUROC: 0.6597
#     G-mean: 0.3489
#     MCC: 0.1470
#     F1-score: 0.1804
#     mAP: 0.1608
#   [MGVAE - kNN]
#     AUROC: 0.6950
#     G-mean: 0.5231
#     MCC: 0.1795
#     F1-score: 0.2474
#     mAP: 0.1556
#   [MGVAE - MLP]
#     AUROC: 0.7484
#     G-mean: 0.4137
#     MCC: 0.1883
#     F1-score: 0.2275
#     mAP: 0.2550
#   [MGVAE - RandomForest]
#     AUROC: 0.7727
#     G-mean: 0.1460
#     MCC: 0.1268
#     F1-score: 0.0734
#     mAP: 0.3112
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.6813
#     G-mean: 0.2066
#     MCC: 0.0367
#     F1-score: 0.0849
#     mAP: 0.1505
#   [GAMO - DecisionTree]
#     AUROC: 0.4940
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0731
#   [GAMO - kNN]
#     AUROC: 0.6634
#     G-mean: 0.2062
#     MCC: 0.1497
#     F1-score: 0.1110
#     mAP: 0.1892
#   [GAMO - MLP]
#     AUROC: 0.7341
#     G-mean: 0.3870
#     MCC: 0.1325
#     F1-score: 0.1865
#     mAP: 0.2096
#   [GAMO - RandomForest]
#     AUROC: 0.7720
#     G-mean: 0.1529
#     MCC: 0.1344
#     F1-score: 0.0782
#     mAP: 0.3121
#   [MGVAE - SVM]
#     AUROC: 0.7853
#     G-mean: 0.1675
#     MCC: 0.1444
#     F1-score: 0.0860
#     mAP: 0.3045
#   [MGVAE - DecisionTree]
#     AUROC: 0.6572
#     G-mean: 0.3463
#     MCC: 0.1436
#     F1-score: 0.1781
#     mAP: 0.1588
#   [MGVAE - kNN]
#     AUROC: 0.6950
#     G-mean: 0.5237
#     MCC: 0.1797
#     F1-score: 0.2475
#     mAP: 0.1559
#   [MGVAE - MLP]
#     AUROC: 0.7483
#     G-mean: 0.4156
#     MCC: 0.1891
#     F1-score: 0.2285
#     mAP: 0.2562
#   [MGVAE - RandomForest]
#     AUROC: 0.7725
#     G-mean: 0.1476
#     MCC: 0.1294
#     F1-score: 0.0744
#     mAP: 0.3125
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/scene_results_GAMO_MGVAE_beta_0.001.csv

# %%
# sick_euthyroid
data_name = 'sick_euthyroid'
maj_target_name = -1

n_epochs = 1000
hidden_dims = [32, 64, 128, 256]
latent_dim = 512
lr = 0.005
beta = 0.001

final_res = run_exp(
    data=data, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    kernel_type=kernel_type,
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    maj_target_name=maj_target_name,
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded: sick_euthyroid
# X shape : (3163, 42)
# target : Counter({0: 2870, 1: 293})
# IR: 9.8
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.9062
#     G-mean: 0.3436
#     MCC: 0.2068
#     F1-score: 0.1959
#     mAP: 0.4529
#   [GAMO - DecisionTree]
#     AUROC: 0.9604
#     G-mean: 0.9259
#     MCC: 0.8303
#     F1-score: 0.8440
#     mAP: 0.7813
#   [GAMO - kNN]
#     AUROC: 0.8902
#     G-mean: 0.6709
#     MCC: 0.5502
#     F1-score: 0.5644
#     mAP: 0.5703
#   [GAMO - MLP]
#     AUROC: 0.9513
#     G-mean: 0.7674
#     MCC: 0.6630
#     F1-score: 0.6774
#     mAP: 0.7248
#   [GAMO - RandomForest]
#     AUROC: 0.9841
#     G-mean: 0.9182
#     MCC: 0.8614
#     F1-score: 0.8725
#     mAP: 0.9123
#   [MGVAE - SVM]
#     AUROC: 0.9385
#     G-mean: 0.5199
#     MCC: 0.4376
#     F1-score: 0.4069
#     mAP: 0.7067
#   [MGVAE - DecisionTree]
#     AUROC: 0.9517
#     G-mean: 0.9208
#     MCC: 0.8537
#     F1-score: 0.8663
#     mAP: 0.8304
#   [MGVAE - kNN]
#     AUROC: 0.8907
#     G-mean: 0.6711
#     MCC: 0.5536
#     F1-score: 0.5666
#     mAP: 0.5769
#   [MGVAE - MLP]
#     AUROC: 0.9318
#     G-mean: 0.7244
#     MCC: 0.6074
#     F1-score: 0.6261
#     mAP: 0.6966
#   [MGVAE - RandomForest]
#     AUROC: 0.9824
#     G-mean: 0.9220
#     MCC: 0.8670
#     F1-score: 0.8778
#     mAP: 0.9064
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.9093
#     G-mean: 0.3402
#     MCC: 0.2066
#     F1-score: 0.1956
#     mAP: 0.4797
#   [GAMO - DecisionTree]
#     AUROC: 0.9613
#     G-mean: 0.9228
#     MCC: 0.8228
#     F1-score: 0.8376
#     mAP: 0.7714
#   [GAMO - kNN]
#     AUROC: 0.8884
#     G-mean: 0.6724
#     MCC: 0.5551
#     F1-score: 0.5681
#     mAP: 0.5663
#   [GAMO - MLP]
#     AUROC: 0.9535
#     G-mean: 0.7739
#     MCC: 0.6679
#     F1-score: 0.6839
#     mAP: 0.7285
#   [GAMO - RandomForest]
#     AUROC: 0.9848
#     G-mean: 0.9202
#     MCC: 0.8639
#     F1-score: 0.8749
#     mAP: 0.9092
#   [MGVAE - SVM]
#     AUROC: 0.9388
#     G-mean: 0.5268
#     MCC: 0.4457
#     F1-score: 0.4148
#     mAP: 0.7101
#   [MGVAE - DecisionTree]
#     AUROC: 0.9541
#     G-mean: 0.9154
#     MCC: 0.8476
#     F1-score: 0.8607
#     mAP: 0.8213
#   [MGVAE - kNN]
#     AUROC: 0.8889
#     G-mean: 0.6726
#     MCC: 0.5588
#     F1-score: 0.5704
#     mAP: 0.5720
#   [MGVAE - MLP]
#     AUROC: 0.9363
#     G-mean: 0.7495
#     MCC: 0.6439
#     F1-score: 0.6600
#     mAP: 0.7196
#   [MGVAE - RandomForest]
#     AUROC: 0.9835
#     G-mean: 0.9212
#     MCC: 0.8657
#     F1-score: 0.8766
#     mAP: 0.9055
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.9114
#     G-mean: 0.3327
#     MCC: 0.1994
#     F1-score: 0.1917
#     mAP: 0.4870
#   [GAMO - DecisionTree]
#     AUROC: 0.9599
#     G-mean: 0.9225
#     MCC: 0.8172
#     F1-score: 0.8323
#     mAP: 0.7634
#   [GAMO - kNN]
#     AUROC: 0.8843
#     G-mean: 0.6688
#     MCC: 0.5466
#     F1-score: 0.5614
#     mAP: 0.5564
#   [GAMO - MLP]
#     AUROC: 0.9537
#     G-mean: 0.7748
#     MCC: 0.6663
#     F1-score: 0.6833
#     mAP: 0.7282
#   [GAMO - RandomForest]
#     AUROC: 0.9849
#     G-mean: 0.9218
#     MCC: 0.8659
#     F1-score: 0.8766
#     mAP: 0.9112
#   [MGVAE - SVM]
#     AUROC: 0.9392
#     G-mean: 0.5256
#     MCC: 0.4428
#     F1-score: 0.4121
#     mAP: 0.7098
#   [MGVAE - DecisionTree]
#     AUROC: 0.9549
#     G-mean: 0.9192
#     MCC: 0.8528
#     F1-score: 0.8655
#     mAP: 0.8223
#   [MGVAE - kNN]
#     AUROC: 0.8848
#     G-mean: 0.6690
#     MCC: 0.5504
#     F1-score: 0.5637
#     mAP: 0.5622
#   [MGVAE - MLP]
#     AUROC: 0.9372
#     G-mean: 0.7356
#     MCC: 0.6286
#     F1-score: 0.6436
#     mAP: 0.7155
#   [MGVAE - RandomForest]
#     AUROC: 0.9840
#     G-mean: 0.9207
#     MCC: 0.8662
#     F1-score: 0.8769
#     mAP: 0.9074
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.9111
#     G-mean: 0.3293
#     MCC: 0.1985
#     F1-score: 0.1905
#     mAP: 0.4858
#   [GAMO - DecisionTree]
#     AUROC: 0.9627
#     G-mean: 0.9235
#     MCC: 0.8198
#     F1-score: 0.8349
#     mAP: 0.7681
#   [GAMO - kNN]
#     AUROC: 0.8852
#     G-mean: 0.6723
#     MCC: 0.5497
#     F1-score: 0.5649
#     mAP: 0.5604
#   [GAMO - MLP]
#     AUROC: 0.9540
#     G-mean: 0.7809
#     MCC: 0.6703
#     F1-score: 0.6882
#     mAP: 0.7343
#   [GAMO - RandomForest]
#     AUROC: 0.9851
#     G-mean: 0.9225
#     MCC: 0.8677
#     F1-score: 0.8784
#     mAP: 0.9099
#   [MGVAE - SVM]
#     AUROC: 0.9392
#     G-mean: 0.5265
#     MCC: 0.4430
#     F1-score: 0.4131
#     mAP: 0.7108
#   [MGVAE - DecisionTree]
#     AUROC: 0.9586
#     G-mean: 0.9218
#     MCC: 0.8545
#     F1-score: 0.8670
#     mAP: 0.8249
#   [MGVAE - kNN]
#     AUROC: 0.8857
#     G-mean: 0.6725
#     MCC: 0.5535
#     F1-score: 0.5673
#     mAP: 0.5665
#   [MGVAE - MLP]
#     AUROC: 0.9412
#     G-mean: 0.7547
#     MCC: 0.6505
#     F1-score: 0.6658
#     mAP: 0.7328
#   [MGVAE - RandomForest]
#     AUROC: 0.9845
#     G-mean: 0.9213
#     MCC: 0.8668
#     F1-score: 0.8777
#     mAP: 0.9062
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.9117
#     G-mean: 0.3291
#     MCC: 0.1980
#     F1-score: 0.1904
#     mAP: 0.4886
#   [GAMO - DecisionTree]
#     AUROC: 0.9641
#     G-mean: 0.9243
#     MCC: 0.8239
#     F1-score: 0.8387
#     mAP: 0.7747
#   [GAMO - kNN]
#     AUROC: 0.8860
#     G-mean: 0.6745
#     MCC: 0.5530
#     F1-score: 0.5681
#     mAP: 0.5609
#   [GAMO - MLP]
#     AUROC: 0.9543
#     G-mean: 0.7803
#     MCC: 0.6680
#     F1-score: 0.6859
#     mAP: 0.7348
#   [GAMO - RandomForest]
#     AUROC: 0.9851
#     G-mean: 0.9242
#     MCC: 0.8700
#     F1-score: 0.8806
#     mAP: 0.9088
#   [MGVAE - SVM]
#     AUROC: 0.9391
#     G-mean: 0.5266
#     MCC: 0.4434
#     F1-score: 0.4134
#     mAP: 0.7117
#   [MGVAE - DecisionTree]
#     AUROC: 0.9581
#     G-mean: 0.9223
#     MCC: 0.8547
#     F1-score: 0.8672
#     mAP: 0.8231
#   [MGVAE - kNN]
#     AUROC: 0.8865
#     G-mean: 0.6747
#     MCC: 0.5567
#     F1-score: 0.5704
#     mAP: 0.5669
#   [MGVAE - MLP]
#     AUROC: 0.9418
#     G-mean: 0.7526
#     MCC: 0.6474
#     F1-score: 0.6632
#     mAP: 0.7313
#   [MGVAE - RandomForest]
#     AUROC: 0.9846
#     G-mean: 0.9218
#     MCC: 0.8677
#     F1-score: 0.8785
#     mAP: 0.9069
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.9100
#     G-mean: 0.3323
#     MCC: 0.2005
#     F1-score: 0.1920
#     mAP: 0.4821
#   [GAMO - DecisionTree]
#     AUROC: 0.9635
#     G-mean: 0.9221
#     MCC: 0.8212
#     F1-score: 0.8363
#     mAP: 0.7754
#   [GAMO - kNN]
#     AUROC: 0.8871
#     G-mean: 0.6745
#     MCC: 0.5516
#     F1-score: 0.5671
#     mAP: 0.5604
#   [GAMO - MLP]
#     AUROC: 0.9550
#     G-mean: 0.7785
#     MCC: 0.6676
#     F1-score: 0.6855
#     mAP: 0.7401
#   [GAMO - RandomForest]
#     AUROC: 0.9850
#     G-mean: 0.9238
#     MCC: 0.8688
#     F1-score: 0.8796
#     mAP: 0.9085
#   [MGVAE - SVM]
#     AUROC: 0.9393
#     G-mean: 0.5291
#     MCC: 0.4460
#     F1-score: 0.4164
#     mAP: 0.7102
#   [MGVAE - DecisionTree]
#     AUROC: 0.9588
#     G-mean: 0.9216
#     MCC: 0.8526
#     F1-score: 0.8653
#     mAP: 0.8245
#   [MGVAE - kNN]
#     AUROC: 0.8875
#     G-mean: 0.6747
#     MCC: 0.5553
#     F1-score: 0.5695
#     mAP: 0.5663
#   [MGVAE - MLP]
#     AUROC: 0.9429
#     G-mean: 0.7588
#     MCC: 0.6535
#     F1-score: 0.6700
#     mAP: 0.7343
#   [MGVAE - RandomForest]
#     AUROC: 0.9846
#     G-mean: 0.9215
#     MCC: 0.8671
#     F1-score: 0.8780
#     mAP: 0.9080
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.9105
#     G-mean: 0.3347
#     MCC: 0.2023
#     F1-score: 0.1931
#     mAP: 0.4822
#   [GAMO - DecisionTree]
#     AUROC: 0.9640
#     G-mean: 0.9222
#     MCC: 0.8222
#     F1-score: 0.8372
#     mAP: 0.7756
#   [GAMO - kNN]
#     AUROC: 0.8874
#     G-mean: 0.6746
#     MCC: 0.5525
#     F1-score: 0.5679
#     mAP: 0.5624
#   [GAMO - MLP]
#     AUROC: 0.9551
#     G-mean: 0.7840
#     MCC: 0.6722
#     F1-score: 0.6908
#     mAP: 0.7411
#   [GAMO - RandomForest]
#     AUROC: 0.9852
#     G-mean: 0.9239
#     MCC: 0.8689
#     F1-score: 0.8796
#     mAP: 0.9095
#   [MGVAE - SVM]
#     AUROC: 0.9394
#     G-mean: 0.5331
#     MCC: 0.4502
#     F1-score: 0.4213
#     mAP: 0.7105
#   [MGVAE - DecisionTree]
#     AUROC: 0.9601
#     G-mean: 0.9219
#     MCC: 0.8531
#     F1-score: 0.8658
#     mAP: 0.8270
#   [MGVAE - kNN]
#     AUROC: 0.8879
#     G-mean: 0.6749
#     MCC: 0.5563
#     F1-score: 0.5703
#     mAP: 0.5682
#   [MGVAE - MLP]
#     AUROC: 0.9437
#     G-mean: 0.7538
#     MCC: 0.6477
#     F1-score: 0.6639
#     mAP: 0.7323
#   [MGVAE - RandomForest]
#     AUROC: 0.9846
#     G-mean: 0.9216
#     MCC: 0.8673
#     F1-score: 0.8782
#     mAP: 0.9087
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.9117
#     G-mean: 0.3364
#     MCC: 0.2039
#     F1-score: 0.1949
#     mAP: 0.4865
#   [GAMO - DecisionTree]
#     AUROC: 0.9640
#     G-mean: 0.9233
#     MCC: 0.8210
#     F1-score: 0.8361
#     mAP: 0.7720
#   [GAMO - kNN]
#     AUROC: 0.8876
#     G-mean: 0.6752
#     MCC: 0.5521
#     F1-score: 0.5681
#     mAP: 0.5621
#   [GAMO - MLP]
#     AUROC: 0.9551
#     G-mean: 0.7834
#     MCC: 0.6701
#     F1-score: 0.6891
#     mAP: 0.7399
#   [GAMO - RandomForest]
#     AUROC: 0.9846
#     G-mean: 0.9239
#     MCC: 0.8690
#     F1-score: 0.8798
#     mAP: 0.9086
#   [MGVAE - SVM]
#     AUROC: 0.9395
#     G-mean: 0.5343
#     MCC: 0.4509
#     F1-score: 0.4227
#     mAP: 0.7099
#   [MGVAE - DecisionTree]
#     AUROC: 0.9605
#     G-mean: 0.9212
#     MCC: 0.8515
#     F1-score: 0.8644
#     mAP: 0.8253
#   [MGVAE - kNN]
#     AUROC: 0.8881
#     G-mean: 0.6755
#     MCC: 0.5558
#     F1-score: 0.5704
#     mAP: 0.5676
#   [MGVAE - MLP]
#     AUROC: 0.9445
#     G-mean: 0.7572
#     MCC: 0.6514
#     F1-score: 0.6675
#     mAP: 0.7357
#   [MGVAE - RandomForest]
#     AUROC: 0.9842
#     G-mean: 0.9222
#     MCC: 0.8677
#     F1-score: 0.8786
#     mAP: 0.9088
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.9120
#     G-mean: 0.3377
#     MCC: 0.2055
#     F1-score: 0.1955
#     mAP: 0.4892
#   [GAMO - DecisionTree]
#     AUROC: 0.9643
#     G-mean: 0.9233
#     MCC: 0.8198
#     F1-score: 0.8349
#     mAP: 0.7720
#   [GAMO - kNN]
#     AUROC: 0.8874
#     G-mean: 0.6737
#     MCC: 0.5510
#     F1-score: 0.5666
#     mAP: 0.5611
#   [GAMO - MLP]
#     AUROC: 0.9553
#     G-mean: 0.7853
#     MCC: 0.6724
#     F1-score: 0.6916
#     mAP: 0.7406
#   [GAMO - RandomForest]
#     AUROC: 0.9846
#     G-mean: 0.9241
#     MCC: 0.8686
#     F1-score: 0.8795
#     mAP: 0.9094
#   [MGVAE - SVM]
#     AUROC: 0.9395
#     G-mean: 0.5368
#     MCC: 0.4539
#     F1-score: 0.4260
#     mAP: 0.7100
#   [MGVAE - DecisionTree]
#     AUROC: 0.9607
#     G-mean: 0.9210
#     MCC: 0.8517
#     F1-score: 0.8645
#     mAP: 0.8253
#   [MGVAE - kNN]
#     AUROC: 0.8879
#     G-mean: 0.6739
#     MCC: 0.5548
#     F1-score: 0.5689
#     mAP: 0.5665
#   [MGVAE - MLP]
#     AUROC: 0.9451
#     G-mean: 0.7619
#     MCC: 0.6571
#     F1-score: 0.6735
#     mAP: 0.7389
#   [MGVAE - RandomForest]
#     AUROC: 0.9843
#     G-mean: 0.9223
#     MCC: 0.8673
#     F1-score: 0.8782
#     mAP: 0.9093
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.9116
#     G-mean: 0.3365
#     MCC: 0.2035
#     F1-score: 0.1938
#     mAP: 0.4885
#   [GAMO - DecisionTree]
#     AUROC: 0.9642
#     G-mean: 0.9241
#     MCC: 0.8204
#     F1-score: 0.8356
#     mAP: 0.7726
#   [GAMO - kNN]
#     AUROC: 0.8874
#     G-mean: 0.6730
#     MCC: 0.5504
#     F1-score: 0.5657
#     mAP: 0.5618
#   [GAMO - MLP]
#     AUROC: 0.9550
#     G-mean: 0.7847
#     MCC: 0.6717
#     F1-score: 0.6907
#     mAP: 0.7393
#   [GAMO - RandomForest]
#     AUROC: 0.9847
#     G-mean: 0.9235
#     MCC: 0.8684
#     F1-score: 0.8793
#     mAP: 0.9088
#   [MGVAE - SVM]
#     AUROC: 0.9395
#     G-mean: 0.5370
#     MCC: 0.4540
#     F1-score: 0.4262
#     mAP: 0.7101
#   [MGVAE - DecisionTree]
#     AUROC: 0.9610
#     G-mean: 0.9220
#     MCC: 0.8524
#     F1-score: 0.8651
#     mAP: 0.8245
#   [MGVAE - kNN]
#     AUROC: 0.8879
#     G-mean: 0.6732
#     MCC: 0.5541
#     F1-score: 0.5681
#     mAP: 0.5672
#   [MGVAE - MLP]
#     AUROC: 0.9458
#     G-mean: 0.7658
#     MCC: 0.6622
#     F1-score: 0.6785
#     mAP: 0.7427
#   [MGVAE - RandomForest]
#     AUROC: 0.9843
#     G-mean: 0.9219
#     MCC: 0.8666
#     F1-score: 0.8776
#     mAP: 0.9091
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/sick_euthyroid_results_GAMO_MGVAE_beta_0.001.csv

# %%
# solar_flare_m0
data_name = 'solar_flare_m0'
maj_target_name = -1

n_epochs = 1000
hidden_dims = [32, 64, 128, 256]
latent_dim = 512
lr = 0.005
beta = 0.001

final_res = run_exp(
    data=data, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    kernel_type=kernel_type,
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    maj_target_name=maj_target_name,
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded: solar_flare_m0
# X shape : (1389, 32)
# target : Counter({0: 1321, 1: 68})
# IR: 19.43
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.6107
#     G-mean: 0.1276
#     MCC: 0.0472
#     F1-score: 0.0709
#     mAP: 0.1597
#   [GAMO - DecisionTree]
#     AUROC: 0.6613
#     G-mean: 0.0756
#     MCC: 0.0649
#     F1-score: 0.0500
#     mAP: 0.1465
#   [GAMO - kNN]
#     AUROC: 0.6538
#     G-mean: 0.0000
#     MCC: -0.0111
#     F1-score: 0.0000
#     mAP: 0.1220
#   [GAMO - MLP]
#     AUROC: 0.7103
#     G-mean: 0.1917
#     MCC: 0.0839
#     F1-score: 0.1101
#     mAP: 0.1809
#   [GAMO - RandomForest]
#     AUROC: 0.7943
#     G-mean: 0.0750
#     MCC: 0.0247
#     F1-score: 0.0404
#     mAP: 0.2083
#   [MGVAE - SVM]
#     AUROC: 0.6707
#     G-mean: 0.0000
#     MCC: -0.0054
#     F1-score: 0.0000
#     mAP: 0.1726
#   [MGVAE - DecisionTree]
#     AUROC: 0.6453
#     G-mean: 0.0749
#     MCC: 0.0193
#     F1-score: 0.0382
#     mAP: 0.1395
#   [MGVAE - kNN]
#     AUROC: 0.6555
#     G-mean: 0.0000
#     MCC: -0.0111
#     F1-score: 0.0000
#     mAP: 0.1236
#   [MGVAE - MLP]
#     AUROC: 0.7782
#     G-mean: 0.3794
#     MCC: 0.1952
#     F1-score: 0.2199
#     mAP: 0.2573
#   [MGVAE - RandomForest]
#     AUROC: 0.7920
#     G-mean: 0.0000
#     MCC: -0.0221
#     F1-score: 0.0000
#     mAP: 0.2046
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.6123
#     G-mean: 0.1389
#     MCC: 0.0563
#     F1-score: 0.0776
#     mAP: 0.1573
#   [GAMO - DecisionTree]
#     AUROC: 0.6761
#     G-mean: 0.1021
#     MCC: 0.0738
#     F1-score: 0.0683
#     mAP: 0.1651
#   [GAMO - kNN]
#     AUROC: 0.6612
#     G-mean: 0.0189
#     MCC: 0.0056
#     F1-score: 0.0125
#     mAP: 0.1443
#   [GAMO - MLP]
#     AUROC: 0.7212
#     G-mean: 0.2049
#     MCC: 0.0980
#     F1-score: 0.1200
#     mAP: 0.1817
#   [GAMO - RandomForest]
#     AUROC: 0.7914
#     G-mean: 0.0375
#     MCC: 0.0010
#     F1-score: 0.0202
#     mAP: 0.2084
#   [MGVAE - SVM]
#     AUROC: 0.6706
#     G-mean: 0.0000
#     MCC: -0.0046
#     F1-score: 0.0000
#     mAP: 0.1793
#   [MGVAE - DecisionTree]
#     AUROC: 0.6447
#     G-mean: 0.1667
#     MCC: 0.0830
#     F1-score: 0.0948
#     mAP: 0.1552
#   [MGVAE - kNN]
#     AUROC: 0.6623
#     G-mean: 0.0189
#     MCC: 0.0056
#     F1-score: 0.0125
#     mAP: 0.1455
#   [MGVAE - MLP]
#     AUROC: 0.7869
#     G-mean: 0.4208
#     MCC: 0.2307
#     F1-score: 0.2561
#     mAP: 0.2691
#   [MGVAE - RandomForest]
#     AUROC: 0.7927
#     G-mean: 0.0000
#     MCC: -0.0227
#     F1-score: 0.0000
#     mAP: 0.2021
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.6057
#     G-mean: 0.1436
#     MCC: 0.0592
#     F1-score: 0.0786
#     mAP: 0.1540
#   [GAMO - DecisionTree]
#     AUROC: 0.6743
#     G-mean: 0.1327
#     MCC: 0.0898
#     F1-score: 0.0831
#     mAP: 0.1760
#   [GAMO - kNN]
#     AUROC: 0.6603
#     G-mean: 0.0126
#     MCC: -0.0016
#     F1-score: 0.0083
#     mAP: 0.1362
#   [GAMO - MLP]
#     AUROC: 0.7173
#     G-mean: 0.2309
#     MCC: 0.1159
#     F1-score: 0.1313
#     mAP: 0.1857
#   [GAMO - RandomForest]
#     AUROC: 0.7893
#     G-mean: 0.0552
#     MCC: 0.0130
#     F1-score: 0.0320
#     mAP: 0.1986
#   [MGVAE - SVM]
#     AUROC: 0.6655
#     G-mean: 0.0000
#     MCC: -0.0044
#     F1-score: 0.0000
#     mAP: 0.1743
#   [MGVAE - DecisionTree]
#     AUROC: 0.6492
#     G-mean: 0.1884
#     MCC: 0.1085
#     F1-score: 0.1090
#     mAP: 0.1688
#   [MGVAE - kNN]
#     AUROC: 0.6614
#     G-mean: 0.0126
#     MCC: -0.0016
#     F1-score: 0.0083
#     mAP: 0.1372
#   [MGVAE - MLP]
#     AUROC: 0.7832
#     G-mean: 0.4155
#     MCC: 0.2264
#     F1-score: 0.2479
#     mAP: 0.2610
#   [MGVAE - RandomForest]
#     AUROC: 0.7878
#     G-mean: 0.0427
#     MCC: 0.0045
#     F1-score: 0.0252
#     mAP: 0.1946
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.6106
#     G-mean: 0.1461
#     MCC: 0.0660
#     F1-score: 0.0820
#     mAP: 0.1574
#   [GAMO - DecisionTree]
#     AUROC: 0.6674
#     G-mean: 0.1418
#     MCC: 0.0893
#     F1-score: 0.0856
#     mAP: 0.1688
#   [GAMO - kNN]
#     AUROC: 0.6622
#     G-mean: 0.0291
#     MCC: 0.0150
#     F1-score: 0.0197
#     mAP: 0.1425
#   [GAMO - MLP]
#     AUROC: 0.7146
#     G-mean: 0.2285
#     MCC: 0.1201
#     F1-score: 0.1330
#     mAP: 0.1896
#   [GAMO - RandomForest]
#     AUROC: 0.7783
#     G-mean: 0.0600
#     MCC: 0.0128
#     F1-score: 0.0324
#     mAP: 0.1951
#   [MGVAE - SVM]
#     AUROC: 0.6584
#     G-mean: 0.0000
#     MCC: -0.0047
#     F1-score: 0.0000
#     mAP: 0.1700
#   [MGVAE - DecisionTree]
#     AUROC: 0.6717
#     G-mean: 0.2022
#     MCC: 0.1214
#     F1-score: 0.1189
#     mAP: 0.1850
#   [MGVAE - kNN]
#     AUROC: 0.6632
#     G-mean: 0.0291
#     MCC: 0.0150
#     F1-score: 0.0197
#     mAP: 0.1434
#   [MGVAE - MLP]
#     AUROC: 0.7805
#     G-mean: 0.4096
#     MCC: 0.2278
#     F1-score: 0.2494
#     mAP: 0.2681
#   [MGVAE - RandomForest]
#     AUROC: 0.7762
#     G-mean: 0.0413
#     MCC: 0.0018
#     F1-score: 0.0227
#     mAP: 0.1911
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.6154
#     G-mean: 0.1549
#     MCC: 0.0681
#     F1-score: 0.0850
#     mAP: 0.1594
#   [GAMO - DecisionTree]
#     AUROC: 0.6620
#     G-mean: 0.1481
#     MCC: 0.0917
#     F1-score: 0.0899
#     mAP: 0.1665
#   [GAMO - kNN]
#     AUROC: 0.6666
#     G-mean: 0.0384
#     MCC: 0.0221
#     F1-score: 0.0252
#     mAP: 0.1470
#   [GAMO - MLP]
#     AUROC: 0.7162
#     G-mean: 0.2345
#     MCC: 0.1225
#     F1-score: 0.1363
#     mAP: 0.1943
#   [GAMO - RandomForest]
#     AUROC: 0.7826
#     G-mean: 0.0561
#     MCC: 0.0101
#     F1-score: 0.0304
#     mAP: 0.1941
#   [MGVAE - SVM]
#     AUROC: 0.6575
#     G-mean: 0.0000
#     MCC: -0.0045
#     F1-score: 0.0000
#     mAP: 0.1654
#   [MGVAE - DecisionTree]
#     AUROC: 0.6611
#     G-mean: 0.1924
#     MCC: 0.1102
#     F1-score: 0.1116
#     mAP: 0.1754
#   [MGVAE - kNN]
#     AUROC: 0.6677
#     G-mean: 0.0384
#     MCC: 0.0221
#     F1-score: 0.0252
#     mAP: 0.1480
#   [MGVAE - MLP]
#     AUROC: 0.7775
#     G-mean: 0.3903
#     MCC: 0.2141
#     F1-score: 0.2366
#     mAP: 0.2675
#   [MGVAE - RandomForest]
#     AUROC: 0.7791
#     G-mean: 0.0491
#     MCC: 0.0048
#     F1-score: 0.0260
#     mAP: 0.1896
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.6119
#     G-mean: 0.1477
#     MCC: 0.0614
#     F1-score: 0.0801
#     mAP: 0.1535
#   [GAMO - DecisionTree]
#     AUROC: 0.6671
#     G-mean: 0.1489
#     MCC: 0.0883
#     F1-score: 0.0886
#     mAP: 0.1709
#   [GAMO - kNN]
#     AUROC: 0.6665
#     G-mean: 0.0450
#     MCC: 0.0248
#     F1-score: 0.0288
#     mAP: 0.1452
#   [GAMO - MLP]
#     AUROC: 0.7138
#     G-mean: 0.2338
#     MCC: 0.1246
#     F1-score: 0.1377
#     mAP: 0.1941
#   [GAMO - RandomForest]
#     AUROC: 0.7842
#     G-mean: 0.0530
#     MCC: 0.0080
#     F1-score: 0.0286
#     mAP: 0.1934
#   [MGVAE - SVM]
#     AUROC: 0.6648
#     G-mean: 0.0000
#     MCC: -0.0047
#     F1-score: 0.0000
#     mAP: 0.1607
#   [MGVAE - DecisionTree]
#     AUROC: 0.6645
#     G-mean: 0.1792
#     MCC: 0.1040
#     F1-score: 0.1044
#     mAP: 0.1782
#   [MGVAE - kNN]
#     AUROC: 0.6676
#     G-mean: 0.0450
#     MCC: 0.0248
#     F1-score: 0.0288
#     mAP: 0.1466
#   [MGVAE - MLP]
#     AUROC: 0.7754
#     G-mean: 0.3826
#     MCC: 0.2148
#     F1-score: 0.2349
#     mAP: 0.2659
#   [MGVAE - RandomForest]
#     AUROC: 0.7815
#     G-mean: 0.0472
#     MCC: 0.0035
#     F1-score: 0.0250
#     mAP: 0.1896
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.6139
#     G-mean: 0.1396
#     MCC: 0.0562
#     F1-score: 0.0763
#     mAP: 0.1520
#   [GAMO - DecisionTree]
#     AUROC: 0.6716
#     G-mean: 0.1459
#     MCC: 0.0848
#     F1-score: 0.0864
#     mAP: 0.1712
#   [GAMO - kNN]
#     AUROC: 0.6642
#     G-mean: 0.0515
#     MCC: 0.0290
#     F1-score: 0.0331
#     mAP: 0.1420
#   [GAMO - MLP]
#     AUROC: 0.7142
#     G-mean: 0.2296
#     MCC: 0.1248
#     F1-score: 0.1380
#     mAP: 0.1941
#   [GAMO - RandomForest]
#     AUROC: 0.7845
#     G-mean: 0.0508
#     MCC: 0.0065
#     F1-score: 0.0274
#     mAP: 0.1922
#   [MGVAE - SVM]
#     AUROC: 0.6617
#     G-mean: 0.0000
#     MCC: -0.0046
#     F1-score: 0.0000
#     mAP: 0.1557
#   [MGVAE - DecisionTree]
#     AUROC: 0.6549
#     G-mean: 0.1740
#     MCC: 0.0982
#     F1-score: 0.1017
#     mAP: 0.1720
#   [MGVAE - kNN]
#     AUROC: 0.6654
#     G-mean: 0.0515
#     MCC: 0.0290
#     F1-score: 0.0331
#     mAP: 0.1433
#   [MGVAE - MLP]
#     AUROC: 0.7751
#     G-mean: 0.3887
#     MCC: 0.2198
#     F1-score: 0.2388
#     mAP: 0.2632
#   [MGVAE - RandomForest]
#     AUROC: 0.7817
#     G-mean: 0.0458
#     MCC: 0.0027
#     F1-score: 0.0243
#     mAP: 0.1892
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.6123
#     G-mean: 0.1364
#     MCC: 0.0523
#     F1-score: 0.0733
#     mAP: 0.1528
#   [GAMO - DecisionTree]
#     AUROC: 0.6742
#     G-mean: 0.1534
#     MCC: 0.0917
#     F1-score: 0.0911
#     mAP: 0.1731
#   [GAMO - kNN]
#     AUROC: 0.6664
#     G-mean: 0.0498
#     MCC: 0.0261
#     F1-score: 0.0314
#     mAP: 0.1417
#   [GAMO - MLP]
#     AUROC: 0.7148
#     G-mean: 0.2352
#     MCC: 0.1302
#     F1-score: 0.1419
#     mAP: 0.1958
#   [GAMO - RandomForest]
#     AUROC: 0.7838
#     G-mean: 0.0538
#     MCC: 0.0082
#     F1-score: 0.0288
#     mAP: 0.1898
#   [MGVAE - SVM]
#     AUROC: 0.6634
#     G-mean: 0.0000
#     MCC: -0.0052
#     F1-score: 0.0000
#     mAP: 0.1556
#   [MGVAE - DecisionTree]
#     AUROC: 0.6546
#     G-mean: 0.1733
#     MCC: 0.0974
#     F1-score: 0.1016
#     mAP: 0.1728
#   [MGVAE - kNN]
#     AUROC: 0.6676
#     G-mean: 0.0498
#     MCC: 0.0261
#     F1-score: 0.0314
#     mAP: 0.1430
#   [MGVAE - MLP]
#     AUROC: 0.7746
#     G-mean: 0.3908
#     MCC: 0.2214
#     F1-score: 0.2373
#     mAP: 0.2597
#   [MGVAE - RandomForest]
#     AUROC: 0.7809
#     G-mean: 0.0495
#     MCC: 0.0051
#     F1-score: 0.0263
#     mAP: 0.1872
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.6149
#     G-mean: 0.1368
#     MCC: 0.0529
#     F1-score: 0.0744
#     mAP: 0.1552
#   [GAMO - DecisionTree]
#     AUROC: 0.6710
#     G-mean: 0.1530
#     MCC: 0.0898
#     F1-score: 0.0899
#     mAP: 0.1712
#   [GAMO - kNN]
#     AUROC: 0.6667
#     G-mean: 0.0485
#     MCC: 0.0260
#     F1-score: 0.0307
#     mAP: 0.1434
#   [GAMO - MLP]
#     AUROC: 0.7151
#     G-mean: 0.2456
#     MCC: 0.1331
#     F1-score: 0.1457
#     mAP: 0.1961
#   [GAMO - RandomForest]
#     AUROC: 0.7841
#     G-mean: 0.0561
#     MCC: 0.0093
#     F1-score: 0.0299
#     mAP: 0.1912
#   [MGVAE - SVM]
#     AUROC: 0.6646
#     G-mean: 0.0000
#     MCC: -0.0055
#     F1-score: 0.0000
#     mAP: 0.1598
#   [MGVAE - DecisionTree]
#     AUROC: 0.6568
#     G-mean: 0.1696
#     MCC: 0.0951
#     F1-score: 0.0998
#     mAP: 0.1727
#   [MGVAE - kNN]
#     AUROC: 0.6679
#     G-mean: 0.0485
#     MCC: 0.0260
#     F1-score: 0.0307
#     mAP: 0.1447
#   [MGVAE - MLP]
#     AUROC: 0.7759
#     G-mean: 0.3941
#     MCC: 0.2266
#     F1-score: 0.2421
#     mAP: 0.2628
#   [MGVAE - RandomForest]
#     AUROC: 0.7817
#     G-mean: 0.0523
#     MCC: 0.0066
#     F1-score: 0.0276
#     mAP: 0.1891
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.6163
#     G-mean: 0.1423
#     MCC: 0.0533
#     F1-score: 0.0756
#     mAP: 0.1557
#   [GAMO - DecisionTree]
#     AUROC: 0.6745
#     G-mean: 0.1571
#     MCC: 0.0933
#     F1-score: 0.0919
#     mAP: 0.1785
#   [GAMO - kNN]
#     AUROC: 0.6676
#     G-mean: 0.0592
#     MCC: 0.0332
#     F1-score: 0.0367
#     mAP: 0.1457
#   [GAMO - MLP]
#     AUROC: 0.7166
#     G-mean: 0.2521
#     MCC: 0.1364
#     F1-score: 0.1495
#     mAP: 0.1960
#   [GAMO - RandomForest]
#     AUROC: 0.7850
#     G-mean: 0.0583
#     MCC: 0.0092
#     F1-score: 0.0304
#     mAP: 0.1935
#   [MGVAE - SVM]
#     AUROC: 0.6660
#     G-mean: 0.0000
#     MCC: -0.0056
#     F1-score: 0.0000
#     mAP: 0.1608
#   [MGVAE - DecisionTree]
#     AUROC: 0.6625
#     G-mean: 0.1735
#     MCC: 0.0989
#     F1-score: 0.1027
#     mAP: 0.1766
#   [MGVAE - kNN]
#     AUROC: 0.6688
#     G-mean: 0.0592
#     MCC: 0.0332
#     F1-score: 0.0367
#     mAP: 0.1470
#   [MGVAE - MLP]
#     AUROC: 0.7773
#     G-mean: 0.3975
#     MCC: 0.2261
#     F1-score: 0.2424
#     mAP: 0.2632
#   [MGVAE - RandomForest]
#     AUROC: 0.7836
#     G-mean: 0.0548
#     MCC: 0.0069
#     F1-score: 0.0283
#     mAP: 0.1917
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/solar_flare_m0_results_GAMO_MGVAE_beta_0.001.csv
