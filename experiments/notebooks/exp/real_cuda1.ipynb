# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

import os
import warnings
import pandas as pd
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from experiment import run_exp

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# Save path 
save_path = "/data4/oldrain123/oldrain123/results/real_results"
data_path = "/data4/oldrain123/oldrain123/dataset"

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# methods = ["AdaBoost", "SMOTEBoost", "RUSBoost", "OUBoost", "Original", "SMOTE", "ADASYN", "bSMOTE", "ROS", "MWMOTE", "CTGAN", "Ours"]
methods = ['SMOTE', 'CTGAN', 'GAMO', 'MGVAE', 'Ours']
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}# base_model = RandomForestClassifier(n_estimators=500, random_state=1203)
kernel_type = 'gaussian'

# %%
# # 실험에 사용할 데이터셋
# data_name = 'ecoli-0-3-4_vs_5'

# # 실험 파라미터 설정
# n_epochs = 1000
# hidden_dims = [8, 16, 32, 64]
# latent_dim = 128
# lr = 0.001
# beta = 0.1 

# # 데이터 불러오기
# ecoli_0_3_4_vs_5 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# # 실험 실행
# final_res = run_exp(
#     data=ecoli_0_3_4_vs_5, 
#     kernel_type=kernel_type,
#     cat_idx=[], 
#     methods=methods, 
#     base_model=base_models, 
#     device=device,
#     n_epochs=n_epochs, 
#     hidden_dims=hidden_dims, 
#     latent_dim=latent_dim, 
#     lr=lr, 
#     beta=beta,
#     data_name=data_name, 
#     seed=1203, 
#     visualize=False, 
#     save_path=save_path
# )

# %%
data_name = 'ecoli3'

n_epochs = 2000
hidden_dims = [8, 16, 32, 64]
latent_dim = 128
lr = 0.001
beta = 0.01 

# Load dataset
ecoli3 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# Run experiment
final_res = run_exp(
    data=ecoli3, 
    kernel_type=kernel_type,
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=True, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (336, 7)
# target : Counter({0: 301, 1: 35})
# IR: 8.6
#
# Starting experiment 1/10...
# [Saved] t-SNE comparison figure saved to: /data4/oldrain123/oldrain123/results/real_results/ecoli3_tsne_comparison.pdf
# [Saved] t-SNE comparison figure saved to: /data4/oldrain123/oldrain123/results/real_results/ecoli3_tsne_comparison.pdf
# [Saved] t-SNE comparison figure saved to: /data4/oldrain123/oldrain123/results/real_results/ecoli3_tsne_comparison.pdf

# %%
data_name = 'ecoli4'

n_epochs = 1000
hidden_dims = [8, 16, 32, 64]
latent_dim = 128
lr = 0.001
beta = 0.1 

# Load dataset
ecoli4 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# Run experiment
final_res = run_exp(
    data=ecoli4, 
    kernel_type=kernel_type,
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (336, 7)
# target : Counter({0: 314, 1: 22})
# IR: 14.27
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.9744
#     G-mean: 0.8915
#     MCC: 0.5762
#     F1-score: 0.5659
#     mAP: 0.8500
#   [GAMO - DecisionTree]
#     AUROC: 0.8376
#     G-mean: 0.8163
#     MCC: 0.7408
#     F1-score: 0.7267
#     mAP: 0.6170
#   [GAMO - kNN]
#     AUROC: 0.9413
#     G-mean: 0.8877
#     MCC: 0.7102
#     F1-score: 0.7071
#     mAP: 0.8008
#   [GAMO - MLP]
#     AUROC: 0.9345
#     G-mean: 0.8552
#     MCC: 0.4210
#     F1-score: 0.3882
#     mAP: 0.8399
#   [GAMO - RandomForest]
#     AUROC: 0.9790
#     G-mean: 0.8206
#     MCC: 0.7951
#     F1-score: 0.7767
#     mAP: 0.9285
#   [MGVAE - SVM]
#     AUROC: 0.9758
#     G-mean: 0.8792
#     MCC: 0.8559
#     F1-score: 0.8433
#     mAP: 0.9226
#   [MGVAE - DecisionTree]
#     AUROC: 0.8362
#     G-mean: 0.8149
#     MCC: 0.7161
#     F1-score: 0.7067
#     mAP: 0.5735
#   [MGVAE - kNN]
#     AUROC: 0.9369
#     G-mean: 0.8792
#     MCC: 0.8559
#     F1-score: 0.8433
#     mAP: 0.8589
#   [MGVAE - MLP]
#     AUROC: 0.8823
#     G-mean: 0.7748
#     MCC: 0.4606
#     F1-score: 0.4770
#     mAP: 0.6913
#   [MGVAE - RandomForest]
#     AUROC: 0.9519
#     G-mean: 0.8515
#     MCC: 0.8452
#     F1-score: 0.8300
#     mAP: 0.9007
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.9709
#     G-mean: 0.8703
#     MCC: 0.5429
#     F1-score: 0.5373
#     mAP: 0.8256
#   [GAMO - DecisionTree]
#     AUROC: 0.8381
#     G-mean: 0.8140
#     MCC: 0.7338
#     F1-score: 0.7267
#     mAP: 0.6118
#   [GAMO - kNN]
#     AUROC: 0.9349
#     G-mean: 0.8603
#     MCC: 0.6831
#     F1-score: 0.6869
#     mAP: 0.8027
#   [GAMO - MLP]
#     AUROC: 0.9402
#     G-mean: 0.8586
#     MCC: 0.4279
#     F1-score: 0.3939
#     mAP: 0.8384
#   [GAMO - RandomForest]
#     AUROC: 0.9707
#     G-mean: 0.7972
#     MCC: 0.7725
#     F1-score: 0.7583
#     mAP: 0.9003
#   [MGVAE - SVM]
#     AUROC: 0.9683
#     G-mean: 0.8765
#     MCC: 0.8529
#     F1-score: 0.8417
#     mAP: 0.9156
#   [MGVAE - DecisionTree]
#     AUROC: 0.8296
#     G-mean: 0.7870
#     MCC: 0.7026
#     F1-score: 0.6969
#     mAP: 0.5847
#   [MGVAE - kNN]
#     AUROC: 0.9331
#     G-mean: 0.8757
#     MCC: 0.8431
#     F1-score: 0.8317
#     mAP: 0.8480
#   [MGVAE - MLP]
#     AUROC: 0.9118
#     G-mean: 0.8328
#     MCC: 0.4975
#     F1-score: 0.4984
#     mAP: 0.7552
#   [MGVAE - RandomForest]
#     AUROC: 0.9579
#     G-mean: 0.8080
#     MCC: 0.8020
#     F1-score: 0.7883
#     mAP: 0.8788
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.9638
#     G-mean: 0.8710
#     MCC: 0.5492
#     F1-score: 0.5449
#     mAP: 0.7966
#   [GAMO - DecisionTree]
#     AUROC: 0.8309
#     G-mean: 0.7726
#     MCC: 0.6998
#     F1-score: 0.6956
#     mAP: 0.6032
#   [GAMO - kNN]
#     AUROC: 0.9253
#     G-mean: 0.8552
#     MCC: 0.6595
#     F1-score: 0.6665
#     mAP: 0.7950
#   [GAMO - MLP]
#     AUROC: 0.9409
#     G-mean: 0.8626
#     MCC: 0.4299
#     F1-score: 0.3947
#     mAP: 0.8276
#   [GAMO - RandomForest]
#     AUROC: 0.9691
#     G-mean: 0.7623
#     MCC: 0.7371
#     F1-score: 0.7267
#     mAP: 0.8908
#   [MGVAE - SVM]
#     AUROC: 0.9657
#     G-mean: 0.8720
#     MCC: 0.8483
#     F1-score: 0.8367
#     mAP: 0.9087
#   [MGVAE - DecisionTree]
#     AUROC: 0.8117
#     G-mean: 0.7324
#     MCC: 0.6512
#     F1-score: 0.6480
#     mAP: 0.5599
#   [MGVAE - kNN]
#     AUROC: 0.9319
#     G-mean: 0.8709
#     MCC: 0.8352
#     F1-score: 0.8233
#     mAP: 0.8517
#   [MGVAE - MLP]
#     AUROC: 0.9066
#     G-mean: 0.7997
#     MCC: 0.4689
#     F1-score: 0.4767
#     mAP: 0.7240
#   [MGVAE - RandomForest]
#     AUROC: 0.9627
#     G-mean: 0.7858
#     MCC: 0.7811
#     F1-score: 0.7700
#     mAP: 0.8694
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.9605
#     G-mean: 0.8707
#     MCC: 0.5438
#     F1-score: 0.5380
#     mAP: 0.8014
#   [GAMO - DecisionTree]
#     AUROC: 0.8381
#     G-mean: 0.7704
#     MCC: 0.6988
#     F1-score: 0.6931
#     mAP: 0.6066
#   [GAMO - kNN]
#     AUROC: 0.9174
#     G-mean: 0.8540
#     MCC: 0.6645
#     F1-score: 0.6681
#     mAP: 0.7873
#   [GAMO - MLP]
#     AUROC: 0.9382
#     G-mean: 0.8569
#     MCC: 0.4269
#     F1-score: 0.3954
#     mAP: 0.8196
#   [GAMO - RandomForest]
#     AUROC: 0.9672
#     G-mean: 0.7567
#     MCC: 0.7328
#     F1-score: 0.7233
#     mAP: 0.8867
#   [MGVAE - SVM]
#     AUROC: 0.9645
#     G-mean: 0.8693
#     MCC: 0.8430
#     F1-score: 0.8308
#     mAP: 0.9040
#   [MGVAE - DecisionTree]
#     AUROC: 0.8236
#     G-mean: 0.7399
#     MCC: 0.6542
#     F1-score: 0.6526
#     mAP: 0.5736
#   [MGVAE - kNN]
#     AUROC: 0.9285
#     G-mean: 0.8682
#     MCC: 0.8275
#     F1-score: 0.8167
#     mAP: 0.8430
#   [MGVAE - MLP]
#     AUROC: 0.9030
#     G-mean: 0.8102
#     MCC: 0.4580
#     F1-score: 0.4597
#     mAP: 0.7062
#   [MGVAE - RandomForest]
#     AUROC: 0.9640
#     G-mean: 0.7892
#     MCC: 0.7846
#     F1-score: 0.7733
#     mAP: 0.8810
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.9610
#     G-mean: 0.8716
#     MCC: 0.5451
#     F1-score: 0.5391
#     mAP: 0.7983
#   [GAMO - DecisionTree]
#     AUROC: 0.8374
#     G-mean: 0.7613
#     MCC: 0.6926
#     F1-score: 0.6905
#     mAP: 0.6162
#   [GAMO - kNN]
#     AUROC: 0.9161
#     G-mean: 0.8537
#     MCC: 0.6660
#     F1-score: 0.6691
#     mAP: 0.7774
#   [GAMO - MLP]
#     AUROC: 0.9446
#     G-mean: 0.8626
#     MCC: 0.4331
#     F1-score: 0.4006
#     mAP: 0.8317
#   [GAMO - RandomForest]
#     AUROC: 0.9656
#     G-mean: 0.7593
#     MCC: 0.7383
#     F1-score: 0.7287
#     mAP: 0.8795
#   [MGVAE - SVM]
#     AUROC: 0.9627
#     G-mean: 0.8550
#     MCC: 0.8295
#     F1-score: 0.8173
#     mAP: 0.9022
#   [MGVAE - DecisionTree]
#     AUROC: 0.8275
#     G-mean: 0.7410
#     MCC: 0.6573
#     F1-score: 0.6575
#     mAP: 0.5845
#   [MGVAE - kNN]
#     AUROC: 0.9298
#     G-mean: 0.8682
#     MCC: 0.8311
#     F1-score: 0.8193
#     mAP: 0.8429
#   [MGVAE - MLP]
#     AUROC: 0.9069
#     G-mean: 0.8012
#     MCC: 0.4469
#     F1-score: 0.4480
#     mAP: 0.7187
#   [MGVAE - RandomForest]
#     AUROC: 0.9647
#     G-mean: 0.7759
#     MCC: 0.7716
#     F1-score: 0.7613
#     mAP: 0.8704
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.9615
#     G-mean: 0.8678
#     MCC: 0.5428
#     F1-score: 0.5370
#     mAP: 0.8005
#   [GAMO - DecisionTree]
#     AUROC: 0.8283
#     G-mean: 0.7539
#     MCC: 0.6826
#     F1-score: 0.6810
#     mAP: 0.6018
#   [GAMO - kNN]
#     AUROC: 0.9134
#     G-mean: 0.8579
#     MCC: 0.6675
#     F1-score: 0.6703
#     mAP: 0.7799
#   [GAMO - MLP]
#     AUROC: 0.9478
#     G-mean: 0.8670
#     MCC: 0.4381
#     F1-score: 0.4042
#     mAP: 0.8300
#   [GAMO - RandomForest]
#     AUROC: 0.9663
#     G-mean: 0.7745
#     MCC: 0.7528
#     F1-score: 0.7439
#     mAP: 0.8806
#   [MGVAE - SVM]
#     AUROC: 0.9633
#     G-mean: 0.8572
#     MCC: 0.8322
#     F1-score: 0.8194
#     mAP: 0.9021
#   [MGVAE - DecisionTree]
#     AUROC: 0.8340
#     G-mean: 0.7535
#     MCC: 0.6712
#     F1-score: 0.6690
#     mAP: 0.5906
#   [MGVAE - kNN]
#     AUROC: 0.9295
#     G-mean: 0.8680
#     MCC: 0.8309
#     F1-score: 0.8187
#     mAP: 0.8436
#   [MGVAE - MLP]
#     AUROC: 0.9062
#     G-mean: 0.7966
#     MCC: 0.4482
#     F1-score: 0.4514
#     mAP: 0.7280
#   [MGVAE - RandomForest]
#     AUROC: 0.9654
#     G-mean: 0.7885
#     MCC: 0.7839
#     F1-score: 0.7728
#     mAP: 0.8715
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.9624
#     G-mean: 0.8702
#     MCC: 0.5502
#     F1-score: 0.5451
#     mAP: 0.8012
#   [GAMO - DecisionTree]
#     AUROC: 0.8277
#     G-mean: 0.7563
#     MCC: 0.6789
#     F1-score: 0.6780
#     mAP: 0.5905
#   [GAMO - kNN]
#     AUROC: 0.9155
#     G-mean: 0.8601
#     MCC: 0.6701
#     F1-score: 0.6727
#     mAP: 0.7845
#   [GAMO - MLP]
#     AUROC: 0.9471
#     G-mean: 0.8674
#     MCC: 0.4397
#     F1-score: 0.4061
#     mAP: 0.8300
#   [GAMO - RandomForest]
#     AUROC: 0.9679
#     G-mean: 0.7872
#     MCC: 0.7658
#     F1-score: 0.7565
#     mAP: 0.8797
#   [MGVAE - SVM]
#     AUROC: 0.9630
#     G-mean: 0.8582
#     MCC: 0.8360
#     F1-score: 0.8233
#     mAP: 0.9010
#   [MGVAE - DecisionTree]
#     AUROC: 0.8281
#     G-mean: 0.7572
#     MCC: 0.6694
#     F1-score: 0.6672
#     mAP: 0.5775
#   [MGVAE - kNN]
#     AUROC: 0.9291
#     G-mean: 0.8670
#     MCC: 0.8300
#     F1-score: 0.8178
#     mAP: 0.8410
#   [MGVAE - MLP]
#     AUROC: 0.9023
#     G-mean: 0.7886
#     MCC: 0.4381
#     F1-score: 0.4405
#     mAP: 0.7124
#   [MGVAE - RandomForest]
#     AUROC: 0.9661
#     G-mean: 0.7809
#     MCC: 0.7759
#     F1-score: 0.7643
#     mAP: 0.8725
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.9619
#     G-mean: 0.8694
#     MCC: 0.5469
#     F1-score: 0.5416
#     mAP: 0.7973
#   [GAMO - DecisionTree]
#     AUROC: 0.8257
#     G-mean: 0.7585
#     MCC: 0.6810
#     F1-score: 0.6799
#     mAP: 0.5939
#   [GAMO - kNN]
#     AUROC: 0.9135
#     G-mean: 0.8592
#     MCC: 0.6652
#     F1-score: 0.6692
#     mAP: 0.7820
#   [GAMO - MLP]
#     AUROC: 0.9486
#     G-mean: 0.8655
#     MCC: 0.4362
#     F1-score: 0.4024
#     mAP: 0.8304
#   [GAMO - RandomForest]
#     AUROC: 0.9666
#     G-mean: 0.7863
#     MCC: 0.7646
#     F1-score: 0.7561
#     mAP: 0.8756
#   [MGVAE - SVM]
#     AUROC: 0.9637
#     G-mean: 0.8538
#     MCC: 0.8339
#     F1-score: 0.8221
#     mAP: 0.8996
#   [MGVAE - DecisionTree]
#     AUROC: 0.8241
#     G-mean: 0.7551
#     MCC: 0.6694
#     F1-score: 0.6672
#     mAP: 0.5760
#   [MGVAE - kNN]
#     AUROC: 0.9286
#     G-mean: 0.8613
#     MCC: 0.8257
#     F1-score: 0.8148
#     mAP: 0.8381
#   [MGVAE - MLP]
#     AUROC: 0.9060
#     G-mean: 0.7967
#     MCC: 0.4455
#     F1-score: 0.4464
#     mAP: 0.7230
#   [MGVAE - RandomForest]
#     AUROC: 0.9646
#     G-mean: 0.7837
#     MCC: 0.7768
#     F1-score: 0.7662
#     mAP: 0.8669
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.9617
#     G-mean: 0.8698
#     MCC: 0.5462
#     F1-score: 0.5410
#     mAP: 0.7967
#   [GAMO - DecisionTree]
#     AUROC: 0.8292
#     G-mean: 0.7642
#     MCC: 0.6856
#     F1-score: 0.6832
#     mAP: 0.5934
#   [GAMO - kNN]
#     AUROC: 0.9138
#     G-mean: 0.8581
#     MCC: 0.6674
#     F1-score: 0.6715
#     mAP: 0.7800
#   [GAMO - MLP]
#     AUROC: 0.9470
#     G-mean: 0.8632
#     MCC: 0.4353
#     F1-score: 0.4028
#     mAP: 0.8306
#   [GAMO - RandomForest]
#     AUROC: 0.9670
#     G-mean: 0.7849
#     MCC: 0.7626
#     F1-score: 0.7547
#     mAP: 0.8765
#   [MGVAE - SVM]
#     AUROC: 0.9634
#     G-mean: 0.8562
#     MCC: 0.8379
#     F1-score: 0.8263
#     mAP: 0.9014
#   [MGVAE - DecisionTree]
#     AUROC: 0.8245
#     G-mean: 0.7562
#     MCC: 0.6695
#     F1-score: 0.6670
#     mAP: 0.5764
#   [MGVAE - kNN]
#     AUROC: 0.9277
#     G-mean: 0.8626
#     MCC: 0.8265
#     F1-score: 0.8161
#     mAP: 0.8380
#   [MGVAE - MLP]
#     AUROC: 0.9048
#     G-mean: 0.7963
#     MCC: 0.4523
#     F1-score: 0.4529
#     mAP: 0.7290
#   [MGVAE - RandomForest]
#     AUROC: 0.9640
#     G-mean: 0.7828
#     MCC: 0.7760
#     F1-score: 0.7655
#     mAP: 0.8677
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.9618
#     G-mean: 0.8703
#     MCC: 0.5458
#     F1-score: 0.5408
#     mAP: 0.7978
#   [GAMO - DecisionTree]
#     AUROC: 0.8259
#     G-mean: 0.7594
#     MCC: 0.6801
#     F1-score: 0.6772
#     mAP: 0.5862
#   [GAMO - kNN]
#     AUROC: 0.9149
#     G-mean: 0.8580
#     MCC: 0.6651
#     F1-score: 0.6701
#     mAP: 0.7805
#   [GAMO - MLP]
#     AUROC: 0.9474
#     G-mean: 0.8639
#     MCC: 0.4357
#     F1-score: 0.4029
#     mAP: 0.8324
#   [GAMO - RandomForest]
#     AUROC: 0.9647
#     G-mean: 0.7857
#     MCC: 0.7636
#     F1-score: 0.7559
#     mAP: 0.8716
#   [MGVAE - SVM]
#     AUROC: 0.9615
#     G-mean: 0.8540
#     MCC: 0.8371
#     F1-score: 0.8263
#     mAP: 0.8980
#   [MGVAE - DecisionTree]
#     AUROC: 0.8238
#     G-mean: 0.7570
#     MCC: 0.6672
#     F1-score: 0.6653
#     mAP: 0.5737
#   [MGVAE - kNN]
#     AUROC: 0.9272
#     G-mean: 0.8596
#     MCC: 0.8248
#     F1-score: 0.8158
#     mAP: 0.8363
#   [MGVAE - MLP]
#     AUROC: 0.9002
#     G-mean: 0.7884
#     MCC: 0.4436
#     F1-score: 0.4463
#     mAP: 0.7178
#   [MGVAE - RandomForest]
#     AUROC: 0.9615
#     G-mean: 0.7791
#     MCC: 0.7723
#     F1-score: 0.7617
#     mAP: 0.8657
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/ecoli4_results_GAMO_MGVAE_beta_0.1.csv

# %%
data_name = 'glass-0-1-2-3_vs_4-5-6'

# 실험 파라미터 설정
n_epochs = 1000
hidden_dims = [9, 16, 32, 64]
latent_dim = 128
lr = 0.001
beta = 0.001

# 데이터 불러오기
glass_0_1_2_3_vs_4_5_6 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# 실험 실행
final_res = run_exp(
    data=glass_0_1_2_3_vs_4_5_6, 
    kernel_type=kernel_type,
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (214, 9)
# target : Counter({0: 163, 1: 51})
# IR: 3.2
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.9863
#     G-mean: 0.9517
#     MCC: 0.8598
#     F1-score: 0.8904
#     mAP: 0.9599
#   [GAMO - DecisionTree]
#     AUROC: 0.9330
#     G-mean: 0.8986
#     MCC: 0.7799
#     F1-score: 0.8286
#     mAP: 0.7855
#   [GAMO - kNN]
#     AUROC: 0.9696
#     G-mean: 0.8982
#     MCC: 0.8273
#     F1-score: 0.8616
#     mAP: 0.9110
#   [GAMO - MLP]
#     AUROC: 0.9740
#     G-mean: 0.9235
#     MCC: 0.7901
#     F1-score: 0.8374
#     mAP: 0.9522
#   [GAMO - RandomForest]
#     AUROC: 0.9781
#     G-mean: 0.9390
#     MCC: 0.8306
#     F1-score: 0.8692
#     mAP: 0.9563
#   [MGVAE - SVM]
#     AUROC: 0.9740
#     G-mean: 0.9151
#     MCC: 0.8383
#     F1-score: 0.8735
#     mAP: 0.9367
#   [MGVAE - DecisionTree]
#     AUROC: 0.9062
#     G-mean: 0.9019
#     MCC: 0.8334
#     F1-score: 0.8679
#     mAP: 0.8065
#   [MGVAE - kNN]
#     AUROC: 0.9584
#     G-mean: 0.8579
#     MCC: 0.7905
#     F1-score: 0.8229
#     mAP: 0.9048
#   [MGVAE - MLP]
#     AUROC: 0.9806
#     G-mean: 0.9065
#     MCC: 0.8115
#     F1-score: 0.8496
#     mAP: 0.9501
#   [MGVAE - RandomForest]
#     AUROC: 0.9869
#     G-mean: 0.9235
#     MCC: 0.8415
#     F1-score: 0.8774
#     mAP: 0.9720
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.9855
#     G-mean: 0.9549
#     MCC: 0.8669
#     F1-score: 0.8962
#     mAP: 0.9585
#   [GAMO - DecisionTree]
#     AUROC: 0.9425
#     G-mean: 0.9089
#     MCC: 0.7995
#     F1-score: 0.8420
#     mAP: 0.8187
#   [GAMO - kNN]
#     AUROC: 0.9748
#     G-mean: 0.8952
#     MCC: 0.8190
#     F1-score: 0.8528
#     mAP: 0.9319
#   [GAMO - MLP]
#     AUROC: 0.9775
#     G-mean: 0.9211
#     MCC: 0.8013
#     F1-score: 0.8442
#     mAP: 0.9515
#   [GAMO - RandomForest]
#     AUROC: 0.9812
#     G-mean: 0.9369
#     MCC: 0.8283
#     F1-score: 0.8663
#     mAP: 0.9624
#   [MGVAE - SVM]
#     AUROC: 0.9756
#     G-mean: 0.9158
#     MCC: 0.8414
#     F1-score: 0.8742
#     mAP: 0.9350
#   [MGVAE - DecisionTree]
#     AUROC: 0.8874
#     G-mean: 0.8743
#     MCC: 0.7918
#     F1-score: 0.8295
#     mAP: 0.7725
#   [MGVAE - kNN]
#     AUROC: 0.9563
#     G-mean: 0.8556
#     MCC: 0.7851
#     F1-score: 0.8169
#     mAP: 0.9037
#   [MGVAE - MLP]
#     AUROC: 0.9843
#     G-mean: 0.9103
#     MCC: 0.8198
#     F1-score: 0.8553
#     mAP: 0.9567
#   [MGVAE - RandomForest]
#     AUROC: 0.9851
#     G-mean: 0.9187
#     MCC: 0.8334
#     F1-score: 0.8709
#     mAP: 0.9668
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.9846
#     G-mean: 0.9563
#     MCC: 0.8705
#     F1-score: 0.8989
#     mAP: 0.9596
#   [GAMO - DecisionTree]
#     AUROC: 0.9432
#     G-mean: 0.8995
#     MCC: 0.7867
#     F1-score: 0.8287
#     mAP: 0.8111
#   [GAMO - kNN]
#     AUROC: 0.9754
#     G-mean: 0.8936
#     MCC: 0.8206
#     F1-score: 0.8531
#     mAP: 0.9326
#   [GAMO - MLP]
#     AUROC: 0.9804
#     G-mean: 0.9236
#     MCC: 0.8036
#     F1-score: 0.8454
#     mAP: 0.9556
#   [GAMO - RandomForest]
#     AUROC: 0.9799
#     G-mean: 0.9364
#     MCC: 0.8285
#     F1-score: 0.8662
#     mAP: 0.9612
#   [MGVAE - SVM]
#     AUROC: 0.9788
#     G-mean: 0.9122
#     MCC: 0.8367
#     F1-score: 0.8694
#     mAP: 0.9446
#   [MGVAE - DecisionTree]
#     AUROC: 0.8891
#     G-mean: 0.8779
#     MCC: 0.7920
#     F1-score: 0.8297
#     mAP: 0.7669
#   [MGVAE - kNN]
#     AUROC: 0.9537
#     G-mean: 0.8521
#     MCC: 0.7820
#     F1-score: 0.8128
#     mAP: 0.9032
#   [MGVAE - MLP]
#     AUROC: 0.9787
#     G-mean: 0.9138
#     MCC: 0.8265
#     F1-score: 0.8604
#     mAP: 0.9541
#   [MGVAE - RandomForest]
#     AUROC: 0.9855
#     G-mean: 0.9234
#     MCC: 0.8416
#     F1-score: 0.8764
#     mAP: 0.9695
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.9851
#     G-mean: 0.9549
#     MCC: 0.8713
#     F1-score: 0.8996
#     mAP: 0.9597
#   [GAMO - DecisionTree]
#     AUROC: 0.9388
#     G-mean: 0.8984
#     MCC: 0.7818
#     F1-score: 0.8266
#     mAP: 0.8019
#   [GAMO - kNN]
#     AUROC: 0.9746
#     G-mean: 0.8942
#     MCC: 0.8205
#     F1-score: 0.8538
#     mAP: 0.9284
#   [GAMO - MLP]
#     AUROC: 0.9781
#     G-mean: 0.9168
#     MCC: 0.7887
#     F1-score: 0.8346
#     mAP: 0.9524
#   [GAMO - RandomForest]
#     AUROC: 0.9782
#     G-mean: 0.9364
#     MCC: 0.8275
#     F1-score: 0.8658
#     mAP: 0.9548
#   [MGVAE - SVM]
#     AUROC: 0.9804
#     G-mean: 0.9105
#     MCC: 0.8362
#     F1-score: 0.8683
#     mAP: 0.9473
#   [MGVAE - DecisionTree]
#     AUROC: 0.8847
#     G-mean: 0.8738
#     MCC: 0.7879
#     F1-score: 0.8261
#     mAP: 0.7597
#   [MGVAE - kNN]
#     AUROC: 0.9536
#     G-mean: 0.8511
#     MCC: 0.7804
#     F1-score: 0.8122
#     mAP: 0.9005
#   [MGVAE - MLP]
#     AUROC: 0.9786
#     G-mean: 0.9074
#     MCC: 0.8115
#     F1-score: 0.8494
#     mAP: 0.9522
#   [MGVAE - RandomForest]
#     AUROC: 0.9861
#     G-mean: 0.9181
#     MCC: 0.8373
#     F1-score: 0.8716
#     mAP: 0.9691
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.9862
#     G-mean: 0.9556
#     MCC: 0.8733
#     F1-score: 0.9011
#     mAP: 0.9613
#   [GAMO - DecisionTree]
#     AUROC: 0.9317
#     G-mean: 0.8922
#     MCC: 0.7705
#     F1-score: 0.8187
#     mAP: 0.7891
#   [GAMO - kNN]
#     AUROC: 0.9754
#     G-mean: 0.8961
#     MCC: 0.8209
#     F1-score: 0.8547
#     mAP: 0.9323
#   [GAMO - MLP]
#     AUROC: 0.9771
#     G-mean: 0.9181
#     MCC: 0.7921
#     F1-score: 0.8370
#     mAP: 0.9520
#   [GAMO - RandomForest]
#     AUROC: 0.9800
#     G-mean: 0.9367
#     MCC: 0.8296
#     F1-score: 0.8670
#     mAP: 0.9572
#   [MGVAE - SVM]
#     AUROC: 0.9802
#     G-mean: 0.9120
#     MCC: 0.8389
#     F1-score: 0.8702
#     mAP: 0.9435
#   [MGVAE - DecisionTree]
#     AUROC: 0.8841
#     G-mean: 0.8742
#     MCC: 0.7868
#     F1-score: 0.8266
#     mAP: 0.7591
#   [MGVAE - kNN]
#     AUROC: 0.9519
#     G-mean: 0.8498
#     MCC: 0.7777
#     F1-score: 0.8106
#     mAP: 0.8993
#   [MGVAE - MLP]
#     AUROC: 0.9763
#     G-mean: 0.9022
#     MCC: 0.7985
#     F1-score: 0.8396
#     mAP: 0.9488
#   [MGVAE - RandomForest]
#     AUROC: 0.9865
#     G-mean: 0.9173
#     MCC: 0.8364
#     F1-score: 0.8700
#     mAP: 0.9691
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.9876
#     G-mean: 0.9555
#     MCC: 0.8726
#     F1-score: 0.9005
#     mAP: 0.9655
#   [GAMO - DecisionTree]
#     AUROC: 0.9271
#     G-mean: 0.8829
#     MCC: 0.7582
#     F1-score: 0.8082
#     mAP: 0.7828
#   [GAMO - kNN]
#     AUROC: 0.9761
#     G-mean: 0.9005
#     MCC: 0.8278
#     F1-score: 0.8610
#     mAP: 0.9350
#   [GAMO - MLP]
#     AUROC: 0.9791
#     G-mean: 0.9224
#     MCC: 0.7991
#     F1-score: 0.8425
#     mAP: 0.9554
#   [GAMO - RandomForest]
#     AUROC: 0.9810
#     G-mean: 0.9381
#     MCC: 0.8319
#     F1-score: 0.8686
#     mAP: 0.9589
#   [MGVAE - SVM]
#     AUROC: 0.9820
#     G-mean: 0.9167
#     MCC: 0.8458
#     F1-score: 0.8760
#     mAP: 0.9494
#   [MGVAE - DecisionTree]
#     AUROC: 0.8812
#     G-mean: 0.8708
#     MCC: 0.7839
#     F1-score: 0.8231
#     mAP: 0.7557
#   [MGVAE - kNN]
#     AUROC: 0.9521
#     G-mean: 0.8532
#     MCC: 0.7826
#     F1-score: 0.8156
#     mAP: 0.9003
#   [MGVAE - MLP]
#     AUROC: 0.9781
#     G-mean: 0.9022
#     MCC: 0.8016
#     F1-score: 0.8420
#     mAP: 0.9524
#   [MGVAE - RandomForest]
#     AUROC: 0.9865
#     G-mean: 0.9216
#     MCC: 0.8426
#     F1-score: 0.8752
#     mAP: 0.9696
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.9873
#     G-mean: 0.9548
#     MCC: 0.8700
#     F1-score: 0.8987
#     mAP: 0.9652
#   [GAMO - DecisionTree]
#     AUROC: 0.9293
#     G-mean: 0.8890
#     MCC: 0.7678
#     F1-score: 0.8163
#     mAP: 0.7877
#   [GAMO - kNN]
#     AUROC: 0.9760
#     G-mean: 0.9019
#     MCC: 0.8292
#     F1-score: 0.8629
#     mAP: 0.9342
#   [GAMO - MLP]
#     AUROC: 0.9797
#     G-mean: 0.9248
#     MCC: 0.8025
#     F1-score: 0.8451
#     mAP: 0.9562
#   [GAMO - RandomForest]
#     AUROC: 0.9810
#     G-mean: 0.9399
#     MCC: 0.8349
#     F1-score: 0.8712
#     mAP: 0.9582
#   [MGVAE - SVM]
#     AUROC: 0.9824
#     G-mean: 0.9183
#     MCC: 0.8476
#     F1-score: 0.8783
#     mAP: 0.9516
#   [MGVAE - DecisionTree]
#     AUROC: 0.8817
#     G-mean: 0.8717
#     MCC: 0.7857
#     F1-score: 0.8251
#     mAP: 0.7572
#   [MGVAE - kNN]
#     AUROC: 0.9544
#     G-mean: 0.8568
#     MCC: 0.7866
#     F1-score: 0.8197
#     mAP: 0.9055
#   [MGVAE - MLP]
#     AUROC: 0.9782
#     G-mean: 0.9016
#     MCC: 0.7970
#     F1-score: 0.8384
#     mAP: 0.9517
#   [MGVAE - RandomForest]
#     AUROC: 0.9860
#     G-mean: 0.9194
#     MCC: 0.8408
#     F1-score: 0.8740
#     mAP: 0.9686
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.9855
#     G-mean: 0.9547
#     MCC: 0.8703
#     F1-score: 0.8989
#     mAP: 0.9608
#   [GAMO - DecisionTree]
#     AUROC: 0.9274
#     G-mean: 0.8823
#     MCC: 0.7563
#     F1-score: 0.8064
#     mAP: 0.7803
#   [GAMO - kNN]
#     AUROC: 0.9727
#     G-mean: 0.9009
#     MCC: 0.8292
#     F1-score: 0.8620
#     mAP: 0.9280
#   [GAMO - MLP]
#     AUROC: 0.9791
#     G-mean: 0.9257
#     MCC: 0.8042
#     F1-score: 0.8467
#     mAP: 0.9533
#   [GAMO - RandomForest]
#     AUROC: 0.9799
#     G-mean: 0.9397
#     MCC: 0.8352
#     F1-score: 0.8717
#     mAP: 0.9552
#   [MGVAE - SVM]
#     AUROC: 0.9798
#     G-mean: 0.9142
#     MCC: 0.8434
#     F1-score: 0.8741
#     mAP: 0.9455
#   [MGVAE - DecisionTree]
#     AUROC: 0.8790
#     G-mean: 0.8686
#     MCC: 0.7812
#     F1-score: 0.8213
#     mAP: 0.7524
#   [MGVAE - kNN]
#     AUROC: 0.9528
#     G-mean: 0.8554
#     MCC: 0.7852
#     F1-score: 0.8177
#     mAP: 0.9016
#   [MGVAE - MLP]
#     AUROC: 0.9772
#     G-mean: 0.8996
#     MCC: 0.7910
#     F1-score: 0.8340
#     mAP: 0.9486
#   [MGVAE - RandomForest]
#     AUROC: 0.9852
#     G-mean: 0.9196
#     MCC: 0.8415
#     F1-score: 0.8744
#     mAP: 0.9673
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.9850
#     G-mean: 0.9551
#     MCC: 0.8712
#     F1-score: 0.8993
#     mAP: 0.9587
#   [GAMO - DecisionTree]
#     AUROC: 0.9265
#     G-mean: 0.8821
#     MCC: 0.7575
#     F1-score: 0.8074
#     mAP: 0.7809
#   [GAMO - kNN]
#     AUROC: 0.9729
#     G-mean: 0.9003
#     MCC: 0.8281
#     F1-score: 0.8610
#     mAP: 0.9279
#   [GAMO - MLP]
#     AUROC: 0.9792
#     G-mean: 0.9283
#     MCC: 0.8088
#     F1-score: 0.8502
#     mAP: 0.9540
#   [GAMO - RandomForest]
#     AUROC: 0.9800
#     G-mean: 0.9392
#     MCC: 0.8342
#     F1-score: 0.8707
#     mAP: 0.9555
#   [MGVAE - SVM]
#     AUROC: 0.9799
#     G-mean: 0.9143
#     MCC: 0.8426
#     F1-score: 0.8736
#     mAP: 0.9451
#   [MGVAE - DecisionTree]
#     AUROC: 0.8835
#     G-mean: 0.8740
#     MCC: 0.7877
#     F1-score: 0.8271
#     mAP: 0.7580
#   [MGVAE - kNN]
#     AUROC: 0.9539
#     G-mean: 0.8556
#     MCC: 0.7856
#     F1-score: 0.8179
#     mAP: 0.9017
#   [MGVAE - MLP]
#     AUROC: 0.9758
#     G-mean: 0.9016
#     MCC: 0.7917
#     F1-score: 0.8350
#     mAP: 0.9480
#   [MGVAE - RandomForest]
#     AUROC: 0.9854
#     G-mean: 0.9198
#     MCC: 0.8415
#     F1-score: 0.8743
#     mAP: 0.9675
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.9846
#     G-mean: 0.9548
#     MCC: 0.8701
#     F1-score: 0.8984
#     mAP: 0.9574
#   [GAMO - DecisionTree]
#     AUROC: 0.9275
#     G-mean: 0.8868
#     MCC: 0.7635
#     F1-score: 0.8126
#     mAP: 0.7836
#   [GAMO - kNN]
#     AUROC: 0.9731
#     G-mean: 0.9031
#     MCC: 0.8320
#     F1-score: 0.8642
#     mAP: 0.9276
#   [GAMO - MLP]
#     AUROC: 0.9796
#     G-mean: 0.9297
#     MCC: 0.8117
#     F1-score: 0.8523
#     mAP: 0.9543
#   [GAMO - RandomForest]
#     AUROC: 0.9788
#     G-mean: 0.9392
#     MCC: 0.8342
#     F1-score: 0.8707
#     mAP: 0.9527
#   [MGVAE - SVM]
#     AUROC: 0.9799
#     G-mean: 0.9157
#     MCC: 0.8437
#     F1-score: 0.8747
#     mAP: 0.9457
#   [MGVAE - DecisionTree]
#     AUROC: 0.8822
#     G-mean: 0.8728
#     MCC: 0.7857
#     F1-score: 0.8257
#     mAP: 0.7552
#   [MGVAE - kNN]
#     AUROC: 0.9539
#     G-mean: 0.8572
#     MCC: 0.7877
#     F1-score: 0.8202
#     mAP: 0.9005
#   [MGVAE - MLP]
#     AUROC: 0.9755
#     G-mean: 0.9027
#     MCC: 0.7931
#     F1-score: 0.8364
#     mAP: 0.9491
#   [MGVAE - RandomForest]
#     AUROC: 0.9853
#     G-mean: 0.9215
#     MCC: 0.8438
#     F1-score: 0.8762
#     mAP: 0.9675
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/glass-0-1-2-3_vs_4-5-6_results_GAMO_MGVAE_beta_0.001.csv

# %%
data_name = 'glass-0-1-6_vs_5'

# 실험 파라미터 설정
n_epochs = 1000
hidden_dims = [32, 64, 128, 256]
latent_dim = 512
lr = 0.002
beta = 0.001 

# 데이터 불러오기
glass_0_1_6_vs_5 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# 실험 실행
final_res = run_exp(
    data=glass_0_1_6_vs_5,
    kernel_type=kernel_type, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (184, 9)
# target : Counter({0: 175, 1: 9})
# IR: 19.44
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.9622
#     G-mean: 0.7672
#     MCC: 0.5976
#     F1-score: 0.5852
#     mAP: 0.7500
#   [GAMO - DecisionTree]
#     AUROC: 0.8239
#     G-mean: 0.5913
#     MCC: 0.5230
#     F1-score: 0.5167
#     mAP: 0.5552
#   [GAMO - kNN]
#     AUROC: 0.9938
#     G-mean: 0.7825
#     MCC: 0.6631
#     F1-score: 0.6500
#     mAP: 0.8889
#   [GAMO - MLP]
#     AUROC: 0.9361
#     G-mean: 0.8093
#     MCC: 0.4680
#     F1-score: 0.4315
#     mAP: 0.6481
#   [GAMO - RandomForest]
#     AUROC: 1.0000
#     G-mean: 0.6913
#     MCC: 0.6230
#     F1-score: 0.6167
#     mAP: 1.0000
#   [MGVAE - SVM]
#     AUROC: 0.9742
#     G-mean: 0.5972
#     MCC: 0.5632
#     F1-score: 0.5667
#     mAP: 0.8611
#   [MGVAE - DecisionTree]
#     AUROC: 0.8237
#     G-mean: 0.5942
#     MCC: 0.5314
#     F1-score: 0.5333
#     mAP: 0.5738
#   [MGVAE - kNN]
#     AUROC: 0.9938
#     G-mean: 0.7915
#     MCC: 0.7232
#     F1-score: 0.7167
#     mAP: 0.9259
#   [MGVAE - MLP]
#     AUROC: 0.9434
#     G-mean: 0.8021
#     MCC: 0.4066
#     F1-score: 0.3621
#     mAP: 0.6111
#   [MGVAE - RandomForest]
#     AUROC: 1.0000
#     G-mean: 0.5972
#     MCC: 0.5687
#     F1-score: 0.5667
#     mAP: 1.0000
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.9681
#     G-mean: 0.7687
#     MCC: 0.5703
#     F1-score: 0.5543
#     mAP: 0.8055
#   [GAMO - DecisionTree]
#     AUROC: 0.8778
#     G-mean: 0.6899
#     MCC: 0.5988
#     F1-score: 0.5917
#     mAP: 0.6140
#   [GAMO - kNN]
#     AUROC: 0.9920
#     G-mean: 0.8337
#     MCC: 0.7116
#     F1-score: 0.7000
#     mAP: 0.8889
#   [GAMO - MLP]
#     AUROC: 0.9323
#     G-mean: 0.7946
#     MCC: 0.4221
#     F1-score: 0.3820
#     mAP: 0.6222
#   [GAMO - RandomForest]
#     AUROC: 0.9968
#     G-mean: 0.7412
#     MCC: 0.6644
#     F1-score: 0.6583
#     mAP: 0.9722
#   [MGVAE - SVM]
#     AUROC: 0.9806
#     G-mean: 0.5486
#     MCC: 0.5287
#     F1-score: 0.5333
#     mAP: 0.8750
#   [MGVAE - DecisionTree]
#     AUROC: 0.8206
#     G-mean: 0.5914
#     MCC: 0.5087
#     F1-score: 0.5083
#     mAP: 0.5369
#   [MGVAE - kNN]
#     AUROC: 0.9937
#     G-mean: 0.7913
#     MCC: 0.7145
#     F1-score: 0.7084
#     mAP: 0.9351
#   [MGVAE - MLP]
#     AUROC: 0.9461
#     G-mean: 0.8126
#     MCC: 0.4441
#     F1-score: 0.4029
#     mAP: 0.6435
#   [MGVAE - RandomForest]
#     AUROC: 1.0000
#     G-mean: 0.6986
#     MCC: 0.6844
#     F1-score: 0.6834
#     mAP: 1.0000
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.9702
#     G-mean: 0.7704
#     MCC: 0.5680
#     F1-score: 0.5529
#     mAP: 0.7963
#   [GAMO - DecisionTree]
#     AUROC: 0.8587
#     G-mean: 0.6580
#     MCC: 0.5754
#     F1-score: 0.5722
#     mAP: 0.6005
#   [GAMO - kNN]
#     AUROC: 0.9905
#     G-mean: 0.8176
#     MCC: 0.6983
#     F1-score: 0.6889
#     mAP: 0.8704
#   [GAMO - MLP]
#     AUROC: 0.9357
#     G-mean: 0.7916
#     MCC: 0.4126
#     F1-score: 0.3704
#     mAP: 0.6216
#   [GAMO - RandomForest]
#     AUROC: 0.9957
#     G-mean: 0.7246
#     MCC: 0.6449
#     F1-score: 0.6389
#     mAP: 0.9629
#   [MGVAE - SVM]
#     AUROC: 0.9698
#     G-mean: 0.5657
#     MCC: 0.5497
#     F1-score: 0.5556
#     mAP: 0.8602
#   [MGVAE - DecisionTree]
#     AUROC: 0.8402
#     G-mean: 0.6256
#     MCC: 0.5496
#     F1-score: 0.5500
#     mAP: 0.5841
#   [MGVAE - kNN]
#     AUROC: 0.9936
#     G-mean: 0.7913
#     MCC: 0.7173
#     F1-score: 0.7111
#     mAP: 0.9197
#   [MGVAE - MLP]
#     AUROC: 0.9492
#     G-mean: 0.8123
#     MCC: 0.4427
#     F1-score: 0.4005
#     mAP: 0.6697
#   [MGVAE - RandomForest]
#     AUROC: 0.9959
#     G-mean: 0.5991
#     MCC: 0.5877
#     F1-score: 0.5889
#     mAP: 0.9753
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.9699
#     G-mean: 0.7694
#     MCC: 0.5757
#     F1-score: 0.5596
#     mAP: 0.7986
#   [GAMO - DecisionTree]
#     AUROC: 0.8491
#     G-mean: 0.6420
#     MCC: 0.5631
#     F1-score: 0.5625
#     mAP: 0.5937
#   [GAMO - kNN]
#     AUROC: 0.9921
#     G-mean: 0.8080
#     MCC: 0.6893
#     F1-score: 0.6792
#     mAP: 0.8889
#   [GAMO - MLP]
#     AUROC: 0.9253
#     G-mean: 0.7899
#     MCC: 0.4398
#     F1-score: 0.4019
#     mAP: 0.6123
#   [GAMO - RandomForest]
#     AUROC: 0.9920
#     G-mean: 0.7413
#     MCC: 0.6602
#     F1-score: 0.6542
#     mAP: 0.9305
#   [MGVAE - SVM]
#     AUROC: 0.9728
#     G-mean: 0.5485
#     MCC: 0.5294
#     F1-score: 0.5333
#     mAP: 0.8744
#   [MGVAE - DecisionTree]
#     AUROC: 0.8492
#     G-mean: 0.6420
#     MCC: 0.5666
#     F1-score: 0.5666
#     mAP: 0.6030
#   [MGVAE - kNN]
#     AUROC: 0.9913
#     G-mean: 0.8163
#     MCC: 0.7437
#     F1-score: 0.7375
#     mAP: 0.9074
#   [MGVAE - MLP]
#     AUROC: 0.9478
#     G-mean: 0.8111
#     MCC: 0.4447
#     F1-score: 0.4031
#     mAP: 0.6699
#   [MGVAE - RandomForest]
#     AUROC: 0.9953
#     G-mean: 0.5993
#     MCC: 0.5893
#     F1-score: 0.5917
#     mAP: 0.9676
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.9746
#     G-mean: 0.7896
#     MCC: 0.5846
#     F1-score: 0.5677
#     mAP: 0.8278
#   [GAMO - DecisionTree]
#     AUROC: 0.8434
#     G-mean: 0.6325
#     MCC: 0.5568
#     F1-score: 0.5567
#     mAP: 0.5896
#   [GAMO - kNN]
#     AUROC: 0.9924
#     G-mean: 0.8229
#     MCC: 0.7006
#     F1-score: 0.6900
#     mAP: 0.9000
#   [GAMO - MLP]
#     AUROC: 0.9213
#     G-mean: 0.7818
#     MCC: 0.4238
#     F1-score: 0.3859
#     mAP: 0.5913
#   [GAMO - RandomForest]
#     AUROC: 0.9911
#     G-mean: 0.7513
#     MCC: 0.6682
#     F1-score: 0.6633
#     mAP: 0.9222
#   [MGVAE - SVM]
#     AUROC: 0.9744
#     G-mean: 0.5388
#     MCC: 0.5224
#     F1-score: 0.5267
#     mAP: 0.8736
#   [MGVAE - DecisionTree]
#     AUROC: 0.8435
#     G-mean: 0.6324
#     MCC: 0.5584
#     F1-score: 0.5600
#     mAP: 0.5971
#   [MGVAE - kNN]
#     AUROC: 0.9918
#     G-mean: 0.8107
#     MCC: 0.7333
#     F1-score: 0.7267
#     mAP: 0.9148
#   [MGVAE - MLP]
#     AUROC: 0.9457
#     G-mean: 0.8065
#     MCC: 0.4445
#     F1-score: 0.4041
#     mAP: 0.6589
#   [MGVAE - RandomForest]
#     AUROC: 0.9950
#     G-mean: 0.5994
#     MCC: 0.5914
#     F1-score: 0.5933
#     mAP: 0.9629
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.9768
#     G-mean: 0.7879
#     MCC: 0.5883
#     F1-score: 0.5731
#     mAP: 0.8441
#   [GAMO - DecisionTree]
#     AUROC: 0.8396
#     G-mean: 0.6261
#     MCC: 0.5517
#     F1-score: 0.5528
#     mAP: 0.5869
#   [GAMO - kNN]
#     AUROC: 0.9916
#     G-mean: 0.8171
#     MCC: 0.6982
#     F1-score: 0.6889
#     mAP: 0.8981
#   [GAMO - MLP]
#     AUROC: 0.9280
#     G-mean: 0.7879
#     MCC: 0.4383
#     F1-score: 0.4011
#     mAP: 0.6162
#   [GAMO - RandomForest]
#     AUROC: 0.9915
#     G-mean: 0.7251
#     MCC: 0.6455
#     F1-score: 0.6417
#     mAP: 0.9259
#   [MGVAE - SVM]
#     AUROC: 0.9754
#     G-mean: 0.5319
#     MCC: 0.5135
#     F1-score: 0.5167
#     mAP: 0.8730
#   [MGVAE - DecisionTree]
#     AUROC: 0.8407
#     G-mean: 0.6260
#     MCC: 0.5549
#     F1-score: 0.5555
#     mAP: 0.5931
#   [MGVAE - kNN]
#     AUROC: 0.9910
#     G-mean: 0.8079
#     MCC: 0.7340
#     F1-score: 0.7278
#     mAP: 0.9012
#   [MGVAE - MLP]
#     AUROC: 0.9461
#     G-mean: 0.8103
#     MCC: 0.4523
#     F1-score: 0.4123
#     mAP: 0.6540
#   [MGVAE - RandomForest]
#     AUROC: 0.9958
#     G-mean: 0.5991
#     MCC: 0.5877
#     F1-score: 0.5889
#     mAP: 0.9691
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.9783
#     G-mean: 0.7854
#     MCC: 0.5867
#     F1-score: 0.5717
#     mAP: 0.8505
#   [GAMO - DecisionTree]
#     AUROC: 0.8449
#     G-mean: 0.6358
#     MCC: 0.5652
#     F1-score: 0.5667
#     mAP: 0.6053
#   [GAMO - kNN]
#     AUROC: 0.9923
#     G-mean: 0.8121
#     MCC: 0.6907
#     F1-score: 0.6809
#     mAP: 0.9047
#   [GAMO - MLP]
#     AUROC: 0.9301
#     G-mean: 0.7869
#     MCC: 0.4322
#     F1-score: 0.3939
#     mAP: 0.6221
#   [GAMO - RandomForest]
#     AUROC: 0.9910
#     G-mean: 0.7350
#     MCC: 0.6611
#     F1-score: 0.6571
#     mAP: 0.9259
#   [MGVAE - SVM]
#     AUROC: 0.9763
#     G-mean: 0.5269
#     MCC: 0.5071
#     F1-score: 0.5095
#     mAP: 0.8674
#   [MGVAE - DecisionTree]
#     AUROC: 0.8537
#     G-mean: 0.6492
#     MCC: 0.5745
#     F1-score: 0.5738
#     mAP: 0.6098
#   [MGVAE - kNN]
#     AUROC: 0.9914
#     G-mean: 0.8064
#     MCC: 0.7381
#     F1-score: 0.7333
#     mAP: 0.9074
#   [MGVAE - MLP]
#     AUROC: 0.9475
#     G-mean: 0.8092
#     MCC: 0.4463
#     F1-score: 0.4059
#     mAP: 0.6585
#   [MGVAE - RandomForest]
#     AUROC: 0.9964
#     G-mean: 0.5845
#     MCC: 0.5707
#     F1-score: 0.5714
#     mAP: 0.9735
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.9794
#     G-mean: 0.7839
#     MCC: 0.5837
#     F1-score: 0.5690
#     mAP: 0.8553
#   [GAMO - DecisionTree]
#     AUROC: 0.8423
#     G-mean: 0.6302
#     MCC: 0.5599
#     F1-score: 0.5604
#     mAP: 0.5991
#   [GAMO - kNN]
#     AUROC: 0.9925
#     G-mean: 0.8088
#     MCC: 0.6869
#     F1-score: 0.6771
#     mAP: 0.9028
#   [GAMO - MLP]
#     AUROC: 0.9267
#     G-mean: 0.7770
#     MCC: 0.4210
#     F1-score: 0.3850
#     mAP: 0.6162
#   [GAMO - RandomForest]
#     AUROC: 0.9913
#     G-mean: 0.7299
#     MCC: 0.6581
#     F1-score: 0.6542
#     mAP: 0.9282
#   [MGVAE - SVM]
#     AUROC: 0.9776
#     G-mean: 0.5353
#     MCC: 0.5109
#     F1-score: 0.5125
#     mAP: 0.8700
#   [MGVAE - DecisionTree]
#     AUROC: 0.8577
#     G-mean: 0.6556
#     MCC: 0.5894
#     F1-score: 0.5896
#     mAP: 0.6323
#   [MGVAE - kNN]
#     AUROC: 0.9913
#     G-mean: 0.8049
#     MCC: 0.7380
#     F1-score: 0.7333
#     mAP: 0.9051
#   [MGVAE - MLP]
#     AUROC: 0.9460
#     G-mean: 0.8102
#     MCC: 0.4476
#     F1-score: 0.4071
#     mAP: 0.6548
#   [MGVAE - RandomForest]
#     AUROC: 0.9961
#     G-mean: 0.6107
#     MCC: 0.5915
#     F1-score: 0.5917
#     mAP: 0.9699
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.9802
#     G-mean: 0.7932
#     MCC: 0.5887
#     F1-score: 0.5732
#     mAP: 0.8591
#   [GAMO - DecisionTree]
#     AUROC: 0.8405
#     G-mean: 0.6262
#     MCC: 0.5574
#     F1-score: 0.5574
#     mAP: 0.5963
#   [GAMO - kNN]
#     AUROC: 0.9926
#     G-mean: 0.8170
#     MCC: 0.6916
#     F1-score: 0.6815
#     mAP: 0.9012
#   [GAMO - MLP]
#     AUROC: 0.9292
#     G-mean: 0.7795
#     MCC: 0.4184
#     F1-score: 0.3813
#     mAP: 0.6187
#   [GAMO - RandomForest]
#     AUROC: 0.9916
#     G-mean: 0.7478
#     MCC: 0.6745
#     F1-score: 0.6704
#     mAP: 0.9300
#   [MGVAE - SVM]
#     AUROC: 0.9787
#     G-mean: 0.5311
#     MCC: 0.5062
#     F1-score: 0.5074
#     mAP: 0.8763
#   [MGVAE - DecisionTree]
#     AUROC: 0.8529
#     G-mean: 0.6478
#     MCC: 0.5744
#     F1-score: 0.5741
#     mAP: 0.6114
#   [MGVAE - kNN]
#     AUROC: 0.9919
#     G-mean: 0.8030
#     MCC: 0.7310
#     F1-score: 0.7259
#     mAP: 0.9094
#   [MGVAE - MLP]
#     AUROC: 0.9472
#     G-mean: 0.8104
#     MCC: 0.4450
#     F1-score: 0.4041
#     mAP: 0.6689
#   [MGVAE - RandomForest]
#     AUROC: 0.9958
#     G-mean: 0.6095
#     MCC: 0.5918
#     F1-score: 0.5926
#     mAP: 0.9671
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.9804
#     G-mean: 0.7914
#     MCC: 0.5933
#     F1-score: 0.5787
#     mAP: 0.8565
#   [GAMO - DecisionTree]
#     AUROC: 0.8441
#     G-mean: 0.6327
#     MCC: 0.5634
#     F1-score: 0.5633
#     mAP: 0.6027
#   [GAMO - kNN]
#     AUROC: 0.9921
#     G-mean: 0.8144
#     MCC: 0.6925
#     F1-score: 0.6833
#     mAP: 0.8981
#   [GAMO - MLP]
#     AUROC: 0.9306
#     G-mean: 0.7817
#     MCC: 0.4181
#     F1-score: 0.3806
#     mAP: 0.6263
#   [GAMO - RandomForest]
#     AUROC: 0.9912
#     G-mean: 0.7522
#     MCC: 0.6794
#     F1-score: 0.6750
#     mAP: 0.9259
#   [MGVAE - SVM]
#     AUROC: 0.9777
#     G-mean: 0.5280
#     MCC: 0.5056
#     F1-score: 0.5067
#     mAP: 0.8683
#   [MGVAE - DecisionTree]
#     AUROC: 0.8497
#     G-mean: 0.6422
#     MCC: 0.5670
#     F1-score: 0.5666
#     mAP: 0.6020
#   [MGVAE - kNN]
#     AUROC: 0.9921
#     G-mean: 0.8024
#     MCC: 0.7342
#     F1-score: 0.7300
#     mAP: 0.9129
#   [MGVAE - MLP]
#     AUROC: 0.9462
#     G-mean: 0.8131
#     MCC: 0.4547
#     F1-score: 0.4146
#     mAP: 0.6705
#   [MGVAE - RandomForest]
#     AUROC: 0.9962
#     G-mean: 0.6083
#     MCC: 0.5895
#     F1-score: 0.5900
#     mAP: 0.9704
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/glass-0-1-6_vs_5_results_GAMO_MGVAE_beta_0.001.csv

# %%
data_name = 'glass4'

# 실험 파라미터 설정
n_epochs = 1000
hidden_dims = [8, 16, 32, 64]
latent_dim = 128
lr = 0.01
beta = 0.1

# 데이터 불러오기
glass4 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# 실험 실행
final_res = run_exp(
    data=glass4, 
    cat_idx=[], 
    methods=methods, 
    kernel_type=kernel_type,
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (214, 9)
# target : Counter({0: 201, 1: 13})
# IR: 15.46
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.9850
#     G-mean: 0.9485
#     MCC: 0.6273
#     F1-score: 0.5976
#     mAP: 0.8833
#   [GAMO - DecisionTree]
#     AUROC: 0.9325
#     G-mean: 0.8721
#     MCC: 0.6393
#     F1-score: 0.6300
#     mAP: 0.6714
#   [GAMO - kNN]
#     AUROC: 0.9637
#     G-mean: 0.6821
#     MCC: 0.5544
#     F1-score: 0.5538
#     mAP: 0.6450
#   [GAMO - MLP]
#     AUROC: 0.9500
#     G-mean: 0.8986
#     MCC: 0.4731
#     F1-score: 0.4290
#     mAP: 0.6742
#   [GAMO - RandomForest]
#     AUROC: 0.9900
#     G-mean: 0.8769
#     MCC: 0.7163
#     F1-score: 0.7038
#     mAP: 0.9000
#   [MGVAE - SVM]
#     AUROC: 0.9875
#     G-mean: 0.7682
#     MCC: 0.7379
#     F1-score: 0.7333
#     mAP: 0.9167
#   [MGVAE - DecisionTree]
#     AUROC: 0.8150
#     G-mean: 0.6605
#     MCC: 0.5739
#     F1-score: 0.5667
#     mAP: 0.5188
#   [MGVAE - kNN]
#     AUROC: 0.9388
#     G-mean: 0.8657
#     MCC: 0.8175
#     F1-score: 0.8133
#     mAP: 0.8381
#   [MGVAE - MLP]
#     AUROC: 0.8777
#     G-mean: 0.8207
#     MCC: 0.5147
#     F1-score: 0.5072
#     mAP: 0.6506
#   [MGVAE - RandomForest]
#     AUROC: 0.9800
#     G-mean: 0.5975
#     MCC: 0.5689
#     F1-score: 0.5667
#     mAP: 0.8750
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.9812
#     G-mean: 0.9413
#     MCC: 0.6213
#     F1-score: 0.5905
#     mAP: 0.8683
#   [GAMO - DecisionTree]
#     AUROC: 0.9012
#     G-mean: 0.8205
#     MCC: 0.6004
#     F1-score: 0.5917
#     mAP: 0.6193
#   [GAMO - kNN]
#     AUROC: 0.9425
#     G-mean: 0.7307
#     MCC: 0.5896
#     F1-score: 0.5902
#     mAP: 0.6765
#   [GAMO - MLP]
#     AUROC: 0.9363
#     G-mean: 0.8628
#     MCC: 0.4126
#     F1-score: 0.3707
#     mAP: 0.6193
#   [GAMO - RandomForest]
#     AUROC: 0.9875
#     G-mean: 0.9149
#     MCC: 0.7562
#     F1-score: 0.7419
#     mAP: 0.8875
#   [MGVAE - SVM]
#     AUROC: 0.9888
#     G-mean: 0.8182
#     MCC: 0.7879
#     F1-score: 0.7833
#     mAP: 0.9208
#   [MGVAE - DecisionTree]
#     AUROC: 0.8476
#     G-mean: 0.7415
#     MCC: 0.6057
#     F1-score: 0.6000
#     mAP: 0.5247
#   [MGVAE - kNN]
#     AUROC: 0.9394
#     G-mean: 0.8976
#     MCC: 0.8036
#     F1-score: 0.7983
#     mAP: 0.8486
#   [MGVAE - MLP]
#     AUROC: 0.9040
#     G-mean: 0.8518
#     MCC: 0.5091
#     F1-score: 0.4948
#     mAP: 0.6921
#   [MGVAE - RandomForest]
#     AUROC: 0.9825
#     G-mean: 0.7182
#     MCC: 0.6879
#     F1-score: 0.6834
#     mAP: 0.8959
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.9817
#     G-mean: 0.9237
#     MCC: 0.5895
#     F1-score: 0.5632
#     mAP: 0.8911
#   [GAMO - DecisionTree]
#     AUROC: 0.9142
#     G-mean: 0.8556
#     MCC: 0.6073
#     F1-score: 0.5955
#     mAP: 0.6172
#   [GAMO - kNN]
#     AUROC: 0.9443
#     G-mean: 0.7354
#     MCC: 0.5886
#     F1-score: 0.5903
#     mAP: 0.6841
#   [GAMO - MLP]
#     AUROC: 0.9317
#     G-mean: 0.8510
#     MCC: 0.4108
#     F1-score: 0.3749
#     mAP: 0.6198
#   [GAMO - RandomForest]
#     AUROC: 0.9858
#     G-mean: 0.9235
#     MCC: 0.7434
#     F1-score: 0.7303
#     mAP: 0.8806
#   [MGVAE - SVM]
#     AUROC: 0.9875
#     G-mean: 0.8584
#     MCC: 0.8276
#     F1-score: 0.8222
#     mAP: 0.9139
#   [MGVAE - DecisionTree]
#     AUROC: 0.8342
#     G-mean: 0.7173
#     MCC: 0.6116
#     F1-score: 0.6167
#     mAP: 0.5658
#   [MGVAE - kNN]
#     AUROC: 0.9483
#     G-mean: 0.9079
#     MCC: 0.8120
#     F1-score: 0.8044
#     mAP: 0.8589
#   [MGVAE - MLP]
#     AUROC: 0.9151
#     G-mean: 0.8498
#     MCC: 0.5224
#     F1-score: 0.5041
#     mAP: 0.7054
#   [MGVAE - RandomForest]
#     AUROC: 0.9842
#     G-mean: 0.7357
#     MCC: 0.7125
#     F1-score: 0.7111
#     mAP: 0.9028
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.9819
#     G-mean: 0.8782
#     MCC: 0.5552
#     F1-score: 0.5299
#     mAP: 0.8829
#   [GAMO - DecisionTree]
#     AUROC: 0.8991
#     G-mean: 0.8313
#     MCC: 0.5839
#     F1-score: 0.5714
#     mAP: 0.5932
#   [GAMO - kNN]
#     AUROC: 0.9523
#     G-mean: 0.7439
#     MCC: 0.5806
#     F1-score: 0.5777
#     mAP: 0.7006
#   [GAMO - MLP]
#     AUROC: 0.9282
#     G-mean: 0.8294
#     MCC: 0.4094
#     F1-score: 0.3760
#     mAP: 0.6115
#   [GAMO - RandomForest]
#     AUROC: 0.9850
#     G-mean: 0.8862
#     MCC: 0.7061
#     F1-score: 0.6954
#     mAP: 0.8779
#   [MGVAE - SVM]
#     AUROC: 0.9900
#     G-mean: 0.8182
#     MCC: 0.7906
#     F1-score: 0.7867
#     mAP: 0.9312
#   [MGVAE - DecisionTree]
#     AUROC: 0.8494
#     G-mean: 0.7367
#     MCC: 0.6504
#     F1-score: 0.6542
#     mAP: 0.6143
#   [MGVAE - kNN]
#     AUROC: 0.9478
#     G-mean: 0.8534
#     MCC: 0.7609
#     F1-score: 0.7550
#     mAP: 0.8600
#   [MGVAE - MLP]
#     AUROC: 0.9040
#     G-mean: 0.8230
#     MCC: 0.5000
#     F1-score: 0.4805
#     mAP: 0.6784
#   [MGVAE - RandomForest]
#     AUROC: 0.9869
#     G-mean: 0.7248
#     MCC: 0.6961
#     F1-score: 0.6950
#     mAP: 0.9209
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.9836
#     G-mean: 0.8710
#     MCC: 0.5502
#     F1-score: 0.5254
#     mAP: 0.8930
#   [GAMO - DecisionTree]
#     AUROC: 0.8933
#     G-mean: 0.8179
#     MCC: 0.5682
#     F1-score: 0.5565
#     mAP: 0.5898
#   [GAMO - kNN]
#     AUROC: 0.9559
#     G-mean: 0.7694
#     MCC: 0.5961
#     F1-score: 0.5902
#     mAP: 0.6938
#   [GAMO - MLP]
#     AUROC: 0.9304
#     G-mean: 0.8183
#     MCC: 0.4059
#     F1-score: 0.3744
#     mAP: 0.6300
#   [GAMO - RandomForest]
#     AUROC: 0.9841
#     G-mean: 0.8833
#     MCC: 0.6993
#     F1-score: 0.6890
#     mAP: 0.8690
#   [MGVAE - SVM]
#     AUROC: 0.9920
#     G-mean: 0.8135
#     MCC: 0.7822
#     F1-score: 0.7787
#     mAP: 0.9450
#   [MGVAE - DecisionTree]
#     AUROC: 0.8575
#     G-mean: 0.7556
#     MCC: 0.6665
#     F1-score: 0.6667
#     mAP: 0.6208
#   [MGVAE - kNN]
#     AUROC: 0.9463
#     G-mean: 0.8417
#     MCC: 0.7584
#     F1-score: 0.7533
#     mAP: 0.8489
#   [MGVAE - MLP]
#     AUROC: 0.9072
#     G-mean: 0.8085
#     MCC: 0.4915
#     F1-score: 0.4734
#     mAP: 0.6845
#   [MGVAE - RandomForest]
#     AUROC: 0.9890
#     G-mean: 0.7477
#     MCC: 0.7204
#     F1-score: 0.7187
#     mAP: 0.9333
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.9847
#     G-mean: 0.8762
#     MCC: 0.5553
#     F1-score: 0.5277
#     mAP: 0.8997
#   [GAMO - DecisionTree]
#     AUROC: 0.8905
#     G-mean: 0.8171
#     MCC: 0.5745
#     F1-score: 0.5615
#     mAP: 0.5757
#   [GAMO - kNN]
#     AUROC: 0.9577
#     G-mean: 0.7860
#     MCC: 0.6102
#     F1-score: 0.6018
#     mAP: 0.7065
#   [GAMO - MLP]
#     AUROC: 0.9324
#     G-mean: 0.8248
#     MCC: 0.4105
#     F1-score: 0.3779
#     mAP: 0.6358
#   [GAMO - RandomForest]
#     AUROC: 0.9847
#     G-mean: 0.8936
#     MCC: 0.7067
#     F1-score: 0.6953
#     mAP: 0.8714
#   [MGVAE - SVM]
#     AUROC: 0.9917
#     G-mean: 0.8296
#     MCC: 0.7978
#     F1-score: 0.7933
#     mAP: 0.9417
#   [MGVAE - DecisionTree]
#     AUROC: 0.8700
#     G-mean: 0.7767
#     MCC: 0.6824
#     F1-score: 0.6811
#     mAP: 0.6341
#   [MGVAE - kNN]
#     AUROC: 0.9494
#     G-mean: 0.8575
#     MCC: 0.7780
#     F1-score: 0.7722
#     mAP: 0.8471
#   [MGVAE - MLP]
#     AUROC: 0.9101
#     G-mean: 0.8218
#     MCC: 0.4942
#     F1-score: 0.4756
#     mAP: 0.6914
#   [MGVAE - RandomForest]
#     AUROC: 0.9892
#     G-mean: 0.7560
#     MCC: 0.7285
#     F1-score: 0.7267
#     mAP: 0.9320
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.9812
#     G-mean: 0.8709
#     MCC: 0.5527
#     F1-score: 0.5258
#     mAP: 0.8836
#   [GAMO - DecisionTree]
#     AUROC: 0.8804
#     G-mean: 0.7963
#     MCC: 0.5582
#     F1-score: 0.5466
#     mAP: 0.5584
#   [GAMO - kNN]
#     AUROC: 0.9569
#     G-mean: 0.7712
#     MCC: 0.5994
#     F1-score: 0.5916
#     mAP: 0.6906
#   [GAMO - MLP]
#     AUROC: 0.9252
#     G-mean: 0.8186
#     MCC: 0.4065
#     F1-score: 0.3756
#     mAP: 0.6168
#   [GAMO - RandomForest]
#     AUROC: 0.9840
#     G-mean: 0.8919
#     MCC: 0.7131
#     F1-score: 0.7016
#     mAP: 0.8659
#   [MGVAE - SVM]
#     AUROC: 0.9921
#     G-mean: 0.8250
#     MCC: 0.7937
#     F1-score: 0.7895
#     mAP: 0.9429
#   [MGVAE - DecisionTree]
#     AUROC: 0.8690
#     G-mean: 0.7740
#     MCC: 0.6765
#     F1-score: 0.6738
#     mAP: 0.6241
#   [MGVAE - kNN]
#     AUROC: 0.9477
#     G-mean: 0.8489
#     MCC: 0.7767
#     F1-score: 0.7714
#     mAP: 0.8410
#   [MGVAE - MLP]
#     AUROC: 0.9101
#     G-mean: 0.8109
#     MCC: 0.4860
#     F1-score: 0.4686
#     mAP: 0.6848
#   [MGVAE - RandomForest]
#     AUROC: 0.9872
#     G-mean: 0.7472
#     MCC: 0.7179
#     F1-score: 0.7157
#     mAP: 0.9214
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.9798
#     G-mean: 0.8792
#     MCC: 0.5577
#     F1-score: 0.5291
#     mAP: 0.8794
#   [GAMO - DecisionTree]
#     AUROC: 0.8828
#     G-mean: 0.8025
#     MCC: 0.5538
#     F1-score: 0.5408
#     mAP: 0.5558
#   [GAMO - kNN]
#     AUROC: 0.9524
#     G-mean: 0.7797
#     MCC: 0.6061
#     F1-score: 0.5974
#     mAP: 0.7046
#   [GAMO - MLP]
#     AUROC: 0.9255
#     G-mean: 0.8267
#     MCC: 0.4172
#     F1-score: 0.3859
#     mAP: 0.6259
#   [GAMO - RandomForest]
#     AUROC: 0.9829
#     G-mean: 0.8901
#     MCC: 0.7097
#     F1-score: 0.6981
#     mAP: 0.8650
#   [MGVAE - SVM]
#     AUROC: 0.9925
#     G-mean: 0.8182
#     MCC: 0.7900
#     F1-score: 0.7867
#     mAP: 0.9437
#   [MGVAE - DecisionTree]
#     AUROC: 0.8738
#     G-mean: 0.7841
#     MCC: 0.6825
#     F1-score: 0.6800
#     mAP: 0.6285
#   [MGVAE - kNN]
#     AUROC: 0.9471
#     G-mean: 0.8507
#     MCC: 0.7787
#     F1-score: 0.7729
#     mAP: 0.8406
#   [MGVAE - MLP]
#     AUROC: 0.9066
#     G-mean: 0.8145
#     MCC: 0.4912
#     F1-score: 0.4734
#     mAP: 0.6874
#   [MGVAE - RandomForest]
#     AUROC: 0.9882
#     G-mean: 0.7495
#     MCC: 0.7187
#     F1-score: 0.7158
#     mAP: 0.9250
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.9798
#     G-mean: 0.8715
#     MCC: 0.5476
#     F1-score: 0.5192
#     mAP: 0.8770
#   [GAMO - DecisionTree]
#     AUROC: 0.8843
#     G-mean: 0.8056
#     MCC: 0.5549
#     F1-score: 0.5420
#     mAP: 0.5534
#   [GAMO - kNN]
#     AUROC: 0.9509
#     G-mean: 0.7724
#     MCC: 0.5956
#     F1-score: 0.5862
#     mAP: 0.7027
#   [GAMO - MLP]
#     AUROC: 0.9241
#     G-mean: 0.8297
#     MCC: 0.4160
#     F1-score: 0.3841
#     mAP: 0.6214
#   [GAMO - RandomForest]
#     AUROC: 0.9826
#     G-mean: 0.8954
#     MCC: 0.7067
#     F1-score: 0.6935
#     mAP: 0.8642
#   [MGVAE - SVM]
#     AUROC: 0.9922
#     G-mean: 0.8126
#     MCC: 0.7842
#     F1-score: 0.7807
#     mAP: 0.9417
#   [MGVAE - DecisionTree]
#     AUROC: 0.8784
#     G-mean: 0.7928
#     MCC: 0.6939
#     F1-score: 0.6915
#     mAP: 0.6417
#   [MGVAE - kNN]
#     AUROC: 0.9495
#     G-mean: 0.8523
#     MCC: 0.7818
#     F1-score: 0.7759
#     mAP: 0.8477
#   [MGVAE - MLP]
#     AUROC: 0.9074
#     G-mean: 0.8147
#     MCC: 0.4915
#     F1-score: 0.4743
#     mAP: 0.6838
#   [MGVAE - RandomForest]
#     AUROC: 0.9879
#     G-mean: 0.7624
#     MCC: 0.7285
#     F1-score: 0.7252
#     mAP: 0.9217
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.9809
#     G-mean: 0.8755
#     MCC: 0.5473
#     F1-score: 0.5188
#     mAP: 0.8810
#   [GAMO - DecisionTree]
#     AUROC: 0.8902
#     G-mean: 0.8184
#     MCC: 0.5657
#     F1-score: 0.5525
#     mAP: 0.5654
#   [GAMO - kNN]
#     AUROC: 0.9532
#     G-mean: 0.7789
#     MCC: 0.5933
#     F1-score: 0.5823
#     mAP: 0.6949
#   [GAMO - MLP]
#     AUROC: 0.9212
#     G-mean: 0.8334
#     MCC: 0.4168
#     F1-score: 0.3836
#     mAP: 0.6127
#   [GAMO - RandomForest]
#     AUROC: 0.9828
#     G-mean: 0.9001
#     MCC: 0.7083
#     F1-score: 0.6945
#     mAP: 0.8637
#   [MGVAE - SVM]
#     AUROC: 0.9922
#     G-mean: 0.8153
#     MCC: 0.7864
#     F1-score: 0.7827
#     mAP: 0.9408
#   [MGVAE - DecisionTree]
#     AUROC: 0.8790
#     G-mean: 0.7964
#     MCC: 0.6951
#     F1-score: 0.6920
#     mAP: 0.6389
#   [MGVAE - kNN]
#     AUROC: 0.9515
#     G-mean: 0.8603
#     MCC: 0.7857
#     F1-score: 0.7800
#     mAP: 0.8518
#   [MGVAE - MLP]
#     AUROC: 0.9129
#     G-mean: 0.8243
#     MCC: 0.4958
#     F1-score: 0.4777
#     mAP: 0.6903
#   [MGVAE - RandomForest]
#     AUROC: 0.9878
#     G-mean: 0.7727
#     MCC: 0.7375
#     F1-score: 0.7343
#     mAP: 0.9178
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/glass4_results_GAMO_MGVAE_beta_0.1.csv

# %%
data_name = 'ionosphere'

# 실험 파라미터 설정
n_epochs = 1000
hidden_dims = [32, 64, 128]
latent_dim = 256
lr = 0.01
beta = 0.005

# 데이터 불러오기
ionosphere = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)
ionosphere = ionosphere.drop(ionosphere.columns[1], axis=1)

# 실험 실행
final_res = run_exp(
    data=ionosphere, 
    cat_idx=[], 
    methods=methods, 
    kernel_type=kernel_type,
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (351, 33)
# target : Counter({0: 225, 1: 126})
# IR: 1.79
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.9847
#     G-mean: 0.9483
#     MCC: 0.9094
#     F1-score: 0.9366
#     mAP: 0.9836
#   [GAMO - DecisionTree]
#     AUROC: 0.8932
#     G-mean: 0.8392
#     MCC: 0.7198
#     F1-score: 0.8055
#     mAP: 0.8061
#   [GAMO - kNN]
#     AUROC: 0.9283
#     G-mean: 0.7916
#     MCC: 0.6979
#     F1-score: 0.7614
#     mAP: 0.8914
#   [GAMO - MLP]
#     AUROC: 0.9330
#     G-mean: 0.8485
#     MCC: 0.7148
#     F1-score: 0.8117
#     mAP: 0.9159
#   [GAMO - RandomForest]
#     AUROC: 0.9808
#     G-mean: 0.9131
#     MCC: 0.8464
#     F1-score: 0.8935
#     mAP: 0.9765
#   [MGVAE - SVM]
#     AUROC: 0.9822
#     G-mean: 0.9260
#     MCC: 0.8842
#     F1-score: 0.9154
#     mAP: 0.9791
#   [MGVAE - DecisionTree]
#     AUROC: 0.8144
#     G-mean: 0.8165
#     MCC: 0.6800
#     F1-score: 0.7730
#     mAP: 0.7368
#   [MGVAE - kNN]
#     AUROC: 0.9200
#     G-mean: 0.7919
#     MCC: 0.6912
#     F1-score: 0.7608
#     mAP: 0.8756
#   [MGVAE - MLP]
#     AUROC: 0.8876
#     G-mean: 0.8093
#     MCC: 0.6772
#     F1-score: 0.7731
#     mAP: 0.8788
#   [MGVAE - RandomForest]
#     AUROC: 0.9776
#     G-mean: 0.9200
#     MCC: 0.8633
#     F1-score: 0.9041
#     mAP: 0.9644
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.9862
#     G-mean: 0.9468
#     MCC: 0.9070
#     F1-score: 0.9363
#     mAP: 0.9839
#   [GAMO - DecisionTree]
#     AUROC: 0.9029
#     G-mean: 0.8566
#     MCC: 0.7540
#     F1-score: 0.8286
#     mAP: 0.8280
#   [GAMO - kNN]
#     AUROC: 0.9261
#     G-mean: 0.7956
#     MCC: 0.7018
#     F1-score: 0.7669
#     mAP: 0.8882
#   [GAMO - MLP]
#     AUROC: 0.9188
#     G-mean: 0.8427
#     MCC: 0.6971
#     F1-score: 0.8031
#     mAP: 0.9063
#   [GAMO - RandomForest]
#     AUROC: 0.9834
#     G-mean: 0.9159
#     MCC: 0.8499
#     F1-score: 0.8980
#     mAP: 0.9775
#   [MGVAE - SVM]
#     AUROC: 0.9827
#     G-mean: 0.9336
#     MCC: 0.8907
#     F1-score: 0.9233
#     mAP: 0.9785
#   [MGVAE - DecisionTree]
#     AUROC: 0.8200
#     G-mean: 0.8273
#     MCC: 0.6962
#     F1-score: 0.7878
#     mAP: 0.7480
#   [MGVAE - kNN]
#     AUROC: 0.9178
#     G-mean: 0.7942
#     MCC: 0.6949
#     F1-score: 0.7641
#     mAP: 0.8727
#   [MGVAE - MLP]
#     AUROC: 0.8841
#     G-mean: 0.8135
#     MCC: 0.6748
#     F1-score: 0.7752
#     mAP: 0.8730
#   [MGVAE - RandomForest]
#     AUROC: 0.9800
#     G-mean: 0.9174
#     MCC: 0.8550
#     F1-score: 0.9015
#     mAP: 0.9693
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.9865
#     G-mean: 0.9479
#     MCC: 0.9079
#     F1-score: 0.9374
#     mAP: 0.9846
#   [GAMO - DecisionTree]
#     AUROC: 0.8825
#     G-mean: 0.8476
#     MCC: 0.7375
#     F1-score: 0.8177
#     mAP: 0.8084
#   [GAMO - kNN]
#     AUROC: 0.9253
#     G-mean: 0.8018
#     MCC: 0.7097
#     F1-score: 0.7744
#     mAP: 0.8862
#   [GAMO - MLP]
#     AUROC: 0.9246
#     G-mean: 0.8453
#     MCC: 0.7038
#     F1-score: 0.8064
#     mAP: 0.9115
#   [GAMO - RandomForest]
#     AUROC: 0.9827
#     G-mean: 0.9167
#     MCC: 0.8512
#     F1-score: 0.8991
#     mAP: 0.9768
#   [MGVAE - SVM]
#     AUROC: 0.9826
#     G-mean: 0.9322
#     MCC: 0.8889
#     F1-score: 0.9226
#     mAP: 0.9788
#   [MGVAE - DecisionTree]
#     AUROC: 0.8229
#     G-mean: 0.8329
#     MCC: 0.7008
#     F1-score: 0.7941
#     mAP: 0.7471
#   [MGVAE - kNN]
#     AUROC: 0.9165
#     G-mean: 0.7928
#     MCC: 0.6933
#     F1-score: 0.7622
#     mAP: 0.8695
#   [MGVAE - MLP]
#     AUROC: 0.8876
#     G-mean: 0.8142
#     MCC: 0.6787
#     F1-score: 0.7773
#     mAP: 0.8770
#   [MGVAE - RandomForest]
#     AUROC: 0.9800
#     G-mean: 0.9170
#     MCC: 0.8550
#     F1-score: 0.9015
#     mAP: 0.9695
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.9865
#     G-mean: 0.9475
#     MCC: 0.9066
#     F1-score: 0.9368
#     mAP: 0.9848
#   [GAMO - DecisionTree]
#     AUROC: 0.8817
#     G-mean: 0.8482
#     MCC: 0.7364
#     F1-score: 0.8177
#     mAP: 0.8096
#   [GAMO - kNN]
#     AUROC: 0.9239
#     G-mean: 0.8056
#     MCC: 0.7153
#     F1-score: 0.7785
#     mAP: 0.8841
#   [GAMO - MLP]
#     AUROC: 0.9250
#     G-mean: 0.8447
#     MCC: 0.7042
#     F1-score: 0.8062
#     mAP: 0.9122
#   [GAMO - RandomForest]
#     AUROC: 0.9834
#     G-mean: 0.9155
#     MCC: 0.8493
#     F1-score: 0.8974
#     mAP: 0.9775
#   [MGVAE - SVM]
#     AUROC: 0.9827
#     G-mean: 0.9342
#     MCC: 0.8909
#     F1-score: 0.9245
#     mAP: 0.9793
#   [MGVAE - DecisionTree]
#     AUROC: 0.8185
#     G-mean: 0.8333
#     MCC: 0.7012
#     F1-score: 0.7942
#     mAP: 0.7445
#   [MGVAE - kNN]
#     AUROC: 0.9157
#     G-mean: 0.7947
#     MCC: 0.6971
#     F1-score: 0.7642
#     mAP: 0.8691
#   [MGVAE - MLP]
#     AUROC: 0.8855
#     G-mean: 0.8119
#     MCC: 0.6743
#     F1-score: 0.7740
#     mAP: 0.8745
#   [MGVAE - RandomForest]
#     AUROC: 0.9803
#     G-mean: 0.9153
#     MCC: 0.8515
#     F1-score: 0.8991
#     mAP: 0.9702
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.9870
#     G-mean: 0.9471
#     MCC: 0.9061
#     F1-score: 0.9363
#     mAP: 0.9850
#   [GAMO - DecisionTree]
#     AUROC: 0.8839
#     G-mean: 0.8475
#     MCC: 0.7353
#     F1-score: 0.8162
#     mAP: 0.8116
#   [GAMO - kNN]
#     AUROC: 0.9225
#     G-mean: 0.8045
#     MCC: 0.7139
#     F1-score: 0.7773
#     mAP: 0.8824
#   [GAMO - MLP]
#     AUROC: 0.9239
#     G-mean: 0.8453
#     MCC: 0.7070
#     F1-score: 0.8069
#     mAP: 0.9117
#   [GAMO - RandomForest]
#     AUROC: 0.9841
#     G-mean: 0.9146
#     MCC: 0.8479
#     F1-score: 0.8964
#     mAP: 0.9783
#   [MGVAE - SVM]
#     AUROC: 0.9834
#     G-mean: 0.9336
#     MCC: 0.8899
#     F1-score: 0.9238
#     mAP: 0.9799
#   [MGVAE - DecisionTree]
#     AUROC: 0.8294
#     G-mean: 0.8418
#     MCC: 0.7134
#     F1-score: 0.8040
#     mAP: 0.7549
#   [MGVAE - kNN]
#     AUROC: 0.9157
#     G-mean: 0.7926
#     MCC: 0.6944
#     F1-score: 0.7618
#     mAP: 0.8698
#   [MGVAE - MLP]
#     AUROC: 0.8860
#     G-mean: 0.8136
#     MCC: 0.6770
#     F1-score: 0.7760
#     mAP: 0.8755
#   [MGVAE - RandomForest]
#     AUROC: 0.9811
#     G-mean: 0.9143
#     MCC: 0.8511
#     F1-score: 0.8980
#     mAP: 0.9716
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.9876
#     G-mean: 0.9464
#     MCC: 0.9056
#     F1-score: 0.9360
#     mAP: 0.9857
#   [GAMO - DecisionTree]
#     AUROC: 0.8801
#     G-mean: 0.8474
#     MCC: 0.7351
#     F1-score: 0.8162
#     mAP: 0.8107
#   [GAMO - kNN]
#     AUROC: 0.9213
#     G-mean: 0.7994
#     MCC: 0.7087
#     F1-score: 0.7707
#     mAP: 0.8809
#   [GAMO - MLP]
#     AUROC: 0.9230
#     G-mean: 0.8431
#     MCC: 0.7049
#     F1-score: 0.8047
#     mAP: 0.9105
#   [GAMO - RandomForest]
#     AUROC: 0.9844
#     G-mean: 0.9148
#     MCC: 0.8480
#     F1-score: 0.8967
#     mAP: 0.9786
#   [MGVAE - SVM]
#     AUROC: 0.9843
#     G-mean: 0.9321
#     MCC: 0.8883
#     F1-score: 0.9222
#     mAP: 0.9811
#   [MGVAE - DecisionTree]
#     AUROC: 0.8356
#     G-mean: 0.8471
#     MCC: 0.7216
#     F1-score: 0.8101
#     mAP: 0.7595
#   [MGVAE - kNN]
#     AUROC: 0.9148
#     G-mean: 0.7914
#     MCC: 0.6935
#     F1-score: 0.7603
#     mAP: 0.8678
#   [MGVAE - MLP]
#     AUROC: 0.8869
#     G-mean: 0.8127
#     MCC: 0.6761
#     F1-score: 0.7750
#     mAP: 0.8773
#   [MGVAE - RandomForest]
#     AUROC: 0.9818
#     G-mean: 0.9153
#     MCC: 0.8525
#     F1-score: 0.8992
#     mAP: 0.9729
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.9876
#     G-mean: 0.9469
#     MCC: 0.9059
#     F1-score: 0.9364
#     mAP: 0.9855
#   [GAMO - DecisionTree]
#     AUROC: 0.8816
#     G-mean: 0.8479
#     MCC: 0.7375
#     F1-score: 0.8172
#     mAP: 0.8152
#   [GAMO - kNN]
#     AUROC: 0.9214
#     G-mean: 0.7998
#     MCC: 0.7094
#     F1-score: 0.7716
#     mAP: 0.8806
#   [GAMO - MLP]
#     AUROC: 0.9246
#     G-mean: 0.8420
#     MCC: 0.7026
#     F1-score: 0.8035
#     mAP: 0.9112
#   [GAMO - RandomForest]
#     AUROC: 0.9842
#     G-mean: 0.9166
#     MCC: 0.8503
#     F1-score: 0.8987
#     mAP: 0.9781
#   [MGVAE - SVM]
#     AUROC: 0.9843
#     G-mean: 0.9335
#     MCC: 0.8892
#     F1-score: 0.9234
#     mAP: 0.9807
#   [MGVAE - DecisionTree]
#     AUROC: 0.8368
#     G-mean: 0.8476
#     MCC: 0.7232
#     F1-score: 0.8112
#     mAP: 0.7628
#   [MGVAE - kNN]
#     AUROC: 0.9149
#     G-mean: 0.7932
#     MCC: 0.6961
#     F1-score: 0.7625
#     mAP: 0.8682
#   [MGVAE - MLP]
#     AUROC: 0.8877
#     G-mean: 0.8120
#     MCC: 0.6739
#     F1-score: 0.7735
#     mAP: 0.8769
#   [MGVAE - RandomForest]
#     AUROC: 0.9813
#     G-mean: 0.9154
#     MCC: 0.8515
#     F1-score: 0.8989
#     mAP: 0.9713
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.9877
#     G-mean: 0.9470
#     MCC: 0.9057
#     F1-score: 0.9364
#     mAP: 0.9855
#   [GAMO - DecisionTree]
#     AUROC: 0.8796
#     G-mean: 0.8463
#     MCC: 0.7339
#     F1-score: 0.8148
#     mAP: 0.8108
#   [GAMO - kNN]
#     AUROC: 0.9219
#     G-mean: 0.7985
#     MCC: 0.7071
#     F1-score: 0.7700
#     mAP: 0.8813
#   [GAMO - MLP]
#     AUROC: 0.9242
#     G-mean: 0.8430
#     MCC: 0.7037
#     F1-score: 0.8043
#     mAP: 0.9113
#   [GAMO - RandomForest]
#     AUROC: 0.9845
#     G-mean: 0.9173
#     MCC: 0.8508
#     F1-score: 0.8992
#     mAP: 0.9785
#   [MGVAE - SVM]
#     AUROC: 0.9844
#     G-mean: 0.9344
#     MCC: 0.8900
#     F1-score: 0.9242
#     mAP: 0.9804
#   [MGVAE - DecisionTree]
#     AUROC: 0.8360
#     G-mean: 0.8481
#     MCC: 0.7255
#     F1-score: 0.8126
#     mAP: 0.7639
#   [MGVAE - kNN]
#     AUROC: 0.9147
#     G-mean: 0.7929
#     MCC: 0.6954
#     F1-score: 0.7619
#     mAP: 0.8680
#   [MGVAE - MLP]
#     AUROC: 0.8877
#     G-mean: 0.8119
#     MCC: 0.6733
#     F1-score: 0.7732
#     mAP: 0.8766
#   [MGVAE - RandomForest]
#     AUROC: 0.9815
#     G-mean: 0.9154
#     MCC: 0.8517
#     F1-score: 0.8988
#     mAP: 0.9713
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.9873
#     G-mean: 0.9475
#     MCC: 0.9065
#     F1-score: 0.9371
#     mAP: 0.9850
#   [GAMO - DecisionTree]
#     AUROC: 0.8829
#     G-mean: 0.8484
#     MCC: 0.7373
#     F1-score: 0.8173
#     mAP: 0.8141
#   [GAMO - kNN]
#     AUROC: 0.9206
#     G-mean: 0.7986
#     MCC: 0.7070
#     F1-score: 0.7699
#     mAP: 0.8792
#   [GAMO - MLP]
#     AUROC: 0.9276
#     G-mean: 0.8439
#     MCC: 0.7063
#     F1-score: 0.8058
#     mAP: 0.9145
#   [GAMO - RandomForest]
#     AUROC: 0.9840
#     G-mean: 0.9173
#     MCC: 0.8502
#     F1-score: 0.8991
#     mAP: 0.9778
#   [MGVAE - SVM]
#     AUROC: 0.9842
#     G-mean: 0.9344
#     MCC: 0.8899
#     F1-score: 0.9242
#     mAP: 0.9803
#   [MGVAE - DecisionTree]
#     AUROC: 0.8336
#     G-mean: 0.8483
#     MCC: 0.7250
#     F1-score: 0.8126
#     mAP: 0.7622
#   [MGVAE - kNN]
#     AUROC: 0.9139
#     G-mean: 0.7923
#     MCC: 0.6941
#     F1-score: 0.7610
#     mAP: 0.8670
#   [MGVAE - MLP]
#     AUROC: 0.8869
#     G-mean: 0.8102
#     MCC: 0.6697
#     F1-score: 0.7710
#     mAP: 0.8746
#   [MGVAE - RandomForest]
#     AUROC: 0.9811
#     G-mean: 0.9152
#     MCC: 0.8503
#     F1-score: 0.8983
#     mAP: 0.9706
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.9872
#     G-mean: 0.9476
#     MCC: 0.9067
#     F1-score: 0.9373
#     mAP: 0.9848
#   [GAMO - DecisionTree]
#     AUROC: 0.8828
#     G-mean: 0.8484
#     MCC: 0.7363
#     F1-score: 0.8171
#     mAP: 0.8127
#   [GAMO - kNN]
#     AUROC: 0.9213
#     G-mean: 0.7977
#     MCC: 0.7057
#     F1-score: 0.7689
#     mAP: 0.8800
#   [GAMO - MLP]
#     AUROC: 0.9274
#     G-mean: 0.8451
#     MCC: 0.7075
#     F1-score: 0.8069
#     mAP: 0.9141
#   [GAMO - RandomForest]
#     AUROC: 0.9839
#     G-mean: 0.9176
#     MCC: 0.8504
#     F1-score: 0.8993
#     mAP: 0.9776
#   [MGVAE - SVM]
#     AUROC: 0.9841
#     G-mean: 0.9356
#     MCC: 0.8917
#     F1-score: 0.9256
#     mAP: 0.9803
#   [MGVAE - DecisionTree]
#     AUROC: 0.8334
#     G-mean: 0.8478
#     MCC: 0.7233
#     F1-score: 0.8117
#     mAP: 0.7605
#   [MGVAE - kNN]
#     AUROC: 0.9146
#     G-mean: 0.7923
#     MCC: 0.6938
#     F1-score: 0.7611
#     mAP: 0.8681
#   [MGVAE - MLP]
#     AUROC: 0.8870
#     G-mean: 0.8113
#     MCC: 0.6704
#     F1-score: 0.7719
#     mAP: 0.8745
#   [MGVAE - RandomForest]
#     AUROC: 0.9806
#     G-mean: 0.9159
#     MCC: 0.8518
#     F1-score: 0.8993
#     mAP: 0.9697
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/ionosphere_results_GAMO_MGVAE_beta_0.005.csv
