# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

import os
import warnings
from imblearn.datasets import fetch_datasets
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from experiment import run_exp

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "6"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Save path 
save_path = "/data4/oldrain123/oldrain123/results/real_results"

# %%
data = fetch_datasets()
methods = ["GAMO", "MGVAE"]
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}

kernel_type = 'GAMO_MGVAE'

# %%
# spectrometer
data_name = 'spectrometer'
maj_target_name = -1

n_epochs = 1000
hidden_dims = [32, 64, 128, 256]
latent_dim = 512
lr = 0.005
beta = 0.001

final_res = run_exp(
    data=data, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    kernel_type=kernel_type,
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    maj_target_name=maj_target_name,
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded: spectrometer
# X shape : (531, 93)
# target : Counter({0: 486, 1: 45})
# IR: 10.8
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.9944
#     G-mean: 0.9043
#     MCC: 0.8637
#     F1-score: 0.8713
#     mAP: 0.9348
#   [GAMO - DecisionTree]
#     AUROC: 0.6762
#     G-mean: 0.5693
#     MCC: 0.3518
#     F1-score: 0.3935
#     mAP: 0.2681
#   [GAMO - kNN]
#     AUROC: 0.9315
#     G-mean: 0.8177
#     MCC: 0.7962
#     F1-score: 0.7853
#     mAP: 0.8426
#   [GAMO - MLP]
#     AUROC: 0.9304
#     G-mean: 0.6795
#     MCC: 0.5544
#     F1-score: 0.5690
#     mAP: 0.7387
#   [GAMO - RandomForest]
#     AUROC: 0.9840
#     G-mean: 0.9006
#     MCC: 0.8260
#     F1-score: 0.8351
#     mAP: 0.8908
#   [MGVAE - SVM]
#     AUROC: 0.9933
#     G-mean: 0.9112
#     MCC: 0.8571
#     F1-score: 0.8612
#     mAP: 0.9348
#   [MGVAE - DecisionTree]
#     AUROC: 0.8761
#     G-mean: 0.8469
#     MCC: 0.7238
#     F1-score: 0.7412
#     mAP: 0.6276
#   [MGVAE - kNN]
#     AUROC: 0.9490
#     G-mean: 0.8625
#     MCC: 0.8085
#     F1-score: 0.8063
#     mAP: 0.8363
#   [MGVAE - MLP]
#     AUROC: 0.9408
#     G-mean: 0.8426
#     MCC: 0.7115
#     F1-score: 0.7260
#     mAP: 0.8279
#   [MGVAE - RandomForest]
#     AUROC: 0.9895
#     G-mean: 0.8665
#     MCC: 0.8064
#     F1-score: 0.8125
#     mAP: 0.9333
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.9946
#     G-mean: 0.9094
#     MCC: 0.8722
#     F1-score: 0.8776
#     mAP: 0.9471
#   [GAMO - DecisionTree]
#     AUROC: 0.6950
#     G-mean: 0.6022
#     MCC: 0.3773
#     F1-score: 0.4145
#     mAP: 0.2825
#   [GAMO - kNN]
#     AUROC: 0.9303
#     G-mean: 0.8141
#     MCC: 0.7925
#     F1-score: 0.7819
#     mAP: 0.8390
#   [GAMO - MLP]
#     AUROC: 0.9344
#     G-mean: 0.7198
#     MCC: 0.5981
#     F1-score: 0.6060
#     mAP: 0.7668
#   [GAMO - RandomForest]
#     AUROC: 0.9829
#     G-mean: 0.8992
#     MCC: 0.8240
#     F1-score: 0.8318
#     mAP: 0.8930
#   [MGVAE - SVM]
#     AUROC: 0.9888
#     G-mean: 0.9179
#     MCC: 0.8483
#     F1-score: 0.8545
#     mAP: 0.9299
#   [MGVAE - DecisionTree]
#     AUROC: 0.8630
#     G-mean: 0.8402
#     MCC: 0.7159
#     F1-score: 0.7325
#     mAP: 0.6044
#   [MGVAE - kNN]
#     AUROC: 0.9451
#     G-mean: 0.8737
#     MCC: 0.8178
#     F1-score: 0.8187
#     mAP: 0.8472
#   [MGVAE - MLP]
#     AUROC: 0.9416
#     G-mean: 0.8652
#     MCC: 0.7359
#     F1-score: 0.7506
#     mAP: 0.8145
#   [MGVAE - RandomForest]
#     AUROC: 0.9915
#     G-mean: 0.8602
#     MCC: 0.8110
#     F1-score: 0.8117
#     mAP: 0.9419
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.9950
#     G-mean: 0.8954
#     MCC: 0.8579
#     F1-score: 0.8593
#     mAP: 0.9491
#   [GAMO - DecisionTree]
#     AUROC: 0.6799
#     G-mean: 0.5863
#     MCC: 0.3598
#     F1-score: 0.3989
#     mAP: 0.2679
#   [GAMO - kNN]
#     AUROC: 0.9293
#     G-mean: 0.8108
#     MCC: 0.7894
#     F1-score: 0.7788
#     mAP: 0.8384
#   [GAMO - MLP]
#     AUROC: 0.9342
#     G-mean: 0.7534
#     MCC: 0.6186
#     F1-score: 0.6329
#     mAP: 0.7794
#   [GAMO - RandomForest]
#     AUROC: 0.9824
#     G-mean: 0.8861
#     MCC: 0.7985
#     F1-score: 0.8091
#     mAP: 0.8901
#   [MGVAE - SVM]
#     AUROC: 0.9895
#     G-mean: 0.9089
#     MCC: 0.8397
#     F1-score: 0.8451
#     mAP: 0.9228
#   [MGVAE - DecisionTree]
#     AUROC: 0.8528
#     G-mean: 0.8288
#     MCC: 0.7065
#     F1-score: 0.7217
#     mAP: 0.5941
#   [MGVAE - kNN]
#     AUROC: 0.9460
#     G-mean: 0.8715
#     MCC: 0.8205
#     F1-score: 0.8209
#     mAP: 0.8469
#   [MGVAE - MLP]
#     AUROC: 0.9390
#     G-mean: 0.8492
#     MCC: 0.7153
#     F1-score: 0.7277
#     mAP: 0.8113
#   [MGVAE - RandomForest]
#     AUROC: 0.9918
#     G-mean: 0.8569
#     MCC: 0.7989
#     F1-score: 0.8025
#     mAP: 0.9379
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.9949
#     G-mean: 0.8963
#     MCC: 0.8579
#     F1-score: 0.8603
#     mAP: 0.9477
#   [GAMO - DecisionTree]
#     AUROC: 0.6705
#     G-mean: 0.5781
#     MCC: 0.3487
#     F1-score: 0.3858
#     mAP: 0.2568
#   [GAMO - kNN]
#     AUROC: 0.9293
#     G-mean: 0.8039
#     MCC: 0.7821
#     F1-score: 0.7701
#     mAP: 0.8395
#   [GAMO - MLP]
#     AUROC: 0.9295
#     G-mean: 0.7358
#     MCC: 0.5994
#     F1-score: 0.6150
#     mAP: 0.7618
#   [GAMO - RandomForest]
#     AUROC: 0.9836
#     G-mean: 0.8842
#     MCC: 0.7900
#     F1-score: 0.8004
#     mAP: 0.8941
#   [MGVAE - SVM]
#     AUROC: 0.9896
#     G-mean: 0.9083
#     MCC: 0.8391
#     F1-score: 0.8444
#     mAP: 0.9284
#   [MGVAE - DecisionTree]
#     AUROC: 0.8409
#     G-mean: 0.8117
#     MCC: 0.6859
#     F1-score: 0.7009
#     mAP: 0.5731
#   [MGVAE - kNN]
#     AUROC: 0.9446
#     G-mean: 0.8714
#     MCC: 0.8167
#     F1-score: 0.8174
#     mAP: 0.8467
#   [MGVAE - MLP]
#     AUROC: 0.9295
#     G-mean: 0.8507
#     MCC: 0.7052
#     F1-score: 0.7194
#     mAP: 0.8140
#   [MGVAE - RandomForest]
#     AUROC: 0.9912
#     G-mean: 0.8496
#     MCC: 0.7929
#     F1-score: 0.7954
#     mAP: 0.9355
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.9947
#     G-mean: 0.8951
#     MCC: 0.8561
#     F1-score: 0.8591
#     mAP: 0.9458
#   [GAMO - DecisionTree]
#     AUROC: 0.6834
#     G-mean: 0.5997
#     MCC: 0.3653
#     F1-score: 0.4036
#     mAP: 0.2717
#   [GAMO - kNN]
#     AUROC: 0.9299
#     G-mean: 0.8074
#     MCC: 0.7851
#     F1-score: 0.7743
#     mAP: 0.8413
#   [GAMO - MLP]
#     AUROC: 0.9270
#     G-mean: 0.7469
#     MCC: 0.6113
#     F1-score: 0.6269
#     mAP: 0.7639
#   [GAMO - RandomForest]
#     AUROC: 0.9833
#     G-mean: 0.8838
#     MCC: 0.7951
#     F1-score: 0.8040
#     mAP: 0.8960
#   [MGVAE - SVM]
#     AUROC: 0.9887
#     G-mean: 0.9103
#     MCC: 0.8375
#     F1-score: 0.8436
#     mAP: 0.9296
#   [MGVAE - DecisionTree]
#     AUROC: 0.8422
#     G-mean: 0.8100
#     MCC: 0.6765
#     F1-score: 0.6932
#     mAP: 0.5702
#   [MGVAE - kNN]
#     AUROC: 0.9458
#     G-mean: 0.8712
#     MCC: 0.8166
#     F1-score: 0.8180
#     mAP: 0.8504
#   [MGVAE - MLP]
#     AUROC: 0.9330
#     G-mean: 0.8534
#     MCC: 0.7041
#     F1-score: 0.7184
#     mAP: 0.8194
#   [MGVAE - RandomForest]
#     AUROC: 0.9908
#     G-mean: 0.8543
#     MCC: 0.7980
#     F1-score: 0.8019
#     mAP: 0.9340
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.9947
#     G-mean: 0.8964
#     MCC: 0.8581
#     F1-score: 0.8613
#     mAP: 0.9483
#   [GAMO - DecisionTree]
#     AUROC: 0.6852
#     G-mean: 0.5948
#     MCC: 0.3640
#     F1-score: 0.4031
#     mAP: 0.2696
#   [GAMO - kNN]
#     AUROC: 0.9303
#     G-mean: 0.8069
#     MCC: 0.7852
#     F1-score: 0.7735
#     mAP: 0.8432
#   [GAMO - MLP]
#     AUROC: 0.9292
#     G-mean: 0.7576
#     MCC: 0.6226
#     F1-score: 0.6376
#     mAP: 0.7700
#   [GAMO - RandomForest]
#     AUROC: 0.9825
#     G-mean: 0.8860
#     MCC: 0.7988
#     F1-score: 0.8076
#     mAP: 0.8949
#   [MGVAE - SVM]
#     AUROC: 0.9888
#     G-mean: 0.9100
#     MCC: 0.8365
#     F1-score: 0.8418
#     mAP: 0.9322
#   [MGVAE - DecisionTree]
#     AUROC: 0.8403
#     G-mean: 0.8102
#     MCC: 0.6775
#     F1-score: 0.6936
#     mAP: 0.5636
#   [MGVAE - kNN]
#     AUROC: 0.9484
#     G-mean: 0.8705
#     MCC: 0.8100
#     F1-score: 0.8108
#     mAP: 0.8499
#   [MGVAE - MLP]
#     AUROC: 0.9326
#     G-mean: 0.8563
#     MCC: 0.7072
#     F1-score: 0.7216
#     mAP: 0.8211
#   [MGVAE - RandomForest]
#     AUROC: 0.9903
#     G-mean: 0.8535
#     MCC: 0.7974
#     F1-score: 0.8010
#     mAP: 0.9312
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.9947
#     G-mean: 0.8926
#     MCC: 0.8537
#     F1-score: 0.8563
#     mAP: 0.9472
#   [GAMO - DecisionTree]
#     AUROC: 0.6896
#     G-mean: 0.5996
#     MCC: 0.3661
#     F1-score: 0.4056
#     mAP: 0.2695
#   [GAMO - kNN]
#     AUROC: 0.9306
#     G-mean: 0.8069
#     MCC: 0.7853
#     F1-score: 0.7732
#     mAP: 0.8440
#   [GAMO - MLP]
#     AUROC: 0.9287
#     G-mean: 0.7495
#     MCC: 0.6151
#     F1-score: 0.6275
#     mAP: 0.7651
#   [GAMO - RandomForest]
#     AUROC: 0.9821
#     G-mean: 0.8852
#     MCC: 0.7964
#     F1-score: 0.8048
#     mAP: 0.8930
#   [MGVAE - SVM]
#     AUROC: 0.9887
#     G-mean: 0.9063
#     MCC: 0.8330
#     F1-score: 0.8381
#     mAP: 0.9279
#   [MGVAE - DecisionTree]
#     AUROC: 0.8441
#     G-mean: 0.8163
#     MCC: 0.6845
#     F1-score: 0.6999
#     mAP: 0.5679
#   [MGVAE - kNN]
#     AUROC: 0.9495
#     G-mean: 0.8716
#     MCC: 0.8139
#     F1-score: 0.8142
#     mAP: 0.8530
#   [MGVAE - MLP]
#     AUROC: 0.9342
#     G-mean: 0.8580
#     MCC: 0.7120
#     F1-score: 0.7251
#     mAP: 0.8256
#   [MGVAE - RandomForest]
#     AUROC: 0.9905
#     G-mean: 0.8504
#     MCC: 0.7966
#     F1-score: 0.7977
#     mAP: 0.9309
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.9947
#     G-mean: 0.8907
#     MCC: 0.8518
#     F1-score: 0.8538
#     mAP: 0.9471
#   [GAMO - DecisionTree]
#     AUROC: 0.6899
#     G-mean: 0.5922
#     MCC: 0.3594
#     F1-score: 0.3995
#     mAP: 0.2671
#   [GAMO - kNN]
#     AUROC: 0.9312
#     G-mean: 0.8049
#     MCC: 0.7828
#     F1-score: 0.7710
#     mAP: 0.8457
#   [GAMO - MLP]
#     AUROC: 0.9301
#     G-mean: 0.7514
#     MCC: 0.6161
#     F1-score: 0.6294
#     mAP: 0.7670
#   [GAMO - RandomForest]
#     AUROC: 0.9822
#     G-mean: 0.8855
#     MCC: 0.7989
#     F1-score: 0.8070
#     mAP: 0.8946
#   [MGVAE - SVM]
#     AUROC: 0.9881
#     G-mean: 0.9007
#     MCC: 0.8263
#     F1-score: 0.8323
#     mAP: 0.9263
#   [MGVAE - DecisionTree]
#     AUROC: 0.8430
#     G-mean: 0.8141
#     MCC: 0.6816
#     F1-score: 0.6973
#     mAP: 0.5683
#   [MGVAE - kNN]
#     AUROC: 0.9498
#     G-mean: 0.8681
#     MCC: 0.8064
#     F1-score: 0.8071
#     mAP: 0.8532
#   [MGVAE - MLP]
#     AUROC: 0.9373
#     G-mean: 0.8489
#     MCC: 0.6995
#     F1-score: 0.7134
#     mAP: 0.8269
#   [MGVAE - RandomForest]
#     AUROC: 0.9903
#     G-mean: 0.8535
#     MCC: 0.8007
#     F1-score: 0.8026
#     mAP: 0.9322
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.9946
#     G-mean: 0.8887
#     MCC: 0.8504
#     F1-score: 0.8519
#     mAP: 0.9481
#   [GAMO - DecisionTree]
#     AUROC: 0.6913
#     G-mean: 0.5970
#     MCC: 0.3635
#     F1-score: 0.4043
#     mAP: 0.2707
#   [GAMO - kNN]
#     AUROC: 0.9314
#     G-mean: 0.8013
#     MCC: 0.7795
#     F1-score: 0.7666
#     mAP: 0.8478
#   [GAMO - MLP]
#     AUROC: 0.9294
#     G-mean: 0.7514
#     MCC: 0.6164
#     F1-score: 0.6306
#     mAP: 0.7650
#   [GAMO - RandomForest]
#     AUROC: 0.9822
#     G-mean: 0.8864
#     MCC: 0.7990
#     F1-score: 0.8072
#     mAP: 0.8955
#   [MGVAE - SVM]
#     AUROC: 0.9888
#     G-mean: 0.8980
#     MCC: 0.8242
#     F1-score: 0.8292
#     mAP: 0.9301
#   [MGVAE - DecisionTree]
#     AUROC: 0.8407
#     G-mean: 0.8124
#     MCC: 0.6816
#     F1-score: 0.6963
#     mAP: 0.5662
#   [MGVAE - kNN]
#     AUROC: 0.9487
#     G-mean: 0.8638
#     MCC: 0.8012
#     F1-score: 0.8004
#     mAP: 0.8512
#   [MGVAE - MLP]
#     AUROC: 0.9367
#     G-mean: 0.8478
#     MCC: 0.6985
#     F1-score: 0.7122
#     mAP: 0.8259
#   [MGVAE - RandomForest]
#     AUROC: 0.9904
#     G-mean: 0.8524
#     MCC: 0.7983
#     F1-score: 0.7999
#     mAP: 0.9328
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.9945
#     G-mean: 0.8877
#     MCC: 0.8494
#     F1-score: 0.8506
#     mAP: 0.9478
#   [GAMO - DecisionTree]
#     AUROC: 0.6908
#     G-mean: 0.5999
#     MCC: 0.3649
#     F1-score: 0.4049
#     mAP: 0.2700
#   [GAMO - kNN]
#     AUROC: 0.9318
#     G-mean: 0.7986
#     MCC: 0.7768
#     F1-score: 0.7629
#     mAP: 0.8484
#   [GAMO - MLP]
#     AUROC: 0.9298
#     G-mean: 0.7544
#     MCC: 0.6220
#     F1-score: 0.6353
#     mAP: 0.7673
#   [GAMO - RandomForest]
#     AUROC: 0.9826
#     G-mean: 0.8853
#     MCC: 0.7974
#     F1-score: 0.8044
#     mAP: 0.8991
#   [MGVAE - SVM]
#     AUROC: 0.9887
#     G-mean: 0.9000
#     MCC: 0.8244
#     F1-score: 0.8293
#     mAP: 0.9326
#   [MGVAE - DecisionTree]
#     AUROC: 0.8428
#     G-mean: 0.8156
#     MCC: 0.6870
#     F1-score: 0.7011
#     mAP: 0.5706
#   [MGVAE - kNN]
#     AUROC: 0.9480
#     G-mean: 0.8599
#     MCC: 0.7968
#     F1-score: 0.7956
#     mAP: 0.8498
#   [MGVAE - MLP]
#     AUROC: 0.9369
#     G-mean: 0.8477
#     MCC: 0.6975
#     F1-score: 0.7114
#     mAP: 0.8261
#   [MGVAE - RandomForest]
#     AUROC: 0.9906
#     G-mean: 0.8502
#     MCC: 0.7956
#     F1-score: 0.7965
#     mAP: 0.9340
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/spectrometer_results_GAMO_MGVAE_beta_0.001.csv

# %%
# thyroid_sick
data_name = 'thyroid_sick'
maj_target_name = -1

n_epochs = 1000
hidden_dims = [32, 64, 128, 256]
latent_dim = 512
lr = 0.005
beta = 0.001

final_res = run_exp(
    data=data, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    kernel_type=kernel_type,
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    maj_target_name=maj_target_name,
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded: thyroid_sick
# X shape : (3772, 52)
# target : Counter({0: 3541, 1: 231})
# IR: 15.33
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.9220
#     G-mean: 0.1038
#     MCC: 0.0360
#     F1-score: 0.0374
#     mAP: 0.4072
#   [GAMO - DecisionTree]
#     AUROC: 0.9794
#     G-mean: 0.9142
#     MCC: 0.7947
#     F1-score: 0.8038
#     mAP: 0.7638
#   [GAMO - kNN]
#     AUROC: 0.8624
#     G-mean: 0.6058
#     MCC: 0.5273
#     F1-score: 0.5038
#     mAP: 0.5472
#   [GAMO - MLP]
#     AUROC: 0.9637
#     G-mean: 0.7537
#     MCC: 0.6499
#     F1-score: 0.6556
#     mAP: 0.6953
#   [GAMO - RandomForest]
#     AUROC: 0.9974
#     G-mean: 0.8955
#     MCC: 0.8579
#     F1-score: 0.8618
#     mAP: 0.9679
#   [MGVAE - SVM]
#     AUROC: 0.9415
#     G-mean: 0.4898
#     MCC: 0.4153
#     F1-score: 0.3706
#     mAP: 0.6776
#   [MGVAE - DecisionTree]
#     AUROC: 0.9703
#     G-mean: 0.9138
#     MCC: 0.8576
#     F1-score: 0.8633
#     mAP: 0.8479
#   [MGVAE - kNN]
#     AUROC: 0.8624
#     G-mean: 0.6058
#     MCC: 0.5273
#     F1-score: 0.5038
#     mAP: 0.5472
#   [MGVAE - MLP]
#     AUROC: 0.9437
#     G-mean: 0.6895
#     MCC: 0.5834
#     F1-score: 0.5848
#     mAP: 0.6549
#   [MGVAE - RandomForest]
#     AUROC: 0.9971
#     G-mean: 0.8743
#     MCC: 0.8374
#     F1-score: 0.8403
#     mAP: 0.9644
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.9230
#     G-mean: 0.1318
#     MCC: 0.0522
#     F1-score: 0.0505
#     mAP: 0.4122
#   [GAMO - DecisionTree]
#     AUROC: 0.9783
#     G-mean: 0.9103
#     MCC: 0.7936
#     F1-score: 0.8041
#     mAP: 0.7638
#   [GAMO - kNN]
#     AUROC: 0.8585
#     G-mean: 0.6080
#     MCC: 0.5253
#     F1-score: 0.5049
#     mAP: 0.5453
#   [GAMO - MLP]
#     AUROC: 0.9663
#     G-mean: 0.7569
#     MCC: 0.6534
#     F1-score: 0.6603
#     mAP: 0.7137
#   [GAMO - RandomForest]
#     AUROC: 0.9971
#     G-mean: 0.8953
#     MCC: 0.8600
#     F1-score: 0.8640
#     mAP: 0.9654
#   [MGVAE - SVM]
#     AUROC: 0.9410
#     G-mean: 0.4934
#     MCC: 0.4218
#     F1-score: 0.3750
#     mAP: 0.6846
#   [MGVAE - DecisionTree]
#     AUROC: 0.9718
#     G-mean: 0.9189
#     MCC: 0.8595
#     F1-score: 0.8659
#     mAP: 0.8525
#   [MGVAE - kNN]
#     AUROC: 0.8585
#     G-mean: 0.6080
#     MCC: 0.5253
#     F1-score: 0.5049
#     mAP: 0.5453
#   [MGVAE - MLP]
#     AUROC: 0.9464
#     G-mean: 0.6855
#     MCC: 0.5833
#     F1-score: 0.5837
#     mAP: 0.6553
#   [MGVAE - RandomForest]
#     AUROC: 0.9970
#     G-mean: 0.8836
#     MCC: 0.8486
#     F1-score: 0.8520
#     mAP: 0.9628
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.9231
#     G-mean: 0.1353
#     MCC: 0.0578
#     F1-score: 0.0568
#     mAP: 0.4142
#   [GAMO - DecisionTree]
#     AUROC: 0.9773
#     G-mean: 0.9102
#     MCC: 0.7958
#     F1-score: 0.8058
#     mAP: 0.7649
#   [GAMO - kNN]
#     AUROC: 0.8565
#     G-mean: 0.6173
#     MCC: 0.5345
#     F1-score: 0.5165
#     mAP: 0.5461
#   [GAMO - MLP]
#     AUROC: 0.9657
#     G-mean: 0.7525
#     MCC: 0.6502
#     F1-score: 0.6567
#     mAP: 0.7119
#   [GAMO - RandomForest]
#     AUROC: 0.9969
#     G-mean: 0.8950
#     MCC: 0.8592
#     F1-score: 0.8633
#     mAP: 0.9641
#   [MGVAE - SVM]
#     AUROC: 0.9408
#     G-mean: 0.4978
#     MCC: 0.4284
#     F1-score: 0.3809
#     mAP: 0.6853
#   [MGVAE - DecisionTree]
#     AUROC: 0.9714
#     G-mean: 0.9183
#     MCC: 0.8587
#     F1-score: 0.8655
#     mAP: 0.8498
#   [MGVAE - kNN]
#     AUROC: 0.8565
#     G-mean: 0.6173
#     MCC: 0.5345
#     F1-score: 0.5165
#     mAP: 0.5461
#   [MGVAE - MLP]
#     AUROC: 0.9471
#     G-mean: 0.6937
#     MCC: 0.5921
#     F1-score: 0.5934
#     mAP: 0.6621
#   [MGVAE - RandomForest]
#     AUROC: 0.9968
#     G-mean: 0.8830
#     MCC: 0.8456
#     F1-score: 0.8494
#     mAP: 0.9620
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.9197
#     G-mean: 0.1338
#     MCC: 0.0570
#     F1-score: 0.0581
#     mAP: 0.4024
#   [GAMO - DecisionTree]
#     AUROC: 0.9781
#     G-mean: 0.9099
#     MCC: 0.7991
#     F1-score: 0.8091
#     mAP: 0.7754
#   [GAMO - kNN]
#     AUROC: 0.8548
#     G-mean: 0.6135
#     MCC: 0.5298
#     F1-score: 0.5123
#     mAP: 0.5438
#   [GAMO - MLP]
#     AUROC: 0.9656
#     G-mean: 0.7407
#     MCC: 0.6404
#     F1-score: 0.6454
#     mAP: 0.7131
#   [GAMO - RandomForest]
#     AUROC: 0.9967
#     G-mean: 0.8954
#     MCC: 0.8609
#     F1-score: 0.8649
#     mAP: 0.9627
#   [MGVAE - SVM]
#     AUROC: 0.9410
#     G-mean: 0.5031
#     MCC: 0.4336
#     F1-score: 0.3870
#     mAP: 0.6858
#   [MGVAE - DecisionTree]
#     AUROC: 0.9713
#     G-mean: 0.9159
#     MCC: 0.8594
#     F1-score: 0.8661
#     mAP: 0.8538
#   [MGVAE - kNN]
#     AUROC: 0.8548
#     G-mean: 0.6135
#     MCC: 0.5298
#     F1-score: 0.5123
#     mAP: 0.5438
#   [MGVAE - MLP]
#     AUROC: 0.9463
#     G-mean: 0.6927
#     MCC: 0.5869
#     F1-score: 0.5885
#     mAP: 0.6553
#   [MGVAE - RandomForest]
#     AUROC: 0.9965
#     G-mean: 0.8843
#     MCC: 0.8463
#     F1-score: 0.8503
#     mAP: 0.9601
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.9205
#     G-mean: 0.1371
#     MCC: 0.0591
#     F1-score: 0.0595
#     mAP: 0.4058
#   [GAMO - DecisionTree]
#     AUROC: 0.9787
#     G-mean: 0.9131
#     MCC: 0.8012
#     F1-score: 0.8108
#     mAP: 0.7796
#   [GAMO - kNN]
#     AUROC: 0.8550
#     G-mean: 0.6117
#     MCC: 0.5296
#     F1-score: 0.5107
#     mAP: 0.5421
#   [GAMO - MLP]
#     AUROC: 0.9659
#     G-mean: 0.7404
#     MCC: 0.6410
#     F1-score: 0.6456
#     mAP: 0.7132
#   [GAMO - RandomForest]
#     AUROC: 0.9968
#     G-mean: 0.8957
#     MCC: 0.8615
#     F1-score: 0.8654
#     mAP: 0.9639
#   [MGVAE - SVM]
#     AUROC: 0.9407
#     G-mean: 0.4994
#     MCC: 0.4317
#     F1-score: 0.3825
#     mAP: 0.6854
#   [MGVAE - DecisionTree]
#     AUROC: 0.9708
#     G-mean: 0.9154
#     MCC: 0.8591
#     F1-score: 0.8657
#     mAP: 0.8524
#   [MGVAE - kNN]
#     AUROC: 0.8550
#     G-mean: 0.6117
#     MCC: 0.5296
#     F1-score: 0.5107
#     mAP: 0.5421
#   [MGVAE - MLP]
#     AUROC: 0.9456
#     G-mean: 0.6854
#     MCC: 0.5791
#     F1-score: 0.5797
#     mAP: 0.6495
#   [MGVAE - RandomForest]
#     AUROC: 0.9966
#     G-mean: 0.8855
#     MCC: 0.8474
#     F1-score: 0.8516
#     mAP: 0.9611
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.9213
#     G-mean: 0.1393
#     MCC: 0.0610
#     F1-score: 0.0602
#     mAP: 0.4071
#   [GAMO - DecisionTree]
#     AUROC: 0.9776
#     G-mean: 0.9121
#     MCC: 0.7972
#     F1-score: 0.8070
#     mAP: 0.7727
#   [GAMO - kNN]
#     AUROC: 0.8548
#     G-mean: 0.6117
#     MCC: 0.5304
#     F1-score: 0.5109
#     mAP: 0.5427
#   [GAMO - MLP]
#     AUROC: 0.9657
#     G-mean: 0.7465
#     MCC: 0.6462
#     F1-score: 0.6518
#     mAP: 0.7148
#   [GAMO - RandomForest]
#     AUROC: 0.9967
#     G-mean: 0.8955
#     MCC: 0.8616
#     F1-score: 0.8654
#     mAP: 0.9633
#   [MGVAE - SVM]
#     AUROC: 0.9404
#     G-mean: 0.5003
#     MCC: 0.4324
#     F1-score: 0.3832
#     mAP: 0.6848
#   [MGVAE - DecisionTree]
#     AUROC: 0.9710
#     G-mean: 0.9141
#     MCC: 0.8564
#     F1-score: 0.8632
#     mAP: 0.8486
#   [MGVAE - kNN]
#     AUROC: 0.8548
#     G-mean: 0.6117
#     MCC: 0.5304
#     F1-score: 0.5109
#     mAP: 0.5427
#   [MGVAE - MLP]
#     AUROC: 0.9448
#     G-mean: 0.6819
#     MCC: 0.5769
#     F1-score: 0.5766
#     mAP: 0.6476
#   [MGVAE - RandomForest]
#     AUROC: 0.9964
#     G-mean: 0.8854
#     MCC: 0.8470
#     F1-score: 0.8512
#     mAP: 0.9604
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.9223
#     G-mean: 0.1359
#     MCC: 0.0596
#     F1-score: 0.0596
#     mAP: 0.4143
#   [GAMO - DecisionTree]
#     AUROC: 0.9777
#     G-mean: 0.9124
#     MCC: 0.7966
#     F1-score: 0.8063
#     mAP: 0.7726
#   [GAMO - kNN]
#     AUROC: 0.8560
#     G-mean: 0.6155
#     MCC: 0.5353
#     F1-score: 0.5158
#     mAP: 0.5449
#   [GAMO - MLP]
#     AUROC: 0.9658
#     G-mean: 0.7513
#     MCC: 0.6525
#     F1-score: 0.6581
#     mAP: 0.7195
#   [GAMO - RandomForest]
#     AUROC: 0.9968
#     G-mean: 0.8963
#     MCC: 0.8627
#     F1-score: 0.8662
#     mAP: 0.9641
#   [MGVAE - SVM]
#     AUROC: 0.9404
#     G-mean: 0.5013
#     MCC: 0.4344
#     F1-score: 0.3846
#     mAP: 0.6859
#   [MGVAE - DecisionTree]
#     AUROC: 0.9719
#     G-mean: 0.9162
#     MCC: 0.8591
#     F1-score: 0.8658
#     mAP: 0.8518
#   [MGVAE - kNN]
#     AUROC: 0.8560
#     G-mean: 0.6155
#     MCC: 0.5353
#     F1-score: 0.5158
#     mAP: 0.5449
#   [MGVAE - MLP]
#     AUROC: 0.9445
#     G-mean: 0.6824
#     MCC: 0.5781
#     F1-score: 0.5776
#     mAP: 0.6494
#   [MGVAE - RandomForest]
#     AUROC: 0.9965
#     G-mean: 0.8857
#     MCC: 0.8483
#     F1-score: 0.8521
#     mAP: 0.9614
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.9218
#     G-mean: 0.1349
#     MCC: 0.0600
#     F1-score: 0.0594
#     mAP: 0.4127
#   [GAMO - DecisionTree]
#     AUROC: 0.9775
#     G-mean: 0.9120
#     MCC: 0.7967
#     F1-score: 0.8063
#     mAP: 0.7741
#   [GAMO - kNN]
#     AUROC: 0.8552
#     G-mean: 0.6164
#     MCC: 0.5367
#     F1-score: 0.5173
#     mAP: 0.5446
#   [GAMO - MLP]
#     AUROC: 0.9661
#     G-mean: 0.7510
#     MCC: 0.6536
#     F1-score: 0.6590
#     mAP: 0.7220
#   [GAMO - RandomForest]
#     AUROC: 0.9968
#     G-mean: 0.8971
#     MCC: 0.8634
#     F1-score: 0.8670
#     mAP: 0.9639
#   [MGVAE - SVM]
#     AUROC: 0.9400
#     G-mean: 0.5002
#     MCC: 0.4331
#     F1-score: 0.3834
#     mAP: 0.6852
#   [MGVAE - DecisionTree]
#     AUROC: 0.9720
#     G-mean: 0.9166
#     MCC: 0.8587
#     F1-score: 0.8656
#     mAP: 0.8530
#   [MGVAE - kNN]
#     AUROC: 0.8552
#     G-mean: 0.6164
#     MCC: 0.5367
#     F1-score: 0.5173
#     mAP: 0.5446
#   [MGVAE - MLP]
#     AUROC: 0.9433
#     G-mean: 0.6830
#     MCC: 0.5762
#     F1-score: 0.5768
#     mAP: 0.6456
#   [MGVAE - RandomForest]
#     AUROC: 0.9965
#     G-mean: 0.8862
#     MCC: 0.8486
#     F1-score: 0.8525
#     mAP: 0.9611
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.9225
#     G-mean: 0.1375
#     MCC: 0.0616
#     F1-score: 0.0606
#     mAP: 0.4174
#   [GAMO - DecisionTree]
#     AUROC: 0.9773
#     G-mean: 0.9140
#     MCC: 0.7967
#     F1-score: 0.8063
#     mAP: 0.7737
#   [GAMO - kNN]
#     AUROC: 0.8565
#     G-mean: 0.6169
#     MCC: 0.5372
#     F1-score: 0.5175
#     mAP: 0.5457
#   [GAMO - MLP]
#     AUROC: 0.9663
#     G-mean: 0.7507
#     MCC: 0.6542
#     F1-score: 0.6593
#     mAP: 0.7228
#   [GAMO - RandomForest]
#     AUROC: 0.9968
#     G-mean: 0.8973
#     MCC: 0.8630
#     F1-score: 0.8667
#     mAP: 0.9638
#   [MGVAE - SVM]
#     AUROC: 0.9402
#     G-mean: 0.4993
#     MCC: 0.4313
#     F1-score: 0.3819
#     mAP: 0.6845
#   [MGVAE - DecisionTree]
#     AUROC: 0.9723
#     G-mean: 0.9169
#     MCC: 0.8590
#     F1-score: 0.8659
#     mAP: 0.8528
#   [MGVAE - kNN]
#     AUROC: 0.8565
#     G-mean: 0.6169
#     MCC: 0.5372
#     F1-score: 0.5175
#     mAP: 0.5457
#   [MGVAE - MLP]
#     AUROC: 0.9437
#     G-mean: 0.6841
#     MCC: 0.5796
#     F1-score: 0.5798
#     mAP: 0.6474
#   [MGVAE - RandomForest]
#     AUROC: 0.9965
#     G-mean: 0.8863
#     MCC: 0.8484
#     F1-score: 0.8524
#     mAP: 0.9611
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.9222
#     G-mean: 0.1338
#     MCC: 0.0602
#     F1-score: 0.0590
#     mAP: 0.4165
#   [GAMO - DecisionTree]
#     AUROC: 0.9771
#     G-mean: 0.9140
#     MCC: 0.7975
#     F1-score: 0.8068
#     mAP: 0.7756
#   [GAMO - kNN]
#     AUROC: 0.8570
#     G-mean: 0.6169
#     MCC: 0.5372
#     F1-score: 0.5175
#     mAP: 0.5472
#   [GAMO - MLP]
#     AUROC: 0.9664
#     G-mean: 0.7497
#     MCC: 0.6529
#     F1-score: 0.6581
#     mAP: 0.7207
#   [GAMO - RandomForest]
#     AUROC: 0.9968
#     G-mean: 0.8962
#     MCC: 0.8619
#     F1-score: 0.8654
#     mAP: 0.9636
#   [MGVAE - SVM]
#     AUROC: 0.9399
#     G-mean: 0.5007
#     MCC: 0.4333
#     F1-score: 0.3838
#     mAP: 0.6840
#   [MGVAE - DecisionTree]
#     AUROC: 0.9718
#     G-mean: 0.9172
#     MCC: 0.8585
#     F1-score: 0.8655
#     mAP: 0.8519
#   [MGVAE - kNN]
#     AUROC: 0.8570
#     G-mean: 0.6169
#     MCC: 0.5372
#     F1-score: 0.5175
#     mAP: 0.5472
#   [MGVAE - MLP]
#     AUROC: 0.9431
#     G-mean: 0.6832
#     MCC: 0.5764
#     F1-score: 0.5776
#     mAP: 0.6430
#   [MGVAE - RandomForest]
#     AUROC: 0.9965
#     G-mean: 0.8858
#     MCC: 0.8480
#     F1-score: 0.8517
#     mAP: 0.9611
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/thyroid_sick_results_GAMO_MGVAE_beta_0.001.csv

# %%
# wine_quality
data_name = 'wine_quality'
maj_target_name = -1

n_epochs = 1000
hidden_dims = [32, 64, 128, 256]
latent_dim = 512
lr = 0.005
beta = 0.001

final_res = run_exp(
    data=data, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    kernel_type=kernel_type,
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    maj_target_name=maj_target_name,
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded: wine_quality
# X shape : (4898, 11)
# target : Counter({0: 4715, 1: 183})
# IR: 25.77
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.6940
#     G-mean: 0.4871
#     MCC: 0.1286
#     F1-score: 0.1616
#     mAP: 0.1029
#   [GAMO - DecisionTree]
#     AUROC: 0.5605
#     G-mean: 0.4806
#     MCC: 0.0109
#     F1-score: 0.0742
#     mAP: 0.0612
#   [GAMO - kNN]
#     AUROC: 0.7321
#     G-mean: 0.4340
#     MCC: 0.1419
#     F1-score: 0.1753
#     mAP: 0.0985
#   [GAMO - MLP]
#     AUROC: 0.6822
#     G-mean: 0.4693
#     MCC: 0.1367
#     F1-score: 0.1712
#     mAP: 0.1094
#   [GAMO - RandomForest]
#     AUROC: 0.8377
#     G-mean: 0.6263
#     MCC: 0.2510
#     F1-score: 0.2708
#     mAP: 0.2091
#   [MGVAE - SVM]
#     AUROC: 0.7491
#     G-mean: 0.1498
#     MCC: 0.1182
#     F1-score: 0.0688
#     mAP: 0.2127
#   [MGVAE - DecisionTree]
#     AUROC: 0.7323
#     G-mean: 0.3824
#     MCC: 0.2410
#     F1-score: 0.2233
#     mAP: 0.2212
#   [MGVAE - kNN]
#     AUROC: 0.7357
#     G-mean: 0.2360
#     MCC: 0.1710
#     F1-score: 0.1317
#     mAP: 0.1698
#   [MGVAE - MLP]
#     AUROC: 0.6968
#     G-mean: 0.4139
#     MCC: 0.1912
#     F1-score: 0.2103
#     mAP: 0.1832
#   [MGVAE - RandomForest]
#     AUROC: 0.9069
#     G-mean: 0.4558
#     MCC: 0.4113
#     F1-score: 0.3379
#     mAP: 0.4989
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.6918
#     G-mean: 0.4834
#     MCC: 0.1284
#     F1-score: 0.1622
#     mAP: 0.1052
#   [GAMO - DecisionTree]
#     AUROC: 0.5551
#     G-mean: 0.4782
#     MCC: 0.0109
#     F1-score: 0.0733
#     mAP: 0.0565
#   [GAMO - kNN]
#     AUROC: 0.7347
#     G-mean: 0.4002
#     MCC: 0.1201
#     F1-score: 0.1543
#     mAP: 0.0980
#   [GAMO - MLP]
#     AUROC: 0.6859
#     G-mean: 0.4538
#     MCC: 0.1285
#     F1-score: 0.1638
#     mAP: 0.1167
#   [GAMO - RandomForest]
#     AUROC: 0.8353
#     G-mean: 0.6306
#     MCC: 0.2529
#     F1-score: 0.2717
#     mAP: 0.2041
#   [MGVAE - SVM]
#     AUROC: 0.7516
#     G-mean: 0.1432
#     MCC: 0.1159
#     F1-score: 0.0692
#     mAP: 0.2142
#   [MGVAE - DecisionTree]
#     AUROC: 0.7249
#     G-mean: 0.3589
#     MCC: 0.2213
#     F1-score: 0.2056
#     mAP: 0.2119
#   [MGVAE - kNN]
#     AUROC: 0.7391
#     G-mean: 0.2238
#     MCC: 0.1596
#     F1-score: 0.1211
#     mAP: 0.1692
#   [MGVAE - MLP]
#     AUROC: 0.6980
#     G-mean: 0.3982
#     MCC: 0.1880
#     F1-score: 0.2076
#     mAP: 0.1835
#   [MGVAE - RandomForest]
#     AUROC: 0.9047
#     G-mean: 0.4407
#     MCC: 0.3999
#     F1-score: 0.3195
#     mAP: 0.5075
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.6923
#     G-mean: 0.4863
#     MCC: 0.1304
#     F1-score: 0.1644
#     mAP: 0.1076
#   [GAMO - DecisionTree]
#     AUROC: 0.5588
#     G-mean: 0.4841
#     MCC: 0.0145
#     F1-score: 0.0757
#     mAP: 0.0611
#   [GAMO - kNN]
#     AUROC: 0.7344
#     G-mean: 0.3981
#     MCC: 0.1259
#     F1-score: 0.1596
#     mAP: 0.1000
#   [GAMO - MLP]
#     AUROC: 0.6837
#     G-mean: 0.4427
#     MCC: 0.1238
#     F1-score: 0.1595
#     mAP: 0.1162
#   [GAMO - RandomForest]
#     AUROC: 0.8369
#     G-mean: 0.6265
#     MCC: 0.2493
#     F1-score: 0.2683
#     mAP: 0.2066
#   [MGVAE - SVM]
#     AUROC: 0.7529
#     G-mean: 0.1453
#     MCC: 0.1130
#     F1-score: 0.0689
#     mAP: 0.2181
#   [MGVAE - DecisionTree]
#     AUROC: 0.7221
#     G-mean: 0.3566
#     MCC: 0.2214
#     F1-score: 0.2068
#     mAP: 0.2099
#   [MGVAE - kNN]
#     AUROC: 0.7404
#     G-mean: 0.2427
#     MCC: 0.1836
#     F1-score: 0.1376
#     mAP: 0.1793
#   [MGVAE - MLP]
#     AUROC: 0.6980
#     G-mean: 0.4020
#     MCC: 0.1915
#     F1-score: 0.2089
#     mAP: 0.1801
#   [MGVAE - RandomForest]
#     AUROC: 0.9043
#     G-mean: 0.4455
#     MCC: 0.4008
#     F1-score: 0.3242
#     mAP: 0.5002
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.6915
#     G-mean: 0.4845
#     MCC: 0.1285
#     F1-score: 0.1627
#     mAP: 0.1079
#   [GAMO - DecisionTree]
#     AUROC: 0.5579
#     G-mean: 0.4799
#     MCC: 0.0130
#     F1-score: 0.0741
#     mAP: 0.0605
#   [GAMO - kNN]
#     AUROC: 0.7347
#     G-mean: 0.4087
#     MCC: 0.1326
#     F1-score: 0.1663
#     mAP: 0.1017
#   [GAMO - MLP]
#     AUROC: 0.6835
#     G-mean: 0.4490
#     MCC: 0.1251
#     F1-score: 0.1602
#     mAP: 0.1196
#   [GAMO - RandomForest]
#     AUROC: 0.8364
#     G-mean: 0.6231
#     MCC: 0.2477
#     F1-score: 0.2668
#     mAP: 0.2083
#   [MGVAE - SVM]
#     AUROC: 0.7530
#     G-mean: 0.1405
#     MCC: 0.1050
#     F1-score: 0.0659
#     mAP: 0.2189
#   [MGVAE - DecisionTree]
#     AUROC: 0.7237
#     G-mean: 0.3485
#     MCC: 0.2159
#     F1-score: 0.1985
#     mAP: 0.2091
#   [MGVAE - kNN]
#     AUROC: 0.7387
#     G-mean: 0.2394
#     MCC: 0.1762
#     F1-score: 0.1353
#     mAP: 0.1754
#   [MGVAE - MLP]
#     AUROC: 0.6956
#     G-mean: 0.3915
#     MCC: 0.1855
#     F1-score: 0.2039
#     mAP: 0.1824
#   [MGVAE - RandomForest]
#     AUROC: 0.9056
#     G-mean: 0.4415
#     MCC: 0.3950
#     F1-score: 0.3186
#     mAP: 0.5018
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.6914
#     G-mean: 0.4826
#     MCC: 0.1270
#     F1-score: 0.1614
#     mAP: 0.1074
#   [GAMO - DecisionTree]
#     AUROC: 0.5575
#     G-mean: 0.4807
#     MCC: 0.0120
#     F1-score: 0.0733
#     mAP: 0.0596
#   [GAMO - kNN]
#     AUROC: 0.7327
#     G-mean: 0.4062
#     MCC: 0.1285
#     F1-score: 0.1627
#     mAP: 0.1010
#   [GAMO - MLP]
#     AUROC: 0.6820
#     G-mean: 0.4447
#     MCC: 0.1219
#     F1-score: 0.1574
#     mAP: 0.1213
#   [GAMO - RandomForest]
#     AUROC: 0.8372
#     G-mean: 0.6237
#     MCC: 0.2471
#     F1-score: 0.2660
#     mAP: 0.2087
#   [MGVAE - SVM]
#     AUROC: 0.7495
#     G-mean: 0.1412
#     MCC: 0.1047
#     F1-score: 0.0678
#     mAP: 0.2157
#   [MGVAE - DecisionTree]
#     AUROC: 0.7334
#     G-mean: 0.3557
#     MCC: 0.2236
#     F1-score: 0.2063
#     mAP: 0.2189
#   [MGVAE - kNN]
#     AUROC: 0.7363
#     G-mean: 0.2381
#     MCC: 0.1722
#     F1-score: 0.1316
#     mAP: 0.1729
#   [MGVAE - MLP]
#     AUROC: 0.6975
#     G-mean: 0.3982
#     MCC: 0.1910
#     F1-score: 0.2080
#     mAP: 0.1826
#   [MGVAE - RandomForest]
#     AUROC: 0.9061
#     G-mean: 0.4414
#     MCC: 0.3922
#     F1-score: 0.3180
#     mAP: 0.4993
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.6921
#     G-mean: 0.4812
#     MCC: 0.1260
#     F1-score: 0.1606
#     mAP: 0.1069
#   [GAMO - DecisionTree]
#     AUROC: 0.5575
#     G-mean: 0.4856
#     MCC: 0.0126
#     F1-score: 0.0735
#     mAP: 0.0591
#   [GAMO - kNN]
#     AUROC: 0.7308
#     G-mean: 0.4018
#     MCC: 0.1281
#     F1-score: 0.1621
#     mAP: 0.1007
#   [GAMO - MLP]
#     AUROC: 0.6824
#     G-mean: 0.4413
#     MCC: 0.1186
#     F1-score: 0.1545
#     mAP: 0.1213
#   [GAMO - RandomForest]
#     AUROC: 0.8374
#     G-mean: 0.6201
#     MCC: 0.2441
#     F1-score: 0.2634
#     mAP: 0.2097
#   [MGVAE - SVM]
#     AUROC: 0.7497
#     G-mean: 0.1426
#     MCC: 0.1052
#     F1-score: 0.0677
#     mAP: 0.2154
#   [MGVAE - DecisionTree]
#     AUROC: 0.7259
#     G-mean: 0.3489
#     MCC: 0.2178
#     F1-score: 0.2013
#     mAP: 0.2123
#   [MGVAE - kNN]
#     AUROC: 0.7349
#     G-mean: 0.2387
#     MCC: 0.1731
#     F1-score: 0.1311
#     mAP: 0.1721
#   [MGVAE - MLP]
#     AUROC: 0.6952
#     G-mean: 0.3989
#     MCC: 0.1899
#     F1-score: 0.2074
#     mAP: 0.1835
#   [MGVAE - RandomForest]
#     AUROC: 0.9066
#     G-mean: 0.4389
#     MCC: 0.3888
#     F1-score: 0.3153
#     mAP: 0.5021
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.6917
#     G-mean: 0.4769
#     MCC: 0.1250
#     F1-score: 0.1596
#     mAP: 0.1067
#   [GAMO - DecisionTree]
#     AUROC: 0.5632
#     G-mean: 0.4907
#     MCC: 0.0155
#     F1-score: 0.0746
#     mAP: 0.0606
#   [GAMO - kNN]
#     AUROC: 0.7300
#     G-mean: 0.3974
#     MCC: 0.1257
#     F1-score: 0.1597
#     mAP: 0.0998
#   [GAMO - MLP]
#     AUROC: 0.6819
#     G-mean: 0.4414
#     MCC: 0.1184
#     F1-score: 0.1544
#     mAP: 0.1202
#   [GAMO - RandomForest]
#     AUROC: 0.8367
#     G-mean: 0.6149
#     MCC: 0.2394
#     F1-score: 0.2593
#     mAP: 0.2092
#   [MGVAE - SVM]
#     AUROC: 0.7509
#     G-mean: 0.1483
#     MCC: 0.1118
#     F1-score: 0.0707
#     mAP: 0.2167
#   [MGVAE - DecisionTree]
#     AUROC: 0.7269
#     G-mean: 0.3474
#     MCC: 0.2206
#     F1-score: 0.2034
#     mAP: 0.2143
#   [MGVAE - kNN]
#     AUROC: 0.7337
#     G-mean: 0.2359
#     MCC: 0.1694
#     F1-score: 0.1290
#     mAP: 0.1707
#   [MGVAE - MLP]
#     AUROC: 0.6953
#     G-mean: 0.4016
#     MCC: 0.1897
#     F1-score: 0.2079
#     mAP: 0.1808
#   [MGVAE - RandomForest]
#     AUROC: 0.9064
#     G-mean: 0.4344
#     MCC: 0.3839
#     F1-score: 0.3132
#     mAP: 0.4999
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.6926
#     G-mean: 0.4793
#     MCC: 0.1261
#     F1-score: 0.1607
#     mAP: 0.1083
#   [GAMO - DecisionTree]
#     AUROC: 0.5647
#     G-mean: 0.4936
#     MCC: 0.0162
#     F1-score: 0.0750
#     mAP: 0.0613
#   [GAMO - kNN]
#     AUROC: 0.7297
#     G-mean: 0.3973
#     MCC: 0.1257
#     F1-score: 0.1597
#     mAP: 0.0999
#   [GAMO - MLP]
#     AUROC: 0.6825
#     G-mean: 0.4449
#     MCC: 0.1202
#     F1-score: 0.1562
#     mAP: 0.1221
#   [GAMO - RandomForest]
#     AUROC: 0.8363
#     G-mean: 0.6130
#     MCC: 0.2388
#     F1-score: 0.2590
#     mAP: 0.2097
#   [MGVAE - SVM]
#     AUROC: 0.7514
#     G-mean: 0.1494
#     MCC: 0.1134
#     F1-score: 0.0713
#     mAP: 0.2172
#   [MGVAE - DecisionTree]
#     AUROC: 0.7242
#     G-mean: 0.3523
#     MCC: 0.2248
#     F1-score: 0.2067
#     mAP: 0.2131
#   [MGVAE - kNN]
#     AUROC: 0.7327
#     G-mean: 0.2395
#     MCC: 0.1718
#     F1-score: 0.1301
#     mAP: 0.1699
#   [MGVAE - MLP]
#     AUROC: 0.6963
#     G-mean: 0.4009
#     MCC: 0.1898
#     F1-score: 0.2078
#     mAP: 0.1810
#   [MGVAE - RandomForest]
#     AUROC: 0.9056
#     G-mean: 0.4322
#     MCC: 0.3832
#     F1-score: 0.3101
#     mAP: 0.4975
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.6926
#     G-mean: 0.4780
#     MCC: 0.1252
#     F1-score: 0.1599
#     mAP: 0.1085
#   [GAMO - DecisionTree]
#     AUROC: 0.5675
#     G-mean: 0.4977
#     MCC: 0.0175
#     F1-score: 0.0756
#     mAP: 0.0629
#   [GAMO - kNN]
#     AUROC: 0.7279
#     G-mean: 0.3977
#     MCC: 0.1261
#     F1-score: 0.1600
#     mAP: 0.1000
#   [GAMO - MLP]
#     AUROC: 0.6821
#     G-mean: 0.4435
#     MCC: 0.1192
#     F1-score: 0.1553
#     mAP: 0.1224
#   [GAMO - RandomForest]
#     AUROC: 0.8358
#     G-mean: 0.6155
#     MCC: 0.2413
#     F1-score: 0.2612
#     mAP: 0.2121
#   [MGVAE - SVM]
#     AUROC: 0.7511
#     G-mean: 0.1496
#     MCC: 0.1144
#     F1-score: 0.0712
#     mAP: 0.2160
#   [MGVAE - DecisionTree]
#     AUROC: 0.7207
#     G-mean: 0.3554
#     MCC: 0.2301
#     F1-score: 0.2110
#     mAP: 0.2145
#   [MGVAE - kNN]
#     AUROC: 0.7321
#     G-mean: 0.2341
#     MCC: 0.1677
#     F1-score: 0.1259
#     mAP: 0.1688
#   [MGVAE - MLP]
#     AUROC: 0.6959
#     G-mean: 0.3986
#     MCC: 0.1893
#     F1-score: 0.2073
#     mAP: 0.1800
#   [MGVAE - RandomForest]
#     AUROC: 0.9054
#     G-mean: 0.4307
#     MCC: 0.3825
#     F1-score: 0.3086
#     mAP: 0.4991
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.6929
#     G-mean: 0.4780
#     MCC: 0.1251
#     F1-score: 0.1598
#     mAP: 0.1082
#   [GAMO - DecisionTree]
#     AUROC: 0.5660
#     G-mean: 0.4995
#     MCC: 0.0176
#     F1-score: 0.0756
#     mAP: 0.0622
#   [GAMO - kNN]
#     AUROC: 0.7261
#     G-mean: 0.3952
#     MCC: 0.1238
#     F1-score: 0.1579
#     mAP: 0.0989
#   [GAMO - MLP]
#     AUROC: 0.6832
#     G-mean: 0.4423
#     MCC: 0.1188
#     F1-score: 0.1550
#     mAP: 0.1244
#   [GAMO - RandomForest]
#     AUROC: 0.8363
#     G-mean: 0.6132
#     MCC: 0.2401
#     F1-score: 0.2604
#     mAP: 0.2130
#   [MGVAE - SVM]
#     AUROC: 0.7519
#     G-mean: 0.1482
#     MCC: 0.1131
#     F1-score: 0.0708
#     mAP: 0.2158
#   [MGVAE - DecisionTree]
#     AUROC: 0.7203
#     G-mean: 0.3499
#     MCC: 0.2258
#     F1-score: 0.2074
#     mAP: 0.2146
#   [MGVAE - kNN]
#     AUROC: 0.7311
#     G-mean: 0.2330
#     MCC: 0.1673
#     F1-score: 0.1244
#     mAP: 0.1687
#   [MGVAE - MLP]
#     AUROC: 0.6959
#     G-mean: 0.3949
#     MCC: 0.1870
#     F1-score: 0.2054
#     mAP: 0.1809
#   [MGVAE - RandomForest]
#     AUROC: 0.9045
#     G-mean: 0.4333
#     MCC: 0.3853
#     F1-score: 0.3115
#     mAP: 0.5009
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/wine_quality_results_GAMO_MGVAE_beta_0.001.csv
