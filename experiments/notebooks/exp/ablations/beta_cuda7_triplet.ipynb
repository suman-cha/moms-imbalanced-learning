# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

# Save path 
save_path = "/data4/oldrain123/oldrain123/results/ablation_results/beta8"
data_path = "/data4/oldrain123/oldrain123/dataset"

# %%
import os
import warnings
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from experiment import run_ablation
from imblearn.datasets import fetch_datasets

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "7"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
data = fetch_datasets()
methods = ["Ours"]
betas = [1e-1, 5e-2, 1e-2, 5e-3, 1e-3, 0.0]
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}

# %%
data_name = 'winequality-white-3_vs_7'

n_epochs = 2000
hidden_dims = [16, 32, 64, 128]
latent_dim = 256
lr = 0.002

for beta in betas:
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )
# Out:
# Dataset loaded from DataFrame
# X shape : (900, 11)
# target : Counter({0: 880, 1: 20})
# IR: 44.0
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.6716
#     G-mean: 0.2930
#     MCC: 0.0682
#     F1-score: 0.0751
#     mAP: 0.2494
#   [Ours - DecisionTree]
#     AUROC: 0.8386
#     G-mean: 0.5752
#     MCC: 0.3730
#     F1-score: 0.3622
#     mAP: 0.3551
#   [Ours - kNN]
#     AUROC: 0.6369
#     G-mean: 0.1707
#     MCC: 0.1664
#     F1-score: 0.1667
#     mAP: 0.2422
#   [Ours - MLP]
#     AUROC: 0.7744
#     G-mean: 0.3692
#     MCC: 0.1392
#     F1-score: 0.1417
#     mAP: 0.2536
#   [Ours - RandomForest]
#     AUROC: 0.8722
#     G-mean: 0.2414
#     MCC: 0.2406
#     F1-score: 0.2333
#     mAP: 0.6492
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.6977
#     G-mean: 0.3655
#     MCC: 0.1129
#     F1-score: 0.1106
#     mAP: 0.2946
#   [Ours - DecisionTree]
#     AUROC: 0.7903
#     G-mean: 0.5465
#     MCC: 0.3470
#     F1-score: 0.3419
#     mAP: 0.3423
#   [Ours - kNN]
#     AUROC: 0.6232
#     G-mean: 0.1207
#     MCC: 0.1159
#     F1-score: 0.1167
#     mAP: 0.2094
#   [Ours - MLP]
#     AUROC: 0.7830
#     G-mean: 0.4908
#     MCC: 0.2329
#     F1-score: 0.2340
#     mAP: 0.2836
#   [Ours - RandomForest]
#     AUROC: 0.8983
#     G-mean: 0.1207
#     MCC: 0.1195
#     F1-score: 0.1167
#     mAP: 0.6607
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.7008
#     G-mean: 0.3622
#     MCC: 0.1012
#     F1-score: 0.1024
#     mAP: 0.2801
#   [Ours - DecisionTree]
#     AUROC: 0.7995
#     G-mean: 0.5470
#     MCC: 0.3618
#     F1-score: 0.3554
#     mAP: 0.3535
#   [Ours - kNN]
#     AUROC: 0.6184
#     G-mean: 0.1039
#     MCC: 0.0908
#     F1-score: 0.0945
#     mAP: 0.1836
#   [Ours - MLP]
#     AUROC: 0.7731
#     G-mean: 0.4739
#     MCC: 0.2197
#     F1-score: 0.2209
#     mAP: 0.3152
#   [Ours - RandomForest]
#     AUROC: 0.9078
#     G-mean: 0.1040
#     MCC: 0.1031
#     F1-score: 0.1000
#     mAP: 0.6381
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.7095
#     G-mean: 0.3744
#     MCC: 0.1095
#     F1-score: 0.1057
#     mAP: 0.3199
#   [Ours - DecisionTree]
#     AUROC: 0.7809
#     G-mean: 0.5328
#     MCC: 0.3574
#     F1-score: 0.3525
#     mAP: 0.3445
#   [Ours - kNN]
#     AUROC: 0.6167
#     G-mean: 0.0956
#     MCC: 0.0835
#     F1-score: 0.0875
#     mAP: 0.1902
#   [Ours - MLP]
#     AUROC: 0.7709
#     G-mean: 0.4710
#     MCC: 0.2359
#     F1-score: 0.2357
#     mAP: 0.3418
#   [Ours - RandomForest]
#     AUROC: 0.9070
#     G-mean: 0.1310
#     MCC: 0.1297
#     F1-score: 0.1250
#     mAP: 0.6465
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.7192
#     G-mean: 0.4302
#     MCC: 0.1317
#     F1-score: 0.1238
#     mAP: 0.3357
#   [Ours - DecisionTree]
#     AUROC: 0.7710
#     G-mean: 0.5355
#     MCC: 0.3531
#     F1-score: 0.3496
#     mAP: 0.3306
#   [Ours - kNN]
#     AUROC: 0.6203
#     G-mean: 0.0906
#     MCC: 0.0793
#     F1-score: 0.0834
#     mAP: 0.1806
#   [Ours - MLP]
#     AUROC: 0.7684
#     G-mean: 0.4573
#     MCC: 0.2281
#     F1-score: 0.2280
#     mAP: 0.3348
#   [Ours - RandomForest]
#     AUROC: 0.9065
#     G-mean: 0.1331
#     MCC: 0.1312
#     F1-score: 0.1267
#     mAP: 0.6236
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.7240
#     G-mean: 0.4790
#     MCC: 0.1490
#     F1-score: 0.1372
#     mAP: 0.3368
#   [Ours - DecisionTree]
#     AUROC: 0.7395
#     G-mean: 0.4975
#     MCC: 0.3295
#     F1-score: 0.3270
#     mAP: 0.3058
#   [Ours - kNN]
#     AUROC: 0.6228
#     G-mean: 0.0990
#     MCC: 0.0844
#     F1-score: 0.0889
#     mAP: 0.1843
#   [Ours - MLP]
#     AUROC: 0.7636
#     G-mean: 0.4433
#     MCC: 0.2186
#     F1-score: 0.2190
#     mAP: 0.3228
#   [Ours - RandomForest]
#     AUROC: 0.9054
#     G-mean: 0.1463
#     MCC: 0.1445
#     F1-score: 0.1389
#     mAP: 0.6191
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.7276
#     G-mean: 0.4982
#     MCC: 0.1664
#     F1-score: 0.1531
#     mAP: 0.3475
#   [Ours - DecisionTree]
#     AUROC: 0.7384
#     G-mean: 0.4941
#     MCC: 0.3184
#     F1-score: 0.3156
#     mAP: 0.2995
#   [Ours - kNN]
#     AUROC: 0.6211
#     G-mean: 0.1051
#     MCC: 0.0920
#     F1-score: 0.0953
#     mAP: 0.1871
#   [Ours - MLP]
#     AUROC: 0.7653
#     G-mean: 0.4280
#     MCC: 0.2162
#     F1-score: 0.2176
#     mAP: 0.3300
#   [Ours - RandomForest]
#     AUROC: 0.9032
#     G-mean: 0.1355
#     MCC: 0.1334
#     F1-score: 0.1286
#     mAP: 0.6192
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.7299
#     G-mean: 0.4983
#     MCC: 0.1643
#     F1-score: 0.1523
#     mAP: 0.3391
#   [Ours - DecisionTree]
#     AUROC: 0.7256
#     G-mean: 0.4758
#     MCC: 0.3054
#     F1-score: 0.3034
#     mAP: 0.2888
#   [Ours - kNN]
#     AUROC: 0.6227
#     G-mean: 0.1095
#     MCC: 0.0929
#     F1-score: 0.0967
#     mAP: 0.1859
#   [Ours - MLP]
#     AUROC: 0.7650
#     G-mean: 0.4212
#     MCC: 0.2096
#     F1-score: 0.2116
#     mAP: 0.3190
#   [Ours - RandomForest]
#     AUROC: 0.9011
#     G-mean: 0.1274
#     MCC: 0.1255
#     F1-score: 0.1208
#     mAP: 0.6131
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.7287
#     G-mean: 0.5080
#     MCC: 0.1665
#     F1-score: 0.1534
#     mAP: 0.3433
#   [Ours - DecisionTree]
#     AUROC: 0.7195
#     G-mean: 0.4692
#     MCC: 0.2944
#     F1-score: 0.2936
#     mAP: 0.2820
#   [Ours - kNN]
#     AUROC: 0.6236
#     G-mean: 0.1129
#     MCC: 0.0913
#     F1-score: 0.0952
#     mAP: 0.1799
#   [Ours - MLP]
#     AUROC: 0.7657
#     G-mean: 0.4310
#     MCC: 0.2149
#     F1-score: 0.2160
#     mAP: 0.3192
#   [Ours - RandomForest]
#     AUROC: 0.8981
#     G-mean: 0.1211
#     MCC: 0.1194
#     F1-score: 0.1148
#     mAP: 0.5907
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.7329
#     G-mean: 0.5099
#     MCC: 0.1686
#     F1-score: 0.1552
#     mAP: 0.3378
#   [Ours - DecisionTree]
#     AUROC: 0.7171
#     G-mean: 0.4644
#     MCC: 0.2943
#     F1-score: 0.2943
#     mAP: 0.2867
#   [Ours - kNN]
#     AUROC: 0.6248
#     G-mean: 0.1156
#     MCC: 0.0923
#     F1-score: 0.0957
#     mAP: 0.1836
#   [Ours - MLP]
#     AUROC: 0.7615
#     G-mean: 0.4179
#     MCC: 0.2049
#     F1-score: 0.2063
#     mAP: 0.3130
#   [Ours - RandomForest]
#     AUROC: 0.8959
#     G-mean: 0.1160
#     MCC: 0.1143
#     F1-score: 0.1100
#     mAP: 0.5840
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/winequality-white-3_vs_7_results_gaussian_beta_0.1.csv
# Dataset loaded from DataFrame
# X shape : (900, 11)
# target : Counter({0: 880, 1: 20})
# IR: 44.0
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.8273
#     G-mean: 0.3899
#     MCC: 0.1308
#     F1-score: 0.1199
#     mAP: 0.3632
#   [Ours - DecisionTree]
#     AUROC: 0.7307
#     G-mean: 0.4386
#     MCC: 0.1658
#     F1-score: 0.1617
#     mAP: 0.1533
#   [Ours - kNN]
#     AUROC: 0.6008
#     G-mean: 0.1398
#     MCC: 0.0680
#     F1-score: 0.0800
#     mAP: 0.1071
#   [Ours - MLP]
#     AUROC: 0.8011
#     G-mean: 0.4706
#     MCC: 0.2105
#     F1-score: 0.2055
#     mAP: 0.3309
#   [Ours - RandomForest]
#     AUROC: 0.9432
#     G-mean: 0.2824
#     MCC: 0.2582
#     F1-score: 0.2500
#     mAP: 0.5559
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.8316
#     G-mean: 0.4567
#     MCC: 0.1906
#     F1-score: 0.1782
#     mAP: 0.3695
#   [Ours - DecisionTree]
#     AUROC: 0.7030
#     G-mean: 0.4540
#     MCC: 0.2050
#     F1-score: 0.2022
#     mAP: 0.1840
#   [Ours - kNN]
#     AUROC: 0.6119
#     G-mean: 0.1199
#     MCC: 0.0758
#     F1-score: 0.0900
#     mAP: 0.1308
#   [Ours - MLP]
#     AUROC: 0.8045
#     G-mean: 0.5166
#     MCC: 0.2385
#     F1-score: 0.2332
#     mAP: 0.3516
#   [Ours - RandomForest]
#     AUROC: 0.9505
#     G-mean: 0.2117
#     MCC: 0.1879
#     F1-score: 0.1834
#     mAP: 0.6176
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.8343
#     G-mean: 0.4817
#     MCC: 0.2003
#     F1-score: 0.1892
#     mAP: 0.3557
#   [Ours - DecisionTree]
#     AUROC: 0.7280
#     G-mean: 0.4710
#     MCC: 0.2043
#     F1-score: 0.1999
#     mAP: 0.2122
#   [Ours - kNN]
#     AUROC: 0.6181
#     G-mean: 0.1501
#     MCC: 0.0924
#     F1-score: 0.1067
#     mAP: 0.1387
#   [Ours - MLP]
#     AUROC: 0.7962
#     G-mean: 0.5007
#     MCC: 0.2301
#     F1-score: 0.2227
#     mAP: 0.3404
#   [Ours - RandomForest]
#     AUROC: 0.9373
#     G-mean: 0.1883
#     MCC: 0.1711
#     F1-score: 0.1667
#     mAP: 0.6020
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.8264
#     G-mean: 0.5016
#     MCC: 0.2077
#     F1-score: 0.1937
#     mAP: 0.3511
#   [Ours - DecisionTree]
#     AUROC: 0.7277
#     G-mean: 0.4637
#     MCC: 0.2010
#     F1-score: 0.1976
#     mAP: 0.2266
#   [Ours - kNN]
#     AUROC: 0.6134
#     G-mean: 0.1478
#     MCC: 0.0966
#     F1-score: 0.1092
#     mAP: 0.1466
#   [Ours - MLP]
#     AUROC: 0.8046
#     G-mean: 0.4828
#     MCC: 0.2274
#     F1-score: 0.2205
#     mAP: 0.3608
#   [Ours - RandomForest]
#     AUROC: 0.9364
#     G-mean: 0.2190
#     MCC: 0.1978
#     F1-score: 0.1933
#     mAP: 0.5933
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.8173
#     G-mean: 0.4856
#     MCC: 0.1989
#     F1-score: 0.1850
#     mAP: 0.3479
#   [Ours - DecisionTree]
#     AUROC: 0.7144
#     G-mean: 0.4540
#     MCC: 0.1979
#     F1-score: 0.1971
#     mAP: 0.2182
#   [Ours - kNN]
#     AUROC: 0.6268
#     G-mean: 0.1883
#     MCC: 0.1225
#     F1-score: 0.1340
#     mAP: 0.1636
#   [Ours - MLP]
#     AUROC: 0.8003
#     G-mean: 0.4751
#     MCC: 0.2258
#     F1-score: 0.2211
#     mAP: 0.3665
#   [Ours - RandomForest]
#     AUROC: 0.9332
#     G-mean: 0.2233
#     MCC: 0.1983
#     F1-score: 0.1940
#     mAP: 0.5876
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.8158
#     G-mean: 0.4893
#     MCC: 0.1991
#     F1-score: 0.1875
#     mAP: 0.3494
#   [Ours - DecisionTree]
#     AUROC: 0.6922
#     G-mean: 0.4480
#     MCC: 0.2044
#     F1-score: 0.2052
#     mAP: 0.2089
#   [Ours - kNN]
#     AUROC: 0.6321
#     G-mean: 0.2039
#     MCC: 0.1385
#     F1-score: 0.1489
#     mAP: 0.1758
#   [Ours - MLP]
#     AUROC: 0.8058
#     G-mean: 0.4928
#     MCC: 0.2403
#     F1-score: 0.2353
#     mAP: 0.3671
#   [Ours - RandomForest]
#     AUROC: 0.9328
#     G-mean: 0.2380
#     MCC: 0.2133
#     F1-score: 0.2089
#     mAP: 0.5939
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.8145
#     G-mean: 0.4964
#     MCC: 0.2060
#     F1-score: 0.1949
#     mAP: 0.3533
#   [Ours - DecisionTree]
#     AUROC: 0.6994
#     G-mean: 0.4691
#     MCC: 0.2196
#     F1-score: 0.2178
#     mAP: 0.2293
#   [Ours - kNN]
#     AUROC: 0.6350
#     G-mean: 0.2150
#     MCC: 0.1485
#     F1-score: 0.1586
#     mAP: 0.1790
#   [Ours - MLP]
#     AUROC: 0.8076
#     G-mean: 0.5003
#     MCC: 0.2518
#     F1-score: 0.2481
#     mAP: 0.3772
#   [Ours - RandomForest]
#     AUROC: 0.9332
#     G-mean: 0.2444
#     MCC: 0.2224
#     F1-score: 0.2171
#     mAP: 0.5818
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.8143
#     G-mean: 0.5101
#     MCC: 0.2151
#     F1-score: 0.2040
#     mAP: 0.3600
#   [Ours - DecisionTree]
#     AUROC: 0.7031
#     G-mean: 0.4745
#     MCC: 0.2319
#     F1-score: 0.2292
#     mAP: 0.2377
#   [Ours - kNN]
#     AUROC: 0.6408
#     G-mean: 0.2354
#     MCC: 0.1600
#     F1-score: 0.1690
#     mAP: 0.1882
#   [Ours - MLP]
#     AUROC: 0.8092
#     G-mean: 0.5107
#     MCC: 0.2567
#     F1-score: 0.2535
#     mAP: 0.3825
#   [Ours - RandomForest]
#     AUROC: 0.9349
#     G-mean: 0.2580
#     MCC: 0.2355
#     F1-score: 0.2296
#     mAP: 0.5829
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.8107
#     G-mean: 0.5230
#     MCC: 0.2192
#     F1-score: 0.2068
#     mAP: 0.3608
#   [Ours - DecisionTree]
#     AUROC: 0.6993
#     G-mean: 0.4626
#     MCC: 0.2197
#     F1-score: 0.2175
#     mAP: 0.2277
#   [Ours - kNN]
#     AUROC: 0.6390
#     G-mean: 0.2324
#     MCC: 0.1520
#     F1-score: 0.1615
#     mAP: 0.1845
#   [Ours - MLP]
#     AUROC: 0.8120
#     G-mean: 0.5224
#     MCC: 0.2546
#     F1-score: 0.2511
#     mAP: 0.3852
#   [Ours - RandomForest]
#     AUROC: 0.9337
#     G-mean: 0.2528
#     MCC: 0.2256
#     F1-score: 0.2207
#     mAP: 0.5742
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.8123
#     G-mean: 0.5207
#     MCC: 0.2133
#     F1-score: 0.2013
#     mAP: 0.3540
#   [Ours - DecisionTree]
#     AUROC: 0.6982
#     G-mean: 0.4717
#     MCC: 0.2223
#     F1-score: 0.2207
#     mAP: 0.2273
#   [Ours - kNN]
#     AUROC: 0.6427
#     G-mean: 0.2331
#     MCC: 0.1525
#     F1-score: 0.1627
#     mAP: 0.1900
#   [Ours - MLP]
#     AUROC: 0.8143
#     G-mean: 0.5238
#     MCC: 0.2520
#     F1-score: 0.2477
#     mAP: 0.3791
#   [Ours - RandomForest]
#     AUROC: 0.9349
#     G-mean: 0.2628
#     MCC: 0.2359
#     F1-score: 0.2303
#     mAP: 0.5751
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/winequality-white-3_vs_7_results_gaussian_beta_0.05.csv
# Dataset loaded from DataFrame
# X shape : (900, 11)
# target : Counter({0: 880, 1: 20})
# IR: 44.0
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.8807
#     G-mean: 0.4924
#     MCC: 0.2031
#     F1-score: 0.1834
#     mAP: 0.2767
#   [Ours - DecisionTree]
#     AUROC: 0.6753
#     G-mean: 0.4658
#     MCC: 0.1820
#     F1-score: 0.1773
#     mAP: 0.1964
#   [Ours - kNN]
#     AUROC: 0.7341
#     G-mean: 0.4006
#     MCC: 0.1808
#     F1-score: 0.1719
#     mAP: 0.1517
#   [Ours - MLP]
#     AUROC: 0.8443
#     G-mean: 0.5670
#     MCC: 0.2969
#     F1-score: 0.2783
#     mAP: 0.3628
#   [Ours - RandomForest]
#     AUROC: 0.9307
#     G-mean: 0.5205
#     MCC: 0.3653
#     F1-score: 0.3700
#     mAP: 0.5134
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.8648
#     G-mean: 0.4170
#     MCC: 0.1597
#     F1-score: 0.1557
#     mAP: 0.2483
#   [Ours - DecisionTree]
#     AUROC: 0.7039
#     G-mean: 0.5292
#     MCC: 0.1943
#     F1-score: 0.1838
#     mAP: 0.2292
#   [Ours - kNN]
#     AUROC: 0.7550
#     G-mean: 0.3539
#     MCC: 0.1767
#     F1-score: 0.1804
#     mAP: 0.1856
#   [Ours - MLP]
#     AUROC: 0.8429
#     G-mean: 0.4972
#     MCC: 0.2480
#     F1-score: 0.2384
#     mAP: 0.3556
#   [Ours - RandomForest]
#     AUROC: 0.9280
#     G-mean: 0.4862
#     MCC: 0.3675
#     F1-score: 0.3717
#     mAP: 0.5083
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.8714
#     G-mean: 0.4930
#     MCC: 0.1948
#     F1-score: 0.1880
#     mAP: 0.2452
#   [Ours - DecisionTree]
#     AUROC: 0.7236
#     G-mean: 0.5097
#     MCC: 0.2012
#     F1-score: 0.1933
#     mAP: 0.2610
#   [Ours - kNN]
#     AUROC: 0.7635
#     G-mean: 0.3738
#     MCC: 0.1785
#     F1-score: 0.1834
#     mAP: 0.2251
#   [Ours - MLP]
#     AUROC: 0.8464
#     G-mean: 0.5631
#     MCC: 0.2583
#     F1-score: 0.2414
#     mAP: 0.3787
#   [Ours - RandomForest]
#     AUROC: 0.9289
#     G-mean: 0.5120
#     MCC: 0.3962
#     F1-score: 0.3978
#     mAP: 0.5201
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.8715
#     G-mean: 0.4803
#     MCC: 0.1956
#     F1-score: 0.1925
#     mAP: 0.2686
#   [Ours - DecisionTree]
#     AUROC: 0.7341
#     G-mean: 0.5402
#     MCC: 0.2249
#     F1-score: 0.2128
#     mAP: 0.2797
#   [Ours - kNN]
#     AUROC: 0.7631
#     G-mean: 0.4329
#     MCC: 0.2075
#     F1-score: 0.2089
#     mAP: 0.2458
#   [Ours - MLP]
#     AUROC: 0.8533
#     G-mean: 0.5873
#     MCC: 0.2760
#     F1-score: 0.2577
#     mAP: 0.4230
#   [Ours - RandomForest]
#     AUROC: 0.9285
#     G-mean: 0.5041
#     MCC: 0.3983
#     F1-score: 0.3976
#     mAP: 0.5135
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.8659
#     G-mean: 0.4766
#     MCC: 0.2084
#     F1-score: 0.2052
#     mAP: 0.2767
#   [Ours - DecisionTree]
#     AUROC: 0.7410
#     G-mean: 0.5499
#     MCC: 0.2322
#     F1-score: 0.2180
#     mAP: 0.2921
#   [Ours - kNN]
#     AUROC: 0.7623
#     G-mean: 0.4488
#     MCC: 0.2175
#     F1-score: 0.2177
#     mAP: 0.2620
#   [Ours - MLP]
#     AUROC: 0.8494
#     G-mean: 0.6005
#     MCC: 0.2762
#     F1-score: 0.2550
#     mAP: 0.4255
#   [Ours - RandomForest]
#     AUROC: 0.9313
#     G-mean: 0.5190
#     MCC: 0.4043
#     F1-score: 0.4028
#     mAP: 0.5307
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.8653
#     G-mean: 0.4663
#     MCC: 0.2022
#     F1-score: 0.2016
#     mAP: 0.2897
#   [Ours - DecisionTree]
#     AUROC: 0.7414
#     G-mean: 0.5552
#     MCC: 0.2308
#     F1-score: 0.2135
#     mAP: 0.3009
#   [Ours - kNN]
#     AUROC: 0.7626
#     G-mean: 0.4361
#     MCC: 0.2069
#     F1-score: 0.2077
#     mAP: 0.2595
#   [Ours - MLP]
#     AUROC: 0.8538
#     G-mean: 0.6212
#     MCC: 0.2839
#     F1-score: 0.2608
#     mAP: 0.4256
#   [Ours - RandomForest]
#     AUROC: 0.9308
#     G-mean: 0.5191
#     MCC: 0.3923
#     F1-score: 0.3923
#     mAP: 0.5238
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.8684
#     G-mean: 0.4729
#     MCC: 0.2075
#     F1-score: 0.2074
#     mAP: 0.2922
#   [Ours - DecisionTree]
#     AUROC: 0.7378
#     G-mean: 0.5660
#     MCC: 0.2374
#     F1-score: 0.2198
#     mAP: 0.3000
#   [Ours - kNN]
#     AUROC: 0.7616
#     G-mean: 0.4316
#     MCC: 0.2071
#     F1-score: 0.2082
#     mAP: 0.2555
#   [Ours - MLP]
#     AUROC: 0.8547
#     G-mean: 0.6320
#     MCC: 0.2848
#     F1-score: 0.2607
#     mAP: 0.4240
#   [Ours - RandomForest]
#     AUROC: 0.9319
#     G-mean: 0.5134
#     MCC: 0.3915
#     F1-score: 0.3897
#     mAP: 0.5324
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.8680
#     G-mean: 0.4728
#     MCC: 0.2098
#     F1-score: 0.2100
#     mAP: 0.2983
#   [Ours - DecisionTree]
#     AUROC: 0.7270
#     G-mean: 0.5534
#     MCC: 0.2290
#     F1-score: 0.2138
#     mAP: 0.2999
#   [Ours - kNN]
#     AUROC: 0.7678
#     G-mean: 0.4487
#     MCC: 0.2194
#     F1-score: 0.2178
#     mAP: 0.2557
#   [Ours - MLP]
#     AUROC: 0.8538
#     G-mean: 0.6285
#     MCC: 0.2815
#     F1-score: 0.2590
#     mAP: 0.4237
#   [Ours - RandomForest]
#     AUROC: 0.9309
#     G-mean: 0.5180
#     MCC: 0.3946
#     F1-score: 0.3924
#     mAP: 0.5304
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.8672
#     G-mean: 0.4767
#     MCC: 0.2121
#     F1-score: 0.2111
#     mAP: 0.3052
#   [Ours - DecisionTree]
#     AUROC: 0.7273
#     G-mean: 0.5569
#     MCC: 0.2304
#     F1-score: 0.2143
#     mAP: 0.2987
#   [Ours - kNN]
#     AUROC: 0.7615
#     G-mean: 0.4511
#     MCC: 0.2206
#     F1-score: 0.2185
#     mAP: 0.2589
#   [Ours - MLP]
#     AUROC: 0.8540
#     G-mean: 0.6312
#     MCC: 0.2809
#     F1-score: 0.2579
#     mAP: 0.4276
#   [Ours - RandomForest]
#     AUROC: 0.9310
#     G-mean: 0.5167
#     MCC: 0.3890
#     F1-score: 0.3862
#     mAP: 0.5296
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.8691
#     G-mean: 0.4732
#     MCC: 0.2123
#     F1-score: 0.2111
#     mAP: 0.3081
#   [Ours - DecisionTree]
#     AUROC: 0.7312
#     G-mean: 0.5601
#     MCC: 0.2340
#     F1-score: 0.2169
#     mAP: 0.2981
#   [Ours - kNN]
#     AUROC: 0.7690
#     G-mean: 0.4478
#     MCC: 0.2212
#     F1-score: 0.2202
#     mAP: 0.2573
#   [Ours - MLP]
#     AUROC: 0.8536
#     G-mean: 0.6329
#     MCC: 0.2799
#     F1-score: 0.2559
#     mAP: 0.4186
#   [Ours - RandomForest]
#     AUROC: 0.9312
#     G-mean: 0.5170
#     MCC: 0.3864
#     F1-score: 0.3841
#     mAP: 0.5239
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/winequality-white-3_vs_7_results_gaussian_beta_0.01.csv
# Dataset loaded from DataFrame
# X shape : (900, 11)
# target : Counter({0: 880, 1: 20})
# IR: 44.0
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9006
#     G-mean: 0.6030
#     MCC: 0.2408
#     F1-score: 0.2207
#     mAP: 0.3412
#   [Ours - DecisionTree]
#     AUROC: 0.6506
#     G-mean: 0.3404
#     MCC: 0.1033
#     F1-score: 0.1240
#     mAP: 0.2115
#   [Ours - kNN]
#     AUROC: 0.8276
#     G-mean: 0.4417
#     MCC: 0.2308
#     F1-score: 0.2255
#     mAP: 0.2594
#   [Ours - MLP]
#     AUROC: 0.8733
#     G-mean: 0.5855
#     MCC: 0.2390
#     F1-score: 0.2090
#     mAP: 0.3862
#   [Ours - RandomForest]
#     AUROC: 0.9366
#     G-mean: 0.5202
#     MCC: 0.3856
#     F1-score: 0.3833
#     mAP: 0.4729
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.8923
#     G-mean: 0.5211
#     MCC: 0.2072
#     F1-score: 0.1975
#     mAP: 0.3271
#   [Ours - DecisionTree]
#     AUROC: 0.7087
#     G-mean: 0.4495
#     MCC: 0.1619
#     F1-score: 0.1639
#     mAP: 0.2419
#   [Ours - kNN]
#     AUROC: 0.8243
#     G-mean: 0.4776
#     MCC: 0.2469
#     F1-score: 0.2478
#     mAP: 0.2843
#   [Ours - MLP]
#     AUROC: 0.8597
#     G-mean: 0.5421
#     MCC: 0.2439
#     F1-score: 0.2287
#     mAP: 0.3801
#   [Ours - RandomForest]
#     AUROC: 0.9366
#     G-mean: 0.4857
#     MCC: 0.3699
#     F1-score: 0.3700
#     mAP: 0.5026
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.8996
#     G-mean: 0.5277
#     MCC: 0.2251
#     F1-score: 0.2172
#     mAP: 0.3271
#   [Ours - DecisionTree]
#     AUROC: 0.7325
#     G-mean: 0.5300
#     MCC: 0.1973
#     F1-score: 0.1889
#     mAP: 0.2532
#   [Ours - kNN]
#     AUROC: 0.8165
#     G-mean: 0.4654
#     MCC: 0.2287
#     F1-score: 0.2300
#     mAP: 0.3001
#   [Ours - MLP]
#     AUROC: 0.8591
#     G-mean: 0.5717
#     MCC: 0.2526
#     F1-score: 0.2346
#     mAP: 0.4020
#   [Ours - RandomForest]
#     AUROC: 0.9356
#     G-mean: 0.5108
#     MCC: 0.3715
#     F1-score: 0.3733
#     mAP: 0.5251
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.8950
#     G-mean: 0.5238
#     MCC: 0.2355
#     F1-score: 0.2293
#     mAP: 0.3399
#   [Ours - DecisionTree]
#     AUROC: 0.7205
#     G-mean: 0.5482
#     MCC: 0.1912
#     F1-score: 0.1828
#     mAP: 0.2414
#   [Ours - kNN]
#     AUROC: 0.8197
#     G-mean: 0.5014
#     MCC: 0.2421
#     F1-score: 0.2409
#     mAP: 0.3117
#   [Ours - MLP]
#     AUROC: 0.8625
#     G-mean: 0.5997
#     MCC: 0.2675
#     F1-score: 0.2454
#     mAP: 0.4214
#   [Ours - RandomForest]
#     AUROC: 0.9371
#     G-mean: 0.5452
#     MCC: 0.4078
#     F1-score: 0.4048
#     mAP: 0.5205
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.8866
#     G-mean: 0.5251
#     MCC: 0.2463
#     F1-score: 0.2393
#     mAP: 0.3444
#   [Ours - DecisionTree]
#     AUROC: 0.7374
#     G-mean: 0.5740
#     MCC: 0.2088
#     F1-score: 0.1932
#     mAP: 0.2453
#   [Ours - kNN]
#     AUROC: 0.8147
#     G-mean: 0.4975
#     MCC: 0.2320
#     F1-score: 0.2313
#     mAP: 0.2891
#   [Ours - MLP]
#     AUROC: 0.8549
#     G-mean: 0.6194
#     MCC: 0.2719
#     F1-score: 0.2480
#     mAP: 0.4219
#   [Ours - RandomForest]
#     AUROC: 0.9401
#     G-mean: 0.5438
#     MCC: 0.4118
#     F1-score: 0.4091
#     mAP: 0.5410
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.8851
#     G-mean: 0.5069
#     MCC: 0.2366
#     F1-score: 0.2329
#     mAP: 0.3491
#   [Ours - DecisionTree]
#     AUROC: 0.7003
#     G-mean: 0.5278
#     MCC: 0.1875
#     F1-score: 0.1762
#     mAP: 0.2251
#   [Ours - kNN]
#     AUROC: 0.8139
#     G-mean: 0.4976
#     MCC: 0.2333
#     F1-score: 0.2305
#     mAP: 0.2983
#   [Ours - MLP]
#     AUROC: 0.8564
#     G-mean: 0.6426
#     MCC: 0.2737
#     F1-score: 0.2473
#     mAP: 0.4189
#   [Ours - RandomForest]
#     AUROC: 0.9378
#     G-mean: 0.5400
#     MCC: 0.4049
#     F1-score: 0.4037
#     mAP: 0.5264
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.8842
#     G-mean: 0.5077
#     MCC: 0.2374
#     F1-score: 0.2347
#     mAP: 0.3448
#   [Ours - DecisionTree]
#     AUROC: 0.6833
#     G-mean: 0.5192
#     MCC: 0.1878
#     F1-score: 0.1780
#     mAP: 0.2238
#   [Ours - kNN]
#     AUROC: 0.8130
#     G-mean: 0.5139
#     MCC: 0.2449
#     F1-score: 0.2417
#     mAP: 0.3063
#   [Ours - MLP]
#     AUROC: 0.8567
#     G-mean: 0.6507
#     MCC: 0.2786
#     F1-score: 0.2522
#     mAP: 0.4301
#   [Ours - RandomForest]
#     AUROC: 0.9383
#     G-mean: 0.5415
#     MCC: 0.4075
#     F1-score: 0.4056
#     mAP: 0.5224
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.8832
#     G-mean: 0.5082
#     MCC: 0.2367
#     F1-score: 0.2345
#     mAP: 0.3457
#   [Ours - DecisionTree]
#     AUROC: 0.7023
#     G-mean: 0.5442
#     MCC: 0.1988
#     F1-score: 0.1857
#     mAP: 0.2437
#   [Ours - kNN]
#     AUROC: 0.8118
#     G-mean: 0.5206
#     MCC: 0.2476
#     F1-score: 0.2430
#     mAP: 0.3110
#   [Ours - MLP]
#     AUROC: 0.8557
#     G-mean: 0.6397
#     MCC: 0.2736
#     F1-score: 0.2483
#     mAP: 0.4271
#   [Ours - RandomForest]
#     AUROC: 0.9382
#     G-mean: 0.5388
#     MCC: 0.4010
#     F1-score: 0.3999
#     mAP: 0.5207
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.8811
#     G-mean: 0.5054
#     MCC: 0.2351
#     F1-score: 0.2335
#     mAP: 0.3421
#   [Ours - DecisionTree]
#     AUROC: 0.7031
#     G-mean: 0.5337
#     MCC: 0.1971
#     F1-score: 0.1838
#     mAP: 0.2477
#   [Ours - kNN]
#     AUROC: 0.8090
#     G-mean: 0.5180
#     MCC: 0.2460
#     F1-score: 0.2403
#     mAP: 0.3085
#   [Ours - MLP]
#     AUROC: 0.8565
#     G-mean: 0.6454
#     MCC: 0.2724
#     F1-score: 0.2465
#     mAP: 0.4259
#   [Ours - RandomForest]
#     AUROC: 0.9378
#     G-mean: 0.5320
#     MCC: 0.3933
#     F1-score: 0.3911
#     mAP: 0.5246
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.8811
#     G-mean: 0.4921
#     MCC: 0.2296
#     F1-score: 0.2282
#     mAP: 0.3409
#   [Ours - DecisionTree]
#     AUROC: 0.7058
#     G-mean: 0.5358
#     MCC: 0.1988
#     F1-score: 0.1849
#     mAP: 0.2500
#   [Ours - kNN]
#     AUROC: 0.8057
#     G-mean: 0.5037
#     MCC: 0.2396
#     F1-score: 0.2349
#     mAP: 0.3043
#   [Ours - MLP]
#     AUROC: 0.8552
#     G-mean: 0.6514
#     MCC: 0.2759
#     F1-score: 0.2479
#     mAP: 0.4210
#   [Ours - RandomForest]
#     AUROC: 0.9384
#     G-mean: 0.5407
#     MCC: 0.3989
#     F1-score: 0.3959
#     mAP: 0.5234
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/winequality-white-3_vs_7_results_gaussian_beta_0.005.csv
# Dataset loaded from DataFrame
# X shape : (900, 11)
# target : Counter({0: 880, 1: 20})
# IR: 44.0
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.8988
#     G-mean: 0.5643
#     MCC: 0.2453
#     F1-score: 0.2241
#     mAP: 0.3508
#   [Ours - DecisionTree]
#     AUROC: 0.6997
#     G-mean: 0.6074
#     MCC: 0.2024
#     F1-score: 0.1940
#     mAP: 0.2599
#   [Ours - kNN]
#     AUROC: 0.8304
#     G-mean: 0.5376
#     MCC: 0.2573
#     F1-score: 0.2462
#     mAP: 0.2438
#   [Ours - MLP]
#     AUROC: 0.8642
#     G-mean: 0.6242
#     MCC: 0.2571
#     F1-score: 0.2299
#     mAP: 0.4023
#   [Ours - RandomForest]
#     AUROC: 0.9412
#     G-mean: 0.4917
#     MCC: 0.3648
#     F1-score: 0.3633
#     mAP: 0.4444
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.8863
#     G-mean: 0.5157
#     MCC: 0.2248
#     F1-score: 0.2132
#     mAP: 0.3223
#   [Ours - DecisionTree]
#     AUROC: 0.6784
#     G-mean: 0.5210
#     MCC: 0.1703
#     F1-score: 0.1660
#     mAP: 0.2804
#   [Ours - kNN]
#     AUROC: 0.8112
#     G-mean: 0.4573
#     MCC: 0.2318
#     F1-score: 0.2350
#     mAP: 0.2948
#   [Ours - MLP]
#     AUROC: 0.8511
#     G-mean: 0.5598
#     MCC: 0.2338
#     F1-score: 0.2157
#     mAP: 0.3901
#   [Ours - RandomForest]
#     AUROC: 0.9394
#     G-mean: 0.4720
#     MCC: 0.3778
#     F1-score: 0.3767
#     mAP: 0.4784
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.8989
#     G-mean: 0.5569
#     MCC: 0.2597
#     F1-score: 0.2481
#     mAP: 0.3442
#   [Ours - DecisionTree]
#     AUROC: 0.6927
#     G-mean: 0.5241
#     MCC: 0.1830
#     F1-score: 0.1790
#     mAP: 0.2696
#   [Ours - kNN]
#     AUROC: 0.8090
#     G-mean: 0.4761
#     MCC: 0.2492
#     F1-score: 0.2504
#     mAP: 0.3065
#   [Ours - MLP]
#     AUROC: 0.8583
#     G-mean: 0.5815
#     MCC: 0.2342
#     F1-score: 0.2125
#     mAP: 0.4120
#   [Ours - RandomForest]
#     AUROC: 0.9385
#     G-mean: 0.5017
#     MCC: 0.3821
#     F1-score: 0.3811
#     mAP: 0.4943
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.8929
#     G-mean: 0.5457
#     MCC: 0.2530
#     F1-score: 0.2445
#     mAP: 0.3617
#   [Ours - DecisionTree]
#     AUROC: 0.6798
#     G-mean: 0.5406
#     MCC: 0.1902
#     F1-score: 0.1837
#     mAP: 0.2596
#   [Ours - kNN]
#     AUROC: 0.8142
#     G-mean: 0.5136
#     MCC: 0.2701
#     F1-score: 0.2657
#     mAP: 0.3287
#   [Ours - MLP]
#     AUROC: 0.8638
#     G-mean: 0.6067
#     MCC: 0.2509
#     F1-score: 0.2257
#     mAP: 0.4511
#   [Ours - RandomForest]
#     AUROC: 0.9376
#     G-mean: 0.5211
#     MCC: 0.4053
#     F1-score: 0.4008
#     mAP: 0.5063
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.8861
#     G-mean: 0.5363
#     MCC: 0.2512
#     F1-score: 0.2428
#     mAP: 0.3604
#   [Ours - DecisionTree]
#     AUROC: 0.6987
#     G-mean: 0.5569
#     MCC: 0.1970
#     F1-score: 0.1864
#     mAP: 0.2663
#   [Ours - kNN]
#     AUROC: 0.8068
#     G-mean: 0.5239
#     MCC: 0.2678
#     F1-score: 0.2603
#     mAP: 0.3235
#   [Ours - MLP]
#     AUROC: 0.8593
#     G-mean: 0.5974
#     MCC: 0.2467
#     F1-score: 0.2222
#     mAP: 0.4541
#   [Ours - RandomForest]
#     AUROC: 0.9371
#     G-mean: 0.5385
#     MCC: 0.4174
#     F1-score: 0.4140
#     mAP: 0.5257
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.8865
#     G-mean: 0.5280
#     MCC: 0.2522
#     F1-score: 0.2460
#     mAP: 0.3641
#   [Ours - DecisionTree]
#     AUROC: 0.7162
#     G-mean: 0.5768
#     MCC: 0.2085
#     F1-score: 0.1931
#     mAP: 0.2786
#   [Ours - kNN]
#     AUROC: 0.8126
#     G-mean: 0.5318
#     MCC: 0.2725
#     F1-score: 0.2645
#     mAP: 0.3394
#   [Ours - MLP]
#     AUROC: 0.8600
#     G-mean: 0.6074
#     MCC: 0.2519
#     F1-score: 0.2257
#     mAP: 0.4501
#   [Ours - RandomForest]
#     AUROC: 0.9374
#     G-mean: 0.5569
#     MCC: 0.4313
#     F1-score: 0.4272
#     mAP: 0.5320
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.8868
#     G-mean: 0.5259
#     MCC: 0.2508
#     F1-score: 0.2462
#     mAP: 0.3660
#   [Ours - DecisionTree]
#     AUROC: 0.7113
#     G-mean: 0.5798
#     MCC: 0.2095
#     F1-score: 0.1935
#     mAP: 0.2681
#   [Ours - kNN]
#     AUROC: 0.8163
#     G-mean: 0.5607
#     MCC: 0.2872
#     F1-score: 0.2771
#     mAP: 0.3496
#   [Ours - MLP]
#     AUROC: 0.8633
#     G-mean: 0.6236
#     MCC: 0.2562
#     F1-score: 0.2281
#     mAP: 0.4583
#   [Ours - RandomForest]
#     AUROC: 0.9393
#     G-mean: 0.5659
#     MCC: 0.4360
#     F1-score: 0.4314
#     mAP: 0.5430
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.8844
#     G-mean: 0.5121
#     MCC: 0.2412
#     F1-score: 0.2386
#     mAP: 0.3625
#   [Ours - DecisionTree]
#     AUROC: 0.7065
#     G-mean: 0.5619
#     MCC: 0.2039
#     F1-score: 0.1901
#     mAP: 0.2616
#   [Ours - kNN]
#     AUROC: 0.8135
#     G-mean: 0.5583
#     MCC: 0.2847
#     F1-score: 0.2754
#     mAP: 0.3507
#   [Ours - MLP]
#     AUROC: 0.8619
#     G-mean: 0.6210
#     MCC: 0.2540
#     F1-score: 0.2275
#     mAP: 0.4561
#   [Ours - RandomForest]
#     AUROC: 0.9391
#     G-mean: 0.5776
#     MCC: 0.4373
#     F1-score: 0.4327
#     mAP: 0.5412
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.8825
#     G-mean: 0.5086
#     MCC: 0.2388
#     F1-score: 0.2367
#     mAP: 0.3608
#   [Ours - DecisionTree]
#     AUROC: 0.6926
#     G-mean: 0.5471
#     MCC: 0.1944
#     F1-score: 0.1817
#     mAP: 0.2497
#   [Ours - kNN]
#     AUROC: 0.8102
#     G-mean: 0.5593
#     MCC: 0.2836
#     F1-score: 0.2737
#     mAP: 0.3411
#   [Ours - MLP]
#     AUROC: 0.8617
#     G-mean: 0.6291
#     MCC: 0.2564
#     F1-score: 0.2297
#     mAP: 0.4513
#   [Ours - RandomForest]
#     AUROC: 0.9393
#     G-mean: 0.5587
#     MCC: 0.4180
#     F1-score: 0.4136
#     mAP: 0.5463
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.8815
#     G-mean: 0.5091
#     MCC: 0.2391
#     F1-score: 0.2375
#     mAP: 0.3597
#   [Ours - DecisionTree]
#     AUROC: 0.6975
#     G-mean: 0.5545
#     MCC: 0.1983
#     F1-score: 0.1838
#     mAP: 0.2459
#   [Ours - kNN]
#     AUROC: 0.8143
#     G-mean: 0.5407
#     MCC: 0.2720
#     F1-score: 0.2635
#     mAP: 0.3337
#   [Ours - MLP]
#     AUROC: 0.8610
#     G-mean: 0.6311
#     MCC: 0.2578
#     F1-score: 0.2306
#     mAP: 0.4475
#   [Ours - RandomForest]
#     AUROC: 0.9399
#     G-mean: 0.5576
#     MCC: 0.4124
#     F1-score: 0.4086
#     mAP: 0.5443
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/winequality-white-3_vs_7_results_gaussian_beta_0.001.csv
# Dataset loaded from DataFrame
# X shape : (900, 11)
# target : Counter({0: 880, 1: 20})
# IR: 44.0
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9023
#     G-mean: 0.6065
#     MCC: 0.2652
#     F1-score: 0.2486
#     mAP: 0.3543
#   [Ours - DecisionTree]
#     AUROC: 0.4443
#     G-mean: 0.1670
#     MCC: 0.0608
#     F1-score: 0.0844
#     mAP: 0.1118
#   [Ours - kNN]
#     AUROC: 0.8045
#     G-mean: 0.5075
#     MCC: 0.2109
#     F1-score: 0.2059
#     mAP: 0.2668
#   [Ours - MLP]
#     AUROC: 0.8704
#     G-mean: 0.6534
#     MCC: 0.2842
#     F1-score: 0.2512
#     mAP: 0.3855
#   [Ours - RandomForest]
#     AUROC: 0.9452
#     G-mean: 0.4905
#     MCC: 0.3151
#     F1-score: 0.3200
#     mAP: 0.4648
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.8866
#     G-mean: 0.5369
#     MCC: 0.2371
#     F1-score: 0.2278
#     mAP: 0.3145
#   [Ours - DecisionTree]
#     AUROC: 0.5872
#     G-mean: 0.3351
#     MCC: 0.1153
#     F1-score: 0.1247
#     mAP: 0.1744
#   [Ours - kNN]
#     AUROC: 0.7993
#     G-mean: 0.4764
#     MCC: 0.2283
#     F1-score: 0.2314
#     mAP: 0.2569
#   [Ours - MLP]
#     AUROC: 0.8559
#     G-mean: 0.5901
#     MCC: 0.2707
#     F1-score: 0.2500
#     mAP: 0.3818
#   [Ours - RandomForest]
#     AUROC: 0.9360
#     G-mean: 0.4707
#     MCC: 0.3349
#     F1-score: 0.3350
#     mAP: 0.4890
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9011
#     G-mean: 0.5707
#     MCC: 0.2679
#     F1-score: 0.2580
#     mAP: 0.3494
#   [Ours - DecisionTree]
#     AUROC: 0.6444
#     G-mean: 0.4470
#     MCC: 0.1692
#     F1-score: 0.1693
#     mAP: 0.2042
#   [Ours - kNN]
#     AUROC: 0.8178
#     G-mean: 0.4980
#     MCC: 0.2535
#     F1-score: 0.2525
#     mAP: 0.2829
#   [Ours - MLP]
#     AUROC: 0.8595
#     G-mean: 0.6234
#     MCC: 0.2671
#     F1-score: 0.2432
#     mAP: 0.4253
#   [Ours - RandomForest]
#     AUROC: 0.9389
#     G-mean: 0.5250
#     MCC: 0.3912
#     F1-score: 0.3889
#     mAP: 0.5195
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.8926
#     G-mean: 0.5559
#     MCC: 0.2585
#     F1-score: 0.2511
#     mAP: 0.3597
#   [Ours - DecisionTree]
#     AUROC: 0.6418
#     G-mean: 0.4479
#     MCC: 0.1578
#     F1-score: 0.1565
#     mAP: 0.2014
#   [Ours - kNN]
#     AUROC: 0.8132
#     G-mean: 0.5224
#     MCC: 0.2614
#     F1-score: 0.2557
#     mAP: 0.2918
#   [Ours - MLP]
#     AUROC: 0.8614
#     G-mean: 0.6252
#     MCC: 0.2768
#     F1-score: 0.2530
#     mAP: 0.4277
#   [Ours - RandomForest]
#     AUROC: 0.9372
#     G-mean: 0.5556
#     MCC: 0.4115
#     F1-score: 0.4067
#     mAP: 0.5250
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.8870
#     G-mean: 0.5506
#     MCC: 0.2640
#     F1-score: 0.2558
#     mAP: 0.3610
#   [Ours - DecisionTree]
#     AUROC: 0.6575
#     G-mean: 0.4709
#     MCC: 0.1770
#     F1-score: 0.1735
#     mAP: 0.2356
#   [Ours - kNN]
#     AUROC: 0.8163
#     G-mean: 0.5503
#     MCC: 0.2721
#     F1-score: 0.2614
#     mAP: 0.2995
#   [Ours - MLP]
#     AUROC: 0.8584
#     G-mean: 0.6305
#     MCC: 0.2744
#     F1-score: 0.2485
#     mAP: 0.4375
#   [Ours - RandomForest]
#     AUROC: 0.9357
#     G-mean: 0.5718
#     MCC: 0.4290
#     F1-score: 0.4228
#     mAP: 0.5388
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.8890
#     G-mean: 0.5515
#     MCC: 0.2694
#     F1-score: 0.2629
#     mAP: 0.3610
#   [Ours - DecisionTree]
#     AUROC: 0.6731
#     G-mean: 0.4751
#     MCC: 0.1826
#     F1-score: 0.1783
#     mAP: 0.2429
#   [Ours - kNN]
#     AUROC: 0.8154
#     G-mean: 0.5490
#     MCC: 0.2721
#     F1-score: 0.2625
#     mAP: 0.3072
#   [Ours - MLP]
#     AUROC: 0.8572
#     G-mean: 0.6366
#     MCC: 0.2704
#     F1-score: 0.2450
#     mAP: 0.4370
#   [Ours - RandomForest]
#     AUROC: 0.9347
#     G-mean: 0.5916
#     MCC: 0.4450
#     F1-score: 0.4390
#     mAP: 0.5395
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.8877
#     G-mean: 0.5460
#     MCC: 0.2640
#     F1-score: 0.2588
#     mAP: 0.3602
#   [Ours - DecisionTree]
#     AUROC: 0.6816
#     G-mean: 0.5064
#     MCC: 0.1997
#     F1-score: 0.1925
#     mAP: 0.2587
#   [Ours - kNN]
#     AUROC: 0.8150
#     G-mean: 0.5752
#     MCC: 0.2849
#     F1-score: 0.2731
#     mAP: 0.3192
#   [Ours - MLP]
#     AUROC: 0.8579
#     G-mean: 0.6456
#     MCC: 0.2739
#     F1-score: 0.2483
#     mAP: 0.4466
#   [Ours - RandomForest]
#     AUROC: 0.9363
#     G-mean: 0.5897
#     MCC: 0.4438
#     F1-score: 0.4375
#     mAP: 0.5462
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.8871
#     G-mean: 0.5382
#     MCC: 0.2562
#     F1-score: 0.2526
#     mAP: 0.3601
#   [Ours - DecisionTree]
#     AUROC: 0.6969
#     G-mean: 0.5183
#     MCC: 0.2038
#     F1-score: 0.1953
#     mAP: 0.2622
#   [Ours - kNN]
#     AUROC: 0.8151
#     G-mean: 0.5792
#     MCC: 0.2847
#     F1-score: 0.2732
#     mAP: 0.3273
#   [Ours - MLP]
#     AUROC: 0.8570
#     G-mean: 0.6433
#     MCC: 0.2702
#     F1-score: 0.2444
#     mAP: 0.4429
#   [Ours - RandomForest]
#     AUROC: 0.9355
#     G-mean: 0.5984
#     MCC: 0.4464
#     F1-score: 0.4402
#     mAP: 0.5471
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.8849
#     G-mean: 0.5351
#     MCC: 0.2556
#     F1-score: 0.2517
#     mAP: 0.3595
#   [Ours - DecisionTree]
#     AUROC: 0.6926
#     G-mean: 0.5167
#     MCC: 0.2034
#     F1-score: 0.1950
#     mAP: 0.2670
#   [Ours - kNN]
#     AUROC: 0.8146
#     G-mean: 0.5702
#     MCC: 0.2795
#     F1-score: 0.2680
#     mAP: 0.3231
#   [Ours - MLP]
#     AUROC: 0.8566
#     G-mean: 0.6337
#     MCC: 0.2641
#     F1-score: 0.2391
#     mAP: 0.4407
#   [Ours - RandomForest]
#     AUROC: 0.9350
#     G-mean: 0.5895
#     MCC: 0.4352
#     F1-score: 0.4283
#     mAP: 0.5517
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.8840
#     G-mean: 0.5327
#     MCC: 0.2536
#     F1-score: 0.2502
#     mAP: 0.3586
#   [Ours - DecisionTree]
#     AUROC: 0.6966
#     G-mean: 0.5045
#     MCC: 0.1976
#     F1-score: 0.1900
#     mAP: 0.2614
#   [Ours - kNN]
#     AUROC: 0.8189
#     G-mean: 0.5702
#     MCC: 0.2825
#     F1-score: 0.2709
#     mAP: 0.3241
#   [Ours - MLP]
#     AUROC: 0.8558
#     G-mean: 0.6362
#     MCC: 0.2670
#     F1-score: 0.2412
#     mAP: 0.4376
#   [Ours - RandomForest]
#     AUROC: 0.9361
#     G-mean: 0.5951
#     MCC: 0.4336
#     F1-score: 0.4267
#     mAP: 0.5501
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/winequality-white-3_vs_7_results_gaussian_beta_0.0.csv

# %%
data_name = 'solar_flare_m0'
maj_target_name = -1

n_epochs = 2000
hidden_dims = [64, 128, 256]
latent_dim = 512
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        fetch_data_func=fetch_datasets,
        maj_target_name=maj_target_name,
        methods=methods,
        base_models=base_models,
        device=device,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )
# Out:
# beta: 0.1
# Dataset loaded: solar_flare_m0
# X shape : (1389, 32)
# target : Counter({0: 1321, 1: 68})
# IR: 19.43
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.7552
#     G-mean: 0.6676
#     MCC: 0.1707
#     F1-score: 0.1851
#     mAP: 0.2527
#   [Ours - DecisionTree]
#     AUROC: 0.6561
#     G-mean: 0.2383
#     MCC: 0.1491
#     F1-score: 0.1535
#     mAP: 0.1792
#   [Ours - kNN]
#     AUROC: 0.6570
#     G-mean: 0.2844
#     MCC: 0.1700
#     F1-score: 0.1676
#     mAP: 0.1722
#   [Ours - MLP]
#     AUROC: 0.7189
#     G-mean: 0.4720
#     MCC: 0.1942
#     F1-score: 0.2312
#     mAP: 0.2163
#   [Ours - RandomForest]
#     AUROC: 0.7924
#     G-mean: 0.1124
#     MCC: 0.0414
#     F1-score: 0.0582
#     mAP: 0.2079
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.7538
#     G-mean: 0.6757
#     MCC: 0.1819
#     F1-score: 0.1937
#     mAP: 0.2384
#   [Ours - DecisionTree]
#     AUROC: 0.6666
#     G-mean: 0.1914
#     MCC: 0.1265
#     F1-score: 0.1301
#     mAP: 0.1778
#   [Ours - kNN]
#     AUROC: 0.6634
#     G-mean: 0.2760
#     MCC: 0.1578
#     F1-score: 0.1641
#     mAP: 0.1752
#   [Ours - MLP]
#     AUROC: 0.7347
#     G-mean: 0.4888
#     MCC: 0.2206
#     F1-score: 0.2504
#     mAP: 0.2263
#   [Ours - RandomForest]
#     AUROC: 0.7883
#     G-mean: 0.0939
#     MCC: 0.0385
#     F1-score: 0.0516
#     mAP: 0.2049
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.7536
#     G-mean: 0.6718
#     MCC: 0.1784
#     F1-score: 0.1914
#     mAP: 0.2426
#   [Ours - DecisionTree]
#     AUROC: 0.6680
#     G-mean: 0.1964
#     MCC: 0.1296
#     F1-score: 0.1295
#     mAP: 0.1745
#   [Ours - kNN]
#     AUROC: 0.6625
#     G-mean: 0.2640
#     MCC: 0.1471
#     F1-score: 0.1544
#     mAP: 0.1657
#   [Ours - MLP]
#     AUROC: 0.7317
#     G-mean: 0.4894
#     MCC: 0.2156
#     F1-score: 0.2479
#     mAP: 0.2242
#   [Ours - RandomForest]
#     AUROC: 0.7869
#     G-mean: 0.0802
#     MCC: 0.0288
#     F1-score: 0.0455
#     mAP: 0.1982
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.7429
#     G-mean: 0.6653
#     MCC: 0.1747
#     F1-score: 0.1880
#     mAP: 0.2299
#   [Ours - DecisionTree]
#     AUROC: 0.6615
#     G-mean: 0.1857
#     MCC: 0.1197
#     F1-score: 0.1196
#     mAP: 0.1714
#   [Ours - kNN]
#     AUROC: 0.6634
#     G-mean: 0.2696
#     MCC: 0.1527
#     F1-score: 0.1613
#     mAP: 0.1692
#   [Ours - MLP]
#     AUROC: 0.7304
#     G-mean: 0.4600
#     MCC: 0.1981
#     F1-score: 0.2329
#     mAP: 0.2224
#   [Ours - RandomForest]
#     AUROC: 0.7763
#     G-mean: 0.0787
#     MCC: 0.0247
#     F1-score: 0.0425
#     mAP: 0.1955
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.7438
#     G-mean: 0.6650
#     MCC: 0.1733
#     F1-score: 0.1865
#     mAP: 0.2328
#   [Ours - DecisionTree]
#     AUROC: 0.6657
#     G-mean: 0.1900
#     MCC: 0.1178
#     F1-score: 0.1195
#     mAP: 0.1716
#   [Ours - kNN]
#     AUROC: 0.6675
#     G-mean: 0.2489
#     MCC: 0.1437
#     F1-score: 0.1508
#     mAP: 0.1696
#   [Ours - MLP]
#     AUROC: 0.7363
#     G-mean: 0.4648
#     MCC: 0.1987
#     F1-score: 0.2344
#     mAP: 0.2284
#   [Ours - RandomForest]
#     AUROC: 0.7775
#     G-mean: 0.0861
#     MCC: 0.0296
#     F1-score: 0.0469
#     mAP: 0.1941
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.7451
#     G-mean: 0.6682
#     MCC: 0.1769
#     F1-score: 0.1892
#     mAP: 0.2389
#   [Ours - DecisionTree]
#     AUROC: 0.6670
#     G-mean: 0.1968
#     MCC: 0.1223
#     F1-score: 0.1252
#     mAP: 0.1778
#   [Ours - kNN]
#     AUROC: 0.6686
#     G-mean: 0.2417
#     MCC: 0.1358
#     F1-score: 0.1448
#     mAP: 0.1666
#   [Ours - MLP]
#     AUROC: 0.7368
#     G-mean: 0.4619
#     MCC: 0.1972
#     F1-score: 0.2330
#     mAP: 0.2308
#   [Ours - RandomForest]
#     AUROC: 0.7803
#     G-mean: 0.0843
#     MCC: 0.0288
#     F1-score: 0.0461
#     mAP: 0.1939
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.7481
#     G-mean: 0.6699
#     MCC: 0.1788
#     F1-score: 0.1907
#     mAP: 0.2384
#   [Ours - DecisionTree]
#     AUROC: 0.6727
#     G-mean: 0.2024
#     MCC: 0.1226
#     F1-score: 0.1275
#     mAP: 0.1778
#   [Ours - kNN]
#     AUROC: 0.6659
#     G-mean: 0.2366
#     MCC: 0.1311
#     F1-score: 0.1405
#     mAP: 0.1601
#   [Ours - MLP]
#     AUROC: 0.7362
#     G-mean: 0.4633
#     MCC: 0.2002
#     F1-score: 0.2359
#     mAP: 0.2327
#   [Ours - RandomForest]
#     AUROC: 0.7816
#     G-mean: 0.0776
#     MCC: 0.0243
#     F1-score: 0.0424
#     mAP: 0.1926
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.7505
#     G-mean: 0.6724
#     MCC: 0.1806
#     F1-score: 0.1918
#     mAP: 0.2352
#   [Ours - DecisionTree]
#     AUROC: 0.6788
#     G-mean: 0.2032
#     MCC: 0.1219
#     F1-score: 0.1270
#     mAP: 0.1797
#   [Ours - kNN]
#     AUROC: 0.6682
#     G-mean: 0.2331
#     MCC: 0.1264
#     F1-score: 0.1372
#     mAP: 0.1597
#   [Ours - MLP]
#     AUROC: 0.7375
#     G-mean: 0.4664
#     MCC: 0.1976
#     F1-score: 0.2336
#     mAP: 0.2298
#   [Ours - RandomForest]
#     AUROC: 0.7806
#     G-mean: 0.0726
#     MCC: 0.0204
#     F1-score: 0.0392
#     mAP: 0.1895
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.7509
#     G-mean: 0.6716
#     MCC: 0.1792
#     F1-score: 0.1909
#     mAP: 0.2361
#   [Ours - DecisionTree]
#     AUROC: 0.6679
#     G-mean: 0.1890
#     MCC: 0.1109
#     F1-score: 0.1172
#     mAP: 0.1775
#   [Ours - kNN]
#     AUROC: 0.6682
#     G-mean: 0.2361
#     MCC: 0.1296
#     F1-score: 0.1395
#     mAP: 0.1599
#   [Ours - MLP]
#     AUROC: 0.7390
#     G-mean: 0.4713
#     MCC: 0.1966
#     F1-score: 0.2332
#     mAP: 0.2319
#   [Ours - RandomForest]
#     AUROC: 0.7819
#     G-mean: 0.0770
#     MCC: 0.0243
#     F1-score: 0.0418
#     mAP: 0.1909
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.7510
#     G-mean: 0.6715
#     MCC: 0.1794
#     F1-score: 0.1912
#     mAP: 0.2383
#   [Ours - DecisionTree]
#     AUROC: 0.6696
#     G-mean: 0.1895
#     MCC: 0.1110
#     F1-score: 0.1164
#     mAP: 0.1798
#   [Ours - kNN]
#     AUROC: 0.6690
#     G-mean: 0.2499
#     MCC: 0.1366
#     F1-score: 0.1467
#     mAP: 0.1619
#   [Ours - MLP]
#     AUROC: 0.7379
#     G-mean: 0.4684
#     MCC: 0.1944
#     F1-score: 0.2312
#     mAP: 0.2320
#   [Ours - RandomForest]
#     AUROC: 0.7834
#     G-mean: 0.0771
#     MCC: 0.0231
#     F1-score: 0.0413
#     mAP: 0.1929
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/solar_flare_m0_results_gaussian_beta_0.1.csv
# beta: 0.05
# Dataset loaded: solar_flare_m0
# X shape : (1389, 32)
# target : Counter({0: 1321, 1: 68})
# IR: 19.43
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.7068
#     G-mean: 0.6023
#     MCC: 0.1379
#     F1-score: 0.1738
#     mAP: 0.1414
#   [Ours - DecisionTree]
#     AUROC: 0.6572
#     G-mean: 0.1812
#     MCC: 0.1124
#     F1-score: 0.1158
#     mAP: 0.2028
#   [Ours - kNN]
#     AUROC: 0.6562
#     G-mean: 0.3639
#     MCC: 0.1784
#     F1-score: 0.2030
#     mAP: 0.1620
#   [Ours - MLP]
#     AUROC: 0.7156
#     G-mean: 0.5168
#     MCC: 0.2272
#     F1-score: 0.2610
#     mAP: 0.2133
#   [Ours - RandomForest]
#     AUROC: 0.7872
#     G-mean: 0.1157
#     MCC: 0.0581
#     F1-score: 0.0654
#     mAP: 0.2053
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.7238
#     G-mean: 0.6040
#     MCC: 0.1442
#     F1-score: 0.1779
#     mAP: 0.1683
#   [Ours - DecisionTree]
#     AUROC: 0.6784
#     G-mean: 0.1627
#     MCC: 0.1053
#     F1-score: 0.1090
#     mAP: 0.2019
#   [Ours - kNN]
#     AUROC: 0.6622
#     G-mean: 0.3416
#     MCC: 0.1727
#     F1-score: 0.2015
#     mAP: 0.1678
#   [Ours - MLP]
#     AUROC: 0.7295
#     G-mean: 0.5053
#     MCC: 0.2151
#     F1-score: 0.2493
#     mAP: 0.2359
#   [Ours - RandomForest]
#     AUROC: 0.7873
#     G-mean: 0.0766
#     MCC: 0.0267
#     F1-score: 0.0427
#     mAP: 0.2009
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.7221
#     G-mean: 0.6029
#     MCC: 0.1429
#     F1-score: 0.1756
#     mAP: 0.1623
#   [Ours - DecisionTree]
#     AUROC: 0.6697
#     G-mean: 0.1844
#     MCC: 0.1094
#     F1-score: 0.1127
#     mAP: 0.1921
#   [Ours - kNN]
#     AUROC: 0.6625
#     G-mean: 0.3051
#     MCC: 0.1498
#     F1-score: 0.1772
#     mAP: 0.1582
#   [Ours - MLP]
#     AUROC: 0.7309
#     G-mean: 0.4795
#     MCC: 0.1952
#     F1-score: 0.2323
#     mAP: 0.2277
#   [Ours - RandomForest]
#     AUROC: 0.7872
#     G-mean: 0.0812
#     MCC: 0.0302
#     F1-score: 0.0470
#     mAP: 0.1964
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.7218
#     G-mean: 0.6004
#     MCC: 0.1441
#     F1-score: 0.1758
#     mAP: 0.1746
#   [Ours - DecisionTree]
#     AUROC: 0.6788
#     G-mean: 0.1672
#     MCC: 0.0949
#     F1-score: 0.1007
#     mAP: 0.1927
#   [Ours - kNN]
#     AUROC: 0.6634
#     G-mean: 0.3144
#     MCC: 0.1587
#     F1-score: 0.1843
#     mAP: 0.1619
#   [Ours - MLP]
#     AUROC: 0.7270
#     G-mean: 0.4714
#     MCC: 0.1988
#     F1-score: 0.2345
#     mAP: 0.2248
#   [Ours - RandomForest]
#     AUROC: 0.7761
#     G-mean: 0.0702
#     MCC: 0.0210
#     F1-score: 0.0391
#     mAP: 0.1927
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.7235
#     G-mean: 0.6116
#     MCC: 0.1525
#     F1-score: 0.1807
#     mAP: 0.1773
#   [Ours - DecisionTree]
#     AUROC: 0.6881
#     G-mean: 0.1645
#     MCC: 0.0923
#     F1-score: 0.0984
#     mAP: 0.1905
#   [Ours - kNN]
#     AUROC: 0.6670
#     G-mean: 0.3187
#     MCC: 0.1596
#     F1-score: 0.1844
#     mAP: 0.1607
#   [Ours - MLP]
#     AUROC: 0.7273
#     G-mean: 0.4720
#     MCC: 0.1943
#     F1-score: 0.2310
#     mAP: 0.2236
#   [Ours - RandomForest]
#     AUROC: 0.7804
#     G-mean: 0.0873
#     MCC: 0.0288
#     F1-score: 0.0471
#     mAP: 0.1913
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.7244
#     G-mean: 0.6169
#     MCC: 0.1564
#     F1-score: 0.1839
#     mAP: 0.1799
#   [Ours - DecisionTree]
#     AUROC: 0.6921
#     G-mean: 0.1760
#     MCC: 0.0999
#     F1-score: 0.1073
#     mAP: 0.1945
#   [Ours - kNN]
#     AUROC: 0.6678
#     G-mean: 0.3159
#     MCC: 0.1577
#     F1-score: 0.1819
#     mAP: 0.1627
#   [Ours - MLP]
#     AUROC: 0.7288
#     G-mean: 0.4741
#     MCC: 0.1961
#     F1-score: 0.2336
#     mAP: 0.2263
#   [Ours - RandomForest]
#     AUROC: 0.7816
#     G-mean: 0.0790
#     MCC: 0.0234
#     F1-score: 0.0426
#     mAP: 0.1910
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.7247
#     G-mean: 0.6165
#     MCC: 0.1566
#     F1-score: 0.1838
#     mAP: 0.1835
#   [Ours - DecisionTree]
#     AUROC: 0.6948
#     G-mean: 0.1713
#     MCC: 0.0957
#     F1-score: 0.1045
#     mAP: 0.1914
#   [Ours - kNN]
#     AUROC: 0.6647
#     G-mean: 0.3005
#     MCC: 0.1460
#     F1-score: 0.1710
#     mAP: 0.1565
#   [Ours - MLP]
#     AUROC: 0.7296
#     G-mean: 0.4796
#     MCC: 0.1962
#     F1-score: 0.2341
#     mAP: 0.2254
#   [Ours - RandomForest]
#     AUROC: 0.7822
#     G-mean: 0.0730
#     MCC: 0.0189
#     F1-score: 0.0387
#     mAP: 0.1904
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.7279
#     G-mean: 0.6207
#     MCC: 0.1579
#     F1-score: 0.1842
#     mAP: 0.1836
#   [Ours - DecisionTree]
#     AUROC: 0.6922
#     G-mean: 0.1600
#     MCC: 0.0882
#     F1-score: 0.0971
#     mAP: 0.1876
#   [Ours - kNN]
#     AUROC: 0.6679
#     G-mean: 0.3029
#     MCC: 0.1471
#     F1-score: 0.1703
#     mAP: 0.1576
#   [Ours - MLP]
#     AUROC: 0.7307
#     G-mean: 0.4826
#     MCC: 0.1945
#     F1-score: 0.2329
#     mAP: 0.2225
#   [Ours - RandomForest]
#     AUROC: 0.7808
#     G-mean: 0.0733
#     MCC: 0.0194
#     F1-score: 0.0389
#     mAP: 0.1880
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.7255
#     G-mean: 0.6224
#     MCC: 0.1577
#     F1-score: 0.1839
#     mAP: 0.1825
#   [Ours - DecisionTree]
#     AUROC: 0.6855
#     G-mean: 0.1590
#     MCC: 0.0889
#     F1-score: 0.0962
#     mAP: 0.1885
#   [Ours - kNN]
#     AUROC: 0.6684
#     G-mean: 0.3003
#     MCC: 0.1477
#     F1-score: 0.1713
#     mAP: 0.1581
#   [Ours - MLP]
#     AUROC: 0.7298
#     G-mean: 0.4915
#     MCC: 0.1967
#     F1-score: 0.2351
#     mAP: 0.2264
#   [Ours - RandomForest]
#     AUROC: 0.7817
#     G-mean: 0.0776
#     MCC: 0.0231
#     F1-score: 0.0415
#     mAP: 0.1899
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.7271
#     G-mean: 0.6220
#     MCC: 0.1567
#     F1-score: 0.1832
#     mAP: 0.1822
#   [Ours - DecisionTree]
#     AUROC: 0.6913
#     G-mean: 0.1699
#     MCC: 0.0961
#     F1-score: 0.1018
#     mAP: 0.1903
#   [Ours - kNN]
#     AUROC: 0.6696
#     G-mean: 0.3106
#     MCC: 0.1517
#     F1-score: 0.1756
#     mAP: 0.1586
#   [Ours - MLP]
#     AUROC: 0.7299
#     G-mean: 0.4889
#     MCC: 0.1934
#     F1-score: 0.2321
#     mAP: 0.2249
#   [Ours - RandomForest]
#     AUROC: 0.7832
#     G-mean: 0.0892
#     MCC: 0.0287
#     F1-score: 0.0471
#     mAP: 0.1928
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/solar_flare_m0_results_gaussian_beta_0.05.csv
# beta: 0.01
# Dataset loaded: solar_flare_m0
# X shape : (1389, 32)
# target : Counter({0: 1321, 1: 68})
# IR: 19.43
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.6883
#     G-mean: 0.5179
#     MCC: 0.1210
#     F1-score: 0.1657
#     mAP: 0.1816
#   [Ours - DecisionTree]
#     AUROC: 0.6740
#     G-mean: 0.1817
#     MCC: 0.1127
#     F1-score: 0.1222
#     mAP: 0.1719
#   [Ours - kNN]
#     AUROC: 0.6642
#     G-mean: 0.4650
#     MCC: 0.1869
#     F1-score: 0.2262
#     mAP: 0.1347
#   [Ours - MLP]
#     AUROC: 0.7171
#     G-mean: 0.5461
#     MCC: 0.1732
#     F1-score: 0.2125
#     mAP: 0.1935
#   [Ours - RandomForest]
#     AUROC: 0.7922
#     G-mean: 0.1532
#     MCC: 0.0793
#     F1-score: 0.0854
#     mAP: 0.1981
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.6862
#     G-mean: 0.5466
#     MCC: 0.1396
#     F1-score: 0.1815
#     mAP: 0.1842
#   [Ours - DecisionTree]
#     AUROC: 0.7038
#     G-mean: 0.1819
#     MCC: 0.1290
#     F1-score: 0.1270
#     mAP: 0.1983
#   [Ours - kNN]
#     AUROC: 0.6660
#     G-mean: 0.4278
#     MCC: 0.1830
#     F1-score: 0.2228
#     mAP: 0.1554
#   [Ours - MLP]
#     AUROC: 0.7275
#     G-mean: 0.5630
#     MCC: 0.1772
#     F1-score: 0.2152
#     mAP: 0.2097
#   [Ours - RandomForest]
#     AUROC: 0.7892
#     G-mean: 0.0954
#     MCC: 0.0387
#     F1-score: 0.0527
#     mAP: 0.1981
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.6799
#     G-mean: 0.5539
#     MCC: 0.1405
#     F1-score: 0.1820
#     mAP: 0.1646
#   [Ours - DecisionTree]
#     AUROC: 0.6835
#     G-mean: 0.2147
#     MCC: 0.1456
#     F1-score: 0.1388
#     mAP: 0.1911
#   [Ours - kNN]
#     AUROC: 0.6653
#     G-mean: 0.3965
#     MCC: 0.1610
#     F1-score: 0.2014
#     mAP: 0.1486
#   [Ours - MLP]
#     AUROC: 0.7228
#     G-mean: 0.5211
#     MCC: 0.1538
#     F1-score: 0.1950
#     mAP: 0.1905
#   [Ours - RandomForest]
#     AUROC: 0.7870
#     G-mean: 0.0936
#     MCC: 0.0354
#     F1-score: 0.0521
#     mAP: 0.1934
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.6773
#     G-mean: 0.5540
#     MCC: 0.1466
#     F1-score: 0.1865
#     mAP: 0.1674
#   [Ours - DecisionTree]
#     AUROC: 0.6869
#     G-mean: 0.2097
#     MCC: 0.1436
#     F1-score: 0.1340
#     mAP: 0.1931
#   [Ours - kNN]
#     AUROC: 0.6659
#     G-mean: 0.4036
#     MCC: 0.1658
#     F1-score: 0.2054
#     mAP: 0.1488
#   [Ours - MLP]
#     AUROC: 0.7193
#     G-mean: 0.5232
#     MCC: 0.1650
#     F1-score: 0.2045
#     mAP: 0.1925
#   [Ours - RandomForest]
#     AUROC: 0.7753
#     G-mean: 0.0990
#     MCC: 0.0372
#     F1-score: 0.0540
#     mAP: 0.1937
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.6815
#     G-mean: 0.5472
#     MCC: 0.1433
#     F1-score: 0.1838
#     mAP: 0.1637
#   [Ours - DecisionTree]
#     AUROC: 0.6802
#     G-mean: 0.1985
#     MCC: 0.1359
#     F1-score: 0.1260
#     mAP: 0.1928
#   [Ours - kNN]
#     AUROC: 0.6704
#     G-mean: 0.4126
#     MCC: 0.1687
#     F1-score: 0.2086
#     mAP: 0.1509
#   [Ours - MLP]
#     AUROC: 0.7223
#     G-mean: 0.5236
#     MCC: 0.1689
#     F1-score: 0.2076
#     mAP: 0.1928
#   [Ours - RandomForest]
#     AUROC: 0.7799
#     G-mean: 0.0947
#     MCC: 0.0324
#     F1-score: 0.0505
#     mAP: 0.1916
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.6840
#     G-mean: 0.5552
#     MCC: 0.1497
#     F1-score: 0.1891
#     mAP: 0.1676
#   [Ours - DecisionTree]
#     AUROC: 0.6804
#     G-mean: 0.1869
#     MCC: 0.1274
#     F1-score: 0.1199
#     mAP: 0.1912
#   [Ours - kNN]
#     AUROC: 0.6711
#     G-mean: 0.4060
#     MCC: 0.1673
#     F1-score: 0.2063
#     mAP: 0.1521
#   [Ours - MLP]
#     AUROC: 0.7205
#     G-mean: 0.5321
#     MCC: 0.1759
#     F1-score: 0.2145
#     mAP: 0.1937
#   [Ours - RandomForest]
#     AUROC: 0.7825
#     G-mean: 0.0915
#     MCC: 0.0310
#     F1-score: 0.0491
#     mAP: 0.1930
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.6831
#     G-mean: 0.5521
#     MCC: 0.1447
#     F1-score: 0.1847
#     mAP: 0.1610
#   [Ours - DecisionTree]
#     AUROC: 0.6833
#     G-mean: 0.1842
#     MCC: 0.1229
#     F1-score: 0.1170
#     mAP: 0.1903
#   [Ours - kNN]
#     AUROC: 0.6691
#     G-mean: 0.4067
#     MCC: 0.1642
#     F1-score: 0.2035
#     mAP: 0.1483
#   [Ours - MLP]
#     AUROC: 0.7221
#     G-mean: 0.5295
#     MCC: 0.1731
#     F1-score: 0.2117
#     mAP: 0.1919
#   [Ours - RandomForest]
#     AUROC: 0.7840
#     G-mean: 0.0784
#     MCC: 0.0231
#     F1-score: 0.0421
#     mAP: 0.1925
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.6862
#     G-mean: 0.5532
#     MCC: 0.1444
#     F1-score: 0.1842
#     mAP: 0.1592
#   [Ours - DecisionTree]
#     AUROC: 0.6814
#     G-mean: 0.1842
#     MCC: 0.1200
#     F1-score: 0.1162
#     mAP: 0.1886
#   [Ours - kNN]
#     AUROC: 0.6713
#     G-mean: 0.4133
#     MCC: 0.1658
#     F1-score: 0.2044
#     mAP: 0.1480
#   [Ours - MLP]
#     AUROC: 0.7240
#     G-mean: 0.5274
#     MCC: 0.1698
#     F1-score: 0.2080
#     mAP: 0.1938
#   [Ours - RandomForest]
#     AUROC: 0.7829
#     G-mean: 0.0733
#     MCC: 0.0193
#     F1-score: 0.0389
#     mAP: 0.1894
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.6835
#     G-mean: 0.5577
#     MCC: 0.1466
#     F1-score: 0.1858
#     mAP: 0.1574
#   [Ours - DecisionTree]
#     AUROC: 0.6818
#     G-mean: 0.1821
#     MCC: 0.1172
#     F1-score: 0.1142
#     mAP: 0.1881
#   [Ours - kNN]
#     AUROC: 0.6730
#     G-mean: 0.4187
#     MCC: 0.1689
#     F1-score: 0.2079
#     mAP: 0.1510
#   [Ours - MLP]
#     AUROC: 0.7226
#     G-mean: 0.5334
#     MCC: 0.1734
#     F1-score: 0.2117
#     mAP: 0.1975
#   [Ours - RandomForest]
#     AUROC: 0.7831
#     G-mean: 0.0734
#     MCC: 0.0194
#     F1-score: 0.0389
#     mAP: 0.1909
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.6844
#     G-mean: 0.5615
#     MCC: 0.1480
#     F1-score: 0.1867
#     mAP: 0.1561
#   [Ours - DecisionTree]
#     AUROC: 0.6857
#     G-mean: 0.1830
#     MCC: 0.1153
#     F1-score: 0.1131
#     mAP: 0.1888
#   [Ours - kNN]
#     AUROC: 0.6740
#     G-mean: 0.4255
#     MCC: 0.1725
#     F1-score: 0.2112
#     mAP: 0.1545
#   [Ours - MLP]
#     AUROC: 0.7227
#     G-mean: 0.5319
#     MCC: 0.1726
#     F1-score: 0.2107
#     mAP: 0.1995
#   [Ours - RandomForest]
#     AUROC: 0.7850
#     G-mean: 0.0776
#     MCC: 0.0206
#     F1-score: 0.0405
#     mAP: 0.1931
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/solar_flare_m0_results_gaussian_beta_0.01.csv
# beta: 0.005
# Dataset loaded: solar_flare_m0
# X shape : (1389, 32)
# target : Counter({0: 1321, 1: 68})
# IR: 19.43
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.6807
#     G-mean: 0.5796
#     MCC: 0.1581
#     F1-score: 0.1970
#     mAP: 0.1693
#   [Ours - DecisionTree]
#     AUROC: 0.6875
#     G-mean: 0.1817
#     MCC: 0.1175
#     F1-score: 0.1222
#     mAP: 0.2004
#   [Ours - kNN]
#     AUROC: 0.6689
#     G-mean: 0.4706
#     MCC: 0.2032
#     F1-score: 0.2429
#     mAP: 0.1421
#   [Ours - MLP]
#     AUROC: 0.7133
#     G-mean: 0.5460
#     MCC: 0.1743
#     F1-score: 0.2180
#     mAP: 0.1816
#   [Ours - RandomForest]
#     AUROC: 0.7921
#     G-mean: 0.0749
#     MCC: 0.0190
#     F1-score: 0.0382
#     mAP: 0.1960
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.6955
#     G-mean: 0.6003
#     MCC: 0.1755
#     F1-score: 0.2087
#     mAP: 0.1578
#   [Ours - DecisionTree]
#     AUROC: 0.7116
#     G-mean: 0.1424
#     MCC: 0.0968
#     F1-score: 0.1022
#     mAP: 0.1986
#   [Ours - kNN]
#     AUROC: 0.6702
#     G-mean: 0.4546
#     MCC: 0.1993
#     F1-score: 0.2394
#     mAP: 0.1558
#   [Ours - MLP]
#     AUROC: 0.7238
#     G-mean: 0.5594
#     MCC: 0.1804
#     F1-score: 0.2215
#     mAP: 0.1903
#   [Ours - RandomForest]
#     AUROC: 0.7932
#     G-mean: 0.0374
#     MCC: -0.0042
#     F1-score: 0.0191
#     mAP: 0.1965
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.6827
#     G-mean: 0.5801
#     MCC: 0.1583
#     F1-score: 0.1954
#     mAP: 0.1489
#   [Ours - DecisionTree]
#     AUROC: 0.7039
#     G-mean: 0.1753
#     MCC: 0.1149
#     F1-score: 0.1168
#     mAP: 0.1907
#   [Ours - kNN]
#     AUROC: 0.6650
#     G-mean: 0.4308
#     MCC: 0.1820
#     F1-score: 0.2225
#     mAP: 0.1529
#   [Ours - MLP]
#     AUROC: 0.7171
#     G-mean: 0.5456
#     MCC: 0.1674
#     F1-score: 0.2104
#     mAP: 0.1826
#   [Ours - RandomForest]
#     AUROC: 0.7900
#     G-mean: 0.0551
#     MCC: 0.0082
#     F1-score: 0.0304
#     mAP: 0.1909
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.6791
#     G-mean: 0.5776
#     MCC: 0.1631
#     F1-score: 0.1984
#     mAP: 0.1506
#   [Ours - DecisionTree]
#     AUROC: 0.7167
#     G-mean: 0.1894
#     MCC: 0.1217
#     F1-score: 0.1212
#     mAP: 0.1963
#   [Ours - kNN]
#     AUROC: 0.6656
#     G-mean: 0.4324
#     MCC: 0.1867
#     F1-score: 0.2258
#     mAP: 0.1540
#   [Ours - MLP]
#     AUROC: 0.7120
#     G-mean: 0.5356
#     MCC: 0.1661
#     F1-score: 0.2078
#     mAP: 0.1876
#   [Ours - RandomForest]
#     AUROC: 0.7781
#     G-mean: 0.0600
#     MCC: 0.0100
#     F1-score: 0.0316
#     mAP: 0.1891
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.6816
#     G-mean: 0.5738
#     MCC: 0.1614
#     F1-score: 0.1968
#     mAP: 0.1503
#   [Ours - DecisionTree]
#     AUROC: 0.7131
#     G-mean: 0.2004
#     MCC: 0.1295
#     F1-score: 0.1271
#     mAP: 0.1957
#   [Ours - kNN]
#     AUROC: 0.6700
#     G-mean: 0.4320
#     MCC: 0.1814
#     F1-score: 0.2207
#     mAP: 0.1502
#   [Ours - MLP]
#     AUROC: 0.7150
#     G-mean: 0.5254
#     MCC: 0.1665
#     F1-score: 0.2078
#     mAP: 0.1902
#   [Ours - RandomForest]
#     AUROC: 0.7812
#     G-mean: 0.0941
#     MCC: 0.0290
#     F1-score: 0.0492
#     mAP: 0.1898
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.6788
#     G-mean: 0.5768
#     MCC: 0.1631
#     F1-score: 0.1988
#     mAP: 0.1545
#   [Ours - DecisionTree]
#     AUROC: 0.7102
#     G-mean: 0.1966
#     MCC: 0.1258
#     F1-score: 0.1258
#     mAP: 0.1958
#   [Ours - kNN]
#     AUROC: 0.6710
#     G-mean: 0.4325
#     MCC: 0.1798
#     F1-score: 0.2187
#     mAP: 0.1490
#   [Ours - MLP]
#     AUROC: 0.7148
#     G-mean: 0.5314
#     MCC: 0.1727
#     F1-score: 0.2133
#     mAP: 0.1923
#   [Ours - RandomForest]
#     AUROC: 0.7830
#     G-mean: 0.0847
#     MCC: 0.0239
#     F1-score: 0.0443
#     mAP: 0.1906
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.6774
#     G-mean: 0.5744
#     MCC: 0.1594
#     F1-score: 0.1954
#     mAP: 0.1487
#   [Ours - DecisionTree]
#     AUROC: 0.7096
#     G-mean: 0.1890
#     MCC: 0.1178
#     F1-score: 0.1204
#     mAP: 0.1926
#   [Ours - kNN]
#     AUROC: 0.6693
#     G-mean: 0.4359
#     MCC: 0.1775
#     F1-score: 0.2170
#     mAP: 0.1454
#   [Ours - MLP]
#     AUROC: 0.7155
#     G-mean: 0.5228
#     MCC: 0.1660
#     F1-score: 0.2071
#     mAP: 0.1894
#   [Ours - RandomForest]
#     AUROC: 0.7841
#     G-mean: 0.0779
#     MCC: 0.0201
#     F1-score: 0.0408
#     mAP: 0.1903
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.6782
#     G-mean: 0.5758
#     MCC: 0.1590
#     F1-score: 0.1950
#     mAP: 0.1483
#   [Ours - DecisionTree]
#     AUROC: 0.7053
#     G-mean: 0.1798
#     MCC: 0.1113
#     F1-score: 0.1133
#     mAP: 0.1913
#   [Ours - kNN]
#     AUROC: 0.6719
#     G-mean: 0.4425
#     MCC: 0.1801
#     F1-score: 0.2186
#     mAP: 0.1448
#   [Ours - MLP]
#     AUROC: 0.7172
#     G-mean: 0.5249
#     MCC: 0.1656
#     F1-score: 0.2066
#     mAP: 0.1882
#   [Ours - RandomForest]
#     AUROC: 0.7839
#     G-mean: 0.0728
#     MCC: 0.0167
#     F1-score: 0.0378
#     mAP: 0.1878
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.6755
#     G-mean: 0.5738
#     MCC: 0.1552
#     F1-score: 0.1918
#     mAP: 0.1461
#   [Ours - DecisionTree]
#     AUROC: 0.6978
#     G-mean: 0.1811
#     MCC: 0.1142
#     F1-score: 0.1141
#     mAP: 0.1896
#   [Ours - kNN]
#     AUROC: 0.6732
#     G-mean: 0.4416
#     MCC: 0.1795
#     F1-score: 0.2186
#     mAP: 0.1466
#   [Ours - MLP]
#     AUROC: 0.7178
#     G-mean: 0.5278
#     MCC: 0.1687
#     F1-score: 0.2092
#     mAP: 0.1899
#   [Ours - RandomForest]
#     AUROC: 0.7851
#     G-mean: 0.0731
#     MCC: 0.0169
#     F1-score: 0.0379
#     mAP: 0.1900
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.6788
#     G-mean: 0.5787
#     MCC: 0.1584
#     F1-score: 0.1940
#     mAP: 0.1466
#   [Ours - DecisionTree]
#     AUROC: 0.6981
#     G-mean: 0.1861
#     MCC: 0.1167
#     F1-score: 0.1158
#     mAP: 0.1892
#   [Ours - kNN]
#     AUROC: 0.6735
#     G-mean: 0.4475
#     MCC: 0.1826
#     F1-score: 0.2214
#     mAP: 0.1496
#   [Ours - MLP]
#     AUROC: 0.7181
#     G-mean: 0.5294
#     MCC: 0.1699
#     F1-score: 0.2103
#     mAP: 0.1902
#   [Ours - RandomForest]
#     AUROC: 0.7870
#     G-mean: 0.0772
#     MCC: 0.0183
#     F1-score: 0.0396
#     mAP: 0.1923
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/solar_flare_m0_results_gaussian_beta_0.005.csv
# beta: 0.001
# Dataset loaded: solar_flare_m0
# X shape : (1389, 32)
# target : Counter({0: 1321, 1: 68})
# IR: 19.43
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.6765
#     G-mean: 0.6022
#     MCC: 0.1900
#     F1-score: 0.2256
#     mAP: 0.1703
#   [Ours - DecisionTree]
#     AUROC: 0.7287
#     G-mean: 0.1661
#     MCC: 0.1109
#     F1-score: 0.1054
#     mAP: 0.2029
#   [Ours - kNN]
#     AUROC: 0.6673
#     G-mean: 0.4562
#     MCC: 0.2048
#     F1-score: 0.2422
#     mAP: 0.1596
#   [Ours - MLP]
#     AUROC: 0.7167
#     G-mean: 0.5175
#     MCC: 0.1910
#     F1-score: 0.2335
#     mAP: 0.2198
#   [Ours - RandomForest]
#     AUROC: 0.7913
#     G-mean: 0.0780
#     MCC: 0.0240
#     F1-score: 0.0422
#     mAP: 0.1981
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.6847
#     G-mean: 0.6188
#     MCC: 0.2032
#     F1-score: 0.2333
#     mAP: 0.1654
#   [Ours - DecisionTree]
#     AUROC: 0.7225
#     G-mean: 0.1474
#     MCC: 0.1009
#     F1-score: 0.0972
#     mAP: 0.1903
#   [Ours - kNN]
#     AUROC: 0.6774
#     G-mean: 0.4254
#     MCC: 0.2011
#     F1-score: 0.2394
#     mAP: 0.1759
#   [Ours - MLP]
#     AUROC: 0.7285
#     G-mean: 0.5255
#     MCC: 0.1938
#     F1-score: 0.2317
#     mAP: 0.2198
#   [Ours - RandomForest]
#     AUROC: 0.7916
#     G-mean: 0.0577
#     MCC: 0.0117
#     F1-score: 0.0311
#     mAP: 0.1961
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.6753
#     G-mean: 0.5872
#     MCC: 0.1782
#     F1-score: 0.2126
#     mAP: 0.1523
#   [Ours - DecisionTree]
#     AUROC: 0.6929
#     G-mean: 0.1785
#     MCC: 0.1127
#     F1-score: 0.1109
#     mAP: 0.1749
#   [Ours - kNN]
#     AUROC: 0.6690
#     G-mean: 0.4211
#     MCC: 0.1894
#     F1-score: 0.2279
#     mAP: 0.1612
#   [Ours - MLP]
#     AUROC: 0.7193
#     G-mean: 0.4989
#     MCC: 0.1656
#     F1-score: 0.2071
#     mAP: 0.1995
#   [Ours - RandomForest]
#     AUROC: 0.7908
#     G-mean: 0.0686
#     MCC: 0.0182
#     F1-score: 0.0385
#     mAP: 0.1913
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.6744
#     G-mean: 0.5740
#     MCC: 0.1739
#     F1-score: 0.2080
#     mAP: 0.1591
#   [Ours - DecisionTree]
#     AUROC: 0.6950
#     G-mean: 0.2011
#     MCC: 0.1271
#     F1-score: 0.1216
#     mAP: 0.1782
#   [Ours - kNN]
#     AUROC: 0.6709
#     G-mean: 0.4344
#     MCC: 0.1968
#     F1-score: 0.2348
#     mAP: 0.1588
#   [Ours - MLP]
#     AUROC: 0.7130
#     G-mean: 0.4946
#     MCC: 0.1687
#     F1-score: 0.2091
#     mAP: 0.2016
#   [Ours - RandomForest]
#     AUROC: 0.7832
#     G-mean: 0.0607
#     MCC: 0.0121
#     F1-score: 0.0327
#     mAP: 0.1902
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.6745
#     G-mean: 0.5678
#     MCC: 0.1710
#     F1-score: 0.2059
#     mAP: 0.1565
#   [Ours - DecisionTree]
#     AUROC: 0.7005
#     G-mean: 0.2062
#     MCC: 0.1332
#     F1-score: 0.1280
#     mAP: 0.1840
#   [Ours - kNN]
#     AUROC: 0.6757
#     G-mean: 0.4296
#     MCC: 0.1888
#     F1-score: 0.2274
#     mAP: 0.1571
#   [Ours - MLP]
#     AUROC: 0.7122
#     G-mean: 0.5029
#     MCC: 0.1745
#     F1-score: 0.2146
#     mAP: 0.2046
#   [Ours - RandomForest]
#     AUROC: 0.7838
#     G-mean: 0.0797
#     MCC: 0.0220
#     F1-score: 0.0424
#     mAP: 0.1888
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.6757
#     G-mean: 0.5730
#     MCC: 0.1751
#     F1-score: 0.2097
#     mAP: 0.1601
#   [Ours - DecisionTree]
#     AUROC: 0.6976
#     G-mean: 0.1906
#     MCC: 0.1190
#     F1-score: 0.1171
#     mAP: 0.1823
#   [Ours - kNN]
#     AUROC: 0.6746
#     G-mean: 0.4338
#     MCC: 0.1919
#     F1-score: 0.2306
#     mAP: 0.1589
#   [Ours - MLP]
#     AUROC: 0.7137
#     G-mean: 0.5114
#     MCC: 0.1803
#     F1-score: 0.2204
#     mAP: 0.2050
#   [Ours - RandomForest]
#     AUROC: 0.7851
#     G-mean: 0.0851
#     MCC: 0.0237
#     F1-score: 0.0445
#     mAP: 0.1898
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.6778
#     G-mean: 0.5731
#     MCC: 0.1724
#     F1-score: 0.2073
#     mAP: 0.1559
#   [Ours - DecisionTree]
#     AUROC: 0.7002
#     G-mean: 0.1816
#     MCC: 0.1102
#     F1-score: 0.1106
#     mAP: 0.1805
#   [Ours - kNN]
#     AUROC: 0.6708
#     G-mean: 0.4304
#     MCC: 0.1829
#     F1-score: 0.2219
#     mAP: 0.1530
#   [Ours - MLP]
#     AUROC: 0.7158
#     G-mean: 0.5094
#     MCC: 0.1761
#     F1-score: 0.2161
#     mAP: 0.2003
#   [Ours - RandomForest]
#     AUROC: 0.7855
#     G-mean: 0.0783
#     MCC: 0.0200
#     F1-score: 0.0410
#     mAP: 0.1887
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.6807
#     G-mean: 0.5770
#     MCC: 0.1744
#     F1-score: 0.2090
#     mAP: 0.1550
#   [Ours - DecisionTree]
#     AUROC: 0.6998
#     G-mean: 0.1878
#     MCC: 0.1120
#     F1-score: 0.1126
#     mAP: 0.1812
#   [Ours - kNN]
#     AUROC: 0.6724
#     G-mean: 0.4384
#     MCC: 0.1849
#     F1-score: 0.2239
#     mAP: 0.1526
#   [Ours - MLP]
#     AUROC: 0.7159
#     G-mean: 0.5073
#     MCC: 0.1738
#     F1-score: 0.2139
#     mAP: 0.1970
#   [Ours - RandomForest]
#     AUROC: 0.7853
#     G-mean: 0.0779
#     MCC: 0.0203
#     F1-score: 0.0409
#     mAP: 0.1876
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.6809
#     G-mean: 0.5781
#     MCC: 0.1731
#     F1-score: 0.2079
#     mAP: 0.1528
#   [Ours - DecisionTree]
#     AUROC: 0.6936
#     G-mean: 0.1753
#     MCC: 0.1040
#     F1-score: 0.1054
#     mAP: 0.1777
#   [Ours - kNN]
#     AUROC: 0.6740
#     G-mean: 0.4429
#     MCC: 0.1887
#     F1-score: 0.2275
#     mAP: 0.1546
#   [Ours - MLP]
#     AUROC: 0.7165
#     G-mean: 0.5085
#     MCC: 0.1722
#     F1-score: 0.2121
#     mAP: 0.2014
#   [Ours - RandomForest]
#     AUROC: 0.7855
#     G-mean: 0.0818
#     MCC: 0.0243
#     F1-score: 0.0434
#     mAP: 0.1898
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.6820
#     G-mean: 0.5792
#     MCC: 0.1735
#     F1-score: 0.2082
#     mAP: 0.1525
#   [Ours - DecisionTree]
#     AUROC: 0.6969
#     G-mean: 0.1810
#     MCC: 0.1090
#     F1-score: 0.1084
#     mAP: 0.1804
#   [Ours - kNN]
#     AUROC: 0.6747
#     G-mean: 0.4450
#     MCC: 0.1886
#     F1-score: 0.2273
#     mAP: 0.1568
#   [Ours - MLP]
#     AUROC: 0.7165
#     G-mean: 0.5084
#     MCC: 0.1710
#     F1-score: 0.2115
#     mAP: 0.2013
#   [Ours - RandomForest]
#     AUROC: 0.7866
#     G-mean: 0.0814
#     MCC: 0.0231
#     F1-score: 0.0427
#     mAP: 0.1914
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/solar_flare_m0_results_gaussian_beta_0.001.csv
# beta: 0.0
# Dataset loaded: solar_flare_m0
# X shape : (1389, 32)
# target : Counter({0: 1321, 1: 68})
# IR: 19.43
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.6709
#     G-mean: 0.5747
#     MCC: 0.1660
#     F1-score: 0.2045
#     mAP: 0.1844
#   [Ours - DecisionTree]
#     AUROC: 0.7223
#     G-mean: 0.2037
#     MCC: 0.1332
#     F1-score: 0.1276
#     mAP: 0.1991
#   [Ours - kNN]
#     AUROC: 0.6669
#     G-mean: 0.4553
#     MCC: 0.1943
#     F1-score: 0.2317
#     mAP: 0.1640
#   [Ours - MLP]
#     AUROC: 0.7312
#     G-mean: 0.5608
#     MCC: 0.2049
#     F1-score: 0.2440
#     mAP: 0.2123
#   [Ours - RandomForest]
#     AUROC: 0.7880
#     G-mean: 0.0405
#     MCC: 0.0020
#     F1-score: 0.0222
#     mAP: 0.2009
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.6805
#     G-mean: 0.6019
#     MCC: 0.1971
#     F1-score: 0.2299
#     mAP: 0.1759
#   [Ours - DecisionTree]
#     AUROC: 0.7219
#     G-mean: 0.1663
#     MCC: 0.1098
#     F1-score: 0.1082
#     mAP: 0.1894
#   [Ours - kNN]
#     AUROC: 0.6729
#     G-mean: 0.4052
#     MCC: 0.1870
#     F1-score: 0.2254
#     mAP: 0.1723
#   [Ours - MLP]
#     AUROC: 0.7329
#     G-mean: 0.5601
#     MCC: 0.2122
#     F1-score: 0.2474
#     mAP: 0.2089
#   [Ours - RandomForest]
#     AUROC: 0.7894
#     G-mean: 0.0390
#     MCC: -0.0006
#     F1-score: 0.0211
#     mAP: 0.2005
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.6691
#     G-mean: 0.5770
#     MCC: 0.1746
#     F1-score: 0.2109
#     mAP: 0.1603
#   [Ours - DecisionTree]
#     AUROC: 0.7047
#     G-mean: 0.1786
#     MCC: 0.1161
#     F1-score: 0.1135
#     mAP: 0.1802
#   [Ours - kNN]
#     AUROC: 0.6675
#     G-mean: 0.4073
#     MCC: 0.1760
#     F1-score: 0.2154
#     mAP: 0.1579
#   [Ours - MLP]
#     AUROC: 0.7239
#     G-mean: 0.5135
#     MCC: 0.1787
#     F1-score: 0.2183
#     mAP: 0.1985
#   [Ours - RandomForest]
#     AUROC: 0.7890
#     G-mean: 0.0561
#     MCC: 0.0100
#     F1-score: 0.0318
#     mAP: 0.1944
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.6684
#     G-mean: 0.5656
#     MCC: 0.1709
#     F1-score: 0.2070
#     mAP: 0.1632
#   [Ours - DecisionTree]
#     AUROC: 0.7088
#     G-mean: 0.2105
#     MCC: 0.1327
#     F1-score: 0.1280
#     mAP: 0.1852
#   [Ours - kNN]
#     AUROC: 0.6661
#     G-mean: 0.4215
#     MCC: 0.1836
#     F1-score: 0.2224
#     mAP: 0.1558
#   [Ours - MLP]
#     AUROC: 0.7199
#     G-mean: 0.5119
#     MCC: 0.1807
#     F1-score: 0.2178
#     mAP: 0.2037
#   [Ours - RandomForest]
#     AUROC: 0.7777
#     G-mean: 0.0514
#     MCC: 0.0059
#     F1-score: 0.0277
#     mAP: 0.1918
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.6690
#     G-mean: 0.5618
#     MCC: 0.1711
#     F1-score: 0.2076
#     mAP: 0.1600
#   [Ours - DecisionTree]
#     AUROC: 0.7050
#     G-mean: 0.2286
#     MCC: 0.1424
#     F1-score: 0.1389
#     mAP: 0.1876
#   [Ours - kNN]
#     AUROC: 0.6750
#     G-mean: 0.4194
#     MCC: 0.1801
#     F1-score: 0.2188
#     mAP: 0.1582
#   [Ours - MLP]
#     AUROC: 0.7184
#     G-mean: 0.5128
#     MCC: 0.1871
#     F1-score: 0.2247
#     mAP: 0.2055
#   [Ours - RandomForest]
#     AUROC: 0.7801
#     G-mean: 0.0647
#     MCC: 0.0129
#     F1-score: 0.0344
#     mAP: 0.1902
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.6732
#     G-mean: 0.5684
#     MCC: 0.1767
#     F1-score: 0.2127
#     mAP: 0.1635
#   [Ours - DecisionTree]
#     AUROC: 0.7058
#     G-mean: 0.2229
#     MCC: 0.1426
#     F1-score: 0.1402
#     mAP: 0.1957
#   [Ours - kNN]
#     AUROC: 0.6755
#     G-mean: 0.4294
#     MCC: 0.1902
#     F1-score: 0.2287
#     mAP: 0.1622
#   [Ours - MLP]
#     AUROC: 0.7184
#     G-mean: 0.5172
#     MCC: 0.1923
#     F1-score: 0.2302
#     mAP: 0.2055
#   [Ours - RandomForest]
#     AUROC: 0.7802
#     G-mean: 0.0602
#     MCC: 0.0100
#     F1-score: 0.0320
#     mAP: 0.1904
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.6751
#     G-mean: 0.5638
#     MCC: 0.1706
#     F1-score: 0.2076
#     mAP: 0.1597
#   [Ours - DecisionTree]
#     AUROC: 0.7035
#     G-mean: 0.2115
#     MCC: 0.1327
#     F1-score: 0.1327
#     mAP: 0.1919
#   [Ours - kNN]
#     AUROC: 0.6740
#     G-mean: 0.4289
#     MCC: 0.1844
#     F1-score: 0.2226
#     mAP: 0.1575
#   [Ours - MLP]
#     AUROC: 0.7193
#     G-mean: 0.5172
#     MCC: 0.1866
#     F1-score: 0.2251
#     mAP: 0.2009
#   [Ours - RandomForest]
#     AUROC: 0.7819
#     G-mean: 0.0569
#     MCC: 0.0073
#     F1-score: 0.0296
#     mAP: 0.1904
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.6787
#     G-mean: 0.5625
#     MCC: 0.1682
#     F1-score: 0.2053
#     mAP: 0.1586
#   [Ours - DecisionTree]
#     AUROC: 0.6964
#     G-mean: 0.2018
#     MCC: 0.1245
#     F1-score: 0.1257
#     mAP: 0.1892
#   [Ours - kNN]
#     AUROC: 0.6762
#     G-mean: 0.4304
#     MCC: 0.1846
#     F1-score: 0.2229
#     mAP: 0.1561
#   [Ours - MLP]
#     AUROC: 0.7198
#     G-mean: 0.5163
#     MCC: 0.1865
#     F1-score: 0.2250
#     mAP: 0.2006
#   [Ours - RandomForest]
#     AUROC: 0.7821
#     G-mean: 0.0592
#     MCC: 0.0097
#     F1-score: 0.0312
#     mAP: 0.1880
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.6792
#     G-mean: 0.5656
#     MCC: 0.1685
#     F1-score: 0.2055
#     mAP: 0.1568
#   [Ours - DecisionTree]
#     AUROC: 0.6939
#     G-mean: 0.1961
#     MCC: 0.1205
#     F1-score: 0.1215
#     mAP: 0.1895
#   [Ours - kNN]
#     AUROC: 0.6769
#     G-mean: 0.4329
#     MCC: 0.1870
#     F1-score: 0.2255
#     mAP: 0.1555
#   [Ours - MLP]
#     AUROC: 0.7200
#     G-mean: 0.5136
#     MCC: 0.1846
#     F1-score: 0.2235
#     mAP: 0.2046
#   [Ours - RandomForest]
#     AUROC: 0.7828
#     G-mean: 0.0609
#     MCC: 0.0106
#     F1-score: 0.0320
#     mAP: 0.1899
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.6806
#     G-mean: 0.5671
#     MCC: 0.1690
#     F1-score: 0.2059
#     mAP: 0.1564
#   [Ours - DecisionTree]
#     AUROC: 0.6959
#     G-mean: 0.1996
#     MCC: 0.1220
#     F1-score: 0.1224
#     mAP: 0.1879
#   [Ours - kNN]
#     AUROC: 0.6773
#     G-mean: 0.4370
#     MCC: 0.1880
#     F1-score: 0.2261
#     mAP: 0.1574
#   [Ours - MLP]
#     AUROC: 0.7205
#     G-mean: 0.5067
#     MCC: 0.1782
#     F1-score: 0.2179
#     mAP: 0.2051
#   [Ours - RandomForest]
#     AUROC: 0.7840
#     G-mean: 0.0626
#     MCC: 0.0107
#     F1-score: 0.0324
#     mAP: 0.1915
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/solar_flare_m0_results_gaussian_beta_0.0.csv

# %%
data_name = 'abalone19'

n_epochs = 2000
hidden_dims = [16, 32, 64, 128]
latent_dim = 256
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        cat_idx=[0],
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )
# Out:
# beta: 0.1
# Dataset loaded from DataFrame
# X shape : (4174, 8)
# target : Counter({0: 4142, 1: 32})
# IR: 129.44
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.8132
#     G-mean: 0.6579
#     MCC: 0.1024
#     F1-score: 0.0593
#     mAP: 0.0875
#   [Ours - DecisionTree]
#     AUROC: 0.6573
#     G-mean: 0.0000
#     MCC: -0.0031
#     F1-score: 0.0000
#     mAP: 0.0279
#   [Ours - kNN]
#     AUROC: 0.6049
#     G-mean: 0.1148
#     MCC: 0.0397
#     F1-score: 0.0450
#     mAP: 0.0286
#   [Ours - MLP]
#     AUROC: 0.8269
#     G-mean: 0.3201
#     MCC: 0.0822
#     F1-score: 0.0724
#     mAP: 0.0748
#   [Ours - RandomForest]
#     AUROC: 0.7338
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0504
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.8054
#     G-mean: 0.6823
#     MCC: 0.1114
#     F1-score: 0.0625
#     mAP: 0.0779
#   [Ours - DecisionTree]
#     AUROC: 0.6965
#     G-mean: 0.0567
#     MCC: 0.0111
#     F1-score: 0.0106
#     mAP: 0.0283
#   [Ours - kNN]
#     AUROC: 0.6089
#     G-mean: 0.0574
#     MCC: 0.0155
#     F1-score: 0.0225
#     mAP: 0.0293
#   [Ours - MLP]
#     AUROC: 0.8216
#     G-mean: 0.3098
#     MCC: 0.0825
#     F1-score: 0.0755
#     mAP: 0.0754
#   [Ours - RandomForest]
#     AUROC: 0.7380
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0519
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.8005
#     G-mean: 0.6281
#     MCC: 0.1064
#     F1-score: 0.0617
#     mAP: 0.0987
#   [Ours - DecisionTree]
#     AUROC: 0.6925
#     G-mean: 0.0378
#     MCC: 0.0065
#     F1-score: 0.0071
#     mAP: 0.0289
#   [Ours - kNN]
#     AUROC: 0.5870
#     G-mean: 0.0383
#     MCC: 0.0073
#     F1-score: 0.0150
#     mAP: 0.0262
#   [Ours - MLP]
#     AUROC: 0.8153
#     G-mean: 0.2688
#     MCC: 0.0738
#     F1-score: 0.0704
#     mAP: 0.0729
#   [Ours - RandomForest]
#     AUROC: 0.7344
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0500
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.7986
#     G-mean: 0.6295
#     MCC: 0.1067
#     F1-score: 0.0616
#     mAP: 0.0929
#   [Ours - DecisionTree]
#     AUROC: 0.6837
#     G-mean: 0.0284
#     MCC: 0.0039
#     F1-score: 0.0053
#     mAP: 0.0259
#   [Ours - kNN]
#     AUROC: 0.5797
#     G-mean: 0.0287
#     MCC: 0.0035
#     F1-score: 0.0112
#     mAP: 0.0256
#   [Ours - MLP]
#     AUROC: 0.8184
#     G-mean: 0.2705
#     MCC: 0.0695
#     F1-score: 0.0664
#     mAP: 0.0714
#   [Ours - RandomForest]
#     AUROC: 0.7379
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0460
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.7963
#     G-mean: 0.6312
#     MCC: 0.1070
#     F1-score: 0.0618
#     mAP: 0.0859
#   [Ours - DecisionTree]
#     AUROC: 0.6802
#     G-mean: 0.0227
#     MCC: 0.0029
#     F1-score: 0.0043
#     mAP: 0.0282
#   [Ours - kNN]
#     AUROC: 0.5786
#     G-mean: 0.0344
#     MCC: 0.0058
#     F1-score: 0.0134
#     mAP: 0.0260
#   [Ours - MLP]
#     AUROC: 0.8205
#     G-mean: 0.2642
#     MCC: 0.0656
#     F1-score: 0.0627
#     mAP: 0.0721
#   [Ours - RandomForest]
#     AUROC: 0.7353
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0453
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.7985
#     G-mean: 0.6407
#     MCC: 0.1086
#     F1-score: 0.0624
#     mAP: 0.0822
#   [Ours - DecisionTree]
#     AUROC: 0.6953
#     G-mean: 0.0189
#     MCC: 0.0016
#     F1-score: 0.0035
#     mAP: 0.0284
#   [Ours - kNN]
#     AUROC: 0.5777
#     G-mean: 0.0383
#     MCC: 0.0074
#     F1-score: 0.0149
#     mAP: 0.0255
#   [Ours - MLP]
#     AUROC: 0.8201
#     G-mean: 0.2783
#     MCC: 0.0709
#     F1-score: 0.0657
#     mAP: 0.0730
#   [Ours - RandomForest]
#     AUROC: 0.7333
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0433
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.7964
#     G-mean: 0.6303
#     MCC: 0.1061
#     F1-score: 0.0611
#     mAP: 0.0773
#   [Ours - DecisionTree]
#     AUROC: 0.6916
#     G-mean: 0.0162
#     MCC: 0.0011
#     F1-score: 0.0030
#     mAP: 0.0291
#   [Ours - kNN]
#     AUROC: 0.5769
#     G-mean: 0.0328
#     MCC: 0.0051
#     F1-score: 0.0128
#     mAP: 0.0254
#   [Ours - MLP]
#     AUROC: 0.8201
#     G-mean: 0.2849
#     MCC: 0.0699
#     F1-score: 0.0645
#     mAP: 0.0731
#   [Ours - RandomForest]
#     AUROC: 0.7361
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0428
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.7932
#     G-mean: 0.6244
#     MCC: 0.1046
#     F1-score: 0.0602
#     mAP: 0.0742
#   [Ours - DecisionTree]
#     AUROC: 0.6991
#     G-mean: 0.0142
#     MCC: 0.0004
#     F1-score: 0.0027
#     mAP: 0.0289
#   [Ours - kNN]
#     AUROC: 0.5748
#     G-mean: 0.0287
#     MCC: 0.0035
#     F1-score: 0.0112
#     mAP: 0.0245
#   [Ours - MLP]
#     AUROC: 0.8196
#     G-mean: 0.2705
#     MCC: 0.0657
#     F1-score: 0.0613
#     mAP: 0.0721
#   [Ours - RandomForest]
#     AUROC: 0.7372
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0425
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.7909
#     G-mean: 0.6151
#     MCC: 0.1035
#     F1-score: 0.0595
#     mAP: 0.0710
#   [Ours - DecisionTree]
#     AUROC: 0.7035
#     G-mean: 0.0126
#     MCC: 0.0000
#     F1-score: 0.0024
#     mAP: 0.0293
#   [Ours - kNN]
#     AUROC: 0.5725
#     G-mean: 0.0255
#     MCC: 0.0020
#     F1-score: 0.0099
#     mAP: 0.0235
#   [Ours - MLP]
#     AUROC: 0.8165
#     G-mean: 0.2703
#     MCC: 0.0655
#     F1-score: 0.0616
#     mAP: 0.0720
#   [Ours - RandomForest]
#     AUROC: 0.7389
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0415
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.7897
#     G-mean: 0.6127
#     MCC: 0.1020
#     F1-score: 0.0588
#     mAP: 0.0711
#   [Ours - DecisionTree]
#     AUROC: 0.6967
#     G-mean: 0.0170
#     MCC: 0.0012
#     F1-score: 0.0034
#     mAP: 0.0299
#   [Ours - kNN]
#     AUROC: 0.5704
#     G-mean: 0.0279
#     MCC: 0.0032
#     F1-score: 0.0112
#     mAP: 0.0232
#   [Ours - MLP]
#     AUROC: 0.8185
#     G-mean: 0.2758
#     MCC: 0.0662
#     F1-score: 0.0623
#     mAP: 0.0729
#   [Ours - RandomForest]
#     AUROC: 0.7415
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0414
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/abalone19_results_gaussian_beta_0.1.csv
# beta: 0.05
# Dataset loaded from DataFrame
# X shape : (4174, 8)
# target : Counter({0: 4142, 1: 32})
# IR: 129.44
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.7844
#     G-mean: 0.6756
#     MCC: 0.1061
#     F1-score: 0.0603
#     mAP: 0.0627
#   [Ours - DecisionTree]
#     AUROC: 0.6622
#     G-mean: 0.0000
#     MCC: -0.0018
#     F1-score: 0.0000
#     mAP: 0.0240
#   [Ours - kNN]
#     AUROC: 0.6260
#     G-mean: 0.2206
#     MCC: 0.0599
#     F1-score: 0.0621
#     mAP: 0.0354
#   [Ours - MLP]
#     AUROC: 0.8089
#     G-mean: 0.3089
#     MCC: 0.0636
#     F1-score: 0.0554
#     mAP: 0.0695
#   [Ours - RandomForest]
#     AUROC: 0.7382
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0382
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.7817
#     G-mean: 0.6896
#     MCC: 0.1103
#     F1-score: 0.0609
#     mAP: 0.0585
#   [Ours - DecisionTree]
#     AUROC: 0.6939
#     G-mean: 0.0000
#     MCC: -0.0024
#     F1-score: 0.0000
#     mAP: 0.0262
#   [Ours - kNN]
#     AUROC: 0.6213
#     G-mean: 0.1103
#     MCC: 0.0232
#     F1-score: 0.0311
#     mAP: 0.0290
#   [Ours - MLP]
#     AUROC: 0.8032
#     G-mean: 0.2757
#     MCC: 0.0597
#     F1-score: 0.0551
#     mAP: 0.0601
#   [Ours - RandomForest]
#     AUROC: 0.7450
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0410
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.7724
#     G-mean: 0.6188
#     MCC: 0.0959
#     F1-score: 0.0550
#     mAP: 0.0677
#   [Ours - DecisionTree]
#     AUROC: 0.7046
#     G-mean: 0.0000
#     MCC: -0.0023
#     F1-score: 0.0000
#     mAP: 0.0252
#   [Ours - kNN]
#     AUROC: 0.6066
#     G-mean: 0.0927
#     MCC: 0.0190
#     F1-score: 0.0281
#     mAP: 0.0267
#   [Ours - MLP]
#     AUROC: 0.7933
#     G-mean: 0.2634
#     MCC: 0.0579
#     F1-score: 0.0547
#     mAP: 0.0667
#   [Ours - RandomForest]
#     AUROC: 0.7499
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0434
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.7756
#     G-mean: 0.6020
#     MCC: 0.0925
#     F1-score: 0.0534
#     mAP: 0.0628
#   [Ours - DecisionTree]
#     AUROC: 0.7003
#     G-mean: 0.0000
#     MCC: -0.0022
#     F1-score: 0.0000
#     mAP: 0.0244
#   [Ours - kNN]
#     AUROC: 0.6022
#     G-mean: 0.0819
#     MCC: 0.0158
#     F1-score: 0.0253
#     mAP: 0.0260
#   [Ours - MLP]
#     AUROC: 0.7940
#     G-mean: 0.2649
#     MCC: 0.0556
#     F1-score: 0.0511
#     mAP: 0.0651
#   [Ours - RandomForest]
#     AUROC: 0.7389
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0412
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.7745
#     G-mean: 0.5933
#     MCC: 0.0910
#     F1-score: 0.0529
#     mAP: 0.0596
#   [Ours - DecisionTree]
#     AUROC: 0.6748
#     G-mean: 0.0000
#     MCC: -0.0021
#     F1-score: 0.0000
#     mAP: 0.0232
#   [Ours - kNN]
#     AUROC: 0.5946
#     G-mean: 0.0655
#     MCC: 0.0099
#     F1-score: 0.0202
#     mAP: 0.0254
#   [Ours - MLP]
#     AUROC: 0.7972
#     G-mean: 0.2627
#     MCC: 0.0578
#     F1-score: 0.0535
#     mAP: 0.0674
#   [Ours - RandomForest]
#     AUROC: 0.7313
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0409
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.7722
#     G-mean: 0.5802
#     MCC: 0.0871
#     F1-score: 0.0510
#     mAP: 0.0572
#   [Ours - DecisionTree]
#     AUROC: 0.6664
#     G-mean: 0.0000
#     MCC: -0.0021
#     F1-score: 0.0000
#     mAP: 0.0226
#   [Ours - kNN]
#     AUROC: 0.5917
#     G-mean: 0.0641
#     MCC: 0.0100
#     F1-score: 0.0202
#     mAP: 0.0252
#   [Ours - MLP]
#     AUROC: 0.7949
#     G-mean: 0.2667
#     MCC: 0.0579
#     F1-score: 0.0536
#     mAP: 0.0720
#   [Ours - RandomForest]
#     AUROC: 0.7290
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0403
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.7734
#     G-mean: 0.5960
#     MCC: 0.0903
#     F1-score: 0.0522
#     mAP: 0.0559
#   [Ours - DecisionTree]
#     AUROC: 0.6713
#     G-mean: 0.0000
#     MCC: -0.0020
#     F1-score: 0.0000
#     mAP: 0.0239
#   [Ours - kNN]
#     AUROC: 0.5889
#     G-mean: 0.0550
#     MCC: 0.0067
#     F1-score: 0.0173
#     mAP: 0.0241
#   [Ours - MLP]
#     AUROC: 0.7938
#     G-mean: 0.2852
#     MCC: 0.0600
#     F1-score: 0.0546
#     mAP: 0.0732
#   [Ours - RandomForest]
#     AUROC: 0.7321
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0399
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.7737
#     G-mean: 0.5954
#     MCC: 0.0893
#     F1-score: 0.0518
#     mAP: 0.0558
#   [Ours - DecisionTree]
#     AUROC: 0.6764
#     G-mean: 0.0000
#     MCC: -0.0020
#     F1-score: 0.0000
#     mAP: 0.0235
#   [Ours - kNN]
#     AUROC: 0.5872
#     G-mean: 0.0552
#     MCC: 0.0066
#     F1-score: 0.0169
#     mAP: 0.0238
#   [Ours - MLP]
#     AUROC: 0.7949
#     G-mean: 0.2759
#     MCC: 0.0565
#     F1-score: 0.0523
#     mAP: 0.0714
#   [Ours - RandomForest]
#     AUROC: 0.7356
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0403
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.7730
#     G-mean: 0.5886
#     MCC: 0.0875
#     F1-score: 0.0508
#     mAP: 0.0536
#   [Ours - DecisionTree]
#     AUROC: 0.6780
#     G-mean: 0.0000
#     MCC: -0.0021
#     F1-score: 0.0000
#     mAP: 0.0246
#   [Ours - kNN]
#     AUROC: 0.5821
#     G-mean: 0.0546
#     MCC: 0.0060
#     F1-score: 0.0165
#     mAP: 0.0226
#   [Ours - MLP]
#     AUROC: 0.7923
#     G-mean: 0.2685
#     MCC: 0.0528
#     F1-score: 0.0499
#     mAP: 0.0705
#   [Ours - RandomForest]
#     AUROC: 0.7341
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0396
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.7742
#     G-mean: 0.5874
#     MCC: 0.0864
#     F1-score: 0.0504
#     mAP: 0.0527
#   [Ours - DecisionTree]
#     AUROC: 0.6722
#     G-mean: 0.0000
#     MCC: -0.0022
#     F1-score: 0.0000
#     mAP: 0.0236
#   [Ours - kNN]
#     AUROC: 0.5811
#     G-mean: 0.0676
#     MCC: 0.0117
#     F1-score: 0.0216
#     mAP: 0.0238
#   [Ours - MLP]
#     AUROC: 0.7932
#     G-mean: 0.2736
#     MCC: 0.0545
#     F1-score: 0.0510
#     mAP: 0.0721
#   [Ours - RandomForest]
#     AUROC: 0.7357
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0400
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/abalone19_results_gaussian_beta_0.05.csv
# beta: 0.01
# Dataset loaded from DataFrame
# X shape : (4174, 8)
# target : Counter({0: 4142, 1: 32})
# IR: 129.44
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.7972
#     G-mean: 0.6600
#     MCC: 0.0988
#     F1-score: 0.0511
#     mAP: 0.0999
#   [Ours - DecisionTree]
#     AUROC: 0.7247
#     G-mean: 0.0000
#     MCC: -0.0032
#     F1-score: 0.0000
#     mAP: 0.0254
#   [Ours - kNN]
#     AUROC: 0.6822
#     G-mean: 0.4765
#     MCC: 0.0830
#     F1-score: 0.0610
#     mAP: 0.0420
#   [Ours - MLP]
#     AUROC: 0.8254
#     G-mean: 0.6030
#     MCC: 0.1006
#     F1-score: 0.0628
#     mAP: 0.0755
#   [Ours - RandomForest]
#     AUROC: 0.7634
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0508
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.8030
#     G-mean: 0.6710
#     MCC: 0.0975
#     F1-score: 0.0503
#     mAP: 0.1033
#   [Ours - DecisionTree]
#     AUROC: 0.7166
#     G-mean: 0.0000
#     MCC: -0.0024
#     F1-score: 0.0000
#     mAP: 0.0238
#   [Ours - kNN]
#     AUROC: 0.6616
#     G-mean: 0.4103
#     MCC: 0.0706
#     F1-score: 0.0553
#     mAP: 0.0334
#   [Ours - MLP]
#     AUROC: 0.8153
#     G-mean: 0.5492
#     MCC: 0.0946
#     F1-score: 0.0634
#     mAP: 0.0795
#   [Ours - RandomForest]
#     AUROC: 0.7634
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0505
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.7961
#     G-mean: 0.6642
#     MCC: 0.0979
#     F1-score: 0.0508
#     mAP: 0.0983
#   [Ours - DecisionTree]
#     AUROC: 0.7082
#     G-mean: 0.0000
#     MCC: -0.0025
#     F1-score: 0.0000
#     mAP: 0.0229
#   [Ours - kNN]
#     AUROC: 0.6548
#     G-mean: 0.3323
#     MCC: 0.0546
#     F1-score: 0.0463
#     mAP: 0.0331
#   [Ours - MLP]
#     AUROC: 0.8020
#     G-mean: 0.4731
#     MCC: 0.0822
#     F1-score: 0.0583
#     mAP: 0.0663
#   [Ours - RandomForest]
#     AUROC: 0.7533
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0478
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.7992
#     G-mean: 0.6746
#     MCC: 0.1008
#     F1-score: 0.0517
#     mAP: 0.0896
#   [Ours - DecisionTree]
#     AUROC: 0.7027
#     G-mean: 0.0000
#     MCC: -0.0022
#     F1-score: 0.0000
#     mAP: 0.0238
#   [Ours - kNN]
#     AUROC: 0.6478
#     G-mean: 0.3196
#     MCC: 0.0492
#     F1-score: 0.0425
#     mAP: 0.0305
#   [Ours - MLP]
#     AUROC: 0.8039
#     G-mean: 0.4771
#     MCC: 0.0813
#     F1-score: 0.0576
#     mAP: 0.0658
#   [Ours - RandomForest]
#     AUROC: 0.7530
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0454
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.7998
#     G-mean: 0.6729
#     MCC: 0.0990
#     F1-score: 0.0513
#     mAP: 0.0833
#   [Ours - DecisionTree]
#     AUROC: 0.6953
#     G-mean: 0.0000
#     MCC: -0.0021
#     F1-score: 0.0000
#     mAP: 0.0236
#   [Ours - kNN]
#     AUROC: 0.6437
#     G-mean: 0.3099
#     MCC: 0.0456
#     F1-score: 0.0404
#     mAP: 0.0291
#   [Ours - MLP]
#     AUROC: 0.8039
#     G-mean: 0.4749
#     MCC: 0.0811
#     F1-score: 0.0570
#     mAP: 0.0620
#   [Ours - RandomForest]
#     AUROC: 0.7498
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0440
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.8026
#     G-mean: 0.6794
#     MCC: 0.1001
#     F1-score: 0.0516
#     mAP: 0.0786
#   [Ours - DecisionTree]
#     AUROC: 0.6901
#     G-mean: 0.0000
#     MCC: -0.0023
#     F1-score: 0.0000
#     mAP: 0.0236
#   [Ours - kNN]
#     AUROC: 0.6473
#     G-mean: 0.3226
#     MCC: 0.0506
#     F1-score: 0.0432
#     mAP: 0.0292
#   [Ours - MLP]
#     AUROC: 0.8034
#     G-mean: 0.4619
#     MCC: 0.0786
#     F1-score: 0.0550
#     mAP: 0.0595
#   [Ours - RandomForest]
#     AUROC: 0.7540
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0455
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.8020
#     G-mean: 0.6820
#     MCC: 0.1000
#     F1-score: 0.0515
#     mAP: 0.0770
#   [Ours - DecisionTree]
#     AUROC: 0.6848
#     G-mean: 0.0000
#     MCC: -0.0024
#     F1-score: 0.0000
#     mAP: 0.0236
#   [Ours - kNN]
#     AUROC: 0.6475
#     G-mean: 0.3234
#     MCC: 0.0499
#     F1-score: 0.0429
#     mAP: 0.0283
#   [Ours - MLP]
#     AUROC: 0.8056
#     G-mean: 0.4838
#     MCC: 0.0807
#     F1-score: 0.0556
#     mAP: 0.0622
#   [Ours - RandomForest]
#     AUROC: 0.7514
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0459
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.8045
#     G-mean: 0.6849
#     MCC: 0.1007
#     F1-score: 0.0516
#     mAP: 0.0789
#   [Ours - DecisionTree]
#     AUROC: 0.6896
#     G-mean: 0.0000
#     MCC: -0.0022
#     F1-score: 0.0000
#     mAP: 0.0238
#   [Ours - kNN]
#     AUROC: 0.6591
#     G-mean: 0.3284
#     MCC: 0.0516
#     F1-score: 0.0441
#     mAP: 0.0307
#   [Ours - MLP]
#     AUROC: 0.8087
#     G-mean: 0.4886
#     MCC: 0.0821
#     F1-score: 0.0560
#     mAP: 0.0622
#   [Ours - RandomForest]
#     AUROC: 0.7515
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0456
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.8047
#     G-mean: 0.6848
#     MCC: 0.1003
#     F1-score: 0.0515
#     mAP: 0.0799
#   [Ours - DecisionTree]
#     AUROC: 0.6883
#     G-mean: 0.0000
#     MCC: -0.0023
#     F1-score: 0.0000
#     mAP: 0.0238
#   [Ours - kNN]
#     AUROC: 0.6537
#     G-mean: 0.3043
#     MCC: 0.0457
#     F1-score: 0.0406
#     mAP: 0.0295
#   [Ours - MLP]
#     AUROC: 0.8078
#     G-mean: 0.4698
#     MCC: 0.0776
#     F1-score: 0.0542
#     mAP: 0.0622
#   [Ours - RandomForest]
#     AUROC: 0.7483
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0445
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.8078
#     G-mean: 0.6834
#     MCC: 0.1005
#     F1-score: 0.0516
#     mAP: 0.0808
#   [Ours - DecisionTree]
#     AUROC: 0.6904
#     G-mean: 0.0000
#     MCC: -0.0022
#     F1-score: 0.0000
#     mAP: 0.0238
#   [Ours - kNN]
#     AUROC: 0.6584
#     G-mean: 0.3216
#     MCC: 0.0498
#     F1-score: 0.0428
#     mAP: 0.0305
#   [Ours - MLP]
#     AUROC: 0.8088
#     G-mean: 0.4653
#     MCC: 0.0772
#     F1-score: 0.0538
#     mAP: 0.0623
#   [Ours - RandomForest]
#     AUROC: 0.7531
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0459
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/abalone19_results_gaussian_beta_0.01.csv
# beta: 0.005
# Dataset loaded from DataFrame
# X shape : (4174, 8)
# target : Counter({0: 4142, 1: 32})
# IR: 129.44
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.7996
#     G-mean: 0.6444
#     MCC: 0.0913
#     F1-score: 0.0479
#     mAP: 0.0875
#   [Ours - DecisionTree]
#     AUROC: 0.7247
#     G-mean: 0.0000
#     MCC: -0.0032
#     F1-score: 0.0000
#     mAP: 0.0254
#   [Ours - kNN]
#     AUROC: 0.7021
#     G-mean: 0.4761
#     MCC: 0.0811
#     F1-score: 0.0591
#     mAP: 0.0332
#   [Ours - MLP]
#     AUROC: 0.8177
#     G-mean: 0.5337
#     MCC: 0.0916
#     F1-score: 0.0596
#     mAP: 0.1098
#   [Ours - RandomForest]
#     AUROC: 0.7510
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0467
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.8060
#     G-mean: 0.6740
#     MCC: 0.0973
#     F1-score: 0.0499
#     mAP: 0.0887
#   [Ours - DecisionTree]
#     AUROC: 0.7165
#     G-mean: 0.0000
#     MCC: -0.0024
#     F1-score: 0.0000
#     mAP: 0.0238
#   [Ours - kNN]
#     AUROC: 0.6858
#     G-mean: 0.4363
#     MCC: 0.0751
#     F1-score: 0.0591
#     mAP: 0.0297
#   [Ours - MLP]
#     AUROC: 0.8054
#     G-mean: 0.5054
#     MCC: 0.0902
#     F1-score: 0.0636
#     mAP: 0.0887
#   [Ours - RandomForest]
#     AUROC: 0.7592
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0543
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.8003
#     G-mean: 0.6588
#     MCC: 0.0950
#     F1-score: 0.0496
#     mAP: 0.0913
#   [Ours - DecisionTree]
#     AUROC: 0.7069
#     G-mean: 0.0000
#     MCC: -0.0027
#     F1-score: 0.0000
#     mAP: 0.0229
#   [Ours - kNN]
#     AUROC: 0.6722
#     G-mean: 0.3937
#     MCC: 0.0690
#     F1-score: 0.0559
#     mAP: 0.0347
#   [Ours - MLP]
#     AUROC: 0.8034
#     G-mean: 0.4892
#     MCC: 0.0879
#     F1-score: 0.0627
#     mAP: 0.0831
#   [Ours - RandomForest]
#     AUROC: 0.7438
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0502
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.8034
#     G-mean: 0.6674
#     MCC: 0.0968
#     F1-score: 0.0500
#     mAP: 0.0837
#   [Ours - DecisionTree]
#     AUROC: 0.7046
#     G-mean: 0.0000
#     MCC: -0.0024
#     F1-score: 0.0000
#     mAP: 0.0238
#   [Ours - kNN]
#     AUROC: 0.6605
#     G-mean: 0.3380
#     MCC: 0.0548
#     F1-score: 0.0470
#     mAP: 0.0305
#   [Ours - MLP]
#     AUROC: 0.8097
#     G-mean: 0.4938
#     MCC: 0.0876
#     F1-score: 0.0613
#     mAP: 0.0765
#   [Ours - RandomForest]
#     AUROC: 0.7451
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0470
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.8038
#     G-mean: 0.6750
#     MCC: 0.0990
#     F1-score: 0.0511
#     mAP: 0.0792
#   [Ours - DecisionTree]
#     AUROC: 0.6969
#     G-mean: 0.0000
#     MCC: -0.0023
#     F1-score: 0.0000
#     mAP: 0.0236
#   [Ours - kNN]
#     AUROC: 0.6636
#     G-mean: 0.3493
#     MCC: 0.0578
#     F1-score: 0.0478
#     mAP: 0.0313
#   [Ours - MLP]
#     AUROC: 0.8089
#     G-mean: 0.4880
#     MCC: 0.0860
#     F1-score: 0.0601
#     mAP: 0.0716
#   [Ours - RandomForest]
#     AUROC: 0.7395
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0469
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.8058
#     G-mean: 0.6799
#     MCC: 0.0999
#     F1-score: 0.0515
#     mAP: 0.0750
#   [Ours - DecisionTree]
#     AUROC: 0.6902
#     G-mean: 0.0000
#     MCC: -0.0024
#     F1-score: 0.0000
#     mAP: 0.0234
#   [Ours - kNN]
#     AUROC: 0.6600
#     G-mean: 0.3382
#     MCC: 0.0544
#     F1-score: 0.0456
#     mAP: 0.0300
#   [Ours - MLP]
#     AUROC: 0.8065
#     G-mean: 0.4583
#     MCC: 0.0797
#     F1-score: 0.0570
#     mAP: 0.0711
#   [Ours - RandomForest]
#     AUROC: 0.7360
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0454
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.8062
#     G-mean: 0.6822
#     MCC: 0.0995
#     F1-score: 0.0512
#     mAP: 0.0794
#   [Ours - DecisionTree]
#     AUROC: 0.6849
#     G-mean: 0.0000
#     MCC: -0.0025
#     F1-score: 0.0000
#     mAP: 0.0235
#   [Ours - kNN]
#     AUROC: 0.6580
#     G-mean: 0.3480
#     MCC: 0.0561
#     F1-score: 0.0464
#     mAP: 0.0291
#   [Ours - MLP]
#     AUROC: 0.8045
#     G-mean: 0.4633
#     MCC: 0.0815
#     F1-score: 0.0586
#     mAP: 0.0729
#   [Ours - RandomForest]
#     AUROC: 0.7453
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0460
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.8079
#     G-mean: 0.6855
#     MCC: 0.1001
#     F1-score: 0.0512
#     mAP: 0.0788
#   [Ours - DecisionTree]
#     AUROC: 0.6900
#     G-mean: 0.0000
#     MCC: -0.0024
#     F1-score: 0.0000
#     mAP: 0.0238
#   [Ours - kNN]
#     AUROC: 0.6648
#     G-mean: 0.3566
#     MCC: 0.0577
#     F1-score: 0.0473
#     mAP: 0.0310
#   [Ours - MLP]
#     AUROC: 0.8082
#     G-mean: 0.4914
#     MCC: 0.0891
#     F1-score: 0.0625
#     mAP: 0.0769
#   [Ours - RandomForest]
#     AUROC: 0.7451
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0457
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.8074
#     G-mean: 0.6830
#     MCC: 0.0990
#     F1-score: 0.0508
#     mAP: 0.0786
#   [Ours - DecisionTree]
#     AUROC: 0.6914
#     G-mean: 0.0000
#     MCC: -0.0024
#     F1-score: 0.0000
#     mAP: 0.0252
#   [Ours - kNN]
#     AUROC: 0.6588
#     G-mean: 0.3471
#     MCC: 0.0544
#     F1-score: 0.0453
#     mAP: 0.0297
#   [Ours - MLP]
#     AUROC: 0.8068
#     G-mean: 0.4738
#     MCC: 0.0858
#     F1-score: 0.0607
#     mAP: 0.0744
#   [Ours - RandomForest]
#     AUROC: 0.7437
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0452
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.8096
#     G-mean: 0.6802
#     MCC: 0.0986
#     F1-score: 0.0508
#     mAP: 0.0782
#   [Ours - DecisionTree]
#     AUROC: 0.6902
#     G-mean: 0.0000
#     MCC: -0.0024
#     F1-score: 0.0000
#     mAP: 0.0250
#   [Ours - kNN]
#     AUROC: 0.6590
#     G-mean: 0.3471
#     MCC: 0.0544
#     F1-score: 0.0454
#     mAP: 0.0296
#   [Ours - MLP]
#     AUROC: 0.8065
#     G-mean: 0.4655
#     MCC: 0.0842
#     F1-score: 0.0592
#     mAP: 0.0748
#   [Ours - RandomForest]
#     AUROC: 0.7457
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0456
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/abalone19_results_gaussian_beta_0.005.csv
# beta: 0.001
# Dataset loaded from DataFrame
# X shape : (4174, 8)
# target : Counter({0: 4142, 1: 32})
# IR: 129.44
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.8044
#     G-mean: 0.6610
#     MCC: 0.0980
#     F1-score: 0.0501
#     mAP: 0.0739
#   [Ours - DecisionTree]
#     AUROC: 0.7384
#     G-mean: 0.0000
#     MCC: -0.0032
#     F1-score: 0.0000
#     mAP: 0.0271
#   [Ours - kNN]
#     AUROC: 0.6687
#     G-mean: 0.4269
#     MCC: 0.0692
#     F1-score: 0.0502
#     mAP: 0.0368
#   [Ours - MLP]
#     AUROC: 0.8233
#     G-mean: 0.6231
#     MCC: 0.1066
#     F1-score: 0.0623
#     mAP: 0.0786
#   [Ours - RandomForest]
#     AUROC: 0.7366
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0530
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.8073
#     G-mean: 0.6839
#     MCC: 0.0997
#     F1-score: 0.0505
#     mAP: 0.0819
#   [Ours - DecisionTree]
#     AUROC: 0.7229
#     G-mean: 0.0000
#     MCC: -0.0024
#     F1-score: 0.0000
#     mAP: 0.0246
#   [Ours - kNN]
#     AUROC: 0.6486
#     G-mean: 0.3969
#     MCC: 0.0673
#     F1-score: 0.0514
#     mAP: 0.0324
#   [Ours - MLP]
#     AUROC: 0.8092
#     G-mean: 0.5304
#     MCC: 0.0876
#     F1-score: 0.0553
#     mAP: 0.0761
#   [Ours - RandomForest]
#     AUROC: 0.7601
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0531
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.8014
#     G-mean: 0.6722
#     MCC: 0.0986
#     F1-score: 0.0505
#     mAP: 0.0859
#   [Ours - DecisionTree]
#     AUROC: 0.7116
#     G-mean: 0.0000
#     MCC: -0.0028
#     F1-score: 0.0000
#     mAP: 0.0235
#   [Ours - kNN]
#     AUROC: 0.6447
#     G-mean: 0.3553
#     MCC: 0.0622
#     F1-score: 0.0496
#     mAP: 0.0350
#   [Ours - MLP]
#     AUROC: 0.7960
#     G-mean: 0.4283
#     MCC: 0.0653
#     F1-score: 0.0454
#     mAP: 0.0642
#   [Ours - RandomForest]
#     AUROC: 0.7463
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0508
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.8027
#     G-mean: 0.6770
#     MCC: 0.0992
#     F1-score: 0.0505
#     mAP: 0.0816
#   [Ours - DecisionTree]
#     AUROC: 0.7054
#     G-mean: 0.0000
#     MCC: -0.0024
#     F1-score: 0.0000
#     mAP: 0.0242
#   [Ours - kNN]
#     AUROC: 0.6331
#     G-mean: 0.3234
#     MCC: 0.0531
#     F1-score: 0.0444
#     mAP: 0.0308
#   [Ours - MLP]
#     AUROC: 0.8000
#     G-mean: 0.4201
#     MCC: 0.0660
#     F1-score: 0.0485
#     mAP: 0.0605
#   [Ours - RandomForest]
#     AUROC: 0.7440
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0474
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.8047
#     G-mean: 0.6870
#     MCC: 0.1024
#     F1-score: 0.0520
#     mAP: 0.0800
#   [Ours - DecisionTree]
#     AUROC: 0.6993
#     G-mean: 0.0000
#     MCC: -0.0023
#     F1-score: 0.0000
#     mAP: 0.0241
#   [Ours - kNN]
#     AUROC: 0.6481
#     G-mean: 0.3214
#     MCC: 0.0522
#     F1-score: 0.0436
#     mAP: 0.0320
#   [Ours - MLP]
#     AUROC: 0.8032
#     G-mean: 0.4349
#     MCC: 0.0688
#     F1-score: 0.0500
#     mAP: 0.0618
#   [Ours - RandomForest]
#     AUROC: 0.7423
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0463
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.8067
#     G-mean: 0.6934
#     MCC: 0.1038
#     F1-score: 0.0526
#     mAP: 0.0773
#   [Ours - DecisionTree]
#     AUROC: 0.7022
#     G-mean: 0.0000
#     MCC: -0.0024
#     F1-score: 0.0000
#     mAP: 0.0244
#   [Ours - kNN]
#     AUROC: 0.6457
#     G-mean: 0.3037
#     MCC: 0.0471
#     F1-score: 0.0408
#     mAP: 0.0299
#   [Ours - MLP]
#     AUROC: 0.8015
#     G-mean: 0.4442
#     MCC: 0.0697
#     F1-score: 0.0501
#     mAP: 0.0647
#   [Ours - RandomForest]
#     AUROC: 0.7398
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0462
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.8066
#     G-mean: 0.6938
#     MCC: 0.1030
#     F1-score: 0.0522
#     mAP: 0.0794
#   [Ours - DecisionTree]
#     AUROC: 0.6952
#     G-mean: 0.0000
#     MCC: -0.0025
#     F1-score: 0.0000
#     mAP: 0.0243
#   [Ours - kNN]
#     AUROC: 0.6493
#     G-mean: 0.3264
#     MCC: 0.0517
#     F1-score: 0.0436
#     mAP: 0.0300
#   [Ours - MLP]
#     AUROC: 0.8017
#     G-mean: 0.4365
#     MCC: 0.0696
#     F1-score: 0.0504
#     mAP: 0.0672
#   [Ours - RandomForest]
#     AUROC: 0.7447
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0468
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.8077
#     G-mean: 0.6955
#     MCC: 0.1029
#     F1-score: 0.0520
#     mAP: 0.0785
#   [Ours - DecisionTree]
#     AUROC: 0.6985
#     G-mean: 0.0000
#     MCC: -0.0023
#     F1-score: 0.0000
#     mAP: 0.0245
#   [Ours - kNN]
#     AUROC: 0.6572
#     G-mean: 0.3531
#     MCC: 0.0595
#     F1-score: 0.0482
#     mAP: 0.0315
#   [Ours - MLP]
#     AUROC: 0.8066
#     G-mean: 0.4598
#     MCC: 0.0752
#     F1-score: 0.0527
#     mAP: 0.0740
#   [Ours - RandomForest]
#     AUROC: 0.7443
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0474
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.8061
#     G-mean: 0.6952
#     MCC: 0.1025
#     F1-score: 0.0518
#     mAP: 0.0751
#   [Ours - DecisionTree]
#     AUROC: 0.6988
#     G-mean: 0.0000
#     MCC: -0.0023
#     F1-score: 0.0000
#     mAP: 0.0258
#   [Ours - kNN]
#     AUROC: 0.6553
#     G-mean: 0.3399
#     MCC: 0.0557
#     F1-score: 0.0459
#     mAP: 0.0305
#   [Ours - MLP]
#     AUROC: 0.8060
#     G-mean: 0.4470
#     MCC: 0.0714
#     F1-score: 0.0506
#     mAP: 0.0702
#   [Ours - RandomForest]
#     AUROC: 0.7389
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0462
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.8092
#     G-mean: 0.6928
#     MCC: 0.1025
#     F1-score: 0.0520
#     mAP: 0.0750
#   [Ours - DecisionTree]
#     AUROC: 0.7015
#     G-mean: 0.0000
#     MCC: -0.0022
#     F1-score: 0.0000
#     mAP: 0.0257
#   [Ours - kNN]
#     AUROC: 0.6560
#     G-mean: 0.3479
#     MCC: 0.0579
#     F1-score: 0.0474
#     mAP: 0.0305
#   [Ours - MLP]
#     AUROC: 0.8077
#     G-mean: 0.4338
#     MCC: 0.0699
#     F1-score: 0.0497
#     mAP: 0.0705
#   [Ours - RandomForest]
#     AUROC: 0.7382
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0457
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/abalone19_results_gaussian_beta_0.001.csv
# beta: 0.0
# Dataset loaded from DataFrame
# X shape : (4174, 8)
# target : Counter({0: 4142, 1: 32})
# IR: 129.44
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.7988
#     G-mean: 0.6443
#     MCC: 0.0908
#     F1-score: 0.0477
#     mAP: 0.0719
#   [Ours - DecisionTree]
#     AUROC: 0.7247
#     G-mean: 0.0000
#     MCC: -0.0032
#     F1-score: 0.0000
#     mAP: 0.0254
#   [Ours - kNN]
#     AUROC: 0.6820
#     G-mean: 0.5583
#     MCC: 0.1002
#     F1-score: 0.0683
#     mAP: 0.0341
#   [Ours - MLP]
#     AUROC: 0.8208
#     G-mean: 0.5714
#     MCC: 0.1039
#     F1-score: 0.0708
#     mAP: 0.0831
#   [Ours - RandomForest]
#     AUROC: 0.7471
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0483
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.8046
#     G-mean: 0.6653
#     MCC: 0.0930
#     F1-score: 0.0484
#     mAP: 0.0819
#   [Ours - DecisionTree]
#     AUROC: 0.7167
#     G-mean: 0.0000
#     MCC: -0.0024
#     F1-score: 0.0000
#     mAP: 0.0238
#   [Ours - kNN]
#     AUROC: 0.6824
#     G-mean: 0.4396
#     MCC: 0.0728
#     F1-score: 0.0553
#     mAP: 0.0295
#   [Ours - MLP]
#     AUROC: 0.8139
#     G-mean: 0.5441
#     MCC: 0.0965
#     F1-score: 0.0657
#     mAP: 0.0792
#   [Ours - RandomForest]
#     AUROC: 0.7516
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0547
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.7973
#     G-mean: 0.6602
#     MCC: 0.0947
#     F1-score: 0.0494
#     mAP: 0.0873
#   [Ours - DecisionTree]
#     AUROC: 0.6923
#     G-mean: 0.0000
#     MCC: -0.0025
#     F1-score: 0.0000
#     mAP: 0.0227
#   [Ours - kNN]
#     AUROC: 0.6721
#     G-mean: 0.3838
#     MCC: 0.0659
#     F1-score: 0.0523
#     mAP: 0.0316
#   [Ours - MLP]
#     AUROC: 0.7989
#     G-mean: 0.4652
#     MCC: 0.0805
#     F1-score: 0.0571
#     mAP: 0.0678
#   [Ours - RandomForest]
#     AUROC: 0.7434
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0513
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.8005
#     G-mean: 0.6544
#     MCC: 0.0941
#     F1-score: 0.0488
#     mAP: 0.0819
#   [Ours - DecisionTree]
#     AUROC: 0.6928
#     G-mean: 0.0000
#     MCC: -0.0024
#     F1-score: 0.0000
#     mAP: 0.0236
#   [Ours - kNN]
#     AUROC: 0.6553
#     G-mean: 0.3365
#     MCC: 0.0556
#     F1-score: 0.0462
#     mAP: 0.0287
#   [Ours - MLP]
#     AUROC: 0.8023
#     G-mean: 0.4796
#     MCC: 0.0819
#     F1-score: 0.0566
#     mAP: 0.0673
#   [Ours - RandomForest]
#     AUROC: 0.7429
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0487
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.8031
#     G-mean: 0.6646
#     MCC: 0.0968
#     F1-score: 0.0500
#     mAP: 0.0802
#   [Ours - DecisionTree]
#     AUROC: 0.6896
#     G-mean: 0.0000
#     MCC: -0.0022
#     F1-score: 0.0000
#     mAP: 0.0237
#   [Ours - kNN]
#     AUROC: 0.6595
#     G-mean: 0.3273
#     MCC: 0.0520
#     F1-score: 0.0438
#     mAP: 0.0288
#   [Ours - MLP]
#     AUROC: 0.8048
#     G-mean: 0.4909
#     MCC: 0.0842
#     F1-score: 0.0575
#     mAP: 0.0649
#   [Ours - RandomForest]
#     AUROC: 0.7435
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0464
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.8052
#     G-mean: 0.6660
#     MCC: 0.0980
#     F1-score: 0.0505
#     mAP: 0.0775
#   [Ours - DecisionTree]
#     AUROC: 0.6908
#     G-mean: 0.0000
#     MCC: -0.0022
#     F1-score: 0.0000
#     mAP: 0.0235
#   [Ours - kNN]
#     AUROC: 0.6574
#     G-mean: 0.3211
#     MCC: 0.0494
#     F1-score: 0.0421
#     mAP: 0.0276
#   [Ours - MLP]
#     AUROC: 0.8046
#     G-mean: 0.4916
#     MCC: 0.0830
#     F1-score: 0.0566
#     mAP: 0.0667
#   [Ours - RandomForest]
#     AUROC: 0.7414
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0462
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.8049
#     G-mean: 0.6703
#     MCC: 0.0980
#     F1-score: 0.0504
#     mAP: 0.0766
#   [Ours - DecisionTree]
#     AUROC: 0.6854
#     G-mean: 0.0000
#     MCC: -0.0023
#     F1-score: 0.0000
#     mAP: 0.0236
#   [Ours - kNN]
#     AUROC: 0.6587
#     G-mean: 0.3333
#     MCC: 0.0521
#     F1-score: 0.0438
#     mAP: 0.0286
#   [Ours - MLP]
#     AUROC: 0.8052
#     G-mean: 0.4742
#     MCC: 0.0801
#     F1-score: 0.0556
#     mAP: 0.0708
#   [Ours - RandomForest]
#     AUROC: 0.7445
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0474
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.8063
#     G-mean: 0.6724
#     MCC: 0.0978
#     F1-score: 0.0503
#     mAP: 0.0759
#   [Ours - DecisionTree]
#     AUROC: 0.6900
#     G-mean: 0.0000
#     MCC: -0.0022
#     F1-score: 0.0000
#     mAP: 0.0238
#   [Ours - kNN]
#     AUROC: 0.6648
#     G-mean: 0.3602
#     MCC: 0.0583
#     F1-score: 0.0474
#     mAP: 0.0300
#   [Ours - MLP]
#     AUROC: 0.8081
#     G-mean: 0.4902
#     MCC: 0.0819
#     F1-score: 0.0564
#     mAP: 0.0730
#   [Ours - RandomForest]
#     AUROC: 0.7399
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0489
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.8046
#     G-mean: 0.6727
#     MCC: 0.0971
#     F1-score: 0.0500
#     mAP: 0.0725
#   [Ours - DecisionTree]
#     AUROC: 0.6914
#     G-mean: 0.0000
#     MCC: -0.0022
#     F1-score: 0.0000
#     mAP: 0.0253
#   [Ours - kNN]
#     AUROC: 0.6629
#     G-mean: 0.3525
#     MCC: 0.0561
#     F1-score: 0.0460
#     mAP: 0.0294
#   [Ours - MLP]
#     AUROC: 0.8075
#     G-mean: 0.4894
#     MCC: 0.0801
#     F1-score: 0.0553
#     mAP: 0.0689
#   [Ours - RandomForest]
#     AUROC: 0.7350
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0472
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.8082
#     G-mean: 0.6708
#     MCC: 0.0968
#     F1-score: 0.0500
#     mAP: 0.0730
#   [Ours - DecisionTree]
#     AUROC: 0.6949
#     G-mean: 0.0000
#     MCC: -0.0021
#     F1-score: 0.0000
#     mAP: 0.0251
#   [Ours - kNN]
#     AUROC: 0.6646
#     G-mean: 0.3517
#     MCC: 0.0564
#     F1-score: 0.0466
#     mAP: 0.0296
#   [Ours - MLP]
#     AUROC: 0.8083
#     G-mean: 0.4673
#     MCC: 0.0762
#     F1-score: 0.0533
#     mAP: 0.0692
#   [Ours - RandomForest]
#     AUROC: 0.7392
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0472
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/abalone19_results_gaussian_beta_0.0.csv
