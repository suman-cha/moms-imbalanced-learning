# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

# Save path 
save_path = "/data4/oldrain123/oldrain123/results/ablation_results/beta8"
data_path = "/data4/oldrain123/oldrain123/dataset"

# %%
import os
import warnings
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from experiment import run_ablation
from imblearn.datasets import fetch_datasets

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "5"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
data = fetch_datasets()
methods = ["Ours"]
betas = [1e-1, 5e-2, 1e-2, 5e-3, 1e-3, 0.0]
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}

# %%
data_name = 'winequality-red-3_vs_5'

n_epochs = 2000
hidden_dims = [32, 64, 128, 256]
latent_dim = 512
lr = 0.001

for beta in betas:
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'ozone_level'
maj_target_name = -1

n_epochs = 2000
hidden_dims = [64, 32, 16, 8]
latent_dim = 4
lr = 0.001
for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        fetch_data_func=fetch_datasets,
        maj_target_name=maj_target_name,
        methods=methods,
        base_models=base_models,
        device=device,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'arrhythmia'
maj_target_name = -1

n_epochs = 2000
hidden_dims = [256, 128, 64, 32]
latent_dim = 32
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        fetch_data_func=fetch_datasets,
        maj_target_name=maj_target_name,
        methods=methods,
        base_models=base_models,
        device=device,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'us_crime'
maj_target_name = -1

n_epochs = 2000
hidden_dims = [64, 32, 16, 8]
latent_dim = 4
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        fetch_data_func=fetch_datasets,
        maj_target_name=maj_target_name,
        methods=methods,
        base_models=base_models,
        device=device,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'ionosphere'

n_epochs = 2000
hidden_dims = [17, 8] # [68, 34]
latent_dim = 4 # 12
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )
# Out:
# beta: 0.1
# Dataset loaded from DataFrame
# X shape : (351, 34)
# target : Counter({0: 225, 1: 126})
# IR: 1.79
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9507
#     G-mean: 0.8754
#     MCC: 0.7938
#     F1-score: 0.8541
#     mAP: 0.9403
#   [Ours - DecisionTree]
#     AUROC: 0.8701
#     G-mean: 0.8701
#     MCC: 0.7768
#     F1-score: 0.8449
#     mAP: 0.8158
#   [Ours - kNN]
#     AUROC: 0.9257
#     G-mean: 0.7941
#     MCC: 0.6967
#     F1-score: 0.7629
#     mAP: 0.8791
#   [Ours - MLP]
#     AUROC: 0.9007
#     G-mean: 0.8180
#     MCC: 0.6806
#     F1-score: 0.7788
#     mAP: 0.8878
#   [Ours - RandomForest]
#     AUROC: 0.9801
#     G-mean: 0.9211
#     MCC: 0.8691
#     F1-score: 0.9059
#     mAP: 0.9700
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9438
#     G-mean: 0.8731
#     MCC: 0.7880
#     F1-score: 0.8514
#     mAP: 0.9374
#   [Ours - DecisionTree]
#     AUROC: 0.8689
#     G-mean: 0.8640
#     MCC: 0.7616
#     F1-score: 0.8353
#     mAP: 0.8029
#   [Ours - kNN]
#     AUROC: 0.9209
#     G-mean: 0.7993
#     MCC: 0.7004
#     F1-score: 0.7690
#     mAP: 0.8764
#   [Ours - MLP]
#     AUROC: 0.9060
#     G-mean: 0.8199
#     MCC: 0.6811
#     F1-score: 0.7806
#     mAP: 0.8893
#   [Ours - RandomForest]
#     AUROC: 0.9799
#     G-mean: 0.9222
#     MCC: 0.8701
#     F1-score: 0.9094
#     mAP: 0.9715
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9456
#     G-mean: 0.8774
#     MCC: 0.7975
#     F1-score: 0.8578
#     mAP: 0.9382
#   [Ours - DecisionTree]
#     AUROC: 0.8527
#     G-mean: 0.8557
#     MCC: 0.7426
#     F1-score: 0.8242
#     mAP: 0.7878
#   [Ours - kNN]
#     AUROC: 0.9180
#     G-mean: 0.8032
#     MCC: 0.7055
#     F1-score: 0.7740
#     mAP: 0.8714
#   [Ours - MLP]
#     AUROC: 0.9037
#     G-mean: 0.8186
#     MCC: 0.6743
#     F1-score: 0.7780
#     mAP: 0.8874
#   [Ours - RandomForest]
#     AUROC: 0.9798
#     G-mean: 0.9232
#     MCC: 0.8703
#     F1-score: 0.9104
#     mAP: 0.9723
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9465
#     G-mean: 0.8767
#     MCC: 0.7966
#     F1-score: 0.8569
#     mAP: 0.9405
#   [Ours - DecisionTree]
#     AUROC: 0.8580
#     G-mean: 0.8580
#     MCC: 0.7478
#     F1-score: 0.8274
#     mAP: 0.7935
#   [Ours - kNN]
#     AUROC: 0.9160
#     G-mean: 0.8066
#     MCC: 0.7092
#     F1-score: 0.7774
#     mAP: 0.8685
#   [Ours - MLP]
#     AUROC: 0.8984
#     G-mean: 0.8099
#     MCC: 0.6637
#     F1-score: 0.7678
#     mAP: 0.8837
#   [Ours - RandomForest]
#     AUROC: 0.9804
#     G-mean: 0.9231
#     MCC: 0.8693
#     F1-score: 0.9097
#     mAP: 0.9725
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9478
#     G-mean: 0.8765
#     MCC: 0.7971
#     F1-score: 0.8570
#     mAP: 0.9415
#   [Ours - DecisionTree]
#     AUROC: 0.8595
#     G-mean: 0.8605
#     MCC: 0.7511
#     F1-score: 0.8301
#     mAP: 0.7932
#   [Ours - kNN]
#     AUROC: 0.9146
#     G-mean: 0.8060
#     MCC: 0.7089
#     F1-score: 0.7771
#     mAP: 0.8687
#   [Ours - MLP]
#     AUROC: 0.9022
#     G-mean: 0.8099
#     MCC: 0.6662
#     F1-score: 0.7683
#     mAP: 0.8867
#   [Ours - RandomForest]
#     AUROC: 0.9815
#     G-mean: 0.9211
#     MCC: 0.8654
#     F1-score: 0.9069
#     mAP: 0.9741
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9480
#     G-mean: 0.8742
#     MCC: 0.7944
#     F1-score: 0.8544
#     mAP: 0.9416
#   [Ours - DecisionTree]
#     AUROC: 0.8636
#     G-mean: 0.8622
#     MCC: 0.7529
#     F1-score: 0.8319
#     mAP: 0.7986
#   [Ours - kNN]
#     AUROC: 0.9145
#     G-mean: 0.8044
#     MCC: 0.7077
#     F1-score: 0.7751
#     mAP: 0.8683
#   [Ours - MLP]
#     AUROC: 0.9005
#     G-mean: 0.8098
#     MCC: 0.6659
#     F1-score: 0.7686
#     mAP: 0.8865
#   [Ours - RandomForest]
#     AUROC: 0.9817
#     G-mean: 0.9205
#     MCC: 0.8646
#     F1-score: 0.9064
#     mAP: 0.9747
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9473
#     G-mean: 0.8731
#     MCC: 0.7918
#     F1-score: 0.8529
#     mAP: 0.9413
#   [Ours - DecisionTree]
#     AUROC: 0.8676
#     G-mean: 0.8640
#     MCC: 0.7583
#     F1-score: 0.8348
#     mAP: 0.8040
#   [Ours - kNN]
#     AUROC: 0.9152
#     G-mean: 0.8042
#     MCC: 0.7074
#     F1-score: 0.7750
#     mAP: 0.8689
#   [Ours - MLP]
#     AUROC: 0.9005
#     G-mean: 0.8110
#     MCC: 0.6690
#     F1-score: 0.7701
#     mAP: 0.8863
#   [Ours - RandomForest]
#     AUROC: 0.9819
#     G-mean: 0.9196
#     MCC: 0.8619
#     F1-score: 0.9050
#     mAP: 0.9748
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9471
#     G-mean: 0.8730
#     MCC: 0.7913
#     F1-score: 0.8526
#     mAP: 0.9408
#   [Ours - DecisionTree]
#     AUROC: 0.8658
#     G-mean: 0.8616
#     MCC: 0.7534
#     F1-score: 0.8315
#     mAP: 0.8005
#   [Ours - kNN]
#     AUROC: 0.9152
#     G-mean: 0.8039
#     MCC: 0.7069
#     F1-score: 0.7746
#     mAP: 0.8694
#   [Ours - MLP]
#     AUROC: 0.9009
#     G-mean: 0.8135
#     MCC: 0.6719
#     F1-score: 0.7731
#     mAP: 0.8875
#   [Ours - RandomForest]
#     AUROC: 0.9821
#     G-mean: 0.9190
#     MCC: 0.8608
#     F1-score: 0.9042
#     mAP: 0.9745
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9480
#     G-mean: 0.8720
#     MCC: 0.7894
#     F1-score: 0.8514
#     mAP: 0.9417
#   [Ours - DecisionTree]
#     AUROC: 0.8652
#     G-mean: 0.8607
#     MCC: 0.7513
#     F1-score: 0.8301
#     mAP: 0.7985
#   [Ours - kNN]
#     AUROC: 0.9140
#     G-mean: 0.8021
#     MCC: 0.7045
#     F1-score: 0.7725
#     mAP: 0.8672
#   [Ours - MLP]
#     AUROC: 0.9012
#     G-mean: 0.8119
#     MCC: 0.6681
#     F1-score: 0.7709
#     mAP: 0.8866
#   [Ours - RandomForest]
#     AUROC: 0.9815
#     G-mean: 0.9194
#     MCC: 0.8610
#     F1-score: 0.9046
#     mAP: 0.9736
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9469
#     G-mean: 0.8711
#     MCC: 0.7882
#     F1-score: 0.8504
#     mAP: 0.9407
#   [Ours - DecisionTree]
#     AUROC: 0.8634
#     G-mean: 0.8581
#     MCC: 0.7478
#     F1-score: 0.8268
#     mAP: 0.7960
#   [Ours - kNN]
#     AUROC: 0.9149
#     G-mean: 0.8031
#     MCC: 0.7056
#     F1-score: 0.7736
#     mAP: 0.8686
#   [Ours - MLP]
#     AUROC: 0.8992
#     G-mean: 0.8108
#     MCC: 0.6661
#     F1-score: 0.7696
#     mAP: 0.8845
#   [Ours - RandomForest]
#     AUROC: 0.9809
#     G-mean: 0.9197
#     MCC: 0.8614
#     F1-score: 0.9050
#     mAP: 0.9726
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/ionosphere_results_gaussian_beta_0.1.csv
# beta: 0.05
# Dataset loaded from DataFrame
# X shape : (351, 34)
# target : Counter({0: 225, 1: 126})
# IR: 1.79
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9645
#     G-mean: 0.9041
#     MCC: 0.8454
#     F1-score: 0.8882
#     mAP: 0.9512
#   [Ours - DecisionTree]
#     AUROC: 0.8627
#     G-mean: 0.8565
#     MCC: 0.7466
#     F1-score: 0.8250
#     mAP: 0.7891
#   [Ours - kNN]
#     AUROC: 0.9183
#     G-mean: 0.8074
#     MCC: 0.7095
#     F1-score: 0.7781
#     mAP: 0.8674
#   [Ours - MLP]
#     AUROC: 0.9116
#     G-mean: 0.8448
#     MCC: 0.7342
#     F1-score: 0.8156
#     mAP: 0.8952
#   [Ours - RandomForest]
#     AUROC: 0.9787
#     G-mean: 0.9195
#     MCC: 0.8580
#     F1-score: 0.9013
#     mAP: 0.9685
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9638
#     G-mean: 0.8972
#     MCC: 0.8336
#     F1-score: 0.8820
#     mAP: 0.9538
#   [Ours - DecisionTree]
#     AUROC: 0.8637
#     G-mean: 0.8568
#     MCC: 0.7410
#     F1-score: 0.8236
#     mAP: 0.7843
#   [Ours - kNN]
#     AUROC: 0.9201
#     G-mean: 0.8180
#     MCC: 0.7225
#     F1-score: 0.7909
#     mAP: 0.8747
#   [Ours - MLP]
#     AUROC: 0.9155
#     G-mean: 0.8406
#     MCC: 0.7211
#     F1-score: 0.8081
#     mAP: 0.8981
#   [Ours - RandomForest]
#     AUROC: 0.9804
#     G-mean: 0.9193
#     MCC: 0.8588
#     F1-score: 0.9037
#     mAP: 0.9721
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9662
#     G-mean: 0.8949
#     MCC: 0.8277
#     F1-score: 0.8787
#     mAP: 0.9559
#   [Ours - DecisionTree]
#     AUROC: 0.8604
#     G-mean: 0.8553
#     MCC: 0.7349
#     F1-score: 0.8215
#     mAP: 0.7848
#   [Ours - kNN]
#     AUROC: 0.9169
#     G-mean: 0.8117
#     MCC: 0.7155
#     F1-score: 0.7834
#     mAP: 0.8691
#   [Ours - MLP]
#     AUROC: 0.9219
#     G-mean: 0.8410
#     MCC: 0.7186
#     F1-score: 0.8080
#     mAP: 0.9045
#   [Ours - RandomForest]
#     AUROC: 0.9795
#     G-mean: 0.9189
#     MCC: 0.8594
#     F1-score: 0.9040
#     mAP: 0.9717
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9662
#     G-mean: 0.8933
#     MCC: 0.8252
#     F1-score: 0.8770
#     mAP: 0.9568
#   [Ours - DecisionTree]
#     AUROC: 0.8528
#     G-mean: 0.8543
#     MCC: 0.7325
#     F1-score: 0.8201
#     mAP: 0.7784
#   [Ours - kNN]
#     AUROC: 0.9163
#     G-mean: 0.8143
#     MCC: 0.7200
#     F1-score: 0.7860
#     mAP: 0.8683
#   [Ours - MLP]
#     AUROC: 0.9099
#     G-mean: 0.8297
#     MCC: 0.6975
#     F1-score: 0.7930
#     mAP: 0.8951
#   [Ours - RandomForest]
#     AUROC: 0.9796
#     G-mean: 0.9194
#     MCC: 0.8596
#     F1-score: 0.9041
#     mAP: 0.9715
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9677
#     G-mean: 0.8906
#     MCC: 0.8211
#     F1-score: 0.8739
#     mAP: 0.9582
#   [Ours - DecisionTree]
#     AUROC: 0.8523
#     G-mean: 0.8558
#     MCC: 0.7375
#     F1-score: 0.8226
#     mAP: 0.7807
#   [Ours - kNN]
#     AUROC: 0.9153
#     G-mean: 0.8121
#     MCC: 0.7175
#     F1-score: 0.7838
#     mAP: 0.8690
#   [Ours - MLP]
#     AUROC: 0.9098
#     G-mean: 0.8276
#     MCC: 0.6942
#     F1-score: 0.7903
#     mAP: 0.8959
#   [Ours - RandomForest]
#     AUROC: 0.9808
#     G-mean: 0.9181
#     MCC: 0.8576
#     F1-score: 0.9024
#     mAP: 0.9733
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9683
#     G-mean: 0.8905
#     MCC: 0.8209
#     F1-score: 0.8735
#     mAP: 0.9591
#   [Ours - DecisionTree]
#     AUROC: 0.8504
#     G-mean: 0.8536
#     MCC: 0.7342
#     F1-score: 0.8202
#     mAP: 0.7781
#   [Ours - kNN]
#     AUROC: 0.9141
#     G-mean: 0.8080
#     MCC: 0.7129
#     F1-score: 0.7790
#     mAP: 0.8669
#   [Ours - MLP]
#     AUROC: 0.9044
#     G-mean: 0.8224
#     MCC: 0.6835
#     F1-score: 0.7841
#     mAP: 0.8911
#   [Ours - RandomForest]
#     AUROC: 0.9808
#     G-mean: 0.9195
#     MCC: 0.8612
#     F1-score: 0.9048
#     mAP: 0.9732
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9684
#     G-mean: 0.8917
#     MCC: 0.8225
#     F1-score: 0.8748
#     mAP: 0.9594
#   [Ours - DecisionTree]
#     AUROC: 0.8559
#     G-mean: 0.8578
#     MCC: 0.7438
#     F1-score: 0.8263
#     mAP: 0.7863
#   [Ours - kNN]
#     AUROC: 0.9138
#     G-mean: 0.8093
#     MCC: 0.7142
#     F1-score: 0.7807
#     mAP: 0.8664
#   [Ours - MLP]
#     AUROC: 0.9035
#     G-mean: 0.8220
#     MCC: 0.6835
#     F1-score: 0.7833
#     mAP: 0.8900
#   [Ours - RandomForest]
#     AUROC: 0.9812
#     G-mean: 0.9203
#     MCC: 0.8616
#     F1-score: 0.9053
#     mAP: 0.9736
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9684
#     G-mean: 0.8908
#     MCC: 0.8207
#     F1-score: 0.8735
#     mAP: 0.9594
#   [Ours - DecisionTree]
#     AUROC: 0.8570
#     G-mean: 0.8566
#     MCC: 0.7417
#     F1-score: 0.8245
#     mAP: 0.7855
#   [Ours - kNN]
#     AUROC: 0.9141
#     G-mean: 0.8089
#     MCC: 0.7127
#     F1-score: 0.7800
#     mAP: 0.8667
#   [Ours - MLP]
#     AUROC: 0.9037
#     G-mean: 0.8227
#     MCC: 0.6843
#     F1-score: 0.7839
#     mAP: 0.8893
#   [Ours - RandomForest]
#     AUROC: 0.9815
#     G-mean: 0.9194
#     MCC: 0.8597
#     F1-score: 0.9040
#     mAP: 0.9736
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9685
#     G-mean: 0.8919
#     MCC: 0.8222
#     F1-score: 0.8750
#     mAP: 0.9597
#   [Ours - DecisionTree]
#     AUROC: 0.8598
#     G-mean: 0.8567
#     MCC: 0.7414
#     F1-score: 0.8246
#     mAP: 0.7880
#   [Ours - kNN]
#     AUROC: 0.9131
#     G-mean: 0.8080
#     MCC: 0.7108
#     F1-score: 0.7788
#     mAP: 0.8647
#   [Ours - MLP]
#     AUROC: 0.9033
#     G-mean: 0.8195
#     MCC: 0.6771
#     F1-score: 0.7797
#     mAP: 0.8873
#   [Ours - RandomForest]
#     AUROC: 0.9809
#     G-mean: 0.9190
#     MCC: 0.8586
#     F1-score: 0.9035
#     mAP: 0.9726
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9681
#     G-mean: 0.8927
#     MCC: 0.8233
#     F1-score: 0.8759
#     mAP: 0.9596
#   [Ours - DecisionTree]
#     AUROC: 0.8560
#     G-mean: 0.8551
#     MCC: 0.7390
#     F1-score: 0.8228
#     mAP: 0.7850
#   [Ours - kNN]
#     AUROC: 0.9138
#     G-mean: 0.8074
#     MCC: 0.7094
#     F1-score: 0.7782
#     mAP: 0.8656
#   [Ours - MLP]
#     AUROC: 0.9034
#     G-mean: 0.8187
#     MCC: 0.6761
#     F1-score: 0.7787
#     mAP: 0.8873
#   [Ours - RandomForest]
#     AUROC: 0.9807
#     G-mean: 0.9184
#     MCC: 0.8574
#     F1-score: 0.9027
#     mAP: 0.9723
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/ionosphere_results_gaussian_beta_0.05.csv
# beta: 0.01
# Dataset loaded from DataFrame
# X shape : (351, 34)
# target : Counter({0: 225, 1: 126})
# IR: 1.79
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9753
#     G-mean: 0.9119
#     MCC: 0.8651
#     F1-score: 0.8997
#     mAP: 0.9668
#   [Ours - DecisionTree]
#     AUROC: 0.8293
#     G-mean: 0.8364
#     MCC: 0.7038
#     F1-score: 0.7959
#     mAP: 0.7496
#   [Ours - kNN]
#     AUROC: 0.9329
#     G-mean: 0.8124
#     MCC: 0.7218
#     F1-score: 0.7842
#     mAP: 0.8994
#   [Ours - MLP]
#     AUROC: 0.9051
#     G-mean: 0.8115
#     MCC: 0.6693
#     F1-score: 0.7718
#     mAP: 0.8941
#   [Ours - RandomForest]
#     AUROC: 0.9814
#     G-mean: 0.9081
#     MCC: 0.8389
#     F1-score: 0.8871
#     mAP: 0.9747
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9730
#     G-mean: 0.9140
#     MCC: 0.8652
#     F1-score: 0.9030
#     mAP: 0.9671
#   [Ours - DecisionTree]
#     AUROC: 0.8538
#     G-mean: 0.8537
#     MCC: 0.7350
#     F1-score: 0.8194
#     mAP: 0.7776
#   [Ours - kNN]
#     AUROC: 0.9249
#     G-mean: 0.8138
#     MCC: 0.7178
#     F1-score: 0.7858
#     mAP: 0.8893
#   [Ours - MLP]
#     AUROC: 0.9154
#     G-mean: 0.8216
#     MCC: 0.6844
#     F1-score: 0.7828
#     mAP: 0.8999
#   [Ours - RandomForest]
#     AUROC: 0.9820
#     G-mean: 0.9114
#     MCC: 0.8429
#     F1-score: 0.8927
#     mAP: 0.9747
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9752
#     G-mean: 0.9134
#     MCC: 0.8613
#     F1-score: 0.9016
#     mAP: 0.9691
#   [Ours - DecisionTree]
#     AUROC: 0.8431
#     G-mean: 0.8452
#     MCC: 0.7174
#     F1-score: 0.8090
#     mAP: 0.7747
#   [Ours - kNN]
#     AUROC: 0.9244
#     G-mean: 0.8111
#     MCC: 0.7118
#     F1-score: 0.7821
#     mAP: 0.8823
#   [Ours - MLP]
#     AUROC: 0.9149
#     G-mean: 0.8270
#     MCC: 0.6889
#     F1-score: 0.7886
#     mAP: 0.8988
#   [Ours - RandomForest]
#     AUROC: 0.9808
#     G-mean: 0.9130
#     MCC: 0.8465
#     F1-score: 0.8954
#     mAP: 0.9728
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9762
#     G-mean: 0.9162
#     MCC: 0.8642
#     F1-score: 0.9040
#     mAP: 0.9705
#   [Ours - DecisionTree]
#     AUROC: 0.8477
#     G-mean: 0.8516
#     MCC: 0.7300
#     F1-score: 0.8175
#     mAP: 0.7789
#   [Ours - kNN]
#     AUROC: 0.9242
#     G-mean: 0.8118
#     MCC: 0.7123
#     F1-score: 0.7821
#     mAP: 0.8806
#   [Ours - MLP]
#     AUROC: 0.9075
#     G-mean: 0.8265
#     MCC: 0.6885
#     F1-score: 0.7881
#     mAP: 0.8933
#   [Ours - RandomForest]
#     AUROC: 0.9815
#     G-mean: 0.9144
#     MCC: 0.8501
#     F1-score: 0.8973
#     mAP: 0.9731
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9768
#     G-mean: 0.9149
#     MCC: 0.8608
#     F1-score: 0.9021
#     mAP: 0.9708
#   [Ours - DecisionTree]
#     AUROC: 0.8563
#     G-mean: 0.8577
#     MCC: 0.7424
#     F1-score: 0.8252
#     mAP: 0.7875
#   [Ours - kNN]
#     AUROC: 0.9227
#     G-mean: 0.8114
#     MCC: 0.7138
#     F1-score: 0.7824
#     mAP: 0.8805
#   [Ours - MLP]
#     AUROC: 0.9104
#     G-mean: 0.8277
#     MCC: 0.6912
#     F1-score: 0.7895
#     mAP: 0.8962
#   [Ours - RandomForest]
#     AUROC: 0.9820
#     G-mean: 0.9136
#     MCC: 0.8491
#     F1-score: 0.8963
#     mAP: 0.9737
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9778
#     G-mean: 0.9156
#     MCC: 0.8619
#     F1-score: 0.9031
#     mAP: 0.9718
#   [Ours - DecisionTree]
#     AUROC: 0.8523
#     G-mean: 0.8552
#     MCC: 0.7402
#     F1-score: 0.8228
#     mAP: 0.7848
#   [Ours - kNN]
#     AUROC: 0.9221
#     G-mean: 0.8128
#     MCC: 0.7182
#     F1-score: 0.7844
#     mAP: 0.8799
#   [Ours - MLP]
#     AUROC: 0.9092
#     G-mean: 0.8270
#     MCC: 0.6897
#     F1-score: 0.7889
#     mAP: 0.8944
#   [Ours - RandomForest]
#     AUROC: 0.9829
#     G-mean: 0.9171
#     MCC: 0.8563
#     F1-score: 0.9010
#     mAP: 0.9748
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9786
#     G-mean: 0.9146
#     MCC: 0.8597
#     F1-score: 0.9017
#     mAP: 0.9723
#   [Ours - DecisionTree]
#     AUROC: 0.8555
#     G-mean: 0.8563
#     MCC: 0.7438
#     F1-score: 0.8247
#     mAP: 0.7912
#   [Ours - kNN]
#     AUROC: 0.9225
#     G-mean: 0.8111
#     MCC: 0.7156
#     F1-score: 0.7823
#     mAP: 0.8793
#   [Ours - MLP]
#     AUROC: 0.9076
#     G-mean: 0.8240
#     MCC: 0.6838
#     F1-score: 0.7847
#     mAP: 0.8920
#   [Ours - RandomForest]
#     AUROC: 0.9827
#     G-mean: 0.9164
#     MCC: 0.8538
#     F1-score: 0.8999
#     mAP: 0.9743
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9782
#     G-mean: 0.9145
#     MCC: 0.8596
#     F1-score: 0.9017
#     mAP: 0.9721
#   [Ours - DecisionTree]
#     AUROC: 0.8577
#     G-mean: 0.8577
#     MCC: 0.7465
#     F1-score: 0.8263
#     mAP: 0.7923
#   [Ours - kNN]
#     AUROC: 0.9223
#     G-mean: 0.8114
#     MCC: 0.7153
#     F1-score: 0.7826
#     mAP: 0.8792
#   [Ours - MLP]
#     AUROC: 0.9080
#     G-mean: 0.8234
#     MCC: 0.6809
#     F1-score: 0.7835
#     mAP: 0.8923
#   [Ours - RandomForest]
#     AUROC: 0.9833
#     G-mean: 0.9165
#     MCC: 0.8543
#     F1-score: 0.9001
#     mAP: 0.9750
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9783
#     G-mean: 0.9137
#     MCC: 0.8588
#     F1-score: 0.9009
#     mAP: 0.9720
#   [Ours - DecisionTree]
#     AUROC: 0.8605
#     G-mean: 0.8602
#     MCC: 0.7499
#     F1-score: 0.8292
#     mAP: 0.7942
#   [Ours - kNN]
#     AUROC: 0.9217
#     G-mean: 0.8104
#     MCC: 0.7131
#     F1-score: 0.7812
#     mAP: 0.8775
#   [Ours - MLP]
#     AUROC: 0.9074
#     G-mean: 0.8243
#     MCC: 0.6822
#     F1-score: 0.7847
#     mAP: 0.8916
#   [Ours - RandomForest]
#     AUROC: 0.9830
#     G-mean: 0.9167
#     MCC: 0.8539
#     F1-score: 0.9002
#     mAP: 0.9745
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9781
#     G-mean: 0.9126
#     MCC: 0.8569
#     F1-score: 0.8996
#     mAP: 0.9719
#   [Ours - DecisionTree]
#     AUROC: 0.8624
#     G-mean: 0.8613
#     MCC: 0.7502
#     F1-score: 0.8300
#     mAP: 0.7934
#   [Ours - kNN]
#     AUROC: 0.9221
#     G-mean: 0.8121
#     MCC: 0.7151
#     F1-score: 0.7834
#     mAP: 0.8782
#   [Ours - MLP]
#     AUROC: 0.9062
#     G-mean: 0.8239
#     MCC: 0.6808
#     F1-score: 0.7842
#     mAP: 0.8902
#   [Ours - RandomForest]
#     AUROC: 0.9825
#     G-mean: 0.9166
#     MCC: 0.8537
#     F1-score: 0.9001
#     mAP: 0.9739
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/ionosphere_results_gaussian_beta_0.01.csv
# beta: 0.005
# Dataset loaded from DataFrame
# X shape : (351, 34)
# target : Counter({0: 225, 1: 126})
# IR: 1.79
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9771
#     G-mean: 0.9138
#     MCC: 0.8659
#     F1-score: 0.9003
#     mAP: 0.9685
#   [Ours - DecisionTree]
#     AUROC: 0.8610
#     G-mean: 0.8563
#     MCC: 0.7339
#     F1-score: 0.8212
#     mAP: 0.7771
#   [Ours - kNN]
#     AUROC: 0.9233
#     G-mean: 0.8355
#     MCC: 0.7466
#     F1-score: 0.8129
#     mAP: 0.8892
#   [Ours - MLP]
#     AUROC: 0.9063
#     G-mean: 0.8252
#     MCC: 0.6767
#     F1-score: 0.7855
#     mAP: 0.8939
#   [Ours - RandomForest]
#     AUROC: 0.9820
#     G-mean: 0.9178
#     MCC: 0.8576
#     F1-score: 0.9007
#     mAP: 0.9748
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9754
#     G-mean: 0.9131
#     MCC: 0.8625
#     F1-score: 0.9016
#     mAP: 0.9680
#   [Ours - DecisionTree]
#     AUROC: 0.8758
#     G-mean: 0.8705
#     MCC: 0.7632
#     F1-score: 0.8414
#     mAP: 0.8020
#   [Ours - kNN]
#     AUROC: 0.9233
#     G-mean: 0.8356
#     MCC: 0.7503
#     F1-score: 0.8133
#     mAP: 0.8884
#   [Ours - MLP]
#     AUROC: 0.8997
#     G-mean: 0.8229
#     MCC: 0.6732
#     F1-score: 0.7822
#     mAP: 0.8841
#   [Ours - RandomForest]
#     AUROC: 0.9824
#     G-mean: 0.9173
#     MCC: 0.8554
#     F1-score: 0.9018
#     mAP: 0.9746
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9762
#     G-mean: 0.9143
#     MCC: 0.8617
#     F1-score: 0.9024
#     mAP: 0.9696
#   [Ours - DecisionTree]
#     AUROC: 0.8653
#     G-mean: 0.8653
#     MCC: 0.7527
#     F1-score: 0.8348
#     mAP: 0.7981
#   [Ours - kNN]
#     AUROC: 0.9210
#     G-mean: 0.8265
#     MCC: 0.7367
#     F1-score: 0.8021
#     mAP: 0.8811
#   [Ours - MLP]
#     AUROC: 0.9071
#     G-mean: 0.8293
#     MCC: 0.6853
#     F1-score: 0.7904
#     mAP: 0.8929
#   [Ours - RandomForest]
#     AUROC: 0.9807
#     G-mean: 0.9162
#     MCC: 0.8526
#     F1-score: 0.9003
#     mAP: 0.9723
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9764
#     G-mean: 0.9148
#     MCC: 0.8613
#     F1-score: 0.9024
#     mAP: 0.9702
#   [Ours - DecisionTree]
#     AUROC: 0.8624
#     G-mean: 0.8635
#     MCC: 0.7498
#     F1-score: 0.8326
#     mAP: 0.7946
#   [Ours - kNN]
#     AUROC: 0.9210
#     G-mean: 0.8258
#     MCC: 0.7350
#     F1-score: 0.8005
#     mAP: 0.8803
#   [Ours - MLP]
#     AUROC: 0.9018
#     G-mean: 0.8261
#     MCC: 0.6835
#     F1-score: 0.7869
#     mAP: 0.8885
#   [Ours - RandomForest]
#     AUROC: 0.9813
#     G-mean: 0.9163
#     MCC: 0.8531
#     F1-score: 0.9000
#     mAP: 0.9731
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9767
#     G-mean: 0.9126
#     MCC: 0.8573
#     F1-score: 0.8998
#     mAP: 0.9703
#   [Ours - DecisionTree]
#     AUROC: 0.8618
#     G-mean: 0.8646
#     MCC: 0.7505
#     F1-score: 0.8333
#     mAP: 0.7950
#   [Ours - kNN]
#     AUROC: 0.9219
#     G-mean: 0.8236
#     MCC: 0.7332
#     F1-score: 0.7985
#     mAP: 0.8818
#   [Ours - MLP]
#     AUROC: 0.9027
#     G-mean: 0.8242
#     MCC: 0.6809
#     F1-score: 0.7847
#     mAP: 0.8894
#   [Ours - RandomForest]
#     AUROC: 0.9822
#     G-mean: 0.9156
#     MCC: 0.8524
#     F1-score: 0.8992
#     mAP: 0.9741
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9770
#     G-mean: 0.9123
#     MCC: 0.8571
#     F1-score: 0.8997
#     mAP: 0.9705
#   [Ours - DecisionTree]
#     AUROC: 0.8555
#     G-mean: 0.8605
#     MCC: 0.7463
#     F1-score: 0.8287
#     mAP: 0.7888
#   [Ours - kNN]
#     AUROC: 0.9217
#     G-mean: 0.8199
#     MCC: 0.7302
#     F1-score: 0.7942
#     mAP: 0.8811
#   [Ours - MLP]
#     AUROC: 0.9048
#     G-mean: 0.8223
#     MCC: 0.6772
#     F1-score: 0.7825
#     mAP: 0.8902
#   [Ours - RandomForest]
#     AUROC: 0.9826
#     G-mean: 0.9174
#     MCC: 0.8558
#     F1-score: 0.9015
#     mAP: 0.9742
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9776
#     G-mean: 0.9123
#     MCC: 0.8565
#     F1-score: 0.8994
#     mAP: 0.9710
#   [Ours - DecisionTree]
#     AUROC: 0.8610
#     G-mean: 0.8643
#     MCC: 0.7564
#     F1-score: 0.8346
#     mAP: 0.7966
#   [Ours - kNN]
#     AUROC: 0.9219
#     G-mean: 0.8198
#     MCC: 0.7292
#     F1-score: 0.7937
#     mAP: 0.8806
#   [Ours - MLP]
#     AUROC: 0.9015
#     G-mean: 0.8173
#     MCC: 0.6692
#     F1-score: 0.7762
#     mAP: 0.8867
#   [Ours - RandomForest]
#     AUROC: 0.9828
#     G-mean: 0.9170
#     MCC: 0.8544
#     F1-score: 0.9009
#     mAP: 0.9745
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9779
#     G-mean: 0.9125
#     MCC: 0.8567
#     F1-score: 0.8996
#     mAP: 0.9712
#   [Ours - DecisionTree]
#     AUROC: 0.8631
#     G-mean: 0.8655
#     MCC: 0.7579
#     F1-score: 0.8358
#     mAP: 0.7974
#   [Ours - kNN]
#     AUROC: 0.9226
#     G-mean: 0.8209
#     MCC: 0.7306
#     F1-score: 0.7950
#     mAP: 0.8815
#   [Ours - MLP]
#     AUROC: 0.9024
#     G-mean: 0.8199
#     MCC: 0.6738
#     F1-score: 0.7794
#     mAP: 0.8872
#   [Ours - RandomForest]
#     AUROC: 0.9833
#     G-mean: 0.9170
#     MCC: 0.8548
#     F1-score: 0.9010
#     mAP: 0.9751
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9780
#     G-mean: 0.9122
#     MCC: 0.8563
#     F1-score: 0.8993
#     mAP: 0.9713
#   [Ours - DecisionTree]
#     AUROC: 0.8653
#     G-mean: 0.8659
#     MCC: 0.7582
#     F1-score: 0.8361
#     mAP: 0.7999
#   [Ours - kNN]
#     AUROC: 0.9217
#     G-mean: 0.8206
#     MCC: 0.7296
#     F1-score: 0.7944
#     mAP: 0.8796
#   [Ours - MLP]
#     AUROC: 0.9031
#     G-mean: 0.8206
#     MCC: 0.6745
#     F1-score: 0.7802
#     mAP: 0.8865
#   [Ours - RandomForest]
#     AUROC: 0.9832
#     G-mean: 0.9166
#     MCC: 0.8537
#     F1-score: 0.9004
#     mAP: 0.9748
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9781
#     G-mean: 0.9115
#     MCC: 0.8546
#     F1-score: 0.8982
#     mAP: 0.9713
#   [Ours - DecisionTree]
#     AUROC: 0.8646
#     G-mean: 0.8659
#     MCC: 0.7579
#     F1-score: 0.8358
#     mAP: 0.7980
#   [Ours - kNN]
#     AUROC: 0.9218
#     G-mean: 0.8212
#     MCC: 0.7286
#     F1-score: 0.7948
#     mAP: 0.8799
#   [Ours - MLP]
#     AUROC: 0.9026
#     G-mean: 0.8203
#     MCC: 0.6730
#     F1-score: 0.7797
#     mAP: 0.8852
#   [Ours - RandomForest]
#     AUROC: 0.9830
#     G-mean: 0.9165
#     MCC: 0.8535
#     F1-score: 0.9003
#     mAP: 0.9744
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/ionosphere_results_gaussian_beta_0.005.csv
# beta: 0.001
# Dataset loaded from DataFrame
# X shape : (351, 34)
# target : Counter({0: 225, 1: 126})
# IR: 1.79
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9778
#     G-mean: 0.9036
#     MCC: 0.8448
#     F1-score: 0.8874
#     mAP: 0.9682
#   [Ours - DecisionTree]
#     AUROC: 0.8386
#     G-mean: 0.8558
#     MCC: 0.7432
#     F1-score: 0.8226
#     mAP: 0.7731
#   [Ours - kNN]
#     AUROC: 0.9242
#     G-mean: 0.8198
#     MCC: 0.7284
#     F1-score: 0.7940
#     mAP: 0.8890
#   [Ours - MLP]
#     AUROC: 0.9084
#     G-mean: 0.8217
#     MCC: 0.6828
#     F1-score: 0.7845
#     mAP: 0.8939
#   [Ours - RandomForest]
#     AUROC: 0.9829
#     G-mean: 0.9166
#     MCC: 0.8572
#     F1-score: 0.8988
#     mAP: 0.9752
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9760
#     G-mean: 0.9036
#     MCC: 0.8423
#     F1-score: 0.8889
#     mAP: 0.9675
#   [Ours - DecisionTree]
#     AUROC: 0.8654
#     G-mean: 0.8701
#     MCC: 0.7689
#     F1-score: 0.8422
#     mAP: 0.7994
#   [Ours - kNN]
#     AUROC: 0.9242
#     G-mean: 0.8270
#     MCC: 0.7382
#     F1-score: 0.8027
#     mAP: 0.8887
#   [Ours - MLP]
#     AUROC: 0.9065
#     G-mean: 0.8282
#     MCC: 0.6911
#     F1-score: 0.7900
#     mAP: 0.8901
#   [Ours - RandomForest]
#     AUROC: 0.9825
#     G-mean: 0.9197
#     MCC: 0.8617
#     F1-score: 0.9045
#     mAP: 0.9741
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9771
#     G-mean: 0.9065
#     MCC: 0.8463
#     F1-score: 0.8924
#     mAP: 0.9692
#   [Ours - DecisionTree]
#     AUROC: 0.8432
#     G-mean: 0.8538
#     MCC: 0.7402
#     F1-score: 0.8225
#     mAP: 0.7785
#   [Ours - kNN]
#     AUROC: 0.9218
#     G-mean: 0.8256
#     MCC: 0.7324
#     F1-score: 0.8002
#     mAP: 0.8804
#   [Ours - MLP]
#     AUROC: 0.8975
#     G-mean: 0.8217
#     MCC: 0.6770
#     F1-score: 0.7811
#     mAP: 0.8838
#   [Ours - RandomForest]
#     AUROC: 0.9809
#     G-mean: 0.9185
#     MCC: 0.8592
#     F1-score: 0.9034
#     mAP: 0.9719
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9779
#     G-mean: 0.9089
#     MCC: 0.8498
#     F1-score: 0.8948
#     mAP: 0.9709
#   [Ours - DecisionTree]
#     AUROC: 0.8437
#     G-mean: 0.8532
#     MCC: 0.7351
#     F1-score: 0.8204
#     mAP: 0.7718
#   [Ours - kNN]
#     AUROC: 0.9212
#     G-mean: 0.8247
#     MCC: 0.7304
#     F1-score: 0.7987
#     mAP: 0.8784
#   [Ours - MLP]
#     AUROC: 0.8996
#     G-mean: 0.8272
#     MCC: 0.6874
#     F1-score: 0.7881
#     mAP: 0.8864
#   [Ours - RandomForest]
#     AUROC: 0.9818
#     G-mean: 0.9196
#     MCC: 0.8625
#     F1-score: 0.9052
#     mAP: 0.9734
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9780
#     G-mean: 0.9088
#     MCC: 0.8492
#     F1-score: 0.8948
#     mAP: 0.9710
#   [Ours - DecisionTree]
#     AUROC: 0.8416
#     G-mean: 0.8530
#     MCC: 0.7346
#     F1-score: 0.8201
#     mAP: 0.7712
#   [Ours - kNN]
#     AUROC: 0.9202
#     G-mean: 0.8214
#     MCC: 0.7268
#     F1-score: 0.7950
#     mAP: 0.8776
#   [Ours - MLP]
#     AUROC: 0.9023
#     G-mean: 0.8273
#     MCC: 0.6891
#     F1-score: 0.7885
#     mAP: 0.8888
#   [Ours - RandomForest]
#     AUROC: 0.9826
#     G-mean: 0.9186
#     MCC: 0.8613
#     F1-score: 0.9041
#     mAP: 0.9745
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9785
#     G-mean: 0.9084
#     MCC: 0.8494
#     F1-score: 0.8946
#     mAP: 0.9718
#   [Ours - DecisionTree]
#     AUROC: 0.8409
#     G-mean: 0.8519
#     MCC: 0.7356
#     F1-score: 0.8196
#     mAP: 0.7716
#   [Ours - kNN]
#     AUROC: 0.9196
#     G-mean: 0.8190
#     MCC: 0.7248
#     F1-score: 0.7921
#     mAP: 0.8771
#   [Ours - MLP]
#     AUROC: 0.9017
#     G-mean: 0.8249
#     MCC: 0.6856
#     F1-score: 0.7859
#     mAP: 0.8869
#   [Ours - RandomForest]
#     AUROC: 0.9831
#     G-mean: 0.9199
#     MCC: 0.8633
#     F1-score: 0.9056
#     mAP: 0.9752
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9788
#     G-mean: 0.9090
#     MCC: 0.8499
#     F1-score: 0.8950
#     mAP: 0.9720
#   [Ours - DecisionTree]
#     AUROC: 0.8438
#     G-mean: 0.8538
#     MCC: 0.7404
#     F1-score: 0.8224
#     mAP: 0.7771
#   [Ours - kNN]
#     AUROC: 0.9207
#     G-mean: 0.8185
#     MCC: 0.7240
#     F1-score: 0.7915
#     mAP: 0.8771
#   [Ours - MLP]
#     AUROC: 0.9006
#     G-mean: 0.8233
#     MCC: 0.6832
#     F1-score: 0.7838
#     mAP: 0.8849
#   [Ours - RandomForest]
#     AUROC: 0.9831
#     G-mean: 0.9191
#     MCC: 0.8608
#     F1-score: 0.9043
#     mAP: 0.9751
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9793
#     G-mean: 0.9096
#     MCC: 0.8510
#     F1-score: 0.8958
#     mAP: 0.9723
#   [Ours - DecisionTree]
#     AUROC: 0.8499
#     G-mean: 0.8564
#     MCC: 0.7437
#     F1-score: 0.8251
#     mAP: 0.7807
#   [Ours - kNN]
#     AUROC: 0.9207
#     G-mean: 0.8188
#     MCC: 0.7243
#     F1-score: 0.7919
#     mAP: 0.8778
#   [Ours - MLP]
#     AUROC: 0.9001
#     G-mean: 0.8230
#     MCC: 0.6814
#     F1-score: 0.7834
#     mAP: 0.8844
#   [Ours - RandomForest]
#     AUROC: 0.9835
#     G-mean: 0.9189
#     MCC: 0.8599
#     F1-score: 0.9039
#     mAP: 0.9756
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9795
#     G-mean: 0.9093
#     MCC: 0.8504
#     F1-score: 0.8955
#     mAP: 0.9724
#   [Ours - DecisionTree]
#     AUROC: 0.8514
#     G-mean: 0.8559
#     MCC: 0.7417
#     F1-score: 0.8242
#     mAP: 0.7819
#   [Ours - kNN]
#     AUROC: 0.9203
#     G-mean: 0.8165
#     MCC: 0.7203
#     F1-score: 0.7888
#     mAP: 0.8764
#   [Ours - MLP]
#     AUROC: 0.9001
#     G-mean: 0.8207
#     MCC: 0.6771
#     F1-score: 0.7806
#     mAP: 0.8823
#   [Ours - RandomForest]
#     AUROC: 0.9834
#     G-mean: 0.9186
#     MCC: 0.8589
#     F1-score: 0.9033
#     mAP: 0.9752
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9791
#     G-mean: 0.9092
#     MCC: 0.8494
#     F1-score: 0.8950
#     mAP: 0.9720
#   [Ours - DecisionTree]
#     AUROC: 0.8518
#     G-mean: 0.8567
#     MCC: 0.7416
#     F1-score: 0.8245
#     mAP: 0.7813
#   [Ours - kNN]
#     AUROC: 0.9210
#     G-mean: 0.8162
#     MCC: 0.7192
#     F1-score: 0.7883
#     mAP: 0.8775
#   [Ours - MLP]
#     AUROC: 0.8998
#     G-mean: 0.8196
#     MCC: 0.6740
#     F1-score: 0.7791
#     mAP: 0.8809
#   [Ours - RandomForest]
#     AUROC: 0.9829
#     G-mean: 0.9183
#     MCC: 0.8582
#     F1-score: 0.9030
#     mAP: 0.9745
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/ionosphere_results_gaussian_beta_0.001.csv
# beta: 0.0
# Dataset loaded from DataFrame
# X shape : (351, 34)
# target : Counter({0: 225, 1: 126})
# IR: 1.79
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9803
#     G-mean: 0.9013
#     MCC: 0.8458
#     F1-score: 0.8867
#     mAP: 0.9712
#   [Ours - DecisionTree]
#     AUROC: 0.8515
#     G-mean: 0.8584
#     MCC: 0.7519
#     F1-score: 0.8270
#     mAP: 0.7902
#   [Ours - kNN]
#     AUROC: 0.9216
#     G-mean: 0.8119
#     MCC: 0.7092
#     F1-score: 0.7829
#     mAP: 0.8830
#   [Ours - MLP]
#     AUROC: 0.9237
#     G-mean: 0.8352
#     MCC: 0.7110
#     F1-score: 0.8015
#     mAP: 0.9092
#   [Ours - RandomForest]
#     AUROC: 0.9840
#     G-mean: 0.9166
#     MCC: 0.8572
#     F1-score: 0.8988
#     mAP: 0.9771
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9787
#     G-mean: 0.9084
#     MCC: 0.8526
#     F1-score: 0.8952
#     mAP: 0.9707
#   [Ours - DecisionTree]
#     AUROC: 0.8717
#     G-mean: 0.8652
#     MCC: 0.7578
#     F1-score: 0.8340
#     mAP: 0.7957
#   [Ours - kNN]
#     AUROC: 0.9230
#     G-mean: 0.8232
#     MCC: 0.7285
#     F1-score: 0.7974
#     mAP: 0.8849
#   [Ours - MLP]
#     AUROC: 0.9128
#     G-mean: 0.8211
#     MCC: 0.6901
#     F1-score: 0.7829
#     mAP: 0.8942
#   [Ours - RandomForest]
#     AUROC: 0.9831
#     G-mean: 0.9167
#     MCC: 0.8551
#     F1-score: 0.9004
#     mAP: 0.9749
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9796
#     G-mean: 0.9090
#     MCC: 0.8511
#     F1-score: 0.8953
#     mAP: 0.9722
#   [Ours - DecisionTree]
#     AUROC: 0.8583
#     G-mean: 0.8521
#     MCC: 0.7316
#     F1-score: 0.8177
#     mAP: 0.7771
#   [Ours - kNN]
#     AUROC: 0.9213
#     G-mean: 0.8186
#     MCC: 0.7214
#     F1-score: 0.7916
#     mAP: 0.8776
#   [Ours - MLP]
#     AUROC: 0.9040
#     G-mean: 0.8186
#     MCC: 0.6784
#     F1-score: 0.7784
#     mAP: 0.8847
#   [Ours - RandomForest]
#     AUROC: 0.9819
#     G-mean: 0.9172
#     MCC: 0.8570
#     F1-score: 0.9019
#     mAP: 0.9737
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9791
#     G-mean: 0.9091
#     MCC: 0.8503
#     F1-score: 0.8949
#     mAP: 0.9723
#   [Ours - DecisionTree]
#     AUROC: 0.8531
#     G-mean: 0.8522
#     MCC: 0.7313
#     F1-score: 0.8178
#     mAP: 0.7731
#   [Ours - kNN]
#     AUROC: 0.9203
#     G-mean: 0.8187
#     MCC: 0.7224
#     F1-score: 0.7916
#     mAP: 0.8755
#   [Ours - MLP]
#     AUROC: 0.9026
#     G-mean: 0.8201
#     MCC: 0.6804
#     F1-score: 0.7802
#     mAP: 0.8857
#   [Ours - RandomForest]
#     AUROC: 0.9827
#     G-mean: 0.9176
#     MCC: 0.8580
#     F1-score: 0.9021
#     mAP: 0.9749
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9790
#     G-mean: 0.9086
#     MCC: 0.8484
#     F1-score: 0.8941
#     mAP: 0.9718
#   [Ours - DecisionTree]
#     AUROC: 0.8529
#     G-mean: 0.8547
#     MCC: 0.7365
#     F1-score: 0.8213
#     mAP: 0.7770
#   [Ours - kNN]
#     AUROC: 0.9188
#     G-mean: 0.8165
#     MCC: 0.7205
#     F1-score: 0.7892
#     mAP: 0.8745
#   [Ours - MLP]
#     AUROC: 0.9040
#     G-mean: 0.8216
#     MCC: 0.6835
#     F1-score: 0.7821
#     mAP: 0.8877
#   [Ours - RandomForest]
#     AUROC: 0.9834
#     G-mean: 0.9170
#     MCC: 0.8577
#     F1-score: 0.9016
#     mAP: 0.9761
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9795
#     G-mean: 0.9078
#     MCC: 0.8470
#     F1-score: 0.8933
#     mAP: 0.9726
#   [Ours - DecisionTree]
#     AUROC: 0.8479
#     G-mean: 0.8534
#     MCC: 0.7373
#     F1-score: 0.8207
#     mAP: 0.7766
#   [Ours - kNN]
#     AUROC: 0.9198
#     G-mean: 0.8150
#     MCC: 0.7195
#     F1-score: 0.7873
#     mAP: 0.8762
#   [Ours - MLP]
#     AUROC: 0.9042
#     G-mean: 0.8209
#     MCC: 0.6805
#     F1-score: 0.7813
#     mAP: 0.8870
#   [Ours - RandomForest]
#     AUROC: 0.9839
#     G-mean: 0.9179
#     MCC: 0.8592
#     F1-score: 0.9029
#     mAP: 0.9764
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9797
#     G-mean: 0.9072
#     MCC: 0.8459
#     F1-score: 0.8926
#     mAP: 0.9726
#   [Ours - DecisionTree]
#     AUROC: 0.8505
#     G-mean: 0.8547
#     MCC: 0.7417
#     F1-score: 0.8230
#     mAP: 0.7817
#   [Ours - kNN]
#     AUROC: 0.9206
#     G-mean: 0.8153
#     MCC: 0.7203
#     F1-score: 0.7879
#     mAP: 0.8764
#   [Ours - MLP]
#     AUROC: 0.9051
#     G-mean: 0.8201
#     MCC: 0.6795
#     F1-score: 0.7803
#     mAP: 0.8875
#   [Ours - RandomForest]
#     AUROC: 0.9832
#     G-mean: 0.9177
#     MCC: 0.8581
#     F1-score: 0.9025
#     mAP: 0.9754
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9795
#     G-mean: 0.9087
#     MCC: 0.8483
#     F1-score: 0.8943
#     mAP: 0.9723
#   [Ours - DecisionTree]
#     AUROC: 0.8547
#     G-mean: 0.8571
#     MCC: 0.7448
#     F1-score: 0.8254
#     mAP: 0.7838
#   [Ours - kNN]
#     AUROC: 0.9214
#     G-mean: 0.8175
#     MCC: 0.7234
#     F1-score: 0.7905
#     mAP: 0.8780
#   [Ours - MLP]
#     AUROC: 0.9055
#     G-mean: 0.8186
#     MCC: 0.6771
#     F1-score: 0.7783
#     mAP: 0.8867
#   [Ours - RandomForest]
#     AUROC: 0.9836
#     G-mean: 0.9188
#     MCC: 0.8599
#     F1-score: 0.9039
#     mAP: 0.9757
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9794
#     G-mean: 0.9090
#     MCC: 0.8486
#     F1-score: 0.8947
#     mAP: 0.9721
#   [Ours - DecisionTree]
#     AUROC: 0.8553
#     G-mean: 0.8569
#     MCC: 0.7441
#     F1-score: 0.8252
#     mAP: 0.7849
#   [Ours - kNN]
#     AUROC: 0.9210
#     G-mean: 0.8168
#     MCC: 0.7210
#     F1-score: 0.7893
#     mAP: 0.8762
#   [Ours - MLP]
#     AUROC: 0.9063
#     G-mean: 0.8190
#     MCC: 0.6761
#     F1-score: 0.7785
#     mAP: 0.8871
#   [Ours - RandomForest]
#     AUROC: 0.9836
#     G-mean: 0.9187
#     MCC: 0.8588
#     F1-score: 0.9035
#     mAP: 0.9756
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9790
#     G-mean: 0.9091
#     MCC: 0.8484
#     F1-score: 0.8946
#     mAP: 0.9717
#   [Ours - DecisionTree]
#     AUROC: 0.8572
#     G-mean: 0.8585
#     MCC: 0.7450
#     F1-score: 0.8266
#     mAP: 0.7848
#   [Ours - kNN]
#     AUROC: 0.9211
#     G-mean: 0.8162
#     MCC: 0.7191
#     F1-score: 0.7883
#     mAP: 0.8765
#   [Ours - MLP]
#     AUROC: 0.9049
#     G-mean: 0.8176
#     MCC: 0.6722
#     F1-score: 0.7766
#     mAP: 0.8851
#   [Ours - RandomForest]
#     AUROC: 0.9831
#     G-mean: 0.9180
#     MCC: 0.8568
#     F1-score: 0.9023
#     mAP: 0.9748
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/ionosphere_results_gaussian_beta_0.0.csv
