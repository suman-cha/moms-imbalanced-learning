# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

# Save path 
save_path = "/data4/oldrain123/oldrain123/results/ablation_results/kernel"
data_path = "/data4/oldrain123/oldrain123/dataset"

# %%
import os
import warnings
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from experiment import run_ablation

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
methods = ["Ours"]
beta = 0.01
kernel_types = ['imq', 'rq', 'laplacian']
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}

# %%
# data_name = 'glass-0-1-2-3_vs_4-5-6'

# n_epochs = 1000
# hidden_dims = [8, 16, 32, 64]
# latent_dim = 128
# lr = 0.002

# for kernel_type in kernel_types:
#     print(f"kernel_type: {kernel_type}")
#     run_ablation(
#         data_name=data_name,
#         beta=beta,
#         methods=methods,
#         base_models=base_models,
#         device=device,
#         data_path=data_path,
#         save_path=save_path,
#         visualize=True,
#         n_epochs=n_epochs,
#         hidden_dims=hidden_dims,
#         latent_dim=latent_dim,
#         lr=lr,
#         kernel_type=kernel_type
#     )

# %%
data_name = 'glass4'

n_epochs = 1000
hidden_dims = [8, 16, 32, 64]
latent_dim = 128
lr = 0.002

for kernel_type in kernel_types:
    print(f"kernel_type: {kernel_type}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        visualize=False,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr,
        kernel_type=kernel_type
    )
# Out:
# kernel_type: imq
# Dataset loaded from DataFrame
# X shape : (214, 9)
# target : Counter({0: 201, 1: 13})
# IR: 15.46
#
# Starting experiment 1/10...
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9850
#     G-mean: 0.8821
#     MCC: 0.7274
#     F1-score: 0.7200
#     mAP: 0.8833
#   [Ours - DecisionTree]
#     AUROC: 0.9100
#     G-mean: 0.8690
#     MCC: 0.6738
#     F1-score: 0.6638
#     mAP: 0.5864
#   [Ours - kNN]
#     AUROC: 0.9825
#     G-mean: 0.9718
#     MCC: 0.7606
#     F1-score: 0.7400
#     mAP: 0.7417
#   [Ours - MLP]
#     AUROC: 0.9352
#     G-mean: 0.8369
#     MCC: 0.5042
#     F1-score: 0.4869
#     mAP: 0.6643
#   [Ours - RandomForest]
#     AUROC: 0.9900
#     G-mean: 0.8874
#     MCC: 0.7553
#     F1-score: 0.7467
#     mAP: 0.9333
#
# Starting experiment 2/10...
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9900
#     G-mean: 0.9053
#     MCC: 0.7800
#     F1-score: 0.7700
#     mAP: 0.9166
#   [Ours - DecisionTree]
#     AUROC: 0.9100
#     G-mean: 0.8622
#     MCC: 0.6866
#     F1-score: 0.6736
#     mAP: 0.5917
#   [Ours - kNN]
#     AUROC: 0.9831
#     G-mean: 0.9467
#     MCC: 0.7601
#     F1-score: 0.7450
#     mAP: 0.7850
#   [Ours - MLP]
#     AUROC: 0.9289
#     G-mean: 0.8590
#     MCC: 0.4981
#     F1-score: 0.4797
#     mAP: 0.6451
#   [Ours - RandomForest]
#     AUROC: 0.9900
#     G-mean: 0.9240
#     MCC: 0.8000
#     F1-score: 0.7901
#     mAP: 0.9166
#
# Starting experiment 3/10...
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9883
#     G-mean: 0.9128
#     MCC: 0.7850
#     F1-score: 0.7800
#     mAP: 0.9055
#   [Ours - DecisionTree]
#     AUROC: 0.9017
#     G-mean: 0.8563
#     MCC: 0.6820
#     F1-score: 0.6759
#     mAP: 0.6026
#   [Ours - kNN]
#     AUROC: 0.9796
#     G-mean: 0.9450
#     MCC: 0.7525
#     F1-score: 0.7400
#     mAP: 0.7911
#   [Ours - MLP]
#     AUROC: 0.9310
#     G-mean: 0.8575
#     MCC: 0.5072
#     F1-score: 0.4896
#     mAP: 0.6713
#   [Ours - RandomForest]
#     AUROC: 0.9858
#     G-mean: 0.9338
#     MCC: 0.8113
#     F1-score: 0.8045
#     mAP: 0.8917
#
# Starting experiment 4/10...
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9894
#     G-mean: 0.9064
#     MCC: 0.7849
#     F1-score: 0.7800
#     mAP: 0.9166
#   [Ours - DecisionTree]
#     AUROC: 0.9028
#     G-mean: 0.8551
#     MCC: 0.6904
#     F1-score: 0.6854
#     mAP: 0.6185
#   [Ours - kNN]
#     AUROC: 0.9653
#     G-mean: 0.8780
#     MCC: 0.6938
#     F1-score: 0.6842
#     mAP: 0.7653
#   [Ours - MLP]
#     AUROC: 0.9164
#     G-mean: 0.8495
#     MCC: 0.4995
#     F1-score: 0.4783
#     mAP: 0.6549
#   [Ours - RandomForest]
#     AUROC: 0.9875
#     G-mean: 0.9228
#     MCC: 0.8170
#     F1-score: 0.8117
#     mAP: 0.9062
#
# Starting experiment 5/10...
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9895
#     G-mean: 0.9031
#     MCC: 0.7885
#     F1-score: 0.7833
#     mAP: 0.9150
#   [Ours - DecisionTree]
#     AUROC: 0.9082
#     G-mean: 0.8601
#     MCC: 0.6924
#     F1-score: 0.6863
#     mAP: 0.6124
#   [Ours - kNN]
#     AUROC: 0.9693
#     G-mean: 0.8777
#     MCC: 0.6965
#     F1-score: 0.6867
#     mAP: 0.7823
#   [Ours - MLP]
#     AUROC: 0.9228
#     G-mean: 0.8476
#     MCC: 0.4983
#     F1-score: 0.4764
#     mAP: 0.6629
#   [Ours - RandomForest]
#     AUROC: 0.9880
#     G-mean: 0.9085
#     MCC: 0.7846
#     F1-score: 0.7787
#     mAP: 0.9083
#
# Starting experiment 6/10...
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9892
#     G-mean: 0.9070
#     MCC: 0.7892
#     F1-score: 0.7833
#     mAP: 0.9139
#   [Ours - DecisionTree]
#     AUROC: 0.9035
#     G-mean: 0.8541
#     MCC: 0.6835
#     F1-score: 0.6775
#     mAP: 0.5973
#   [Ours - kNN]
#     AUROC: 0.9722
#     G-mean: 0.8847
#     MCC: 0.7019
#     F1-score: 0.6928
#     mAP: 0.7894
#   [Ours - MLP]
#     AUROC: 0.9261
#     G-mean: 0.8531
#     MCC: 0.4960
#     F1-score: 0.4737
#     mAP: 0.6744
#   [Ours - RandomForest]
#     AUROC: 0.9888
#     G-mean: 0.9128
#     MCC: 0.7958
#     F1-score: 0.7906
#     mAP: 0.9125
#
# Starting experiment 7/10...
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9893
#     G-mean: 0.9038
#     MCC: 0.7855
#     F1-score: 0.7790
#     mAP: 0.9119
#   [Ours - DecisionTree]
#     AUROC: 0.8948
#     G-mean: 0.8387
#     MCC: 0.6663
#     F1-score: 0.6612
#     mAP: 0.5818
#   [Ours - kNN]
#     AUROC: 0.9726
#     G-mean: 0.8836
#     MCC: 0.7027
#     F1-score: 0.6933
#     mAP: 0.7814
#   [Ours - MLP]
#     AUROC: 0.9255
#     G-mean: 0.8373
#     MCC: 0.4862
#     F1-score: 0.4649
#     mAP: 0.6742
#   [Ours - RandomForest]
#     AUROC: 0.9879
#     G-mean: 0.9049
#     MCC: 0.7933
#     F1-score: 0.7872
#     mAP: 0.9012
#
# Starting experiment 8/10...
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9900
#     G-mean: 0.9021
#     MCC: 0.7878
#     F1-score: 0.7812
#     mAP: 0.9166
#   [Ours - DecisionTree]
#     AUROC: 0.8892
#     G-mean: 0.8280
#     MCC: 0.6587
#     F1-score: 0.6535
#     mAP: 0.5744
#   [Ours - kNN]
#     AUROC: 0.9742
#     G-mean: 0.8824
#     MCC: 0.7023
#     F1-score: 0.6921
#     mAP: 0.7879
#   [Ours - MLP]
#     AUROC: 0.9242
#     G-mean: 0.8340
#     MCC: 0.4875
#     F1-score: 0.4676
#     mAP: 0.6823
#   [Ours - RandomForest]
#     AUROC: 0.9888
#     G-mean: 0.8991
#     MCC: 0.7896
#     F1-score: 0.7829
#     mAP: 0.9073
#
# Starting experiment 9/10...
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9897
#     G-mean: 0.9084
#     MCC: 0.7952
#     F1-score: 0.7889
#     mAP: 0.9170
#   [Ours - DecisionTree]
#     AUROC: 0.8906
#     G-mean: 0.8306
#     MCC: 0.6609
#     F1-score: 0.6568
#     mAP: 0.5773
#   [Ours - kNN]
#     AUROC: 0.9747
#     G-mean: 0.8861
#     MCC: 0.6992
#     F1-score: 0.6896
#     mAP: 0.7892
#   [Ours - MLP]
#     AUROC: 0.9268
#     G-mean: 0.8306
#     MCC: 0.4805
#     F1-score: 0.4603
#     mAP: 0.6778
#   [Ours - RandomForest]
#     AUROC: 0.9889
#     G-mean: 0.9053
#     MCC: 0.7919
#     F1-score: 0.7845
#     mAP: 0.9093
#
# Starting experiment 10/10...
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9900
#     G-mean: 0.9134
#     MCC: 0.7994
#     F1-score: 0.7933
#     mAP: 0.9186
#   [Ours - DecisionTree]
#     AUROC: 0.8920
#     G-mean: 0.8329
#     MCC: 0.6673
#     F1-score: 0.6625
#     mAP: 0.5839
#   [Ours - kNN]
#     AUROC: 0.9757
#     G-mean: 0.8913
#     MCC: 0.6968
#     F1-score: 0.6863
#     mAP: 0.7886
#   [Ours - MLP]
#     AUROC: 0.9304
#     G-mean: 0.8365
#     MCC: 0.4822
#     F1-score: 0.4612
#     mAP: 0.6896
#   [Ours - RandomForest]
#     AUROC: 0.9893
#     G-mean: 0.9109
#     MCC: 0.7982
#     F1-score: 0.7907
#     mAP: 0.9117
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/kernel/glass4_results_imq_beta_0.01.csv
# kernel_type: rq
# Dataset loaded from DataFrame
# X shape : (214, 9)
# target : Counter({0: 201, 1: 13})
# IR: 15.46
#
# Starting experiment 1/10...
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9875
#     G-mean: 0.8613
#     MCC: 0.7624
#     F1-score: 0.7633
#     mAP: 0.9167
#   [Ours - DecisionTree]
#     AUROC: 0.9275
#     G-mean: 0.8795
#     MCC: 0.7240
#     F1-score: 0.7167
#     mAP: 0.6798
#   [Ours - kNN]
#     AUROC: 0.9775
#     G-mean: 0.8320
#     MCC: 0.7264
#     F1-score: 0.7300
#     mAP: 0.7750
#   [Ours - MLP]
#     AUROC: 0.9302
#     G-mean: 0.8178
#     MCC: 0.5046
#     F1-score: 0.5002
#     mAP: 0.6894
#   [Ours - RandomForest]
#     AUROC: 1.0000
#     G-mean: 0.8682
#     MCC: 0.8379
#     F1-score: 0.8333
#     mAP: 1.0000
#
# Starting experiment 2/10...
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9888
#     G-mean: 0.9122
#     MCC: 0.8244
#     F1-score: 0.8216
#     mAP: 0.9208
#   [Ours - DecisionTree]
#     AUROC: 0.9313
#     G-mean: 0.8821
#     MCC: 0.7357
#     F1-score: 0.7250
#     mAP: 0.6778
#   [Ours - kNN]
#     AUROC: 0.9668
#     G-mean: 0.8883
#     MCC: 0.7335
#     F1-score: 0.7316
#     mAP: 0.7939
#   [Ours - MLP]
#     AUROC: 0.9164
#     G-mean: 0.8592
#     MCC: 0.5059
#     F1-score: 0.4889
#     mAP: 0.6486
#   [Ours - RandomForest]
#     AUROC: 0.9938
#     G-mean: 0.9156
#     MCC: 0.8653
#     F1-score: 0.8583
#     mAP: 0.9416
#
# Starting experiment 3/10...
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9858
#     G-mean: 0.9173
#     MCC: 0.8262
#     F1-score: 0.8246
#     mAP: 0.9039
#   [Ours - DecisionTree]
#     AUROC: 0.8933
#     G-mean: 0.8272
#     MCC: 0.6765
#     F1-score: 0.6746
#     mAP: 0.6242
#   [Ours - kNN]
#     AUROC: 0.9592
#     G-mean: 0.8982
#     MCC: 0.7378
#     F1-score: 0.7368
#     mAP: 0.7836
#   [Ours - MLP]
#     AUROC: 0.9168
#     G-mean: 0.8498
#     MCC: 0.5062
#     F1-score: 0.4906
#     mAP: 0.6574
#   [Ours - RandomForest]
#     AUROC: 0.9892
#     G-mean: 0.9053
#     MCC: 0.8375
#     F1-score: 0.8333
#     mAP: 0.9111
#
# Starting experiment 4/10...
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9875
#     G-mean: 0.9104
#     MCC: 0.8236
#     F1-score: 0.8218
#     mAP: 0.9154
#   [Ours - DecisionTree]
#     AUROC: 0.9019
#     G-mean: 0.8397
#     MCC: 0.6853
#     F1-score: 0.6819
#     mAP: 0.6210
#   [Ours - kNN]
#     AUROC: 0.9650
#     G-mean: 0.8422
#     MCC: 0.6778
#     F1-score: 0.6743
#     mAP: 0.7898
#   [Ours - MLP]
#     AUROC: 0.9276
#     G-mean: 0.8385
#     MCC: 0.4955
#     F1-score: 0.4767
#     mAP: 0.6702
#   [Ours - RandomForest]
#     AUROC: 0.9906
#     G-mean: 0.9007
#     MCC: 0.8289
#     F1-score: 0.8250
#     mAP: 0.9271
#
# Starting experiment 5/10...
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9890
#     G-mean: 0.8873
#     MCC: 0.8085
#     F1-score: 0.8068
#     mAP: 0.9223
#   [Ours - DecisionTree]
#     AUROC: 0.9075
#     G-mean: 0.8481
#     MCC: 0.7006
#     F1-score: 0.6962
#     mAP: 0.6360
#   [Ours - kNN]
#     AUROC: 0.9570
#     G-mean: 0.8302
#     MCC: 0.6744
#     F1-score: 0.6714
#     mAP: 0.7744
#   [Ours - MLP]
#     AUROC: 0.9280
#     G-mean: 0.8393
#     MCC: 0.4985
#     F1-score: 0.4784
#     mAP: 0.6636
#   [Ours - RandomForest]
#     AUROC: 0.9925
#     G-mean: 0.8791
#     MCC: 0.8100
#     F1-score: 0.8060
#     mAP: 0.9417
#
# Starting experiment 6/10...
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9888
#     G-mean: 0.8948
#     MCC: 0.8134
#     F1-score: 0.8112
#     mAP: 0.9200
#   [Ours - DecisionTree]
#     AUROC: 0.9096
#     G-mean: 0.8592
#     MCC: 0.6988
#     F1-score: 0.6929
#     mAP: 0.6218
#   [Ours - kNN]
#     AUROC: 0.9613
#     G-mean: 0.8460
#     MCC: 0.6872
#     F1-score: 0.6845
#     mAP: 0.7787
#   [Ours - MLP]
#     AUROC: 0.9283
#     G-mean: 0.8440
#     MCC: 0.4918
#     F1-score: 0.4707
#     mAP: 0.6821
#   [Ours - RandomForest]
#     AUROC: 0.9921
#     G-mean: 0.8879
#     MCC: 0.8118
#     F1-score: 0.8078
#     mAP: 0.9375
#
# Starting experiment 7/10...
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9883
#     G-mean: 0.8805
#     MCC: 0.8019
#     F1-score: 0.8001
#     mAP: 0.9100
#   [Ours - DecisionTree]
#     AUROC: 0.8993
#     G-mean: 0.8347
#     MCC: 0.6838
#     F1-score: 0.6792
#     mAP: 0.6195
#   [Ours - kNN]
#     AUROC: 0.9633
#     G-mean: 0.8376
#     MCC: 0.6837
#     F1-score: 0.6815
#     mAP: 0.7746
#   [Ours - MLP]
#     AUROC: 0.9301
#     G-mean: 0.8422
#     MCC: 0.4896
#     F1-score: 0.4673
#     mAP: 0.6792
#   [Ours - RandomForest]
#     AUROC: 0.9911
#     G-mean: 0.8881
#     MCC: 0.8123
#     F1-score: 0.8076
#     mAP: 0.9298
#
# Starting experiment 8/10...
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9891
#     G-mean: 0.8820
#     MCC: 0.8038
#     F1-score: 0.8017
#     mAP: 0.9150
#   [Ours - DecisionTree]
#     AUROC: 0.9038
#     G-mean: 0.8409
#     MCC: 0.6917
#     F1-score: 0.6872
#     mAP: 0.6302
#   [Ours - kNN]
#     AUROC: 0.9657
#     G-mean: 0.8428
#     MCC: 0.6908
#     F1-score: 0.6871
#     mAP: 0.7850
#   [Ours - MLP]
#     AUROC: 0.9235
#     G-mean: 0.8429
#     MCC: 0.4997
#     F1-score: 0.4778
#     mAP: 0.6845
#   [Ours - RandomForest]
#     AUROC: 0.9909
#     G-mean: 0.8884
#     MCC: 0.8098
#     F1-score: 0.8046
#     mAP: 0.9260
#
# Starting experiment 9/10...
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9895
#     G-mean: 0.8904
#     MCC: 0.8087
#     F1-score: 0.8052
#     mAP: 0.9170
#   [Ours - DecisionTree]
#     AUROC: 0.9042
#     G-mean: 0.8423
#     MCC: 0.6903
#     F1-score: 0.6846
#     mAP: 0.6223
#   [Ours - kNN]
#     AUROC: 0.9651
#     G-mean: 0.8435
#     MCC: 0.6853
#     F1-score: 0.6808
#     mAP: 0.7909
#   [Ours - MLP]
#     AUROC: 0.9242
#     G-mean: 0.8493
#     MCC: 0.4993
#     F1-score: 0.4761
#     mAP: 0.6824
#   [Ours - RandomForest]
#     AUROC: 0.9906
#     G-mean: 0.8961
#     MCC: 0.8121
#     F1-score: 0.8059
#     mAP: 0.9250
#
# Starting experiment 10/10...
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9898
#     G-mean: 0.8943
#     MCC: 0.8085
#     F1-score: 0.8047
#     mAP: 0.9187
#   [Ours - DecisionTree]
#     AUROC: 0.9060
#     G-mean: 0.8493
#     MCC: 0.6907
#     F1-score: 0.6842
#     mAP: 0.6233
#   [Ours - kNN]
#     AUROC: 0.9650
#     G-mean: 0.8537
#     MCC: 0.6889
#     F1-score: 0.6827
#     mAP: 0.7898
#   [Ours - MLP]
#     AUROC: 0.9278
#     G-mean: 0.8530
#     MCC: 0.5003
#     F1-score: 0.4776
#     mAP: 0.6933
#   [Ours - RandomForest]
#     AUROC: 0.9908
#     G-mean: 0.8994
#     MCC: 0.8116
#     F1-score: 0.8053
#     mAP: 0.9258
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/kernel/glass4_results_rq_beta_0.01.csv
# kernel_type: laplacian
# Dataset loaded from DataFrame
# X shape : (214, 9)
# target : Counter({0: 201, 1: 13})
# IR: 15.46
#
# Starting experiment 1/10...
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9800
#     G-mean: 0.8631
#     MCC: 0.7792
#     F1-score: 0.7800
#     mAP: 0.8750
#   [Ours - DecisionTree]
#     AUROC: 0.9088
#     G-mean: 0.8543
#     MCC: 0.7226
#     F1-score: 0.7200
#     mAP: 0.6676
#   [Ours - kNN]
#     AUROC: 0.9725
#     G-mean: 0.7536
#     MCC: 0.5908
#     F1-score: 0.5967
#     mAP: 0.7333
#   [Ours - MLP]
#     AUROC: 0.9402
#     G-mean: 0.7385
#     MCC: 0.5128
#     F1-score: 0.5186
#     mAP: 0.6117
#   [Ours - RandomForest]
#     AUROC: 0.9950
#     G-mean: 0.7581
#     MCC: 0.6349
#     F1-score: 0.6267
#     mAP: 0.9500
#
# Starting experiment 2/10...
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9850
#     G-mean: 0.8959
#     MCC: 0.7947
#     F1-score: 0.7883
#     mAP: 0.9000
#   [Ours - DecisionTree]
#     AUROC: 0.9069
#     G-mean: 0.8526
#     MCC: 0.7093
#     F1-score: 0.7050
#     mAP: 0.6406
#   [Ours - kNN]
#     AUROC: 0.9757
#     G-mean: 0.8518
#     MCC: 0.6875
#     F1-score: 0.6884
#     mAP: 0.7792
#   [Ours - MLP]
#     AUROC: 0.9327
#     G-mean: 0.8068
#     MCC: 0.4937
#     F1-score: 0.4838
#     mAP: 0.6560
#   [Ours - RandomForest]
#     AUROC: 0.9912
#     G-mean: 0.8473
#     MCC: 0.7554
#     F1-score: 0.7467
#     mAP: 0.9166
#
# Starting experiment 3/10...
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9850
#     G-mean: 0.8849
#     MCC: 0.7958
#     F1-score: 0.7922
#     mAP: 0.8944
#   [Ours - DecisionTree]
#     AUROC: 0.8963
#     G-mean: 0.8417
#     MCC: 0.6907
#     F1-score: 0.6857
#     mAP: 0.6117
#   [Ours - kNN]
#     AUROC: 0.9775
#     G-mean: 0.8512
#     MCC: 0.6931
#     F1-score: 0.6913
#     mAP: 0.7983
#   [Ours - MLP]
#     AUROC: 0.9393
#     G-mean: 0.8225
#     MCC: 0.5188
#     F1-score: 0.5071
#     mAP: 0.6827
#   [Ours - RandomForest]
#     AUROC: 0.9892
#     G-mean: 0.8833
#     MCC: 0.7896
#     F1-score: 0.7811
#     mAP: 0.9055
#
# Starting experiment 4/10...
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9869
#     G-mean: 0.8611
#     MCC: 0.7758
#     F1-score: 0.7725
#     mAP: 0.9083
#   [Ours - DecisionTree]
#     AUROC: 0.9166
#     G-mean: 0.8754
#     MCC: 0.7299
#     F1-score: 0.7244
#     mAP: 0.6521
#   [Ours - kNN]
#     AUROC: 0.9525
#     G-mean: 0.8083
#     MCC: 0.6529
#     F1-score: 0.6510
#     mAP: 0.7657
#   [Ours - MLP]
#     AUROC: 0.9220
#     G-mean: 0.8004
#     MCC: 0.4985
#     F1-score: 0.4825
#     mAP: 0.6903
#   [Ours - RandomForest]
#     AUROC: 0.9888
#     G-mean: 0.8592
#     MCC: 0.7680
#     F1-score: 0.7609
#     mAP: 0.9041
#
# Starting experiment 5/10...
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9875
#     G-mean: 0.8469
#     MCC: 0.7613
#     F1-score: 0.7573
#     mAP: 0.9083
#   [Ours - DecisionTree]
#     AUROC: 0.9198
#     G-mean: 0.8757
#     MCC: 0.7214
#     F1-score: 0.7135
#     mAP: 0.6509
#   [Ours - kNN]
#     AUROC: 0.9490
#     G-mean: 0.8030
#     MCC: 0.6514
#     F1-score: 0.6501
#     mAP: 0.7735
#   [Ours - MLP]
#     AUROC: 0.9249
#     G-mean: 0.7852
#     MCC: 0.4896
#     F1-score: 0.4758
#     mAP: 0.6851
#   [Ours - RandomForest]
#     AUROC: 0.9900
#     G-mean: 0.8649
#     MCC: 0.7654
#     F1-score: 0.7580
#     mAP: 0.9150
#
# Starting experiment 6/10...
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9883
#     G-mean: 0.8606
#     MCC: 0.7717
#     F1-score: 0.7672
#     mAP: 0.9125
#   [Ours - DecisionTree]
#     AUROC: 0.9140
#     G-mean: 0.8683
#     MCC: 0.7217
#     F1-score: 0.7141
#     mAP: 0.6503
#   [Ours - kNN]
#     AUROC: 0.9517
#     G-mean: 0.8272
#     MCC: 0.6681
#     F1-score: 0.6656
#     mAP: 0.7801
#   [Ours - MLP]
#     AUROC: 0.9249
#     G-mean: 0.8016
#     MCC: 0.4907
#     F1-score: 0.4754
#     mAP: 0.7025
#   [Ours - RandomForest]
#     AUROC: 0.9904
#     G-mean: 0.8761
#     MCC: 0.7775
#     F1-score: 0.7706
#     mAP: 0.9180
#
# Starting experiment 7/10...
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9886
#     G-mean: 0.8644
#     MCC: 0.7734
#     F1-score: 0.7681
#     mAP: 0.9107
#   [Ours - DecisionTree]
#     AUROC: 0.8988
#     G-mean: 0.8384
#     MCC: 0.6973
#     F1-score: 0.6925
#     mAP: 0.6303
#   [Ours - kNN]
#     AUROC: 0.9551
#     G-mean: 0.8215
#     MCC: 0.6670
#     F1-score: 0.6653
#     mAP: 0.7758
#   [Ours - MLP]
#     AUROC: 0.9201
#     G-mean: 0.7930
#     MCC: 0.4857
#     F1-score: 0.4716
#     mAP: 0.7047
#   [Ours - RandomForest]
#     AUROC: 0.9900
#     G-mean: 0.8736
#     MCC: 0.7733
#     F1-score: 0.7672
#     mAP: 0.9131
#
# Starting experiment 8/10...
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9888
#     G-mean: 0.8639
#     MCC: 0.7733
#     F1-score: 0.7675
#     mAP: 0.9094
#   [Ours - DecisionTree]
#     AUROC: 0.8967
#     G-mean: 0.8317
#     MCC: 0.6910
#     F1-score: 0.6864
#     mAP: 0.6235
#   [Ours - kNN]
#     AUROC: 0.9521
#     G-mean: 0.8244
#     MCC: 0.6705
#     F1-score: 0.6670
#     mAP: 0.7742
#   [Ours - MLP]
#     AUROC: 0.9154
#     G-mean: 0.7969
#     MCC: 0.4945
#     F1-score: 0.4795
#     mAP: 0.7048
#   [Ours - RandomForest]
#     AUROC: 0.9906
#     G-mean: 0.8719
#     MCC: 0.7760
#     F1-score: 0.7696
#     mAP: 0.9177
#
# Starting experiment 9/10...
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9889
#     G-mean: 0.8633
#     MCC: 0.7716
#     F1-score: 0.7652
#     mAP: 0.9111
#   [Ours - DecisionTree]
#     AUROC: 0.8835
#     G-mean: 0.8048
#     MCC: 0.6705
#     F1-score: 0.6679
#     mAP: 0.6114
#   [Ours - kNN]
#     AUROC: 0.9515
#     G-mean: 0.8241
#     MCC: 0.6655
#     F1-score: 0.6614
#     mAP: 0.7702
#   [Ours - MLP]
#     AUROC: 0.9184
#     G-mean: 0.8093
#     MCC: 0.5006
#     F1-score: 0.4842
#     mAP: 0.7034
#   [Ours - RandomForest]
#     AUROC: 0.9900
#     G-mean: 0.8710
#     MCC: 0.7754
#     F1-score: 0.7693
#     mAP: 0.9129
#
# Starting experiment 10/10...
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9885
#     G-mean: 0.8701
#     MCC: 0.7765
#     F1-score: 0.7703
#     mAP: 0.9067
#   [Ours - DecisionTree]
#     AUROC: 0.8861
#     G-mean: 0.8098
#     MCC: 0.6738
#     F1-score: 0.6708
#     mAP: 0.6133
#   [Ours - kNN]
#     AUROC: 0.9519
#     G-mean: 0.8266
#     MCC: 0.6613
#     F1-score: 0.6569
#     mAP: 0.7611
#   [Ours - MLP]
#     AUROC: 0.9231
#     G-mean: 0.8178
#     MCC: 0.5017
#     F1-score: 0.4842
#     mAP: 0.7109
#   [Ours - RandomForest]
#     AUROC: 0.9898
#     G-mean: 0.8694
#     MCC: 0.7689
#     F1-score: 0.7620
#     mAP: 0.9108
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/kernel/glass4_results_laplacian_beta_0.01.csv

# %%
data_name = 'glass-0-1-6_vs_5'

n_epochs = 1000
hidden_dims = [32, 64, 128, 256]
latent_dim = 512
lr = 0.004

for kernel_type in kernel_types:
    print(f"kernel_type: {kernel_type}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        visualize=False,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr,
        kernel_type=kernel_type
    )
# Out:
# kernel_type: imq
# Dataset loaded from DataFrame
# X shape : (184, 9)
# target : Counter({0: 175, 1: 9})
# IR: 19.44
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9938
#     G-mean: 0.6944
#     MCC: 0.6319
#     F1-score: 0.6333
#     mAP: 0.9444
#   [Ours - DecisionTree]
#     AUROC: 0.7191
#     G-mean: 0.3972
#     MCC: 0.3687
#     F1-score: 0.3667
#     mAP: 0.4188
#   [Ours - kNN]
#     AUROC: 0.9907
#     G-mean: 0.8915
#     MCC: 0.8232
#     F1-score: 0.8167
#     mAP: 0.8704
#   [Ours - MLP]
#     AUROC: 0.9365
#     G-mean: 0.7855
#     MCC: 0.3618
#     F1-score: 0.3124
#     mAP: 0.6018
#   [Ours - RandomForest]
#     AUROC: 1.0000
#     G-mean: 0.7972
#     MCC: 0.7687
#     F1-score: 0.7667
#     mAP: 1.0000
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9937
#     G-mean: 0.6957
#     MCC: 0.6473
#     F1-score: 0.6500
#     mAP: 0.9444
#   [Ours - DecisionTree]
#     AUROC: 0.7746
#     G-mean: 0.4986
#     MCC: 0.4814
#     F1-score: 0.4834
#     mAP: 0.5520
#   [Ours - kNN]
#     AUROC: 0.9856
#     G-mean: 0.8398
#     MCC: 0.7459
#     F1-score: 0.7417
#     mAP: 0.8518
#   [Ours - MLP]
#     AUROC: 0.9325
#     G-mean: 0.7988
#     MCC: 0.4275
#     F1-score: 0.3849
#     mAP: 0.6296
#   [Ours - RandomForest]
#     AUROC: 1.0000
#     G-mean: 0.7471
#     MCC: 0.7187
#     F1-score: 0.7167
#     mAP: 1.0000
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9917
#     G-mean: 0.6961
#     MCC: 0.6517
#     F1-score: 0.6556
#     mAP: 0.9382
#   [Ours - DecisionTree]
#     AUROC: 0.7889
#     G-mean: 0.5285
#     MCC: 0.4848
#     F1-score: 0.4833
#     mAP: 0.5343
#   [Ours - kNN]
#     AUROC: 0.9687
#     G-mean: 0.8246
#     MCC: 0.7403
#     F1-score: 0.7389
#     mAP: 0.8476
#   [Ours - MLP]
#     AUROC: 0.9362
#     G-mean: 0.7987
#     MCC: 0.4251
#     F1-score: 0.3819
#     mAP: 0.6658
#   [Ours - RandomForest]
#     AUROC: 0.9979
#     G-mean: 0.6971
#     MCC: 0.6687
#     F1-score: 0.6667
#     mAP: 0.9815
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9875
#     G-mean: 0.6956
#     MCC: 0.6461
#     F1-score: 0.6500
#     mAP: 0.9190
#   [Ours - DecisionTree]
#     AUROC: 0.8115
#     G-mean: 0.5691
#     MCC: 0.5193
#     F1-score: 0.5167
#     mAP: 0.5658
#   [Ours - kNN]
#     AUROC: 0.9742
#     G-mean: 0.8155
#     MCC: 0.7281
#     F1-score: 0.7250
#     mAP: 0.8533
#   [Ours - MLP]
#     AUROC: 0.9349
#     G-mean: 0.7952
#     MCC: 0.4129
#     F1-score: 0.3691
#     mAP: 0.6507
#   [Ours - RandomForest]
#     AUROC: 0.9968
#     G-mean: 0.7214
#     MCC: 0.6858
#     F1-score: 0.6833
#     mAP: 0.9722
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9887
#     G-mean: 0.6953
#     MCC: 0.6466
#     F1-score: 0.6500
#     mAP: 0.9240
#   [Ours - DecisionTree]
#     AUROC: 0.8368
#     G-mean: 0.6141
#     MCC: 0.5629
#     F1-score: 0.5600
#     mAP: 0.6094
#   [Ours - kNN]
#     AUROC: 0.9768
#     G-mean: 0.8106
#     MCC: 0.7260
#     F1-score: 0.7233
#     mAP: 0.8493
#   [Ours - MLP]
#     AUROC: 0.9352
#     G-mean: 0.7877
#     MCC: 0.4077
#     F1-score: 0.3649
#     mAP: 0.6335
#   [Ours - RandomForest]
#     AUROC: 0.9975
#     G-mean: 0.7165
#     MCC: 0.6824
#     F1-score: 0.6800
#     mAP: 0.9778
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9885
#     G-mean: 0.6956
#     MCC: 0.6493
#     F1-score: 0.6528
#     mAP: 0.9182
#   [Ours - DecisionTree]
#     AUROC: 0.8444
#     G-mean: 0.6280
#     MCC: 0.5795
#     F1-score: 0.5778
#     mAP: 0.6302
#   [Ours - kNN]
#     AUROC: 0.9704
#     G-mean: 0.8069
#     MCC: 0.7174
#     F1-score: 0.7139
#     mAP: 0.8384
#   [Ours - MLP]
#     AUROC: 0.9374
#     G-mean: 0.7925
#     MCC: 0.4195
#     F1-score: 0.3779
#     mAP: 0.6406
#   [Ours - RandomForest]
#     AUROC: 0.9979
#     G-mean: 0.7133
#     MCC: 0.6801
#     F1-score: 0.6778
#     mAP: 0.9815
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9893
#     G-mean: 0.6958
#     MCC: 0.6512
#     F1-score: 0.6548
#     mAP: 0.9219
#   [Ours - DecisionTree]
#     AUROC: 0.8480
#     G-mean: 0.6362
#     MCC: 0.5735
#     F1-score: 0.5714
#     mAP: 0.6133
#   [Ours - kNN]
#     AUROC: 0.9728
#     G-mean: 0.8051
#     MCC: 0.7203
#     F1-score: 0.7167
#     mAP: 0.8377
#   [Ours - MLP]
#     AUROC: 0.9409
#     G-mean: 0.7923
#     MCC: 0.4152
#     F1-score: 0.3731
#     mAP: 0.6634
#   [Ours - RandomForest]
#     AUROC: 0.9982
#     G-mean: 0.7253
#     MCC: 0.6928
#     F1-score: 0.6905
#     mAP: 0.9841
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9906
#     G-mean: 0.6952
#     MCC: 0.6477
#     F1-score: 0.6500
#     mAP: 0.9317
#   [Ours - DecisionTree]
#     AUROC: 0.8593
#     G-mean: 0.6560
#     MCC: 0.5940
#     F1-score: 0.5917
#     mAP: 0.6346
#   [Ours - kNN]
#     AUROC: 0.9758
#     G-mean: 0.8034
#     MCC: 0.7206
#     F1-score: 0.7167
#     mAP: 0.8510
#   [Ours - MLP]
#     AUROC: 0.9394
#     G-mean: 0.7927
#     MCC: 0.4106
#     F1-score: 0.3678
#     mAP: 0.6522
#   [Ours - RandomForest]
#     AUROC: 0.9984
#     G-mean: 0.7346
#     MCC: 0.7062
#     F1-score: 0.7042
#     mAP: 0.9861
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9910
#     G-mean: 0.6944
#     MCC: 0.6396
#     F1-score: 0.6408
#     mAP: 0.9331
#   [Ours - DecisionTree]
#     AUROC: 0.8674
#     G-mean: 0.6707
#     MCC: 0.6049
#     F1-score: 0.6019
#     mAP: 0.6430
#   [Ours - kNN]
#     AUROC: 0.9778
#     G-mean: 0.8128
#     MCC: 0.7266
#     F1-score: 0.7222
#     mAP: 0.8552
#   [Ours - MLP]
#     AUROC: 0.9413
#     G-mean: 0.7938
#     MCC: 0.4088
#     F1-score: 0.3655
#     mAP: 0.6662
#   [Ours - RandomForest]
#     AUROC: 0.9979
#     G-mean: 0.7412
#     MCC: 0.7096
#     F1-score: 0.7074
#     mAP: 0.9815
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9906
#     G-mean: 0.6950
#     MCC: 0.6445
#     F1-score: 0.6467
#     mAP: 0.9287
#   [Ours - DecisionTree]
#     AUROC: 0.8741
#     G-mean: 0.6828
#     MCC: 0.6150
#     F1-score: 0.6117
#     mAP: 0.6515
#   [Ours - kNN]
#     AUROC: 0.9785
#     G-mean: 0.8112
#     MCC: 0.7300
#     F1-score: 0.7267
#     mAP: 0.8568
#   [Ours - MLP]
#     AUROC: 0.9427
#     G-mean: 0.7959
#     MCC: 0.4108
#     F1-score: 0.3674
#     mAP: 0.6727
#   [Ours - RandomForest]
#     AUROC: 0.9981
#     G-mean: 0.7468
#     MCC: 0.7155
#     F1-score: 0.7133
#     mAP: 0.9833
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/kernel/glass-0-1-6_vs_5_results_imq_beta_0.01.csv
# kernel_type: rq
# Dataset loaded from DataFrame
# X shape : (184, 9)
# target : Counter({0: 175, 1: 9})
# IR: 19.44
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9746
#     G-mean: 0.7915
#     MCC: 0.7232
#     F1-score: 0.7167
#     mAP: 0.8148
#   [Ours - DecisionTree]
#     AUROC: 0.8272
#     G-mean: 0.5944
#     MCC: 0.5374
#     F1-score: 0.5333
#     mAP: 0.5734
#   [Ours - kNN]
#     AUROC: 0.9876
#     G-mean: 0.7915
#     MCC: 0.7176
#     F1-score: 0.7167
#     mAP: 0.8704
#   [Ours - MLP]
#     AUROC: 0.9492
#     G-mean: 0.7925
#     MCC: 0.3705
#     F1-score: 0.3208
#     mAP: 0.6296
#   [Ours - RandomForest]
#     AUROC: 1.0000
#     G-mean: 0.6972
#     MCC: 0.6687
#     F1-score: 0.6667
#     mAP: 1.0000
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9841
#     G-mean: 0.7429
#     MCC: 0.6773
#     F1-score: 0.6750
#     mAP: 0.8796
#   [Ours - DecisionTree]
#     AUROC: 0.8532
#     G-mean: 0.6457
#     MCC: 0.5971
#     F1-score: 0.6000
#     mAP: 0.6540
#   [Ours - kNN]
#     AUROC: 0.9872
#     G-mean: 0.7913
#     MCC: 0.7088
#     F1-score: 0.7084
#     mAP: 0.8797
#   [Ours - MLP]
#     AUROC: 0.9423
#     G-mean: 0.7952
#     MCC: 0.4225
#     F1-score: 0.3799
#     mAP: 0.5972
#   [Ours - RandomForest]
#     AUROC: 1.0000
#     G-mean: 0.7471
#     MCC: 0.7187
#     F1-score: 0.7167
#     mAP: 1.0000
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9831
#     G-mean: 0.7590
#     MCC: 0.6925
#     F1-score: 0.6889
#     mAP: 0.8765
#   [Ours - DecisionTree]
#     AUROC: 0.8619
#     G-mean: 0.6609
#     MCC: 0.6057
#     F1-score: 0.6056
#     mAP: 0.6559
#   [Ours - kNN]
#     AUROC: 0.9698
#     G-mean: 0.7912
#     MCC: 0.7108
#     F1-score: 0.7111
#     mAP: 0.8662
#   [Ours - MLP]
#     AUROC: 0.9488
#     G-mean: 0.8008
#     MCC: 0.4264
#     F1-score: 0.3828
#     mAP: 0.6450
#   [Ours - RandomForest]
#     AUROC: 1.0000
#     G-mean: 0.7295
#     MCC: 0.6972
#     F1-score: 0.6945
#     mAP: 1.0000
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9810
#     G-mean: 0.7428
#     MCC: 0.6767
#     F1-score: 0.6750
#     mAP: 0.8727
#   [Ours - DecisionTree]
#     AUROC: 0.8663
#     G-mean: 0.6685
#     MCC: 0.6100
#     F1-score: 0.6083
#     mAP: 0.6571
#   [Ours - kNN]
#     AUROC: 0.9611
#     G-mean: 0.7905
#     MCC: 0.7060
#     F1-score: 0.7042
#     mAP: 0.8409
#   [Ours - MLP]
#     AUROC: 0.9491
#     G-mean: 0.8016
#     MCC: 0.4257
#     F1-score: 0.3827
#     mAP: 0.6652
#   [Ours - RandomForest]
#     AUROC: 0.9952
#     G-mean: 0.7214
#     MCC: 0.6886
#     F1-score: 0.6875
#     mAP: 0.9583
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9836
#     G-mean: 0.7524
#     MCC: 0.6859
#     F1-score: 0.6833
#     mAP: 0.8870
#   [Ours - DecisionTree]
#     AUROC: 0.8689
#     G-mean: 0.6736
#     MCC: 0.6144
#     F1-score: 0.6133
#     mAP: 0.6613
#   [Ours - kNN]
#     AUROC: 0.9645
#     G-mean: 0.7906
#     MCC: 0.7083
#     F1-score: 0.7067
#     mAP: 0.8357
#   [Ours - MLP]
#     AUROC: 0.9389
#     G-mean: 0.7928
#     MCC: 0.4192
#     F1-score: 0.3774
#     mAP: 0.6248
#   [Ours - RandomForest]
#     AUROC: 0.9962
#     G-mean: 0.7165
#     MCC: 0.6846
#     F1-score: 0.6834
#     mAP: 0.9667
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9842
#     G-mean: 0.7432
#     MCC: 0.6821
#     F1-score: 0.6806
#     mAP: 0.8873
#   [Ours - DecisionTree]
#     AUROC: 0.8701
#     G-mean: 0.6771
#     MCC: 0.6168
#     F1-score: 0.6167
#     mAP: 0.6642
#   [Ours - kNN]
#     AUROC: 0.9688
#     G-mean: 0.7907
#     MCC: 0.7079
#     F1-score: 0.7056
#     mAP: 0.8445
#   [Ours - MLP]
#     AUROC: 0.9437
#     G-mean: 0.7963
#     MCC: 0.4258
#     F1-score: 0.3843
#     mAP: 0.6472
#   [Ours - RandomForest]
#     AUROC: 0.9962
#     G-mean: 0.7300
#     MCC: 0.6986
#     F1-score: 0.6973
#     mAP: 0.9629
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9856
#     G-mean: 0.7366
#     MCC: 0.6794
#     F1-score: 0.6786
#     mAP: 0.8955
#   [Ours - DecisionTree]
#     AUROC: 0.8789
#     G-mean: 0.6930
#     MCC: 0.6250
#     F1-score: 0.6238
#     mAP: 0.6655
#   [Ours - kNN]
#     AUROC: 0.9719
#     G-mean: 0.7908
#     MCC: 0.7076
#     F1-score: 0.7048
#     mAP: 0.8429
#   [Ours - MLP]
#     AUROC: 0.9444
#     G-mean: 0.7949
#     MCC: 0.4204
#     F1-score: 0.3787
#     mAP: 0.6585
#   [Ours - RandomForest]
#     AUROC: 0.9959
#     G-mean: 0.7392
#     MCC: 0.7042
#     F1-score: 0.7024
#     mAP: 0.9603
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9858
#     G-mean: 0.7309
#     MCC: 0.6723
#     F1-score: 0.6708
#     mAP: 0.8947
#   [Ours - DecisionTree]
#     AUROC: 0.8790
#     G-mean: 0.6927
#     MCC: 0.6226
#     F1-score: 0.6208
#     mAP: 0.6602
#   [Ours - kNN]
#     AUROC: 0.9750
#     G-mean: 0.7909
#     MCC: 0.7095
#     F1-score: 0.7063
#     mAP: 0.8556
#   [Ours - MLP]
#     AUROC: 0.9433
#     G-mean: 0.7949
#     MCC: 0.4147
#     F1-score: 0.3720
#     mAP: 0.6548
#   [Ours - RandomForest]
#     AUROC: 0.9956
#     G-mean: 0.7339
#     MCC: 0.6990
#     F1-score: 0.6979
#     mAP: 0.9583
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9874
#     G-mean: 0.7376
#     MCC: 0.6760
#     F1-score: 0.6741
#     mAP: 0.9064
#   [Ours - DecisionTree]
#     AUROC: 0.8725
#     G-mean: 0.6815
#     MCC: 0.6090
#     F1-score: 0.6074
#     mAP: 0.6444
#   [Ours - kNN]
#     AUROC: 0.9771
#     G-mean: 0.8017
#     MCC: 0.7168
#     F1-score: 0.7130
#     mAP: 0.8593
#   [Ours - MLP]
#     AUROC: 0.9440
#     G-mean: 0.7961
#     MCC: 0.4151
#     F1-score: 0.3724
#     mAP: 0.6665
#   [Ours - RandomForest]
#     AUROC: 0.9954
#     G-mean: 0.7295
#     MCC: 0.6922
#     F1-score: 0.6908
#     mAP: 0.9568
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9874
#     G-mean: 0.7339
#     MCC: 0.6773
#     F1-score: 0.6767
#     mAP: 0.9046
#   [Ours - DecisionTree]
#     AUROC: 0.8784
#     G-mean: 0.6921
#     MCC: 0.6195
#     F1-score: 0.6173
#     mAP: 0.6556
#   [Ours - kNN]
#     AUROC: 0.9779
#     G-mean: 0.8012
#     MCC: 0.7211
#     F1-score: 0.7184
#     mAP: 0.8604
#   [Ours - MLP]
#     AUROC: 0.9452
#     G-mean: 0.7986
#     MCC: 0.4179
#     F1-score: 0.3753
#     mAP: 0.6730
#   [Ours - RandomForest]
#     AUROC: 0.9958
#     G-mean: 0.7363
#     MCC: 0.6998
#     F1-score: 0.6984
#     mAP: 0.9611
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/kernel/glass-0-1-6_vs_5_results_rq_beta_0.01.csv
# kernel_type: laplacian
# Dataset loaded from DataFrame
# X shape : (184, 9)
# target : Counter({0: 175, 1: 9})
# IR: 19.44
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9938
#     G-mean: 0.7943
#     MCC: 0.7489
#     F1-score: 0.7500
#     mAP: 0.9444
#   [Ours - DecisionTree]
#     AUROC: 0.9381
#     G-mean: 0.7942
#     MCC: 0.7373
#     F1-score: 0.7333
#     mAP: 0.7836
#   [Ours - kNN]
#     AUROC: 0.9876
#     G-mean: 0.7915
#     MCC: 0.7176
#     F1-score: 0.7167
#     mAP: 0.8704
#   [Ours - MLP]
#     AUROC: 0.9303
#     G-mean: 0.8118
#     MCC: 0.4264
#     F1-score: 0.3836
#     mAP: 0.5833
#   [Ours - RandomForest]
#     AUROC: 1.0000
#     G-mean: 0.6972
#     MCC: 0.6687
#     F1-score: 0.6667
#     mAP: 1.0000
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9937
#     G-mean: 0.7943
#     MCC: 0.7402
#     F1-score: 0.7416
#     mAP: 0.9444
#   [Ours - DecisionTree]
#     AUROC: 0.9103
#     G-mean: 0.7457
#     MCC: 0.7000
#     F1-score: 0.7000
#     mAP: 0.7591
#   [Ours - kNN]
#     AUROC: 0.9889
#     G-mean: 0.7899
#     MCC: 0.6932
#     F1-score: 0.6917
#     mAP: 0.8797
#   [Ours - MLP]
#     AUROC: 0.9171
#     G-mean: 0.7983
#     MCC: 0.4362
#     F1-score: 0.3960
#     mAP: 0.5759
#   [Ours - RandomForest]
#     AUROC: 1.0000
#     G-mean: 0.7457
#     MCC: 0.7030
#     F1-score: 0.7000
#     mAP: 1.0000
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9917
#     G-mean: 0.7618
#     MCC: 0.7136
#     F1-score: 0.7167
#     mAP: 0.9382
#   [Ours - DecisionTree]
#     AUROC: 0.9185
#     G-mean: 0.7609
#     MCC: 0.7020
#     F1-score: 0.7000
#     mAP: 0.7488
#   [Ours - kNN]
#     AUROC: 0.9874
#     G-mean: 0.8217
#     MCC: 0.7155
#     F1-score: 0.7111
#     mAP: 0.8766
#   [Ours - MLP]
#     AUROC: 0.9299
#     G-mean: 0.8027
#     MCC: 0.4306
#     F1-score: 0.3890
#     mAP: 0.6278
#   [Ours - RandomForest]
#     AUROC: 1.0000
#     G-mean: 0.6952
#     MCC: 0.6535
#     F1-score: 0.6500
#     mAP: 1.0000
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9890
#     G-mean: 0.7449
#     MCC: 0.6925
#     F1-score: 0.6958
#     mAP: 0.9213
#   [Ours - DecisionTree]
#     AUROC: 0.9242
#     G-mean: 0.7699
#     MCC: 0.7187
#     F1-score: 0.7167
#     mAP: 0.7714
#   [Ours - kNN]
#     AUROC: 0.9751
#     G-mean: 0.8126
#     MCC: 0.7017
#     F1-score: 0.6958
#     mAP: 0.8533
#   [Ours - MLP]
#     AUROC: 0.9365
#     G-mean: 0.8023
#     MCC: 0.4251
#     F1-score: 0.3832
#     mAP: 0.6421
#   [Ours - RandomForest]
#     AUROC: 0.9984
#     G-mean: 0.7200
#     MCC: 0.6744
#     F1-score: 0.6708
#     mAP: 0.9861
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9900
#     G-mean: 0.7347
#     MCC: 0.6837
#     F1-score: 0.6867
#     mAP: 0.9259
#   [Ours - DecisionTree]
#     AUROC: 0.9263
#     G-mean: 0.7742
#     MCC: 0.7161
#     F1-score: 0.7133
#     mAP: 0.7628
#   [Ours - kNN]
#     AUROC: 0.9776
#     G-mean: 0.8077
#     MCC: 0.6986
#     F1-score: 0.6933
#     mAP: 0.8493
#   [Ours - MLP]
#     AUROC: 0.9340
#     G-mean: 0.7955
#     MCC: 0.4193
#     F1-score: 0.3778
#     mAP: 0.6341
#   [Ours - RandomForest]
#     AUROC: 0.9974
#     G-mean: 0.7354
#     MCC: 0.6933
#     F1-score: 0.6900
#     mAP: 0.9778
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9906
#     G-mean: 0.7118
#     MCC: 0.6636
#     F1-score: 0.6667
#     mAP: 0.9290
#   [Ours - DecisionTree]
#     AUROC: 0.9000
#     G-mean: 0.7275
#     MCC: 0.6696
#     F1-score: 0.6667
#     mAP: 0.7137
#   [Ours - kNN]
#     AUROC: 0.9802
#     G-mean: 0.8050
#     MCC: 0.6998
#     F1-score: 0.6944
#     mAP: 0.8559
#   [Ours - MLP]
#     AUROC: 0.9342
#     G-mean: 0.7990
#     MCC: 0.4285
#     F1-score: 0.3878
#     mAP: 0.6287
#   [Ours - RandomForest]
#     AUROC: 0.9978
#     G-mean: 0.7290
#     MCC: 0.6892
#     F1-score: 0.6861
#     mAP: 0.9815
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9910
#     G-mean: 0.7097
#     MCC: 0.6635
#     F1-score: 0.6667
#     mAP: 0.9312
#   [Ours - DecisionTree]
#     AUROC: 0.8891
#     G-mean: 0.7085
#     MCC: 0.6524
#     F1-score: 0.6500
#     mAP: 0.6990
#   [Ours - kNN]
#     AUROC: 0.9821
#     G-mean: 0.8177
#     MCC: 0.7194
#     F1-score: 0.7143
#     mAP: 0.8606
#   [Ours - MLP]
#     AUROC: 0.9372
#     G-mean: 0.7978
#     MCC: 0.4245
#     F1-score: 0.3836
#     mAP: 0.6381
#   [Ours - RandomForest]
#     AUROC: 0.9981
#     G-mean: 0.7102
#     MCC: 0.6720
#     F1-score: 0.6691
#     mAP: 0.9841
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9922
#     G-mean: 0.7324
#     MCC: 0.6834
#     F1-score: 0.6854
#     mAP: 0.9398
#   [Ours - DecisionTree]
#     AUROC: 0.8879
#     G-mean: 0.7067
#     MCC: 0.6519
#     F1-score: 0.6500
#     mAP: 0.7011
#   [Ours - kNN]
#     AUROC: 0.9832
#     G-mean: 0.8140
#     MCC: 0.7160
#     F1-score: 0.7104
#     mAP: 0.8572
#   [Ours - MLP]
#     AUROC: 0.9355
#     G-mean: 0.7965
#     MCC: 0.4179
#     F1-score: 0.3762
#     mAP: 0.6271
#   [Ours - RandomForest]
#     AUROC: 0.9984
#     G-mean: 0.7089
#     MCC: 0.6755
#     F1-score: 0.6729
#     mAP: 0.9861
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9930
#     G-mean: 0.7389
#     MCC: 0.6859
#     F1-score: 0.6870
#     mAP: 0.9465
#   [Ours - DecisionTree]
#     AUROC: 0.8873
#     G-mean: 0.7053
#     MCC: 0.6503
#     F1-score: 0.6481
#     mAP: 0.6986
#   [Ours - kNN]
#     AUROC: 0.9843
#     G-mean: 0.8108
#     MCC: 0.7098
#     F1-score: 0.7037
#     mAP: 0.8607
#   [Ours - MLP]
#     AUROC: 0.9378
#     G-mean: 0.7969
#     MCC: 0.4146
#     F1-score: 0.3722
#     mAP: 0.6438
#   [Ours - RandomForest]
#     AUROC: 0.9978
#     G-mean: 0.7190
#     MCC: 0.6893
#     F1-score: 0.6870
#     mAP: 0.9815
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9925
#     G-mean: 0.7350
#     MCC: 0.6862
#     F1-score: 0.6883
#     mAP: 0.9407
#   [Ours - DecisionTree]
#     AUROC: 0.8806
#     G-mean: 0.6936
#     MCC: 0.6327
#     F1-score: 0.6300
#     mAP: 0.6750
#   [Ours - kNN]
#     AUROC: 0.9844
#     G-mean: 0.8095
#     MCC: 0.7148
#     F1-score: 0.7100
#     mAP: 0.8617
#   [Ours - MLP]
#     AUROC: 0.9384
#     G-mean: 0.7983
#     MCC: 0.4197
#     F1-score: 0.3777
#     mAP: 0.6452
#   [Ours - RandomForest]
#     AUROC: 0.9974
#     G-mean: 0.7068
#     MCC: 0.6772
#     F1-score: 0.6750
#     mAP: 0.9778
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/kernel/glass-0-1-6_vs_5_results_laplacian_beta_0.01.csv
