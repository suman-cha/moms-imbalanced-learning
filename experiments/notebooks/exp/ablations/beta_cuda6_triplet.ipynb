# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

# Save path 
save_path = "/data4/oldrain123/oldrain123/results/ablation_results/beta8"
data_path = "/data4/oldrain123/oldrain123/dataset"

# %%
import os
import warnings
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from experiment import run_ablation
from imblearn.datasets import fetch_datasets

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "6"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
data = fetch_datasets()
methods = ["Ours"]
betas = [1e-1, 5e-2, 1e-2, 5e-3, 1e-3, 0.0]
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}

# %%
data_name = 'oil'
maj_target_name = -1

n_epochs = 2000
hidden_dims = [64, 128, 256]
latent_dim = 512
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        fetch_data_func=fetch_datasets,
        maj_target_name=maj_target_name,
        methods=methods,
        base_models=base_models,
        device=device,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'sick_euthyroid'
maj_target_name = -1

n_epochs = 2000
hidden_dims = [64, 128, 256]
latent_dim = 512
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        fetch_data_func=fetch_datasets,
        maj_target_name=maj_target_name,
        methods=methods,
        base_models=base_models,
        device=device,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'ecoli3'

n_epochs = 2000
hidden_dims = [16, 32, 64, 128]  
latent_dim = 256
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'ecoli4'

n_epochs = 2000
hidden_dims = [16, 32, 64, 128]  
latent_dim = 256
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'ecoli-0-3-4_vs_5'

n_epochs = 2000
hidden_dims = [7, 14, 28]
latent_dim = 10
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )
# Out:
# beta: 0.1
# Dataset loaded from DataFrame
# X shape : (200, 7)
# target : Counter({0: 180, 1: 20})
# IR: 9.0
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9528
#     G-mean: 0.8921
#     MCC: 0.7896
#     F1-score: 0.7838
#     mAP: 0.8860
#   [Ours - DecisionTree]
#     AUROC: 0.8486
#     G-mean: 0.8326
#     MCC: 0.7044
#     F1-score: 0.7152
#     mAP: 0.6183
#   [Ours - kNN]
#     AUROC: 0.9347
#     G-mean: 0.8950
#     MCC: 0.8022
#     F1-score: 0.7972
#     mAP: 0.8133
#   [Ours - MLP]
#     AUROC: 0.9278
#     G-mean: 0.8213
#     MCC: 0.5349
#     F1-score: 0.5583
#     mAP: 0.7244
#   [Ours - RandomForest]
#     AUROC: 0.9875
#     G-mean: 0.8996
#     MCC: 0.8084
#     F1-score: 0.8133
#     mAP: 0.9367
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9528
#     G-mean: 0.8917
#     MCC: 0.7657
#     F1-score: 0.7686
#     mAP: 0.8827
#   [Ours - DecisionTree]
#     AUROC: 0.8695
#     G-mean: 0.8511
#     MCC: 0.7404
#     F1-score: 0.7459
#     mAP: 0.6733
#   [Ours - kNN]
#     AUROC: 0.9250
#     G-mean: 0.8945
#     MCC: 0.7823
#     F1-score: 0.7853
#     mAP: 0.8141
#   [Ours - MLP]
#     AUROC: 0.9194
#     G-mean: 0.8109
#     MCC: 0.5813
#     F1-score: 0.5963
#     mAP: 0.7391
#   [Ours - RandomForest]
#     AUROC: 0.9896
#     G-mean: 0.9021
#     MCC: 0.8246
#     F1-score: 0.8283
#     mAP: 0.9475
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9528
#     G-mean: 0.8924
#     MCC: 0.7688
#     F1-score: 0.7724
#     mAP: 0.8799
#   [Ours - DecisionTree]
#     AUROC: 0.8736
#     G-mean: 0.8568
#     MCC: 0.7445
#     F1-score: 0.7517
#     mAP: 0.6694
#   [Ours - kNN]
#     AUROC: 0.9301
#     G-mean: 0.8934
#     MCC: 0.7730
#     F1-score: 0.7768
#     mAP: 0.8239
#   [Ours - MLP]
#     AUROC: 0.9185
#     G-mean: 0.7792
#     MCC: 0.5500
#     F1-score: 0.5648
#     mAP: 0.7234
#   [Ours - RandomForest]
#     AUROC: 0.9903
#     G-mean: 0.9019
#     MCC: 0.8231
#     F1-score: 0.8266
#     mAP: 0.9511
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9500
#     G-mean: 0.8919
#     MCC: 0.7659
#     F1-score: 0.7694
#     mAP: 0.8725
#   [Ours - DecisionTree]
#     AUROC: 0.8691
#     G-mean: 0.8524
#     MCC: 0.7388
#     F1-score: 0.7463
#     mAP: 0.6562
#   [Ours - kNN]
#     AUROC: 0.9264
#     G-mean: 0.8948
#     MCC: 0.7796
#     F1-score: 0.7834
#     mAP: 0.8216
#   [Ours - MLP]
#     AUROC: 0.9194
#     G-mean: 0.7954
#     MCC: 0.5610
#     F1-score: 0.5722
#     mAP: 0.7361
#   [Ours - RandomForest]
#     AUROC: 0.9907
#     G-mean: 0.9024
#     MCC: 0.8285
#     F1-score: 0.8300
#     mAP: 0.9508
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9534
#     G-mean: 0.8923
#     MCC: 0.7677
#     F1-score: 0.7715
#     mAP: 0.8802
#   [Ours - DecisionTree]
#     AUROC: 0.8544
#     G-mean: 0.8370
#     MCC: 0.7155
#     F1-score: 0.7237
#     mAP: 0.6220
#   [Ours - kNN]
#     AUROC: 0.9239
#     G-mean: 0.8957
#     MCC: 0.7854
#     F1-score: 0.7894
#     mAP: 0.8203
#   [Ours - MLP]
#     AUROC: 0.9205
#     G-mean: 0.8052
#     MCC: 0.5758
#     F1-score: 0.5895
#     mAP: 0.7382
#   [Ours - RandomForest]
#     AUROC: 0.9900
#     G-mean: 0.8911
#     MCC: 0.8184
#     F1-score: 0.8193
#     mAP: 0.9440
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9505
#     G-mean: 0.8941
#     MCC: 0.7752
#     F1-score: 0.7813
#     mAP: 0.8808
#   [Ours - DecisionTree]
#     AUROC: 0.8583
#     G-mean: 0.8416
#     MCC: 0.7202
#     F1-score: 0.7275
#     mAP: 0.6272
#   [Ours - kNN]
#     AUROC: 0.9245
#     G-mean: 0.8955
#     MCC: 0.7813
#     F1-score: 0.7884
#     mAP: 0.8158
#   [Ours - MLP]
#     AUROC: 0.9217
#     G-mean: 0.8099
#     MCC: 0.5770
#     F1-score: 0.5939
#     mAP: 0.7513
#   [Ours - RandomForest]
#     AUROC: 0.9884
#     G-mean: 0.8930
#     MCC: 0.8202
#     F1-score: 0.8217
#     mAP: 0.9400
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9520
#     G-mean: 0.8876
#     MCC: 0.7682
#     F1-score: 0.7754
#     mAP: 0.8823
#   [Ours - DecisionTree]
#     AUROC: 0.8583
#     G-mean: 0.8417
#     MCC: 0.7289
#     F1-score: 0.7337
#     mAP: 0.6350
#   [Ours - kNN]
#     AUROC: 0.9270
#     G-mean: 0.8895
#     MCC: 0.7798
#     F1-score: 0.7867
#     mAP: 0.8209
#   [Ours - MLP]
#     AUROC: 0.9210
#     G-mean: 0.8016
#     MCC: 0.5650
#     F1-score: 0.5823
#     mAP: 0.7532
#   [Ours - RandomForest]
#     AUROC: 0.9889
#     G-mean: 0.8840
#     MCC: 0.8120
#     F1-score: 0.8128
#     mAP: 0.9414
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9563
#     G-mean: 0.8841
#     MCC: 0.7704
#     F1-score: 0.7768
#     mAP: 0.8907
#   [Ours - DecisionTree]
#     AUROC: 0.8566
#     G-mean: 0.8355
#     MCC: 0.7175
#     F1-score: 0.7240
#     mAP: 0.6244
#   [Ours - kNN]
#     AUROC: 0.9293
#     G-mean: 0.8890
#     MCC: 0.7829
#     F1-score: 0.7892
#     mAP: 0.8269
#   [Ours - MLP]
#     AUROC: 0.9212
#     G-mean: 0.7996
#     MCC: 0.5612
#     F1-score: 0.5787
#     mAP: 0.7500
#   [Ours - RandomForest]
#     AUROC: 0.9896
#     G-mean: 0.8813
#     MCC: 0.8114
#     F1-score: 0.8121
#     mAP: 0.9446
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9556
#     G-mean: 0.8851
#     MCC: 0.7708
#     F1-score: 0.7768
#     mAP: 0.8879
#   [Ours - DecisionTree]
#     AUROC: 0.8595
#     G-mean: 0.8392
#     MCC: 0.7210
#     F1-score: 0.7288
#     mAP: 0.6295
#   [Ours - kNN]
#     AUROC: 0.9335
#     G-mean: 0.8942
#     MCC: 0.7955
#     F1-score: 0.8008
#     mAP: 0.8346
#   [Ours - MLP]
#     AUROC: 0.9228
#     G-mean: 0.8001
#     MCC: 0.5633
#     F1-score: 0.5812
#     mAP: 0.7570
#   [Ours - RandomForest]
#     AUROC: 0.9889
#     G-mean: 0.8839
#     MCC: 0.8147
#     F1-score: 0.8155
#     mAP: 0.9405
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9561
#     G-mean: 0.8852
#     MCC: 0.7694
#     F1-score: 0.7741
#     mAP: 0.8873
#   [Ours - DecisionTree]
#     AUROC: 0.8612
#     G-mean: 0.8409
#     MCC: 0.7243
#     F1-score: 0.7304
#     mAP: 0.6330
#   [Ours - kNN]
#     AUROC: 0.9319
#     G-mean: 0.8943
#     MCC: 0.7962
#     F1-score: 0.8004
#     mAP: 0.8343
#   [Ours - MLP]
#     AUROC: 0.9225
#     G-mean: 0.8025
#     MCC: 0.5611
#     F1-score: 0.5793
#     mAP: 0.7561
#   [Ours - RandomForest]
#     AUROC: 0.9900
#     G-mean: 0.8855
#     MCC: 0.8175
#     F1-score: 0.8177
#     mAP: 0.9465
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/ecoli-0-3-4_vs_5_results_gaussian_beta_0.1.csv
# beta: 0.05
# Dataset loaded from DataFrame
# X shape : (200, 7)
# target : Counter({0: 180, 1: 20})
# IR: 9.0
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9750
#     G-mean: 0.8921
#     MCC: 0.7896
#     F1-score: 0.7838
#     mAP: 0.9325
#   [Ours - DecisionTree]
#     AUROC: 0.7972
#     G-mean: 0.7742
#     MCC: 0.6234
#     F1-score: 0.6367
#     mAP: 0.5058
#   [Ours - kNN]
#     AUROC: 0.9361
#     G-mean: 0.8901
#     MCC: 0.7652
#     F1-score: 0.7672
#     mAP: 0.8183
#   [Ours - MLP]
#     AUROC: 0.9305
#     G-mean: 0.8460
#     MCC: 0.5562
#     F1-score: 0.5717
#     mAP: 0.7560
#   [Ours - RandomForest]
#     AUROC: 0.9889
#     G-mean: 0.8724
#     MCC: 0.7890
#     F1-score: 0.7900
#     mAP: 0.9417
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9736
#     G-mean: 0.8979
#     MCC: 0.8171
#     F1-score: 0.8119
#     mAP: 0.9305
#   [Ours - DecisionTree]
#     AUROC: 0.8541
#     G-mean: 0.8012
#     MCC: 0.6810
#     F1-score: 0.6900
#     mAP: 0.6146
#   [Ours - kNN]
#     AUROC: 0.9395
#     G-mean: 0.8935
#     MCC: 0.7742
#     F1-score: 0.7802
#     mAP: 0.8475
#   [Ours - MLP]
#     AUROC: 0.9291
#     G-mean: 0.8158
#     MCC: 0.5501
#     F1-score: 0.5633
#     mAP: 0.7610
#   [Ours - RandomForest]
#     AUROC: 0.9903
#     G-mean: 0.9031
#     MCC: 0.8305
#     F1-score: 0.8334
#     mAP: 0.9500
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9676
#     G-mean: 0.8979
#     MCC: 0.8177
#     F1-score: 0.8124
#     mAP: 0.9159
#   [Ours - DecisionTree]
#     AUROC: 0.8597
#     G-mean: 0.8075
#     MCC: 0.6797
#     F1-score: 0.6924
#     mAP: 0.6130
#   [Ours - kNN]
#     AUROC: 0.9398
#     G-mean: 0.8936
#     MCC: 0.7744
#     F1-score: 0.7802
#     mAP: 0.8461
#   [Ours - MLP]
#     AUROC: 0.9324
#     G-mean: 0.7925
#     MCC: 0.5350
#     F1-score: 0.5491
#     mAP: 0.7738
#   [Ours - RandomForest]
#     AUROC: 0.9898
#     G-mean: 0.9133
#     MCC: 0.8443
#     F1-score: 0.8478
#     mAP: 0.9444
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9653
#     G-mean: 0.8962
#     MCC: 0.8017
#     F1-score: 0.8003
#     mAP: 0.9055
#   [Ours - DecisionTree]
#     AUROC: 0.8590
#     G-mean: 0.8154
#     MCC: 0.6922
#     F1-score: 0.7034
#     mAP: 0.6181
#   [Ours - kNN]
#     AUROC: 0.9451
#     G-mean: 0.8935
#     MCC: 0.7724
#     F1-score: 0.7776
#     mAP: 0.8491
#   [Ours - MLP]
#     AUROC: 0.9285
#     G-mean: 0.8013
#     MCC: 0.5490
#     F1-score: 0.5618
#     mAP: 0.7730
#   [Ours - RandomForest]
#     AUROC: 0.9889
#     G-mean: 0.9033
#     MCC: 0.8296
#     F1-score: 0.8342
#     mAP: 0.9375
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9639
#     G-mean: 0.8959
#     MCC: 0.7989
#     F1-score: 0.7989
#     mAP: 0.9089
#   [Ours - DecisionTree]
#     AUROC: 0.8525
#     G-mean: 0.8194
#     MCC: 0.6937
#     F1-score: 0.7041
#     mAP: 0.6095
#   [Ours - kNN]
#     AUROC: 0.9389
#     G-mean: 0.8947
#     MCC: 0.7796
#     F1-score: 0.7848
#     mAP: 0.8423
#   [Ours - MLP]
#     AUROC: 0.9283
#     G-mean: 0.8068
#     MCC: 0.5585
#     F1-score: 0.5717
#     mAP: 0.7819
#   [Ours - RandomForest]
#     AUROC: 0.9895
#     G-mean: 0.9092
#     MCC: 0.8388
#     F1-score: 0.8420
#     mAP: 0.9400
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9606
#     G-mean: 0.8971
#     MCC: 0.8012
#     F1-score: 0.8041
#     mAP: 0.9058
#   [Ours - DecisionTree]
#     AUROC: 0.8468
#     G-mean: 0.8104
#     MCC: 0.6835
#     F1-score: 0.6951
#     mAP: 0.6004
#   [Ours - kNN]
#     AUROC: 0.9340
#     G-mean: 0.8957
#     MCC: 0.7837
#     F1-score: 0.7901
#     mAP: 0.8378
#   [Ours - MLP]
#     AUROC: 0.9255
#     G-mean: 0.8058
#     MCC: 0.5557
#     F1-score: 0.5733
#     mAP: 0.7800
#   [Ours - RandomForest]
#     AUROC: 0.9880
#     G-mean: 0.9034
#     MCC: 0.8313
#     F1-score: 0.8356
#     mAP: 0.9366
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9623
#     G-mean: 0.8910
#     MCC: 0.7974
#     F1-score: 0.8006
#     mAP: 0.9051
#   [Ours - DecisionTree]
#     AUROC: 0.8476
#     G-mean: 0.8075
#     MCC: 0.6809
#     F1-score: 0.6911
#     mAP: 0.5965
#   [Ours - kNN]
#     AUROC: 0.9349
#     G-mean: 0.8896
#     MCC: 0.7830
#     F1-score: 0.7882
#     mAP: 0.8398
#   [Ours - MLP]
#     AUROC: 0.9310
#     G-mean: 0.8025
#     MCC: 0.5541
#     F1-score: 0.5707
#     mAP: 0.7944
#   [Ours - RandomForest]
#     AUROC: 0.9885
#     G-mean: 0.8975
#     MCC: 0.8290
#     F1-score: 0.8324
#     mAP: 0.9386
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9635
#     G-mean: 0.8877
#     MCC: 0.8012
#     F1-score: 0.8039
#     mAP: 0.9098
#   [Ours - DecisionTree]
#     AUROC: 0.8441
#     G-mean: 0.8028
#     MCC: 0.6765
#     F1-score: 0.6885
#     mAP: 0.5955
#   [Ours - kNN]
#     AUROC: 0.9363
#     G-mean: 0.8891
#     MCC: 0.7857
#     F1-score: 0.7905
#     mAP: 0.8433
#   [Ours - MLP]
#     AUROC: 0.9309
#     G-mean: 0.8054
#     MCC: 0.5612
#     F1-score: 0.5775
#     mAP: 0.7888
#   [Ours - RandomForest]
#     AUROC: 0.9891
#     G-mean: 0.8932
#     MCC: 0.8257
#     F1-score: 0.8296
#     mAP: 0.9400
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9626
#     G-mean: 0.8893
#     MCC: 0.8033
#     F1-score: 0.8060
#     mAP: 0.9077
#   [Ours - DecisionTree]
#     AUROC: 0.8437
#     G-mean: 0.8061
#     MCC: 0.6756
#     F1-score: 0.6883
#     mAP: 0.5909
#   [Ours - kNN]
#     AUROC: 0.9367
#     G-mean: 0.8912
#     MCC: 0.7941
#     F1-score: 0.7986
#     mAP: 0.8461
#   [Ours - MLP]
#     AUROC: 0.9299
#     G-mean: 0.8078
#     MCC: 0.5645
#     F1-score: 0.5812
#     mAP: 0.7893
#   [Ours - RandomForest]
#     AUROC: 0.9891
#     G-mean: 0.8944
#     MCC: 0.8274
#     F1-score: 0.8311
#     mAP: 0.9402
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9630
#     G-mean: 0.8907
#     MCC: 0.8074
#     F1-score: 0.8094
#     mAP: 0.9079
#   [Ours - DecisionTree]
#     AUROC: 0.8442
#     G-mean: 0.8085
#     MCC: 0.6812
#     F1-score: 0.6922
#     mAP: 0.5963
#   [Ours - kNN]
#     AUROC: 0.9350
#     G-mean: 0.8916
#     MCC: 0.7945
#     F1-score: 0.7988
#     mAP: 0.8447
#   [Ours - MLP]
#     AUROC: 0.9300
#     G-mean: 0.8087
#     MCC: 0.5597
#     F1-score: 0.5767
#     mAP: 0.7852
#   [Ours - RandomForest]
#     AUROC: 0.9902
#     G-mean: 0.8924
#     MCC: 0.8268
#     F1-score: 0.8293
#     mAP: 0.9462
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/ecoli-0-3-4_vs_5_results_gaussian_beta_0.05.csv
# beta: 0.01
# Dataset loaded from DataFrame
# X shape : (200, 7)
# target : Counter({0: 180, 1: 20})
# IR: 9.0
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9778
#     G-mean: 0.8901
#     MCC: 0.7652
#     F1-score: 0.7672
#     mAP: 0.9444
#   [Ours - DecisionTree]
#     AUROC: 0.8292
#     G-mean: 0.8345
#     MCC: 0.7118
#     F1-score: 0.7100
#     mAP: 0.5833
#   [Ours - kNN]
#     AUROC: 0.9361
#     G-mean: 0.9224
#     MCC: 0.8053
#     F1-score: 0.8100
#     mAP: 0.8183
#   [Ours - MLP]
#     AUROC: 0.9139
#     G-mean: 0.8256
#     MCC: 0.5594
#     F1-score: 0.5786
#     mAP: 0.7726
#   [Ours - RandomForest]
#     AUROC: 0.9861
#     G-mean: 0.8703
#     MCC: 0.7772
#     F1-score: 0.7800
#     mAP: 0.9333
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9792
#     G-mean: 0.8955
#     MCC: 0.7945
#     F1-score: 0.7936
#     mAP: 0.9405
#   [Ours - DecisionTree]
#     AUROC: 0.8541
#     G-mean: 0.8153
#     MCC: 0.6955
#     F1-score: 0.7000
#     mAP: 0.6017
#   [Ours - kNN]
#     AUROC: 0.9382
#     G-mean: 0.9106
#     MCC: 0.8064
#     F1-score: 0.8100
#     mAP: 0.8392
#   [Ours - MLP]
#     AUROC: 0.9223
#     G-mean: 0.8041
#     MCC: 0.5472
#     F1-score: 0.5620
#     mAP: 0.7668
#   [Ours - RandomForest]
#     AUROC: 0.9889
#     G-mean: 0.9021
#     MCC: 0.8246
#     F1-score: 0.8284
#     mAP: 0.9458
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9695
#     G-mean: 0.8972
#     MCC: 0.8070
#     F1-score: 0.8046
#     mAP: 0.9276
#   [Ours - DecisionTree]
#     AUROC: 0.8782
#     G-mean: 0.8500
#     MCC: 0.7291
#     F1-score: 0.7335
#     mAP: 0.6372
#   [Ours - kNN]
#     AUROC: 0.9384
#     G-mean: 0.9050
#     MCC: 0.7959
#     F1-score: 0.8000
#     mAP: 0.8433
#   [Ours - MLP]
#     AUROC: 0.9232
#     G-mean: 0.7871
#     MCC: 0.5336
#     F1-score: 0.5496
#     mAP: 0.7562
#   [Ours - RandomForest]
#     AUROC: 0.9898
#     G-mean: 0.9117
#     MCC: 0.8335
#     F1-score: 0.8378
#     mAP: 0.9500
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9681
#     G-mean: 0.8991
#     MCC: 0.8154
#     F1-score: 0.8143
#     mAP: 0.9232
#   [Ours - DecisionTree]
#     AUROC: 0.8726
#     G-mean: 0.8470
#     MCC: 0.7270
#     F1-score: 0.7318
#     mAP: 0.6300
#   [Ours - kNN]
#     AUROC: 0.9389
#     G-mean: 0.9035
#     MCC: 0.7968
#     F1-score: 0.8008
#     mAP: 0.8433
#   [Ours - MLP]
#     AUROC: 0.9285
#     G-mean: 0.7973
#     MCC: 0.5381
#     F1-score: 0.5549
#     mAP: 0.7777
#   [Ours - RandomForest]
#     AUROC: 0.9889
#     G-mean: 0.9021
#     MCC: 0.8214
#     F1-score: 0.8267
#     mAP: 0.9416
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9661
#     G-mean: 0.8990
#     MCC: 0.8138
#     F1-score: 0.8134
#     mAP: 0.9231
#   [Ours - DecisionTree]
#     AUROC: 0.8678
#     G-mean: 0.8451
#     MCC: 0.7288
#     F1-score: 0.7322
#     mAP: 0.6286
#   [Ours - kNN]
#     AUROC: 0.9383
#     G-mean: 0.9033
#     MCC: 0.8032
#     F1-score: 0.8073
#     mAP: 0.8440
#   [Ours - MLP]
#     AUROC: 0.9278
#     G-mean: 0.8064
#     MCC: 0.5553
#     F1-score: 0.5740
#     mAP: 0.7762
#   [Ours - RandomForest]
#     AUROC: 0.9883
#     G-mean: 0.8965
#     MCC: 0.8198
#     F1-score: 0.8227
#     mAP: 0.9383
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9644
#     G-mean: 0.8994
#     MCC: 0.8117
#     F1-score: 0.8145
#     mAP: 0.9185
#   [Ours - DecisionTree]
#     AUROC: 0.8551
#     G-mean: 0.8270
#     MCC: 0.7070
#     F1-score: 0.7135
#     mAP: 0.6102
#   [Ours - kNN]
#     AUROC: 0.9370
#     G-mean: 0.9025
#     MCC: 0.8022
#     F1-score: 0.8078
#     mAP: 0.8411
#   [Ours - MLP]
#     AUROC: 0.9264
#     G-mean: 0.8110
#     MCC: 0.5614
#     F1-score: 0.5817
#     mAP: 0.7692
#   [Ours - RandomForest]
#     AUROC: 0.9875
#     G-mean: 0.8855
#     MCC: 0.8103
#     F1-score: 0.8122
#     mAP: 0.9361
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9667
#     G-mean: 0.8918
#     MCC: 0.7988
#     F1-score: 0.8025
#     mAP: 0.9180
#   [Ours - DecisionTree]
#     AUROC: 0.8484
#     G-mean: 0.8192
#     MCC: 0.7055
#     F1-score: 0.7111
#     mAP: 0.6119
#   [Ours - kNN]
#     AUROC: 0.9373
#     G-mean: 0.8939
#     MCC: 0.7876
#     F1-score: 0.7933
#     mAP: 0.8379
#   [Ours - MLP]
#     AUROC: 0.9290
#     G-mean: 0.8065
#     MCC: 0.5582
#     F1-score: 0.5772
#     mAP: 0.7728
#   [Ours - RandomForest]
#     AUROC: 0.9885
#     G-mean: 0.8817
#     MCC: 0.8080
#     F1-score: 0.8095
#     mAP: 0.9393
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9677
#     G-mean: 0.8878
#     MCC: 0.7972
#     F1-score: 0.8005
#     mAP: 0.9193
#   [Ours - DecisionTree]
#     AUROC: 0.8484
#     G-mean: 0.8166
#     MCC: 0.7040
#     F1-score: 0.7106
#     mAP: 0.6156
#   [Ours - kNN]
#     AUROC: 0.9382
#     G-mean: 0.8929
#     MCC: 0.7888
#     F1-score: 0.7942
#     mAP: 0.8396
#   [Ours - MLP]
#     AUROC: 0.9312
#     G-mean: 0.8082
#     MCC: 0.5616
#     F1-score: 0.5800
#     mAP: 0.7804
#   [Ours - RandomForest]
#     AUROC: 0.9892
#     G-mean: 0.8754
#     MCC: 0.8019
#     F1-score: 0.8037
#     mAP: 0.9427
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9670
#     G-mean: 0.8893
#     MCC: 0.7998
#     F1-score: 0.8030
#     mAP: 0.9189
#   [Ours - DecisionTree]
#     AUROC: 0.8475
#     G-mean: 0.8182
#     MCC: 0.6994
#     F1-score: 0.7076
#     mAP: 0.6082
#   [Ours - kNN]
#     AUROC: 0.9410
#     G-mean: 0.8974
#     MCC: 0.7984
#     F1-score: 0.8030
#     mAP: 0.8459
#   [Ours - MLP]
#     AUROC: 0.9327
#     G-mean: 0.8106
#     MCC: 0.5680
#     F1-score: 0.5858
#     mAP: 0.7830
#   [Ours - RandomForest]
#     AUROC: 0.9883
#     G-mean: 0.8786
#     MCC: 0.8063
#     F1-score: 0.8081
#     mAP: 0.9361
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9672
#     G-mean: 0.8904
#     MCC: 0.8042
#     F1-score: 0.8064
#     mAP: 0.9182
#   [Ours - DecisionTree]
#     AUROC: 0.8468
#     G-mean: 0.8180
#     MCC: 0.7054
#     F1-score: 0.7115
#     mAP: 0.6120
#   [Ours - kNN]
#     AUROC: 0.9389
#     G-mean: 0.8977
#     MCC: 0.8029
#     F1-score: 0.8064
#     mAP: 0.8445
#   [Ours - MLP]
#     AUROC: 0.9308
#     G-mean: 0.8092
#     MCC: 0.5625
#     F1-score: 0.5809
#     mAP: 0.7762
#   [Ours - RandomForest]
#     AUROC: 0.9894
#     G-mean: 0.8811
#     MCC: 0.8109
#     F1-score: 0.8120
#     mAP: 0.9425
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/ecoli-0-3-4_vs_5_results_gaussian_beta_0.01.csv
# beta: 0.005
# Dataset loaded from DataFrame
# X shape : (200, 7)
# target : Counter({0: 180, 1: 20})
# IR: 9.0
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9778
#     G-mean: 0.8958
#     MCC: 0.7985
#     F1-score: 0.8005
#     mAP: 0.9444
#   [Ours - DecisionTree]
#     AUROC: 0.8306
#     G-mean: 0.8126
#     MCC: 0.6985
#     F1-score: 0.7100
#     mAP: 0.5883
#   [Ours - kNN]
#     AUROC: 0.9347
#     G-mean: 0.8901
#     MCC: 0.7652
#     F1-score: 0.7672
#     mAP: 0.8183
#   [Ours - MLP]
#     AUROC: 0.9139
#     G-mean: 0.7952
#     MCC: 0.4745
#     F1-score: 0.5128
#     mAP: 0.7759
#   [Ours - RandomForest]
#     AUROC: 0.9833
#     G-mean: 0.8724
#     MCC: 0.7890
#     F1-score: 0.7900
#     mAP: 0.9283
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9792
#     G-mean: 0.8969
#     MCC: 0.8049
#     F1-score: 0.8036
#     mAP: 0.9405
#   [Ours - DecisionTree]
#     AUROC: 0.8535
#     G-mean: 0.8029
#     MCC: 0.6785
#     F1-score: 0.6900
#     mAP: 0.5875
#   [Ours - kNN]
#     AUROC: 0.9361
#     G-mean: 0.8931
#     MCC: 0.7760
#     F1-score: 0.7786
#     mAP: 0.8392
#   [Ours - MLP]
#     AUROC: 0.9223
#     G-mean: 0.7509
#     MCC: 0.4675
#     F1-score: 0.4936
#     mAP: 0.7667
#   [Ours - RandomForest]
#     AUROC: 0.9889
#     G-mean: 0.9031
#     MCC: 0.8305
#     F1-score: 0.8334
#     mAP: 0.9516
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9713
#     G-mean: 0.8956
#     MCC: 0.7946
#     F1-score: 0.7946
#     mAP: 0.9240
#   [Ours - DecisionTree]
#     AUROC: 0.8639
#     G-mean: 0.8113
#     MCC: 0.6985
#     F1-score: 0.7078
#     mAP: 0.6178
#   [Ours - kNN]
#     AUROC: 0.9380
#     G-mean: 0.8943
#     MCC: 0.7799
#     F1-score: 0.7835
#     mAP: 0.8489
#   [Ours - MLP]
#     AUROC: 0.9232
#     G-mean: 0.7638
#     MCC: 0.5025
#     F1-score: 0.5229
#     mAP: 0.7617
#   [Ours - RandomForest]
#     AUROC: 0.9889
#     G-mean: 0.9133
#     MCC: 0.8443
#     F1-score: 0.8478
#     mAP: 0.9455
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9694
#     G-mean: 0.8964
#     MCC: 0.7958
#     F1-score: 0.7968
#     mAP: 0.9211
#   [Ours - DecisionTree]
#     AUROC: 0.8694
#     G-mean: 0.8264
#     MCC: 0.7221
#     F1-score: 0.7275
#     mAP: 0.6350
#   [Ours - kNN]
#     AUROC: 0.9375
#     G-mean: 0.8950
#     MCC: 0.7787
#     F1-score: 0.7843
#     mAP: 0.8371
#   [Ours - MLP]
#     AUROC: 0.9299
#     G-mean: 0.7849
#     MCC: 0.5203
#     F1-score: 0.5383
#     mAP: 0.7775
#   [Ours - RandomForest]
#     AUROC: 0.9889
#     G-mean: 0.9109
#     MCC: 0.8444
#     F1-score: 0.8458
#     mAP: 0.9425
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9672
#     G-mean: 0.8969
#     MCC: 0.7966
#     F1-score: 0.7981
#     mAP: 0.9182
#   [Ours - DecisionTree]
#     AUROC: 0.8644
#     G-mean: 0.8283
#     MCC: 0.7169
#     F1-score: 0.7240
#     mAP: 0.6247
#   [Ours - kNN]
#     AUROC: 0.9381
#     G-mean: 0.9016
#     MCC: 0.7891
#     F1-score: 0.7948
#     mAP: 0.8383
#   [Ours - MLP]
#     AUROC: 0.9317
#     G-mean: 0.8006
#     MCC: 0.5459
#     F1-score: 0.5636
#     mAP: 0.7860
#   [Ours - RandomForest]
#     AUROC: 0.9889
#     G-mean: 0.9089
#     MCC: 0.8419
#     F1-score: 0.8420
#     mAP: 0.9406
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9657
#     G-mean: 0.8974
#     MCC: 0.7978
#     F1-score: 0.8006
#     mAP: 0.9151
#   [Ours - DecisionTree]
#     AUROC: 0.8671
#     G-mean: 0.8283
#     MCC: 0.7193
#     F1-score: 0.7272
#     mAP: 0.6336
#   [Ours - kNN]
#     AUROC: 0.9364
#     G-mean: 0.9007
#     MCC: 0.7863
#     F1-score: 0.7945
#     mAP: 0.8402
#   [Ours - MLP]
#     AUROC: 0.9310
#     G-mean: 0.8048
#     MCC: 0.5496
#     F1-score: 0.5700
#     mAP: 0.7950
#   [Ours - RandomForest]
#     AUROC: 0.9875
#     G-mean: 0.9124
#     MCC: 0.8454
#     F1-score: 0.8450
#     mAP: 0.9372
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9655
#     G-mean: 0.8901
#     MCC: 0.7869
#     F1-score: 0.7905
#     mAP: 0.9121
#   [Ours - DecisionTree]
#     AUROC: 0.8734
#     G-mean: 0.8319
#     MCC: 0.7252
#     F1-score: 0.7319
#     mAP: 0.6452
#   [Ours - kNN]
#     AUROC: 0.9369
#     G-mean: 0.8929
#     MCC: 0.7770
#     F1-score: 0.7848
#     mAP: 0.8394
#   [Ours - MLP]
#     AUROC: 0.9322
#     G-mean: 0.8021
#     MCC: 0.5476
#     F1-score: 0.5669
#     mAP: 0.7919
#   [Ours - RandomForest]
#     AUROC: 0.9885
#     G-mean: 0.9090
#     MCC: 0.8425
#     F1-score: 0.8424
#     mAP: 0.9402
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9670
#     G-mean: 0.8859
#     MCC: 0.7852
#     F1-score: 0.7884
#     mAP: 0.9162
#   [Ours - DecisionTree]
#     AUROC: 0.8706
#     G-mean: 0.8275
#     MCC: 0.7214
#     F1-score: 0.7284
#     mAP: 0.6435
#   [Ours - kNN]
#     AUROC: 0.9380
#     G-mean: 0.8916
#     MCC: 0.7779
#     F1-score: 0.7851
#     mAP: 0.8420
#   [Ours - MLP]
#     AUROC: 0.9326
#     G-mean: 0.8033
#     MCC: 0.5490
#     F1-score: 0.5675
#     mAP: 0.7949
#   [Ours - RandomForest]
#     AUROC: 0.9896
#     G-mean: 0.9028
#     MCC: 0.8365
#     F1-score: 0.8363
#     mAP: 0.9456
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9664
#     G-mean: 0.8877
#     MCC: 0.7891
#     F1-score: 0.7923
#     mAP: 0.9161
#   [Ours - DecisionTree]
#     AUROC: 0.8714
#     G-mean: 0.8322
#     MCC: 0.7271
#     F1-score: 0.7341
#     mAP: 0.6483
#   [Ours - kNN]
#     AUROC: 0.9380
#     G-mean: 0.8960
#     MCC: 0.7860
#     F1-score: 0.7930
#     mAP: 0.8449
#   [Ours - MLP]
#     AUROC: 0.9312
#     G-mean: 0.8075
#     MCC: 0.5588
#     F1-score: 0.5779
#     mAP: 0.7927
#   [Ours - RandomForest]
#     AUROC: 0.9886
#     G-mean: 0.9024
#     MCC: 0.8324
#     F1-score: 0.8326
#     mAP: 0.9387
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9669
#     G-mean: 0.8892
#     MCC: 0.7966
#     F1-score: 0.7988
#     mAP: 0.9155
#   [Ours - DecisionTree]
#     AUROC: 0.8690
#     G-mean: 0.8323
#     MCC: 0.7292
#     F1-score: 0.7345
#     mAP: 0.6472
#   [Ours - kNN]
#     AUROC: 0.9382
#     G-mean: 0.8965
#     MCC: 0.7918
#     F1-score: 0.7974
#     mAP: 0.8456
#   [Ours - MLP]
#     AUROC: 0.9314
#     G-mean: 0.8094
#     MCC: 0.5581
#     F1-score: 0.5775
#     mAP: 0.7941
#   [Ours - RandomForest]
#     AUROC: 0.9897
#     G-mean: 0.8996
#     MCC: 0.8313
#     F1-score: 0.8307
#     mAP: 0.9448
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/ecoli-0-3-4_vs_5_results_gaussian_beta_0.005.csv
# beta: 0.001
# Dataset loaded from DataFrame
# X shape : (200, 7)
# target : Counter({0: 180, 1: 20})
# IR: 9.0
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9667
#     G-mean: 0.8901
#     MCC: 0.7652
#     F1-score: 0.7672
#     mAP: 0.9410
#   [Ours - DecisionTree]
#     AUROC: 0.8486
#     G-mean: 0.8362
#     MCC: 0.6963
#     F1-score: 0.7100
#     mAP: 0.5833
#   [Ours - kNN]
#     AUROC: 0.9361
#     G-mean: 0.8882
#     MCC: 0.7328
#     F1-score: 0.7438
#     mAP: 0.8183
#   [Ours - MLP]
#     AUROC: 0.9166
#     G-mean: 0.8325
#     MCC: 0.5631
#     F1-score: 0.5924
#     mAP: 0.7622
#   [Ours - RandomForest]
#     AUROC: 0.9917
#     G-mean: 0.9037
#     MCC: 0.8445
#     F1-score: 0.8400
#     mAP: 0.9583
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9723
#     G-mean: 0.8955
#     MCC: 0.7985
#     F1-score: 0.7970
#     mAP: 0.9371
#   [Ours - DecisionTree]
#     AUROC: 0.8778
#     G-mean: 0.8690
#     MCC: 0.7582
#     F1-score: 0.7667
#     mAP: 0.6617
#   [Ours - kNN]
#     AUROC: 0.9389
#     G-mean: 0.8921
#     MCC: 0.7598
#     F1-score: 0.7669
#     mAP: 0.8475
#   [Ours - MLP]
#     AUROC: 0.9264
#     G-mean: 0.8100
#     MCC: 0.5594
#     F1-score: 0.5786
#     mAP: 0.7699
#   [Ours - RandomForest]
#     AUROC: 0.9917
#     G-mean: 0.9173
#     MCC: 0.8479
#     F1-score: 0.8483
#     mAP: 0.9583
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9667
#     G-mean: 0.8944
#     MCC: 0.7916
#     F1-score: 0.7891
#     mAP: 0.9298
#   [Ours - DecisionTree]
#     AUROC: 0.8875
#     G-mean: 0.8779
#     MCC: 0.7704
#     F1-score: 0.7767
#     mAP: 0.6767
#   [Ours - kNN]
#     AUROC: 0.9398
#     G-mean: 0.8918
#     MCC: 0.7580
#     F1-score: 0.7646
#     mAP: 0.8544
#   [Ours - MLP]
#     AUROC: 0.9231
#     G-mean: 0.7913
#     MCC: 0.5385
#     F1-score: 0.5593
#     mAP: 0.7625
#   [Ours - RandomForest]
#     AUROC: 0.9917
#     G-mean: 0.9228
#     MCC: 0.8559
#     F1-score: 0.8578
#     mAP: 0.9583
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9674
#     G-mean: 0.8948
#     MCC: 0.7884
#     F1-score: 0.7877
#     mAP: 0.9234
#   [Ours - DecisionTree]
#     AUROC: 0.8812
#     G-mean: 0.8589
#     MCC: 0.7578
#     F1-score: 0.7633
#     mAP: 0.6700
#   [Ours - kNN]
#     AUROC: 0.9389
#     G-mean: 0.8994
#     MCC: 0.7678
#     F1-score: 0.7743
#     mAP: 0.8454
#   [Ours - MLP]
#     AUROC: 0.9194
#     G-mean: 0.8009
#     MCC: 0.5495
#     F1-score: 0.5677
#     mAP: 0.7533
#   [Ours - RandomForest]
#     AUROC: 0.9917
#     G-mean: 0.9181
#     MCC: 0.8531
#     F1-score: 0.8533
#     mAP: 0.9562
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9639
#     G-mean: 0.8956
#     MCC: 0.7922
#     F1-score: 0.7921
#     mAP: 0.9233
#   [Ours - DecisionTree]
#     AUROC: 0.8622
#     G-mean: 0.8431
#     MCC: 0.7317
#     F1-score: 0.7413
#     mAP: 0.6397
#   [Ours - kNN]
#     AUROC: 0.9395
#     G-mean: 0.9050
#     MCC: 0.7811
#     F1-score: 0.7861
#     mAP: 0.8483
#   [Ours - MLP]
#     AUROC: 0.9211
#     G-mean: 0.8128
#     MCC: 0.5630
#     F1-score: 0.5824
#     mAP: 0.7525
#   [Ours - RandomForest]
#     AUROC: 0.9917
#     G-mean: 0.9152
#     MCC: 0.8514
#     F1-score: 0.8507
#     mAP: 0.9550
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9630
#     G-mean: 0.8964
#     MCC: 0.7943
#     F1-score: 0.7962
#     mAP: 0.9193
#   [Ours - DecisionTree]
#     AUROC: 0.8641
#     G-mean: 0.8397
#     MCC: 0.7260
#     F1-score: 0.7361
#     mAP: 0.6378
#   [Ours - kNN]
#     AUROC: 0.9384
#     G-mean: 0.9034
#     MCC: 0.7803
#     F1-score: 0.7867
#     mAP: 0.8489
#   [Ours - MLP]
#     AUROC: 0.9213
#     G-mean: 0.8162
#     MCC: 0.5669
#     F1-score: 0.5881
#     mAP: 0.7523
#   [Ours - RandomForest]
#     AUROC: 0.9899
#     G-mean: 0.9133
#     MCC: 0.8516
#     F1-score: 0.8500
#     mAP: 0.9492
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9635
#     G-mean: 0.8893
#     MCC: 0.7839
#     F1-score: 0.7868
#     mAP: 0.9162
#   [Ours - DecisionTree]
#     AUROC: 0.8627
#     G-mean: 0.8326
#     MCC: 0.7157
#     F1-score: 0.7248
#     mAP: 0.6324
#   [Ours - kNN]
#     AUROC: 0.9385
#     G-mean: 0.8952
#     MCC: 0.7718
#     F1-score: 0.7782
#     mAP: 0.8505
#   [Ours - MLP]
#     AUROC: 0.9242
#     G-mean: 0.8127
#     MCC: 0.5660
#     F1-score: 0.5862
#     mAP: 0.7556
#   [Ours - RandomForest]
#     AUROC: 0.9905
#     G-mean: 0.9097
#     MCC: 0.8478
#     F1-score: 0.8467
#     mAP: 0.9505
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9646
#     G-mean: 0.8855
#     MCC: 0.7852
#     F1-score: 0.7876
#     mAP: 0.9186
#   [Ours - DecisionTree]
#     AUROC: 0.8606
#     G-mean: 0.8274
#     MCC: 0.7096
#     F1-score: 0.7188
#     mAP: 0.6273
#   [Ours - kNN]
#     AUROC: 0.9398
#     G-mean: 0.8940
#     MCC: 0.7749
#     F1-score: 0.7809
#     mAP: 0.8558
#   [Ours - MLP]
#     AUROC: 0.9267
#     G-mean: 0.8093
#     MCC: 0.5615
#     F1-score: 0.5815
#     mAP: 0.7652
#   [Ours - RandomForest]
#     AUROC: 0.9907
#     G-mean: 0.9035
#     MCC: 0.8407
#     F1-score: 0.8404
#     mAP: 0.9504
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9645
#     G-mean: 0.8873
#     MCC: 0.7891
#     F1-score: 0.7915
#     mAP: 0.9192
#   [Ours - DecisionTree]
#     AUROC: 0.8650
#     G-mean: 0.8346
#     MCC: 0.7172
#     F1-score: 0.7248
#     mAP: 0.6315
#   [Ours - kNN]
#     AUROC: 0.9421
#     G-mean: 0.8973
#     MCC: 0.7770
#     F1-score: 0.7838
#     mAP: 0.8589
#   [Ours - MLP]
#     AUROC: 0.9284
#     G-mean: 0.8153
#     MCC: 0.5730
#     F1-score: 0.5921
#     mAP: 0.7718
#   [Ours - RandomForest]
#     AUROC: 0.9901
#     G-mean: 0.9004
#     MCC: 0.8372
#     F1-score: 0.8371
#     mAP: 0.9476
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9653
#     G-mean: 0.8884
#     MCC: 0.7924
#     F1-score: 0.7941
#     mAP: 0.9182
#   [Ours - DecisionTree]
#     AUROC: 0.8649
#     G-mean: 0.8370
#     MCC: 0.7222
#     F1-score: 0.7281
#     mAP: 0.6348
#   [Ours - kNN]
#     AUROC: 0.9395
#     G-mean: 0.8975
#     MCC: 0.7821
#     F1-score: 0.7884
#     mAP: 0.8562
#   [Ours - MLP]
#     AUROC: 0.9267
#     G-mean: 0.8161
#     MCC: 0.5699
#     F1-score: 0.5893
#     mAP: 0.7751
#   [Ours - RandomForest]
#     AUROC: 0.9911
#     G-mean: 0.9007
#     MCC: 0.8387
#     F1-score: 0.8380
#     mAP: 0.9528
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/ecoli-0-3-4_vs_5_results_gaussian_beta_0.001.csv
# beta: 0.0
# Dataset loaded from DataFrame
# X shape : (200, 7)
# target : Counter({0: 180, 1: 20})
# IR: 9.0
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9833
#     G-mean: 0.8921
#     MCC: 0.7896
#     F1-score: 0.7838
#     mAP: 0.9333
#   [Ours - DecisionTree]
#     AUROC: 0.8708
#     G-mean: 0.8596
#     MCC: 0.7059
#     F1-score: 0.7205
#     mAP: 0.6017
#   [Ours - kNN]
#     AUROC: 0.9347
#     G-mean: 0.8902
#     MCC: 0.7572
#     F1-score: 0.7605
#     mAP: 0.8133
#   [Ours - MLP]
#     AUROC: 0.9167
#     G-mean: 0.8316
#     MCC: 0.5428
#     F1-score: 0.5757
#     mAP: 0.7596
#   [Ours - RandomForest]
#     AUROC: 0.9944
#     G-mean: 0.9009
#     MCC: 0.8239
#     F1-score: 0.8200
#     mAP: 0.9667
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9806
#     G-mean: 0.8964
#     MCC: 0.8107
#     F1-score: 0.8053
#     mAP: 0.9338
#   [Ours - DecisionTree]
#     AUROC: 0.8729
#     G-mean: 0.8621
#     MCC: 0.7186
#     F1-score: 0.7303
#     mAP: 0.6109
#   [Ours - kNN]
#     AUROC: 0.9368
#     G-mean: 0.8945
#     MCC: 0.7823
#     F1-score: 0.7853
#     mAP: 0.8367
#   [Ours - MLP]
#     AUROC: 0.9250
#     G-mean: 0.8450
#     MCC: 0.5837
#     F1-score: 0.6037
#     mAP: 0.7645
#   [Ours - RandomForest]
#     AUROC: 0.9930
#     G-mean: 0.9160
#     MCC: 0.8376
#     F1-score: 0.8383
#     mAP: 0.9625
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9704
#     G-mean: 0.8934
#     MCC: 0.7874
#     F1-score: 0.7846
#     mAP: 0.9177
#   [Ours - DecisionTree]
#     AUROC: 0.8917
#     G-mean: 0.8822
#     MCC: 0.7475
#     F1-score: 0.7568
#     mAP: 0.6467
#   [Ours - kNN]
#     AUROC: 0.9380
#     G-mean: 0.8934
#     MCC: 0.7730
#     F1-score: 0.7768
#     mAP: 0.8472
#   [Ours - MLP]
#     AUROC: 0.9250
#     G-mean: 0.8368
#     MCC: 0.5737
#     F1-score: 0.5926
#     mAP: 0.7553
#   [Ours - RandomForest]
#     AUROC: 0.9926
#     G-mean: 0.9121
#     MCC: 0.8387
#     F1-score: 0.8400
#     mAP: 0.9611
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9688
#     G-mean: 0.8941
#     MCC: 0.7853
#     F1-score: 0.7843
#     mAP: 0.9131
#   [Ours - DecisionTree]
#     AUROC: 0.8837
#     G-mean: 0.8614
#     MCC: 0.7355
#     F1-score: 0.7435
#     mAP: 0.6392
#   [Ours - kNN]
#     AUROC: 0.9368
#     G-mean: 0.8937
#     MCC: 0.7706
#     F1-score: 0.7768
#     mAP: 0.8400
#   [Ours - MLP]
#     AUROC: 0.9243
#     G-mean: 0.8357
#     MCC: 0.5791
#     F1-score: 0.5960
#     mAP: 0.7613
#   [Ours - RandomForest]
#     AUROC: 0.9924
#     G-mean: 0.9029
#     MCC: 0.8314
#     F1-score: 0.8325
#     mAP: 0.9583
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9667
#     G-mean: 0.8950
#     MCC: 0.7897
#     F1-score: 0.7894
#     mAP: 0.9159
#   [Ours - DecisionTree]
#     AUROC: 0.8711
#     G-mean: 0.8507
#     MCC: 0.7216
#     F1-score: 0.7308
#     mAP: 0.6207
#   [Ours - kNN]
#     AUROC: 0.9419
#     G-mean: 0.8949
#     MCC: 0.7756
#     F1-score: 0.7828
#     mAP: 0.8470
#   [Ours - MLP]
#     AUROC: 0.9250
#     G-mean: 0.8419
#     MCC: 0.5903
#     F1-score: 0.6086
#     mAP: 0.7680
#   [Ours - RandomForest]
#     AUROC: 0.9911
#     G-mean: 0.8972
#     MCC: 0.8278
#     F1-score: 0.8273
#     mAP: 0.9500
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9653
#     G-mean: 0.8954
#     MCC: 0.7901
#     F1-score: 0.7917
#     mAP: 0.9131
#   [Ours - DecisionTree]
#     AUROC: 0.8646
#     G-mean: 0.8423
#     MCC: 0.7175
#     F1-score: 0.7284
#     mAP: 0.6256
#   [Ours - kNN]
#     AUROC: 0.9400
#     G-mean: 0.8950
#     MCC: 0.7757
#     F1-score: 0.7840
#     mAP: 0.8474
#   [Ours - MLP]
#     AUROC: 0.9232
#     G-mean: 0.8392
#     MCC: 0.5893
#     F1-score: 0.6100
#     mAP: 0.7704
#   [Ours - RandomForest]
#     AUROC: 0.9887
#     G-mean: 0.8909
#     MCC: 0.8209
#     F1-score: 0.8217
#     mAP: 0.9400
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9659
#     G-mean: 0.8884
#     MCC: 0.7803
#     F1-score: 0.7829
#     mAP: 0.9111
#   [Ours - DecisionTree]
#     AUROC: 0.8621
#     G-mean: 0.8345
#     MCC: 0.7054
#     F1-score: 0.7163
#     mAP: 0.6172
#   [Ours - kNN]
#     AUROC: 0.9399
#     G-mean: 0.8880
#     MCC: 0.7679
#     F1-score: 0.7758
#     mAP: 0.8444
#   [Ours - MLP]
#     AUROC: 0.9242
#     G-mean: 0.8358
#     MCC: 0.5861
#     F1-score: 0.6060
#     mAP: 0.7728
#   [Ours - RandomForest]
#     AUROC: 0.9891
#     G-mean: 0.8910
#     MCC: 0.8245
#     F1-score: 0.8252
#     mAP: 0.9414
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9656
#     G-mean: 0.8844
#     MCC: 0.7809
#     F1-score: 0.7830
#     mAP: 0.9128
#   [Ours - DecisionTree]
#     AUROC: 0.8604
#     G-mean: 0.8295
#     MCC: 0.7011
#     F1-score: 0.7126
#     mAP: 0.6159
#   [Ours - kNN]
#     AUROC: 0.9408
#     G-mean: 0.8877
#     MCC: 0.7715
#     F1-score: 0.7788
#     mAP: 0.8484
#   [Ours - MLP]
#     AUROC: 0.9267
#     G-mean: 0.8342
#     MCC: 0.5878
#     F1-score: 0.6070
#     mAP: 0.7823
#   [Ours - RandomForest]
#     AUROC: 0.9894
#     G-mean: 0.8911
#     MCC: 0.8262
#     F1-score: 0.8271
#     mAP: 0.9425
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9657
#     G-mean: 0.8863
#     MCC: 0.7853
#     F1-score: 0.7875
#     mAP: 0.9141
#   [Ours - DecisionTree]
#     AUROC: 0.8650
#     G-mean: 0.8368
#     MCC: 0.7119
#     F1-score: 0.7216
#     mAP: 0.6250
#   [Ours - kNN]
#     AUROC: 0.9430
#     G-mean: 0.8921
#     MCC: 0.7794
#     F1-score: 0.7856
#     mAP: 0.8523
#   [Ours - MLP]
#     AUROC: 0.9278
#     G-mean: 0.8339
#     MCC: 0.5915
#     F1-score: 0.6095
#     mAP: 0.7849
#   [Ours - RandomForest]
#     AUROC: 0.9897
#     G-mean: 0.8957
#     MCC: 0.8317
#     F1-score: 0.8322
#     mAP: 0.9442
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9664
#     G-mean: 0.8875
#     MCC: 0.7890
#     F1-score: 0.7905
#     mAP: 0.9136
#   [Ours - DecisionTree]
#     AUROC: 0.8619
#     G-mean: 0.8323
#     MCC: 0.7062
#     F1-score: 0.7144
#     mAP: 0.6167
#   [Ours - kNN]
#     AUROC: 0.9403
#     G-mean: 0.8928
#     MCC: 0.7842
#     F1-score: 0.7901
#     mAP: 0.8503
#   [Ours - MLP]
#     AUROC: 0.9267
#     G-mean: 0.8303
#     MCC: 0.5843
#     F1-score: 0.6033
#     mAP: 0.7842
#   [Ours - RandomForest]
#     AUROC: 0.9904
#     G-mean: 0.8936
#     MCC: 0.8306
#     F1-score: 0.8303
#     mAP: 0.9482
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/ecoli-0-3-4_vs_5_results_gaussian_beta_0.0.csv
