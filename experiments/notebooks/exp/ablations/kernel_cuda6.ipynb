# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

# Save path 
save_path = "/data4/oldrain123/oldrain123/results/ablation_results/kernel"
data_path = "/data4/oldrain123/oldrain123/dataset"

# %%
import os
import warnings
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from experiment import run_ablation

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "6"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
methods = ["Ours"]
beta = 0.01
kernel_types = ['imq', 'rq', 'laplacian']
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}

# %%
# data_name = 'ecoli3'

# n_epochs = 1000
# hidden_dims = [16, 32, 64, 128]  
# latent_dim = 256
# lr = 0.002

# for kernel_type in kernel_types:
#     print(f"kernel_type: {kernel_type}")
#     run_ablation(
#         data_name=data_name,
#         beta=beta,
#         methods=methods,
#         base_models=base_models,
#         device=device,
#         data_path=data_path,
#         save_path=save_path,
#         n_epochs=n_epochs,
#         hidden_dims=hidden_dims,
#         latent_dim=latent_dim,
#         lr=lr,
#         kernel_type=kernel_type
#     )

# %%
data_name = 'ecoli-0-3-4_vs_5'

n_epochs = 1000
hidden_dims = [8, 16, 32, 64]
latent_dim = 128
lr = 0.002

for kernel_type in kernel_types:
    print(f"kernel_type: {kernel_type}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr,
        kernel_type=kernel_type
    )
# Out:
# kernel_type: imq
# Dataset loaded from DataFrame
# X shape : (200, 7)
# target : Counter({0: 180, 1: 20})
# IR: 9.0
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9500
#     G-mean: 0.8950
#     MCC: 0.7985
#     F1-score: 0.7934
#     mAP: 0.8900
#   [Ours - DecisionTree]
#     AUROC: 0.8389
#     G-mean: 0.8240
#     MCC: 0.6670
#     F1-score: 0.6744
#     mAP: 0.5452
#   [Ours - kNN]
#     AUROC: 0.9319
#     G-mean: 0.9195
#     MCC: 0.7926
#     F1-score: 0.7967
#     mAP: 0.7683
#   [Ours - MLP]
#     AUROC: 0.8972
#     G-mean: 0.8417
#     MCC: 0.5281
#     F1-score: 0.5535
#     mAP: 0.7369
#   [Ours - RandomForest]
#     AUROC: 0.9917
#     G-mean: 0.9009
#     MCC: 0.8239
#     F1-score: 0.8200
#     mAP: 0.9500
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9639
#     G-mean: 0.8960
#     MCC: 0.7868
#     F1-score: 0.7900
#     mAP: 0.9063
#   [Ours - DecisionTree]
#     AUROC: 0.8597
#     G-mean: 0.8443
#     MCC: 0.7031
#     F1-score: 0.7106
#     mAP: 0.5910
#   [Ours - kNN]
#     AUROC: 0.9361
#     G-mean: 0.9214
#     MCC: 0.7931
#     F1-score: 0.8017
#     mAP: 0.8141
#   [Ours - MLP]
#     AUROC: 0.9139
#     G-mean: 0.7766
#     MCC: 0.4993
#     F1-score: 0.5236
#     mAP: 0.7326
#   [Ours - RandomForest]
#     AUROC: 0.9903
#     G-mean: 0.8866
#     MCC: 0.8065
#     F1-score: 0.8050
#     mAP: 0.9500
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9630
#     G-mean: 0.8976
#     MCC: 0.7992
#     F1-score: 0.8000
#     mAP: 0.9121
#   [Ours - DecisionTree]
#     AUROC: 0.8666
#     G-mean: 0.8514
#     MCC: 0.7086
#     F1-score: 0.7193
#     mAP: 0.6062
#   [Ours - kNN]
#     AUROC: 0.9366
#     G-mean: 0.9123
#     MCC: 0.7802
#     F1-score: 0.7900
#     mAP: 0.8267
#   [Ours - MLP]
#     AUROC: 0.9037
#     G-mean: 0.7682
#     MCC: 0.4989
#     F1-score: 0.5244
#     mAP: 0.6961
#   [Ours - RandomForest]
#     AUROC: 0.9898
#     G-mean: 0.8917
#     MCC: 0.8110
#     F1-score: 0.8111
#     mAP: 0.9444
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9653
#     G-mean: 0.8960
#     MCC: 0.7848
#     F1-score: 0.7883
#     mAP: 0.9130
#   [Ours - DecisionTree]
#     AUROC: 0.8541
#     G-mean: 0.8315
#     MCC: 0.6748
#     F1-score: 0.6895
#     mAP: 0.5851
#   [Ours - kNN]
#     AUROC: 0.9368
#     G-mean: 0.9136
#     MCC: 0.7764
#     F1-score: 0.7858
#     mAP: 0.8246
#   [Ours - MLP]
#     AUROC: 0.9062
#     G-mean: 0.7814
#     MCC: 0.5112
#     F1-score: 0.5359
#     mAP: 0.7086
#   [Ours - RandomForest]
#     AUROC: 0.9882
#     G-mean: 0.8875
#     MCC: 0.8106
#     F1-score: 0.8108
#     mAP: 0.9312
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9650
#     G-mean: 0.8956
#     MCC: 0.7813
#     F1-score: 0.7853
#     mAP: 0.9110
#   [Ours - DecisionTree]
#     AUROC: 0.8589
#     G-mean: 0.8373
#     MCC: 0.6890
#     F1-score: 0.7004
#     mAP: 0.5964
#   [Ours - kNN]
#     AUROC: 0.9375
#     G-mean: 0.9163
#     MCC: 0.7880
#     F1-score: 0.7953
#     mAP: 0.8250
#   [Ours - MLP]
#     AUROC: 0.9089
#     G-mean: 0.7847
#     MCC: 0.5181
#     F1-score: 0.5411
#     mAP: 0.7205
#   [Ours - RandomForest]
#     AUROC: 0.9889
#     G-mean: 0.8902
#     MCC: 0.8133
#     F1-score: 0.8127
#     mAP: 0.9350
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9630
#     G-mean: 0.8962
#     MCC: 0.7864
#     F1-score: 0.7920
#     mAP: 0.9077
#   [Ours - DecisionTree]
#     AUROC: 0.8569
#     G-mean: 0.8259
#     MCC: 0.6833
#     F1-score: 0.6965
#     mAP: 0.5994
#   [Ours - kNN]
#     AUROC: 0.9373
#     G-mean: 0.9181
#     MCC: 0.7938
#     F1-score: 0.8022
#     mAP: 0.8267
#   [Ours - MLP]
#     AUROC: 0.9097
#     G-mean: 0.7917
#     MCC: 0.5245
#     F1-score: 0.5496
#     mAP: 0.7198
#   [Ours - RandomForest]
#     AUROC: 0.9866
#     G-mean: 0.8764
#     MCC: 0.8046
#     F1-score: 0.8044
#     mAP: 0.9269
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9623
#     G-mean: 0.8888
#     MCC: 0.7749
#     F1-score: 0.7822
#     mAP: 0.9051
#   [Ours - DecisionTree]
#     AUROC: 0.8559
#     G-mean: 0.8214
#     MCC: 0.6800
#     F1-score: 0.6946
#     mAP: 0.5995
#   [Ours - kNN]
#     AUROC: 0.9381
#     G-mean: 0.9118
#     MCC: 0.7861
#     F1-score: 0.7948
#     mAP: 0.8314
#   [Ours - MLP]
#     AUROC: 0.9115
#     G-mean: 0.7905
#     MCC: 0.5230
#     F1-score: 0.5479
#     mAP: 0.7249
#   [Ours - RandomForest]
#     AUROC: 0.9861
#     G-mean: 0.8660
#     MCC: 0.7972
#     F1-score: 0.7962
#     mAP: 0.9243
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9653
#     G-mean: 0.8851
#     MCC: 0.7764
#     F1-score: 0.7827
#     mAP: 0.9107
#   [Ours - DecisionTree]
#     AUROC: 0.8528
#     G-mean: 0.8145
#     MCC: 0.6729
#     F1-score: 0.6886
#     mAP: 0.5929
#   [Ours - kNN]
#     AUROC: 0.9410
#     G-mean: 0.9078
#     MCC: 0.7843
#     F1-score: 0.7921
#     mAP: 0.8302
#   [Ours - MLP]
#     AUROC: 0.9153
#     G-mean: 0.7965
#     MCC: 0.5347
#     F1-score: 0.5573
#     mAP: 0.7312
#   [Ours - RandomForest]
#     AUROC: 0.9871
#     G-mean: 0.8620
#     MCC: 0.7941
#     F1-score: 0.7937
#     mAP: 0.9296
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9648
#     G-mean: 0.8866
#     MCC: 0.7798
#     F1-score: 0.7858
#     mAP: 0.9113
#   [Ours - DecisionTree]
#     AUROC: 0.8555
#     G-mean: 0.8197
#     MCC: 0.6788
#     F1-score: 0.6929
#     mAP: 0.5939
#   [Ours - kNN]
#     AUROC: 0.9440
#     G-mean: 0.9109
#     MCC: 0.7967
#     F1-score: 0.8033
#     mAP: 0.8394
#   [Ours - MLP]
#     AUROC: 0.9170
#     G-mean: 0.8018
#     MCC: 0.5421
#     F1-score: 0.5648
#     mAP: 0.7419
#   [Ours - RandomForest]
#     AUROC: 0.9870
#     G-mean: 0.8666
#     MCC: 0.7997
#     F1-score: 0.7989
#     mAP: 0.9300
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9658
#     G-mean: 0.8877
#     MCC: 0.7841
#     F1-score: 0.7889
#     mAP: 0.9145
#   [Ours - DecisionTree]
#     AUROC: 0.8575
#     G-mean: 0.8238
#     MCC: 0.6849
#     F1-score: 0.6976
#     mAP: 0.5973
#   [Ours - kNN]
#     AUROC: 0.9464
#     G-mean: 0.9096
#     MCC: 0.7994
#     F1-score: 0.8047
#     mAP: 0.8443
#   [Ours - MLP]
#     AUROC: 0.9189
#     G-mean: 0.8070
#     MCC: 0.5458
#     F1-score: 0.5676
#     mAP: 0.7467
#   [Ours - RandomForest]
#     AUROC: 0.9883
#     G-mean: 0.8671
#     MCC: 0.8009
#     F1-score: 0.7994
#     mAP: 0.9370
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/kernel/ecoli-0-3-4_vs_5_results_imq_beta_0.01.csv
# kernel_type: rq
# Dataset loaded from DataFrame
# X shape : (200, 7)
# target : Counter({0: 180, 1: 20})
# IR: 9.0
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9639
#     G-mean: 0.8873
#     MCC: 0.7408
#     F1-score: 0.7434
#     mAP: 0.9000
#   [Ours - DecisionTree]
#     AUROC: 0.8514
#     G-mean: 0.8304
#     MCC: 0.6794
#     F1-score: 0.6871
#     mAP: 0.6000
#   [Ours - kNN]
#     AUROC: 0.9361
#     G-mean: 0.8931
#     MCC: 0.7741
#     F1-score: 0.7767
#     mAP: 0.8017
#   [Ours - MLP]
#     AUROC: 0.9111
#     G-mean: 0.8458
#     MCC: 0.5553
#     F1-score: 0.5778
#     mAP: 0.7805
#   [Ours - RandomForest]
#     AUROC: 0.9917
#     G-mean: 0.9009
#     MCC: 0.8239
#     F1-score: 0.8200
#     mAP: 0.9583
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9736
#     G-mean: 0.8906
#     MCC: 0.7516
#     F1-score: 0.7583
#     mAP: 0.9208
#   [Ours - DecisionTree]
#     AUROC: 0.8639
#     G-mean: 0.8457
#     MCC: 0.7008
#     F1-score: 0.7052
#     mAP: 0.6225
#   [Ours - kNN]
#     AUROC: 0.9368
#     G-mean: 0.9097
#     MCC: 0.7902
#     F1-score: 0.7983
#     mAP: 0.8225
#   [Ours - MLP]
#     AUROC: 0.9264
#     G-mean: 0.8065
#     MCC: 0.5191
#     F1-score: 0.5369
#     mAP: 0.7786
#   [Ours - RandomForest]
#     AUROC: 0.9903
#     G-mean: 0.9173
#     MCC: 0.8479
#     F1-score: 0.8483
#     mAP: 0.9542
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9685
#     G-mean: 0.8915
#     MCC: 0.7591
#     F1-score: 0.7645
#     mAP: 0.9217
#   [Ours - DecisionTree]
#     AUROC: 0.8611
#     G-mean: 0.8291
#     MCC: 0.6936
#     F1-score: 0.7001
#     mAP: 0.6150
#   [Ours - kNN]
#     AUROC: 0.9384
#     G-mean: 0.9158
#     MCC: 0.8037
#     F1-score: 0.8111
#     mAP: 0.8378
#   [Ours - MLP]
#     AUROC: 0.9213
#     G-mean: 0.8080
#     MCC: 0.5158
#     F1-score: 0.5362
#     mAP: 0.7462
#   [Ours - RandomForest]
#     AUROC: 0.9898
#     G-mean: 0.8892
#     MCC: 0.8213
#     F1-score: 0.8233
#     mAP: 0.9472
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9694
#     G-mean: 0.8914
#     MCC: 0.7528
#     F1-score: 0.7600
#     mAP: 0.9179
#   [Ours - DecisionTree]
#     AUROC: 0.8594
#     G-mean: 0.8213
#     MCC: 0.6900
#     F1-score: 0.6993
#     mAP: 0.6154
#   [Ours - kNN]
#     AUROC: 0.9379
#     G-mean: 0.9172
#     MCC: 0.8004
#     F1-score: 0.8083
#     mAP: 0.8329
#   [Ours - MLP]
#     AUROC: 0.9222
#     G-mean: 0.8192
#     MCC: 0.5372
#     F1-score: 0.5556
#     mAP: 0.7450
#   [Ours - RandomForest]
#     AUROC: 0.9903
#     G-mean: 0.8857
#     MCC: 0.8184
#     F1-score: 0.8200
#     mAP: 0.9479
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9672
#     G-mean: 0.8915
#     MCC: 0.7541
#     F1-score: 0.7614
#     mAP: 0.9125
#   [Ours - DecisionTree]
#     AUROC: 0.8558
#     G-mean: 0.8240
#     MCC: 0.6866
#     F1-score: 0.6988
#     mAP: 0.6057
#   [Ours - kNN]
#     AUROC: 0.9367
#     G-mean: 0.9180
#     MCC: 0.8029
#     F1-score: 0.8088
#     mAP: 0.8290
#   [Ours - MLP]
#     AUROC: 0.9228
#     G-mean: 0.8324
#     MCC: 0.5630
#     F1-score: 0.5787
#     mAP: 0.7335
#   [Ours - RandomForest]
#     AUROC: 0.9895
#     G-mean: 0.8889
#     MCC: 0.8187
#     F1-score: 0.8207
#     mAP: 0.9433
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9648
#     G-mean: 0.8915
#     MCC: 0.7541
#     F1-score: 0.7637
#     mAP: 0.9089
#   [Ours - DecisionTree]
#     AUROC: 0.8651
#     G-mean: 0.8370
#     MCC: 0.7088
#     F1-score: 0.7195
#     mAP: 0.6281
#   [Ours - kNN]
#     AUROC: 0.9361
#     G-mean: 0.9190
#     MCC: 0.8028
#     F1-score: 0.8101
#     mAP: 0.8300
#   [Ours - MLP]
#     AUROC: 0.9199
#     G-mean: 0.8204
#     MCC: 0.5574
#     F1-score: 0.5770
#     mAP: 0.7281
#   [Ours - RandomForest]
#     AUROC: 0.9884
#     G-mean: 0.8920
#     MCC: 0.8258
#     F1-score: 0.8278
#     mAP: 0.9408
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9607
#     G-mean: 0.8849
#     MCC: 0.7471
#     F1-score: 0.7574
#     mAP: 0.9029
#   [Ours - DecisionTree]
#     AUROC: 0.8603
#     G-mean: 0.8279
#     MCC: 0.7062
#     F1-score: 0.7167
#     mAP: 0.6283
#   [Ours - kNN]
#     AUROC: 0.9371
#     G-mean: 0.9134
#     MCC: 0.7998
#     F1-score: 0.8072
#     mAP: 0.8343
#   [Ours - MLP]
#     AUROC: 0.9179
#     G-mean: 0.8062
#     MCC: 0.5436
#     F1-score: 0.5651
#     mAP: 0.7340
#   [Ours - RandomForest]
#     AUROC: 0.9881
#     G-mean: 0.8835
#     MCC: 0.8198
#     F1-score: 0.8209
#     mAP: 0.9386
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9625
#     G-mean: 0.8839
#     MCC: 0.7505
#     F1-score: 0.7595
#     mAP: 0.9038
#   [Ours - DecisionTree]
#     AUROC: 0.8634
#     G-mean: 0.8352
#     MCC: 0.7092
#     F1-score: 0.7200
#     mAP: 0.6293
#   [Ours - kNN]
#     AUROC: 0.9370
#     G-mean: 0.9092
#     MCC: 0.7972
#     F1-score: 0.8038
#     mAP: 0.8271
#   [Ours - MLP]
#     AUROC: 0.9219
#     G-mean: 0.8061
#     MCC: 0.5435
#     F1-score: 0.5638
#     mAP: 0.7498
#   [Ours - RandomForest]
#     AUROC: 0.9889
#     G-mean: 0.8842
#     MCC: 0.8205
#     F1-score: 0.8217
#     mAP: 0.9421
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9617
#     G-mean: 0.8856
#     MCC: 0.7568
#     F1-score: 0.7651
#     mAP: 0.9023
#   [Ours - DecisionTree]
#     AUROC: 0.8653
#     G-mean: 0.8387
#     MCC: 0.7144
#     F1-score: 0.7241
#     mAP: 0.6310
#   [Ours - kNN]
#     AUROC: 0.9372
#     G-mean: 0.9109
#     MCC: 0.7999
#     F1-score: 0.8056
#     mAP: 0.8307
#   [Ours - MLP]
#     AUROC: 0.9225
#     G-mean: 0.8078
#     MCC: 0.5494
#     F1-score: 0.5697
#     mAP: 0.7518
#   [Ours - RandomForest]
#     AUROC: 0.9886
#     G-mean: 0.8800
#     MCC: 0.8154
#     F1-score: 0.8170
#     mAP: 0.9402
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9636
#     G-mean: 0.8863
#     MCC: 0.7589
#     F1-score: 0.7667
#     mAP: 0.9046
#   [Ours - DecisionTree]
#     AUROC: 0.8665
#     G-mean: 0.8410
#     MCC: 0.7152
#     F1-score: 0.7240
#     mAP: 0.6274
#   [Ours - kNN]
#     AUROC: 0.9396
#     G-mean: 0.9094
#     MCC: 0.7998
#     F1-score: 0.8051
#     mAP: 0.8340
#   [Ours - MLP]
#     AUROC: 0.9217
#     G-mean: 0.8094
#     MCC: 0.5493
#     F1-score: 0.5697
#     mAP: 0.7540
#   [Ours - RandomForest]
#     AUROC: 0.9897
#     G-mean: 0.8791
#     MCC: 0.8151
#     F1-score: 0.8157
#     mAP: 0.9462
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/kernel/ecoli-0-3-4_vs_5_results_rq_beta_0.01.csv
# kernel_type: laplacian
# Dataset loaded from DataFrame
# X shape : (200, 7)
# target : Counter({0: 180, 1: 20})
# IR: 9.0
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9528
#     G-mean: 0.8951
#     MCC: 0.7905
#     F1-score: 0.7867
#     mAP: 0.9146
#   [Ours - DecisionTree]
#     AUROC: 0.8791
#     G-mean: 0.8638
#     MCC: 0.7429
#     F1-score: 0.7433
#     mAP: 0.6283
#   [Ours - kNN]
#     AUROC: 0.9375
#     G-mean: 0.8951
#     MCC: 0.7905
#     F1-score: 0.7867
#     mAP: 0.8183
#   [Ours - MLP]
#     AUROC: 0.8861
#     G-mean: 0.8202
#     MCC: 0.5164
#     F1-score: 0.5486
#     mAP: 0.7046
#   [Ours - RandomForest]
#     AUROC: 0.9889
#     G-mean: 0.9017
#     MCC: 0.8201
#     F1-score: 0.8233
#     mAP: 0.9417
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9667
#     G-mean: 0.8960
#     MCC: 0.7828
#     F1-score: 0.7867
#     mAP: 0.9228
#   [Ours - DecisionTree]
#     AUROC: 0.9076
#     G-mean: 0.8950
#     MCC: 0.7746
#     F1-score: 0.7816
#     mAP: 0.6942
#   [Ours - kNN]
#     AUROC: 0.9250
#     G-mean: 0.8931
#     MCC: 0.7720
#     F1-score: 0.7752
#     mAP: 0.8083
#   [Ours - MLP]
#     AUROC: 0.9139
#     G-mean: 0.7660
#     MCC: 0.4922
#     F1-score: 0.5168
#     mAP: 0.7444
#   [Ours - RandomForest]
#     AUROC: 0.9882
#     G-mean: 0.9163
#     MCC: 0.8357
#     F1-score: 0.8400
#     mAP: 0.9433
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9658
#     G-mean: 0.8976
#     MCC: 0.7965
#     F1-score: 0.7978
#     mAP: 0.9233
#   [Ours - DecisionTree]
#     AUROC: 0.8889
#     G-mean: 0.8622
#     MCC: 0.7457
#     F1-score: 0.7544
#     mAP: 0.6711
#   [Ours - kNN]
#     AUROC: 0.9296
#     G-mean: 0.8931
#     MCC: 0.7700
#     F1-score: 0.7735
#     mAP: 0.8172
#   [Ours - MLP]
#     AUROC: 0.9176
#     G-mean: 0.7715
#     MCC: 0.5172
#     F1-score: 0.5348
#     mAP: 0.7410
#   [Ours - RandomForest]
#     AUROC: 0.9884
#     G-mean: 0.9115
#     MCC: 0.8305
#     F1-score: 0.8344
#     mAP: 0.9400
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9632
#     G-mean: 0.8965
#     MCC: 0.7889
#     F1-score: 0.7908
#     mAP: 0.9201
#   [Ours - DecisionTree]
#     AUROC: 0.8774
#     G-mean: 0.8540
#     MCC: 0.7212
#     F1-score: 0.7333
#     mAP: 0.6408
#   [Ours - kNN]
#     AUROC: 0.9313
#     G-mean: 0.9004
#     MCC: 0.7749
#     F1-score: 0.7793
#     mAP: 0.8133
#   [Ours - MLP]
#     AUROC: 0.9174
#     G-mean: 0.7912
#     MCC: 0.5418
#     F1-score: 0.5574
#     mAP: 0.7371
#   [Ours - RandomForest]
#     AUROC: 0.9886
#     G-mean: 0.9014
#     MCC: 0.8131
#     F1-score: 0.8200
#     mAP: 0.9383
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9639
#     G-mean: 0.8960
#     MCC: 0.7861
#     F1-score: 0.7887
#     mAP: 0.9152
#   [Ours - DecisionTree]
#     AUROC: 0.8772
#     G-mean: 0.8560
#     MCC: 0.7239
#     F1-score: 0.7340
#     mAP: 0.6350
#   [Ours - kNN]
#     AUROC: 0.9322
#     G-mean: 0.8995
#     MCC: 0.7773
#     F1-score: 0.7814
#     mAP: 0.8133
#   [Ours - MLP]
#     AUROC: 0.9133
#     G-mean: 0.7943
#     MCC: 0.5468
#     F1-score: 0.5625
#     mAP: 0.7188
#   [Ours - RandomForest]
#     AUROC: 0.9892
#     G-mean: 0.8901
#     MCC: 0.8085
#     F1-score: 0.8120
#     mAP: 0.9407
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9621
#     G-mean: 0.8957
#     MCC: 0.7842
#     F1-score: 0.7898
#     mAP: 0.9110
#   [Ours - DecisionTree]
#     AUROC: 0.8766
#     G-mean: 0.8499
#     MCC: 0.7161
#     F1-score: 0.7256
#     mAP: 0.6255
#   [Ours - kNN]
#     AUROC: 0.9326
#     G-mean: 0.9036
#     MCC: 0.7815
#     F1-score: 0.7873
#     mAP: 0.8128
#   [Ours - MLP]
#     AUROC: 0.9158
#     G-mean: 0.8077
#     MCC: 0.5620
#     F1-score: 0.5776
#     mAP: 0.7243
#   [Ours - RandomForest]
#     AUROC: 0.9873
#     G-mean: 0.8859
#     MCC: 0.8117
#     F1-score: 0.8145
#     mAP: 0.9331
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9595
#     G-mean: 0.8898
#     MCC: 0.7798
#     F1-score: 0.7865
#     mAP: 0.9068
#   [Ours - DecisionTree]
#     AUROC: 0.8772
#     G-mean: 0.8461
#     MCC: 0.7163
#     F1-score: 0.7253
#     mAP: 0.6305
#   [Ours - kNN]
#     AUROC: 0.9339
#     G-mean: 0.8994
#     MCC: 0.7767
#     F1-score: 0.7829
#     mAP: 0.8171
#   [Ours - MLP]
#     AUROC: 0.9107
#     G-mean: 0.8038
#     MCC: 0.5571
#     F1-score: 0.5730
#     mAP: 0.7184
#   [Ours - RandomForest]
#     AUROC: 0.9859
#     G-mean: 0.8746
#     MCC: 0.8050
#     F1-score: 0.8067
#     mAP: 0.9276
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9615
#     G-mean: 0.8893
#     MCC: 0.7829
#     F1-score: 0.7891
#     mAP: 0.9072
#   [Ours - DecisionTree]
#     AUROC: 0.8769
#     G-mean: 0.8434
#     MCC: 0.7152
#     F1-score: 0.7250
#     mAP: 0.6339
#   [Ours - kNN]
#     AUROC: 0.9342
#     G-mean: 0.8966
#     MCC: 0.7749
#     F1-score: 0.7806
#     mAP: 0.8121
#   [Ours - MLP]
#     AUROC: 0.9153
#     G-mean: 0.8178
#     MCC: 0.5730
#     F1-score: 0.5875
#     mAP: 0.7327
#   [Ours - RandomForest]
#     AUROC: 0.9870
#     G-mean: 0.8732
#     MCC: 0.8048
#     F1-score: 0.8071
#     mAP: 0.9325
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9599
#     G-mean: 0.8904
#     MCC: 0.7852
#     F1-score: 0.7917
#     mAP: 0.9025
#   [Ours - DecisionTree]
#     AUROC: 0.8798
#     G-mean: 0.8491
#     MCC: 0.7245
#     F1-score: 0.7326
#     mAP: 0.6410
#   [Ours - kNN]
#     AUROC: 0.9380
#     G-mean: 0.9005
#     MCC: 0.7830
#     F1-score: 0.7894
#     mAP: 0.8233
#   [Ours - MLP]
#     AUROC: 0.9167
#     G-mean: 0.8219
#     MCC: 0.5799
#     F1-score: 0.5943
#     mAP: 0.7394
#   [Ours - RandomForest]
#     AUROC: 0.9866
#     G-mean: 0.8766
#     MCC: 0.8092
#     F1-score: 0.8107
#     mAP: 0.9307
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9625
#     G-mean: 0.8910
#     MCC: 0.7865
#     F1-score: 0.7926
#     mAP: 0.9056
#   [Ours - DecisionTree]
#     AUROC: 0.8767
#     G-mean: 0.8478
#     MCC: 0.7282
#     F1-score: 0.7344
#     mAP: 0.6427
#   [Ours - kNN]
#     AUROC: 0.9401
#     G-mean: 0.9027
#     MCC: 0.7856
#     F1-score: 0.7918
#     mAP: 0.8282
#   [Ours - MLP]
#     AUROC: 0.9175
#     G-mean: 0.8223
#     MCC: 0.5765
#     F1-score: 0.5914
#     mAP: 0.7412
#   [Ours - RandomForest]
#     AUROC: 0.9879
#     G-mean: 0.8763
#     MCC: 0.8104
#     F1-score: 0.8110
#     mAP: 0.9377
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/kernel/ecoli-0-3-4_vs_5_results_laplacian_beta_0.01.csv

# %%
data_name = 'ecoli4'

n_epochs = 1000
hidden_dims = [16, 32, 64, 128]  
latent_dim = 256
lr = 0.002

for kernel_type in kernel_types:
    print(f"kernel_type: {kernel_type}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr,
        kernel_type=kernel_type
    )
# Out:
# kernel_type: imq
# Dataset loaded from DataFrame
# X shape : (336, 7)
# target : Counter({0: 314, 1: 22})
# IR: 14.27
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9764
#     G-mean: 0.8689
#     MCC: 0.7402
#     F1-score: 0.7372
#     mAP: 0.9122
#   [Ours - DecisionTree]
#     AUROC: 0.8094
#     G-mean: 0.7865
#     MCC: 0.7213
#     F1-score: 0.6967
#     mAP: 0.5781
#   [Ours - kNN]
#     AUROC: 0.9340
#     G-mean: 0.8914
#     MCC: 0.7332
#     F1-score: 0.7367
#     mAP: 0.8478
#   [Ours - MLP]
#     AUROC: 0.9371
#     G-mean: 0.8812
#     MCC: 0.5286
#     F1-score: 0.5138
#     mAP: 0.8974
#   [Ours - RandomForest]
#     AUROC: 0.9715
#     G-mean: 0.8763
#     MCC: 0.8193
#     F1-score: 0.8100
#     mAP: 0.9228
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9748
#     G-mean: 0.8654
#     MCC: 0.7309
#     F1-score: 0.7252
#     mAP: 0.9062
#   [Ours - DecisionTree]
#     AUROC: 0.8435
#     G-mean: 0.7943
#     MCC: 0.7270
#     F1-score: 0.7117
#     mAP: 0.6126
#   [Ours - kNN]
#     AUROC: 0.9294
#     G-mean: 0.8872
#     MCC: 0.7510
#     F1-score: 0.7495
#     mAP: 0.8134
#   [Ours - MLP]
#     AUROC: 0.9437
#     G-mean: 0.8822
#     MCC: 0.5189
#     F1-score: 0.5030
#     mAP: 0.8844
#   [Ours - RandomForest]
#     AUROC: 0.9720
#     G-mean: 0.8696
#     MCC: 0.8292
#     F1-score: 0.8184
#     mAP: 0.9083
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9725
#     G-mean: 0.8686
#     MCC: 0.7186
#     F1-score: 0.7147
#     mAP: 0.8972
#   [Ours - DecisionTree]
#     AUROC: 0.8466
#     G-mean: 0.8149
#     MCC: 0.7351
#     F1-score: 0.7245
#     mAP: 0.6246
#   [Ours - kNN]
#     AUROC: 0.9281
#     G-mean: 0.8849
#     MCC: 0.7428
#     F1-score: 0.7416
#     mAP: 0.8174
#   [Ours - MLP]
#     AUROC: 0.9461
#     G-mean: 0.8807
#     MCC: 0.5091
#     F1-score: 0.4923
#     mAP: 0.8833
#   [Ours - RandomForest]
#     AUROC: 0.9734
#     G-mean: 0.8434
#     MCC: 0.8017
#     F1-score: 0.7933
#     mAP: 0.9000
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9736
#     G-mean: 0.8635
#     MCC: 0.7165
#     F1-score: 0.7120
#     mAP: 0.8892
#   [Ours - DecisionTree]
#     AUROC: 0.8449
#     G-mean: 0.7956
#     MCC: 0.7244
#     F1-score: 0.7134
#     mAP: 0.6230
#   [Ours - kNN]
#     AUROC: 0.9236
#     G-mean: 0.8810
#     MCC: 0.7250
#     F1-score: 0.7220
#     mAP: 0.7961
#   [Ours - MLP]
#     AUROC: 0.9416
#     G-mean: 0.8747
#     MCC: 0.4965
#     F1-score: 0.4787
#     mAP: 0.8813
#   [Ours - RandomForest]
#     AUROC: 0.9740
#     G-mean: 0.8239
#     MCC: 0.7770
#     F1-score: 0.7683
#     mAP: 0.9050
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9730
#     G-mean: 0.8616
#     MCC: 0.7158
#     F1-score: 0.7089
#     mAP: 0.8938
#   [Ours - DecisionTree]
#     AUROC: 0.8487
#     G-mean: 0.7949
#     MCC: 0.7211
#     F1-score: 0.7134
#     mAP: 0.6349
#   [Ours - kNN]
#     AUROC: 0.9255
#     G-mean: 0.8809
#     MCC: 0.7210
#     F1-score: 0.7170
#     mAP: 0.8037
#   [Ours - MLP]
#     AUROC: 0.9400
#     G-mean: 0.8690
#     MCC: 0.4867
#     F1-score: 0.4690
#     mAP: 0.8639
#   [Ours - RandomForest]
#     AUROC: 0.9738
#     G-mean: 0.8234
#     MCC: 0.7816
#     F1-score: 0.7733
#     mAP: 0.8967
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9751
#     G-mean: 0.8609
#     MCC: 0.7176
#     F1-score: 0.7099
#     mAP: 0.8967
#   [Ours - DecisionTree]
#     AUROC: 0.8523
#     G-mean: 0.7985
#     MCC: 0.7236
#     F1-score: 0.7157
#     mAP: 0.6319
#   [Ours - kNN]
#     AUROC: 0.9248
#     G-mean: 0.8813
#     MCC: 0.7192
#     F1-score: 0.7163
#     mAP: 0.8036
#   [Ours - MLP]
#     AUROC: 0.9392
#     G-mean: 0.8677
#     MCC: 0.4913
#     F1-score: 0.4738
#     mAP: 0.8689
#   [Ours - RandomForest]
#     AUROC: 0.9727
#     G-mean: 0.8330
#     MCC: 0.7972
#     F1-score: 0.7883
#     mAP: 0.8940
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9752
#     G-mean: 0.8591
#     MCC: 0.7161
#     F1-score: 0.7092
#     mAP: 0.8914
#   [Ours - DecisionTree]
#     AUROC: 0.8600
#     G-mean: 0.7922
#     MCC: 0.7117
#     F1-score: 0.7038
#     mAP: 0.6309
#   [Ours - kNN]
#     AUROC: 0.9238
#     G-mean: 0.8803
#     MCC: 0.7154
#     F1-score: 0.7130
#     mAP: 0.7998
#   [Ours - MLP]
#     AUROC: 0.9380
#     G-mean: 0.8680
#     MCC: 0.4892
#     F1-score: 0.4716
#     mAP: 0.8681
#   [Ours - RandomForest]
#     AUROC: 0.9737
#     G-mean: 0.8373
#     MCC: 0.8032
#     F1-score: 0.7938
#     mAP: 0.8947
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9749
#     G-mean: 0.8570
#     MCC: 0.7199
#     F1-score: 0.7135
#     mAP: 0.8881
#   [Ours - DecisionTree]
#     AUROC: 0.8583
#     G-mean: 0.7926
#     MCC: 0.7075
#     F1-score: 0.7021
#     mAP: 0.6275
#   [Ours - kNN]
#     AUROC: 0.9239
#     G-mean: 0.8841
#     MCC: 0.7228
#     F1-score: 0.7202
#     mAP: 0.8031
#   [Ours - MLP]
#     AUROC: 0.9424
#     G-mean: 0.8690
#     MCC: 0.4885
#     F1-score: 0.4706
#     mAP: 0.8684
#   [Ours - RandomForest]
#     AUROC: 0.9731
#     G-mean: 0.8351
#     MCC: 0.8001
#     F1-score: 0.7921
#     mAP: 0.8901
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9752
#     G-mean: 0.8575
#     MCC: 0.7202
#     F1-score: 0.7132
#     mAP: 0.8893
#   [Ours - DecisionTree]
#     AUROC: 0.8641
#     G-mean: 0.7976
#     MCC: 0.7101
#     F1-score: 0.7048
#     mAP: 0.6291
#   [Ours - kNN]
#     AUROC: 0.9225
#     G-mean: 0.8808
#     MCC: 0.7144
#     F1-score: 0.7116
#     mAP: 0.7976
#   [Ours - MLP]
#     AUROC: 0.9461
#     G-mean: 0.8696
#     MCC: 0.4969
#     F1-score: 0.4804
#     mAP: 0.8711
#   [Ours - RandomForest]
#     AUROC: 0.9736
#     G-mean: 0.8389
#     MCC: 0.7988
#     F1-score: 0.7911
#     mAP: 0.8911
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9738
#     G-mean: 0.8537
#     MCC: 0.7175
#     F1-score: 0.7115
#     mAP: 0.8854
#   [Ours - DecisionTree]
#     AUROC: 0.8672
#     G-mean: 0.7991
#     MCC: 0.7086
#     F1-score: 0.7042
#     mAP: 0.6287
#   [Ours - kNN]
#     AUROC: 0.9225
#     G-mean: 0.8814
#     MCC: 0.7108
#     F1-score: 0.7095
#     mAP: 0.8015
#   [Ours - MLP]
#     AUROC: 0.9453
#     G-mean: 0.8678
#     MCC: 0.4929
#     F1-score: 0.4767
#     mAP: 0.8660
#   [Ours - RandomForest]
#     AUROC: 0.9705
#     G-mean: 0.8341
#     MCC: 0.7946
#     F1-score: 0.7872
#     mAP: 0.8876
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/kernel/ecoli4_results_imq_beta_0.01.csv
# kernel_type: rq
# Dataset loaded from DataFrame
# X shape : (336, 7)
# target : Counter({0: 314, 1: 22})
# IR: 14.27
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9823
#     G-mean: 0.8705
#     MCC: 0.7484
#     F1-score: 0.7467
#     mAP: 0.9072
#   [Ours - DecisionTree]
#     AUROC: 0.8589
#     G-mean: 0.8190
#     MCC: 0.7755
#     F1-score: 0.7567
#     mAP: 0.6614
#   [Ours - kNN]
#     AUROC: 0.9340
#     G-mean: 0.8930
#     MCC: 0.7528
#     F1-score: 0.7567
#     mAP: 0.8456
#   [Ours - MLP]
#     AUROC: 0.9367
#     G-mean: 0.8789
#     MCC: 0.5237
#     F1-score: 0.5122
#     mAP: 0.8788
#   [Ours - RandomForest]
#     AUROC: 0.9801
#     G-mean: 0.8795
#     MCC: 0.8587
#     F1-score: 0.8500
#     mAP: 0.9306
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9756
#     G-mean: 0.8661
#     MCC: 0.7319
#     F1-score: 0.7284
#     mAP: 0.9016
#   [Ours - DecisionTree]
#     AUROC: 0.8548
#     G-mean: 0.8298
#     MCC: 0.7650
#     F1-score: 0.7550
#     mAP: 0.6499
#   [Ours - kNN]
#     AUROC: 0.9294
#     G-mean: 0.8863
#     MCC: 0.7507
#     F1-score: 0.7481
#     mAP: 0.8273
#   [Ours - MLP]
#     AUROC: 0.9409
#     G-mean: 0.8806
#     MCC: 0.5128
#     F1-score: 0.4976
#     mAP: 0.8846
#   [Ours - RandomForest]
#     AUROC: 0.9787
#     G-mean: 0.8592
#     MCC: 0.8367
#     F1-score: 0.8234
#     mAP: 0.9153
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9779
#     G-mean: 0.8623
#     MCC: 0.7309
#     F1-score: 0.7286
#     mAP: 0.9048
#   [Ours - DecisionTree]
#     AUROC: 0.8483
#     G-mean: 0.7922
#     MCC: 0.7251
#     F1-score: 0.7178
#     mAP: 0.6503
#   [Ours - kNN]
#     AUROC: 0.9273
#     G-mean: 0.8848
#     MCC: 0.7466
#     F1-score: 0.7451
#     mAP: 0.8156
#   [Ours - MLP]
#     AUROC: 0.9450
#     G-mean: 0.8761
#     MCC: 0.4984
#     F1-score: 0.4813
#     mAP: 0.8725
#   [Ours - RandomForest]
#     AUROC: 0.9750
#     G-mean: 0.8365
#     MCC: 0.8067
#     F1-score: 0.7967
#     mAP: 0.8905
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9777
#     G-mean: 0.8594
#     MCC: 0.7300
#     F1-score: 0.7266
#     mAP: 0.8952
#   [Ours - DecisionTree]
#     AUROC: 0.8633
#     G-mean: 0.7673
#     MCC: 0.6990
#     F1-score: 0.6922
#     mAP: 0.6561
#   [Ours - kNN]
#     AUROC: 0.9239
#     G-mean: 0.8823
#     MCC: 0.7409
#     F1-score: 0.7374
#     mAP: 0.8064
#   [Ours - MLP]
#     AUROC: 0.9423
#     G-mean: 0.8658
#     MCC: 0.4841
#     F1-score: 0.4683
#     mAP: 0.8702
#   [Ours - RandomForest]
#     AUROC: 0.9754
#     G-mean: 0.8434
#     MCC: 0.8027
#     F1-score: 0.7925
#     mAP: 0.8982
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9777
#     G-mean: 0.8590
#     MCC: 0.7330
#     F1-score: 0.7273
#     mAP: 0.8961
#   [Ours - DecisionTree]
#     AUROC: 0.8598
#     G-mean: 0.7517
#     MCC: 0.6748
#     F1-score: 0.6706
#     mAP: 0.6414
#   [Ours - kNN]
#     AUROC: 0.9259
#     G-mean: 0.8832
#     MCC: 0.7444
#     F1-score: 0.7398
#     mAP: 0.8176
#   [Ours - MLP]
#     AUROC: 0.9450
#     G-mean: 0.8716
#     MCC: 0.4945
#     F1-score: 0.4778
#     mAP: 0.8661
#   [Ours - RandomForest]
#     AUROC: 0.9754
#     G-mean: 0.8386
#     MCC: 0.7998
#     F1-score: 0.7900
#     mAP: 0.8909
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9768
#     G-mean: 0.8585
#     MCC: 0.7280
#     F1-score: 0.7224
#     mAP: 0.8898
#   [Ours - DecisionTree]
#     AUROC: 0.8650
#     G-mean: 0.7668
#     MCC: 0.6817
#     F1-score: 0.6788
#     mAP: 0.6373
#   [Ours - kNN]
#     AUROC: 0.9249
#     G-mean: 0.8783
#     MCC: 0.7349
#     F1-score: 0.7309
#     mAP: 0.8142
#   [Ours - MLP]
#     AUROC: 0.9427
#     G-mean: 0.8713
#     MCC: 0.4902
#     F1-score: 0.4734
#     mAP: 0.8693
#   [Ours - RandomForest]
#     AUROC: 0.9764
#     G-mean: 0.8450
#     MCC: 0.8030
#     F1-score: 0.7950
#     mAP: 0.8968
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9767
#     G-mean: 0.8577
#     MCC: 0.7267
#     F1-score: 0.7226
#     mAP: 0.8886
#   [Ours - DecisionTree]
#     AUROC: 0.8655
#     G-mean: 0.7757
#     MCC: 0.6928
#     F1-score: 0.6888
#     mAP: 0.6383
#   [Ours - kNN]
#     AUROC: 0.9246
#     G-mean: 0.8828
#     MCC: 0.7417
#     F1-score: 0.7379
#     mAP: 0.8101
#   [Ours - MLP]
#     AUROC: 0.9410
#     G-mean: 0.8734
#     MCC: 0.4966
#     F1-score: 0.4807
#     mAP: 0.8684
#   [Ours - RandomForest]
#     AUROC: 0.9777
#     G-mean: 0.8469
#     MCC: 0.8018
#     F1-score: 0.7931
#     mAP: 0.8986
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9765
#     G-mean: 0.8518
#     MCC: 0.7210
#     F1-score: 0.7173
#     mAP: 0.8855
#   [Ours - DecisionTree]
#     AUROC: 0.8628
#     G-mean: 0.7743
#     MCC: 0.6839
#     F1-score: 0.6815
#     mAP: 0.6236
#   [Ours - kNN]
#     AUROC: 0.9243
#     G-mean: 0.8859
#     MCC: 0.7433
#     F1-score: 0.7390
#     mAP: 0.8073
#   [Ours - MLP]
#     AUROC: 0.9442
#     G-mean: 0.8734
#     MCC: 0.4968
#     F1-score: 0.4803
#     mAP: 0.8686
#   [Ours - RandomForest]
#     AUROC: 0.9751
#     G-mean: 0.8433
#     MCC: 0.7970
#     F1-score: 0.7890
#     mAP: 0.8917
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9761
#     G-mean: 0.8526
#     MCC: 0.7161
#     F1-score: 0.7128
#     mAP: 0.8863
#   [Ours - DecisionTree]
#     AUROC: 0.8655
#     G-mean: 0.7807
#     MCC: 0.6813
#     F1-score: 0.6799
#     mAP: 0.6150
#   [Ours - kNN]
#     AUROC: 0.9262
#     G-mean: 0.8853
#     MCC: 0.7459
#     F1-score: 0.7410
#     mAP: 0.8103
#   [Ours - MLP]
#     AUROC: 0.9421
#     G-mean: 0.8730
#     MCC: 0.4962
#     F1-score: 0.4797
#     mAP: 0.8650
#   [Ours - RandomForest]
#     AUROC: 0.9750
#     G-mean: 0.8464
#     MCC: 0.7982
#     F1-score: 0.7906
#     mAP: 0.8905
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9757
#     G-mean: 0.8494
#     MCC: 0.7102
#     F1-score: 0.7086
#     mAP: 0.8841
#   [Ours - DecisionTree]
#     AUROC: 0.8670
#     G-mean: 0.7819
#     MCC: 0.6780
#     F1-score: 0.6776
#     mAP: 0.6151
#   [Ours - kNN]
#     AUROC: 0.9281
#     G-mean: 0.8861
#     MCC: 0.7457
#     F1-score: 0.7425
#     mAP: 0.8140
#   [Ours - MLP]
#     AUROC: 0.9403
#     G-mean: 0.8709
#     MCC: 0.4927
#     F1-score: 0.4769
#     mAP: 0.8580
#   [Ours - RandomForest]
#     AUROC: 0.9724
#     G-mean: 0.8408
#     MCC: 0.7941
#     F1-score: 0.7867
#     mAP: 0.8874
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/kernel/ecoli4_results_rq_beta_0.01.csv
# kernel_type: laplacian
# Dataset loaded from DataFrame
# X shape : (336, 7)
# target : Counter({0: 314, 1: 22})
# IR: 14.27
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9802
#     G-mean: 0.8610
#     MCC: 0.6702
#     F1-score: 0.6648
#     mAP: 0.8972
#   [Ours - DecisionTree]
#     AUROC: 0.8932
#     G-mean: 0.8746
#     MCC: 0.7997
#     F1-score: 0.7900
#     mAP: 0.6936
#   [Ours - kNN]
#     AUROC: 0.9279
#     G-mean: 0.8865
#     MCC: 0.6897
#     F1-score: 0.6900
#     mAP: 0.7422
#   [Ours - MLP]
#     AUROC: 0.9281
#     G-mean: 0.8585
#     MCC: 0.4424
#     F1-score: 0.4198
#     mAP: 0.8547
#   [Ours - RandomForest]
#     AUROC: 0.9688
#     G-mean: 0.8763
#     MCC: 0.8193
#     F1-score: 0.8100
#     mAP: 0.9209
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9835
#     G-mean: 0.8778
#     MCC: 0.7209
#     F1-score: 0.7190
#     mAP: 0.9086
#   [Ours - DecisionTree]
#     AUROC: 0.8953
#     G-mean: 0.8527
#     MCC: 0.7830
#     F1-score: 0.7733
#     mAP: 0.6766
#   [Ours - kNN]
#     AUROC: 0.9357
#     G-mean: 0.8840
#     MCC: 0.7251
#     F1-score: 0.7214
#     mAP: 0.7508
#   [Ours - MLP]
#     AUROC: 0.9386
#     G-mean: 0.8687
#     MCC: 0.4697
#     F1-score: 0.4490
#     mAP: 0.8552
#   [Ours - RandomForest]
#     AUROC: 0.9726
#     G-mean: 0.8696
#     MCC: 0.8292
#     F1-score: 0.8184
#     mAP: 0.9104
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9821
#     G-mean: 0.8658
#     MCC: 0.6960
#     F1-score: 0.6927
#     mAP: 0.9016
#   [Ours - DecisionTree]
#     AUROC: 0.8794
#     G-mean: 0.8111
#     MCC: 0.7300
#     F1-score: 0.7253
#     mAP: 0.6327
#   [Ours - kNN]
#     AUROC: 0.9305
#     G-mean: 0.8814
#     MCC: 0.7164
#     F1-score: 0.7137
#     mAP: 0.7546
#   [Ours - MLP]
#     AUROC: 0.9438
#     G-mean: 0.8735
#     MCC: 0.4779
#     F1-score: 0.4576
#     mAP: 0.8691
#   [Ours - RandomForest]
#     AUROC: 0.9712
#     G-mean: 0.8254
#     MCC: 0.7785
#     F1-score: 0.7711
#     mAP: 0.8859
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9793
#     G-mean: 0.8653
#     MCC: 0.6981
#     F1-score: 0.6944
#     mAP: 0.8884
#   [Ours - DecisionTree]
#     AUROC: 0.8921
#     G-mean: 0.8135
#     MCC: 0.7441
#     F1-score: 0.7406
#     mAP: 0.6658
#   [Ours - kNN]
#     AUROC: 0.9306
#     G-mean: 0.8780
#     MCC: 0.7023
#     F1-score: 0.6978
#     mAP: 0.7412
#   [Ours - MLP]
#     AUROC: 0.9371
#     G-mean: 0.8631
#     MCC: 0.4661
#     F1-score: 0.4476
#     mAP: 0.8532
#   [Ours - RandomForest]
#     AUROC: 0.9708
#     G-mean: 0.8174
#     MCC: 0.7642
#     F1-score: 0.7567
#     mAP: 0.8896
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9793
#     G-mean: 0.8628
#     MCC: 0.6948
#     F1-score: 0.6901
#     mAP: 0.8929
#   [Ours - DecisionTree]
#     AUROC: 0.8792
#     G-mean: 0.7841
#     MCC: 0.7145
#     F1-score: 0.7132
#     mAP: 0.6429
#   [Ours - kNN]
#     AUROC: 0.9304
#     G-mean: 0.8782
#     MCC: 0.6993
#     F1-score: 0.6949
#     mAP: 0.7454
#   [Ours - MLP]
#     AUROC: 0.9366
#     G-mean: 0.8603
#     MCC: 0.4660
#     F1-score: 0.4488
#     mAP: 0.8443
#   [Ours - RandomForest]
#     AUROC: 0.9708
#     G-mean: 0.7982
#     MCC: 0.7504
#     F1-score: 0.7440
#     mAP: 0.8841
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9804
#     G-mean: 0.8616
#     MCC: 0.6981
#     F1-score: 0.6920
#     mAP: 0.8961
#   [Ours - DecisionTree]
#     AUROC: 0.8844
#     G-mean: 0.7974
#     MCC: 0.7265
#     F1-score: 0.7243
#     mAP: 0.6508
#   [Ours - kNN]
#     AUROC: 0.9291
#     G-mean: 0.8782
#     MCC: 0.6991
#     F1-score: 0.6955
#     mAP: 0.7546
#   [Ours - MLP]
#     AUROC: 0.9405
#     G-mean: 0.8583
#     MCC: 0.4669
#     F1-score: 0.4502
#     mAP: 0.8490
#   [Ours - RandomForest]
#     AUROC: 0.9721
#     G-mean: 0.8068
#     MCC: 0.7629
#     F1-score: 0.7550
#     mAP: 0.8891
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9800
#     G-mean: 0.8629
#     MCC: 0.6987
#     F1-score: 0.6923
#     mAP: 0.8921
#   [Ours - DecisionTree]
#     AUROC: 0.8877
#     G-mean: 0.7958
#     MCC: 0.7210
#     F1-score: 0.7193
#     mAP: 0.6495
#   [Ours - kNN]
#     AUROC: 0.9281
#     G-mean: 0.8815
#     MCC: 0.7017
#     F1-score: 0.6976
#     mAP: 0.7576
#   [Ours - MLP]
#     AUROC: 0.9390
#     G-mean: 0.8564
#     MCC: 0.4606
#     F1-score: 0.4429
#     mAP: 0.8508
#   [Ours - RandomForest]
#     AUROC: 0.9732
#     G-mean: 0.8148
#     MCC: 0.7738
#     F1-score: 0.7652
#     mAP: 0.8954
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9799
#     G-mean: 0.8600
#     MCC: 0.6996
#     F1-score: 0.6941
#     mAP: 0.8918
#   [Ours - DecisionTree]
#     AUROC: 0.8841
#     G-mean: 0.7924
#     MCC: 0.7161
#     F1-score: 0.7148
#     mAP: 0.6436
#   [Ours - kNN]
#     AUROC: 0.9304
#     G-mean: 0.8844
#     MCC: 0.7038
#     F1-score: 0.6999
#     mAP: 0.7630
#   [Ours - MLP]
#     AUROC: 0.9423
#     G-mean: 0.8578
#     MCC: 0.4604
#     F1-score: 0.4419
#     mAP: 0.8522
#   [Ours - RandomForest]
#     AUROC: 0.9722
#     G-mean: 0.8130
#     MCC: 0.7701
#     F1-score: 0.7621
#     mAP: 0.8913
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9788
#     G-mean: 0.8600
#     MCC: 0.7023
#     F1-score: 0.6959
#     mAP: 0.8921
#   [Ours - DecisionTree]
#     AUROC: 0.8798
#     G-mean: 0.7897
#     MCC: 0.7112
#     F1-score: 0.7102
#     mAP: 0.6364
#   [Ours - kNN]
#     AUROC: 0.9282
#     G-mean: 0.8832
#     MCC: 0.7024
#     F1-score: 0.6976
#     mAP: 0.7602
#   [Ours - MLP]
#     AUROC: 0.9399
#     G-mean: 0.8506
#     MCC: 0.4605
#     F1-score: 0.4430
#     mAP: 0.8502
#   [Ours - RandomForest]
#     AUROC: 0.9709
#     G-mean: 0.8231
#     MCC: 0.7820
#     F1-score: 0.7748
#     mAP: 0.8934
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9772
#     G-mean: 0.8563
#     MCC: 0.7028
#     F1-score: 0.6976
#     mAP: 0.8874
#   [Ours - DecisionTree]
#     AUROC: 0.8780
#     G-mean: 0.7875
#     MCC: 0.7080
#     F1-score: 0.7069
#     mAP: 0.6349
#   [Ours - kNN]
#     AUROC: 0.9274
#     G-mean: 0.8827
#     MCC: 0.6948
#     F1-score: 0.6911
#     mAP: 0.7667
#   [Ours - MLP]
#     AUROC: 0.9404
#     G-mean: 0.8534
#     MCC: 0.4636
#     F1-score: 0.4460
#     mAP: 0.8510
#   [Ours - RandomForest]
#     AUROC: 0.9686
#     G-mean: 0.8200
#     MCC: 0.7803
#     F1-score: 0.7733
#     mAP: 0.8897
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/kernel/ecoli4_results_laplacian_beta_0.01.csv
