# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

# Save path 
save_path = "/data4/oldrain123/oldrain123/results/ablation_results/classifiers"
data_path = "/data4/oldrain123/oldrain123/dataset"

# %%
import os
import warnings
import pandas as pd
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from experiment import run_exp
from imblearn.datasets import fetch_datasets

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "3"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
data = fetch_datasets()
methods = ["Original", "SMOTE", "ADASYN", "bSMOTE", "ROS", "MWMOTE", "CTGAN"]
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}

# %%
# data_name = 'thyroid_sick'
# maj_target_name = -1

# n_epochs = 2000
# hidden_dims = [64, 128, 256]
# latent_dim = 512
# lr = 0.01
# run_exp(
#     data=data, 
#     cat_idx=[], 
#     methods=methods, 
#     base_model=base_models,  
#     device=device,
#     n_epochs=n_epochs, 
#     hidden_dims=hidden_dims, 
#     latent_dim=latent_dim, 
#     lr=lr, 
#     beta=0.0,
#     seed=1203, 
#     data_name=data_name, 
#     maj_target_name=maj_target_name,    
#     save_path=save_path
# )

# %%
# data_name = 'yeast-0-5-6-7-9_vs_4'

# # 실험 파라미터 설정
# n_epochs = 2000
# hidden_dims = [8, 16, 32, 64, 128, 256, 512]
# latent_dim = 1024
# lr = 0.005
# beta = 0.1

# # 데이터 불러오기
# yeast_0_5_6_7_9_vs_4 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# # Run experiment
# final_results = run_exp(
#     data=yeast_0_5_6_7_9_vs_4, 
#     cat_idx=[], 
#     methods=methods, 
#     base_model=base_models, 
#     device=device,
#     n_epochs=n_epochs, 
#     hidden_dims=hidden_dims, 
#     latent_dim=latent_dim, 
#     lr=lr, 
#     beta=beta,
#     data_name=data_name, 
#     seed=1203, 
#     visualize=True, 
#     save_path=save_path
# )

# # Process the final_results.
# # Expecting keys like "Original - DecisionTree", "SMOTE - kNN", etc.
# res_data = {
#     "Classifier": [],
#     "Method": [],
#     "Metric": [],
#     "Value": [],
# }

# for key, metrics in final_results.items():
#     # Split the key into oversampling method and classifier if possible
#     if " - " in key:
#         method_name, clf_name = key.split(" - ", 1)
#     else:
#         method_name, clf_name = key, "Default"
#     for metric, values in metrics.items():
#         avg_val = np.mean(values) if values else "N/A"
#         res_data["Classifier"].append(clf_name)
#         res_data["Method"].append(method_name)
#         res_data["Metric"].append(metric)
#         res_data["Value"].append(avg_val)

# res_df = pd.DataFrame(res_data)

# # Save the final results with classifier information
# os.makedirs(save_path, exist_ok=True)
# save_file = os.path.join(save_path, f"{data_name}_results.csv")
# res_df.to_csv(save_file, index=False)
# print(f"\n[Saved] Final results are saved to {save_file}")

# %%
# data_name = 'yeast6'

# # 실험 파라미터 설정
# n_epochs = 2000
# hidden_dims = [8, 16, 32, 64]
# latent_dim = 128
# lr = 0.001
# beta = 0.1

# # 데이터 불러오기
# yeast6 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# # Run experiment
# final_results = run_exp(
#     data=yeast_0_5_6_7_9_vs_4, 
#     cat_idx=[], 
#     methods=methods, 
#     base_model=base_models, 
#     device=device,
#     n_epochs=n_epochs, 
#     hidden_dims=hidden_dims, 
#     latent_dim=latent_dim, 
#     lr=lr, 
#     beta=beta,
#     data_name=data_name, 
#     seed=1203, 
#     visualize=True, 
#     save_path=save_path
# )

# # Process the final_results.
# # Expecting keys like "Original - DecisionTree", "SMOTE - kNN", etc.
# res_data = {
#     "Classifier": [],
#     "Method": [],
#     "Metric": [],
#     "Value": [],
# }

# for key, metrics in final_results.items():
#     # Split the key into oversampling method and classifier if possible
#     if " - " in key:
#         method_name, clf_name = key.split(" - ", 1)
#     else:
#         method_name, clf_name = key, "Default"
#     for metric, values in metrics.items():
#         avg_val = np.mean(values) if values else "N/A"
#         res_data["Classifier"].append(clf_name)
#         res_data["Method"].append(method_name)
#         res_data["Metric"].append(metric)
#         res_data["Value"].append(avg_val)

# res_df = pd.DataFrame(res_data)

# # Save the final results with classifier information
# os.makedirs(save_path, exist_ok=True)
# save_file = os.path.join(save_path, f"{data_name}_results.csv")
# res_df.to_csv(save_file, index=False)
# print(f"\n[Saved] Final results are saved to {save_file}")

# %%
data_name = 'yeast-1-2-8-9_vs_7'

# 실험 파라미터 설정
n_epochs = 2000
hidden_dims = [8, 16, 32, 64]
latent_dim = 128
lr = 0.001
beta = 0.1

# 데이터 불러오기
yeast_1_2_8_9_vs_7 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# Run experiment
final_results = run_exp(
    data=yeast_1_2_8_9_vs_7, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (947, 8)
# target : Counter({0: 917, 1: 30})
# IR: 30.57
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Original - SVM]
#     AUROC: 0.6731
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.4153
#   [Original - DecisionTree]
#     AUROC: 0.7093
#     G-mean: 0.4392
#     MCC: 0.3484
#     F1-score: 0.3467
#     mAP: 0.2916
#   [Original - kNN]
#     AUROC: 0.7022
#     G-mean: 0.0577
#     MCC: 0.0571
#     F1-score: 0.0500
#     mAP: 0.2248
#   [Original - MLP]
#     AUROC: 0.2898
#     G-mean: 0.0000
#     MCC: -0.0045
#     F1-score: 0.0000
#     mAP: 0.0634
#   [Original - RandomForest]
#     AUROC: 0.7836
#     G-mean: 0.1968
#     MCC: 0.1757
#     F1-score: 0.1700
#     mAP: 0.3274
#   [SMOTE - SVM]
#     AUROC: 0.7372
#     G-mean: 0.6169
#     MCC: 0.1738
#     F1-score: 0.1647
#     mAP: 0.2613
#   [SMOTE - DecisionTree]
#     AUROC: 0.6291
#     G-mean: 0.5359
#     MCC: 0.1090
#     F1-score: 0.1265
#     mAP: 0.1382
#   [SMOTE - kNN]
#     AUROC: 0.7540
#     G-mean: 0.6322
#     MCC: 0.1786
#     F1-score: 0.1652
#     mAP: 0.1837
#   [SMOTE - MLP]
#     AUROC: 0.7696
#     G-mean: 0.6899
#     MCC: 0.1838
#     F1-score: 0.1604
#     mAP: 0.2567
#   [SMOTE - RandomForest]
#     AUROC: 0.7625
#     G-mean: 0.3661
#     MCC: 0.2036
#     F1-score: 0.2269
#     mAP: 0.2699
#   [ADASYN - SVM]
#     AUROC: 0.7270
#     G-mean: 0.5310
#     MCC: 0.1187
#     F1-score: 0.1251
#     mAP: 0.2483
#   [ADASYN - DecisionTree]
#     AUROC: 0.5805
#     G-mean: 0.4440
#     MCC: 0.0702
#     F1-score: 0.0938
#     mAP: 0.1056
#   [ADASYN - kNN]
#     AUROC: 0.7531
#     G-mean: 0.6487
#     MCC: 0.1906
#     F1-score: 0.1710
#     mAP: 0.1750
#   [ADASYN - MLP]
#     AUROC: 0.7801
#     G-mean: 0.6709
#     MCC: 0.1654
#     F1-score: 0.1485
#     mAP: 0.3073
#   [ADASYN - RandomForest]
#     AUROC: 0.7896
#     G-mean: 0.2525
#     MCC: 0.1426
#     F1-score: 0.1686
#     mAP: 0.2425
#   [bSMOTE - SVM]
#     AUROC: 0.7506
#     G-mean: 0.5804
#     MCC: 0.1856
#     F1-score: 0.1907
#     mAP: 0.2838
#   [bSMOTE - DecisionTree]
#     AUROC: 0.6876
#     G-mean: 0.5792
#     MCC: 0.2146
#     F1-score: 0.2212
#     mAP: 0.2363
#   [bSMOTE - kNN]
#     AUROC: 0.7357
#     G-mean: 0.5810
#     MCC: 0.2087
#     F1-score: 0.2034
#     mAP: 0.2029
#   [bSMOTE - MLP]
#     AUROC: 0.8034
#     G-mean: 0.6058
#     MCC: 0.1746
#     F1-score: 0.1679
#     mAP: 0.3113
#   [bSMOTE - RandomForest]
#     AUROC: 0.7632
#     G-mean: 0.3899
#     MCC: 0.2576
#     F1-score: 0.2697
#     mAP: 0.2805
#   [ROS - SVM]
#     AUROC: 0.7459
#     G-mean: 0.5611
#     MCC: 0.1791
#     F1-score: 0.1798
#     mAP: 0.2585
#   [ROS - DecisionTree]
#     AUROC: 0.7164
#     G-mean: 0.6082
#     MCC: 0.1538
#     F1-score: 0.1446
#     mAP: 0.2405
#   [ROS - kNN]
#     AUROC: 0.7029
#     G-mean: 0.4680
#     MCC: 0.2174
#     F1-score: 0.2295
#     mAP: 0.2531
#   [ROS - MLP]
#     AUROC: 0.8015
#     G-mean: 0.7195
#     MCC: 0.2174
#     F1-score: 0.1872
#     mAP: 0.3231
#   [ROS - RandomForest]
#     AUROC: 0.8114
#     G-mean: 0.2542
#     MCC: 0.2247
#     F1-score: 0.2133
#     mAP: 0.3472
#   [MWMOTE - SVM]
#     AUROC: 0.6994
#     G-mean: 0.5066
#     MCC: 0.1120
#     F1-score: 0.1264
#     mAP: 0.1692
#   [MWMOTE - DecisionTree]
#     AUROC: 0.6132
#     G-mean: 0.5473
#     MCC: 0.0989
#     F1-score: 0.1124
#     mAP: 0.0942
#   [MWMOTE - kNN]
#     AUROC: 0.7165
#     G-mean: 0.5760
#     MCC: 0.1906
#     F1-score: 0.1882
#     mAP: 0.1687
#   [MWMOTE - MLP]
#     AUROC: 0.7514
#     G-mean: 0.5701
#     MCC: 0.1264
#     F1-score: 0.1302
#     mAP: 0.2517
#   [MWMOTE - RandomForest]
#     AUROC: 0.7509
#     G-mean: 0.1152
#     MCC: 0.0804
#     F1-score: 0.0900
#     mAP: 0.2210
#   [CTGAN - SVM]
#     AUROC: 0.7007
#     G-mean: 0.4041
#     MCC: 0.1563
#     F1-score: 0.1755
#     mAP: 0.3054
#   [CTGAN - DecisionTree]
#     AUROC: 0.6602
#     G-mean: 0.3347
#     MCC: 0.2740
#     F1-score: 0.2657
#     mAP: 0.2432
#   [CTGAN - kNN]
#     AUROC: 0.6985
#     G-mean: 0.3474
#     MCC: 0.1350
#     F1-score: 0.1580
#     mAP: 0.2020
#   [CTGAN - MLP]
#     AUROC: 0.6857
#     G-mean: 0.4226
#     MCC: 0.0987
#     F1-score: 0.1220
#     mAP: 0.1576
#   [CTGAN - RandomForest]
#     AUROC: 0.7741
#     G-mean: 0.2874
#     MCC: 0.2239
#     F1-score: 0.2133
#     mAP: 0.3177
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Original - SVM]
#     AUROC: 0.6665
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.4144
#   [Original - DecisionTree]
#     AUROC: 0.6751
#     G-mean: 0.4485
#     MCC: 0.3268
#     F1-score: 0.3244
#     mAP: 0.2476
#   [Original - kNN]
#     AUROC: 0.6946
#     G-mean: 0.1154
#     MCC: 0.1142
#     F1-score: 0.1000
#     mAP: 0.2328
#   [Original - MLP]
#     AUROC: 0.2886
#     G-mean: 0.0000
#     MCC: -0.0054
#     F1-score: 0.0000
#     mAP: 0.0524
#   [Original - RandomForest]
#     AUROC: 0.7699
#     G-mean: 0.2137
#     MCC: 0.1913
#     F1-score: 0.1800
#     mAP: 0.3483
#   [SMOTE - SVM]
#     AUROC: 0.7231
#     G-mean: 0.5563
#     MCC: 0.1506
#     F1-score: 0.1522
#     mAP: 0.2842
#   [SMOTE - DecisionTree]
#     AUROC: 0.6427
#     G-mean: 0.5725
#     MCC: 0.1220
#     F1-score: 0.1348
#     mAP: 0.1680
#   [SMOTE - kNN]
#     AUROC: 0.7389
#     G-mean: 0.6197
#     MCC: 0.1804
#     F1-score: 0.1668
#     mAP: 0.1672
#   [SMOTE - MLP]
#     AUROC: 0.7767
#     G-mean: 0.7049
#     MCC: 0.1892
#     F1-score: 0.1595
#     mAP: 0.2719
#   [SMOTE - RandomForest]
#     AUROC: 0.7530
#     G-mean: 0.3545
#     MCC: 0.1952
#     F1-score: 0.2177
#     mAP: 0.2514
#   [ADASYN - SVM]
#     AUROC: 0.7205
#     G-mean: 0.5371
#     MCC: 0.1251
#     F1-score: 0.1327
#     mAP: 0.2729
#   [ADASYN - DecisionTree]
#     AUROC: 0.5839
#     G-mean: 0.4794
#     MCC: 0.0791
#     F1-score: 0.1033
#     mAP: 0.1140
#   [ADASYN - kNN]
#     AUROC: 0.7269
#     G-mean: 0.6185
#     MCC: 0.1778
#     F1-score: 0.1644
#     mAP: 0.1523
#   [ADASYN - MLP]
#     AUROC: 0.7636
#     G-mean: 0.6441
#     MCC: 0.1540
#     F1-score: 0.1436
#     mAP: 0.3075
#   [ADASYN - RandomForest]
#     AUROC: 0.7745
#     G-mean: 0.2692
#     MCC: 0.1477
#     F1-score: 0.1719
#     mAP: 0.2416
#   [bSMOTE - SVM]
#     AUROC: 0.7449
#     G-mean: 0.5323
#     MCC: 0.1588
#     F1-score: 0.1717
#     mAP: 0.2723
#   [bSMOTE - DecisionTree]
#     AUROC: 0.6754
#     G-mean: 0.5177
#     MCC: 0.1610
#     F1-score: 0.1778
#     mAP: 0.2030
#   [bSMOTE - kNN]
#     AUROC: 0.7162
#     G-mean: 0.5762
#     MCC: 0.2008
#     F1-score: 0.1988
#     mAP: 0.1946
#   [bSMOTE - MLP]
#     AUROC: 0.7951
#     G-mean: 0.6018
#     MCC: 0.1763
#     F1-score: 0.1750
#     mAP: 0.3267
#   [bSMOTE - RandomForest]
#     AUROC: 0.7545
#     G-mean: 0.3669
#     MCC: 0.2427
#     F1-score: 0.2523
#     mAP: 0.2676
#   [ROS - SVM]
#     AUROC: 0.7307
#     G-mean: 0.5780
#     MCC: 0.1945
#     F1-score: 0.1941
#     mAP: 0.2720
#   [ROS - DecisionTree]
#     AUROC: 0.6705
#     G-mean: 0.5613
#     MCC: 0.1328
#     F1-score: 0.1390
#     mAP: 0.2137
#   [ROS - kNN]
#     AUROC: 0.6955
#     G-mean: 0.5027
#     MCC: 0.2162
#     F1-score: 0.2287
#     mAP: 0.2505
#   [ROS - MLP]
#     AUROC: 0.7959
#     G-mean: 0.7148
#     MCC: 0.2062
#     F1-score: 0.1745
#     mAP: 0.3158
#   [ROS - RandomForest]
#     AUROC: 0.7885
#     G-mean: 0.2714
#     MCC: 0.2512
#     F1-score: 0.2316
#     mAP: 0.3357
#   [MWMOTE - SVM]
#     AUROC: 0.7074
#     G-mean: 0.5201
#     MCC: 0.1331
#     F1-score: 0.1390
#     mAP: 0.2396
#   [MWMOTE - DecisionTree]
#     AUROC: 0.6070
#     G-mean: 0.4534
#     MCC: 0.0740
#     F1-score: 0.0993
#     mAP: 0.0931
#   [MWMOTE - kNN]
#     AUROC: 0.7183
#     G-mean: 0.5430
#     MCC: 0.1789
#     F1-score: 0.1821
#     mAP: 0.1705
#   [MWMOTE - MLP]
#     AUROC: 0.7513
#     G-mean: 0.6412
#     MCC: 0.1662
#     F1-score: 0.1543
#     mAP: 0.2674
#   [MWMOTE - RandomForest]
#     AUROC: 0.7488
#     G-mean: 0.1441
#     MCC: 0.1139
#     F1-score: 0.1150
#     mAP: 0.2389
#   [CTGAN - SVM]
#     AUROC: 0.7002
#     G-mean: 0.4206
#     MCC: 0.1620
#     F1-score: 0.1819
#     mAP: 0.2583
#   [CTGAN - DecisionTree]
#     AUROC: 0.6741
#     G-mean: 0.3683
#     MCC: 0.2969
#     F1-score: 0.2820
#     mAP: 0.2589
#   [CTGAN - kNN]
#     AUROC: 0.6924
#     G-mean: 0.4178
#     MCC: 0.1476
#     F1-score: 0.1674
#     mAP: 0.1898
#   [CTGAN - MLP]
#     AUROC: 0.6594
#     G-mean: 0.3976
#     MCC: 0.0968
#     F1-score: 0.1210
#     mAP: 0.1321
#   [CTGAN - RandomForest]
#     AUROC: 0.7592
#     G-mean: 0.3167
#     MCC: 0.2725
#     F1-score: 0.2516
#     mAP: 0.3375
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Original - SVM]
#     AUROC: 0.6596
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.4112
#   [Original - DecisionTree]
#     AUROC: 0.6335
#     G-mean: 0.3947
#     MCC: 0.2867
#     F1-score: 0.2852
#     mAP: 0.2224
#   [Original - kNN]
#     AUROC: 0.6937
#     G-mean: 0.1234
#     MCC: 0.1223
#     F1-score: 0.1100
#     mAP: 0.2381
#   [Original - MLP]
#     AUROC: 0.2909
#     G-mean: 0.0000
#     MCC: -0.0061
#     F1-score: 0.0000
#     mAP: 0.0478
#   [Original - RandomForest]
#     AUROC: 0.7640
#     G-mean: 0.2001
#     MCC: 0.1775
#     F1-score: 0.1667
#     mAP: 0.3480
#   [SMOTE - SVM]
#     AUROC: 0.7109
#     G-mean: 0.5571
#     MCC: 0.1426
#     F1-score: 0.1467
#     mAP: 0.2718
#   [SMOTE - DecisionTree]
#     AUROC: 0.6426
#     G-mean: 0.5447
#     MCC: 0.1074
#     F1-score: 0.1235
#     mAP: 0.1732
#   [SMOTE - kNN]
#     AUROC: 0.7185
#     G-mean: 0.6214
#     MCC: 0.1789
#     F1-score: 0.1677
#     mAP: 0.1599
#   [SMOTE - MLP]
#     AUROC: 0.7759
#     G-mean: 0.6827
#     MCC: 0.1830
#     F1-score: 0.1582
#     mAP: 0.2901
#   [SMOTE - RandomForest]
#     AUROC: 0.7490
#     G-mean: 0.3471
#     MCC: 0.1913
#     F1-score: 0.2138
#     mAP: 0.2446
#   [ADASYN - SVM]
#     AUROC: 0.7080
#     G-mean: 0.5472
#     MCC: 0.1224
#     F1-score: 0.1299
#     mAP: 0.2576
#   [ADASYN - DecisionTree]
#     AUROC: 0.6001
#     G-mean: 0.4914
#     MCC: 0.0848
#     F1-score: 0.1061
#     mAP: 0.1285
#   [ADASYN - kNN]
#     AUROC: 0.7152
#     G-mean: 0.6211
#     MCC: 0.1777
#     F1-score: 0.1661
#     mAP: 0.1492
#   [ADASYN - MLP]
#     AUROC: 0.7674
#     G-mean: 0.6357
#     MCC: 0.1628
#     F1-score: 0.1479
#     mAP: 0.3148
#   [ADASYN - RandomForest]
#     AUROC: 0.7616
#     G-mean: 0.2636
#     MCC: 0.1493
#     F1-score: 0.1730
#     mAP: 0.2306
#   [bSMOTE - SVM]
#     AUROC: 0.7405
#     G-mean: 0.5230
#     MCC: 0.1538
#     F1-score: 0.1668
#     mAP: 0.2672
#   [bSMOTE - DecisionTree]
#     AUROC: 0.6784
#     G-mean: 0.4851
#     MCC: 0.1508
#     F1-score: 0.1685
#     mAP: 0.1873
#   [bSMOTE - kNN]
#     AUROC: 0.7080
#     G-mean: 0.5916
#     MCC: 0.2054
#     F1-score: 0.2037
#     mAP: 0.1861
#   [bSMOTE - MLP]
#     AUROC: 0.7925
#     G-mean: 0.5975
#     MCC: 0.1766
#     F1-score: 0.1723
#     mAP: 0.3261
#   [bSMOTE - RandomForest]
#     AUROC: 0.7642
#     G-mean: 0.3558
#     MCC: 0.2362
#     F1-score: 0.2479
#     mAP: 0.2746
#   [ROS - SVM]
#     AUROC: 0.7222
#     G-mean: 0.5417
#     MCC: 0.1737
#     F1-score: 0.1770
#     mAP: 0.2581
#   [ROS - DecisionTree]
#     AUROC: 0.6602
#     G-mean: 0.5352
#     MCC: 0.1176
#     F1-score: 0.1296
#     mAP: 0.2262
#   [ROS - kNN]
#     AUROC: 0.6938
#     G-mean: 0.5150
#     MCC: 0.2209
#     F1-score: 0.2344
#     mAP: 0.2354
#   [ROS - MLP]
#     AUROC: 0.7925
#     G-mean: 0.7037
#     MCC: 0.1974
#     F1-score: 0.1699
#     mAP: 0.3195
#   [ROS - RandomForest]
#     AUROC: 0.7845
#     G-mean: 0.2576
#     MCC: 0.2239
#     F1-score: 0.2111
#     mAP: 0.3241
#   [MWMOTE - SVM]
#     AUROC: 0.7044
#     G-mean: 0.5538
#     MCC: 0.1438
#     F1-score: 0.1452
#     mAP: 0.2299
#   [MWMOTE - DecisionTree]
#     AUROC: 0.6256
#     G-mean: 0.4878
#     MCC: 0.0928
#     F1-score: 0.1104
#     mAP: 0.1295
#   [MWMOTE - kNN]
#     AUROC: 0.7119
#     G-mean: 0.5693
#     MCC: 0.1857
#     F1-score: 0.1863
#     mAP: 0.1543
#   [MWMOTE - MLP]
#     AUROC: 0.7523
#     G-mean: 0.6630
#     MCC: 0.1762
#     F1-score: 0.1598
#     mAP: 0.2673
#   [MWMOTE - RandomForest]
#     AUROC: 0.7476
#     G-mean: 0.1614
#     MCC: 0.1255
#     F1-score: 0.1295
#     mAP: 0.2400
#   [CTGAN - SVM]
#     AUROC: 0.7118
#     G-mean: 0.4687
#     MCC: 0.1806
#     F1-score: 0.1921
#     mAP: 0.2790
#   [CTGAN - DecisionTree]
#     AUROC: 0.6662
#     G-mean: 0.3418
#     MCC: 0.2919
#     F1-score: 0.2713
#     mAP: 0.2574
#   [CTGAN - kNN]
#     AUROC: 0.7073
#     G-mean: 0.4596
#     MCC: 0.1679
#     F1-score: 0.1827
#     mAP: 0.2029
#   [CTGAN - MLP]
#     AUROC: 0.6865
#     G-mean: 0.4442
#     MCC: 0.1227
#     F1-score: 0.1397
#     mAP: 0.1804
#   [CTGAN - RandomForest]
#     AUROC: 0.7612
#     G-mean: 0.3073
#     MCC: 0.2703
#     F1-score: 0.2478
#     mAP: 0.3420
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Original - SVM]
#     AUROC: 0.6644
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.4221
#   [Original - DecisionTree]
#     AUROC: 0.6258
#     G-mean: 0.3881
#     MCC: 0.2831
#     F1-score: 0.2822
#     mAP: 0.2210
#   [Original - kNN]
#     AUROC: 0.7007
#     G-mean: 0.1214
#     MCC: 0.1202
#     F1-score: 0.1075
#     mAP: 0.2416
#   [Original - MLP]
#     AUROC: 0.2940
#     G-mean: 0.0000
#     MCC: -0.0055
#     F1-score: 0.0000
#     mAP: 0.0478
#   [Original - RandomForest]
#     AUROC: 0.7624
#     G-mean: 0.1933
#     MCC: 0.1704
#     F1-score: 0.1600
#     mAP: 0.3522
#   [SMOTE - SVM]
#     AUROC: 0.7149
#     G-mean: 0.5578
#     MCC: 0.1373
#     F1-score: 0.1430
#     mAP: 0.2672
#   [SMOTE - DecisionTree]
#     AUROC: 0.6251
#     G-mean: 0.5435
#     MCC: 0.1088
#     F1-score: 0.1253
#     mAP: 0.1591
#   [SMOTE - kNN]
#     AUROC: 0.7239
#     G-mean: 0.6166
#     MCC: 0.1767
#     F1-score: 0.1652
#     mAP: 0.1579
#   [SMOTE - MLP]
#     AUROC: 0.7777
#     G-mean: 0.6713
#     MCC: 0.1777
#     F1-score: 0.1555
#     mAP: 0.3044
#   [SMOTE - RandomForest]
#     AUROC: 0.7514
#     G-mean: 0.3372
#     MCC: 0.1869
#     F1-score: 0.2062
#     mAP: 0.2555
#   [ADASYN - SVM]
#     AUROC: 0.7107
#     G-mean: 0.5585
#     MCC: 0.1242
#     F1-score: 0.1304
#     mAP: 0.2529
#   [ADASYN - DecisionTree]
#     AUROC: 0.6119
#     G-mean: 0.5035
#     MCC: 0.0964
#     F1-score: 0.1146
#     mAP: 0.1429
#   [ADASYN - kNN]
#     AUROC: 0.7234
#     G-mean: 0.6204
#     MCC: 0.1791
#     F1-score: 0.1658
#     mAP: 0.1548
#   [ADASYN - MLP]
#     AUROC: 0.7735
#     G-mean: 0.6451
#     MCC: 0.1692
#     F1-score: 0.1515
#     mAP: 0.3199
#   [ADASYN - RandomForest]
#     AUROC: 0.7604
#     G-mean: 0.2745
#     MCC: 0.1510
#     F1-score: 0.1731
#     mAP: 0.2372
#   [bSMOTE - SVM]
#     AUROC: 0.7464
#     G-mean: 0.5491
#     MCC: 0.1768
#     F1-score: 0.1864
#     mAP: 0.2659
#   [bSMOTE - DecisionTree]
#     AUROC: 0.6724
#     G-mean: 0.5149
#     MCC: 0.1637
#     F1-score: 0.1776
#     mAP: 0.2030
#   [bSMOTE - kNN]
#     AUROC: 0.7095
#     G-mean: 0.5861
#     MCC: 0.2008
#     F1-score: 0.1997
#     mAP: 0.1859
#   [bSMOTE - MLP]
#     AUROC: 0.7920
#     G-mean: 0.6080
#     MCC: 0.1901
#     F1-score: 0.1855
#     mAP: 0.3346
#   [bSMOTE - RandomForest]
#     AUROC: 0.7677
#     G-mean: 0.3585
#     MCC: 0.2371
#     F1-score: 0.2478
#     mAP: 0.2800
#   [ROS - SVM]
#     AUROC: 0.7311
#     G-mean: 0.5630
#     MCC: 0.1862
#     F1-score: 0.1886
#     mAP: 0.2811
#   [ROS - DecisionTree]
#     AUROC: 0.6556
#     G-mean: 0.5291
#     MCC: 0.1169
#     F1-score: 0.1289
#     mAP: 0.2199
#   [ROS - kNN]
#     AUROC: 0.7002
#     G-mean: 0.5126
#     MCC: 0.2183
#     F1-score: 0.2313
#     mAP: 0.2329
#   [ROS - MLP]
#     AUROC: 0.7913
#     G-mean: 0.6893
#     MCC: 0.1907
#     F1-score: 0.1664
#     mAP: 0.3267
#   [ROS - RandomForest]
#     AUROC: 0.7812
#     G-mean: 0.2510
#     MCC: 0.2239
#     F1-score: 0.2083
#     mAP: 0.3317
#   [MWMOTE - SVM]
#     AUROC: 0.7009
#     G-mean: 0.5610
#     MCC: 0.1431
#     F1-score: 0.1453
#     mAP: 0.2144
#   [MWMOTE - DecisionTree]
#     AUROC: 0.6304
#     G-mean: 0.4917
#     MCC: 0.0994
#     F1-score: 0.1137
#     mAP: 0.1446
#   [MWMOTE - kNN]
#     AUROC: 0.7144
#     G-mean: 0.5773
#     MCC: 0.1879
#     F1-score: 0.1858
#     mAP: 0.1548
#   [MWMOTE - MLP]
#     AUROC: 0.7517
#     G-mean: 0.6530
#     MCC: 0.1712
#     F1-score: 0.1562
#     mAP: 0.2862
#   [MWMOTE - RandomForest]
#     AUROC: 0.7540
#     G-mean: 0.1786
#     MCC: 0.1384
#     F1-score: 0.1405
#     mAP: 0.2407
#   [CTGAN - SVM]
#     AUROC: 0.7193
#     G-mean: 0.5046
#     MCC: 0.1973
#     F1-score: 0.2059
#     mAP: 0.2884
#   [CTGAN - DecisionTree]
#     AUROC: 0.6649
#     G-mean: 0.3488
#     MCC: 0.3050
#     F1-score: 0.2835
#     mAP: 0.2609
#   [CTGAN - kNN]
#     AUROC: 0.7052
#     G-mean: 0.4854
#     MCC: 0.1722
#     F1-score: 0.1858
#     mAP: 0.2036
#   [CTGAN - MLP]
#     AUROC: 0.6989
#     G-mean: 0.4675
#     MCC: 0.1302
#     F1-score: 0.1467
#     mAP: 0.1845
#   [CTGAN - RandomForest]
#     AUROC: 0.7509
#     G-mean: 0.2881
#     MCC: 0.2545
#     F1-score: 0.2333
#     mAP: 0.3462
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Original - SVM]
#     AUROC: 0.6630
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.4253
#   [Original - DecisionTree]
#     AUROC: 0.6147
#     G-mean: 0.3954
#     MCC: 0.2885
#     F1-score: 0.2855
#     mAP: 0.2184
#   [Original - kNN]
#     AUROC: 0.7058
#     G-mean: 0.1318
#     MCC: 0.1305
#     F1-score: 0.1160
#     mAP: 0.2497
#   [Original - MLP]
#     AUROC: 0.2924
#     G-mean: 0.0000
#     MCC: -0.0051
#     F1-score: 0.0000
#     mAP: 0.0462
#   [Original - RandomForest]
#     AUROC: 0.7678
#     G-mean: 0.1893
#     MCC: 0.1695
#     F1-score: 0.1580
#     mAP: 0.3416
#   [SMOTE - SVM]
#     AUROC: 0.7148
#     G-mean: 0.5612
#     MCC: 0.1367
#     F1-score: 0.1420
#     mAP: 0.2574
#   [SMOTE - DecisionTree]
#     AUROC: 0.6308
#     G-mean: 0.5650
#     MCC: 0.1167
#     F1-score: 0.1283
#     mAP: 0.1625
#   [SMOTE - kNN]
#     AUROC: 0.7262
#     G-mean: 0.6216
#     MCC: 0.1775
#     F1-score: 0.1659
#     mAP: 0.1564
#   [SMOTE - MLP]
#     AUROC: 0.7789
#     G-mean: 0.6640
#     MCC: 0.1730
#     F1-score: 0.1539
#     mAP: 0.3037
#   [SMOTE - RandomForest]
#     AUROC: 0.7563
#     G-mean: 0.3477
#     MCC: 0.1995
#     F1-score: 0.2166
#     mAP: 0.2582
#   [ADASYN - SVM]
#     AUROC: 0.7104
#     G-mean: 0.5608
#     MCC: 0.1240
#     F1-score: 0.1305
#     mAP: 0.2455
#   [ADASYN - DecisionTree]
#     AUROC: 0.6219
#     G-mean: 0.5231
#     MCC: 0.1055
#     F1-score: 0.1200
#     mAP: 0.1477
#   [ADASYN - kNN]
#     AUROC: 0.7287
#     G-mean: 0.6275
#     MCC: 0.1814
#     F1-score: 0.1670
#     mAP: 0.1554
#   [ADASYN - MLP]
#     AUROC: 0.7759
#     G-mean: 0.6601
#     MCC: 0.1763
#     F1-score: 0.1568
#     mAP: 0.3197
#   [ADASYN - RandomForest]
#     AUROC: 0.7646
#     G-mean: 0.2702
#     MCC: 0.1560
#     F1-score: 0.1749
#     mAP: 0.2454
#   [bSMOTE - SVM]
#     AUROC: 0.7454
#     G-mean: 0.5448
#     MCC: 0.1747
#     F1-score: 0.1843
#     mAP: 0.2697
#   [bSMOTE - DecisionTree]
#     AUROC: 0.6611
#     G-mean: 0.4817
#     MCC: 0.1455
#     F1-score: 0.1619
#     mAP: 0.1904
#   [bSMOTE - kNN]
#     AUROC: 0.7107
#     G-mean: 0.5715
#     MCC: 0.1973
#     F1-score: 0.1973
#     mAP: 0.1822
#   [bSMOTE - MLP]
#     AUROC: 0.7882
#     G-mean: 0.6017
#     MCC: 0.1853
#     F1-score: 0.1828
#     mAP: 0.3355
#   [bSMOTE - RandomForest]
#     AUROC: 0.7706
#     G-mean: 0.3669
#     MCC: 0.2382
#     F1-score: 0.2486
#     mAP: 0.2812
#   [ROS - SVM]
#     AUROC: 0.7343
#     G-mean: 0.5848
#     MCC: 0.1971
#     F1-score: 0.1980
#     mAP: 0.2860
#   [ROS - DecisionTree]
#     AUROC: 0.6515
#     G-mean: 0.5230
#     MCC: 0.1112
#     F1-score: 0.1261
#     mAP: 0.2162
#   [ROS - kNN]
#     AUROC: 0.7042
#     G-mean: 0.5287
#     MCC: 0.2233
#     F1-score: 0.2356
#     mAP: 0.2229
#   [ROS - MLP]
#     AUROC: 0.7878
#     G-mean: 0.6867
#     MCC: 0.1867
#     F1-score: 0.1645
#     mAP: 0.3362
#   [ROS - RandomForest]
#     AUROC: 0.7801
#     G-mean: 0.2699
#     MCC: 0.2384
#     F1-score: 0.2213
#     mAP: 0.3335
#   [MWMOTE - SVM]
#     AUROC: 0.7023
#     G-mean: 0.5660
#     MCC: 0.1444
#     F1-score: 0.1477
#     mAP: 0.2129
#   [MWMOTE - DecisionTree]
#     AUROC: 0.6398
#     G-mean: 0.4609
#     MCC: 0.0915
#     F1-score: 0.1074
#     mAP: 0.1460
#   [MWMOTE - kNN]
#     AUROC: 0.7236
#     G-mean: 0.5940
#     MCC: 0.1980
#     F1-score: 0.1939
#     mAP: 0.1549
#   [MWMOTE - MLP]
#     AUROC: 0.7542
#     G-mean: 0.6537
#     MCC: 0.1707
#     F1-score: 0.1578
#     mAP: 0.2926
#   [MWMOTE - RandomForest]
#     AUROC: 0.7550
#     G-mean: 0.1774
#     MCC: 0.1378
#     F1-score: 0.1390
#     mAP: 0.2542
#   [CTGAN - SVM]
#     AUROC: 0.7272
#     G-mean: 0.5078
#     MCC: 0.2028
#     F1-score: 0.2110
#     mAP: 0.2906
#   [CTGAN - DecisionTree]
#     AUROC: 0.6709
#     G-mean: 0.3597
#     MCC: 0.3148
#     F1-score: 0.2915
#     mAP: 0.2692
#   [CTGAN - kNN]
#     AUROC: 0.7034
#     G-mean: 0.4870
#     MCC: 0.1751
#     F1-score: 0.1878
#     mAP: 0.2171
#   [CTGAN - MLP]
#     AUROC: 0.7128
#     G-mean: 0.4564
#     MCC: 0.1282
#     F1-score: 0.1449
#     mAP: 0.1905
#   [CTGAN - RandomForest]
#     AUROC: 0.7523
#     G-mean: 0.2766
#     MCC: 0.2441
#     F1-score: 0.2233
#     mAP: 0.3465
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Original - SVM]
#     AUROC: 0.6609
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.4234
#   [Original - DecisionTree]
#     AUROC: 0.6141
#     G-mean: 0.3909
#     MCC: 0.2863
#     F1-score: 0.2835
#     mAP: 0.2137
#   [Original - kNN]
#     AUROC: 0.7028
#     G-mean: 0.1291
#     MCC: 0.1278
#     F1-score: 0.1133
#     mAP: 0.2485
#   [Original - MLP]
#     AUROC: 0.2926
#     G-mean: 0.0000
#     MCC: -0.0052
#     F1-score: 0.0000
#     mAP: 0.0455
#   [Original - RandomForest]
#     AUROC: 0.7661
#     G-mean: 0.1961
#     MCC: 0.1728
#     F1-score: 0.1617
#     mAP: 0.3394
#   [SMOTE - SVM]
#     AUROC: 0.7131
#     G-mean: 0.5546
#     MCC: 0.1338
#     F1-score: 0.1396
#     mAP: 0.2574
#   [SMOTE - DecisionTree]
#     AUROC: 0.6359
#     G-mean: 0.5619
#     MCC: 0.1189
#     F1-score: 0.1296
#     mAP: 0.1784
#   [SMOTE - kNN]
#     AUROC: 0.7302
#     G-mean: 0.6293
#     MCC: 0.1784
#     F1-score: 0.1665
#     mAP: 0.1550
#   [SMOTE - MLP]
#     AUROC: 0.7841
#     G-mean: 0.6666
#     MCC: 0.1730
#     F1-score: 0.1549
#     mAP: 0.3152
#   [SMOTE - RandomForest]
#     AUROC: 0.7583
#     G-mean: 0.3466
#     MCC: 0.1947
#     F1-score: 0.2126
#     mAP: 0.2565
#   [ADASYN - SVM]
#     AUROC: 0.7091
#     G-mean: 0.5565
#     MCC: 0.1228
#     F1-score: 0.1295
#     mAP: 0.2401
#   [ADASYN - DecisionTree]
#     AUROC: 0.6168
#     G-mean: 0.5084
#     MCC: 0.1029
#     F1-score: 0.1183
#     mAP: 0.1496
#   [ADASYN - kNN]
#     AUROC: 0.7318
#     G-mean: 0.6345
#     MCC: 0.1822
#     F1-score: 0.1683
#     mAP: 0.1517
#   [ADASYN - MLP]
#     AUROC: 0.7769
#     G-mean: 0.6636
#     MCC: 0.1755
#     F1-score: 0.1562
#     mAP: 0.3280
#   [ADASYN - RandomForest]
#     AUROC: 0.7616
#     G-mean: 0.2726
#     MCC: 0.1541
#     F1-score: 0.1732
#     mAP: 0.2419
#   [bSMOTE - SVM]
#     AUROC: 0.7469
#     G-mean: 0.5388
#     MCC: 0.1740
#     F1-score: 0.1843
#     mAP: 0.2727
#   [bSMOTE - DecisionTree]
#     AUROC: 0.6584
#     G-mean: 0.4905
#     MCC: 0.1453
#     F1-score: 0.1616
#     mAP: 0.1999
#   [bSMOTE - kNN]
#     AUROC: 0.7143
#     G-mean: 0.5853
#     MCC: 0.2002
#     F1-score: 0.1994
#     mAP: 0.1834
#   [bSMOTE - MLP]
#     AUROC: 0.7882
#     G-mean: 0.6140
#     MCC: 0.1903
#     F1-score: 0.1874
#     mAP: 0.3346
#   [bSMOTE - RandomForest]
#     AUROC: 0.7703
#     G-mean: 0.3669
#     MCC: 0.2361
#     F1-score: 0.2475
#     mAP: 0.2799
#   [ROS - SVM]
#     AUROC: 0.7315
#     G-mean: 0.5998
#     MCC: 0.2023
#     F1-score: 0.2026
#     mAP: 0.2809
#   [ROS - DecisionTree]
#     AUROC: 0.6430
#     G-mean: 0.4923
#     MCC: 0.1074
#     F1-score: 0.1232
#     mAP: 0.2121
#   [ROS - kNN]
#     AUROC: 0.7012
#     G-mean: 0.5357
#     MCC: 0.2234
#     F1-score: 0.2356
#     mAP: 0.2118
#   [ROS - MLP]
#     AUROC: 0.7861
#     G-mean: 0.6876
#     MCC: 0.1863
#     F1-score: 0.1649
#     mAP: 0.3372
#   [ROS - RandomForest]
#     AUROC: 0.7785
#     G-mean: 0.2728
#     MCC: 0.2383
#     F1-score: 0.2216
#     mAP: 0.3307
#   [MWMOTE - SVM]
#     AUROC: 0.7026
#     G-mean: 0.5650
#     MCC: 0.1428
#     F1-score: 0.1471
#     mAP: 0.2207
#   [MWMOTE - DecisionTree]
#     AUROC: 0.6459
#     G-mean: 0.4706
#     MCC: 0.0950
#     F1-score: 0.1099
#     mAP: 0.1535
#   [MWMOTE - kNN]
#     AUROC: 0.7225
#     G-mean: 0.5958
#     MCC: 0.1911
#     F1-score: 0.1889
#     mAP: 0.1517
#   [MWMOTE - MLP]
#     AUROC: 0.7564
#     G-mean: 0.6575
#     MCC: 0.1693
#     F1-score: 0.1566
#     mAP: 0.2949
#   [MWMOTE - RandomForest]
#     AUROC: 0.7518
#     G-mean: 0.1861
#     MCC: 0.1456
#     F1-score: 0.1450
#     mAP: 0.2537
#   [CTGAN - SVM]
#     AUROC: 0.7214
#     G-mean: 0.5171
#     MCC: 0.2049
#     F1-score: 0.2146
#     mAP: 0.2992
#   [CTGAN - DecisionTree]
#     AUROC: 0.6682
#     G-mean: 0.3613
#     MCC: 0.3128
#     F1-score: 0.2918
#     mAP: 0.2714
#   [CTGAN - kNN]
#     AUROC: 0.7021
#     G-mean: 0.5076
#     MCC: 0.1882
#     F1-score: 0.2001
#     mAP: 0.2281
#   [CTGAN - MLP]
#     AUROC: 0.7113
#     G-mean: 0.4634
#     MCC: 0.1308
#     F1-score: 0.1480
#     mAP: 0.2161
#   [CTGAN - RandomForest]
#     AUROC: 0.7500
#     G-mean: 0.2785
#     MCC: 0.2474
#     F1-score: 0.2261
#     mAP: 0.3512
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Original - SVM]
#     AUROC: 0.6573
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.4240
#   [Original - DecisionTree]
#     AUROC: 0.6140
#     G-mean: 0.4006
#     MCC: 0.2917
#     F1-score: 0.2887
#     mAP: 0.2128
#   [Original - kNN]
#     AUROC: 0.7039
#     G-mean: 0.1354
#     MCC: 0.1340
#     F1-score: 0.1186
#     mAP: 0.2517
#   [Original - MLP]
#     AUROC: 0.2927
#     G-mean: 0.0000
#     MCC: -0.0051
#     F1-score: 0.0000
#     mAP: 0.0443
#   [Original - RandomForest]
#     AUROC: 0.7652
#     G-mean: 0.1928
#     MCC: 0.1696
#     F1-score: 0.1586
#     mAP: 0.3398
#   [SMOTE - SVM]
#     AUROC: 0.7129
#     G-mean: 0.5530
#     MCC: 0.1340
#     F1-score: 0.1392
#     mAP: 0.2434
#   [SMOTE - DecisionTree]
#     AUROC: 0.6323
#     G-mean: 0.5459
#     MCC: 0.1138
#     F1-score: 0.1256
#     mAP: 0.1774
#   [SMOTE - kNN]
#     AUROC: 0.7264
#     G-mean: 0.6360
#     MCC: 0.1796
#     F1-score: 0.1677
#     mAP: 0.1513
#   [SMOTE - MLP]
#     AUROC: 0.7843
#     G-mean: 0.6724
#     MCC: 0.1745
#     F1-score: 0.1551
#     mAP: 0.3113
#   [SMOTE - RandomForest]
#     AUROC: 0.7577
#     G-mean: 0.3461
#     MCC: 0.1966
#     F1-score: 0.2130
#     mAP: 0.2572
#   [ADASYN - SVM]
#     AUROC: 0.7093
#     G-mean: 0.5673
#     MCC: 0.1285
#     F1-score: 0.1327
#     mAP: 0.2307
#   [ADASYN - DecisionTree]
#     AUROC: 0.6157
#     G-mean: 0.5049
#     MCC: 0.1017
#     F1-score: 0.1178
#     mAP: 0.1455
#   [ADASYN - kNN]
#     AUROC: 0.7298
#     G-mean: 0.6428
#     MCC: 0.1849
#     F1-score: 0.1704
#     mAP: 0.1472
#   [ADASYN - MLP]
#     AUROC: 0.7756
#     G-mean: 0.6674
#     MCC: 0.1753
#     F1-score: 0.1558
#     mAP: 0.3208
#   [ADASYN - RandomForest]
#     AUROC: 0.7628
#     G-mean: 0.2697
#     MCC: 0.1566
#     F1-score: 0.1739
#     mAP: 0.2408
#   [bSMOTE - SVM]
#     AUROC: 0.7472
#     G-mean: 0.5494
#     MCC: 0.1752
#     F1-score: 0.1851
#     mAP: 0.2606
#   [bSMOTE - DecisionTree]
#     AUROC: 0.6550
#     G-mean: 0.4740
#     MCC: 0.1392
#     F1-score: 0.1571
#     mAP: 0.1951
#   [bSMOTE - kNN]
#     AUROC: 0.7124
#     G-mean: 0.5920
#     MCC: 0.1986
#     F1-score: 0.1982
#     mAP: 0.1772
#   [bSMOTE - MLP]
#     AUROC: 0.7899
#     G-mean: 0.6128
#     MCC: 0.1874
#     F1-score: 0.1839
#     mAP: 0.3344
#   [bSMOTE - RandomForest]
#     AUROC: 0.7725
#     G-mean: 0.3752
#     MCC: 0.2453
#     F1-score: 0.2549
#     mAP: 0.2856
#   [ROS - SVM]
#     AUROC: 0.7308
#     G-mean: 0.6082
#     MCC: 0.2048
#     F1-score: 0.2052
#     mAP: 0.2787
#   [ROS - DecisionTree]
#     AUROC: 0.6341
#     G-mean: 0.4758
#     MCC: 0.0997
#     F1-score: 0.1183
#     mAP: 0.2064
#   [ROS - kNN]
#     AUROC: 0.7019
#     G-mean: 0.5407
#     MCC: 0.2221
#     F1-score: 0.2345
#     mAP: 0.2082
#   [ROS - MLP]
#     AUROC: 0.7854
#     G-mean: 0.6913
#     MCC: 0.1878
#     F1-score: 0.1657
#     mAP: 0.3334
#   [ROS - RandomForest]
#     AUROC: 0.7790
#     G-mean: 0.2751
#     MCC: 0.2445
#     F1-score: 0.2257
#     mAP: 0.3375
#   [MWMOTE - SVM]
#     AUROC: 0.7045
#     G-mean: 0.5546
#     MCC: 0.1393
#     F1-score: 0.1440
#     mAP: 0.2142
#   [MWMOTE - DecisionTree]
#     AUROC: 0.6597
#     G-mean: 0.4961
#     MCC: 0.1036
#     F1-score: 0.1156
#     mAP: 0.1658
#   [MWMOTE - kNN]
#     AUROC: 0.7196
#     G-mean: 0.5987
#     MCC: 0.1913
#     F1-score: 0.1888
#     mAP: 0.1521
#   [MWMOTE - MLP]
#     AUROC: 0.7599
#     G-mean: 0.6581
#     MCC: 0.1683
#     F1-score: 0.1558
#     mAP: 0.2978
#   [MWMOTE - RandomForest]
#     AUROC: 0.7513
#     G-mean: 0.1875
#     MCC: 0.1439
#     F1-score: 0.1444
#     mAP: 0.2530
#   [CTGAN - SVM]
#     AUROC: 0.7303
#     G-mean: 0.5219
#     MCC: 0.2103
#     F1-score: 0.2207
#     mAP: 0.3044
#   [CTGAN - DecisionTree]
#     AUROC: 0.6652
#     G-mean: 0.3755
#     MCC: 0.3246
#     F1-score: 0.3020
#     mAP: 0.2757
#   [CTGAN - kNN]
#     AUROC: 0.7094
#     G-mean: 0.5253
#     MCC: 0.2044
#     F1-score: 0.2157
#     mAP: 0.2314
#   [CTGAN - MLP]
#     AUROC: 0.7215
#     G-mean: 0.4690
#     MCC: 0.1358
#     F1-score: 0.1520
#     mAP: 0.2168
#   [CTGAN - RandomForest]
#     AUROC: 0.7541
#     G-mean: 0.2717
#     MCC: 0.2418
#     F1-score: 0.2209
#     mAP: 0.3519
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Original - SVM]
#     AUROC: 0.6592
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.4211
#   [Original - DecisionTree]
#     AUROC: 0.6195
#     G-mean: 0.4065
#     MCC: 0.2975
#     F1-score: 0.2934
#     mAP: 0.2184
#   [Original - kNN]
#     AUROC: 0.7021
#     G-mean: 0.1328
#     MCC: 0.1283
#     F1-score: 0.1142
#     mAP: 0.2538
#   [Original - MLP]
#     AUROC: 0.2923
#     G-mean: 0.0000
#     MCC: -0.0047
#     F1-score: 0.0000
#     mAP: 0.0441
#   [Original - RandomForest]
#     AUROC: 0.7616
#     G-mean: 0.1903
#     MCC: 0.1674
#     F1-score: 0.1562
#     mAP: 0.3386
#   [SMOTE - SVM]
#     AUROC: 0.7125
#     G-mean: 0.5553
#     MCC: 0.1328
#     F1-score: 0.1382
#     mAP: 0.2399
#   [SMOTE - DecisionTree]
#     AUROC: 0.6320
#     G-mean: 0.5410
#     MCC: 0.1147
#     F1-score: 0.1267
#     mAP: 0.1786
#   [SMOTE - kNN]
#     AUROC: 0.7285
#     G-mean: 0.6381
#     MCC: 0.1785
#     F1-score: 0.1673
#     mAP: 0.1503
#   [SMOTE - MLP]
#     AUROC: 0.7806
#     G-mean: 0.6698
#     MCC: 0.1721
#     F1-score: 0.1542
#     mAP: 0.3095
#   [SMOTE - RandomForest]
#     AUROC: 0.7582
#     G-mean: 0.3445
#     MCC: 0.1996
#     F1-score: 0.2155
#     mAP: 0.2592
#   [ADASYN - SVM]
#     AUROC: 0.7092
#     G-mean: 0.5696
#     MCC: 0.1280
#     F1-score: 0.1319
#     mAP: 0.2288
#   [ADASYN - DecisionTree]
#     AUROC: 0.6190
#     G-mean: 0.5143
#     MCC: 0.1022
#     F1-score: 0.1175
#     mAP: 0.1466
#   [ADASYN - kNN]
#     AUROC: 0.7297
#     G-mean: 0.6465
#     MCC: 0.1846
#     F1-score: 0.1704
#     mAP: 0.1449
#   [ADASYN - MLP]
#     AUROC: 0.7738
#     G-mean: 0.6739
#     MCC: 0.1783
#     F1-score: 0.1573
#     mAP: 0.3170
#   [ADASYN - RandomForest]
#     AUROC: 0.7614
#     G-mean: 0.2776
#     MCC: 0.1640
#     F1-score: 0.1808
#     mAP: 0.2418
#   [bSMOTE - SVM]
#     AUROC: 0.7489
#     G-mean: 0.5385
#     MCC: 0.1699
#     F1-score: 0.1794
#     mAP: 0.2622
#   [bSMOTE - DecisionTree]
#     AUROC: 0.6592
#     G-mean: 0.4832
#     MCC: 0.1447
#     F1-score: 0.1612
#     mAP: 0.1982
#   [bSMOTE - kNN]
#     AUROC: 0.7145
#     G-mean: 0.5954
#     MCC: 0.2004
#     F1-score: 0.1997
#     mAP: 0.1781
#   [bSMOTE - MLP]
#     AUROC: 0.7905
#     G-mean: 0.6210
#     MCC: 0.1894
#     F1-score: 0.1845
#     mAP: 0.3333
#   [bSMOTE - RandomForest]
#     AUROC: 0.7706
#     G-mean: 0.3699
#     MCC: 0.2424
#     F1-score: 0.2520
#     mAP: 0.2882
#   [ROS - SVM]
#     AUROC: 0.7323
#     G-mean: 0.6140
#     MCC: 0.2064
#     F1-score: 0.2064
#     mAP: 0.2777
#   [ROS - DecisionTree]
#     AUROC: 0.6370
#     G-mean: 0.4797
#     MCC: 0.1048
#     F1-score: 0.1237
#     mAP: 0.2105
#   [ROS - kNN]
#     AUROC: 0.6996
#     G-mean: 0.5442
#     MCC: 0.2223
#     F1-score: 0.2344
#     mAP: 0.2059
#   [ROS - MLP]
#     AUROC: 0.7823
#     G-mean: 0.6937
#     MCC: 0.1888
#     F1-score: 0.1665
#     mAP: 0.3295
#   [ROS - RandomForest]
#     AUROC: 0.7755
#     G-mean: 0.2653
#     MCC: 0.2339
#     F1-score: 0.2171
#     mAP: 0.3467
#   [MWMOTE - SVM]
#     AUROC: 0.7051
#     G-mean: 0.5567
#     MCC: 0.1380
#     F1-score: 0.1426
#     mAP: 0.2090
#   [MWMOTE - DecisionTree]
#     AUROC: 0.6582
#     G-mean: 0.5046
#     MCC: 0.1057
#     F1-score: 0.1177
#     mAP: 0.1635
#   [MWMOTE - kNN]
#     AUROC: 0.7214
#     G-mean: 0.5986
#     MCC: 0.1900
#     F1-score: 0.1881
#     mAP: 0.1532
#   [MWMOTE - MLP]
#     AUROC: 0.7608
#     G-mean: 0.6636
#     MCC: 0.1716
#     F1-score: 0.1578
#     mAP: 0.3004
#   [MWMOTE - RandomForest]
#     AUROC: 0.7496
#     G-mean: 0.2029
#     MCC: 0.1529
#     F1-score: 0.1545
#     mAP: 0.2588
#   [CTGAN - SVM]
#     AUROC: 0.7363
#     G-mean: 0.5283
#     MCC: 0.2128
#     F1-score: 0.2221
#     mAP: 0.3134
#   [CTGAN - DecisionTree]
#     AUROC: 0.6683
#     G-mean: 0.3846
#     MCC: 0.3281
#     F1-score: 0.3059
#     mAP: 0.2754
#   [CTGAN - kNN]
#     AUROC: 0.7134
#     G-mean: 0.5318
#     MCC: 0.2033
#     F1-score: 0.2138
#     mAP: 0.2322
#   [CTGAN - MLP]
#     AUROC: 0.7227
#     G-mean: 0.4780
#     MCC: 0.1403
#     F1-score: 0.1550
#     mAP: 0.2218
#   [CTGAN - RandomForest]
#     AUROC: 0.7529
#     G-mean: 0.2665
#     MCC: 0.2372
#     F1-score: 0.2171
#     mAP: 0.3486
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Original - SVM]
#     AUROC: 0.6585
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.4209
#   [Original - DecisionTree]
#     AUROC: 0.6212
#     G-mean: 0.3984
#     MCC: 0.2908
#     F1-score: 0.2870
#     mAP: 0.2178
#   [Original - kNN]
#     AUROC: 0.7041
#     G-mean: 0.1245
#     MCC: 0.1204
#     F1-score: 0.1070
#     mAP: 0.2484
#   [Original - MLP]
#     AUROC: 0.2929
#     G-mean: 0.0000
#     MCC: -0.0049
#     F1-score: 0.0000
#     mAP: 0.0436
#   [Original - RandomForest]
#     AUROC: 0.7644
#     G-mean: 0.1873
#     MCC: 0.1649
#     F1-score: 0.1552
#     mAP: 0.3436
#   [SMOTE - SVM]
#     AUROC: 0.7103
#     G-mean: 0.5585
#     MCC: 0.1342
#     F1-score: 0.1395
#     mAP: 0.2340
#   [SMOTE - DecisionTree]
#     AUROC: 0.6224
#     G-mean: 0.5305
#     MCC: 0.1110
#     F1-score: 0.1246
#     mAP: 0.1687
#   [SMOTE - kNN]
#     AUROC: 0.7282
#     G-mean: 0.6431
#     MCC: 0.1799
#     F1-score: 0.1687
#     mAP: 0.1514
#   [SMOTE - MLP]
#     AUROC: 0.7819
#     G-mean: 0.6711
#     MCC: 0.1718
#     F1-score: 0.1541
#     mAP: 0.3094
#   [SMOTE - RandomForest]
#     AUROC: 0.7612
#     G-mean: 0.3343
#     MCC: 0.1954
#     F1-score: 0.2111
#     mAP: 0.2576
#   [ADASYN - SVM]
#     AUROC: 0.7065
#     G-mean: 0.5702
#     MCC: 0.1278
#     F1-score: 0.1319
#     mAP: 0.2239
#   [ADASYN - DecisionTree]
#     AUROC: 0.6259
#     G-mean: 0.5290
#     MCC: 0.1064
#     F1-score: 0.1193
#     mAP: 0.1478
#   [ADASYN - kNN]
#     AUROC: 0.7311
#     G-mean: 0.6501
#     MCC: 0.1843
#     F1-score: 0.1704
#     mAP: 0.1443
#   [ADASYN - MLP]
#     AUROC: 0.7774
#     G-mean: 0.6811
#     MCC: 0.1808
#     F1-score: 0.1585
#     mAP: 0.3163
#   [ADASYN - RandomForest]
#     AUROC: 0.7632
#     G-mean: 0.2811
#     MCC: 0.1655
#     F1-score: 0.1826
#     mAP: 0.2414
#   [bSMOTE - SVM]
#     AUROC: 0.7496
#     G-mean: 0.5412
#     MCC: 0.1704
#     F1-score: 0.1800
#     mAP: 0.2615
#   [bSMOTE - DecisionTree]
#     AUROC: 0.6506
#     G-mean: 0.4794
#     MCC: 0.1425
#     F1-score: 0.1595
#     mAP: 0.1982
#   [bSMOTE - kNN]
#     AUROC: 0.7144
#     G-mean: 0.6026
#     MCC: 0.2024
#     F1-score: 0.2016
#     mAP: 0.1746
#   [bSMOTE - MLP]
#     AUROC: 0.7917
#     G-mean: 0.6305
#     MCC: 0.1942
#     F1-score: 0.1878
#     mAP: 0.3331
#   [bSMOTE - RandomForest]
#     AUROC: 0.7738
#     G-mean: 0.3670
#     MCC: 0.2390
#     F1-score: 0.2487
#     mAP: 0.2858
#   [ROS - SVM]
#     AUROC: 0.7305
#     G-mean: 0.6098
#     MCC: 0.2021
#     F1-score: 0.2029
#     mAP: 0.2756
#   [ROS - DecisionTree]
#     AUROC: 0.6272
#     G-mean: 0.4563
#     MCC: 0.0981
#     F1-score: 0.1187
#     mAP: 0.2072
#   [ROS - kNN]
#     AUROC: 0.7019
#     G-mean: 0.5561
#     MCC: 0.2272
#     F1-score: 0.2388
#     mAP: 0.2081
#   [ROS - MLP]
#     AUROC: 0.7838
#     G-mean: 0.6982
#     MCC: 0.1905
#     F1-score: 0.1674
#     mAP: 0.3261
#   [ROS - RandomForest]
#     AUROC: 0.7770
#     G-mean: 0.2486
#     MCC: 0.2197
#     F1-score: 0.2041
#     mAP: 0.3448
#   [MWMOTE - SVM]
#     AUROC: 0.7027
#     G-mean: 0.5618
#     MCC: 0.1393
#     F1-score: 0.1432
#     mAP: 0.2061
#   [MWMOTE - DecisionTree]
#     AUROC: 0.6539
#     G-mean: 0.5056
#     MCC: 0.1059
#     F1-score: 0.1180
#     mAP: 0.1603
#   [MWMOTE - kNN]
#     AUROC: 0.7196
#     G-mean: 0.5987
#     MCC: 0.1891
#     F1-score: 0.1876
#     mAP: 0.1527
#   [MWMOTE - MLP]
#     AUROC: 0.7614
#     G-mean: 0.6639
#     MCC: 0.1709
#     F1-score: 0.1578
#     mAP: 0.2952
#   [MWMOTE - RandomForest]
#     AUROC: 0.7525
#     G-mean: 0.1931
#     MCC: 0.1475
#     F1-score: 0.1484
#     mAP: 0.2565
#   [CTGAN - SVM]
#     AUROC: 0.7357
#     G-mean: 0.5333
#     MCC: 0.2147
#     F1-score: 0.2245
#     mAP: 0.3077
#   [CTGAN - DecisionTree]
#     AUROC: 0.6666
#     G-mean: 0.3879
#     MCC: 0.3277
#     F1-score: 0.3079
#     mAP: 0.2765
#   [CTGAN - kNN]
#     AUROC: 0.7167
#     G-mean: 0.5364
#     MCC: 0.2070
#     F1-score: 0.2179
#     mAP: 0.2318
#   [CTGAN - MLP]
#     AUROC: 0.7241
#     G-mean: 0.4831
#     MCC: 0.1418
#     F1-score: 0.1559
#     mAP: 0.2239
#   [CTGAN - RandomForest]
#     AUROC: 0.7542
#     G-mean: 0.2550
#     MCC: 0.2267
#     F1-score: 0.2093
#     mAP: 0.3530
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Original - SVM]
#     AUROC: 0.6609
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.4233
#   [Original - DecisionTree]
#     AUROC: 0.6233
#     G-mean: 0.3953
#     MCC: 0.2881
#     F1-score: 0.2842
#     mAP: 0.2194
#   [Original - kNN]
#     AUROC: 0.7046
#     G-mean: 0.1293
#     MCC: 0.1255
#     F1-score: 0.1113
#     mAP: 0.2456
#   [Original - MLP]
#     AUROC: 0.2922
#     G-mean: 0.0000
#     MCC: -0.0051
#     F1-score: 0.0000
#     mAP: 0.0456
#   [Original - RandomForest]
#     AUROC: 0.7665
#     G-mean: 0.1858
#     MCC: 0.1636
#     F1-score: 0.1537
#     mAP: 0.3463
#   [SMOTE - SVM]
#     AUROC: 0.7109
#     G-mean: 0.5631
#     MCC: 0.1370
#     F1-score: 0.1417
#     mAP: 0.2341
#   [SMOTE - DecisionTree]
#     AUROC: 0.6222
#     G-mean: 0.5288
#     MCC: 0.1096
#     F1-score: 0.1235
#     mAP: 0.1684
#   [SMOTE - kNN]
#     AUROC: 0.7315
#     G-mean: 0.6449
#     MCC: 0.1825
#     F1-score: 0.1705
#     mAP: 0.1532
#   [SMOTE - MLP]
#     AUROC: 0.7832
#     G-mean: 0.6763
#     MCC: 0.1746
#     F1-score: 0.1558
#     mAP: 0.3097
#   [SMOTE - RandomForest]
#     AUROC: 0.7620
#     G-mean: 0.3374
#     MCC: 0.1981
#     F1-score: 0.2127
#     mAP: 0.2589
#   [ADASYN - SVM]
#     AUROC: 0.7071
#     G-mean: 0.5769
#     MCC: 0.1318
#     F1-score: 0.1344
#     mAP: 0.2269
#   [ADASYN - DecisionTree]
#     AUROC: 0.6262
#     G-mean: 0.5272
#     MCC: 0.1051
#     F1-score: 0.1183
#     mAP: 0.1457
#   [ADASYN - kNN]
#     AUROC: 0.7342
#     G-mean: 0.6507
#     MCC: 0.1866
#     F1-score: 0.1724
#     mAP: 0.1457
#   [ADASYN - MLP]
#     AUROC: 0.7785
#     G-mean: 0.6783
#     MCC: 0.1803
#     F1-score: 0.1584
#     mAP: 0.3139
#   [ADASYN - RandomForest]
#     AUROC: 0.7650
#     G-mean: 0.2760
#     MCC: 0.1643
#     F1-score: 0.1805
#     mAP: 0.2434
#   [bSMOTE - SVM]
#     AUROC: 0.7511
#     G-mean: 0.5400
#     MCC: 0.1714
#     F1-score: 0.1810
#     mAP: 0.2613
#   [bSMOTE - DecisionTree]
#     AUROC: 0.6493
#     G-mean: 0.4749
#     MCC: 0.1386
#     F1-score: 0.1557
#     mAP: 0.2004
#   [bSMOTE - kNN]
#     AUROC: 0.7153
#     G-mean: 0.6048
#     MCC: 0.2048
#     F1-score: 0.2039
#     mAP: 0.1743
#   [bSMOTE - MLP]
#     AUROC: 0.7932
#     G-mean: 0.6281
#     MCC: 0.1936
#     F1-score: 0.1873
#     mAP: 0.3368
#   [bSMOTE - RandomForest]
#     AUROC: 0.7760
#     G-mean: 0.3670
#     MCC: 0.2414
#     F1-score: 0.2500
#     mAP: 0.2903
#   [ROS - SVM]
#     AUROC: 0.7318
#     G-mean: 0.6142
#     MCC: 0.2083
#     F1-score: 0.2089
#     mAP: 0.2763
#   [ROS - DecisionTree]
#     AUROC: 0.6360
#     G-mean: 0.4676
#     MCC: 0.1033
#     F1-score: 0.1218
#     mAP: 0.2103
#   [ROS - kNN]
#     AUROC: 0.7024
#     G-mean: 0.5543
#     MCC: 0.2259
#     F1-score: 0.2375
#     mAP: 0.2047
#   [ROS - MLP]
#     AUROC: 0.7855
#     G-mean: 0.6944
#     MCC: 0.1907
#     F1-score: 0.1683
#     mAP: 0.3296
#   [ROS - RandomForest]
#     AUROC: 0.7788
#     G-mean: 0.2549
#     MCC: 0.2242
#     F1-score: 0.2087
#     mAP: 0.3460
#   [MWMOTE - SVM]
#     AUROC: 0.7023
#     G-mean: 0.5637
#     MCC: 0.1399
#     F1-score: 0.1439
#     mAP: 0.2001
#   [MWMOTE - DecisionTree]
#     AUROC: 0.6565
#     G-mean: 0.5126
#     MCC: 0.1088
#     F1-score: 0.1200
#     mAP: 0.1612
#   [MWMOTE - kNN]
#     AUROC: 0.7175
#     G-mean: 0.6014
#     MCC: 0.1916
#     F1-score: 0.1900
#     mAP: 0.1501
#   [MWMOTE - MLP]
#     AUROC: 0.7641
#     G-mean: 0.6694
#     MCC: 0.1741
#     F1-score: 0.1594
#     mAP: 0.2956
#   [MWMOTE - RandomForest]
#     AUROC: 0.7534
#     G-mean: 0.1911
#     MCC: 0.1433
#     F1-score: 0.1456
#     mAP: 0.2597
#   [CTGAN - SVM]
#     AUROC: 0.7369
#     G-mean: 0.5291
#     MCC: 0.2108
#     F1-score: 0.2216
#     mAP: 0.3002
#   [CTGAN - DecisionTree]
#     AUROC: 0.6650
#     G-mean: 0.3860
#     MCC: 0.3273
#     F1-score: 0.3068
#     mAP: 0.2739
#   [CTGAN - kNN]
#     AUROC: 0.7168
#     G-mean: 0.5350
#     MCC: 0.2035
#     F1-score: 0.2155
#     mAP: 0.2249
#   [CTGAN - MLP]
#     AUROC: 0.7197
#     G-mean: 0.4774
#     MCC: 0.1391
#     F1-score: 0.1544
#     mAP: 0.2145
#   [CTGAN - RandomForest]
#     AUROC: 0.7535
#     G-mean: 0.2584
#     MCC: 0.2306
#     F1-score: 0.2123
#     mAP: 0.3600
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/classifiers/yeast-1-2-8-9_vs_7_results_gaussian_beta_0.1.csv

# %%
data_name = 'yeast-1-4-5-8_vs_7'

# 실험 파라미터 설정
n_epochs = 2000
hidden_dims = [8, 16, 32, 64]
latent_dim = 128
lr = 0.001
beta = 0.1

# 데이터 불러오기
yeast_1_4_5_8_vs_7 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# Run experiment
final_results = run_exp(
    data=yeast_1_4_5_8_vs_7, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (693, 8)
# target : Counter({0: 663, 1: 30})
# IR: 22.1
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Original - SVM]
#     AUROC: 0.6262
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2930
#   [Original - DecisionTree]
#     AUROC: 0.6453
#     G-mean: 0.2527
#     MCC: 0.1581
#     F1-score: 0.1867
#     mAP: 0.1938
#   [Original - kNN]
#     AUROC: 0.6774
#     G-mean: 0.0577
#     MCC: 0.0543
#     F1-score: 0.0500
#     mAP: 0.1297
#   [Original - MLP]
#     AUROC: 0.4475
#     G-mean: 0.0573
#     MCC: 0.0301
#     F1-score: 0.0400
#     mAP: 0.0755
#   [Original - RandomForest]
#     AUROC: 0.7123
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2228
#   [SMOTE - SVM]
#     AUROC: 0.6924
#     G-mean: 0.5940
#     MCC: 0.1568
#     F1-score: 0.1751
#     mAP: 0.1885
#   [SMOTE - DecisionTree]
#     AUROC: 0.5367
#     G-mean: 0.4659
#     MCC: 0.1073
#     F1-score: 0.1437
#     mAP: 0.1581
#   [SMOTE - kNN]
#     AUROC: 0.7007
#     G-mean: 0.6364
#     MCC: 0.1839
#     F1-score: 0.1946
#     mAP: 0.1810
#   [SMOTE - MLP]
#     AUROC: 0.7385
#     G-mean: 0.6848
#     MCC: 0.1773
#     F1-score: 0.1727
#     mAP: 0.2512
#   [SMOTE - RandomForest]
#     AUROC: 0.6756
#     G-mean: 0.2843
#     MCC: 0.1395
#     F1-score: 0.1686
#     mAP: 0.2169
#   [ADASYN - SVM]
#     AUROC: 0.6864
#     G-mean: 0.5682
#     MCC: 0.1312
#     F1-score: 0.1553
#     mAP: 0.2054
#   [ADASYN - DecisionTree]
#     AUROC: 0.5565
#     G-mean: 0.3568
#     MCC: 0.0533
#     F1-score: 0.0981
#     mAP: 0.1094
#   [ADASYN - kNN]
#     AUROC: 0.7030
#     G-mean: 0.6199
#     MCC: 0.1803
#     F1-score: 0.1943
#     mAP: 0.1503
#   [ADASYN - MLP]
#     AUROC: 0.7250
#     G-mean: 0.6631
#     MCC: 0.1597
#     F1-score: 0.1633
#     mAP: 0.1972
#   [ADASYN - RandomForest]
#     AUROC: 0.6755
#     G-mean: 0.2256
#     MCC: 0.0833
#     F1-score: 0.1155
#     mAP: 0.1941
#   [bSMOTE - SVM]
#     AUROC: 0.7146
#     G-mean: 0.5509
#     MCC: 0.1625
#     F1-score: 0.1899
#     mAP: 0.2243
#   [bSMOTE - DecisionTree]
#     AUROC: 0.6260
#     G-mean: 0.4430
#     MCC: 0.1256
#     F1-score: 0.1656
#     mAP: 0.1281
#   [bSMOTE - kNN]
#     AUROC: 0.7041
#     G-mean: 0.6430
#     MCC: 0.2408
#     F1-score: 0.2529
#     mAP: 0.1902
#   [bSMOTE - MLP]
#     AUROC: 0.7355
#     G-mean: 0.6001
#     MCC: 0.1624
#     F1-score: 0.1730
#     mAP: 0.2280
#   [bSMOTE - RandomForest]
#     AUROC: 0.7173
#     G-mean: 0.1715
#     MCC: 0.0901
#     F1-score: 0.1133
#     mAP: 0.2063
#   [ROS - SVM]
#     AUROC: 0.6839
#     G-mean: 0.4930
#     MCC: 0.0986
#     F1-score: 0.1358
#     mAP: 0.2619
#   [ROS - DecisionTree]
#     AUROC: 0.5203
#     G-mean: 0.3900
#     MCC: 0.0600
#     F1-score: 0.1149
#     mAP: 0.0931
#   [ROS - kNN]
#     AUROC: 0.6826
#     G-mean: 0.4186
#     MCC: 0.1504
#     F1-score: 0.1821
#     mAP: 0.1597
#   [ROS - MLP]
#     AUROC: 0.7229
#     G-mean: 0.6588
#     MCC: 0.1611
#     F1-score: 0.1690
#     mAP: 0.2648
#   [ROS - RandomForest]
#     AUROC: 0.7173
#     G-mean: 0.0577
#     MCC: 0.0543
#     F1-score: 0.0500
#     mAP: 0.2535
#   [MWMOTE - SVM]
#     AUROC: 0.6836
#     G-mean: 0.5051
#     MCC: 0.1166
#     F1-score: 0.1497
#     mAP: 0.1976
#   [MWMOTE - DecisionTree]
#     AUROC: 0.5811
#     G-mean: 0.4068
#     MCC: 0.0890
#     F1-score: 0.1219
#     mAP: 0.1235
#   [MWMOTE - kNN]
#     AUROC: 0.6681
#     G-mean: 0.5356
#     MCC: 0.1583
#     F1-score: 0.1814
#     mAP: 0.1344
#   [MWMOTE - MLP]
#     AUROC: 0.7295
#     G-mean: 0.6861
#     MCC: 0.1850
#     F1-score: 0.1781
#     mAP: 0.2329
#   [MWMOTE - RandomForest]
#     AUROC: 0.6970
#     G-mean: 0.1155
#     MCC: 0.0882
#     F1-score: 0.1000
#     mAP: 0.2130
#   [CTGAN - SVM]
#     AUROC: 0.6242
#     G-mean: 0.3016
#     MCC: 0.0994
#     F1-score: 0.1410
#     mAP: 0.2024
#   [CTGAN - DecisionTree]
#     AUROC: 0.5922
#     G-mean: 0.1719
#     MCC: 0.1088
#     F1-score: 0.1233
#     mAP: 0.1392
#   [CTGAN - kNN]
#     AUROC: 0.6382
#     G-mean: 0.2978
#     MCC: 0.0818
#     F1-score: 0.1186
#     mAP: 0.1504
#   [CTGAN - MLP]
#     AUROC: 0.6204
#     G-mean: 0.4469
#     MCC: 0.1090
#     F1-score: 0.1519
#     mAP: 0.1885
#   [CTGAN - RandomForest]
#     AUROC: 0.7108
#     G-mean: 0.0000
#     MCC: -0.0052
#     F1-score: 0.0000
#     mAP: 0.2254
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Original - SVM]
#     AUROC: 0.6129
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2840
#   [Original - DecisionTree]
#     AUROC: 0.6607
#     G-mean: 0.2389
#     MCC: 0.1175
#     F1-score: 0.1497
#     mAP: 0.1538
#   [Original - kNN]
#     AUROC: 0.6643
#     G-mean: 0.0289
#     MCC: 0.0259
#     F1-score: 0.0250
#     mAP: 0.1204
#   [Original - MLP]
#     AUROC: 0.4392
#     G-mean: 0.0286
#     MCC: 0.0102
#     F1-score: 0.0200
#     mAP: 0.0804
#   [Original - RandomForest]
#     AUROC: 0.7020
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2229
#   [SMOTE - SVM]
#     AUROC: 0.6754
#     G-mean: 0.5176
#     MCC: 0.1204
#     F1-score: 0.1498
#     mAP: 0.1730
#   [SMOTE - DecisionTree]
#     AUROC: 0.5243
#     G-mean: 0.4484
#     MCC: 0.1090
#     F1-score: 0.1512
#     mAP: 0.1426
#   [SMOTE - kNN]
#     AUROC: 0.6935
#     G-mean: 0.6285
#     MCC: 0.1855
#     F1-score: 0.1982
#     mAP: 0.1567
#   [SMOTE - MLP]
#     AUROC: 0.7206
#     G-mean: 0.6292
#     MCC: 0.1586
#     F1-score: 0.1639
#     mAP: 0.2654
#   [SMOTE - RandomForest]
#     AUROC: 0.6586
#     G-mean: 0.2554
#     MCC: 0.1252
#     F1-score: 0.1510
#     mAP: 0.2104
#   [ADASYN - SVM]
#     AUROC: 0.6696
#     G-mean: 0.5179
#     MCC: 0.1046
#     F1-score: 0.1389
#     mAP: 0.1869
#   [ADASYN - DecisionTree]
#     AUROC: 0.5624
#     G-mean: 0.3907
#     MCC: 0.0692
#     F1-score: 0.1122
#     mAP: 0.1209
#   [ADASYN - kNN]
#     AUROC: 0.6956
#     G-mean: 0.6176
#     MCC: 0.1804
#     F1-score: 0.1940
#     mAP: 0.1431
#   [ADASYN - MLP]
#     AUROC: 0.7170
#     G-mean: 0.6150
#     MCC: 0.1442
#     F1-score: 0.1560
#     mAP: 0.2345
#   [ADASYN - RandomForest]
#     AUROC: 0.6657
#     G-mean: 0.1978
#     MCC: 0.0814
#     F1-score: 0.1106
#     mAP: 0.1978
#   [bSMOTE - SVM]
#     AUROC: 0.7007
#     G-mean: 0.5123
#     MCC: 0.1400
#     F1-score: 0.1738
#     mAP: 0.2100
#   [bSMOTE - DecisionTree]
#     AUROC: 0.5712
#     G-mean: 0.3999
#     MCC: 0.0993
#     F1-score: 0.1409
#     mAP: 0.1097
#   [bSMOTE - kNN]
#     AUROC: 0.7044
#     G-mean: 0.6318
#     MCC: 0.2306
#     F1-score: 0.2457
#     mAP: 0.1856
#   [bSMOTE - MLP]
#     AUROC: 0.7288
#     G-mean: 0.5701
#     MCC: 0.1575
#     F1-score: 0.1702
#     mAP: 0.2520
#   [bSMOTE - RandomForest]
#     AUROC: 0.7081
#     G-mean: 0.1835
#     MCC: 0.1124
#     F1-score: 0.1316
#     mAP: 0.2197
#   [ROS - SVM]
#     AUROC: 0.6776
#     G-mean: 0.5093
#     MCC: 0.1036
#     F1-score: 0.1390
#     mAP: 0.2391
#   [ROS - DecisionTree]
#     AUROC: 0.5192
#     G-mean: 0.3522
#     MCC: 0.0346
#     F1-score: 0.0975
#     mAP: 0.0990
#   [ROS - kNN]
#     AUROC: 0.6696
#     G-mean: 0.4515
#     MCC: 0.1536
#     F1-score: 0.1874
#     mAP: 0.1466
#   [ROS - MLP]
#     AUROC: 0.7042
#     G-mean: 0.6102
#     MCC: 0.1475
#     F1-score: 0.1563
#     mAP: 0.2712
#   [ROS - RandomForest]
#     AUROC: 0.7063
#     G-mean: 0.0289
#     MCC: 0.0259
#     F1-score: 0.0250
#     mAP: 0.2321
#   [MWMOTE - SVM]
#     AUROC: 0.6710
#     G-mean: 0.4419
#     MCC: 0.0893
#     F1-score: 0.1313
#     mAP: 0.1822
#   [MWMOTE - DecisionTree]
#     AUROC: 0.6091
#     G-mean: 0.4426
#     MCC: 0.1058
#     F1-score: 0.1339
#     mAP: 0.1098
#   [MWMOTE - kNN]
#     AUROC: 0.6666
#     G-mean: 0.5533
#     MCC: 0.1655
#     F1-score: 0.1900
#     mAP: 0.1416
#   [MWMOTE - MLP]
#     AUROC: 0.7183
#     G-mean: 0.5956
#     MCC: 0.1474
#     F1-score: 0.1573
#     mAP: 0.2671
#   [MWMOTE - RandomForest]
#     AUROC: 0.7049
#     G-mean: 0.0859
#     MCC: 0.0487
#     F1-score: 0.0643
#     mAP: 0.2283
#   [CTGAN - SVM]
#     AUROC: 0.6319
#     G-mean: 0.2712
#     MCC: 0.0682
#     F1-score: 0.1138
#     mAP: 0.1731
#   [CTGAN - DecisionTree]
#     AUROC: 0.5785
#     G-mean: 0.1148
#     MCC: 0.0698
#     F1-score: 0.0867
#     mAP: 0.1367
#   [CTGAN - kNN]
#     AUROC: 0.6429
#     G-mean: 0.2695
#     MCC: 0.0614
#     F1-score: 0.1047
#     mAP: 0.1202
#   [CTGAN - MLP]
#     AUROC: 0.6225
#     G-mean: 0.3648
#     MCC: 0.0660
#     F1-score: 0.1137
#     mAP: 0.1452
#   [CTGAN - RandomForest]
#     AUROC: 0.6921
#     G-mean: 0.0000
#     MCC: -0.0044
#     F1-score: 0.0000
#     mAP: 0.2057
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Original - SVM]
#     AUROC: 0.6170
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2751
#   [Original - DecisionTree]
#     AUROC: 0.6441
#     G-mean: 0.2348
#     MCC: 0.1087
#     F1-score: 0.1415
#     mAP: 0.1368
#   [Original - kNN]
#     AUROC: 0.6444
#     G-mean: 0.0192
#     MCC: 0.0173
#     F1-score: 0.0167
#     mAP: 0.1198
#   [Original - MLP]
#     AUROC: 0.4372
#     G-mean: 0.0191
#     MCC: 0.0027
#     F1-score: 0.0133
#     mAP: 0.0772
#   [Original - RandomForest]
#     AUROC: 0.7058
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2161
#   [SMOTE - SVM]
#     AUROC: 0.6721
#     G-mean: 0.4908
#     MCC: 0.1154
#     F1-score: 0.1471
#     mAP: 0.1824
#   [SMOTE - DecisionTree]
#     AUROC: 0.5674
#     G-mean: 0.4887
#     MCC: 0.1275
#     F1-score: 0.1585
#     mAP: 0.1589
#   [SMOTE - kNN]
#     AUROC: 0.6823
#     G-mean: 0.6018
#     MCC: 0.1711
#     F1-score: 0.1858
#     mAP: 0.1495
#   [SMOTE - MLP]
#     AUROC: 0.7189
#     G-mean: 0.6017
#     MCC: 0.1465
#     F1-score: 0.1577
#     mAP: 0.2658
#   [SMOTE - RandomForest]
#     AUROC: 0.6715
#     G-mean: 0.2537
#     MCC: 0.1244
#     F1-score: 0.1525
#     mAP: 0.2065
#   [ADASYN - SVM]
#     AUROC: 0.6624
#     G-mean: 0.4902
#     MCC: 0.1023
#     F1-score: 0.1388
#     mAP: 0.1895
#   [ADASYN - DecisionTree]
#     AUROC: 0.5706
#     G-mean: 0.3979
#     MCC: 0.0840
#     F1-score: 0.1258
#     mAP: 0.1286
#   [ADASYN - kNN]
#     AUROC: 0.6917
#     G-mean: 0.6073
#     MCC: 0.1806
#     F1-score: 0.1918
#     mAP: 0.1419
#   [ADASYN - MLP]
#     AUROC: 0.7153
#     G-mean: 0.6135
#     MCC: 0.1438
#     F1-score: 0.1561
#     mAP: 0.2458
#   [ADASYN - RandomForest]
#     AUROC: 0.6825
#     G-mean: 0.2076
#     MCC: 0.0867
#     F1-score: 0.1172
#     mAP: 0.1982
#   [bSMOTE - SVM]
#     AUROC: 0.7018
#     G-mean: 0.4728
#     MCC: 0.1388
#     F1-score: 0.1712
#     mAP: 0.2190
#   [bSMOTE - DecisionTree]
#     AUROC: 0.5633
#     G-mean: 0.3906
#     MCC: 0.0864
#     F1-score: 0.1284
#     mAP: 0.1024
#   [bSMOTE - kNN]
#     AUROC: 0.6931
#     G-mean: 0.5761
#     MCC: 0.2113
#     F1-score: 0.2280
#     mAP: 0.1794
#   [bSMOTE - MLP]
#     AUROC: 0.7206
#     G-mean: 0.5597
#     MCC: 0.1531
#     F1-score: 0.1707
#     mAP: 0.2607
#   [bSMOTE - RandomForest]
#     AUROC: 0.7179
#     G-mean: 0.1606
#     MCC: 0.0943
#     F1-score: 0.1144
#     mAP: 0.2177
#   [ROS - SVM]
#     AUROC: 0.6746
#     G-mean: 0.4825
#     MCC: 0.1017
#     F1-score: 0.1374
#     mAP: 0.2349
#   [ROS - DecisionTree]
#     AUROC: 0.5352
#     G-mean: 0.3621
#     MCC: 0.0419
#     F1-score: 0.1000
#     mAP: 0.0958
#   [ROS - kNN]
#     AUROC: 0.6507
#     G-mean: 0.4239
#     MCC: 0.1380
#     F1-score: 0.1744
#     mAP: 0.1454
#   [ROS - MLP]
#     AUROC: 0.6982
#     G-mean: 0.5957
#     MCC: 0.1361
#     F1-score: 0.1527
#     mAP: 0.2616
#   [ROS - RandomForest]
#     AUROC: 0.7121
#     G-mean: 0.0192
#     MCC: 0.0155
#     F1-score: 0.0167
#     mAP: 0.2345
#   [MWMOTE - SVM]
#     AUROC: 0.6682
#     G-mean: 0.4156
#     MCC: 0.0880
#     F1-score: 0.1301
#     mAP: 0.1920
#   [MWMOTE - DecisionTree]
#     AUROC: 0.6050
#     G-mean: 0.4570
#     MCC: 0.1144
#     F1-score: 0.1431
#     mAP: 0.1167
#   [MWMOTE - kNN]
#     AUROC: 0.6570
#     G-mean: 0.5068
#     MCC: 0.1472
#     F1-score: 0.1723
#     mAP: 0.1316
#   [MWMOTE - MLP]
#     AUROC: 0.7127
#     G-mean: 0.5741
#     MCC: 0.1332
#     F1-score: 0.1513
#     mAP: 0.2730
#   [MWMOTE - RandomForest]
#     AUROC: 0.7008
#     G-mean: 0.0955
#     MCC: 0.0574
#     F1-score: 0.0706
#     mAP: 0.2186
#   [CTGAN - SVM]
#     AUROC: 0.6185
#     G-mean: 0.2613
#     MCC: 0.0603
#     F1-score: 0.1073
#     mAP: 0.1673
#   [CTGAN - DecisionTree]
#     AUROC: 0.6065
#     G-mean: 0.1149
#     MCC: 0.0725
#     F1-score: 0.0878
#     mAP: 0.1404
#   [CTGAN - kNN]
#     AUROC: 0.6318
#     G-mean: 0.2709
#     MCC: 0.0558
#     F1-score: 0.1031
#     mAP: 0.1077
#   [CTGAN - MLP]
#     AUROC: 0.5973
#     G-mean: 0.3559
#     MCC: 0.0582
#     F1-score: 0.1094
#     mAP: 0.1370
#   [CTGAN - RandomForest]
#     AUROC: 0.6878
#     G-mean: 0.0000
#     MCC: -0.0030
#     F1-score: 0.0000
#     mAP: 0.1911
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Original - SVM]
#     AUROC: 0.6304
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2772
#   [Original - DecisionTree]
#     AUROC: 0.6339
#     G-mean: 0.2191
#     MCC: 0.1078
#     F1-score: 0.1369
#     mAP: 0.1431
#   [Original - kNN]
#     AUROC: 0.6535
#     G-mean: 0.0144
#     MCC: 0.0123
#     F1-score: 0.0125
#     mAP: 0.1245
#   [Original - MLP]
#     AUROC: 0.4361
#     G-mean: 0.0143
#     MCC: 0.0000
#     F1-score: 0.0100
#     mAP: 0.0801
#   [Original - RandomForest]
#     AUROC: 0.7087
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2184
#   [SMOTE - SVM]
#     AUROC: 0.6790
#     G-mean: 0.4963
#     MCC: 0.1161
#     F1-score: 0.1471
#     mAP: 0.1839
#   [SMOTE - DecisionTree]
#     AUROC: 0.5681
#     G-mean: 0.4863
#     MCC: 0.1224
#     F1-score: 0.1534
#     mAP: 0.1435
#   [SMOTE - kNN]
#     AUROC: 0.6929
#     G-mean: 0.6010
#     MCC: 0.1705
#     F1-score: 0.1843
#     mAP: 0.1473
#   [SMOTE - MLP]
#     AUROC: 0.7228
#     G-mean: 0.6099
#     MCC: 0.1507
#     F1-score: 0.1606
#     mAP: 0.2660
#   [SMOTE - RandomForest]
#     AUROC: 0.6801
#     G-mean: 0.2383
#     MCC: 0.1191
#     F1-score: 0.1431
#     mAP: 0.2127
#   [ADASYN - SVM]
#     AUROC: 0.6657
#     G-mean: 0.4923
#     MCC: 0.1087
#     F1-score: 0.1421
#     mAP: 0.1879
#   [ADASYN - DecisionTree]
#     AUROC: 0.5849
#     G-mean: 0.4225
#     MCC: 0.0961
#     F1-score: 0.1365
#     mAP: 0.1365
#   [ADASYN - kNN]
#     AUROC: 0.7005
#     G-mean: 0.6097
#     MCC: 0.1815
#     F1-score: 0.1908
#     mAP: 0.1404
#   [ADASYN - MLP]
#     AUROC: 0.7182
#     G-mean: 0.6156
#     MCC: 0.1473
#     F1-score: 0.1585
#     mAP: 0.2464
#   [ADASYN - RandomForest]
#     AUROC: 0.6857
#     G-mean: 0.2079
#     MCC: 0.0934
#     F1-score: 0.1191
#     mAP: 0.2028
#   [bSMOTE - SVM]
#     AUROC: 0.7067
#     G-mean: 0.4698
#     MCC: 0.1410
#     F1-score: 0.1725
#     mAP: 0.2174
#   [bSMOTE - DecisionTree]
#     AUROC: 0.5433
#     G-mean: 0.3818
#     MCC: 0.0820
#     F1-score: 0.1236
#     mAP: 0.0991
#   [bSMOTE - kNN]
#     AUROC: 0.6972
#     G-mean: 0.5786
#     MCC: 0.2064
#     F1-score: 0.2232
#     mAP: 0.1745
#   [bSMOTE - MLP]
#     AUROC: 0.7253
#     G-mean: 0.5792
#     MCC: 0.1589
#     F1-score: 0.1736
#     mAP: 0.2514
#   [bSMOTE - RandomForest]
#     AUROC: 0.7180
#     G-mean: 0.1634
#     MCC: 0.1001
#     F1-score: 0.1167
#     mAP: 0.2119
#   [ROS - SVM]
#     AUROC: 0.6798
#     G-mean: 0.4846
#     MCC: 0.1004
#     F1-score: 0.1365
#     mAP: 0.2338
#   [ROS - DecisionTree]
#     AUROC: 0.5484
#     G-mean: 0.3718
#     MCC: 0.0502
#     F1-score: 0.1034
#     mAP: 0.1031
#   [ROS - kNN]
#     AUROC: 0.6599
#     G-mean: 0.4383
#     MCC: 0.1413
#     F1-score: 0.1767
#     mAP: 0.1486
#   [ROS - MLP]
#     AUROC: 0.7067
#     G-mean: 0.6064
#     MCC: 0.1453
#     F1-score: 0.1576
#     mAP: 0.2465
#   [ROS - RandomForest]
#     AUROC: 0.7148
#     G-mean: 0.0289
#     MCC: 0.0246
#     F1-score: 0.0250
#     mAP: 0.2363
#   [MWMOTE - SVM]
#     AUROC: 0.6766
#     G-mean: 0.4282
#     MCC: 0.0960
#     F1-score: 0.1355
#     mAP: 0.1886
#   [MWMOTE - DecisionTree]
#     AUROC: 0.6049
#     G-mean: 0.4531
#     MCC: 0.1155
#     F1-score: 0.1417
#     mAP: 0.1236
#   [MWMOTE - kNN]
#     AUROC: 0.6626
#     G-mean: 0.5120
#     MCC: 0.1504
#     F1-score: 0.1756
#     mAP: 0.1327
#   [MWMOTE - MLP]
#     AUROC: 0.7157
#     G-mean: 0.5799
#     MCC: 0.1367
#     F1-score: 0.1554
#     mAP: 0.2673
#   [MWMOTE - RandomForest]
#     AUROC: 0.6976
#     G-mean: 0.1002
#     MCC: 0.0593
#     F1-score: 0.0726
#     mAP: 0.2165
#   [CTGAN - SVM]
#     AUROC: 0.6200
#     G-mean: 0.2880
#     MCC: 0.0712
#     F1-score: 0.1160
#     mAP: 0.1703
#   [CTGAN - DecisionTree]
#     AUROC: 0.6061
#     G-mean: 0.1004
#     MCC: 0.0591
#     F1-score: 0.0741
#     mAP: 0.1313
#   [CTGAN - kNN]
#     AUROC: 0.6302
#     G-mean: 0.2812
#     MCC: 0.0605
#     F1-score: 0.1057
#     mAP: 0.1115
#   [CTGAN - MLP]
#     AUROC: 0.6095
#     G-mean: 0.3433
#     MCC: 0.0548
#     F1-score: 0.1070
#     mAP: 0.1470
#   [CTGAN - RandomForest]
#     AUROC: 0.6869
#     G-mean: 0.0000
#     MCC: -0.0022
#     F1-score: 0.0000
#     mAP: 0.1901
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Original - SVM]
#     AUROC: 0.6339
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2761
#   [Original - DecisionTree]
#     AUROC: 0.6149
#     G-mean: 0.2095
#     MCC: 0.1034
#     F1-score: 0.1319
#     mAP: 0.1380
#   [Original - kNN]
#     AUROC: 0.6582
#     G-mean: 0.0115
#     MCC: 0.0088
#     F1-score: 0.0100
#     mAP: 0.1285
#   [Original - MLP]
#     AUROC: 0.4365
#     G-mean: 0.0115
#     MCC: -0.0046
#     F1-score: 0.0080
#     mAP: 0.0776
#   [Original - RandomForest]
#     AUROC: 0.7123
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2272
#   [SMOTE - SVM]
#     AUROC: 0.6803
#     G-mean: 0.5167
#     MCC: 0.1283
#     F1-score: 0.1574
#     mAP: 0.1958
#   [SMOTE - DecisionTree]
#     AUROC: 0.5700
#     G-mean: 0.4638
#     MCC: 0.1217
#     F1-score: 0.1560
#     mAP: 0.1524
#   [SMOTE - kNN]
#     AUROC: 0.6930
#     G-mean: 0.6039
#     MCC: 0.1715
#     F1-score: 0.1847
#     mAP: 0.1475
#   [SMOTE - MLP]
#     AUROC: 0.7174
#     G-mean: 0.6114
#     MCC: 0.1510
#     F1-score: 0.1602
#     mAP: 0.2644
#   [SMOTE - RandomForest]
#     AUROC: 0.6807
#     G-mean: 0.2297
#     MCC: 0.1191
#     F1-score: 0.1439
#     mAP: 0.2182
#   [ADASYN - SVM]
#     AUROC: 0.6668
#     G-mean: 0.5074
#     MCC: 0.1142
#     F1-score: 0.1470
#     mAP: 0.1976
#   [ADASYN - DecisionTree]
#     AUROC: 0.6021
#     G-mean: 0.4371
#     MCC: 0.1025
#     F1-score: 0.1428
#     mAP: 0.1593
#   [ADASYN - kNN]
#     AUROC: 0.6978
#     G-mean: 0.6218
#     MCC: 0.1835
#     F1-score: 0.1912
#     mAP: 0.1385
#   [ADASYN - MLP]
#     AUROC: 0.7162
#     G-mean: 0.6101
#     MCC: 0.1444
#     F1-score: 0.1565
#     mAP: 0.2498
#   [ADASYN - RandomForest]
#     AUROC: 0.6877
#     G-mean: 0.2120
#     MCC: 0.1007
#     F1-score: 0.1266
#     mAP: 0.2068
#   [bSMOTE - SVM]
#     AUROC: 0.7070
#     G-mean: 0.4927
#     MCC: 0.1594
#     F1-score: 0.1883
#     mAP: 0.2293
#   [bSMOTE - DecisionTree]
#     AUROC: 0.5472
#     G-mean: 0.3682
#     MCC: 0.0818
#     F1-score: 0.1240
#     mAP: 0.1011
#   [bSMOTE - kNN]
#     AUROC: 0.6994
#     G-mean: 0.5877
#     MCC: 0.2096
#     F1-score: 0.2248
#     mAP: 0.1729
#   [bSMOTE - MLP]
#     AUROC: 0.7242
#     G-mean: 0.5758
#     MCC: 0.1614
#     F1-score: 0.1765
#     mAP: 0.2512
#   [bSMOTE - RandomForest]
#     AUROC: 0.7142
#     G-mean: 0.1534
#     MCC: 0.0885
#     F1-score: 0.1057
#     mAP: 0.2059
#   [ROS - SVM]
#     AUROC: 0.6834
#     G-mean: 0.5091
#     MCC: 0.1152
#     F1-score: 0.1472
#     mAP: 0.2479
#   [ROS - DecisionTree]
#     AUROC: 0.5494
#     G-mean: 0.3723
#     MCC: 0.0499
#     F1-score: 0.1031
#     mAP: 0.1016
#   [ROS - kNN]
#     AUROC: 0.6647
#     G-mean: 0.4516
#     MCC: 0.1462
#     F1-score: 0.1806
#     mAP: 0.1501
#   [ROS - MLP]
#     AUROC: 0.7045
#     G-mean: 0.6061
#     MCC: 0.1449
#     F1-score: 0.1555
#     mAP: 0.2434
#   [ROS - RandomForest]
#     AUROC: 0.7187
#     G-mean: 0.0346
#     MCC: 0.0305
#     F1-score: 0.0300
#     mAP: 0.2511
#   [MWMOTE - SVM]
#     AUROC: 0.6768
#     G-mean: 0.4485
#     MCC: 0.1083
#     F1-score: 0.1462
#     mAP: 0.1979
#   [MWMOTE - DecisionTree]
#     AUROC: 0.6004
#     G-mean: 0.4564
#     MCC: 0.1107
#     F1-score: 0.1385
#     mAP: 0.1150
#   [MWMOTE - kNN]
#     AUROC: 0.6705
#     G-mean: 0.5149
#     MCC: 0.1519
#     F1-score: 0.1768
#     mAP: 0.1322
#   [MWMOTE - MLP]
#     AUROC: 0.7149
#     G-mean: 0.5838
#     MCC: 0.1376
#     F1-score: 0.1550
#     mAP: 0.2664
#   [MWMOTE - RandomForest]
#     AUROC: 0.7005
#     G-mean: 0.1257
#     MCC: 0.0717
#     F1-score: 0.0865
#     mAP: 0.2208
#   [CTGAN - SVM]
#     AUROC: 0.6198
#     G-mean: 0.2949
#     MCC: 0.0819
#     F1-score: 0.1242
#     mAP: 0.1797
#   [CTGAN - DecisionTree]
#     AUROC: 0.5938
#     G-mean: 0.0803
#     MCC: 0.0436
#     F1-score: 0.0593
#     mAP: 0.1263
#   [CTGAN - kNN]
#     AUROC: 0.6252
#     G-mean: 0.2833
#     MCC: 0.0605
#     F1-score: 0.1054
#     mAP: 0.1140
#   [CTGAN - MLP]
#     AUROC: 0.6058
#     G-mean: 0.3401
#     MCC: 0.0588
#     F1-score: 0.1093
#     mAP: 0.1432
#   [CTGAN - RandomForest]
#     AUROC: 0.6872
#     G-mean: 0.0000
#     MCC: -0.0023
#     F1-score: 0.0000
#     mAP: 0.1966
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Original - SVM]
#     AUROC: 0.6364
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2830
#   [Original - DecisionTree]
#     AUROC: 0.6127
#     G-mean: 0.1937
#     MCC: 0.0962
#     F1-score: 0.1238
#     mAP: 0.1362
#   [Original - kNN]
#     AUROC: 0.6566
#     G-mean: 0.0096
#     MCC: 0.0065
#     F1-score: 0.0083
#     mAP: 0.1280
#   [Original - MLP]
#     AUROC: 0.4365
#     G-mean: 0.0095
#     MCC: -0.0058
#     F1-score: 0.0067
#     mAP: 0.0756
#   [Original - RandomForest]
#     AUROC: 0.7158
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2268
#   [SMOTE - SVM]
#     AUROC: 0.6827
#     G-mean: 0.5309
#     MCC: 0.1313
#     F1-score: 0.1602
#     mAP: 0.1974
#   [SMOTE - DecisionTree]
#     AUROC: 0.5730
#     G-mean: 0.4743
#     MCC: 0.1206
#     F1-score: 0.1544
#     mAP: 0.1464
#   [SMOTE - kNN]
#     AUROC: 0.6933
#     G-mean: 0.6109
#     MCC: 0.1708
#     F1-score: 0.1843
#     mAP: 0.1470
#   [SMOTE - MLP]
#     AUROC: 0.7180
#     G-mean: 0.6074
#     MCC: 0.1468
#     F1-score: 0.1569
#     mAP: 0.2609
#   [SMOTE - RandomForest]
#     AUROC: 0.6812
#     G-mean: 0.2293
#     MCC: 0.1162
#     F1-score: 0.1419
#     mAP: 0.2139
#   [ADASYN - SVM]
#     AUROC: 0.6681
#     G-mean: 0.5226
#     MCC: 0.1184
#     F1-score: 0.1501
#     mAP: 0.1972
#   [ADASYN - DecisionTree]
#     AUROC: 0.6000
#     G-mean: 0.4416
#     MCC: 0.1027
#     F1-score: 0.1419
#     mAP: 0.1561
#   [ADASYN - kNN]
#     AUROC: 0.6986
#     G-mean: 0.6317
#     MCC: 0.1857
#     F1-score: 0.1930
#     mAP: 0.1414
#   [ADASYN - MLP]
#     AUROC: 0.7153
#     G-mean: 0.6116
#     MCC: 0.1408
#     F1-score: 0.1538
#     mAP: 0.2499
#   [ADASYN - RandomForest]
#     AUROC: 0.6878
#     G-mean: 0.1955
#     MCC: 0.0882
#     F1-score: 0.1159
#     mAP: 0.2028
#   [bSMOTE - SVM]
#     AUROC: 0.7062
#     G-mean: 0.5050
#     MCC: 0.1609
#     F1-score: 0.1893
#     mAP: 0.2211
#   [bSMOTE - DecisionTree]
#     AUROC: 0.5411
#     G-mean: 0.3614
#     MCC: 0.0735
#     F1-score: 0.1167
#     mAP: 0.0984
#   [bSMOTE - kNN]
#     AUROC: 0.6970
#     G-mean: 0.5930
#     MCC: 0.2109
#     F1-score: 0.2268
#     mAP: 0.1737
#   [bSMOTE - MLP]
#     AUROC: 0.7260
#     G-mean: 0.5746
#     MCC: 0.1584
#     F1-score: 0.1743
#     mAP: 0.2521
#   [bSMOTE - RandomForest]
#     AUROC: 0.7115
#     G-mean: 0.1374
#     MCC: 0.0758
#     F1-score: 0.0948
#     mAP: 0.2013
#   [ROS - SVM]
#     AUROC: 0.6835
#     G-mean: 0.5108
#     MCC: 0.1160
#     F1-score: 0.1484
#     mAP: 0.2411
#   [ROS - DecisionTree]
#     AUROC: 0.5465
#     G-mean: 0.3572
#     MCC: 0.0435
#     F1-score: 0.0980
#     mAP: 0.0952
#   [ROS - kNN]
#     AUROC: 0.6639
#     G-mean: 0.4701
#     MCC: 0.1555
#     F1-score: 0.1893
#     mAP: 0.1498
#   [ROS - MLP]
#     AUROC: 0.7082
#     G-mean: 0.6171
#     MCC: 0.1499
#     F1-score: 0.1585
#     mAP: 0.2461
#   [ROS - RandomForest]
#     AUROC: 0.7191
#     G-mean: 0.0385
#     MCC: 0.0345
#     F1-score: 0.0333
#     mAP: 0.2491
#   [MWMOTE - SVM]
#     AUROC: 0.6787
#     G-mean: 0.4588
#     MCC: 0.1075
#     F1-score: 0.1456
#     mAP: 0.1958
#   [MWMOTE - DecisionTree]
#     AUROC: 0.5880
#     G-mean: 0.4411
#     MCC: 0.1036
#     F1-score: 0.1356
#     mAP: 0.1095
#   [MWMOTE - kNN]
#     AUROC: 0.6738
#     G-mean: 0.5206
#     MCC: 0.1514
#     F1-score: 0.1777
#     mAP: 0.1374
#   [MWMOTE - MLP]
#     AUROC: 0.7173
#     G-mean: 0.5833
#     MCC: 0.1346
#     F1-score: 0.1518
#     mAP: 0.2662
#   [MWMOTE - RandomForest]
#     AUROC: 0.6993
#     G-mean: 0.1239
#     MCC: 0.0713
#     F1-score: 0.0860
#     mAP: 0.2207
#   [CTGAN - SVM]
#     AUROC: 0.6231
#     G-mean: 0.2737
#     MCC: 0.0708
#     F1-score: 0.1156
#     mAP: 0.1736
#   [CTGAN - DecisionTree]
#     AUROC: 0.5900
#     G-mean: 0.0764
#     MCC: 0.0384
#     F1-score: 0.0550
#     mAP: 0.1237
#   [CTGAN - kNN]
#     AUROC: 0.6205
#     G-mean: 0.2824
#     MCC: 0.0617
#     F1-score: 0.1082
#     mAP: 0.1112
#   [CTGAN - MLP]
#     AUROC: 0.6026
#     G-mean: 0.3093
#     MCC: 0.0427
#     F1-score: 0.0970
#     mAP: 0.1419
#   [CTGAN - RandomForest]
#     AUROC: 0.6874
#     G-mean: 0.0000
#     MCC: -0.0028
#     F1-score: 0.0000
#     mAP: 0.1944
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Original - SVM]
#     AUROC: 0.6430
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2845
#   [Original - DecisionTree]
#     AUROC: 0.6102
#     G-mean: 0.1900
#     MCC: 0.0896
#     F1-score: 0.1182
#     mAP: 0.1320
#   [Original - kNN]
#     AUROC: 0.6596
#     G-mean: 0.0082
#     MCC: 0.0048
#     F1-score: 0.0071
#     mAP: 0.1291
#   [Original - MLP]
#     AUROC: 0.4369
#     G-mean: 0.0082
#     MCC: -0.0069
#     F1-score: 0.0057
#     mAP: 0.0785
#   [Original - RandomForest]
#     AUROC: 0.7170
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2293
#   [SMOTE - SVM]
#     AUROC: 0.6867
#     G-mean: 0.5392
#     MCC: 0.1352
#     F1-score: 0.1623
#     mAP: 0.1941
#   [SMOTE - DecisionTree]
#     AUROC: 0.5791
#     G-mean: 0.4708
#     MCC: 0.1191
#     F1-score: 0.1537
#     mAP: 0.1500
#   [SMOTE - kNN]
#     AUROC: 0.6959
#     G-mean: 0.6150
#     MCC: 0.1745
#     F1-score: 0.1860
#     mAP: 0.1450
#   [SMOTE - MLP]
#     AUROC: 0.7195
#     G-mean: 0.6199
#     MCC: 0.1530
#     F1-score: 0.1602
#     mAP: 0.2537
#   [SMOTE - RandomForest]
#     AUROC: 0.6863
#     G-mean: 0.2484
#     MCC: 0.1266
#     F1-score: 0.1524
#     mAP: 0.2170
#   [ADASYN - SVM]
#     AUROC: 0.6719
#     G-mean: 0.5279
#     MCC: 0.1198
#     F1-score: 0.1504
#     mAP: 0.1974
#   [ADASYN - DecisionTree]
#     AUROC: 0.6055
#     G-mean: 0.4523
#     MCC: 0.1111
#     F1-score: 0.1483
#     mAP: 0.1625
#   [ADASYN - kNN]
#     AUROC: 0.7020
#     G-mean: 0.6379
#     MCC: 0.1870
#     F1-score: 0.1935
#     mAP: 0.1408
#   [ADASYN - MLP]
#     AUROC: 0.7167
#     G-mean: 0.6197
#     MCC: 0.1452
#     F1-score: 0.1562
#     mAP: 0.2480
#   [ADASYN - RandomForest]
#     AUROC: 0.6921
#     G-mean: 0.1998
#     MCC: 0.0873
#     F1-score: 0.1160
#     mAP: 0.2027
#   [bSMOTE - SVM]
#     AUROC: 0.7045
#     G-mean: 0.5061
#     MCC: 0.1604
#     F1-score: 0.1880
#     mAP: 0.2168
#   [bSMOTE - DecisionTree]
#     AUROC: 0.5484
#     G-mean: 0.3730
#     MCC: 0.0815
#     F1-score: 0.1237
#     mAP: 0.1025
#   [bSMOTE - kNN]
#     AUROC: 0.6985
#     G-mean: 0.5926
#     MCC: 0.2124
#     F1-score: 0.2270
#     mAP: 0.1750
#   [bSMOTE - MLP]
#     AUROC: 0.7245
#     G-mean: 0.5747
#     MCC: 0.1593
#     F1-score: 0.1760
#     mAP: 0.2467
#   [bSMOTE - RandomForest]
#     AUROC: 0.7127
#     G-mean: 0.1259
#     MCC: 0.0667
#     F1-score: 0.0860
#     mAP: 0.1996
#   [ROS - SVM]
#     AUROC: 0.6860
#     G-mean: 0.5040
#     MCC: 0.1138
#     F1-score: 0.1461
#     mAP: 0.2365
#   [ROS - DecisionTree]
#     AUROC: 0.5495
#     G-mean: 0.3615
#     MCC: 0.0464
#     F1-score: 0.0993
#     mAP: 0.0940
#   [ROS - kNN]
#     AUROC: 0.6678
#     G-mean: 0.4850
#     MCC: 0.1621
#     F1-score: 0.1936
#     mAP: 0.1515
#   [ROS - MLP]
#     AUROC: 0.7094
#     G-mean: 0.6209
#     MCC: 0.1498
#     F1-score: 0.1583
#     mAP: 0.2407
#   [ROS - RandomForest]
#     AUROC: 0.7208
#     G-mean: 0.0412
#     MCC: 0.0370
#     F1-score: 0.0357
#     mAP: 0.2485
#   [MWMOTE - SVM]
#     AUROC: 0.6818
#     G-mean: 0.4670
#     MCC: 0.1103
#     F1-score: 0.1462
#     mAP: 0.1976
#   [MWMOTE - DecisionTree]
#     AUROC: 0.5924
#     G-mean: 0.4553
#     MCC: 0.1074
#     F1-score: 0.1388
#     mAP: 0.1168
#   [MWMOTE - kNN]
#     AUROC: 0.6765
#     G-mean: 0.5347
#     MCC: 0.1588
#     F1-score: 0.1824
#     mAP: 0.1375
#   [MWMOTE - MLP]
#     AUROC: 0.7188
#     G-mean: 0.5853
#     MCC: 0.1356
#     F1-score: 0.1515
#     mAP: 0.2567
#   [MWMOTE - RandomForest]
#     AUROC: 0.7011
#     G-mean: 0.1387
#     MCC: 0.0807
#     F1-score: 0.0947
#     mAP: 0.2274
#   [CTGAN - SVM]
#     AUROC: 0.6264
#     G-mean: 0.2824
#     MCC: 0.0749
#     F1-score: 0.1203
#     mAP: 0.1733
#   [CTGAN - DecisionTree]
#     AUROC: 0.5876
#     G-mean: 0.0735
#     MCC: 0.0323
#     F1-score: 0.0507
#     mAP: 0.1192
#   [CTGAN - kNN]
#     AUROC: 0.6219
#     G-mean: 0.3047
#     MCC: 0.0716
#     F1-score: 0.1170
#     mAP: 0.1162
#   [CTGAN - MLP]
#     AUROC: 0.6051
#     G-mean: 0.3233
#     MCC: 0.0475
#     F1-score: 0.1018
#     mAP: 0.1440
#   [CTGAN - RandomForest]
#     AUROC: 0.6920
#     G-mean: 0.0000
#     MCC: -0.0027
#     F1-score: 0.0000
#     mAP: 0.1952
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Original - SVM]
#     AUROC: 0.6405
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2854
#   [Original - DecisionTree]
#     AUROC: 0.6004
#     G-mean: 0.1734
#     MCC: 0.0782
#     F1-score: 0.1076
#     mAP: 0.1264
#   [Original - kNN]
#     AUROC: 0.6540
#     G-mean: 0.0144
#     MCC: 0.0113
#     F1-score: 0.0125
#     mAP: 0.1272
#   [Original - MLP]
#     AUROC: 0.4363
#     G-mean: 0.0072
#     MCC: -0.0070
#     F1-score: 0.0050
#     mAP: 0.0797
#   [Original - RandomForest]
#     AUROC: 0.7147
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2263
#   [SMOTE - SVM]
#     AUROC: 0.6783
#     G-mean: 0.5298
#     MCC: 0.1320
#     F1-score: 0.1598
#     mAP: 0.1917
#   [SMOTE - DecisionTree]
#     AUROC: 0.5758
#     G-mean: 0.4655
#     MCC: 0.1161
#     F1-score: 0.1514
#     mAP: 0.1480
#   [SMOTE - kNN]
#     AUROC: 0.6850
#     G-mean: 0.5950
#     MCC: 0.1660
#     F1-score: 0.1796
#     mAP: 0.1411
#   [SMOTE - MLP]
#     AUROC: 0.7160
#     G-mean: 0.6193
#     MCC: 0.1521
#     F1-score: 0.1603
#     mAP: 0.2508
#   [SMOTE - RandomForest]
#     AUROC: 0.6798
#     G-mean: 0.2385
#     MCC: 0.1207
#     F1-score: 0.1455
#     mAP: 0.2146
#   [ADASYN - SVM]
#     AUROC: 0.6635
#     G-mean: 0.5195
#     MCC: 0.1180
#     F1-score: 0.1487
#     mAP: 0.1941
#   [ADASYN - DecisionTree]
#     AUROC: 0.6027
#     G-mean: 0.4446
#     MCC: 0.1097
#     F1-score: 0.1464
#     mAP: 0.1594
#   [ADASYN - kNN]
#     AUROC: 0.6927
#     G-mean: 0.6111
#     MCC: 0.1766
#     F1-score: 0.1860
#     mAP: 0.1381
#   [ADASYN - MLP]
#     AUROC: 0.7141
#     G-mean: 0.6108
#     MCC: 0.1429
#     F1-score: 0.1550
#     mAP: 0.2450
#   [ADASYN - RandomForest]
#     AUROC: 0.6838
#     G-mean: 0.1959
#     MCC: 0.0852
#     F1-score: 0.1130
#     mAP: 0.1981
#   [bSMOTE - SVM]
#     AUROC: 0.7024
#     G-mean: 0.5051
#     MCC: 0.1628
#     F1-score: 0.1892
#     mAP: 0.2173
#   [bSMOTE - DecisionTree]
#     AUROC: 0.5456
#     G-mean: 0.3628
#     MCC: 0.0801
#     F1-score: 0.1222
#     mAP: 0.1031
#   [bSMOTE - kNN]
#     AUROC: 0.6928
#     G-mean: 0.5779
#     MCC: 0.2050
#     F1-score: 0.2212
#     mAP: 0.1710
#   [bSMOTE - MLP]
#     AUROC: 0.7227
#     G-mean: 0.5647
#     MCC: 0.1558
#     F1-score: 0.1730
#     mAP: 0.2418
#   [bSMOTE - RandomForest]
#     AUROC: 0.7047
#     G-mean: 0.1304
#     MCC: 0.0732
#     F1-score: 0.0924
#     mAP: 0.2016
#   [ROS - SVM]
#     AUROC: 0.6811
#     G-mean: 0.4943
#     MCC: 0.1119
#     F1-score: 0.1437
#     mAP: 0.2326
#   [ROS - DecisionTree]
#     AUROC: 0.5475
#     G-mean: 0.3595
#     MCC: 0.0453
#     F1-score: 0.0985
#     mAP: 0.0946
#   [ROS - kNN]
#     AUROC: 0.6620
#     G-mean: 0.4658
#     MCC: 0.1540
#     F1-score: 0.1861
#     mAP: 0.1488
#   [ROS - MLP]
#     AUROC: 0.7088
#     G-mean: 0.6126
#     MCC: 0.1469
#     F1-score: 0.1561
#     mAP: 0.2377
#   [ROS - RandomForest]
#     AUROC: 0.7178
#     G-mean: 0.0433
#     MCC: 0.0394
#     F1-score: 0.0375
#     mAP: 0.2456
#   [MWMOTE - SVM]
#     AUROC: 0.6744
#     G-mean: 0.4596
#     MCC: 0.1051
#     F1-score: 0.1427
#     mAP: 0.2019
#   [MWMOTE - DecisionTree]
#     AUROC: 0.5966
#     G-mean: 0.4561
#     MCC: 0.1064
#     F1-score: 0.1373
#     mAP: 0.1177
#   [MWMOTE - kNN]
#     AUROC: 0.6720
#     G-mean: 0.5257
#     MCC: 0.1547
#     F1-score: 0.1778
#     mAP: 0.1378
#   [MWMOTE - MLP]
#     AUROC: 0.7164
#     G-mean: 0.5788
#     MCC: 0.1329
#     F1-score: 0.1500
#     mAP: 0.2520
#   [MWMOTE - RandomForest]
#     AUROC: 0.6961
#     G-mean: 0.1358
#     MCC: 0.0827
#     F1-score: 0.0954
#     mAP: 0.2271
#   [CTGAN - SVM]
#     AUROC: 0.6375
#     G-mean: 0.2817
#     MCC: 0.0746
#     F1-score: 0.1201
#     mAP: 0.1742
#   [CTGAN - DecisionTree]
#     AUROC: 0.5938
#     G-mean: 0.0715
#     MCC: 0.0335
#     F1-score: 0.0506
#     mAP: 0.1251
#   [CTGAN - kNN]
#     AUROC: 0.6220
#     G-mean: 0.3042
#     MCC: 0.0752
#     F1-score: 0.1202
#     mAP: 0.1161
#   [CTGAN - MLP]
#     AUROC: 0.6115
#     G-mean: 0.3282
#     MCC: 0.0517
#     F1-score: 0.1050
#     mAP: 0.1435
#   [CTGAN - RandomForest]
#     AUROC: 0.6912
#     G-mean: 0.0000
#     MCC: -0.0024
#     F1-score: 0.0000
#     mAP: 0.1924
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Original - SVM]
#     AUROC: 0.6365
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2804
#   [Original - DecisionTree]
#     AUROC: 0.6030
#     G-mean: 0.1757
#     MCC: 0.0799
#     F1-score: 0.1096
#     mAP: 0.1288
#   [Original - kNN]
#     AUROC: 0.6528
#     G-mean: 0.0192
#     MCC: 0.0161
#     F1-score: 0.0167
#     mAP: 0.1277
#   [Original - MLP]
#     AUROC: 0.4364
#     G-mean: 0.0064
#     MCC: -0.0083
#     F1-score: 0.0044
#     mAP: 0.0792
#   [Original - RandomForest]
#     AUROC: 0.7113
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2256
#   [SMOTE - SVM]
#     AUROC: 0.6761
#     G-mean: 0.5239
#     MCC: 0.1296
#     F1-score: 0.1575
#     mAP: 0.1912
#   [SMOTE - DecisionTree]
#     AUROC: 0.5793
#     G-mean: 0.4605
#     MCC: 0.1153
#     F1-score: 0.1503
#     mAP: 0.1482
#   [SMOTE - kNN]
#     AUROC: 0.6852
#     G-mean: 0.5868
#     MCC: 0.1648
#     F1-score: 0.1787
#     mAP: 0.1397
#   [SMOTE - MLP]
#     AUROC: 0.7153
#     G-mean: 0.6093
#     MCC: 0.1466
#     F1-score: 0.1572
#     mAP: 0.2452
#   [SMOTE - RandomForest]
#     AUROC: 0.6762
#     G-mean: 0.2336
#     MCC: 0.1170
#     F1-score: 0.1437
#     mAP: 0.2134
#   [ADASYN - SVM]
#     AUROC: 0.6623
#     G-mean: 0.5145
#     MCC: 0.1165
#     F1-score: 0.1473
#     mAP: 0.1937
#   [ADASYN - DecisionTree]
#     AUROC: 0.5995
#     G-mean: 0.4375
#     MCC: 0.1078
#     F1-score: 0.1444
#     mAP: 0.1574
#   [ADASYN - kNN]
#     AUROC: 0.6913
#     G-mean: 0.6032
#     MCC: 0.1753
#     F1-score: 0.1853
#     mAP: 0.1364
#   [ADASYN - MLP]
#     AUROC: 0.7129
#     G-mean: 0.6065
#     MCC: 0.1423
#     F1-score: 0.1542
#     mAP: 0.2387
#   [ADASYN - RandomForest]
#     AUROC: 0.6799
#     G-mean: 0.1958
#     MCC: 0.0874
#     F1-score: 0.1160
#     mAP: 0.1988
#   [bSMOTE - SVM]
#     AUROC: 0.7023
#     G-mean: 0.4941
#     MCC: 0.1575
#     F1-score: 0.1846
#     mAP: 0.2130
#   [bSMOTE - DecisionTree]
#     AUROC: 0.5441
#     G-mean: 0.3593
#     MCC: 0.0795
#     F1-score: 0.1225
#     mAP: 0.1078
#   [bSMOTE - kNN]
#     AUROC: 0.6936
#     G-mean: 0.5719
#     MCC: 0.2037
#     F1-score: 0.2203
#     mAP: 0.1707
#   [bSMOTE - MLP]
#     AUROC: 0.7223
#     G-mean: 0.5626
#     MCC: 0.1536
#     F1-score: 0.1715
#     mAP: 0.2410
#   [bSMOTE - RandomForest]
#     AUROC: 0.7019
#     G-mean: 0.1222
#     MCC: 0.0648
#     F1-score: 0.0853
#     mAP: 0.2007
#   [ROS - SVM]
#     AUROC: 0.6768
#     G-mean: 0.4915
#     MCC: 0.1116
#     F1-score: 0.1439
#     mAP: 0.2251
#   [ROS - DecisionTree]
#     AUROC: 0.5439
#     G-mean: 0.3568
#     MCC: 0.0438
#     F1-score: 0.0989
#     mAP: 0.0957
#   [ROS - kNN]
#     AUROC: 0.6597
#     G-mean: 0.4515
#     MCC: 0.1475
#     F1-score: 0.1803
#     mAP: 0.1437
#   [ROS - MLP]
#     AUROC: 0.7078
#     G-mean: 0.6051
#     MCC: 0.1434
#     F1-score: 0.1542
#     mAP: 0.2356
#   [ROS - RandomForest]
#     AUROC: 0.7129
#     G-mean: 0.0449
#     MCC: 0.0410
#     F1-score: 0.0389
#     mAP: 0.2385
#   [MWMOTE - SVM]
#     AUROC: 0.6749
#     G-mean: 0.4599
#     MCC: 0.1054
#     F1-score: 0.1425
#     mAP: 0.2012
#   [MWMOTE - DecisionTree]
#     AUROC: 0.5943
#     G-mean: 0.4650
#     MCC: 0.1099
#     F1-score: 0.1396
#     mAP: 0.1215
#   [MWMOTE - kNN]
#     AUROC: 0.6739
#     G-mean: 0.5236
#     MCC: 0.1566
#     F1-score: 0.1801
#     mAP: 0.1392
#   [MWMOTE - MLP]
#     AUROC: 0.7172
#     G-mean: 0.5793
#     MCC: 0.1348
#     F1-score: 0.1507
#     mAP: 0.2488
#   [MWMOTE - RandomForest]
#     AUROC: 0.6932
#     G-mean: 0.1336
#     MCC: 0.0836
#     F1-score: 0.0959
#     mAP: 0.2260
#   [CTGAN - SVM]
#     AUROC: 0.6399
#     G-mean: 0.3002
#     MCC: 0.0860
#     F1-score: 0.1300
#     mAP: 0.1876
#   [CTGAN - DecisionTree]
#     AUROC: 0.5923
#     G-mean: 0.0761
#     MCC: 0.0332
#     F1-score: 0.0513
#     mAP: 0.1260
#   [CTGAN - kNN]
#     AUROC: 0.6273
#     G-mean: 0.3106
#     MCC: 0.0821
#     F1-score: 0.1259
#     mAP: 0.1215
#   [CTGAN - MLP]
#     AUROC: 0.6156
#     G-mean: 0.3517
#     MCC: 0.0626
#     F1-score: 0.1125
#     mAP: 0.1497
#   [CTGAN - RandomForest]
#     AUROC: 0.6898
#     G-mean: 0.0000
#     MCC: -0.0024
#     F1-score: 0.0000
#     mAP: 0.1943
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Original - SVM]
#     AUROC: 0.6389
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2844
#   [Original - DecisionTree]
#     AUROC: 0.6022
#     G-mean: 0.1752
#     MCC: 0.0783
#     F1-score: 0.1086
#     mAP: 0.1284
#   [Original - kNN]
#     AUROC: 0.6549
#     G-mean: 0.0231
#     MCC: 0.0199
#     F1-score: 0.0200
#     mAP: 0.1301
#   [Original - MLP]
#     AUROC: 0.4360
#     G-mean: 0.0057
#     MCC: -0.0086
#     F1-score: 0.0040
#     mAP: 0.0779
#   [Original - RandomForest]
#     AUROC: 0.7142
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.2291
#   [SMOTE - SVM]
#     AUROC: 0.6777
#     G-mean: 0.5295
#     MCC: 0.1291
#     F1-score: 0.1572
#     mAP: 0.1933
#   [SMOTE - DecisionTree]
#     AUROC: 0.5847
#     G-mean: 0.4659
#     MCC: 0.1207
#     F1-score: 0.1539
#     mAP: 0.1527
#   [SMOTE - kNN]
#     AUROC: 0.6867
#     G-mean: 0.5886
#     MCC: 0.1642
#     F1-score: 0.1779
#     mAP: 0.1384
#   [SMOTE - MLP]
#     AUROC: 0.7151
#     G-mean: 0.6118
#     MCC: 0.1483
#     F1-score: 0.1581
#     mAP: 0.2475
#   [SMOTE - RandomForest]
#     AUROC: 0.6781
#     G-mean: 0.2392
#     MCC: 0.1206
#     F1-score: 0.1474
#     mAP: 0.2167
#   [ADASYN - SVM]
#     AUROC: 0.6631
#     G-mean: 0.5231
#     MCC: 0.1188
#     F1-score: 0.1490
#     mAP: 0.1931
#   [ADASYN - DecisionTree]
#     AUROC: 0.6013
#     G-mean: 0.4382
#     MCC: 0.1105
#     F1-score: 0.1462
#     mAP: 0.1594
#   [ADASYN - kNN]
#     AUROC: 0.6935
#     G-mean: 0.6046
#     MCC: 0.1738
#     F1-score: 0.1836
#     mAP: 0.1344
#   [ADASYN - MLP]
#     AUROC: 0.7137
#     G-mean: 0.6042
#     MCC: 0.1402
#     F1-score: 0.1525
#     mAP: 0.2407
#   [ADASYN - RandomForest]
#     AUROC: 0.6816
#     G-mean: 0.1995
#     MCC: 0.0901
#     F1-score: 0.1184
#     mAP: 0.2037
#   [bSMOTE - SVM]
#     AUROC: 0.7018
#     G-mean: 0.5023
#     MCC: 0.1606
#     F1-score: 0.1877
#     mAP: 0.2126
#   [bSMOTE - DecisionTree]
#     AUROC: 0.5505
#     G-mean: 0.3580
#     MCC: 0.0788
#     F1-score: 0.1226
#     mAP: 0.1078
#   [bSMOTE - kNN]
#     AUROC: 0.6946
#     G-mean: 0.5700
#     MCC: 0.2009
#     F1-score: 0.2177
#     mAP: 0.1681
#   [bSMOTE - MLP]
#     AUROC: 0.7221
#     G-mean: 0.5638
#     MCC: 0.1540
#     F1-score: 0.1727
#     mAP: 0.2464
#   [bSMOTE - RandomForest]
#     AUROC: 0.7033
#     G-mean: 0.1408
#     MCC: 0.0790
#     F1-score: 0.0980
#     mAP: 0.2045
#   [ROS - SVM]
#     AUROC: 0.6781
#     G-mean: 0.4940
#     MCC: 0.1106
#     F1-score: 0.1439
#     mAP: 0.2230
#   [ROS - DecisionTree]
#     AUROC: 0.5447
#     G-mean: 0.3569
#     MCC: 0.0455
#     F1-score: 0.0996
#     mAP: 0.0940
#   [ROS - kNN]
#     AUROC: 0.6620
#     G-mean: 0.4573
#     MCC: 0.1460
#     F1-score: 0.1793
#     mAP: 0.1454
#   [ROS - MLP]
#     AUROC: 0.7087
#     G-mean: 0.6053
#     MCC: 0.1431
#     F1-score: 0.1537
#     mAP: 0.2392
#   [ROS - RandomForest]
#     AUROC: 0.7136
#     G-mean: 0.0462
#     MCC: 0.0423
#     F1-score: 0.0400
#     mAP: 0.2377
#   [MWMOTE - SVM]
#     AUROC: 0.6763
#     G-mean: 0.4660
#     MCC: 0.1067
#     F1-score: 0.1442
#     mAP: 0.2016
#   [MWMOTE - DecisionTree]
#     AUROC: 0.5919
#     G-mean: 0.4629
#     MCC: 0.1069
#     F1-score: 0.1377
#     mAP: 0.1187
#   [MWMOTE - kNN]
#     AUROC: 0.6760
#     G-mean: 0.5230
#     MCC: 0.1524
#     F1-score: 0.1771
#     mAP: 0.1391
#   [MWMOTE - MLP]
#     AUROC: 0.7171
#     G-mean: 0.5787
#     MCC: 0.1342
#     F1-score: 0.1508
#     mAP: 0.2505
#   [MWMOTE - RandomForest]
#     AUROC: 0.6903
#     G-mean: 0.1316
#     MCC: 0.0795
#     F1-score: 0.0931
#     mAP: 0.2201
#   [CTGAN - SVM]
#     AUROC: 0.6384
#     G-mean: 0.2965
#     MCC: 0.0852
#     F1-score: 0.1292
#     mAP: 0.1898
#   [CTGAN - DecisionTree]
#     AUROC: 0.5933
#     G-mean: 0.0685
#     MCC: 0.0286
#     F1-score: 0.0462
#     mAP: 0.1226
#   [CTGAN - kNN]
#     AUROC: 0.6301
#     G-mean: 0.3116
#     MCC: 0.0825
#     F1-score: 0.1265
#     mAP: 0.1240
#   [CTGAN - MLP]
#     AUROC: 0.6152
#     G-mean: 0.3546
#     MCC: 0.0652
#     F1-score: 0.1143
#     mAP: 0.1499
#   [CTGAN - RandomForest]
#     AUROC: 0.6927
#     G-mean: 0.0000
#     MCC: -0.0022
#     F1-score: 0.0000
#     mAP: 0.1963
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/classifiers/yeast-1-4-5-8_vs_7_results_gaussian_beta_0.1.csv

# %%
data_name = 'yeast4'

# 실험 파라미터 설정
n_epochs = 2000
hidden_dims = [8, 16, 32, 64]
latent_dim = 128
lr = 0.001
beta = 0.1

# 데이터 불러오기
yeast4 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# Run experiment
final_results = run_exp(
    data=yeast4, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (1484, 8)
# target : Counter({0: 1433, 1: 51})
# IR: 28.1
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Original - SVM]
#     AUROC: 0.8470
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.4682
#   [Original - DecisionTree]
#     AUROC: 0.7331
#     G-mean: 0.4872
#     MCC: 0.3185
#     F1-score: 0.3288
#     mAP: 0.2446
#   [Original - kNN]
#     AUROC: 0.7500
#     G-mean: 0.3884
#     MCC: 0.3159
#     F1-score: 0.2801
#     mAP: 0.2758
#   [Original - MLP]
#     AUROC: 0.3557
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0319
#   [Original - RandomForest]
#     AUROC: 0.9163
#     G-mean: 0.2680
#     MCC: 0.2306
#     F1-score: 0.1905
#     mAP: 0.4566
#   [SMOTE - SVM]
#     AUROC: 0.8925
#     G-mean: 0.7586
#     MCC: 0.3157
#     F1-score: 0.2933
#     mAP: 0.4066
#   [SMOTE - DecisionTree]
#     AUROC: 0.8048
#     G-mean: 0.6921
#     MCC: 0.2746
#     F1-score: 0.2670
#     mAP: 0.2753
#   [SMOTE - kNN]
#     AUROC: 0.8206
#     G-mean: 0.7582
#     MCC: 0.3323
#     F1-score: 0.3164
#     mAP: 0.2320
#   [SMOTE - MLP]
#     AUROC: 0.8667
#     G-mean: 0.8081
#     MCC: 0.3461
#     F1-score: 0.3077
#     mAP: 0.4709
#   [SMOTE - RandomForest]
#     AUROC: 0.9228
#     G-mean: 0.6100
#     MCC: 0.3679
#     F1-score: 0.3825
#     mAP: 0.4568
#   [ADASYN - SVM]
#     AUROC: 0.8844
#     G-mean: 0.7508
#     MCC: 0.2931
#     F1-score: 0.2736
#     mAP: 0.3797
#   [ADASYN - DecisionTree]
#     AUROC: 0.8204
#     G-mean: 0.6497
#     MCC: 0.2496
#     F1-score: 0.2452
#     mAP: 0.2411
#   [ADASYN - kNN]
#     AUROC: 0.8200
#     G-mean: 0.7688
#     MCC: 0.3323
#     F1-score: 0.3126
#     mAP: 0.2253
#   [ADASYN - MLP]
#     AUROC: 0.8581
#     G-mean: 0.7747
#     MCC: 0.3062
#     F1-score: 0.2763
#     mAP: 0.4803
#   [ADASYN - RandomForest]
#     AUROC: 0.9229
#     G-mean: 0.5944
#     MCC: 0.3425
#     F1-score: 0.3574
#     mAP: 0.4389
#   [bSMOTE - SVM]
#     AUROC: 0.8722
#     G-mean: 0.6837
#     MCC: 0.3318
#     F1-score: 0.3308
#     mAP: 0.3883
#   [bSMOTE - DecisionTree]
#     AUROC: 0.8234
#     G-mean: 0.6744
#     MCC: 0.3156
#     F1-score: 0.3107
#     mAP: 0.2559
#   [bSMOTE - kNN]
#     AUROC: 0.8097
#     G-mean: 0.7126
#     MCC: 0.3412
#     F1-score: 0.3394
#     mAP: 0.2516
#   [bSMOTE - MLP]
#     AUROC: 0.8404
#     G-mean: 0.7027
#     MCC: 0.3322
#     F1-score: 0.3238
#     mAP: 0.4420
#   [bSMOTE - RandomForest]
#     AUROC: 0.9272
#     G-mean: 0.5118
#     MCC: 0.3174
#     F1-score: 0.3302
#     mAP: 0.4409
#   [ROS - SVM]
#     AUROC: 0.8884
#     G-mean: 0.7740
#     MCC: 0.3104
#     F1-score: 0.2848
#     mAP: 0.4085
#   [ROS - DecisionTree]
#     AUROC: 0.7410
#     G-mean: 0.6883
#     MCC: 0.2749
#     F1-score: 0.2722
#     mAP: 0.2645
#   [ROS - kNN]
#     AUROC: 0.7486
#     G-mean: 0.6425
#     MCC: 0.2847
#     F1-score: 0.2935
#     mAP: 0.2154
#   [ROS - MLP]
#     AUROC: 0.8796
#     G-mean: 0.7883
#     MCC: 0.3110
#     F1-score: 0.2738
#     mAP: 0.4232
#   [ROS - RandomForest]
#     AUROC: 0.9193
#     G-mean: 0.4225
#     MCC: 0.3534
#     F1-score: 0.3190
#     mAP: 0.4609
#   [MWMOTE - SVM]
#     AUROC: 0.8817
#     G-mean: 0.7200
#     MCC: 0.3083
#     F1-score: 0.3019
#     mAP: 0.3948
#   [MWMOTE - DecisionTree]
#     AUROC: 0.7040
#     G-mean: 0.6326
#     MCC: 0.2710
#     F1-score: 0.2764
#     mAP: 0.2317
#   [MWMOTE - kNN]
#     AUROC: 0.8366
#     G-mean: 0.7592
#     MCC: 0.3594
#     F1-score: 0.3465
#     mAP: 0.2468
#   [MWMOTE - MLP]
#     AUROC: 0.8623
#     G-mean: 0.7918
#     MCC: 0.3504
#     F1-score: 0.3213
#     mAP: 0.4500
#   [MWMOTE - RandomForest]
#     AUROC: 0.9109
#     G-mean: 0.6402
#     MCC: 0.3928
#     F1-score: 0.4038
#     mAP: 0.4526
#   [CTGAN - SVM]
#     AUROC: 0.8373
#     G-mean: 0.6817
#     MCC: 0.3138
#     F1-score: 0.3164
#     mAP: 0.3334
#   [CTGAN - DecisionTree]
#     AUROC: 0.8438
#     G-mean: 0.3176
#     MCC: 0.2166
#     F1-score: 0.2177
#     mAP: 0.3132
#   [CTGAN - kNN]
#     AUROC: 0.7740
#     G-mean: 0.6224
#     MCC: 0.3044
#     F1-score: 0.3151
#     mAP: 0.2578
#   [CTGAN - MLP]
#     AUROC: 0.7839
#     G-mean: 0.7231
#     MCC: 0.2761
#     F1-score: 0.2650
#     mAP: 0.2853
#   [CTGAN - RandomForest]
#     AUROC: 0.9190
#     G-mean: 0.3175
#     MCC: 0.2661
#     F1-score: 0.2405
#     mAP: 0.4431
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Original - SVM]
#     AUROC: 0.8462
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.4985
#   [Original - DecisionTree]
#     AUROC: 0.6964
#     G-mean: 0.4367
#     MCC: 0.2686
#     F1-score: 0.2797
#     mAP: 0.1974
#   [Original - kNN]
#     AUROC: 0.7571
#     G-mean: 0.3516
#     MCC: 0.2853
#     F1-score: 0.2583
#     mAP: 0.2951
#   [Original - MLP]
#     AUROC: 0.3415
#     G-mean: 0.0000
#     MCC: -0.0019
#     F1-score: 0.0000
#     mAP: 0.0317
#   [Original - RandomForest]
#     AUROC: 0.9200
#     G-mean: 0.2734
#     MCC: 0.2394
#     F1-score: 0.2084
#     mAP: 0.4787
#   [SMOTE - SVM]
#     AUROC: 0.8948
#     G-mean: 0.7438
#     MCC: 0.3154
#     F1-score: 0.2924
#     mAP: 0.4268
#   [SMOTE - DecisionTree]
#     AUROC: 0.7819
#     G-mean: 0.6852
#     MCC: 0.2611
#     F1-score: 0.2535
#     mAP: 0.2593
#   [SMOTE - kNN]
#     AUROC: 0.8158
#     G-mean: 0.7511
#     MCC: 0.3271
#     F1-score: 0.3137
#     mAP: 0.2431
#   [SMOTE - MLP]
#     AUROC: 0.8774
#     G-mean: 0.7961
#     MCC: 0.3296
#     F1-score: 0.2937
#     mAP: 0.4652
#   [SMOTE - RandomForest]
#     AUROC: 0.9210
#     G-mean: 0.6111
#     MCC: 0.3761
#     F1-score: 0.3876
#     mAP: 0.4677
#   [ADASYN - SVM]
#     AUROC: 0.8903
#     G-mean: 0.7326
#     MCC: 0.2923
#     F1-score: 0.2717
#     mAP: 0.4023
#   [ADASYN - DecisionTree]
#     AUROC: 0.8111
#     G-mean: 0.6739
#     MCC: 0.2763
#     F1-score: 0.2666
#     mAP: 0.2606
#   [ADASYN - kNN]
#     AUROC: 0.8193
#     G-mean: 0.7508
#     MCC: 0.3224
#     F1-score: 0.3084
#     mAP: 0.2472
#   [ADASYN - MLP]
#     AUROC: 0.8710
#     G-mean: 0.7635
#     MCC: 0.3076
#     F1-score: 0.2752
#     mAP: 0.4616
#   [ADASYN - RandomForest]
#     AUROC: 0.9202
#     G-mean: 0.6028
#     MCC: 0.3589
#     F1-score: 0.3698
#     mAP: 0.4591
#   [bSMOTE - SVM]
#     AUROC: 0.8904
#     G-mean: 0.7093
#     MCC: 0.3605
#     F1-score: 0.3557
#     mAP: 0.4299
#   [bSMOTE - DecisionTree]
#     AUROC: 0.8069
#     G-mean: 0.6529
#     MCC: 0.2943
#     F1-score: 0.2950
#     mAP: 0.2308
#   [bSMOTE - kNN]
#     AUROC: 0.8040
#     G-mean: 0.7101
#     MCC: 0.3383
#     F1-score: 0.3399
#     mAP: 0.2530
#   [bSMOTE - MLP]
#     AUROC: 0.8602
#     G-mean: 0.7359
#     MCC: 0.3483
#     F1-score: 0.3361
#     mAP: 0.4456
#   [bSMOTE - RandomForest]
#     AUROC: 0.9240
#     G-mean: 0.5417
#     MCC: 0.3513
#     F1-score: 0.3557
#     mAP: 0.4775
#   [ROS - SVM]
#     AUROC: 0.8943
#     G-mean: 0.7608
#     MCC: 0.3144
#     F1-score: 0.2864
#     mAP: 0.4434
#   [ROS - DecisionTree]
#     AUROC: 0.7229
#     G-mean: 0.6626
#     MCC: 0.2535
#     F1-score: 0.2540
#     mAP: 0.2397
#   [ROS - kNN]
#     AUROC: 0.7541
#     G-mean: 0.6481
#     MCC: 0.2987
#     F1-score: 0.3073
#     mAP: 0.2307
#   [ROS - MLP]
#     AUROC: 0.8843
#     G-mean: 0.7942
#     MCC: 0.3130
#     F1-score: 0.2739
#     mAP: 0.4173
#   [ROS - RandomForest]
#     AUROC: 0.9230
#     G-mean: 0.3572
#     MCC: 0.2855
#     F1-score: 0.2665
#     mAP: 0.4915
#   [MWMOTE - SVM]
#     AUROC: 0.8915
#     G-mean: 0.7147
#     MCC: 0.3110
#     F1-score: 0.2997
#     mAP: 0.4425
#   [MWMOTE - DecisionTree]
#     AUROC: 0.7263
#     G-mean: 0.6499
#     MCC: 0.2714
#     F1-score: 0.2712
#     mAP: 0.2325
#   [MWMOTE - kNN]
#     AUROC: 0.8132
#     G-mean: 0.7099
#     MCC: 0.3267
#     F1-score: 0.3216
#     mAP: 0.2453
#   [MWMOTE - MLP]
#     AUROC: 0.8751
#     G-mean: 0.7899
#     MCC: 0.3547
#     F1-score: 0.3292
#     mAP: 0.4659
#   [MWMOTE - RandomForest]
#     AUROC: 0.9164
#     G-mean: 0.6146
#     MCC: 0.3912
#     F1-score: 0.4020
#     mAP: 0.4761
#   [CTGAN - SVM]
#     AUROC: 0.8531
#     G-mean: 0.6729
#     MCC: 0.3166
#     F1-score: 0.3192
#     mAP: 0.3608
#   [CTGAN - DecisionTree]
#     AUROC: 0.8587
#     G-mean: 0.3749
#     MCC: 0.2455
#     F1-score: 0.2490
#     mAP: 0.2964
#   [CTGAN - kNN]
#     AUROC: 0.7970
#     G-mean: 0.6007
#     MCC: 0.2810
#     F1-score: 0.2952
#     mAP: 0.2661
#   [CTGAN - MLP]
#     AUROC: 0.7997
#     G-mean: 0.6774
#     MCC: 0.2673
#     F1-score: 0.2642
#     mAP: 0.2916
#   [CTGAN - RandomForest]
#     AUROC: 0.9184
#     G-mean: 0.3254
#     MCC: 0.2719
#     F1-score: 0.2494
#     mAP: 0.4689
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Original - SVM]
#     AUROC: 0.8489
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.5042
#   [Original - DecisionTree]
#     AUROC: 0.7380
#     G-mean: 0.4616
#     MCC: 0.2880
#     F1-score: 0.2989
#     mAP: 0.2275
#   [Original - kNN]
#     AUROC: 0.7700
#     G-mean: 0.3644
#     MCC: 0.2936
#     F1-score: 0.2654
#     mAP: 0.3120
#   [Original - MLP]
#     AUROC: 0.3433
#     G-mean: 0.0000
#     MCC: -0.0012
#     F1-score: 0.0000
#     mAP: 0.0314
#   [Original - RandomForest]
#     AUROC: 0.9251
#     G-mean: 0.2677
#     MCC: 0.2319
#     F1-score: 0.2029
#     mAP: 0.4681
#   [SMOTE - SVM]
#     AUROC: 0.8973
#     G-mean: 0.7497
#     MCC: 0.3180
#     F1-score: 0.2946
#     mAP: 0.4350
#   [SMOTE - DecisionTree]
#     AUROC: 0.7824
#     G-mean: 0.6918
#     MCC: 0.2643
#     F1-score: 0.2579
#     mAP: 0.2570
#   [SMOTE - kNN]
#     AUROC: 0.8156
#     G-mean: 0.7533
#     MCC: 0.3221
#     F1-score: 0.3066
#     mAP: 0.2435
#   [SMOTE - MLP]
#     AUROC: 0.8785
#     G-mean: 0.8009
#     MCC: 0.3340
#     F1-score: 0.2991
#     mAP: 0.4552
#   [SMOTE - RandomForest]
#     AUROC: 0.9231
#     G-mean: 0.6247
#     MCC: 0.3778
#     F1-score: 0.3886
#     mAP: 0.4639
#   [ADASYN - SVM]
#     AUROC: 0.8925
#     G-mean: 0.7527
#     MCC: 0.3091
#     F1-score: 0.2846
#     mAP: 0.4150
#   [ADASYN - DecisionTree]
#     AUROC: 0.8093
#     G-mean: 0.6986
#     MCC: 0.2864
#     F1-score: 0.2746
#     mAP: 0.2655
#   [ADASYN - kNN]
#     AUROC: 0.8207
#     G-mean: 0.7616
#     MCC: 0.3233
#     F1-score: 0.3058
#     mAP: 0.2416
#   [ADASYN - MLP]
#     AUROC: 0.8744
#     G-mean: 0.7781
#     MCC: 0.3207
#     F1-score: 0.2889
#     mAP: 0.4505
#   [ADASYN - RandomForest]
#     AUROC: 0.9222
#     G-mean: 0.6225
#     MCC: 0.3635
#     F1-score: 0.3734
#     mAP: 0.4540
#   [bSMOTE - SVM]
#     AUROC: 0.8978
#     G-mean: 0.7237
#     MCC: 0.3653
#     F1-score: 0.3595
#     mAP: 0.4455
#   [bSMOTE - DecisionTree]
#     AUROC: 0.8064
#     G-mean: 0.6644
#     MCC: 0.2973
#     F1-score: 0.3000
#     mAP: 0.2406
#   [bSMOTE - kNN]
#     AUROC: 0.8067
#     G-mean: 0.7230
#     MCC: 0.3423
#     F1-score: 0.3415
#     mAP: 0.2550
#   [bSMOTE - MLP]
#     AUROC: 0.8659
#     G-mean: 0.7441
#     MCC: 0.3502
#     F1-score: 0.3370
#     mAP: 0.4529
#   [bSMOTE - RandomForest]
#     AUROC: 0.9277
#     G-mean: 0.5686
#     MCC: 0.3795
#     F1-score: 0.3824
#     mAP: 0.4824
#   [ROS - SVM]
#     AUROC: 0.8963
#     G-mean: 0.7626
#     MCC: 0.3143
#     F1-score: 0.2868
#     mAP: 0.4468
#   [ROS - DecisionTree]
#     AUROC: 0.7329
#     G-mean: 0.6731
#     MCC: 0.2592
#     F1-score: 0.2580
#     mAP: 0.2572
#   [ROS - kNN]
#     AUROC: 0.7663
#     G-mean: 0.6684
#     MCC: 0.3117
#     F1-score: 0.3182
#     mAP: 0.2411
#   [ROS - MLP]
#     AUROC: 0.8848
#     G-mean: 0.7990
#     MCC: 0.3122
#     F1-score: 0.2728
#     mAP: 0.4133
#   [ROS - RandomForest]
#     AUROC: 0.9266
#     G-mean: 0.3594
#     MCC: 0.2912
#     F1-score: 0.2692
#     mAP: 0.4908
#   [MWMOTE - SVM]
#     AUROC: 0.8947
#     G-mean: 0.7228
#     MCC: 0.3146
#     F1-score: 0.3017
#     mAP: 0.4448
#   [MWMOTE - DecisionTree]
#     AUROC: 0.7493
#     G-mean: 0.6643
#     MCC: 0.2758
#     F1-score: 0.2761
#     mAP: 0.2333
#   [MWMOTE - kNN]
#     AUROC: 0.8163
#     G-mean: 0.7286
#     MCC: 0.3332
#     F1-score: 0.3249
#     mAP: 0.2456
#   [MWMOTE - MLP]
#     AUROC: 0.8733
#     G-mean: 0.7951
#     MCC: 0.3582
#     F1-score: 0.3320
#     mAP: 0.4511
#   [MWMOTE - RandomForest]
#     AUROC: 0.9216
#     G-mean: 0.6058
#     MCC: 0.3846
#     F1-score: 0.3913
#     mAP: 0.4633
#   [CTGAN - SVM]
#     AUROC: 0.8478
#     G-mean: 0.6597
#     MCC: 0.3006
#     F1-score: 0.3045
#     mAP: 0.3530
#   [CTGAN - DecisionTree]
#     AUROC: 0.8642
#     G-mean: 0.4426
#     MCC: 0.3076
#     F1-score: 0.3065
#     mAP: 0.3288
#   [CTGAN - kNN]
#     AUROC: 0.7942
#     G-mean: 0.5991
#     MCC: 0.2746
#     F1-score: 0.2863
#     mAP: 0.2625
#   [CTGAN - MLP]
#     AUROC: 0.7929
#     G-mean: 0.6734
#     MCC: 0.2565
#     F1-score: 0.2557
#     mAP: 0.2784
#   [CTGAN - RandomForest]
#     AUROC: 0.9230
#     G-mean: 0.3157
#     MCC: 0.2610
#     F1-score: 0.2384
#     mAP: 0.4723
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Original - SVM]
#     AUROC: 0.8497
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.5036
#   [Original - DecisionTree]
#     AUROC: 0.7328
#     G-mean: 0.4628
#     MCC: 0.2816
#     F1-score: 0.2937
#     mAP: 0.2195
#   [Original - kNN]
#     AUROC: 0.7733
#     G-mean: 0.3661
#     MCC: 0.2973
#     F1-score: 0.2630
#     mAP: 0.3146
#   [Original - MLP]
#     AUROC: 0.3407
#     G-mean: 0.0000
#     MCC: -0.0016
#     F1-score: 0.0000
#     mAP: 0.0312
#   [Original - RandomForest]
#     AUROC: 0.9243
#     G-mean: 0.2491
#     MCC: 0.2175
#     F1-score: 0.1894
#     mAP: 0.4640
#   [SMOTE - SVM]
#     AUROC: 0.8966
#     G-mean: 0.7462
#     MCC: 0.3115
#     F1-score: 0.2903
#     mAP: 0.4285
#   [SMOTE - DecisionTree]
#     AUROC: 0.7790
#     G-mean: 0.6936
#     MCC: 0.2612
#     F1-score: 0.2545
#     mAP: 0.2471
#   [SMOTE - kNN]
#     AUROC: 0.8132
#     G-mean: 0.7523
#     MCC: 0.3194
#     F1-score: 0.3044
#     mAP: 0.2319
#   [SMOTE - MLP]
#     AUROC: 0.8787
#     G-mean: 0.8000
#     MCC: 0.3324
#     F1-score: 0.2983
#     mAP: 0.4476
#   [SMOTE - RandomForest]
#     AUROC: 0.9236
#     G-mean: 0.6227
#     MCC: 0.3706
#     F1-score: 0.3826
#     mAP: 0.4605
#   [ADASYN - SVM]
#     AUROC: 0.8929
#     G-mean: 0.7532
#     MCC: 0.3067
#     F1-score: 0.2828
#     mAP: 0.4125
#   [ADASYN - DecisionTree]
#     AUROC: 0.8012
#     G-mean: 0.6972
#     MCC: 0.2742
#     F1-score: 0.2642
#     mAP: 0.2573
#   [ADASYN - kNN]
#     AUROC: 0.8163
#     G-mean: 0.7580
#     MCC: 0.3178
#     F1-score: 0.3011
#     mAP: 0.2313
#   [ADASYN - MLP]
#     AUROC: 0.8756
#     G-mean: 0.7831
#     MCC: 0.3178
#     F1-score: 0.2846
#     mAP: 0.4464
#   [ADASYN - RandomForest]
#     AUROC: 0.9226
#     G-mean: 0.6241
#     MCC: 0.3572
#     F1-score: 0.3687
#     mAP: 0.4446
#   [bSMOTE - SVM]
#     AUROC: 0.8959
#     G-mean: 0.7267
#     MCC: 0.3616
#     F1-score: 0.3562
#     mAP: 0.4359
#   [bSMOTE - DecisionTree]
#     AUROC: 0.7798
#     G-mean: 0.6491
#     MCC: 0.2787
#     F1-score: 0.2846
#     mAP: 0.2262
#   [bSMOTE - kNN]
#     AUROC: 0.8066
#     G-mean: 0.7220
#     MCC: 0.3367
#     F1-score: 0.3356
#     mAP: 0.2451
#   [bSMOTE - MLP]
#     AUROC: 0.8668
#     G-mean: 0.7535
#     MCC: 0.3511
#     F1-score: 0.3363
#     mAP: 0.4430
#   [bSMOTE - RandomForest]
#     AUROC: 0.9279
#     G-mean: 0.5653
#     MCC: 0.3616
#     F1-score: 0.3674
#     mAP: 0.4708
#   [ROS - SVM]
#     AUROC: 0.8980
#     G-mean: 0.7652
#     MCC: 0.3128
#     F1-score: 0.2860
#     mAP: 0.4487
#   [ROS - DecisionTree]
#     AUROC: 0.7340
#     G-mean: 0.6763
#     MCC: 0.2553
#     F1-score: 0.2532
#     mAP: 0.2515
#   [ROS - kNN]
#     AUROC: 0.7693
#     G-mean: 0.6737
#     MCC: 0.3113
#     F1-score: 0.3181
#     mAP: 0.2353
#   [ROS - MLP]
#     AUROC: 0.8865
#     G-mean: 0.8099
#     MCC: 0.3217
#     F1-score: 0.2798
#     mAP: 0.4194
#   [ROS - RandomForest]
#     AUROC: 0.9274
#     G-mean: 0.3557
#     MCC: 0.2800
#     F1-score: 0.2594
#     mAP: 0.4820
#   [MWMOTE - SVM]
#     AUROC: 0.8917
#     G-mean: 0.7308
#     MCC: 0.3175
#     F1-score: 0.3040
#     mAP: 0.4314
#   [MWMOTE - DecisionTree]
#     AUROC: 0.7544
#     G-mean: 0.6737
#     MCC: 0.2769
#     F1-score: 0.2770
#     mAP: 0.2284
#   [MWMOTE - kNN]
#     AUROC: 0.8169
#     G-mean: 0.7224
#     MCC: 0.3227
#     F1-score: 0.3159
#     mAP: 0.2350
#   [MWMOTE - MLP]
#     AUROC: 0.8711
#     G-mean: 0.7950
#     MCC: 0.3571
#     F1-score: 0.3318
#     mAP: 0.4465
#   [MWMOTE - RandomForest]
#     AUROC: 0.9214
#     G-mean: 0.6070
#     MCC: 0.3810
#     F1-score: 0.3892
#     mAP: 0.4598
#   [CTGAN - SVM]
#     AUROC: 0.8560
#     G-mean: 0.6768
#     MCC: 0.3136
#     F1-score: 0.3148
#     mAP: 0.3705
#   [CTGAN - DecisionTree]
#     AUROC: 0.8655
#     G-mean: 0.4657
#     MCC: 0.3306
#     F1-score: 0.3283
#     mAP: 0.3376
#   [CTGAN - kNN]
#     AUROC: 0.8030
#     G-mean: 0.6185
#     MCC: 0.2897
#     F1-score: 0.2989
#     mAP: 0.2611
#   [CTGAN - MLP]
#     AUROC: 0.8072
#     G-mean: 0.6910
#     MCC: 0.2702
#     F1-score: 0.2655
#     mAP: 0.2964
#   [CTGAN - RandomForest]
#     AUROC: 0.9253
#     G-mean: 0.3074
#     MCC: 0.2519
#     F1-score: 0.2285
#     mAP: 0.4724
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Original - SVM]
#     AUROC: 0.8454
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.4945
#   [Original - DecisionTree]
#     AUROC: 0.7394
#     G-mean: 0.4698
#     MCC: 0.2955
#     F1-score: 0.3055
#     mAP: 0.2317
#   [Original - kNN]
#     AUROC: 0.7719
#     G-mean: 0.3710
#     MCC: 0.3064
#     F1-score: 0.2724
#     mAP: 0.3197
#   [Original - MLP]
#     AUROC: 0.3446
#     G-mean: 0.0000
#     MCC: -0.0016
#     F1-score: 0.0000
#     mAP: 0.0324
#   [Original - RandomForest]
#     AUROC: 0.9245
#     G-mean: 0.2557
#     MCC: 0.2209
#     F1-score: 0.1917
#     mAP: 0.4602
#   [SMOTE - SVM]
#     AUROC: 0.8956
#     G-mean: 0.7542
#     MCC: 0.3174
#     F1-score: 0.2953
#     mAP: 0.4269
#   [SMOTE - DecisionTree]
#     AUROC: 0.7826
#     G-mean: 0.6982
#     MCC: 0.2657
#     F1-score: 0.2587
#     mAP: 0.2425
#   [SMOTE - kNN]
#     AUROC: 0.8166
#     G-mean: 0.7478
#     MCC: 0.3157
#     F1-score: 0.3014
#     mAP: 0.2360
#   [SMOTE - MLP]
#     AUROC: 0.8763
#     G-mean: 0.7951
#     MCC: 0.3272
#     F1-score: 0.2940
#     mAP: 0.4461
#   [SMOTE - RandomForest]
#     AUROC: 0.9237
#     G-mean: 0.6259
#     MCC: 0.3694
#     F1-score: 0.3809
#     mAP: 0.4601
#   [ADASYN - SVM]
#     AUROC: 0.8918
#     G-mean: 0.7568
#     MCC: 0.3083
#     F1-score: 0.2844
#     mAP: 0.4147
#   [ADASYN - DecisionTree]
#     AUROC: 0.7955
#     G-mean: 0.7015
#     MCC: 0.2749
#     F1-score: 0.2648
#     mAP: 0.2475
#   [ADASYN - kNN]
#     AUROC: 0.8183
#     G-mean: 0.7516
#     MCC: 0.3117
#     F1-score: 0.2957
#     mAP: 0.2322
#   [ADASYN - MLP]
#     AUROC: 0.8742
#     G-mean: 0.7803
#     MCC: 0.3118
#     F1-score: 0.2791
#     mAP: 0.4504
#   [ADASYN - RandomForest]
#     AUROC: 0.9219
#     G-mean: 0.6271
#     MCC: 0.3610
#     F1-score: 0.3709
#     mAP: 0.4460
#   [bSMOTE - SVM]
#     AUROC: 0.8975
#     G-mean: 0.7314
#     MCC: 0.3624
#     F1-score: 0.3567
#     mAP: 0.4403
#   [bSMOTE - DecisionTree]
#     AUROC: 0.7729
#     G-mean: 0.6534
#     MCC: 0.2866
#     F1-score: 0.2937
#     mAP: 0.2240
#   [bSMOTE - kNN]
#     AUROC: 0.8093
#     G-mean: 0.7167
#     MCC: 0.3328
#     F1-score: 0.3319
#     mAP: 0.2509
#   [bSMOTE - MLP]
#     AUROC: 0.8648
#     G-mean: 0.7546
#     MCC: 0.3473
#     F1-score: 0.3327
#     mAP: 0.4502
#   [bSMOTE - RandomForest]
#     AUROC: 0.9258
#     G-mean: 0.5737
#     MCC: 0.3631
#     F1-score: 0.3708
#     mAP: 0.4661
#   [ROS - SVM]
#     AUROC: 0.8957
#     G-mean: 0.7710
#     MCC: 0.3175
#     F1-score: 0.2902
#     mAP: 0.4444
#   [ROS - DecisionTree]
#     AUROC: 0.7385
#     G-mean: 0.6827
#     MCC: 0.2629
#     F1-score: 0.2603
#     mAP: 0.2504
#   [ROS - kNN]
#     AUROC: 0.7681
#     G-mean: 0.6728
#     MCC: 0.3094
#     F1-score: 0.3155
#     mAP: 0.2394
#   [ROS - MLP]
#     AUROC: 0.8858
#     G-mean: 0.8079
#     MCC: 0.3186
#     F1-score: 0.2769
#     mAP: 0.4185
#   [ROS - RandomForest]
#     AUROC: 0.9271
#     G-mean: 0.3657
#     MCC: 0.2869
#     F1-score: 0.2642
#     mAP: 0.4800
#   [MWMOTE - SVM]
#     AUROC: 0.8899
#     G-mean: 0.7340
#     MCC: 0.3167
#     F1-score: 0.3033
#     mAP: 0.4296
#   [MWMOTE - DecisionTree]
#     AUROC: 0.7590
#     G-mean: 0.6739
#     MCC: 0.2813
#     F1-score: 0.2799
#     mAP: 0.2351
#   [MWMOTE - kNN]
#     AUROC: 0.8075
#     G-mean: 0.7175
#     MCC: 0.3160
#     F1-score: 0.3100
#     mAP: 0.2348
#   [MWMOTE - MLP]
#     AUROC: 0.8665
#     G-mean: 0.7956
#     MCC: 0.3567
#     F1-score: 0.3309
#     mAP: 0.4531
#   [MWMOTE - RandomForest]
#     AUROC: 0.9224
#     G-mean: 0.5931
#     MCC: 0.3685
#     F1-score: 0.3774
#     mAP: 0.4578
#   [CTGAN - SVM]
#     AUROC: 0.8534
#     G-mean: 0.6708
#     MCC: 0.3226
#     F1-score: 0.3247
#     mAP: 0.3629
#   [CTGAN - DecisionTree]
#     AUROC: 0.8711
#     G-mean: 0.4598
#     MCC: 0.3311
#     F1-score: 0.3263
#     mAP: 0.3412
#   [CTGAN - kNN]
#     AUROC: 0.8030
#     G-mean: 0.6224
#     MCC: 0.2943
#     F1-score: 0.3039
#     mAP: 0.2601
#   [CTGAN - MLP]
#     AUROC: 0.8071
#     G-mean: 0.6774
#     MCC: 0.2752
#     F1-score: 0.2729
#     mAP: 0.2948
#   [CTGAN - RandomForest]
#     AUROC: 0.9253
#     G-mean: 0.3272
#     MCC: 0.2719
#     F1-score: 0.2439
#     mAP: 0.4721
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Original - SVM]
#     AUROC: 0.8471
#     G-mean: 0.0074
#     MCC: 0.0073
#     F1-score: 0.0056
#     mAP: 0.4952
#   [Original - DecisionTree]
#     AUROC: 0.7382
#     G-mean: 0.4865
#     MCC: 0.3085
#     F1-score: 0.3181
#     mAP: 0.2336
#   [Original - kNN]
#     AUROC: 0.7723
#     G-mean: 0.3594
#     MCC: 0.2999
#     F1-score: 0.2657
#     mAP: 0.3239
#   [Original - MLP]
#     AUROC: 0.3432
#     G-mean: 0.0000
#     MCC: -0.0013
#     F1-score: 0.0000
#     mAP: 0.0322
#   [Original - RandomForest]
#     AUROC: 0.9247
#     G-mean: 0.2609
#     MCC: 0.2287
#     F1-score: 0.1958
#     mAP: 0.4637
#   [SMOTE - SVM]
#     AUROC: 0.8972
#     G-mean: 0.7612
#     MCC: 0.3229
#     F1-score: 0.3004
#     mAP: 0.4293
#   [SMOTE - DecisionTree]
#     AUROC: 0.7847
#     G-mean: 0.7017
#     MCC: 0.2678
#     F1-score: 0.2597
#     mAP: 0.2487
#   [SMOTE - kNN]
#     AUROC: 0.8176
#     G-mean: 0.7475
#     MCC: 0.3133
#     F1-score: 0.2990
#     mAP: 0.2366
#   [SMOTE - MLP]
#     AUROC: 0.8773
#     G-mean: 0.7941
#     MCC: 0.3258
#     F1-score: 0.2928
#     mAP: 0.4400
#   [SMOTE - RandomForest]
#     AUROC: 0.9234
#     G-mean: 0.6330
#     MCC: 0.3719
#     F1-score: 0.3843
#     mAP: 0.4601
#   [ADASYN - SVM]
#     AUROC: 0.8932
#     G-mean: 0.7582
#     MCC: 0.3069
#     F1-score: 0.2831
#     mAP: 0.4179
#   [ADASYN - DecisionTree]
#     AUROC: 0.8011
#     G-mean: 0.7142
#     MCC: 0.2841
#     F1-score: 0.2712
#     mAP: 0.2594
#   [ADASYN - kNN]
#     AUROC: 0.8185
#     G-mean: 0.7542
#     MCC: 0.3149
#     F1-score: 0.2983
#     mAP: 0.2304
#   [ADASYN - MLP]
#     AUROC: 0.8764
#     G-mean: 0.7837
#     MCC: 0.3146
#     F1-score: 0.2816
#     mAP: 0.4420
#   [ADASYN - RandomForest]
#     AUROC: 0.9213
#     G-mean: 0.6363
#     MCC: 0.3676
#     F1-score: 0.3785
#     mAP: 0.4515
#   [bSMOTE - SVM]
#     AUROC: 0.8977
#     G-mean: 0.7318
#     MCC: 0.3607
#     F1-score: 0.3558
#     mAP: 0.4413
#   [bSMOTE - DecisionTree]
#     AUROC: 0.7686
#     G-mean: 0.6601
#     MCC: 0.2908
#     F1-score: 0.2977
#     mAP: 0.2266
#   [bSMOTE - kNN]
#     AUROC: 0.8101
#     G-mean: 0.7175
#     MCC: 0.3340
#     F1-score: 0.3337
#     mAP: 0.2570
#   [bSMOTE - MLP]
#     AUROC: 0.8639
#     G-mean: 0.7563
#     MCC: 0.3470
#     F1-score: 0.3317
#     mAP: 0.4507
#   [bSMOTE - RandomForest]
#     AUROC: 0.9245
#     G-mean: 0.5796
#     MCC: 0.3653
#     F1-score: 0.3749
#     mAP: 0.4620
#   [ROS - SVM]
#     AUROC: 0.8970
#     G-mean: 0.7737
#     MCC: 0.3176
#     F1-score: 0.2902
#     mAP: 0.4459
#   [ROS - DecisionTree]
#     AUROC: 0.7415
#     G-mean: 0.6855
#     MCC: 0.2642
#     F1-score: 0.2615
#     mAP: 0.2554
#   [ROS - kNN]
#     AUROC: 0.7684
#     G-mean: 0.6769
#     MCC: 0.3129
#     F1-score: 0.3193
#     mAP: 0.2409
#   [ROS - MLP]
#     AUROC: 0.8871
#     G-mean: 0.8075
#     MCC: 0.3188
#     F1-score: 0.2775
#     mAP: 0.4211
#   [ROS - RandomForest]
#     AUROC: 0.9256
#     G-mean: 0.3660
#     MCC: 0.2860
#     F1-score: 0.2643
#     mAP: 0.4784
#   [MWMOTE - SVM]
#     AUROC: 0.8910
#     G-mean: 0.7378
#     MCC: 0.3199
#     F1-score: 0.3069
#     mAP: 0.4300
#   [MWMOTE - DecisionTree]
#     AUROC: 0.7638
#     G-mean: 0.6819
#     MCC: 0.2859
#     F1-score: 0.2836
#     mAP: 0.2350
#   [MWMOTE - kNN]
#     AUROC: 0.8095
#     G-mean: 0.7226
#     MCC: 0.3188
#     F1-score: 0.3120
#     mAP: 0.2395
#   [MWMOTE - MLP]
#     AUROC: 0.8666
#     G-mean: 0.7930
#     MCC: 0.3502
#     F1-score: 0.3241
#     mAP: 0.4456
#   [MWMOTE - RandomForest]
#     AUROC: 0.9219
#     G-mean: 0.5984
#     MCC: 0.3693
#     F1-score: 0.3796
#     mAP: 0.4624
#   [CTGAN - SVM]
#     AUROC: 0.8506
#     G-mean: 0.6684
#     MCC: 0.3167
#     F1-score: 0.3200
#     mAP: 0.3506
#   [CTGAN - DecisionTree]
#     AUROC: 0.8716
#     G-mean: 0.4709
#     MCC: 0.3389
#     F1-score: 0.3344
#     mAP: 0.3365
#   [CTGAN - kNN]
#     AUROC: 0.8086
#     G-mean: 0.6385
#     MCC: 0.3038
#     F1-score: 0.3125
#     mAP: 0.2631
#   [CTGAN - MLP]
#     AUROC: 0.8068
#     G-mean: 0.6667
#     MCC: 0.2675
#     F1-score: 0.2670
#     mAP: 0.2866
#   [CTGAN - RandomForest]
#     AUROC: 0.9243
#     G-mean: 0.3204
#     MCC: 0.2679
#     F1-score: 0.2379
#     mAP: 0.4721
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Original - SVM]
#     AUROC: 0.8465
#     G-mean: 0.0064
#     MCC: 0.0063
#     F1-score: 0.0048
#     mAP: 0.4885
#   [Original - DecisionTree]
#     AUROC: 0.7397
#     G-mean: 0.4820
#     MCC: 0.3020
#     F1-score: 0.3124
#     mAP: 0.2287
#   [Original - kNN]
#     AUROC: 0.7726
#     G-mean: 0.3560
#     MCC: 0.2975
#     F1-score: 0.2646
#     mAP: 0.3255
#   [Original - MLP]
#     AUROC: 0.3448
#     G-mean: 0.0000
#     MCC: -0.0015
#     F1-score: 0.0000
#     mAP: 0.0323
#   [Original - RandomForest]
#     AUROC: 0.9260
#     G-mean: 0.2703
#     MCC: 0.2335
#     F1-score: 0.2008
#     mAP: 0.4629
#   [SMOTE - SVM]
#     AUROC: 0.8972
#     G-mean: 0.7601
#     MCC: 0.3213
#     F1-score: 0.2993
#     mAP: 0.4285
#   [SMOTE - DecisionTree]
#     AUROC: 0.7835
#     G-mean: 0.7065
#     MCC: 0.2707
#     F1-score: 0.2622
#     mAP: 0.2442
#   [SMOTE - kNN]
#     AUROC: 0.8185
#     G-mean: 0.7485
#     MCC: 0.3149
#     F1-score: 0.3004
#     mAP: 0.2428
#   [SMOTE - MLP]
#     AUROC: 0.8772
#     G-mean: 0.7939
#     MCC: 0.3260
#     F1-score: 0.2933
#     mAP: 0.4405
#   [SMOTE - RandomForest]
#     AUROC: 0.9232
#     G-mean: 0.6301
#     MCC: 0.3726
#     F1-score: 0.3851
#     mAP: 0.4600
#   [ADASYN - SVM]
#     AUROC: 0.8929
#     G-mean: 0.7572
#     MCC: 0.3044
#     F1-score: 0.2812
#     mAP: 0.4186
#   [ADASYN - DecisionTree]
#     AUROC: 0.7995
#     G-mean: 0.7173
#     MCC: 0.2842
#     F1-score: 0.2714
#     mAP: 0.2542
#   [ADASYN - kNN]
#     AUROC: 0.8198
#     G-mean: 0.7499
#     MCC: 0.3122
#     F1-score: 0.2964
#     mAP: 0.2359
#   [ADASYN - MLP]
#     AUROC: 0.8763
#     G-mean: 0.7808
#     MCC: 0.3132
#     F1-score: 0.2813
#     mAP: 0.4441
#   [ADASYN - RandomForest]
#     AUROC: 0.9213
#     G-mean: 0.6327
#     MCC: 0.3647
#     F1-score: 0.3763
#     mAP: 0.4509
#   [bSMOTE - SVM]
#     AUROC: 0.8991
#     G-mean: 0.7326
#     MCC: 0.3597
#     F1-score: 0.3548
#     mAP: 0.4417
#   [bSMOTE - DecisionTree]
#     AUROC: 0.7710
#     G-mean: 0.6684
#     MCC: 0.3014
#     F1-score: 0.3077
#     mAP: 0.2297
#   [bSMOTE - kNN]
#     AUROC: 0.8135
#     G-mean: 0.7204
#     MCC: 0.3377
#     F1-score: 0.3367
#     mAP: 0.2659
#   [bSMOTE - MLP]
#     AUROC: 0.8655
#     G-mean: 0.7618
#     MCC: 0.3496
#     F1-score: 0.3333
#     mAP: 0.4492
#   [bSMOTE - RandomForest]
#     AUROC: 0.9247
#     G-mean: 0.5787
#     MCC: 0.3688
#     F1-score: 0.3774
#     mAP: 0.4610
#   [ROS - SVM]
#     AUROC: 0.8962
#     G-mean: 0.7726
#     MCC: 0.3164
#     F1-score: 0.2892
#     mAP: 0.4440
#   [ROS - DecisionTree]
#     AUROC: 0.7421
#     G-mean: 0.6891
#     MCC: 0.2651
#     F1-score: 0.2620
#     mAP: 0.2560
#   [ROS - kNN]
#     AUROC: 0.7690
#     G-mean: 0.6799
#     MCC: 0.3160
#     F1-score: 0.3218
#     mAP: 0.2442
#   [ROS - MLP]
#     AUROC: 0.8860
#     G-mean: 0.8056
#     MCC: 0.3176
#     F1-score: 0.2770
#     mAP: 0.4183
#   [ROS - RandomForest]
#     AUROC: 0.9269
#     G-mean: 0.3787
#     MCC: 0.2991
#     F1-score: 0.2768
#     mAP: 0.4754
#   [MWMOTE - SVM]
#     AUROC: 0.8925
#     G-mean: 0.7351
#     MCC: 0.3166
#     F1-score: 0.3041
#     mAP: 0.4278
#   [MWMOTE - DecisionTree]
#     AUROC: 0.7659
#     G-mean: 0.6837
#     MCC: 0.2843
#     F1-score: 0.2821
#     mAP: 0.2442
#   [MWMOTE - kNN]
#     AUROC: 0.8079
#     G-mean: 0.7215
#     MCC: 0.3176
#     F1-score: 0.3109
#     mAP: 0.2469
#   [MWMOTE - MLP]
#     AUROC: 0.8697
#     G-mean: 0.7965
#     MCC: 0.3518
#     F1-score: 0.3244
#     mAP: 0.4458
#   [MWMOTE - RandomForest]
#     AUROC: 0.9226
#     G-mean: 0.5965
#     MCC: 0.3714
#     F1-score: 0.3824
#     mAP: 0.4654
#   [CTGAN - SVM]
#     AUROC: 0.8480
#     G-mean: 0.6605
#     MCC: 0.3129
#     F1-score: 0.3179
#     mAP: 0.3432
#   [CTGAN - DecisionTree]
#     AUROC: 0.8740
#     G-mean: 0.4769
#     MCC: 0.3415
#     F1-score: 0.3372
#     mAP: 0.3349
#   [CTGAN - kNN]
#     AUROC: 0.8099
#     G-mean: 0.6307
#     MCC: 0.3051
#     F1-score: 0.3141
#     mAP: 0.2695
#   [CTGAN - MLP]
#     AUROC: 0.8074
#     G-mean: 0.6577
#     MCC: 0.2623
#     F1-score: 0.2616
#     mAP: 0.2813
#   [CTGAN - RandomForest]
#     AUROC: 0.9251
#     G-mean: 0.3329
#     MCC: 0.2754
#     F1-score: 0.2457
#     mAP: 0.4714
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Original - SVM]
#     AUROC: 0.8460
#     G-mean: 0.0056
#     MCC: 0.0055
#     F1-score: 0.0042
#     mAP: 0.4818
#   [Original - DecisionTree]
#     AUROC: 0.7402
#     G-mean: 0.4808
#     MCC: 0.3005
#     F1-score: 0.3106
#     mAP: 0.2302
#   [Original - kNN]
#     AUROC: 0.7726
#     G-mean: 0.3547
#     MCC: 0.2983
#     F1-score: 0.2638
#     mAP: 0.3227
#   [Original - MLP]
#     AUROC: 0.3441
#     G-mean: 0.0000
#     MCC: -0.0013
#     F1-score: 0.0000
#     mAP: 0.0323
#   [Original - RandomForest]
#     AUROC: 0.9267
#     G-mean: 0.2644
#     MCC: 0.2297
#     F1-score: 0.1960
#     mAP: 0.4622
#   [SMOTE - SVM]
#     AUROC: 0.8969
#     G-mean: 0.7581
#     MCC: 0.3184
#     F1-score: 0.2971
#     mAP: 0.4316
#   [SMOTE - DecisionTree]
#     AUROC: 0.7849
#     G-mean: 0.7032
#     MCC: 0.2692
#     F1-score: 0.2612
#     mAP: 0.2420
#   [SMOTE - kNN]
#     AUROC: 0.8192
#     G-mean: 0.7470
#     MCC: 0.3129
#     F1-score: 0.2985
#     mAP: 0.2377
#   [SMOTE - MLP]
#     AUROC: 0.8776
#     G-mean: 0.7989
#     MCC: 0.3312
#     F1-score: 0.2979
#     mAP: 0.4406
#   [SMOTE - RandomForest]
#     AUROC: 0.9238
#     G-mean: 0.6276
#     MCC: 0.3667
#     F1-score: 0.3802
#     mAP: 0.4595
#   [ADASYN - SVM]
#     AUROC: 0.8928
#     G-mean: 0.7577
#     MCC: 0.3034
#     F1-score: 0.2800
#     mAP: 0.4210
#   [ADASYN - DecisionTree]
#     AUROC: 0.7975
#     G-mean: 0.7220
#     MCC: 0.2879
#     F1-score: 0.2745
#     mAP: 0.2580
#   [ADASYN - kNN]
#     AUROC: 0.8205
#     G-mean: 0.7501
#     MCC: 0.3118
#     F1-score: 0.2960
#     mAP: 0.2314
#   [ADASYN - MLP]
#     AUROC: 0.8770
#     G-mean: 0.7816
#     MCC: 0.3156
#     F1-score: 0.2845
#     mAP: 0.4497
#   [ADASYN - RandomForest]
#     AUROC: 0.9223
#     G-mean: 0.6330
#     MCC: 0.3618
#     F1-score: 0.3744
#     mAP: 0.4489
#   [bSMOTE - SVM]
#     AUROC: 0.8986
#     G-mean: 0.7317
#     MCC: 0.3565
#     F1-score: 0.3515
#     mAP: 0.4427
#   [bSMOTE - DecisionTree]
#     AUROC: 0.7756
#     G-mean: 0.6719
#     MCC: 0.3019
#     F1-score: 0.3078
#     mAP: 0.2338
#   [bSMOTE - kNN]
#     AUROC: 0.8143
#     G-mean: 0.7255
#     MCC: 0.3415
#     F1-score: 0.3396
#     mAP: 0.2638
#   [bSMOTE - MLP]
#     AUROC: 0.8663
#     G-mean: 0.7626
#     MCC: 0.3492
#     F1-score: 0.3328
#     mAP: 0.4496
#   [bSMOTE - RandomForest]
#     AUROC: 0.9246
#     G-mean: 0.5689
#     MCC: 0.3604
#     F1-score: 0.3694
#     mAP: 0.4576
#   [ROS - SVM]
#     AUROC: 0.8965
#     G-mean: 0.7694
#     MCC: 0.3118
#     F1-score: 0.2854
#     mAP: 0.4488
#   [ROS - DecisionTree]
#     AUROC: 0.7355
#     G-mean: 0.6796
#     MCC: 0.2587
#     F1-score: 0.2573
#     mAP: 0.2532
#   [ROS - kNN]
#     AUROC: 0.7687
#     G-mean: 0.6827
#     MCC: 0.3176
#     F1-score: 0.3232
#     mAP: 0.2374
#   [ROS - MLP]
#     AUROC: 0.8868
#     G-mean: 0.8045
#     MCC: 0.3154
#     F1-score: 0.2752
#     mAP: 0.4169
#   [ROS - RandomForest]
#     AUROC: 0.9283
#     G-mean: 0.3846
#     MCC: 0.3030
#     F1-score: 0.2813
#     mAP: 0.4716
#   [MWMOTE - SVM]
#     AUROC: 0.8921
#     G-mean: 0.7343
#     MCC: 0.3149
#     F1-score: 0.3024
#     mAP: 0.4319
#   [MWMOTE - DecisionTree]
#     AUROC: 0.7627
#     G-mean: 0.6801
#     MCC: 0.2799
#     F1-score: 0.2783
#     mAP: 0.2418
#   [MWMOTE - kNN]
#     AUROC: 0.8080
#     G-mean: 0.7262
#     MCC: 0.3208
#     F1-score: 0.3136
#     mAP: 0.2507
#   [MWMOTE - MLP]
#     AUROC: 0.8721
#     G-mean: 0.7951
#     MCC: 0.3504
#     F1-score: 0.3232
#     mAP: 0.4456
#   [MWMOTE - RandomForest]
#     AUROC: 0.9234
#     G-mean: 0.5934
#     MCC: 0.3727
#     F1-score: 0.3822
#     mAP: 0.4631
#   [CTGAN - SVM]
#     AUROC: 0.8474
#     G-mean: 0.6621
#     MCC: 0.3127
#     F1-score: 0.3175
#     mAP: 0.3376
#   [CTGAN - DecisionTree]
#     AUROC: 0.8790
#     G-mean: 0.4799
#     MCC: 0.3464
#     F1-score: 0.3418
#     mAP: 0.3373
#   [CTGAN - kNN]
#     AUROC: 0.8108
#     G-mean: 0.6371
#     MCC: 0.3111
#     F1-score: 0.3189
#     mAP: 0.2707
#   [CTGAN - MLP]
#     AUROC: 0.8084
#     G-mean: 0.6623
#     MCC: 0.2642
#     F1-score: 0.2625
#     mAP: 0.2796
#   [CTGAN - RandomForest]
#     AUROC: 0.9260
#     G-mean: 0.3294
#     MCC: 0.2749
#     F1-score: 0.2445
#     mAP: 0.4721
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Original - SVM]
#     AUROC: 0.8440
#     G-mean: 0.0050
#     MCC: 0.0049
#     F1-score: 0.0037
#     mAP: 0.4808
#   [Original - DecisionTree]
#     AUROC: 0.7396
#     G-mean: 0.4845
#     MCC: 0.3074
#     F1-score: 0.3155
#     mAP: 0.2352
#   [Original - kNN]
#     AUROC: 0.7730
#     G-mean: 0.3566
#     MCC: 0.3018
#     F1-score: 0.2648
#     mAP: 0.3295
#   [Original - MLP]
#     AUROC: 0.3441
#     G-mean: 0.0000
#     MCC: -0.0019
#     F1-score: 0.0000
#     mAP: 0.0331
#   [Original - RandomForest]
#     AUROC: 0.9281
#     G-mean: 0.2755
#     MCC: 0.2419
#     F1-score: 0.2061
#     mAP: 0.4707
#   [SMOTE - SVM]
#     AUROC: 0.8970
#     G-mean: 0.7610
#     MCC: 0.3217
#     F1-score: 0.2999
#     mAP: 0.4302
#   [SMOTE - DecisionTree]
#     AUROC: 0.7878
#     G-mean: 0.7052
#     MCC: 0.2701
#     F1-score: 0.2613
#     mAP: 0.2428
#   [SMOTE - kNN]
#     AUROC: 0.8187
#     G-mean: 0.7507
#     MCC: 0.3179
#     F1-score: 0.3029
#     mAP: 0.2399
#   [SMOTE - MLP]
#     AUROC: 0.8785
#     G-mean: 0.7978
#     MCC: 0.3327
#     F1-score: 0.3002
#     mAP: 0.4449
#   [SMOTE - RandomForest]
#     AUROC: 0.9245
#     G-mean: 0.6248
#     MCC: 0.3671
#     F1-score: 0.3805
#     mAP: 0.4641
#   [ADASYN - SVM]
#     AUROC: 0.8930
#     G-mean: 0.7607
#     MCC: 0.3059
#     F1-score: 0.2815
#     mAP: 0.4204
#   [ADASYN - DecisionTree]
#     AUROC: 0.7973
#     G-mean: 0.7196
#     MCC: 0.2852
#     F1-score: 0.2724
#     mAP: 0.2563
#   [ADASYN - kNN]
#     AUROC: 0.8210
#     G-mean: 0.7531
#     MCC: 0.3154
#     F1-score: 0.2989
#     mAP: 0.2343
#   [ADASYN - MLP]
#     AUROC: 0.8771
#     G-mean: 0.7814
#     MCC: 0.3158
#     F1-score: 0.2844
#     mAP: 0.4488
#   [ADASYN - RandomForest]
#     AUROC: 0.9235
#     G-mean: 0.6331
#     MCC: 0.3605
#     F1-score: 0.3737
#     mAP: 0.4548
#   [bSMOTE - SVM]
#     AUROC: 0.8982
#     G-mean: 0.7251
#     MCC: 0.3518
#     F1-score: 0.3471
#     mAP: 0.4408
#   [bSMOTE - DecisionTree]
#     AUROC: 0.7750
#     G-mean: 0.6659
#     MCC: 0.2998
#     F1-score: 0.3057
#     mAP: 0.2353
#   [bSMOTE - kNN]
#     AUROC: 0.8131
#     G-mean: 0.7226
#     MCC: 0.3433
#     F1-score: 0.3411
#     mAP: 0.2671
#   [bSMOTE - MLP]
#     AUROC: 0.8656
#     G-mean: 0.7634
#     MCC: 0.3485
#     F1-score: 0.3320
#     mAP: 0.4438
#   [bSMOTE - RandomForest]
#     AUROC: 0.9243
#     G-mean: 0.5612
#     MCC: 0.3557
#     F1-score: 0.3638
#     mAP: 0.4578
#   [ROS - SVM]
#     AUROC: 0.8969
#     G-mean: 0.7703
#     MCC: 0.3126
#     F1-score: 0.2860
#     mAP: 0.4507
#   [ROS - DecisionTree]
#     AUROC: 0.7364
#     G-mean: 0.6740
#     MCC: 0.2557
#     F1-score: 0.2543
#     mAP: 0.2540
#   [ROS - kNN]
#     AUROC: 0.7691
#     G-mean: 0.6820
#     MCC: 0.3214
#     F1-score: 0.3265
#     mAP: 0.2431
#   [ROS - MLP]
#     AUROC: 0.8868
#     G-mean: 0.8025
#     MCC: 0.3147
#     F1-score: 0.2754
#     mAP: 0.4141
#   [ROS - RandomForest]
#     AUROC: 0.9298
#     G-mean: 0.3894
#     MCC: 0.3111
#     F1-score: 0.2867
#     mAP: 0.4783
#   [MWMOTE - SVM]
#     AUROC: 0.8924
#     G-mean: 0.7361
#     MCC: 0.3170
#     F1-score: 0.3041
#     mAP: 0.4343
#   [MWMOTE - DecisionTree]
#     AUROC: 0.7626
#     G-mean: 0.6764
#     MCC: 0.2820
#     F1-score: 0.2812
#     mAP: 0.2463
#   [MWMOTE - kNN]
#     AUROC: 0.8078
#     G-mean: 0.7241
#     MCC: 0.3237
#     F1-score: 0.3160
#     mAP: 0.2570
#   [MWMOTE - MLP]
#     AUROC: 0.8723
#     G-mean: 0.7954
#     MCC: 0.3517
#     F1-score: 0.3246
#     mAP: 0.4453
#   [MWMOTE - RandomForest]
#     AUROC: 0.9239
#     G-mean: 0.5921
#     MCC: 0.3738
#     F1-score: 0.3833
#     mAP: 0.4639
#   [CTGAN - SVM]
#     AUROC: 0.8475
#     G-mean: 0.6620
#     MCC: 0.3146
#     F1-score: 0.3199
#     mAP: 0.3362
#   [CTGAN - DecisionTree]
#     AUROC: 0.8783
#     G-mean: 0.4637
#     MCC: 0.3315
#     F1-score: 0.3283
#     mAP: 0.3306
#   [CTGAN - kNN]
#     AUROC: 0.8142
#     G-mean: 0.6376
#     MCC: 0.3120
#     F1-score: 0.3200
#     mAP: 0.2711
#   [CTGAN - MLP]
#     AUROC: 0.8090
#     G-mean: 0.6662
#     MCC: 0.2673
#     F1-score: 0.2658
#     mAP: 0.2751
#   [CTGAN - RandomForest]
#     AUROC: 0.9274
#     G-mean: 0.3310
#     MCC: 0.2769
#     F1-score: 0.2452
#     mAP: 0.4756
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Original - SVM]
#     AUROC: 0.8419
#     G-mean: 0.0045
#     MCC: 0.0044
#     F1-score: 0.0033
#     mAP: 0.4789
#   [Original - DecisionTree]
#     AUROC: 0.7356
#     G-mean: 0.4761
#     MCC: 0.3032
#     F1-score: 0.3107
#     mAP: 0.2340
#   [Original - kNN]
#     AUROC: 0.7700
#     G-mean: 0.3527
#     MCC: 0.2978
#     F1-score: 0.2620
#     mAP: 0.3278
#   [Original - MLP]
#     AUROC: 0.3427
#     G-mean: 0.0000
#     MCC: -0.0023
#     F1-score: 0.0000
#     mAP: 0.0333
#   [Original - RandomForest]
#     AUROC: 0.9272
#     G-mean: 0.2696
#     MCC: 0.2360
#     F1-score: 0.2024
#     mAP: 0.4641
#   [SMOTE - SVM]
#     AUROC: 0.8958
#     G-mean: 0.7602
#     MCC: 0.3200
#     F1-score: 0.2986
#     mAP: 0.4313
#   [SMOTE - DecisionTree]
#     AUROC: 0.7839
#     G-mean: 0.7011
#     MCC: 0.2660
#     F1-score: 0.2579
#     mAP: 0.2378
#   [SMOTE - kNN]
#     AUROC: 0.8145
#     G-mean: 0.7482
#     MCC: 0.3155
#     F1-score: 0.3009
#     mAP: 0.2366
#   [SMOTE - MLP]
#     AUROC: 0.8760
#     G-mean: 0.7982
#     MCC: 0.3346
#     F1-score: 0.3027
#     mAP: 0.4439
#   [SMOTE - RandomForest]
#     AUROC: 0.9238
#     G-mean: 0.6271
#     MCC: 0.3676
#     F1-score: 0.3816
#     mAP: 0.4587
#   [ADASYN - SVM]
#     AUROC: 0.8920
#     G-mean: 0.7581
#     MCC: 0.3030
#     F1-score: 0.2795
#     mAP: 0.4204
#   [ADASYN - DecisionTree]
#     AUROC: 0.7934
#     G-mean: 0.7145
#     MCC: 0.2805
#     F1-score: 0.2685
#     mAP: 0.2499
#   [ADASYN - kNN]
#     AUROC: 0.8164
#     G-mean: 0.7513
#     MCC: 0.3137
#     F1-score: 0.2974
#     mAP: 0.2300
#   [ADASYN - MLP]
#     AUROC: 0.8769
#     G-mean: 0.7825
#     MCC: 0.3161
#     F1-score: 0.2849
#     mAP: 0.4492
#   [ADASYN - RandomForest]
#     AUROC: 0.9232
#     G-mean: 0.6361
#     MCC: 0.3606
#     F1-score: 0.3741
#     mAP: 0.4487
#   [bSMOTE - SVM]
#     AUROC: 0.8976
#     G-mean: 0.7283
#     MCC: 0.3533
#     F1-score: 0.3486
#     mAP: 0.4401
#   [bSMOTE - DecisionTree]
#     AUROC: 0.7773
#     G-mean: 0.6679
#     MCC: 0.2975
#     F1-score: 0.3030
#     mAP: 0.2377
#   [bSMOTE - kNN]
#     AUROC: 0.8085
#     G-mean: 0.7171
#     MCC: 0.3379
#     F1-score: 0.3367
#     mAP: 0.2624
#   [bSMOTE - MLP]
#     AUROC: 0.8641
#     G-mean: 0.7597
#     MCC: 0.3436
#     F1-score: 0.3276
#     mAP: 0.4419
#   [bSMOTE - RandomForest]
#     AUROC: 0.9237
#     G-mean: 0.5650
#     MCC: 0.3572
#     F1-score: 0.3664
#     mAP: 0.4523
#   [ROS - SVM]
#     AUROC: 0.8959
#     G-mean: 0.7694
#     MCC: 0.3114
#     F1-score: 0.2853
#     mAP: 0.4497
#   [ROS - DecisionTree]
#     AUROC: 0.7387
#     G-mean: 0.6728
#     MCC: 0.2556
#     F1-score: 0.2534
#     mAP: 0.2534
#   [ROS - kNN]
#     AUROC: 0.7660
#     G-mean: 0.6807
#     MCC: 0.3193
#     F1-score: 0.3248
#     mAP: 0.2400
#   [ROS - MLP]
#     AUROC: 0.8854
#     G-mean: 0.8008
#     MCC: 0.3139
#     F1-score: 0.2755
#     mAP: 0.4143
#   [ROS - RandomForest]
#     AUROC: 0.9293
#     G-mean: 0.3853
#     MCC: 0.3087
#     F1-score: 0.2850
#     mAP: 0.4726
#   [MWMOTE - SVM]
#     AUROC: 0.8914
#     G-mean: 0.7349
#     MCC: 0.3165
#     F1-score: 0.3044
#     mAP: 0.4333
#   [MWMOTE - DecisionTree]
#     AUROC: 0.7587
#     G-mean: 0.6699
#     MCC: 0.2788
#     F1-score: 0.2788
#     mAP: 0.2459
#   [MWMOTE - kNN]
#     AUROC: 0.8023
#     G-mean: 0.7222
#     MCC: 0.3206
#     F1-score: 0.3132
#     mAP: 0.2502
#   [MWMOTE - MLP]
#     AUROC: 0.8721
#     G-mean: 0.7958
#     MCC: 0.3514
#     F1-score: 0.3243
#     mAP: 0.4454
#   [MWMOTE - RandomForest]
#     AUROC: 0.9231
#     G-mean: 0.5765
#     MCC: 0.3601
#     F1-score: 0.3708
#     mAP: 0.4584
#   [CTGAN - SVM]
#     AUROC: 0.8479
#     G-mean: 0.6515
#     MCC: 0.3086
#     F1-score: 0.3147
#     mAP: 0.3335
#   [CTGAN - DecisionTree]
#     AUROC: 0.8758
#     G-mean: 0.4688
#     MCC: 0.3358
#     F1-score: 0.3327
#     mAP: 0.3332
#   [CTGAN - kNN]
#     AUROC: 0.8121
#     G-mean: 0.6435
#     MCC: 0.3156
#     F1-score: 0.3237
#     mAP: 0.2725
#   [CTGAN - MLP]
#     AUROC: 0.8075
#     G-mean: 0.6542
#     MCC: 0.2613
#     F1-score: 0.2608
#     mAP: 0.2754
#   [CTGAN - RandomForest]
#     AUROC: 0.9269
#     G-mean: 0.3404
#     MCC: 0.2820
#     F1-score: 0.2517
#     mAP: 0.4655
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/classifiers/yeast4_results_gaussian_beta_0.1.csv
