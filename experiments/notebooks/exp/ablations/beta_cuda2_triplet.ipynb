# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

# Save path 
save_path = "/data4/oldrain123/oldrain123/results/ablation_results/beta8"
data_path = "/data4/oldrain123/oldrain123/dataset"

# %%
import os
import warnings
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from experiment import run_ablation
from imblearn.datasets import fetch_datasets

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
data = fetch_datasets()
methods = ["Ours"]
betas = [1e-1, 5e-2, 1e-2, 5e-3, 1e-3, 0.0]
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}

# %%
data_name = 'wine_quality'
maj_target_name = -1

n_epochs = 2000
hidden_dims = [16, 32, 64, 128, 256]
latent_dim = 512
lr = 0.001
for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        fetch_data_func=fetch_datasets,
        maj_target_name=maj_target_name,
        methods=methods,
        base_models=base_models,
        device=device,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )
# Out:
# beta: 0.1
# Dataset loaded: wine_quality
# X shape : (4898, 11)
# target : Counter({0: 4715, 1: 183})
# IR: 25.77
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.7829
#     G-mean: 0.6283
#     MCC: 0.2187
#     F1-score: 0.2300
#     mAP: 0.1919
#   [Ours - DecisionTree]
#     AUROC: 0.7092
#     G-mean: 0.5023
#     MCC: 0.1538
#     F1-score: 0.1840
#     mAP: 0.1284
#   [Ours - kNN]
#     AUROC: 0.7375
#     G-mean: 0.3124
#     MCC: 0.1970
#     F1-score: 0.1663
#     mAP: 0.1740
#   [Ours - MLP]
#     AUROC: 0.7906
#     G-mean: 0.4713
#     MCC: 0.2190
#     F1-score: 0.2447
#     mAP: 0.2341
#   [Ours - RandomForest]
#     AUROC: 0.9010
#     G-mean: 0.4609
#     MCC: 0.4098
#     F1-score: 0.3407
#     mAP: 0.4956
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.7902
#     G-mean: 0.6199
#     MCC: 0.2198
#     F1-score: 0.2334
#     mAP: 0.1972
#   [Ours - DecisionTree]
#     AUROC: 0.7033
#     G-mean: 0.5025
#     MCC: 0.1725
#     F1-score: 0.2014
#     mAP: 0.1326
#   [Ours - kNN]
#     AUROC: 0.7379
#     G-mean: 0.3135
#     MCC: 0.1814
#     F1-score: 0.1651
#     mAP: 0.1724
#   [Ours - MLP]
#     AUROC: 0.7861
#     G-mean: 0.4730
#     MCC: 0.2357
#     F1-score: 0.2572
#     mAP: 0.2484
#   [Ours - RandomForest]
#     AUROC: 0.8986
#     G-mean: 0.4429
#     MCC: 0.3933
#     F1-score: 0.3190
#     mAP: 0.4979
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.7899
#     G-mean: 0.6310
#     MCC: 0.2306
#     F1-score: 0.2430
#     mAP: 0.2097
#   [Ours - DecisionTree]
#     AUROC: 0.7107
#     G-mean: 0.4927
#     MCC: 0.1702
#     F1-score: 0.1999
#     mAP: 0.1435
#   [Ours - kNN]
#     AUROC: 0.7400
#     G-mean: 0.3149
#     MCC: 0.1878
#     F1-score: 0.1732
#     mAP: 0.1754
#   [Ours - MLP]
#     AUROC: 0.7818
#     G-mean: 0.4863
#     MCC: 0.2488
#     F1-score: 0.2694
#     mAP: 0.2475
#   [Ours - RandomForest]
#     AUROC: 0.9012
#     G-mean: 0.4460
#     MCC: 0.3881
#     F1-score: 0.3208
#     mAP: 0.4988
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.7875
#     G-mean: 0.6221
#     MCC: 0.2259
#     F1-score: 0.2392
#     mAP: 0.2110
#   [Ours - DecisionTree]
#     AUROC: 0.7111
#     G-mean: 0.4937
#     MCC: 0.1773
#     F1-score: 0.2066
#     mAP: 0.1485
#   [Ours - kNN]
#     AUROC: 0.7408
#     G-mean: 0.3176
#     MCC: 0.1874
#     F1-score: 0.1748
#     mAP: 0.1777
#   [Ours - MLP]
#     AUROC: 0.7824
#     G-mean: 0.4876
#     MCC: 0.2482
#     F1-score: 0.2688
#     mAP: 0.2467
#   [Ours - RandomForest]
#     AUROC: 0.9025
#     G-mean: 0.4418
#     MCC: 0.3832
#     F1-score: 0.3157
#     mAP: 0.4940
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.7897
#     G-mean: 0.6132
#     MCC: 0.2195
#     F1-score: 0.2339
#     mAP: 0.2115
#   [Ours - DecisionTree]
#     AUROC: 0.7104
#     G-mean: 0.5014
#     MCC: 0.1840
#     F1-score: 0.2123
#     mAP: 0.1532
#   [Ours - kNN]
#     AUROC: 0.7386
#     G-mean: 0.3168
#     MCC: 0.1860
#     F1-score: 0.1734
#     mAP: 0.1745
#   [Ours - MLP]
#     AUROC: 0.7826
#     G-mean: 0.4811
#     MCC: 0.2397
#     F1-score: 0.2610
#     mAP: 0.2491
#   [Ours - RandomForest]
#     AUROC: 0.9029
#     G-mean: 0.4426
#     MCC: 0.3837
#     F1-score: 0.3166
#     mAP: 0.4902
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.7903
#     G-mean: 0.6163
#     MCC: 0.2178
#     F1-score: 0.2314
#     mAP: 0.2133
#   [Ours - DecisionTree]
#     AUROC: 0.7108
#     G-mean: 0.4984
#     MCC: 0.1811
#     F1-score: 0.2100
#     mAP: 0.1556
#   [Ours - kNN]
#     AUROC: 0.7380
#     G-mean: 0.3175
#     MCC: 0.1893
#     F1-score: 0.1749
#     mAP: 0.1751
#   [Ours - MLP]
#     AUROC: 0.7820
#     G-mean: 0.4812
#     MCC: 0.2428
#     F1-score: 0.2636
#     mAP: 0.2482
#   [Ours - RandomForest]
#     AUROC: 0.9047
#     G-mean: 0.4431
#     MCC: 0.3857
#     F1-score: 0.3180
#     mAP: 0.4941
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.7930
#     G-mean: 0.6185
#     MCC: 0.2188
#     F1-score: 0.2325
#     mAP: 0.2170
#   [Ours - DecisionTree]
#     AUROC: 0.7050
#     G-mean: 0.4950
#     MCC: 0.1799
#     F1-score: 0.2083
#     mAP: 0.1537
#   [Ours - kNN]
#     AUROC: 0.7375
#     G-mean: 0.3106
#     MCC: 0.1812
#     F1-score: 0.1692
#     mAP: 0.1731
#   [Ours - MLP]
#     AUROC: 0.7826
#     G-mean: 0.4863
#     MCC: 0.2446
#     F1-score: 0.2656
#     mAP: 0.2485
#   [Ours - RandomForest]
#     AUROC: 0.9051
#     G-mean: 0.4383
#     MCC: 0.3831
#     F1-score: 0.3161
#     mAP: 0.4928
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.7923
#     G-mean: 0.6196
#     MCC: 0.2201
#     F1-score: 0.2341
#     mAP: 0.2198
#   [Ours - DecisionTree]
#     AUROC: 0.6998
#     G-mean: 0.4942
#     MCC: 0.1790
#     F1-score: 0.2074
#     mAP: 0.1519
#   [Ours - kNN]
#     AUROC: 0.7361
#     G-mean: 0.3111
#     MCC: 0.1811
#     F1-score: 0.1692
#     mAP: 0.1720
#   [Ours - MLP]
#     AUROC: 0.7811
#     G-mean: 0.4855
#     MCC: 0.2425
#     F1-score: 0.2641
#     mAP: 0.2477
#   [Ours - RandomForest]
#     AUROC: 0.9031
#     G-mean: 0.4362
#     MCC: 0.3801
#     F1-score: 0.3127
#     mAP: 0.4901
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.7933
#     G-mean: 0.6198
#     MCC: 0.2214
#     F1-score: 0.2351
#     mAP: 0.2196
#   [Ours - DecisionTree]
#     AUROC: 0.6982
#     G-mean: 0.4929
#     MCC: 0.1778
#     F1-score: 0.2065
#     mAP: 0.1497
#   [Ours - kNN]
#     AUROC: 0.7346
#     G-mean: 0.3093
#     MCC: 0.1811
#     F1-score: 0.1679
#     mAP: 0.1723
#   [Ours - MLP]
#     AUROC: 0.7837
#     G-mean: 0.4853
#     MCC: 0.2398
#     F1-score: 0.2618
#     mAP: 0.2476
#   [Ours - RandomForest]
#     AUROC: 0.9033
#     G-mean: 0.4333
#     MCC: 0.3796
#     F1-score: 0.3116
#     mAP: 0.4896
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.7931
#     G-mean: 0.6231
#     MCC: 0.2238
#     F1-score: 0.2365
#     mAP: 0.2239
#   [Ours - DecisionTree]
#     AUROC: 0.6992
#     G-mean: 0.4881
#     MCC: 0.1755
#     F1-score: 0.2044
#     mAP: 0.1509
#   [Ours - kNN]
#     AUROC: 0.7338
#     G-mean: 0.3102
#     MCC: 0.1813
#     F1-score: 0.1681
#     mAP: 0.1724
#   [Ours - MLP]
#     AUROC: 0.7838
#     G-mean: 0.4875
#     MCC: 0.2404
#     F1-score: 0.2628
#     mAP: 0.2498
#   [Ours - RandomForest]
#     AUROC: 0.9028
#     G-mean: 0.4336
#     MCC: 0.3785
#     F1-score: 0.3126
#     mAP: 0.4904
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/wine_quality_results_gaussian_beta_0.1.csv
# beta: 0.05
# Dataset loaded: wine_quality
# X shape : (4898, 11)
# target : Counter({0: 4715, 1: 183})
# IR: 25.77
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.7999
#     G-mean: 0.5628
#     MCC: 0.2251
#     F1-score: 0.2527
#     mAP: 0.2203
#   [Ours - DecisionTree]
#     AUROC: 0.6978
#     G-mean: 0.5532
#     MCC: 0.1658
#     F1-score: 0.1912
#     mAP: 0.1406
#   [Ours - kNN]
#     AUROC: 0.7452
#     G-mean: 0.4231
#     MCC: 0.2184
#     F1-score: 0.2317
#     mAP: 0.1720
#   [Ours - MLP]
#     AUROC: 0.8025
#     G-mean: 0.5037
#     MCC: 0.2211
#     F1-score: 0.2494
#     mAP: 0.2765
#   [Ours - RandomForest]
#     AUROC: 0.9018
#     G-mean: 0.5189
#     MCC: 0.4157
#     F1-score: 0.3863
#     mAP: 0.4554
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.7961
#     G-mean: 0.5556
#     MCC: 0.2225
#     F1-score: 0.2512
#     mAP: 0.2250
#   [Ours - DecisionTree]
#     AUROC: 0.7067
#     G-mean: 0.5668
#     MCC: 0.1783
#     F1-score: 0.2021
#     mAP: 0.1565
#   [Ours - kNN]
#     AUROC: 0.7433
#     G-mean: 0.4071
#     MCC: 0.2006
#     F1-score: 0.2152
#     mAP: 0.1717
#   [Ours - MLP]
#     AUROC: 0.8028
#     G-mean: 0.5217
#     MCC: 0.2415
#     F1-score: 0.2691
#     mAP: 0.2797
#   [Ours - RandomForest]
#     AUROC: 0.9013
#     G-mean: 0.5141
#     MCC: 0.4161
#     F1-score: 0.3814
#     mAP: 0.4699
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.7951
#     G-mean: 0.5580
#     MCC: 0.2218
#     F1-score: 0.2500
#     mAP: 0.2228
#   [Ours - DecisionTree]
#     AUROC: 0.7123
#     G-mean: 0.5625
#     MCC: 0.1800
#     F1-score: 0.2049
#     mAP: 0.1550
#   [Ours - kNN]
#     AUROC: 0.7453
#     G-mean: 0.4000
#     MCC: 0.2043
#     F1-score: 0.2190
#     mAP: 0.1756
#   [Ours - MLP]
#     AUROC: 0.8019
#     G-mean: 0.5354
#     MCC: 0.2543
#     F1-score: 0.2817
#     mAP: 0.2735
#   [Ours - RandomForest]
#     AUROC: 0.9038
#     G-mean: 0.5134
#     MCC: 0.4143
#     F1-score: 0.3827
#     mAP: 0.4686
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.7980
#     G-mean: 0.5549
#     MCC: 0.2221
#     F1-score: 0.2506
#     mAP: 0.2286
#   [Ours - DecisionTree]
#     AUROC: 0.7215
#     G-mean: 0.5532
#     MCC: 0.1850
#     F1-score: 0.2109
#     mAP: 0.1594
#   [Ours - kNN]
#     AUROC: 0.7457
#     G-mean: 0.4088
#     MCC: 0.2090
#     F1-score: 0.2241
#     mAP: 0.1790
#   [Ours - MLP]
#     AUROC: 0.8090
#     G-mean: 0.5335
#     MCC: 0.2536
#     F1-score: 0.2812
#     mAP: 0.2783
#   [Ours - RandomForest]
#     AUROC: 0.9047
#     G-mean: 0.5101
#     MCC: 0.4093
#     F1-score: 0.3783
#     mAP: 0.4750
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.7979
#     G-mean: 0.5512
#     MCC: 0.2204
#     F1-score: 0.2492
#     mAP: 0.2266
#   [Ours - DecisionTree]
#     AUROC: 0.7187
#     G-mean: 0.5552
#     MCC: 0.1852
#     F1-score: 0.2102
#     mAP: 0.1514
#   [Ours - kNN]
#     AUROC: 0.7431
#     G-mean: 0.4048
#     MCC: 0.2042
#     F1-score: 0.2203
#     mAP: 0.1745
#   [Ours - MLP]
#     AUROC: 0.8092
#     G-mean: 0.5363
#     MCC: 0.2539
#     F1-score: 0.2813
#     mAP: 0.2796
#   [Ours - RandomForest]
#     AUROC: 0.9058
#     G-mean: 0.5057
#     MCC: 0.4031
#     F1-score: 0.3727
#     mAP: 0.4728
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.7969
#     G-mean: 0.5477
#     MCC: 0.2194
#     F1-score: 0.2480
#     mAP: 0.2267
#   [Ours - DecisionTree]
#     AUROC: 0.7175
#     G-mean: 0.5553
#     MCC: 0.1846
#     F1-score: 0.2097
#     mAP: 0.1517
#   [Ours - kNN]
#     AUROC: 0.7424
#     G-mean: 0.4083
#     MCC: 0.2071
#     F1-score: 0.2227
#     mAP: 0.1751
#   [Ours - MLP]
#     AUROC: 0.8089
#     G-mean: 0.5382
#     MCC: 0.2538
#     F1-score: 0.2811
#     mAP: 0.2793
#   [Ours - RandomForest]
#     AUROC: 0.9060
#     G-mean: 0.5093
#     MCC: 0.4099
#     F1-score: 0.3784
#     mAP: 0.4736
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.7991
#     G-mean: 0.5510
#     MCC: 0.2224
#     F1-score: 0.2508
#     mAP: 0.2284
#   [Ours - DecisionTree]
#     AUROC: 0.7154
#     G-mean: 0.5588
#     MCC: 0.1891
#     F1-score: 0.2138
#     mAP: 0.1518
#   [Ours - kNN]
#     AUROC: 0.7422
#     G-mean: 0.4030
#     MCC: 0.2003
#     F1-score: 0.2167
#     mAP: 0.1729
#   [Ours - MLP]
#     AUROC: 0.8088
#     G-mean: 0.5356
#     MCC: 0.2505
#     F1-score: 0.2776
#     mAP: 0.2791
#   [Ours - RandomForest]
#     AUROC: 0.9054
#     G-mean: 0.5050
#     MCC: 0.4030
#     F1-score: 0.3734
#     mAP: 0.4713
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.8001
#     G-mean: 0.5516
#     MCC: 0.2225
#     F1-score: 0.2508
#     mAP: 0.2261
#   [Ours - DecisionTree]
#     AUROC: 0.7172
#     G-mean: 0.5623
#     MCC: 0.1940
#     F1-score: 0.2186
#     mAP: 0.1542
#   [Ours - kNN]
#     AUROC: 0.7425
#     G-mean: 0.4058
#     MCC: 0.2033
#     F1-score: 0.2193
#     mAP: 0.1748
#   [Ours - MLP]
#     AUROC: 0.8095
#     G-mean: 0.5367
#     MCC: 0.2505
#     F1-score: 0.2774
#     mAP: 0.2771
#   [Ours - RandomForest]
#     AUROC: 0.9050
#     G-mean: 0.5052
#     MCC: 0.4054
#     F1-score: 0.3737
#     mAP: 0.4699
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.8001
#     G-mean: 0.5525
#     MCC: 0.2251
#     F1-score: 0.2532
#     mAP: 0.2270
#   [Ours - DecisionTree]
#     AUROC: 0.7130
#     G-mean: 0.5602
#     MCC: 0.1931
#     F1-score: 0.2180
#     mAP: 0.1520
#   [Ours - kNN]
#     AUROC: 0.7432
#     G-mean: 0.4055
#     MCC: 0.2034
#     F1-score: 0.2193
#     mAP: 0.1755
#   [Ours - MLP]
#     AUROC: 0.8094
#     G-mean: 0.5369
#     MCC: 0.2506
#     F1-score: 0.2777
#     mAP: 0.2790
#   [Ours - RandomForest]
#     AUROC: 0.9054
#     G-mean: 0.5037
#     MCC: 0.4050
#     F1-score: 0.3721
#     mAP: 0.4683
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.8012
#     G-mean: 0.5563
#     MCC: 0.2272
#     F1-score: 0.2550
#     mAP: 0.2290
#   [Ours - DecisionTree]
#     AUROC: 0.7117
#     G-mean: 0.5590
#     MCC: 0.1913
#     F1-score: 0.2164
#     mAP: 0.1496
#   [Ours - kNN]
#     AUROC: 0.7426
#     G-mean: 0.4065
#     MCC: 0.2058
#     F1-score: 0.2217
#     mAP: 0.1769
#   [Ours - MLP]
#     AUROC: 0.8103
#     G-mean: 0.5396
#     MCC: 0.2526
#     F1-score: 0.2797
#     mAP: 0.2793
#   [Ours - RandomForest]
#     AUROC: 0.9047
#     G-mean: 0.5020
#     MCC: 0.4014
#     F1-score: 0.3695
#     mAP: 0.4677
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/wine_quality_results_gaussian_beta_0.05.csv
# beta: 0.01
# Dataset loaded: wine_quality
# X shape : (4898, 11)
# target : Counter({0: 4715, 1: 183})
# IR: 25.77
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.8075
#     G-mean: 0.6740
#     MCC: 0.2391
#     F1-score: 0.2453
#     mAP: 0.2063
#   [Ours - DecisionTree]
#     AUROC: 0.7364
#     G-mean: 0.6862
#     MCC: 0.1944
#     F1-score: 0.1899
#     mAP: 0.1941
#   [Ours - kNN]
#     AUROC: 0.7689
#     G-mean: 0.6272
#     MCC: 0.2295
#     F1-score: 0.2469
#     mAP: 0.1429
#   [Ours - MLP]
#     AUROC: 0.7933
#     G-mean: 0.6290
#     MCC: 0.2370
#     F1-score: 0.2545
#     mAP: 0.2558
#   [Ours - RandomForest]
#     AUROC: 0.9037
#     G-mean: 0.7083
#     MCC: 0.3937
#     F1-score: 0.4088
#     mAP: 0.3918
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.8101
#     G-mean: 0.6828
#     MCC: 0.2431
#     F1-score: 0.2460
#     mAP: 0.2330
#   [Ours - DecisionTree]
#     AUROC: 0.7530
#     G-mean: 0.6870
#     MCC: 0.2037
#     F1-score: 0.1985
#     mAP: 0.1950
#   [Ours - kNN]
#     AUROC: 0.7706
#     G-mean: 0.6242
#     MCC: 0.2264
#     F1-score: 0.2443
#     mAP: 0.1513
#   [Ours - MLP]
#     AUROC: 0.7975
#     G-mean: 0.6430
#     MCC: 0.2481
#     F1-score: 0.2629
#     mAP: 0.2830
#   [Ours - RandomForest]
#     AUROC: 0.8999
#     G-mean: 0.7110
#     MCC: 0.3954
#     F1-score: 0.4109
#     mAP: 0.3959
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.8106
#     G-mean: 0.6719
#     MCC: 0.2398
#     F1-score: 0.2454
#     mAP: 0.2376
#   [Ours - DecisionTree]
#     AUROC: 0.7506
#     G-mean: 0.6856
#     MCC: 0.2031
#     F1-score: 0.1990
#     mAP: 0.1846
#   [Ours - kNN]
#     AUROC: 0.7632
#     G-mean: 0.6130
#     MCC: 0.2191
#     F1-score: 0.2384
#     mAP: 0.1491
#   [Ours - MLP]
#     AUROC: 0.7978
#     G-mean: 0.6389
#     MCC: 0.2530
#     F1-score: 0.2689
#     mAP: 0.2853
#   [Ours - RandomForest]
#     AUROC: 0.8983
#     G-mean: 0.7090
#     MCC: 0.3931
#     F1-score: 0.4086
#     mAP: 0.3965
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.8156
#     G-mean: 0.6798
#     MCC: 0.2465
#     F1-score: 0.2507
#     mAP: 0.2493
#   [Ours - DecisionTree]
#     AUROC: 0.7559
#     G-mean: 0.6946
#     MCC: 0.2115
#     F1-score: 0.2056
#     mAP: 0.1831
#   [Ours - kNN]
#     AUROC: 0.7711
#     G-mean: 0.6220
#     MCC: 0.2284
#     F1-score: 0.2462
#     mAP: 0.1577
#   [Ours - MLP]
#     AUROC: 0.8052
#     G-mean: 0.6403
#     MCC: 0.2545
#     F1-score: 0.2702
#     mAP: 0.2886
#   [Ours - RandomForest]
#     AUROC: 0.9004
#     G-mean: 0.7142
#     MCC: 0.3982
#     F1-score: 0.4134
#     mAP: 0.4079
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.8168
#     G-mean: 0.6793
#     MCC: 0.2455
#     F1-score: 0.2498
#     mAP: 0.2459
#   [Ours - DecisionTree]
#     AUROC: 0.7552
#     G-mean: 0.6932
#     MCC: 0.2103
#     F1-score: 0.2047
#     mAP: 0.1792
#   [Ours - kNN]
#     AUROC: 0.7699
#     G-mean: 0.6129
#     MCC: 0.2223
#     F1-score: 0.2408
#     mAP: 0.1540
#   [Ours - MLP]
#     AUROC: 0.8047
#     G-mean: 0.6389
#     MCC: 0.2519
#     F1-score: 0.2677
#     mAP: 0.2860
#   [Ours - RandomForest]
#     AUROC: 0.8988
#     G-mean: 0.7124
#     MCC: 0.3959
#     F1-score: 0.4111
#     mAP: 0.4037
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.8158
#     G-mean: 0.6832
#     MCC: 0.2480
#     F1-score: 0.2512
#     mAP: 0.2405
#   [Ours - DecisionTree]
#     AUROC: 0.7534
#     G-mean: 0.6919
#     MCC: 0.2080
#     F1-score: 0.2026
#     mAP: 0.1799
#   [Ours - kNN]
#     AUROC: 0.7713
#     G-mean: 0.6119
#     MCC: 0.2207
#     F1-score: 0.2391
#     mAP: 0.1555
#   [Ours - MLP]
#     AUROC: 0.8057
#     G-mean: 0.6371
#     MCC: 0.2510
#     F1-score: 0.2669
#     mAP: 0.2851
#   [Ours - RandomForest]
#     AUROC: 0.8999
#     G-mean: 0.7158
#     MCC: 0.4000
#     F1-score: 0.4150
#     mAP: 0.4048
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.8161
#     G-mean: 0.6810
#     MCC: 0.2471
#     F1-score: 0.2507
#     mAP: 0.2398
#   [Ours - DecisionTree]
#     AUROC: 0.7513
#     G-mean: 0.6903
#     MCC: 0.2040
#     F1-score: 0.1986
#     mAP: 0.1777
#   [Ours - kNN]
#     AUROC: 0.7716
#     G-mean: 0.6141
#     MCC: 0.2226
#     F1-score: 0.2409
#     mAP: 0.1557
#   [Ours - MLP]
#     AUROC: 0.8060
#     G-mean: 0.6374
#     MCC: 0.2504
#     F1-score: 0.2662
#     mAP: 0.2795
#   [Ours - RandomForest]
#     AUROC: 0.8996
#     G-mean: 0.7135
#     MCC: 0.3985
#     F1-score: 0.4139
#     mAP: 0.4029
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.8149
#     G-mean: 0.6818
#     MCC: 0.2476
#     F1-score: 0.2508
#     mAP: 0.2379
#   [Ours - DecisionTree]
#     AUROC: 0.7503
#     G-mean: 0.6886
#     MCC: 0.2030
#     F1-score: 0.1983
#     mAP: 0.1756
#   [Ours - kNN]
#     AUROC: 0.7711
#     G-mean: 0.6162
#     MCC: 0.2255
#     F1-score: 0.2436
#     mAP: 0.1585
#   [Ours - MLP]
#     AUROC: 0.8059
#     G-mean: 0.6413
#     MCC: 0.2535
#     F1-score: 0.2686
#     mAP: 0.2792
#   [Ours - RandomForest]
#     AUROC: 0.8993
#     G-mean: 0.7138
#     MCC: 0.3985
#     F1-score: 0.4138
#     mAP: 0.4056
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.8149
#     G-mean: 0.6835
#     MCC: 0.2488
#     F1-score: 0.2518
#     mAP: 0.2373
#   [Ours - DecisionTree]
#     AUROC: 0.7532
#     G-mean: 0.6928
#     MCC: 0.2072
#     F1-score: 0.2014
#     mAP: 0.1778
#   [Ours - kNN]
#     AUROC: 0.7692
#     G-mean: 0.6160
#     MCC: 0.2253
#     F1-score: 0.2435
#     mAP: 0.1579
#   [Ours - MLP]
#     AUROC: 0.8056
#     G-mean: 0.6437
#     MCC: 0.2541
#     F1-score: 0.2687
#     mAP: 0.2803
#   [Ours - RandomForest]
#     AUROC: 0.8987
#     G-mean: 0.7113
#     MCC: 0.3967
#     F1-score: 0.4124
#     mAP: 0.4046
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.8154
#     G-mean: 0.6840
#     MCC: 0.2483
#     F1-score: 0.2509
#     mAP: 0.2372
#   [Ours - DecisionTree]
#     AUROC: 0.7533
#     G-mean: 0.6934
#     MCC: 0.2077
#     F1-score: 0.2017
#     mAP: 0.1765
#   [Ours - kNN]
#     AUROC: 0.7692
#     G-mean: 0.6166
#     MCC: 0.2250
#     F1-score: 0.2431
#     mAP: 0.1571
#   [Ours - MLP]
#     AUROC: 0.8061
#     G-mean: 0.6461
#     MCC: 0.2550
#     F1-score: 0.2690
#     mAP: 0.2828
#   [Ours - RandomForest]
#     AUROC: 0.8996
#     G-mean: 0.7100
#     MCC: 0.3952
#     F1-score: 0.4110
#     mAP: 0.4064
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/wine_quality_results_gaussian_beta_0.01.csv
# beta: 0.005
# Dataset loaded: wine_quality
# X shape : (4898, 11)
# target : Counter({0: 4715, 1: 183})
# IR: 25.77
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.8125
#     G-mean: 0.6983
#     MCC: 0.2455
#     F1-score: 0.2448
#     mAP: 0.2245
#   [Ours - DecisionTree]
#     AUROC: 0.7609
#     G-mean: 0.6859
#     MCC: 0.1925
#     F1-score: 0.1889
#     mAP: 0.1529
#   [Ours - kNN]
#     AUROC: 0.7658
#     G-mean: 0.6050
#     MCC: 0.1935
#     F1-score: 0.2119
#     mAP: 0.1359
#   [Ours - MLP]
#     AUROC: 0.7811
#     G-mean: 0.6155
#     MCC: 0.2218
#     F1-score: 0.2412
#     mAP: 0.2649
#   [Ours - RandomForest]
#     AUROC: 0.9023
#     G-mean: 0.7255
#     MCC: 0.3771
#     F1-score: 0.3868
#     mAP: 0.3747
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.8101
#     G-mean: 0.6949
#     MCC: 0.2440
#     F1-score: 0.2434
#     mAP: 0.2347
#   [Ours - DecisionTree]
#     AUROC: 0.7653
#     G-mean: 0.6992
#     MCC: 0.2067
#     F1-score: 0.1991
#     mAP: 0.1612
#   [Ours - kNN]
#     AUROC: 0.7606
#     G-mean: 0.6118
#     MCC: 0.2046
#     F1-score: 0.2228
#     mAP: 0.1488
#   [Ours - MLP]
#     AUROC: 0.7817
#     G-mean: 0.6135
#     MCC: 0.2296
#     F1-score: 0.2495
#     mAP: 0.2753
#   [Ours - RandomForest]
#     AUROC: 0.8966
#     G-mean: 0.7324
#     MCC: 0.3858
#     F1-score: 0.3954
#     mAP: 0.3740
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.8083
#     G-mean: 0.6850
#     MCC: 0.2430
#     F1-score: 0.2453
#     mAP: 0.2353
#   [Ours - DecisionTree]
#     AUROC: 0.7586
#     G-mean: 0.6833
#     MCC: 0.2004
#     F1-score: 0.1978
#     mAP: 0.1649
#   [Ours - kNN]
#     AUROC: 0.7664
#     G-mean: 0.6087
#     MCC: 0.2032
#     F1-score: 0.2221
#     mAP: 0.1494
#   [Ours - MLP]
#     AUROC: 0.7842
#     G-mean: 0.6171
#     MCC: 0.2359
#     F1-score: 0.2558
#     mAP: 0.2757
#   [Ours - RandomForest]
#     AUROC: 0.8977
#     G-mean: 0.7273
#     MCC: 0.3858
#     F1-score: 0.3967
#     mAP: 0.3817
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.8142
#     G-mean: 0.6923
#     MCC: 0.2492
#     F1-score: 0.2495
#     mAP: 0.2470
#   [Ours - DecisionTree]
#     AUROC: 0.7678
#     G-mean: 0.6925
#     MCC: 0.2114
#     F1-score: 0.2064
#     mAP: 0.1682
#   [Ours - kNN]
#     AUROC: 0.7718
#     G-mean: 0.6198
#     MCC: 0.2121
#     F1-score: 0.2289
#     mAP: 0.1581
#   [Ours - MLP]
#     AUROC: 0.7943
#     G-mean: 0.6226
#     MCC: 0.2429
#     F1-score: 0.2621
#     mAP: 0.2837
#   [Ours - RandomForest]
#     AUROC: 0.8995
#     G-mean: 0.7297
#     MCC: 0.3870
#     F1-score: 0.3974
#     mAP: 0.3922
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.8157
#     G-mean: 0.6906
#     MCC: 0.2480
#     F1-score: 0.2487
#     mAP: 0.2511
#   [Ours - DecisionTree]
#     AUROC: 0.7650
#     G-mean: 0.6895
#     MCC: 0.2069
#     F1-score: 0.2023
#     mAP: 0.1642
#   [Ours - kNN]
#     AUROC: 0.7709
#     G-mean: 0.6160
#     MCC: 0.2096
#     F1-score: 0.2262
#     mAP: 0.1578
#   [Ours - MLP]
#     AUROC: 0.7959
#     G-mean: 0.6237
#     MCC: 0.2440
#     F1-score: 0.2631
#     mAP: 0.2855
#   [Ours - RandomForest]
#     AUROC: 0.8994
#     G-mean: 0.7304
#     MCC: 0.3894
#     F1-score: 0.3998
#     mAP: 0.3852
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.8148
#     G-mean: 0.6900
#     MCC: 0.2460
#     F1-score: 0.2463
#     mAP: 0.2500
#   [Ours - DecisionTree]
#     AUROC: 0.7649
#     G-mean: 0.6896
#     MCC: 0.2059
#     F1-score: 0.2011
#     mAP: 0.1641
#   [Ours - kNN]
#     AUROC: 0.7733
#     G-mean: 0.6162
#     MCC: 0.2090
#     F1-score: 0.2252
#     mAP: 0.1587
#   [Ours - MLP]
#     AUROC: 0.7946
#     G-mean: 0.6227
#     MCC: 0.2416
#     F1-score: 0.2603
#     mAP: 0.2783
#   [Ours - RandomForest]
#     AUROC: 0.9011
#     G-mean: 0.7312
#     MCC: 0.3913
#     F1-score: 0.4021
#     mAP: 0.3905
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.8140
#     G-mean: 0.6846
#     MCC: 0.2418
#     F1-score: 0.2431
#     mAP: 0.2476
#   [Ours - DecisionTree]
#     AUROC: 0.7605
#     G-mean: 0.6882
#     MCC: 0.2028
#     F1-score: 0.1981
#     mAP: 0.1649
#   [Ours - kNN]
#     AUROC: 0.7736
#     G-mean: 0.6202
#     MCC: 0.2137
#     F1-score: 0.2295
#     mAP: 0.1587
#   [Ours - MLP]
#     AUROC: 0.7944
#     G-mean: 0.6214
#     MCC: 0.2401
#     F1-score: 0.2586
#     mAP: 0.2741
#   [Ours - RandomForest]
#     AUROC: 0.9000
#     G-mean: 0.7317
#     MCC: 0.3925
#     F1-score: 0.4032
#     mAP: 0.3902
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.8132
#     G-mean: 0.6839
#     MCC: 0.2405
#     F1-score: 0.2418
#     mAP: 0.2456
#   [Ours - DecisionTree]
#     AUROC: 0.7618
#     G-mean: 0.6886
#     MCC: 0.2027
#     F1-score: 0.1978
#     mAP: 0.1633
#   [Ours - kNN]
#     AUROC: 0.7740
#     G-mean: 0.6231
#     MCC: 0.2162
#     F1-score: 0.2316
#     mAP: 0.1601
#   [Ours - MLP]
#     AUROC: 0.7937
#     G-mean: 0.6253
#     MCC: 0.2434
#     F1-score: 0.2613
#     mAP: 0.2735
#   [Ours - RandomForest]
#     AUROC: 0.9003
#     G-mean: 0.7307
#     MCC: 0.3913
#     F1-score: 0.4020
#     mAP: 0.3945
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.8135
#     G-mean: 0.6843
#     MCC: 0.2409
#     F1-score: 0.2422
#     mAP: 0.2446
#   [Ours - DecisionTree]
#     AUROC: 0.7619
#     G-mean: 0.6873
#     MCC: 0.2023
#     F1-score: 0.1980
#     mAP: 0.1644
#   [Ours - kNN]
#     AUROC: 0.7729
#     G-mean: 0.6208
#     MCC: 0.2140
#     F1-score: 0.2299
#     mAP: 0.1592
#   [Ours - MLP]
#     AUROC: 0.7929
#     G-mean: 0.6268
#     MCC: 0.2439
#     F1-score: 0.2615
#     mAP: 0.2755
#   [Ours - RandomForest]
#     AUROC: 0.8998
#     G-mean: 0.7282
#     MCC: 0.3899
#     F1-score: 0.4011
#     mAP: 0.3959
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.8140
#     G-mean: 0.6843
#     MCC: 0.2403
#     F1-score: 0.2415
#     mAP: 0.2446
#   [Ours - DecisionTree]
#     AUROC: 0.7619
#     G-mean: 0.6909
#     MCC: 0.2061
#     F1-score: 0.2008
#     mAP: 0.1658
#   [Ours - kNN]
#     AUROC: 0.7721
#     G-mean: 0.6225
#     MCC: 0.2149
#     F1-score: 0.2306
#     mAP: 0.1584
#   [Ours - MLP]
#     AUROC: 0.7935
#     G-mean: 0.6286
#     MCC: 0.2447
#     F1-score: 0.2620
#     mAP: 0.2771
#   [Ours - RandomForest]
#     AUROC: 0.8997
#     G-mean: 0.7281
#     MCC: 0.3890
#     F1-score: 0.4000
#     mAP: 0.3986
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/wine_quality_results_gaussian_beta_0.005.csv
# beta: 0.001
# Dataset loaded: wine_quality
# X shape : (4898, 11)
# target : Counter({0: 4715, 1: 183})
# IR: 25.77
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.7996
#     G-mean: 0.6877
#     MCC: 0.2479
#     F1-score: 0.2509
#     mAP: 0.2258
#   [Ours - DecisionTree]
#     AUROC: 0.7559
#     G-mean: 0.6700
#     MCC: 0.1909
#     F1-score: 0.1926
#     mAP: 0.1789
#   [Ours - kNN]
#     AUROC: 0.7719
#     G-mean: 0.6186
#     MCC: 0.2116
#     F1-score: 0.2286
#     mAP: 0.1515
#   [Ours - MLP]
#     AUROC: 0.7749
#     G-mean: 0.5816
#     MCC: 0.2169
#     F1-score: 0.2406
#     mAP: 0.2692
#   [Ours - RandomForest]
#     AUROC: 0.9065
#     G-mean: 0.7320
#     MCC: 0.3837
#     F1-score: 0.3938
#     mAP: 0.3829
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.8001
#     G-mean: 0.6820
#     MCC: 0.2428
#     F1-score: 0.2463
#     mAP: 0.2335
#   [Ours - DecisionTree]
#     AUROC: 0.7702
#     G-mean: 0.6928
#     MCC: 0.2111
#     F1-score: 0.2063
#     mAP: 0.1864
#   [Ours - kNN]
#     AUROC: 0.7721
#     G-mean: 0.6220
#     MCC: 0.2169
#     F1-score: 0.2334
#     mAP: 0.1579
#   [Ours - MLP]
#     AUROC: 0.7740
#     G-mean: 0.5901
#     MCC: 0.2159
#     F1-score: 0.2389
#     mAP: 0.2648
#   [Ours - RandomForest]
#     AUROC: 0.8990
#     G-mean: 0.7298
#     MCC: 0.3892
#     F1-score: 0.4006
#     mAP: 0.3825
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.7946
#     G-mean: 0.6672
#     MCC: 0.2380
#     F1-score: 0.2452
#     mAP: 0.2291
#   [Ours - DecisionTree]
#     AUROC: 0.7634
#     G-mean: 0.6816
#     MCC: 0.2014
#     F1-score: 0.1995
#     mAP: 0.1765
#   [Ours - kNN]
#     AUROC: 0.7686
#     G-mean: 0.6074
#     MCC: 0.2107
#     F1-score: 0.2292
#     mAP: 0.1555
#   [Ours - MLP]
#     AUROC: 0.7728
#     G-mean: 0.5832
#     MCC: 0.2196
#     F1-score: 0.2432
#     mAP: 0.2614
#   [Ours - RandomForest]
#     AUROC: 0.8993
#     G-mean: 0.7303
#     MCC: 0.4010
#     F1-score: 0.4130
#     mAP: 0.3903
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.8011
#     G-mean: 0.6731
#     MCC: 0.2412
#     F1-score: 0.2467
#     mAP: 0.2420
#   [Ours - DecisionTree]
#     AUROC: 0.7651
#     G-mean: 0.6865
#     MCC: 0.2089
#     F1-score: 0.2056
#     mAP: 0.1783
#   [Ours - kNN]
#     AUROC: 0.7752
#     G-mean: 0.6119
#     MCC: 0.2123
#     F1-score: 0.2299
#     mAP: 0.1580
#   [Ours - MLP]
#     AUROC: 0.7802
#     G-mean: 0.5980
#     MCC: 0.2296
#     F1-score: 0.2512
#     mAP: 0.2719
#   [Ours - RandomForest]
#     AUROC: 0.9004
#     G-mean: 0.7358
#     MCC: 0.4046
#     F1-score: 0.4158
#     mAP: 0.4006
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.8034
#     G-mean: 0.6725
#     MCC: 0.2405
#     F1-score: 0.2459
#     mAP: 0.2478
#   [Ours - DecisionTree]
#     AUROC: 0.7653
#     G-mean: 0.6904
#     MCC: 0.2097
#     F1-score: 0.2048
#     mAP: 0.1749
#   [Ours - kNN]
#     AUROC: 0.7722
#     G-mean: 0.6099
#     MCC: 0.2099
#     F1-score: 0.2278
#     mAP: 0.1580
#   [Ours - MLP]
#     AUROC: 0.7837
#     G-mean: 0.5978
#     MCC: 0.2290
#     F1-score: 0.2508
#     mAP: 0.2721
#   [Ours - RandomForest]
#     AUROC: 0.9001
#     G-mean: 0.7315
#     MCC: 0.3993
#     F1-score: 0.4108
#     mAP: 0.3939
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.8028
#     G-mean: 0.6703
#     MCC: 0.2375
#     F1-score: 0.2425
#     mAP: 0.2453
#   [Ours - DecisionTree]
#     AUROC: 0.7654
#     G-mean: 0.6914
#     MCC: 0.2074
#     F1-score: 0.2019
#     mAP: 0.1727
#   [Ours - kNN]
#     AUROC: 0.7729
#     G-mean: 0.6095
#     MCC: 0.2083
#     F1-score: 0.2259
#     mAP: 0.1590
#   [Ours - MLP]
#     AUROC: 0.7834
#     G-mean: 0.6006
#     MCC: 0.2318
#     F1-score: 0.2530
#     mAP: 0.2680
#   [Ours - RandomForest]
#     AUROC: 0.9005
#     G-mean: 0.7309
#     MCC: 0.3992
#     F1-score: 0.4108
#     mAP: 0.3957
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.8012
#     G-mean: 0.6690
#     MCC: 0.2377
#     F1-score: 0.2431
#     mAP: 0.2416
#   [Ours - DecisionTree]
#     AUROC: 0.7649
#     G-mean: 0.6918
#     MCC: 0.2069
#     F1-score: 0.2009
#     mAP: 0.1738
#   [Ours - kNN]
#     AUROC: 0.7716
#     G-mean: 0.6070
#     MCC: 0.2076
#     F1-score: 0.2255
#     mAP: 0.1586
#   [Ours - MLP]
#     AUROC: 0.7835
#     G-mean: 0.6029
#     MCC: 0.2333
#     F1-score: 0.2540
#     mAP: 0.2665
#   [Ours - RandomForest]
#     AUROC: 0.8990
#     G-mean: 0.7261
#     MCC: 0.3940
#     F1-score: 0.4061
#     mAP: 0.3951
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.8017
#     G-mean: 0.6705
#     MCC: 0.2382
#     F1-score: 0.2431
#     mAP: 0.2409
#   [Ours - DecisionTree]
#     AUROC: 0.7657
#     G-mean: 0.6913
#     MCC: 0.2080
#     F1-score: 0.2024
#     mAP: 0.1750
#   [Ours - kNN]
#     AUROC: 0.7730
#     G-mean: 0.6143
#     MCC: 0.2136
#     F1-score: 0.2305
#     mAP: 0.1606
#   [Ours - MLP]
#     AUROC: 0.7838
#     G-mean: 0.6069
#     MCC: 0.2367
#     F1-score: 0.2568
#     mAP: 0.2648
#   [Ours - RandomForest]
#     AUROC: 0.8992
#     G-mean: 0.7278
#     MCC: 0.3960
#     F1-score: 0.4075
#     mAP: 0.3992
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.8022
#     G-mean: 0.6712
#     MCC: 0.2387
#     F1-score: 0.2436
#     mAP: 0.2409
#   [Ours - DecisionTree]
#     AUROC: 0.7638
#     G-mean: 0.6877
#     MCC: 0.2043
#     F1-score: 0.1999
#     mAP: 0.1741
#   [Ours - kNN]
#     AUROC: 0.7706
#     G-mean: 0.6160
#     MCC: 0.2155
#     F1-score: 0.2323
#     mAP: 0.1604
#   [Ours - MLP]
#     AUROC: 0.7841
#     G-mean: 0.6079
#     MCC: 0.2379
#     F1-score: 0.2580
#     mAP: 0.2657
#   [Ours - RandomForest]
#     AUROC: 0.8985
#     G-mean: 0.7287
#     MCC: 0.3977
#     F1-score: 0.4093
#     mAP: 0.3997
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.8022
#     G-mean: 0.6702
#     MCC: 0.2373
#     F1-score: 0.2420
#     mAP: 0.2401
#   [Ours - DecisionTree]
#     AUROC: 0.7626
#     G-mean: 0.6867
#     MCC: 0.2051
#     F1-score: 0.2007
#     mAP: 0.1740
#   [Ours - kNN]
#     AUROC: 0.7698
#     G-mean: 0.6169
#     MCC: 0.2150
#     F1-score: 0.2316
#     mAP: 0.1580
#   [Ours - MLP]
#     AUROC: 0.7840
#     G-mean: 0.6058
#     MCC: 0.2361
#     F1-score: 0.2563
#     mAP: 0.2668
#   [Ours - RandomForest]
#     AUROC: 0.8981
#     G-mean: 0.7284
#     MCC: 0.3969
#     F1-score: 0.4085
#     mAP: 0.4027
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/wine_quality_results_gaussian_beta_0.001.csv
# beta: 0.0
# Dataset loaded: wine_quality
# X shape : (4898, 11)
# target : Counter({0: 4715, 1: 183})
# IR: 25.77
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.8011
#     G-mean: 0.6806
#     MCC: 0.2418
#     F1-score: 0.2461
#     mAP: 0.2244
#   [Ours - DecisionTree]
#     AUROC: 0.7371
#     G-mean: 0.6783
#     MCC: 0.1960
#     F1-score: 0.1955
#     mAP: 0.1507
#   [Ours - kNN]
#     AUROC: 0.7629
#     G-mean: 0.6073
#     MCC: 0.2026
#     F1-score: 0.2216
#     mAP: 0.1475
#   [Ours - MLP]
#     AUROC: 0.7738
#     G-mean: 0.5965
#     MCC: 0.2328
#     F1-score: 0.2575
#     mAP: 0.2740
#   [Ours - RandomForest]
#     AUROC: 0.9076
#     G-mean: 0.7215
#     MCC: 0.3737
#     F1-score: 0.3852
#     mAP: 0.3968
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.7982
#     G-mean: 0.6803
#     MCC: 0.2426
#     F1-score: 0.2463
#     mAP: 0.2356
#   [Ours - DecisionTree]
#     AUROC: 0.7694
#     G-mean: 0.6877
#     MCC: 0.2031
#     F1-score: 0.1979
#     mAP: 0.1746
#   [Ours - kNN]
#     AUROC: 0.7646
#     G-mean: 0.6106
#     MCC: 0.2074
#     F1-score: 0.2259
#     mAP: 0.1535
#   [Ours - MLP]
#     AUROC: 0.7711
#     G-mean: 0.5874
#     MCC: 0.2240
#     F1-score: 0.2490
#     mAP: 0.2576
#   [Ours - RandomForest]
#     AUROC: 0.8998
#     G-mean: 0.7322
#     MCC: 0.3938
#     F1-score: 0.4053
#     mAP: 0.3941
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.7918
#     G-mean: 0.6611
#     MCC: 0.2355
#     F1-score: 0.2435
#     mAP: 0.2313
#   [Ours - DecisionTree]
#     AUROC: 0.7642
#     G-mean: 0.6756
#     MCC: 0.1980
#     F1-score: 0.1959
#     mAP: 0.1710
#   [Ours - kNN]
#     AUROC: 0.7655
#     G-mean: 0.6025
#     MCC: 0.2051
#     F1-score: 0.2249
#     mAP: 0.1535
#   [Ours - MLP]
#     AUROC: 0.7682
#     G-mean: 0.5796
#     MCC: 0.2224
#     F1-score: 0.2483
#     mAP: 0.2525
#   [Ours - RandomForest]
#     AUROC: 0.8989
#     G-mean: 0.7250
#     MCC: 0.3948
#     F1-score: 0.4070
#     mAP: 0.3962
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.7983
#     G-mean: 0.6657
#     MCC: 0.2382
#     F1-score: 0.2453
#     mAP: 0.2454
#   [Ours - DecisionTree]
#     AUROC: 0.7601
#     G-mean: 0.6771
#     MCC: 0.2008
#     F1-score: 0.1983
#     mAP: 0.1774
#   [Ours - kNN]
#     AUROC: 0.7736
#     G-mean: 0.6084
#     MCC: 0.2101
#     F1-score: 0.2291
#     mAP: 0.1566
#   [Ours - MLP]
#     AUROC: 0.7752
#     G-mean: 0.5880
#     MCC: 0.2265
#     F1-score: 0.2506
#     mAP: 0.2614
#   [Ours - RandomForest]
#     AUROC: 0.9002
#     G-mean: 0.7295
#     MCC: 0.4012
#     F1-score: 0.4134
#     mAP: 0.4049
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.8008
#     G-mean: 0.6657
#     MCC: 0.2375
#     F1-score: 0.2443
#     mAP: 0.2478
#   [Ours - DecisionTree]
#     AUROC: 0.7574
#     G-mean: 0.6729
#     MCC: 0.1931
#     F1-score: 0.1917
#     mAP: 0.1685
#   [Ours - kNN]
#     AUROC: 0.7696
#     G-mean: 0.6032
#     MCC: 0.2059
#     F1-score: 0.2256
#     mAP: 0.1558
#   [Ours - MLP]
#     AUROC: 0.7806
#     G-mean: 0.5936
#     MCC: 0.2287
#     F1-score: 0.2518
#     mAP: 0.2624
#   [Ours - RandomForest]
#     AUROC: 0.8993
#     G-mean: 0.7285
#     MCC: 0.4000
#     F1-score: 0.4119
#     mAP: 0.3995
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.7998
#     G-mean: 0.6619
#     MCC: 0.2335
#     F1-score: 0.2403
#     mAP: 0.2428
#   [Ours - DecisionTree]
#     AUROC: 0.7585
#     G-mean: 0.6770
#     MCC: 0.1949
#     F1-score: 0.1926
#     mAP: 0.1696
#   [Ours - kNN]
#     AUROC: 0.7712
#     G-mean: 0.6016
#     MCC: 0.2031
#     F1-score: 0.2228
#     mAP: 0.1559
#   [Ours - MLP]
#     AUROC: 0.7798
#     G-mean: 0.5930
#     MCC: 0.2289
#     F1-score: 0.2521
#     mAP: 0.2576
#   [Ours - RandomForest]
#     AUROC: 0.8998
#     G-mean: 0.7300
#     MCC: 0.4026
#     F1-score: 0.4145
#     mAP: 0.3991
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.7983
#     G-mean: 0.6607
#     MCC: 0.2333
#     F1-score: 0.2404
#     mAP: 0.2407
#   [Ours - DecisionTree]
#     AUROC: 0.7575
#     G-mean: 0.6772
#     MCC: 0.1958
#     F1-score: 0.1934
#     mAP: 0.1696
#   [Ours - kNN]
#     AUROC: 0.7705
#     G-mean: 0.5995
#     MCC: 0.2031
#     F1-score: 0.2230
#     mAP: 0.1565
#   [Ours - MLP]
#     AUROC: 0.7791
#     G-mean: 0.5898
#     MCC: 0.2282
#     F1-score: 0.2515
#     mAP: 0.2572
#   [Ours - RandomForest]
#     AUROC: 0.8987
#     G-mean: 0.7244
#     MCC: 0.3975
#     F1-score: 0.4101
#     mAP: 0.3968
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.7990
#     G-mean: 0.6625
#     MCC: 0.2340
#     F1-score: 0.2407
#     mAP: 0.2412
#   [Ours - DecisionTree]
#     AUROC: 0.7581
#     G-mean: 0.6788
#     MCC: 0.1959
#     F1-score: 0.1932
#     mAP: 0.1701
#   [Ours - kNN]
#     AUROC: 0.7715
#     G-mean: 0.6080
#     MCC: 0.2107
#     F1-score: 0.2294
#     mAP: 0.1581
#   [Ours - MLP]
#     AUROC: 0.7803
#     G-mean: 0.5955
#     MCC: 0.2333
#     F1-score: 0.2557
#     mAP: 0.2561
#   [Ours - RandomForest]
#     AUROC: 0.8985
#     G-mean: 0.7260
#     MCC: 0.3992
#     F1-score: 0.4112
#     mAP: 0.4004
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.7993
#     G-mean: 0.6633
#     MCC: 0.2349
#     F1-score: 0.2417
#     mAP: 0.2412
#   [Ours - DecisionTree]
#     AUROC: 0.7527
#     G-mean: 0.6756
#     MCC: 0.1947
#     F1-score: 0.1928
#     mAP: 0.1715
#   [Ours - kNN]
#     AUROC: 0.7694
#     G-mean: 0.6090
#     MCC: 0.2125
#     F1-score: 0.2312
#     mAP: 0.1578
#   [Ours - MLP]
#     AUROC: 0.7812
#     G-mean: 0.5977
#     MCC: 0.2356
#     F1-score: 0.2575
#     mAP: 0.2572
#   [Ours - RandomForest]
#     AUROC: 0.8982
#     G-mean: 0.7254
#     MCC: 0.4000
#     F1-score: 0.4125
#     mAP: 0.4010
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.7989
#     G-mean: 0.6622
#     MCC: 0.2335
#     F1-score: 0.2400
#     mAP: 0.2408
#   [Ours - DecisionTree]
#     AUROC: 0.7541
#     G-mean: 0.6779
#     MCC: 0.1968
#     F1-score: 0.1941
#     mAP: 0.1713
#   [Ours - kNN]
#     AUROC: 0.7684
#     G-mean: 0.6091
#     MCC: 0.2113
#     F1-score: 0.2297
#     mAP: 0.1556
#   [Ours - MLP]
#     AUROC: 0.7808
#     G-mean: 0.5975
#     MCC: 0.2351
#     F1-score: 0.2571
#     mAP: 0.2589
#   [Ours - RandomForest]
#     AUROC: 0.8980
#     G-mean: 0.7236
#     MCC: 0.3977
#     F1-score: 0.4103
#     mAP: 0.4043
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/wine_quality_results_gaussian_beta_0.0.csv

# %%
data_name = 'abalone9-18'

n_epochs = 2000
hidden_dims = [16, 32, 64, 128]
latent_dim = 256
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        cat_idx=[0],
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'libras_move'
maj_target_name = -1

n_epochs = 2000
hidden_dims = [98, 49, 24]
latent_dim = 12
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        fetch_data_func=fetch_datasets,
        maj_target_name=maj_target_name,
        methods=methods,
        base_models=base_models,
        device=device,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'spectrometer'
maj_target_name = -1

n_epochs = 2000
hidden_dims = [46, 23, 12]
latent_dim = 6
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        fetch_data_func=fetch_datasets,
        maj_target_name=maj_target_name,
        methods=methods,
        base_models=base_models,
        device=device,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'yeast6'
n_epochs = 2000
hidden_dims = [8, 16, 32, 64]
latent_dim = 128
lr = 0.001

for beta in betas:
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'yeast-1-2-8-9_vs_7'
n_epochs = 2000
hidden_dims = [8, 16, 32, 64]
latent_dim = 128
lr = 0.001

for beta in betas:
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'yeast-0-5-6-7-9_vs_4'

n_epochs = 2000
hidden_dims = [16, 32, 64, 128]
latent_dim = 256
lr = 0.001

for beta in betas:
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )
