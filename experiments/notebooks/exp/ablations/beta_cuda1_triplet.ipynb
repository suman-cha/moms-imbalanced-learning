# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

# Save path 
save_path = "/data4/oldrain123/oldrain123/results/ablation_results/beta8"
data_path = "/data4/oldrain123/oldrain123/dataset"

# %%
import os
import warnings
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from experiment import run_ablation
from imblearn.datasets import fetch_datasets

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
data = fetch_datasets()
methods = ["Ours"]
betas = [1e-1, 5e-2, 1e-2, 5e-3, 1e-3, 0.0]
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}

# %%
data_name = 'winequality-white-3-9_vs_5'

n_epochs = 2000
hidden_dims = [16, 32, 64, 128, 256]
latent_dim = 512
lr = 0.001

for beta in betas:
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )
# Out:
# Dataset loaded from DataFrame
# X shape : (1482, 11)
# target : Counter({0: 1457, 1: 25})
# IR: 58.28
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.6874
#     G-mean: 0.6606
#     MCC: 0.1900
#     F1-score: 0.1519
#     mAP: 0.2703
#   [Ours - DecisionTree]
#     AUROC: 0.4236
#     G-mean: 0.1962
#     MCC: 0.0715
#     F1-score: 0.0850
#     mAP: 0.0627
#   [Ours - kNN]
#     AUROC: 0.6225
#     G-mean: 0.1276
#     MCC: 0.0644
#     F1-score: 0.0733
#     mAP: 0.1586
#   [Ours - MLP]
#     AUROC: 0.7121
#     G-mean: 0.5939
#     MCC: 0.2925
#     F1-score: 0.2856
#     mAP: 0.3914
#   [Ours - RandomForest]
#     AUROC: 0.8588
#     G-mean: 0.0000
#     MCC: -0.0043
#     F1-score: 0.0000
#     mAP: 0.2780
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.6861
#     G-mean: 0.6488
#     MCC: 0.1809
#     F1-score: 0.1442
#     mAP: 0.2507
#   [Ours - DecisionTree]
#     AUROC: 0.4599
#     G-mean: 0.2411
#     MCC: 0.0969
#     F1-score: 0.1080
#     mAP: 0.0903
#   [Ours - kNN]
#     AUROC: 0.6196
#     G-mean: 0.1686
#     MCC: 0.1180
#     F1-score: 0.1233
#     mAP: 0.1486
#   [Ours - MLP]
#     AUROC: 0.7020
#     G-mean: 0.5196
#     MCC: 0.2628
#     F1-score: 0.2596
#     mAP: 0.3439
#   [Ours - RandomForest]
#     AUROC: 0.8562
#     G-mean: 0.0578
#     MCC: 0.0547
#     F1-score: 0.0500
#     mAP: 0.2853
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.6900
#     G-mean: 0.6478
#     MCC: 0.1686
#     F1-score: 0.1357
#     mAP: 0.2536
#   [Ours - DecisionTree]
#     AUROC: 0.4765
#     G-mean: 0.2819
#     MCC: 0.1157
#     F1-score: 0.1255
#     mAP: 0.0942
#   [Ours - kNN]
#     AUROC: 0.6132
#     G-mean: 0.1786
#     MCC: 0.1231
#     F1-score: 0.1289
#     mAP: 0.1495
#   [Ours - MLP]
#     AUROC: 0.6917
#     G-mean: 0.4852
#     MCC: 0.2394
#     F1-score: 0.2382
#     mAP: 0.3373
#   [Ours - RandomForest]
#     AUROC: 0.8536
#     G-mean: 0.0621
#     MCC: 0.0600
#     F1-score: 0.0556
#     mAP: 0.3113
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.6923
#     G-mean: 0.6339
#     MCC: 0.1690
#     F1-score: 0.1371
#     mAP: 0.2572
#   [Ours - DecisionTree]
#     AUROC: 0.4801
#     G-mean: 0.2813
#     MCC: 0.1142
#     F1-score: 0.1221
#     mAP: 0.0984
#   [Ours - kNN]
#     AUROC: 0.6128
#     G-mean: 0.1762
#     MCC: 0.1201
#     F1-score: 0.1244
#     mAP: 0.1411
#   [Ours - MLP]
#     AUROC: 0.6875
#     G-mean: 0.4931
#     MCC: 0.2441
#     F1-score: 0.2398
#     mAP: 0.3326
#   [Ours - RandomForest]
#     AUROC: 0.8513
#     G-mean: 0.0716
#     MCC: 0.0697
#     F1-score: 0.0667
#     mAP: 0.3265
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.6875
#     G-mean: 0.6070
#     MCC: 0.1610
#     F1-score: 0.1320
#     mAP: 0.2493
#   [Ours - DecisionTree]
#     AUROC: 0.4841
#     G-mean: 0.2477
#     MCC: 0.0948
#     F1-score: 0.1057
#     mAP: 0.0950
#   [Ours - kNN]
#     AUROC: 0.6124
#     G-mean: 0.1663
#     MCC: 0.1084
#     F1-score: 0.1125
#     mAP: 0.1263
#   [Ours - MLP]
#     AUROC: 0.6812
#     G-mean: 0.4842
#     MCC: 0.2344
#     F1-score: 0.2321
#     mAP: 0.3239
#   [Ours - RandomForest]
#     AUROC: 0.8511
#     G-mean: 0.0572
#     MCC: 0.0554
#     F1-score: 0.0533
#     mAP: 0.3270
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.6858
#     G-mean: 0.5934
#     MCC: 0.1579
#     F1-score: 0.1292
#     mAP: 0.2399
#   [Ours - DecisionTree]
#     AUROC: 0.4851
#     G-mean: 0.2465
#     MCC: 0.0958
#     F1-score: 0.1071
#     mAP: 0.0968
#   [Ours - kNN]
#     AUROC: 0.6145
#     G-mean: 0.1766
#     MCC: 0.1195
#     F1-score: 0.1227
#     mAP: 0.1375
#   [Ours - MLP]
#     AUROC: 0.6824
#     G-mean: 0.4676
#     MCC: 0.2275
#     F1-score: 0.2259
#     mAP: 0.3138
#   [Ours - RandomForest]
#     AUROC: 0.8411
#     G-mean: 0.0477
#     MCC: 0.0459
#     F1-score: 0.0445
#     mAP: 0.3215
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.6845
#     G-mean: 0.6006
#     MCC: 0.1592
#     F1-score: 0.1296
#     mAP: 0.2359
#   [Ours - DecisionTree]
#     AUROC: 0.5074
#     G-mean: 0.2634
#     MCC: 0.1011
#     F1-score: 0.1119
#     mAP: 0.1080
#   [Ours - kNN]
#     AUROC: 0.6115
#     G-mean: 0.1779
#     MCC: 0.1224
#     F1-score: 0.1251
#     mAP: 0.1357
#   [Ours - MLP]
#     AUROC: 0.6819
#     G-mean: 0.4781
#     MCC: 0.2261
#     F1-score: 0.2237
#     mAP: 0.3042
#   [Ours - RandomForest]
#     AUROC: 0.8442
#     G-mean: 0.0491
#     MCC: 0.0473
#     F1-score: 0.0452
#     mAP: 0.3148
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.6885
#     G-mean: 0.6099
#     MCC: 0.1609
#     F1-score: 0.1313
#     mAP: 0.2346
#   [Ours - DecisionTree]
#     AUROC: 0.5102
#     G-mean: 0.2648
#     MCC: 0.0973
#     F1-score: 0.1069
#     mAP: 0.1069
#   [Ours - kNN]
#     AUROC: 0.6065
#     G-mean: 0.1717
#     MCC: 0.1222
#     F1-score: 0.1241
#     mAP: 0.1328
#   [Ours - MLP]
#     AUROC: 0.6819
#     G-mean: 0.4699
#     MCC: 0.2206
#     F1-score: 0.2188
#     mAP: 0.2965
#   [Ours - RandomForest]
#     AUROC: 0.8457
#     G-mean: 0.0518
#     MCC: 0.0499
#     F1-score: 0.0479
#     mAP: 0.3089
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.6904
#     G-mean: 0.6142
#     MCC: 0.1624
#     F1-score: 0.1322
#     mAP: 0.2408
#   [Ours - DecisionTree]
#     AUROC: 0.5324
#     G-mean: 0.2901
#     MCC: 0.1087
#     F1-score: 0.1176
#     mAP: 0.1170
#   [Ours - kNN]
#     AUROC: 0.6051
#     G-mean: 0.1680
#     MCC: 0.1191
#     F1-score: 0.1208
#     mAP: 0.1303
#   [Ours - MLP]
#     AUROC: 0.6809
#     G-mean: 0.4495
#     MCC: 0.2093
#     F1-score: 0.2085
#     mAP: 0.2868
#   [Ours - RandomForest]
#     AUROC: 0.8444
#     G-mean: 0.0589
#     MCC: 0.0570
#     F1-score: 0.0537
#     mAP: 0.3103
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.6954
#     G-mean: 0.6085
#     MCC: 0.1637
#     F1-score: 0.1342
#     mAP: 0.2372
#   [Ours - DecisionTree]
#     AUROC: 0.5335
#     G-mean: 0.2989
#     MCC: 0.1174
#     F1-score: 0.1254
#     mAP: 0.1177
#   [Ours - kNN]
#     AUROC: 0.6045
#     G-mean: 0.1685
#     MCC: 0.1204
#     F1-score: 0.1217
#     mAP: 0.1292
#   [Ours - MLP]
#     AUROC: 0.6823
#     G-mean: 0.4434
#     MCC: 0.2039
#     F1-score: 0.2039
#     mAP: 0.2799
#   [Ours - RandomForest]
#     AUROC: 0.8460
#     G-mean: 0.0716
#     MCC: 0.0676
#     F1-score: 0.0633
#     mAP: 0.3196
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/winequality-white-3-9_vs_5_results_gaussian_beta_0.1.csv
# Dataset loaded from DataFrame
# X shape : (1482, 11)
# target : Counter({0: 1457, 1: 25})
# IR: 58.28
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.6802
#     G-mean: 0.3514
#     MCC: 0.1513
#     F1-score: 0.1571
#     mAP: 0.2035
#   [Ours - DecisionTree]
#     AUROC: 0.5696
#     G-mean: 0.3065
#     MCC: 0.1776
#     F1-score: 0.1905
#     mAP: 0.1970
#   [Ours - kNN]
#     AUROC: 0.6439
#     G-mean: 0.2680
#     MCC: 0.1442
#     F1-score: 0.1567
#     mAP: 0.1823
#   [Ours - MLP]
#     AUROC: 0.7009
#     G-mean: 0.5332
#     MCC: 0.2187
#     F1-score: 0.2141
#     mAP: 0.2839
#   [Ours - RandomForest]
#     AUROC: 0.8445
#     G-mean: 0.2860
#     MCC: 0.2636
#     F1-score: 0.2567
#     mAP: 0.3708
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.6807
#     G-mean: 0.3808
#     MCC: 0.1516
#     F1-score: 0.1536
#     mAP: 0.2298
#   [Ours - DecisionTree]
#     AUROC: 0.5396
#     G-mean: 0.3080
#     MCC: 0.1297
#     F1-score: 0.1338
#     mAP: 0.1410
#   [Ours - kNN]
#     AUROC: 0.6241
#     G-mean: 0.2317
#     MCC: 0.1273
#     F1-score: 0.1373
#     mAP: 0.1326
#   [Ours - MLP]
#     AUROC: 0.7007
#     G-mean: 0.4826
#     MCC: 0.1878
#     F1-score: 0.1827
#     mAP: 0.2651
#   [Ours - RandomForest]
#     AUROC: 0.8605
#     G-mean: 0.2475
#     MCC: 0.1991
#     F1-score: 0.1983
#     mAP: 0.3496
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.6932
#     G-mean: 0.4489
#     MCC: 0.1678
#     F1-score: 0.1609
#     mAP: 0.2249
#   [Ours - DecisionTree]
#     AUROC: 0.5743
#     G-mean: 0.3115
#     MCC: 0.1194
#     F1-score: 0.1241
#     mAP: 0.1273
#   [Ours - kNN]
#     AUROC: 0.6264
#     G-mean: 0.2200
#     MCC: 0.1116
#     F1-score: 0.1210
#     mAP: 0.1179
#   [Ours - MLP]
#     AUROC: 0.7027
#     G-mean: 0.5039
#     MCC: 0.1903
#     F1-score: 0.1828
#     mAP: 0.2872
#   [Ours - RandomForest]
#     AUROC: 0.8584
#     G-mean: 0.2077
#     MCC: 0.1672
#     F1-score: 0.1656
#     mAP: 0.3330
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.6781
#     G-mean: 0.4509
#     MCC: 0.1739
#     F1-score: 0.1656
#     mAP: 0.2178
#   [Ours - DecisionTree]
#     AUROC: 0.5803
#     G-mean: 0.3063
#     MCC: 0.1125
#     F1-score: 0.1167
#     mAP: 0.1225
#   [Ours - kNN]
#     AUROC: 0.6302
#     G-mean: 0.2358
#     MCC: 0.1253
#     F1-score: 0.1328
#     mAP: 0.1387
#   [Ours - MLP]
#     AUROC: 0.7000
#     G-mean: 0.4667
#     MCC: 0.1821
#     F1-score: 0.1747
#     mAP: 0.2915
#   [Ours - RandomForest]
#     AUROC: 0.8407
#     G-mean: 0.1952
#     MCC: 0.1631
#     F1-score: 0.1617
#     mAP: 0.3302
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.6773
#     G-mean: 0.4518
#     MCC: 0.1770
#     F1-score: 0.1698
#     mAP: 0.2262
#   [Ours - DecisionTree]
#     AUROC: 0.5875
#     G-mean: 0.3107
#     MCC: 0.1110
#     F1-score: 0.1156
#     mAP: 0.1205
#   [Ours - kNN]
#     AUROC: 0.6321
#     G-mean: 0.2368
#     MCC: 0.1210
#     F1-score: 0.1288
#     mAP: 0.1321
#   [Ours - MLP]
#     AUROC: 0.6873
#     G-mean: 0.4561
#     MCC: 0.1764
#     F1-score: 0.1707
#     mAP: 0.2865
#   [Ours - RandomForest]
#     AUROC: 0.8343
#     G-mean: 0.1934
#     MCC: 0.1628
#     F1-score: 0.1593
#     mAP: 0.3228
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.6793
#     G-mean: 0.4480
#     MCC: 0.1791
#     F1-score: 0.1722
#     mAP: 0.2330
#   [Ours - DecisionTree]
#     AUROC: 0.5823
#     G-mean: 0.3124
#     MCC: 0.1090
#     F1-score: 0.1137
#     mAP: 0.1199
#   [Ours - kNN]
#     AUROC: 0.6296
#     G-mean: 0.2349
#     MCC: 0.1226
#     F1-score: 0.1289
#     mAP: 0.1352
#   [Ours - MLP]
#     AUROC: 0.6838
#     G-mean: 0.4471
#     MCC: 0.1767
#     F1-score: 0.1707
#     mAP: 0.2906
#   [Ours - RandomForest]
#     AUROC: 0.8319
#     G-mean: 0.1874
#     MCC: 0.1610
#     F1-score: 0.1578
#     mAP: 0.3125
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.6791
#     G-mean: 0.4547
#     MCC: 0.1779
#     F1-score: 0.1703
#     mAP: 0.2336
#   [Ours - DecisionTree]
#     AUROC: 0.5708
#     G-mean: 0.2956
#     MCC: 0.1012
#     F1-score: 0.1074
#     mAP: 0.1123
#   [Ours - kNN]
#     AUROC: 0.6376
#     G-mean: 0.2457
#     MCC: 0.1251
#     F1-score: 0.1318
#     mAP: 0.1335
#   [Ours - MLP]
#     AUROC: 0.6832
#     G-mean: 0.4533
#     MCC: 0.1775
#     F1-score: 0.1709
#     mAP: 0.2818
#   [Ours - RandomForest]
#     AUROC: 0.8365
#     G-mean: 0.1689
#     MCC: 0.1457
#     F1-score: 0.1424
#     mAP: 0.3099
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.6826
#     G-mean: 0.4490
#     MCC: 0.1740
#     F1-score: 0.1673
#     mAP: 0.2271
#   [Ours - DecisionTree]
#     AUROC: 0.5474
#     G-mean: 0.2813
#     MCC: 0.0935
#     F1-score: 0.1010
#     mAP: 0.1081
#   [Ours - kNN]
#     AUROC: 0.6345
#     G-mean: 0.2381
#     MCC: 0.1197
#     F1-score: 0.1273
#     mAP: 0.1281
#   [Ours - MLP]
#     AUROC: 0.6816
#     G-mean: 0.4424
#     MCC: 0.1757
#     F1-score: 0.1707
#     mAP: 0.2681
#   [Ours - RandomForest]
#     AUROC: 0.8384
#     G-mean: 0.1711
#     MCC: 0.1501
#     F1-score: 0.1454
#     mAP: 0.3049
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.6797
#     G-mean: 0.4468
#     MCC: 0.1746
#     F1-score: 0.1685
#     mAP: 0.2287
#   [Ours - DecisionTree]
#     AUROC: 0.5535
#     G-mean: 0.2843
#     MCC: 0.0958
#     F1-score: 0.1034
#     mAP: 0.1065
#   [Ours - kNN]
#     AUROC: 0.6350
#     G-mean: 0.2383
#     MCC: 0.1199
#     F1-score: 0.1265
#     mAP: 0.1271
#   [Ours - MLP]
#     AUROC: 0.6775
#     G-mean: 0.4464
#     MCC: 0.1756
#     F1-score: 0.1707
#     mAP: 0.2697
#   [Ours - RandomForest]
#     AUROC: 0.8374
#     G-mean: 0.1649
#     MCC: 0.1435
#     F1-score: 0.1393
#     mAP: 0.3039
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.6859
#     G-mean: 0.4435
#     MCC: 0.1751
#     F1-score: 0.1686
#     mAP: 0.2289
#   [Ours - DecisionTree]
#     AUROC: 0.5577
#     G-mean: 0.2833
#     MCC: 0.0954
#     F1-score: 0.1029
#     mAP: 0.1104
#   [Ours - kNN]
#     AUROC: 0.6362
#     G-mean: 0.2317
#     MCC: 0.1169
#     F1-score: 0.1240
#     mAP: 0.1227
#   [Ours - MLP]
#     AUROC: 0.6800
#     G-mean: 0.4428
#     MCC: 0.1732
#     F1-score: 0.1688
#     mAP: 0.2658
#   [Ours - RandomForest]
#     AUROC: 0.8363
#     G-mean: 0.1541
#     MCC: 0.1327
#     F1-score: 0.1293
#     mAP: 0.2973
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/winequality-white-3-9_vs_5_results_gaussian_beta_0.05.csv
# Dataset loaded from DataFrame
# X shape : (1482, 11)
# target : Counter({0: 1457, 1: 25})
# IR: 58.28
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.7505
#     G-mean: 0.5605
#     MCC: 0.2413
#     F1-score: 0.2301
#     mAP: 0.2853
#   [Ours - DecisionTree]
#     AUROC: 0.6275
#     G-mean: 0.5701
#     MCC: 0.1715
#     F1-score: 0.1491
#     mAP: 0.1822
#   [Ours - kNN]
#     AUROC: 0.7043
#     G-mean: 0.4597
#     MCC: 0.1540
#     F1-score: 0.1481
#     mAP: 0.1679
#   [Ours - MLP]
#     AUROC: 0.7006
#     G-mean: 0.5950
#     MCC: 0.1820
#     F1-score: 0.1648
#     mAP: 0.3112
#   [Ours - RandomForest]
#     AUROC: 0.8793
#     G-mean: 0.4247
#     MCC: 0.2541
#     F1-score: 0.2586
#     mAP: 0.3641
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.7070
#     G-mean: 0.5089
#     MCC: 0.2046
#     F1-score: 0.1983
#     mAP: 0.2649
#   [Ours - DecisionTree]
#     AUROC: 0.6321
#     G-mean: 0.4913
#     MCC: 0.1438
#     F1-score: 0.1326
#     mAP: 0.1779
#   [Ours - kNN]
#     AUROC: 0.6828
#     G-mean: 0.4055
#     MCC: 0.1362
#     F1-score: 0.1344
#     mAP: 0.1421
#   [Ours - MLP]
#     AUROC: 0.6781
#     G-mean: 0.5456
#     MCC: 0.1709
#     F1-score: 0.1560
#     mAP: 0.2762
#   [Ours - RandomForest]
#     AUROC: 0.8609
#     G-mean: 0.3831
#     MCC: 0.2436
#     F1-score: 0.2419
#     mAP: 0.3202
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.7077
#     G-mean: 0.4990
#     MCC: 0.1949
#     F1-score: 0.1893
#     mAP: 0.2686
#   [Ours - DecisionTree]
#     AUROC: 0.6327
#     G-mean: 0.4961
#     MCC: 0.1398
#     F1-score: 0.1253
#     mAP: 0.1698
#   [Ours - kNN]
#     AUROC: 0.6877
#     G-mean: 0.4169
#     MCC: 0.1416
#     F1-score: 0.1368
#     mAP: 0.1408
#   [Ours - MLP]
#     AUROC: 0.6721
#     G-mean: 0.5856
#     MCC: 0.1826
#     F1-score: 0.1646
#     mAP: 0.2885
#   [Ours - RandomForest]
#     AUROC: 0.8574
#     G-mean: 0.3480
#     MCC: 0.2087
#     F1-score: 0.2102
#     mAP: 0.3322
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.7026
#     G-mean: 0.4600
#     MCC: 0.1749
#     F1-score: 0.1705
#     mAP: 0.2474
#   [Ours - DecisionTree]
#     AUROC: 0.6411
#     G-mean: 0.4938
#     MCC: 0.1416
#     F1-score: 0.1298
#     mAP: 0.1642
#   [Ours - kNN]
#     AUROC: 0.6769
#     G-mean: 0.3874
#     MCC: 0.1280
#     F1-score: 0.1242
#     mAP: 0.1425
#   [Ours - MLP]
#     AUROC: 0.6622
#     G-mean: 0.5508
#     MCC: 0.1751
#     F1-score: 0.1586
#     mAP: 0.2977
#   [Ours - RandomForest]
#     AUROC: 0.8534
#     G-mean: 0.3553
#     MCC: 0.2099
#     F1-score: 0.2120
#     mAP: 0.3327
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.7185
#     G-mean: 0.4943
#     MCC: 0.1998
#     F1-score: 0.1947
#     mAP: 0.2632
#   [Ours - DecisionTree]
#     AUROC: 0.6439
#     G-mean: 0.4871
#     MCC: 0.1375
#     F1-score: 0.1269
#     mAP: 0.1599
#   [Ours - kNN]
#     AUROC: 0.6875
#     G-mean: 0.3816
#     MCC: 0.1188
#     F1-score: 0.1164
#     mAP: 0.1367
#   [Ours - MLP]
#     AUROC: 0.6628
#     G-mean: 0.5534
#     MCC: 0.1821
#     F1-score: 0.1663
#     mAP: 0.2939
#   [Ours - RandomForest]
#     AUROC: 0.8529
#     G-mean: 0.3628
#     MCC: 0.2126
#     F1-score: 0.2150
#     mAP: 0.3376
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.7116
#     G-mean: 0.4790
#     MCC: 0.1958
#     F1-score: 0.1925
#     mAP: 0.2671
#   [Ours - DecisionTree]
#     AUROC: 0.6127
#     G-mean: 0.4581
#     MCC: 0.1241
#     F1-score: 0.1166
#     mAP: 0.1529
#   [Ours - kNN]
#     AUROC: 0.6867
#     G-mean: 0.3737
#     MCC: 0.1159
#     F1-score: 0.1140
#     mAP: 0.1354
#   [Ours - MLP]
#     AUROC: 0.6611
#     G-mean: 0.5362
#     MCC: 0.1792
#     F1-score: 0.1642
#     mAP: 0.2857
#   [Ours - RandomForest]
#     AUROC: 0.8457
#     G-mean: 0.3661
#     MCC: 0.2176
#     F1-score: 0.2201
#     mAP: 0.3213
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.7126
#     G-mean: 0.4676
#     MCC: 0.1873
#     F1-score: 0.1847
#     mAP: 0.2528
#   [Ours - DecisionTree]
#     AUROC: 0.5968
#     G-mean: 0.4512
#     MCC: 0.1187
#     F1-score: 0.1109
#     mAP: 0.1466
#   [Ours - kNN]
#     AUROC: 0.6836
#     G-mean: 0.3876
#     MCC: 0.1207
#     F1-score: 0.1179
#     mAP: 0.1322
#   [Ours - MLP]
#     AUROC: 0.6558
#     G-mean: 0.5182
#     MCC: 0.1718
#     F1-score: 0.1584
#     mAP: 0.2703
#   [Ours - RandomForest]
#     AUROC: 0.8447
#     G-mean: 0.3585
#     MCC: 0.2118
#     F1-score: 0.2156
#     mAP: 0.3169
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.7090
#     G-mean: 0.4489
#     MCC: 0.1777
#     F1-score: 0.1762
#     mAP: 0.2433
#   [Ours - DecisionTree]
#     AUROC: 0.5999
#     G-mean: 0.4574
#     MCC: 0.1218
#     F1-score: 0.1149
#     mAP: 0.1476
#   [Ours - kNN]
#     AUROC: 0.6775
#     G-mean: 0.3787
#     MCC: 0.1167
#     F1-score: 0.1153
#     mAP: 0.1295
#   [Ours - MLP]
#     AUROC: 0.6488
#     G-mean: 0.4985
#     MCC: 0.1656
#     F1-score: 0.1536
#     mAP: 0.2641
#   [Ours - RandomForest]
#     AUROC: 0.8440
#     G-mean: 0.3540
#     MCC: 0.2085
#     F1-score: 0.2128
#     mAP: 0.3088
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.7034
#     G-mean: 0.4331
#     MCC: 0.1679
#     F1-score: 0.1674
#     mAP: 0.2353
#   [Ours - DecisionTree]
#     AUROC: 0.6036
#     G-mean: 0.4729
#     MCC: 0.1282
#     F1-score: 0.1197
#     mAP: 0.1439
#   [Ours - kNN]
#     AUROC: 0.6724
#     G-mean: 0.3820
#     MCC: 0.1197
#     F1-score: 0.1186
#     mAP: 0.1258
#   [Ours - MLP]
#     AUROC: 0.6431
#     G-mean: 0.4933
#     MCC: 0.1617
#     F1-score: 0.1507
#     mAP: 0.2638
#   [Ours - RandomForest]
#     AUROC: 0.8419
#     G-mean: 0.3441
#     MCC: 0.2020
#     F1-score: 0.2068
#     mAP: 0.3008
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.7074
#     G-mean: 0.4210
#     MCC: 0.1612
#     F1-score: 0.1604
#     mAP: 0.2290
#   [Ours - DecisionTree]
#     AUROC: 0.6112
#     G-mean: 0.4768
#     MCC: 0.1264
#     F1-score: 0.1179
#     mAP: 0.1448
#   [Ours - kNN]
#     AUROC: 0.6768
#     G-mean: 0.3924
#     MCC: 0.1254
#     F1-score: 0.1233
#     mAP: 0.1286
#   [Ours - MLP]
#     AUROC: 0.6491
#     G-mean: 0.4933
#     MCC: 0.1635
#     F1-score: 0.1527
#     mAP: 0.2588
#   [Ours - RandomForest]
#     AUROC: 0.8420
#     G-mean: 0.3508
#     MCC: 0.2067
#     F1-score: 0.2111
#     mAP: 0.3024
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/winequality-white-3-9_vs_5_results_gaussian_beta_0.01.csv
# Dataset loaded from DataFrame
# X shape : (1482, 11)
# target : Counter({0: 1457, 1: 25})
# IR: 58.28
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.7323
#     G-mean: 0.5607
#     MCC: 0.2349
#     F1-score: 0.2242
#     mAP: 0.3195
#   [Ours - DecisionTree]
#     AUROC: 0.6429
#     G-mean: 0.4819
#     MCC: 0.1048
#     F1-score: 0.0894
#     mAP: 0.2477
#   [Ours - kNN]
#     AUROC: 0.7620
#     G-mean: 0.6076
#     MCC: 0.1899
#     F1-score: 0.1657
#     mAP: 0.1581
#   [Ours - MLP]
#     AUROC: 0.6933
#     G-mean: 0.5950
#     MCC: 0.1835
#     F1-score: 0.1650
#     mAP: 0.3379
#   [Ours - RandomForest]
#     AUROC: 0.8659
#     G-mean: 0.5516
#     MCC: 0.3138
#     F1-score: 0.3169
#     mAP: 0.3409
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.6960
#     G-mean: 0.5073
#     MCC: 0.1895
#     F1-score: 0.1818
#     mAP: 0.2802
#   [Ours - DecisionTree]
#     AUROC: 0.6285
#     G-mean: 0.4840
#     MCC: 0.1182
#     F1-score: 0.1062
#     mAP: 0.1899
#   [Ours - kNN]
#     AUROC: 0.7228
#     G-mean: 0.4775
#     MCC: 0.1416
#     F1-score: 0.1295
#     mAP: 0.1502
#   [Ours - MLP]
#     AUROC: 0.6663
#     G-mean: 0.5514
#     MCC: 0.1729
#     F1-score: 0.1561
#     mAP: 0.3211
#   [Ours - RandomForest]
#     AUROC: 0.8448
#     G-mean: 0.4370
#     MCC: 0.2499
#     F1-score: 0.2510
#     mAP: 0.3135
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.7019
#     G-mean: 0.5119
#     MCC: 0.1996
#     F1-score: 0.1911
#     mAP: 0.2874
#   [Ours - DecisionTree]
#     AUROC: 0.6286
#     G-mean: 0.4765
#     MCC: 0.1209
#     F1-score: 0.1100
#     mAP: 0.1790
#   [Ours - kNN]
#     AUROC: 0.7276
#     G-mean: 0.4818
#     MCC: 0.1419
#     F1-score: 0.1283
#     mAP: 0.1672
#   [Ours - MLP]
#     AUROC: 0.6614
#     G-mean: 0.5716
#     MCC: 0.1806
#     F1-score: 0.1626
#     mAP: 0.3051
#   [Ours - RandomForest]
#     AUROC: 0.8396
#     G-mean: 0.4515
#     MCC: 0.2532
#     F1-score: 0.2544
#     mAP: 0.3305
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.7027
#     G-mean: 0.4692
#     MCC: 0.1751
#     F1-score: 0.1685
#     mAP: 0.2566
#   [Ours - DecisionTree]
#     AUROC: 0.6268
#     G-mean: 0.4502
#     MCC: 0.1147
#     F1-score: 0.1064
#     mAP: 0.1697
#   [Ours - kNN]
#     AUROC: 0.7311
#     G-mean: 0.4810
#     MCC: 0.1426
#     F1-score: 0.1287
#     mAP: 0.1576
#   [Ours - MLP]
#     AUROC: 0.6557
#     G-mean: 0.5402
#     MCC: 0.1737
#     F1-score: 0.1576
#     mAP: 0.3027
#   [Ours - RandomForest]
#     AUROC: 0.8482
#     G-mean: 0.4327
#     MCC: 0.2395
#     F1-score: 0.2401
#     mAP: 0.3357
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.7125
#     G-mean: 0.4959
#     MCC: 0.1940
#     F1-score: 0.1876
#     mAP: 0.2623
#   [Ours - DecisionTree]
#     AUROC: 0.6284
#     G-mean: 0.4649
#     MCC: 0.1181
#     F1-score: 0.1097
#     mAP: 0.1567
#   [Ours - kNN]
#     AUROC: 0.7307
#     G-mean: 0.4752
#     MCC: 0.1380
#     F1-score: 0.1251
#     mAP: 0.1489
#   [Ours - MLP]
#     AUROC: 0.6576
#     G-mean: 0.5376
#     MCC: 0.1741
#     F1-score: 0.1593
#     mAP: 0.2980
#   [Ours - RandomForest]
#     AUROC: 0.8424
#     G-mean: 0.4179
#     MCC: 0.2328
#     F1-score: 0.2341
#     mAP: 0.3352
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.7090
#     G-mean: 0.4803
#     MCC: 0.1888
#     F1-score: 0.1846
#     mAP: 0.2593
#   [Ours - DecisionTree]
#     AUROC: 0.6143
#     G-mean: 0.4661
#     MCC: 0.1194
#     F1-score: 0.1106
#     mAP: 0.1474
#   [Ours - kNN]
#     AUROC: 0.7250
#     G-mean: 0.4705
#     MCC: 0.1397
#     F1-score: 0.1268
#     mAP: 0.1519
#   [Ours - MLP]
#     AUROC: 0.6544
#     G-mean: 0.5188
#     MCC: 0.1677
#     F1-score: 0.1539
#     mAP: 0.2883
#   [Ours - RandomForest]
#     AUROC: 0.8382
#     G-mean: 0.4157
#     MCC: 0.2277
#     F1-score: 0.2290
#     mAP: 0.3241
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.7111
#     G-mean: 0.4745
#     MCC: 0.1848
#     F1-score: 0.1800
#     mAP: 0.2550
#   [Ours - DecisionTree]
#     AUROC: 0.6066
#     G-mean: 0.4736
#     MCC: 0.1242
#     F1-score: 0.1137
#     mAP: 0.1491
#   [Ours - kNN]
#     AUROC: 0.7240
#     G-mean: 0.4638
#     MCC: 0.1386
#     F1-score: 0.1268
#     mAP: 0.1460
#   [Ours - MLP]
#     AUROC: 0.6446
#     G-mean: 0.5033
#     MCC: 0.1617
#     F1-score: 0.1493
#     mAP: 0.2758
#   [Ours - RandomForest]
#     AUROC: 0.8405
#     G-mean: 0.4249
#     MCC: 0.2311
#     F1-score: 0.2323
#     mAP: 0.3250
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.7111
#     G-mean: 0.4606
#     MCC: 0.1788
#     F1-score: 0.1746
#     mAP: 0.2480
#   [Ours - DecisionTree]
#     AUROC: 0.6091
#     G-mean: 0.4803
#     MCC: 0.1306
#     F1-score: 0.1208
#     mAP: 0.1538
#   [Ours - kNN]
#     AUROC: 0.7185
#     G-mean: 0.4552
#     MCC: 0.1368
#     F1-score: 0.1267
#     mAP: 0.1439
#   [Ours - MLP]
#     AUROC: 0.6403
#     G-mean: 0.4938
#     MCC: 0.1580
#     F1-score: 0.1462
#     mAP: 0.2725
#   [Ours - RandomForest]
#     AUROC: 0.8397
#     G-mean: 0.4162
#     MCC: 0.2237
#     F1-score: 0.2260
#     mAP: 0.3205
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.7051
#     G-mean: 0.4497
#     MCC: 0.1712
#     F1-score: 0.1683
#     mAP: 0.2387
#   [Ours - DecisionTree]
#     AUROC: 0.6062
#     G-mean: 0.4747
#     MCC: 0.1288
#     F1-score: 0.1201
#     mAP: 0.1535
#   [Ours - kNN]
#     AUROC: 0.7102
#     G-mean: 0.4509
#     MCC: 0.1345
#     F1-score: 0.1262
#     mAP: 0.1374
#   [Ours - MLP]
#     AUROC: 0.6353
#     G-mean: 0.4919
#     MCC: 0.1562
#     F1-score: 0.1447
#     mAP: 0.2724
#   [Ours - RandomForest]
#     AUROC: 0.8385
#     G-mean: 0.4162
#     MCC: 0.2262
#     F1-score: 0.2287
#     mAP: 0.3159
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.7096
#     G-mean: 0.4469
#     MCC: 0.1698
#     F1-score: 0.1671
#     mAP: 0.2356
#   [Ours - DecisionTree]
#     AUROC: 0.6090
#     G-mean: 0.4860
#     MCC: 0.1296
#     F1-score: 0.1200
#     mAP: 0.1529
#   [Ours - kNN]
#     AUROC: 0.7124
#     G-mean: 0.4665
#     MCC: 0.1404
#     F1-score: 0.1307
#     mAP: 0.1385
#   [Ours - MLP]
#     AUROC: 0.6413
#     G-mean: 0.4920
#     MCC: 0.1584
#     F1-score: 0.1471
#     mAP: 0.2670
#   [Ours - RandomForest]
#     AUROC: 0.8397
#     G-mean: 0.4289
#     MCC: 0.2350
#     F1-score: 0.2374
#     mAP: 0.3188
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/winequality-white-3-9_vs_5_results_gaussian_beta_0.005.csv
# Dataset loaded from DataFrame
# X shape : (1482, 11)
# target : Counter({0: 1457, 1: 25})
# IR: 58.28
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.7432
#     G-mean: 0.5604
#     MCC: 0.2286
#     F1-score: 0.2159
#     mAP: 0.2951
#   [Ours - DecisionTree]
#     AUROC: 0.6795
#     G-mean: 0.4988
#     MCC: 0.1369
#     F1-score: 0.1167
#     mAP: 0.2033
#   [Ours - kNN]
#     AUROC: 0.7447
#     G-mean: 0.6188
#     MCC: 0.1884
#     F1-score: 0.1605
#     mAP: 0.2116
#   [Ours - MLP]
#     AUROC: 0.6963
#     G-mean: 0.6246
#     MCC: 0.2173
#     F1-score: 0.1936
#     mAP: 0.3154
#   [Ours - RandomForest]
#     AUROC: 0.8704
#     G-mean: 0.4927
#     MCC: 0.2473
#     F1-score: 0.2457
#     mAP: 0.3467
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.7045
#     G-mean: 0.5397
#     MCC: 0.1888
#     F1-score: 0.1759
#     mAP: 0.2434
#   [Ours - DecisionTree]
#     AUROC: 0.6135
#     G-mean: 0.4439
#     MCC: 0.1190
#     F1-score: 0.1101
#     mAP: 0.1736
#   [Ours - kNN]
#     AUROC: 0.7139
#     G-mean: 0.5200
#     MCC: 0.1585
#     F1-score: 0.1414
#     mAP: 0.1703
#   [Ours - MLP]
#     AUROC: 0.6698
#     G-mean: 0.5949
#     MCC: 0.2026
#     F1-score: 0.1814
#     mAP: 0.3415
#   [Ours - RandomForest]
#     AUROC: 0.8471
#     G-mean: 0.4506
#     MCC: 0.2198
#     F1-score: 0.2178
#     mAP: 0.3208
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.7093
#     G-mean: 0.5558
#     MCC: 0.2009
#     F1-score: 0.1861
#     mAP: 0.2566
#   [Ours - DecisionTree]
#     AUROC: 0.6397
#     G-mean: 0.4386
#     MCC: 0.1152
#     F1-score: 0.1062
#     mAP: 0.1848
#   [Ours - kNN]
#     AUROC: 0.7217
#     G-mean: 0.5010
#     MCC: 0.1477
#     F1-score: 0.1337
#     mAP: 0.1558
#   [Ours - MLP]
#     AUROC: 0.6620
#     G-mean: 0.5706
#     MCC: 0.1889
#     F1-score: 0.1721
#     mAP: 0.3136
#   [Ours - RandomForest]
#     AUROC: 0.8431
#     G-mean: 0.4602
#     MCC: 0.2318
#     F1-score: 0.2296
#     mAP: 0.3293
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.7141
#     G-mean: 0.5215
#     MCC: 0.1829
#     F1-score: 0.1698
#     mAP: 0.2329
#   [Ours - DecisionTree]
#     AUROC: 0.6170
#     G-mean: 0.4251
#     MCC: 0.1137
#     F1-score: 0.1080
#     mAP: 0.1759
#   [Ours - kNN]
#     AUROC: 0.7248
#     G-mean: 0.5180
#     MCC: 0.1559
#     F1-score: 0.1393
#     mAP: 0.1497
#   [Ours - MLP]
#     AUROC: 0.6643
#     G-mean: 0.5597
#     MCC: 0.1901
#     F1-score: 0.1732
#     mAP: 0.3163
#   [Ours - RandomForest]
#     AUROC: 0.8515
#     G-mean: 0.4706
#     MCC: 0.2324
#     F1-score: 0.2291
#     mAP: 0.3284
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.7189
#     G-mean: 0.5114
#     MCC: 0.1837
#     F1-score: 0.1735
#     mAP: 0.2463
#   [Ours - DecisionTree]
#     AUROC: 0.5963
#     G-mean: 0.4105
#     MCC: 0.1057
#     F1-score: 0.1016
#     mAP: 0.1628
#   [Ours - kNN]
#     AUROC: 0.7186
#     G-mean: 0.5187
#     MCC: 0.1542
#     F1-score: 0.1379
#     mAP: 0.1411
#   [Ours - MLP]
#     AUROC: 0.6616
#     G-mean: 0.5411
#     MCC: 0.1807
#     F1-score: 0.1663
#     mAP: 0.3005
#   [Ours - RandomForest]
#     AUROC: 0.8471
#     G-mean: 0.4620
#     MCC: 0.2311
#     F1-score: 0.2291
#     mAP: 0.3336
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.7114
#     G-mean: 0.4900
#     MCC: 0.1794
#     F1-score: 0.1709
#     mAP: 0.2451
#   [Ours - DecisionTree]
#     AUROC: 0.5913
#     G-mean: 0.4162
#     MCC: 0.1038
#     F1-score: 0.0994
#     mAP: 0.1629
#   [Ours - kNN]
#     AUROC: 0.7100
#     G-mean: 0.5069
#     MCC: 0.1535
#     F1-score: 0.1379
#     mAP: 0.1450
#   [Ours - MLP]
#     AUROC: 0.6556
#     G-mean: 0.5183
#     MCC: 0.1745
#     F1-score: 0.1621
#     mAP: 0.2885
#   [Ours - RandomForest]
#     AUROC: 0.8423
#     G-mean: 0.4524
#     MCC: 0.2261
#     F1-score: 0.2249
#     mAP: 0.3217
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.7134
#     G-mean: 0.4827
#     MCC: 0.1755
#     F1-score: 0.1669
#     mAP: 0.2369
#   [Ours - DecisionTree]
#     AUROC: 0.5973
#     G-mean: 0.4430
#     MCC: 0.1094
#     F1-score: 0.1024
#     mAP: 0.1643
#   [Ours - kNN]
#     AUROC: 0.7117
#     G-mean: 0.4979
#     MCC: 0.1512
#     F1-score: 0.1359
#     mAP: 0.1496
#   [Ours - MLP]
#     AUROC: 0.6481
#     G-mean: 0.5104
#     MCC: 0.1690
#     F1-score: 0.1574
#     mAP: 0.2783
#   [Ours - RandomForest]
#     AUROC: 0.8415
#     G-mean: 0.4581
#     MCC: 0.2337
#     F1-score: 0.2334
#     mAP: 0.3276
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.7124
#     G-mean: 0.4677
#     MCC: 0.1708
#     F1-score: 0.1635
#     mAP: 0.2353
#   [Ours - DecisionTree]
#     AUROC: 0.5844
#     G-mean: 0.4353
#     MCC: 0.1078
#     F1-score: 0.1019
#     mAP: 0.1579
#   [Ours - kNN]
#     AUROC: 0.7090
#     G-mean: 0.4846
#     MCC: 0.1454
#     F1-score: 0.1321
#     mAP: 0.1489
#   [Ours - MLP]
#     AUROC: 0.6450
#     G-mean: 0.5001
#     MCC: 0.1653
#     F1-score: 0.1544
#     mAP: 0.2767
#   [Ours - RandomForest]
#     AUROC: 0.8423
#     G-mean: 0.4511
#     MCC: 0.2304
#     F1-score: 0.2307
#     mAP: 0.3273
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.7067
#     G-mean: 0.4558
#     MCC: 0.1624
#     F1-score: 0.1566
#     mAP: 0.2244
#   [Ours - DecisionTree]
#     AUROC: 0.5840
#     G-mean: 0.4397
#     MCC: 0.1100
#     F1-score: 0.1040
#     mAP: 0.1558
#   [Ours - kNN]
#     AUROC: 0.6999
#     G-mean: 0.4691
#     MCC: 0.1377
#     F1-score: 0.1270
#     mAP: 0.1406
#   [Ours - MLP]
#     AUROC: 0.6409
#     G-mean: 0.4946
#     MCC: 0.1609
#     F1-score: 0.1508
#     mAP: 0.2708
#   [Ours - RandomForest]
#     AUROC: 0.8407
#     G-mean: 0.4392
#     MCC: 0.2230
#     F1-score: 0.2241
#     mAP: 0.3206
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.7110
#     G-mean: 0.4528
#     MCC: 0.1609
#     F1-score: 0.1550
#     mAP: 0.2215
#   [Ours - DecisionTree]
#     AUROC: 0.5989
#     G-mean: 0.4576
#     MCC: 0.1142
#     F1-score: 0.1060
#     mAP: 0.1528
#   [Ours - kNN]
#     AUROC: 0.7069
#     G-mean: 0.4731
#     MCC: 0.1402
#     F1-score: 0.1284
#     mAP: 0.1444
#   [Ours - MLP]
#     AUROC: 0.6453
#     G-mean: 0.5010
#     MCC: 0.1628
#     F1-score: 0.1519
#     mAP: 0.2670
#   [Ours - RandomForest]
#     AUROC: 0.8418
#     G-mean: 0.4457
#     MCC: 0.2287
#     F1-score: 0.2297
#     mAP: 0.3239
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/winequality-white-3-9_vs_5_results_gaussian_beta_0.001.csv
# Dataset loaded from DataFrame
# X shape : (1482, 11)
# target : Counter({0: 1457, 1: 25})
# IR: 58.28
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.7434
#     G-mean: 0.5568
#     MCC: 0.2059
#     F1-score: 0.1903
#     mAP: 0.2900
#   [Ours - DecisionTree]
#     AUROC: 0.6241
#     G-mean: 0.5563
#     MCC: 0.1488
#     F1-score: 0.1269
#     mAP: 0.1020
#   [Ours - kNN]
#     AUROC: 0.7602
#     G-mean: 0.6748
#     MCC: 0.2091
#     F1-score: 0.1786
#     mAP: 0.1723
#   [Ours - MLP]
#     AUROC: 0.7003
#     G-mean: 0.5942
#     MCC: 0.1875
#     F1-score: 0.1701
#     mAP: 0.3176
#   [Ours - RandomForest]
#     AUROC: 0.8772
#     G-mean: 0.4923
#     MCC: 0.2394
#     F1-score: 0.2360
#     mAP: 0.3063
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.7031
#     G-mean: 0.5385
#     MCC: 0.1822
#     F1-score: 0.1689
#     mAP: 0.2553
#   [Ours - DecisionTree]
#     AUROC: 0.6008
#     G-mean: 0.4948
#     MCC: 0.1308
#     F1-score: 0.1152
#     mAP: 0.1215
#   [Ours - kNN]
#     AUROC: 0.7137
#     G-mean: 0.5110
#     MCC: 0.1492
#     F1-score: 0.1340
#     mAP: 0.1438
#   [Ours - MLP]
#     AUROC: 0.6676
#     G-mean: 0.5809
#     MCC: 0.1933
#     F1-score: 0.1769
#     mAP: 0.3325
#   [Ours - RandomForest]
#     AUROC: 0.8477
#     G-mean: 0.4507
#     MCC: 0.2284
#     F1-score: 0.2224
#     mAP: 0.2915
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.7098
#     G-mean: 0.5472
#     MCC: 0.1903
#     F1-score: 0.1763
#     mAP: 0.2614
#   [Ours - DecisionTree]
#     AUROC: 0.6050
#     G-mean: 0.4594
#     MCC: 0.1167
#     F1-score: 0.1063
#     mAP: 0.1094
#   [Ours - kNN]
#     AUROC: 0.7274
#     G-mean: 0.4953
#     MCC: 0.1436
#     F1-score: 0.1311
#     mAP: 0.1493
#   [Ours - MLP]
#     AUROC: 0.6606
#     G-mean: 0.5835
#     MCC: 0.1879
#     F1-score: 0.1717
#     mAP: 0.3047
#   [Ours - RandomForest]
#     AUROC: 0.8485
#     G-mean: 0.4373
#     MCC: 0.2279
#     F1-score: 0.2249
#     mAP: 0.3112
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.7111
#     G-mean: 0.5150
#     MCC: 0.1742
#     F1-score: 0.1615
#     mAP: 0.2418
#   [Ours - DecisionTree]
#     AUROC: 0.5991
#     G-mean: 0.4583
#     MCC: 0.1137
#     F1-score: 0.1040
#     mAP: 0.1096
#   [Ours - kNN]
#     AUROC: 0.7236
#     G-mean: 0.4934
#     MCC: 0.1464
#     F1-score: 0.1338
#     mAP: 0.1379
#   [Ours - MLP]
#     AUROC: 0.6604
#     G-mean: 0.5633
#     MCC: 0.1828
#     F1-score: 0.1668
#     mAP: 0.3108
#   [Ours - RandomForest]
#     AUROC: 0.8572
#     G-mean: 0.4185
#     MCC: 0.2053
#     F1-score: 0.2018
#     mAP: 0.3164
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.7160
#     G-mean: 0.5167
#     MCC: 0.1753
#     F1-score: 0.1640
#     mAP: 0.2418
#   [Ours - DecisionTree]
#     AUROC: 0.5930
#     G-mean: 0.4644
#     MCC: 0.1183
#     F1-score: 0.1088
#     mAP: 0.1085
#   [Ours - kNN]
#     AUROC: 0.7261
#     G-mean: 0.5039
#     MCC: 0.1512
#     F1-score: 0.1374
#     mAP: 0.1370
#   [Ours - MLP]
#     AUROC: 0.6605
#     G-mean: 0.5543
#     MCC: 0.1842
#     F1-score: 0.1685
#     mAP: 0.2966
#   [Ours - RandomForest]
#     AUROC: 0.8533
#     G-mean: 0.4268
#     MCC: 0.2068
#     F1-score: 0.2043
#     mAP: 0.3227
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.7097
#     G-mean: 0.4867
#     MCC: 0.1662
#     F1-score: 0.1578
#     mAP: 0.2403
#   [Ours - DecisionTree]
#     AUROC: 0.5796
#     G-mean: 0.4457
#     MCC: 0.1078
#     F1-score: 0.1018
#     mAP: 0.1131
#   [Ours - kNN]
#     AUROC: 0.7161
#     G-mean: 0.4945
#     MCC: 0.1506
#     F1-score: 0.1369
#     mAP: 0.1372
#   [Ours - MLP]
#     AUROC: 0.6576
#     G-mean: 0.5245
#     MCC: 0.1749
#     F1-score: 0.1609
#     mAP: 0.2865
#   [Ours - RandomForest]
#     AUROC: 0.8473
#     G-mean: 0.4268
#     MCC: 0.2077
#     F1-score: 0.2050
#     mAP: 0.3090
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.7128
#     G-mean: 0.4798
#     MCC: 0.1641
#     F1-score: 0.1556
#     mAP: 0.2323
#   [Ours - DecisionTree]
#     AUROC: 0.5840
#     G-mean: 0.4694
#     MCC: 0.1147
#     F1-score: 0.1058
#     mAP: 0.1255
#   [Ours - kNN]
#     AUROC: 0.7168
#     G-mean: 0.4875
#     MCC: 0.1500
#     F1-score: 0.1364
#     mAP: 0.1407
#   [Ours - MLP]
#     AUROC: 0.6522
#     G-mean: 0.5199
#     MCC: 0.1721
#     F1-score: 0.1580
#     mAP: 0.2776
#   [Ours - RandomForest]
#     AUROC: 0.8468
#     G-mean: 0.4278
#     MCC: 0.2097
#     F1-score: 0.2079
#     mAP: 0.3159
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.7127
#     G-mean: 0.4652
#     MCC: 0.1608
#     F1-score: 0.1537
#     mAP: 0.2301
#   [Ours - DecisionTree]
#     AUROC: 0.5722
#     G-mean: 0.4522
#     MCC: 0.1109
#     F1-score: 0.1039
#     mAP: 0.1204
#   [Ours - kNN]
#     AUROC: 0.7096
#     G-mean: 0.4900
#     MCC: 0.1497
#     F1-score: 0.1368
#     mAP: 0.1394
#   [Ours - MLP]
#     AUROC: 0.6485
#     G-mean: 0.4999
#     MCC: 0.1656
#     F1-score: 0.1533
#     mAP: 0.2723
#   [Ours - RandomForest]
#     AUROC: 0.8478
#     G-mean: 0.4334
#     MCC: 0.2146
#     F1-score: 0.2133
#     mAP: 0.3160
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.7069
#     G-mean: 0.4613
#     MCC: 0.1568
#     F1-score: 0.1508
#     mAP: 0.2191
#   [Ours - DecisionTree]
#     AUROC: 0.5765
#     G-mean: 0.4559
#     MCC: 0.1086
#     F1-score: 0.1019
#     mAP: 0.1220
#   [Ours - kNN]
#     AUROC: 0.7007
#     G-mean: 0.4842
#     MCC: 0.1464
#     F1-score: 0.1351
#     mAP: 0.1330
#   [Ours - MLP]
#     AUROC: 0.6445
#     G-mean: 0.5049
#     MCC: 0.1653
#     F1-score: 0.1525
#     mAP: 0.2684
#   [Ours - RandomForest]
#     AUROC: 0.8444
#     G-mean: 0.4235
#     MCC: 0.2110
#     F1-score: 0.2109
#     mAP: 0.3088
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.7113
#     G-mean: 0.4558
#     MCC: 0.1536
#     F1-score: 0.1478
#     mAP: 0.2167
#   [Ours - DecisionTree]
#     AUROC: 0.5870
#     G-mean: 0.4646
#     MCC: 0.1099
#     F1-score: 0.1022
#     mAP: 0.1210
#   [Ours - kNN]
#     AUROC: 0.7076
#     G-mean: 0.5009
#     MCC: 0.1536
#     F1-score: 0.1403
#     mAP: 0.1354
#   [Ours - MLP]
#     AUROC: 0.6480
#     G-mean: 0.5077
#     MCC: 0.1675
#     F1-score: 0.1552
#     mAP: 0.2639
#   [Ours - RandomForest]
#     AUROC: 0.8460
#     G-mean: 0.4297
#     MCC: 0.2165
#     F1-score: 0.2166
#     mAP: 0.3147
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/winequality-white-3-9_vs_5_results_gaussian_beta_0.0.csv

# %%
data_name = 'car_eval_34'
maj_target_name = -1

n_epochs = 2000
hidden_dims = [32, 64, 128]
latent_dim = 256
lr = 0.001
for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        fetch_data_func=fetch_datasets,
        maj_target_name=maj_target_name,
        methods=methods,
        base_models=base_models,
        device=device,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'scene'
maj_target_name = -1

n_epochs = 2000
hidden_dims = [256, 128, 64, 32]
latent_dim = 16
lr = 0.001
for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        fetch_data_func=fetch_datasets,
        maj_target_name=maj_target_name,
        methods=methods,
        base_models=base_models,
        device=device,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'glass4'
# betas = [0.5, 0.1, 0.05, 0.01, 0]
n_epochs = 2000
hidden_dims = [8, 16, 32, 64]
latent_dim = 128
lr = 0.001

for beta in betas:
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'glass-0-1-2-3_vs_4-5-6'

n_epochs = 2000
hidden_dims = [8, 16, 32, 64]
latent_dim = 128
lr = 0.001

for beta in betas:
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'glass-0-1-6_vs_5'
n_epochs = 2000
hidden_dims = [32, 64, 128, 256]
latent_dim = 512
lr = 0.001

for beta in betas:
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )
