# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

# Save path 
save_path = "/data4/oldrain123/oldrain123/results/ablation_results/kernel"
data_path = "/data4/oldrain123/oldrain123/dataset"

# %%
import os
import warnings
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from imblearn.datasets import fetch_datasets
from experiment import run_ablation

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "5"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
methods = ["Ours"]
beta = 0.01
kernel_types = ['imq', 'rq', 'laplacian']
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}

# %%
# data_name = 'arrhythmia'
# maj_target_name = -1

# n_epochs = 1000
# hidden_dims = [256, 128, 64, 32]
# latent_dim = 32
# lr = 0.005

# for kernel_type in kernel_types:
#     print(f"kernel_type: {kernel_type}")
#     run_ablation(
#         data_name=data_name,
#         beta=beta,
#         fetch_data_func=fetch_datasets,
#         maj_target_name=maj_target_name,
#         methods=methods,
#         base_models=base_models,
#         device=device,
#         save_path=save_path,
#         n_epochs=n_epochs,
#         hidden_dims=hidden_dims,
#         latent_dim=latent_dim,
#         lr=lr,
#         kernel_type=kernel_type
#     )

# %%
data_name = 'us_crime'
maj_target_name = -1

n_epochs = 1000
hidden_dims = [100, 64, 32]
latent_dim = 16
lr = 0.005

for kernel_type in kernel_types:
    print(f"kernel_type: {kernel_type}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        fetch_data_func=fetch_datasets,
        maj_target_name=maj_target_name,
        methods=methods,
        base_models=base_models,
        device=device,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr,
        kernel_type=kernel_type
    )
# Out:
# kernel_type: imq
# Dataset loaded: us_crime
# X shape : (1994, 100)
# target : Counter({0: 1844, 1: 150})
# IR: 12.29
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9239
#     G-mean: 0.4295
#     MCC: 0.3341
#     F1-score: 0.3009
#     mAP: 0.5771
#   [Ours - DecisionTree]
#     AUROC: 0.7434
#     G-mean: 0.5797
#     MCC: 0.3732
#     F1-score: 0.4073
#     mAP: 0.3664
#   [Ours - kNN]
#     AUROC: 0.8214
#     G-mean: 0.5112
#     MCC: 0.3787
#     F1-score: 0.3723
#     mAP: 0.4019
#   [Ours - MLP]
#     AUROC: 0.8977
#     G-mean: 0.5174
#     MCC: 0.3793
#     F1-score: 0.3941
#     mAP: 0.5104
#   [Ours - RandomForest]
#     AUROC: 0.9187
#     G-mean: 0.5972
#     MCC: 0.5002
#     F1-score: 0.4882
#     mAP: 0.6078
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9241
#     G-mean: 0.4424
#     MCC: 0.3495
#     F1-score: 0.3154
#     mAP: 0.5787
#   [Ours - DecisionTree]
#     AUROC: 0.7207
#     G-mean: 0.5848
#     MCC: 0.3892
#     F1-score: 0.4189
#     mAP: 0.3551
#   [Ours - kNN]
#     AUROC: 0.8253
#     G-mean: 0.5170
#     MCC: 0.3877
#     F1-score: 0.3805
#     mAP: 0.4095
#   [Ours - MLP]
#     AUROC: 0.9042
#     G-mean: 0.5464
#     MCC: 0.4076
#     F1-score: 0.4178
#     mAP: 0.5284
#   [Ours - RandomForest]
#     AUROC: 0.9207
#     G-mean: 0.5936
#     MCC: 0.4971
#     F1-score: 0.4843
#     mAP: 0.6134
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9226
#     G-mean: 0.4381
#     MCC: 0.3445
#     F1-score: 0.3086
#     mAP: 0.5766
#   [Ours - DecisionTree]
#     AUROC: 0.7276
#     G-mean: 0.5885
#     MCC: 0.3810
#     F1-score: 0.4128
#     mAP: 0.3506
#   [Ours - kNN]
#     AUROC: 0.8212
#     G-mean: 0.5091
#     MCC: 0.3766
#     F1-score: 0.3702
#     mAP: 0.3978
#   [Ours - MLP]
#     AUROC: 0.9049
#     G-mean: 0.5565
#     MCC: 0.4185
#     F1-score: 0.4254
#     mAP: 0.5342
#   [Ours - RandomForest]
#     AUROC: 0.9215
#     G-mean: 0.5864
#     MCC: 0.4890
#     F1-score: 0.4751
#     mAP: 0.6150
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9223
#     G-mean: 0.4353
#     MCC: 0.3430
#     F1-score: 0.3050
#     mAP: 0.5776
#   [Ours - DecisionTree]
#     AUROC: 0.7246
#     G-mean: 0.5935
#     MCC: 0.3889
#     F1-score: 0.4205
#     mAP: 0.3482
#   [Ours - kNN]
#     AUROC: 0.8206
#     G-mean: 0.5181
#     MCC: 0.3888
#     F1-score: 0.3819
#     mAP: 0.4002
#   [Ours - MLP]
#     AUROC: 0.9047
#     G-mean: 0.5589
#     MCC: 0.4173
#     F1-score: 0.4248
#     mAP: 0.5381
#   [Ours - RandomForest]
#     AUROC: 0.9212
#     G-mean: 0.5904
#     MCC: 0.4935
#     F1-score: 0.4798
#     mAP: 0.6135
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9224
#     G-mean: 0.4394
#     MCC: 0.3487
#     F1-score: 0.3086
#     mAP: 0.5803
#   [Ours - DecisionTree]
#     AUROC: 0.7261
#     G-mean: 0.6012
#     MCC: 0.3972
#     F1-score: 0.4279
#     mAP: 0.3491
#   [Ours - kNN]
#     AUROC: 0.8195
#     G-mean: 0.5166
#     MCC: 0.3881
#     F1-score: 0.3800
#     mAP: 0.4000
#   [Ours - MLP]
#     AUROC: 0.9066
#     G-mean: 0.5606
#     MCC: 0.4171
#     F1-score: 0.4245
#     mAP: 0.5398
#   [Ours - RandomForest]
#     AUROC: 0.9214
#     G-mean: 0.5935
#     MCC: 0.4973
#     F1-score: 0.4835
#     mAP: 0.6154
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9226
#     G-mean: 0.4400
#     MCC: 0.3500
#     F1-score: 0.3100
#     mAP: 0.5815
#   [Ours - DecisionTree]
#     AUROC: 0.7327
#     G-mean: 0.6035
#     MCC: 0.3993
#     F1-score: 0.4300
#     mAP: 0.3529
#   [Ours - kNN]
#     AUROC: 0.8181
#     G-mean: 0.5101
#     MCC: 0.3856
#     F1-score: 0.3767
#     mAP: 0.3997
#   [Ours - MLP]
#     AUROC: 0.9049
#     G-mean: 0.5545
#     MCC: 0.4102
#     F1-score: 0.4172
#     mAP: 0.5372
#   [Ours - RandomForest]
#     AUROC: 0.9215
#     G-mean: 0.5910
#     MCC: 0.4955
#     F1-score: 0.4811
#     mAP: 0.6129
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9225
#     G-mean: 0.4362
#     MCC: 0.3476
#     F1-score: 0.3061
#     mAP: 0.5804
#   [Ours - DecisionTree]
#     AUROC: 0.7338
#     G-mean: 0.5940
#     MCC: 0.3936
#     F1-score: 0.4242
#     mAP: 0.3516
#   [Ours - kNN]
#     AUROC: 0.8186
#     G-mean: 0.5084
#     MCC: 0.3866
#     F1-score: 0.3759
#     mAP: 0.4014
#   [Ours - MLP]
#     AUROC: 0.9053
#     G-mean: 0.5549
#     MCC: 0.4118
#     F1-score: 0.4174
#     mAP: 0.5377
#   [Ours - RandomForest]
#     AUROC: 0.9215
#     G-mean: 0.5880
#     MCC: 0.4909
#     F1-score: 0.4768
#     mAP: 0.6102
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9229
#     G-mean: 0.4351
#     MCC: 0.3463
#     F1-score: 0.3044
#     mAP: 0.5811
#   [Ours - DecisionTree]
#     AUROC: 0.7381
#     G-mean: 0.5895
#     MCC: 0.3903
#     F1-score: 0.4196
#     mAP: 0.3563
#   [Ours - kNN]
#     AUROC: 0.8170
#     G-mean: 0.5117
#     MCC: 0.3896
#     F1-score: 0.3790
#     mAP: 0.4027
#   [Ours - MLP]
#     AUROC: 0.9045
#     G-mean: 0.5550
#     MCC: 0.4113
#     F1-score: 0.4169
#     mAP: 0.5370
#   [Ours - RandomForest]
#     AUROC: 0.9214
#     G-mean: 0.5879
#     MCC: 0.4913
#     F1-score: 0.4770
#     mAP: 0.6102
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9228
#     G-mean: 0.4387
#     MCC: 0.3481
#     F1-score: 0.3072
#     mAP: 0.5813
#   [Ours - DecisionTree]
#     AUROC: 0.7390
#     G-mean: 0.5910
#     MCC: 0.3876
#     F1-score: 0.4180
#     mAP: 0.3541
#   [Ours - kNN]
#     AUROC: 0.8175
#     G-mean: 0.5118
#     MCC: 0.3892
#     F1-score: 0.3786
#     mAP: 0.4044
#   [Ours - MLP]
#     AUROC: 0.9050
#     G-mean: 0.5577
#     MCC: 0.4130
#     F1-score: 0.4194
#     mAP: 0.5367
#   [Ours - RandomForest]
#     AUROC: 0.9217
#     G-mean: 0.5879
#     MCC: 0.4912
#     F1-score: 0.4768
#     mAP: 0.6103
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9226
#     G-mean: 0.4402
#     MCC: 0.3513
#     F1-score: 0.3107
#     mAP: 0.5805
#   [Ours - DecisionTree]
#     AUROC: 0.7436
#     G-mean: 0.5925
#     MCC: 0.3894
#     F1-score: 0.4191
#     mAP: 0.3545
#   [Ours - kNN]
#     AUROC: 0.8169
#     G-mean: 0.5131
#     MCC: 0.3905
#     F1-score: 0.3795
#     mAP: 0.4037
#   [Ours - MLP]
#     AUROC: 0.9043
#     G-mean: 0.5544
#     MCC: 0.4104
#     F1-score: 0.4159
#     mAP: 0.5326
#   [Ours - RandomForest]
#     AUROC: 0.9218
#     G-mean: 0.5872
#     MCC: 0.4891
#     F1-score: 0.4747
#     mAP: 0.6098
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/kernel/us_crime_results_imq_beta_0.01.csv
# kernel_type: rq
# Dataset loaded: us_crime
# X shape : (1994, 100)
# target : Counter({0: 1844, 1: 150})
# IR: 12.29
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9064
#     G-mean: 0.6367
#     MCC: 0.4908
#     F1-score: 0.5033
#     mAP: 0.5792
#   [Ours - DecisionTree]
#     AUROC: 0.6927
#     G-mean: 0.5812
#     MCC: 0.3685
#     F1-score: 0.4030
#     mAP: 0.3173
#   [Ours - kNN]
#     AUROC: 0.8217
#     G-mean: 0.5173
#     MCC: 0.3855
#     F1-score: 0.3794
#     mAP: 0.4052
#   [Ours - MLP]
#     AUROC: 0.8976
#     G-mean: 0.6459
#     MCC: 0.4111
#     F1-score: 0.4500
#     mAP: 0.5339
#   [Ours - RandomForest]
#     AUROC: 0.9218
#     G-mean: 0.6464
#     MCC: 0.4913
#     F1-score: 0.5085
#     mAP: 0.5749
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9117
#     G-mean: 0.6309
#     MCC: 0.4742
#     F1-score: 0.4918
#     mAP: 0.5775
#   [Ours - DecisionTree]
#     AUROC: 0.7153
#     G-mean: 0.6124
#     MCC: 0.3871
#     F1-score: 0.4239
#     mAP: 0.3221
#   [Ours - kNN]
#     AUROC: 0.8253
#     G-mean: 0.5171
#     MCC: 0.3878
#     F1-score: 0.3805
#     mAP: 0.4093
#   [Ours - MLP]
#     AUROC: 0.9031
#     G-mean: 0.6552
#     MCC: 0.4226
#     F1-score: 0.4611
#     mAP: 0.5416
#   [Ours - RandomForest]
#     AUROC: 0.9239
#     G-mean: 0.6434
#     MCC: 0.4812
#     F1-score: 0.5012
#     mAP: 0.5890
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9122
#     G-mean: 0.6315
#     MCC: 0.4770
#     F1-score: 0.4936
#     mAP: 0.5791
#   [Ours - DecisionTree]
#     AUROC: 0.7409
#     G-mean: 0.6251
#     MCC: 0.3949
#     F1-score: 0.4323
#     mAP: 0.3293
#   [Ours - kNN]
#     AUROC: 0.8210
#     G-mean: 0.5092
#     MCC: 0.3766
#     F1-score: 0.3702
#     mAP: 0.3973
#   [Ours - MLP]
#     AUROC: 0.9028
#     G-mean: 0.6660
#     MCC: 0.4395
#     F1-score: 0.4739
#     mAP: 0.5379
#   [Ours - RandomForest]
#     AUROC: 0.9219
#     G-mean: 0.6374
#     MCC: 0.4751
#     F1-score: 0.4941
#     mAP: 0.5838
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9132
#     G-mean: 0.6294
#     MCC: 0.4748
#     F1-score: 0.4920
#     mAP: 0.5850
#   [Ours - DecisionTree]
#     AUROC: 0.7330
#     G-mean: 0.6209
#     MCC: 0.3850
#     F1-score: 0.4237
#     mAP: 0.3232
#   [Ours - kNN]
#     AUROC: 0.8206
#     G-mean: 0.5198
#     MCC: 0.3908
#     F1-score: 0.3838
#     mAP: 0.4010
#   [Ours - MLP]
#     AUROC: 0.9048
#     G-mean: 0.6626
#     MCC: 0.4398
#     F1-score: 0.4737
#     mAP: 0.5423
#   [Ours - RandomForest]
#     AUROC: 0.9212
#     G-mean: 0.6384
#     MCC: 0.4792
#     F1-score: 0.4979
#     mAP: 0.5841
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9151
#     G-mean: 0.6343
#     MCC: 0.4829
#     F1-score: 0.4994
#     mAP: 0.5884
#   [Ours - DecisionTree]
#     AUROC: 0.7407
#     G-mean: 0.6209
#     MCC: 0.3837
#     F1-score: 0.4232
#     mAP: 0.3272
#   [Ours - kNN]
#     AUROC: 0.8195
#     G-mean: 0.5179
#     MCC: 0.3897
#     F1-score: 0.3815
#     mAP: 0.4007
#   [Ours - MLP]
#     AUROC: 0.9065
#     G-mean: 0.6651
#     MCC: 0.4443
#     F1-score: 0.4778
#     mAP: 0.5456
#   [Ours - RandomForest]
#     AUROC: 0.9210
#     G-mean: 0.6379
#     MCC: 0.4794
#     F1-score: 0.4977
#     mAP: 0.5847
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9149
#     G-mean: 0.6365
#     MCC: 0.4871
#     F1-score: 0.5023
#     mAP: 0.5866
#   [Ours - DecisionTree]
#     AUROC: 0.7421
#     G-mean: 0.6208
#     MCC: 0.3814
#     F1-score: 0.4216
#     mAP: 0.3254
#   [Ours - kNN]
#     AUROC: 0.8182
#     G-mean: 0.5122
#     MCC: 0.3879
#     F1-score: 0.3791
#     mAP: 0.4008
#   [Ours - MLP]
#     AUROC: 0.9052
#     G-mean: 0.6623
#     MCC: 0.4427
#     F1-score: 0.4762
#     mAP: 0.5438
#   [Ours - RandomForest]
#     AUROC: 0.9209
#     G-mean: 0.6332
#     MCC: 0.4756
#     F1-score: 0.4927
#     mAP: 0.5805
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9152
#     G-mean: 0.6336
#     MCC: 0.4817
#     F1-score: 0.4975
#     mAP: 0.5844
#   [Ours - DecisionTree]
#     AUROC: 0.7425
#     G-mean: 0.6257
#     MCC: 0.3877
#     F1-score: 0.4276
#     mAP: 0.3312
#   [Ours - kNN]
#     AUROC: 0.8187
#     G-mean: 0.5109
#     MCC: 0.3893
#     F1-score: 0.3788
#     mAP: 0.4026
#   [Ours - MLP]
#     AUROC: 0.9053
#     G-mean: 0.6637
#     MCC: 0.4446
#     F1-score: 0.4782
#     mAP: 0.5434
#   [Ours - RandomForest]
#     AUROC: 0.9209
#     G-mean: 0.6316
#     MCC: 0.4727
#     F1-score: 0.4899
#     mAP: 0.5776
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9162
#     G-mean: 0.6364
#     MCC: 0.4850
#     F1-score: 0.5003
#     mAP: 0.5842
#   [Ours - DecisionTree]
#     AUROC: 0.7424
#     G-mean: 0.6217
#     MCC: 0.3863
#     F1-score: 0.4256
#     mAP: 0.3303
#   [Ours - kNN]
#     AUROC: 0.8171
#     G-mean: 0.5139
#     MCC: 0.3920
#     F1-score: 0.3816
#     mAP: 0.4037
#   [Ours - MLP]
#     AUROC: 0.9057
#     G-mean: 0.6642
#     MCC: 0.4453
#     F1-score: 0.4788
#     mAP: 0.5431
#   [Ours - RandomForest]
#     AUROC: 0.9212
#     G-mean: 0.6328
#     MCC: 0.4712
#     F1-score: 0.4893
#     mAP: 0.5800
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9166
#     G-mean: 0.6372
#     MCC: 0.4849
#     F1-score: 0.5008
#     mAP: 0.5857
#   [Ours - DecisionTree]
#     AUROC: 0.7452
#     G-mean: 0.6221
#     MCC: 0.3863
#     F1-score: 0.4256
#     mAP: 0.3322
#   [Ours - kNN]
#     AUROC: 0.8175
#     G-mean: 0.5137
#     MCC: 0.3913
#     F1-score: 0.3809
#     mAP: 0.4049
#   [Ours - MLP]
#     AUROC: 0.9065
#     G-mean: 0.6649
#     MCC: 0.4456
#     F1-score: 0.4791
#     mAP: 0.5440
#   [Ours - RandomForest]
#     AUROC: 0.9216
#     G-mean: 0.6335
#     MCC: 0.4735
#     F1-score: 0.4912
#     mAP: 0.5797
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9162
#     G-mean: 0.6359
#     MCC: 0.4848
#     F1-score: 0.4994
#     mAP: 0.5863
#   [Ours - DecisionTree]
#     AUROC: 0.7494
#     G-mean: 0.6245
#     MCC: 0.3904
#     F1-score: 0.4289
#     mAP: 0.3348
#   [Ours - kNN]
#     AUROC: 0.8169
#     G-mean: 0.5154
#     MCC: 0.3931
#     F1-score: 0.3823
#     mAP: 0.4044
#   [Ours - MLP]
#     AUROC: 0.9068
#     G-mean: 0.6646
#     MCC: 0.4458
#     F1-score: 0.4789
#     mAP: 0.5456
#   [Ours - RandomForest]
#     AUROC: 0.9217
#     G-mean: 0.6319
#     MCC: 0.4721
#     F1-score: 0.4891
#     mAP: 0.5808
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/kernel/us_crime_results_rq_beta_0.01.csv
# kernel_type: laplacian
# Dataset loaded: us_crime
# X shape : (1994, 100)
# target : Counter({0: 1844, 1: 150})
# IR: 12.29
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9174
#     G-mean: 0.6492
#     MCC: 0.4612
#     F1-score: 0.4893
#     mAP: 0.5330
#   [Ours - DecisionTree]
#     AUROC: 0.7881
#     G-mean: 0.6574
#     MCC: 0.4355
#     F1-score: 0.4732
#     mAP: 0.3842
#   [Ours - kNN]
#     AUROC: 0.8250
#     G-mean: 0.5112
#     MCC: 0.3787
#     F1-score: 0.3723
#     mAP: 0.4036
#   [Ours - MLP]
#     AUROC: 0.9010
#     G-mean: 0.6314
#     MCC: 0.4183
#     F1-score: 0.4542
#     mAP: 0.5218
#   [Ours - RandomForest]
#     AUROC: 0.9233
#     G-mean: 0.6211
#     MCC: 0.4826
#     F1-score: 0.4900
#     mAP: 0.5796
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9179
#     G-mean: 0.6561
#     MCC: 0.4673
#     F1-score: 0.4920
#     mAP: 0.5341
#   [Ours - DecisionTree]
#     AUROC: 0.7997
#     G-mean: 0.6545
#     MCC: 0.4257
#     F1-score: 0.4645
#     mAP: 0.3794
#   [Ours - kNN]
#     AUROC: 0.8268
#     G-mean: 0.5196
#     MCC: 0.3872
#     F1-score: 0.3822
#     mAP: 0.4088
#   [Ours - MLP]
#     AUROC: 0.9060
#     G-mean: 0.6492
#     MCC: 0.4509
#     F1-score: 0.4794
#     mAP: 0.5386
#   [Ours - RandomForest]
#     AUROC: 0.9245
#     G-mean: 0.6241
#     MCC: 0.4798
#     F1-score: 0.4920
#     mAP: 0.5814
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9178
#     G-mean: 0.6498
#     MCC: 0.4682
#     F1-score: 0.4910
#     mAP: 0.5369
#   [Ours - DecisionTree]
#     AUROC: 0.7763
#     G-mean: 0.6372
#     MCC: 0.4061
#     F1-score: 0.4460
#     mAP: 0.3575
#   [Ours - kNN]
#     AUROC: 0.8223
#     G-mean: 0.5151
#     MCC: 0.3788
#     F1-score: 0.3755
#     mAP: 0.3984
#   [Ours - MLP]
#     AUROC: 0.9033
#     G-mean: 0.6320
#     MCC: 0.4348
#     F1-score: 0.4631
#     mAP: 0.5375
#   [Ours - RandomForest]
#     AUROC: 0.9229
#     G-mean: 0.6244
#     MCC: 0.4775
#     F1-score: 0.4902
#     mAP: 0.5788
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9179
#     G-mean: 0.6473
#     MCC: 0.4670
#     F1-score: 0.4901
#     mAP: 0.5396
#   [Ours - DecisionTree]
#     AUROC: 0.7807
#     G-mean: 0.6491
#     MCC: 0.4187
#     F1-score: 0.4583
#     mAP: 0.3695
#   [Ours - kNN]
#     AUROC: 0.8216
#     G-mean: 0.5255
#     MCC: 0.3938
#     F1-score: 0.3894
#     mAP: 0.4021
#   [Ours - MLP]
#     AUROC: 0.9035
#     G-mean: 0.6286
#     MCC: 0.4315
#     F1-score: 0.4604
#     mAP: 0.5372
#   [Ours - RandomForest]
#     AUROC: 0.9228
#     G-mean: 0.6245
#     MCC: 0.4755
#     F1-score: 0.4889
#     mAP: 0.5793
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9185
#     G-mean: 0.6516
#     MCC: 0.4686
#     F1-score: 0.4928
#     mAP: 0.5416
#   [Ours - DecisionTree]
#     AUROC: 0.7834
#     G-mean: 0.6619
#     MCC: 0.4279
#     F1-score: 0.4674
#     mAP: 0.3690
#   [Ours - kNN]
#     AUROC: 0.8203
#     G-mean: 0.5250
#     MCC: 0.3947
#     F1-score: 0.3889
#     mAP: 0.4015
#   [Ours - MLP]
#     AUROC: 0.9040
#     G-mean: 0.6341
#     MCC: 0.4354
#     F1-score: 0.4643
#     mAP: 0.5401
#   [Ours - RandomForest]
#     AUROC: 0.9230
#     G-mean: 0.6267
#     MCC: 0.4775
#     F1-score: 0.4909
#     mAP: 0.5822
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9179
#     G-mean: 0.6495
#     MCC: 0.4660
#     F1-score: 0.4907
#     mAP: 0.5422
#   [Ours - DecisionTree]
#     AUROC: 0.7838
#     G-mean: 0.6583
#     MCC: 0.4226
#     F1-score: 0.4622
#     mAP: 0.3647
#   [Ours - kNN]
#     AUROC: 0.8189
#     G-mean: 0.5200
#     MCC: 0.3919
#     F1-score: 0.3869
#     mAP: 0.4019
#   [Ours - MLP]
#     AUROC: 0.9043
#     G-mean: 0.6301
#     MCC: 0.4325
#     F1-score: 0.4611
#     mAP: 0.5407
#   [Ours - RandomForest]
#     AUROC: 0.9225
#     G-mean: 0.6290
#     MCC: 0.4800
#     F1-score: 0.4928
#     mAP: 0.5815
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9177
#     G-mean: 0.6455
#     MCC: 0.4628
#     F1-score: 0.4873
#     mAP: 0.5407
#   [Ours - DecisionTree]
#     AUROC: 0.7857
#     G-mean: 0.6515
#     MCC: 0.4161
#     F1-score: 0.4556
#     mAP: 0.3624
#   [Ours - kNN]
#     AUROC: 0.8193
#     G-mean: 0.5190
#     MCC: 0.3938
#     F1-score: 0.3865
#     mAP: 0.4042
#   [Ours - MLP]
#     AUROC: 0.9049
#     G-mean: 0.6293
#     MCC: 0.4337
#     F1-score: 0.4620
#     mAP: 0.5404
#   [Ours - RandomForest]
#     AUROC: 0.9227
#     G-mean: 0.6271
#     MCC: 0.4790
#     F1-score: 0.4913
#     mAP: 0.5800
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9178
#     G-mean: 0.6470
#     MCC: 0.4629
#     F1-score: 0.4877
#     mAP: 0.5418
#   [Ours - DecisionTree]
#     AUROC: 0.7769
#     G-mean: 0.6470
#     MCC: 0.4086
#     F1-score: 0.4488
#     mAP: 0.3557
#   [Ours - kNN]
#     AUROC: 0.8177
#     G-mean: 0.5227
#     MCC: 0.3970
#     F1-score: 0.3901
#     mAP: 0.4052
#   [Ours - MLP]
#     AUROC: 0.9059
#     G-mean: 0.6299
#     MCC: 0.4373
#     F1-score: 0.4643
#     mAP: 0.5437
#   [Ours - RandomForest]
#     AUROC: 0.9228
#     G-mean: 0.6252
#     MCC: 0.4768
#     F1-score: 0.4892
#     mAP: 0.5802
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9177
#     G-mean: 0.6510
#     MCC: 0.4663
#     F1-score: 0.4911
#     mAP: 0.5420
#   [Ours - DecisionTree]
#     AUROC: 0.7791
#     G-mean: 0.6499
#     MCC: 0.4123
#     F1-score: 0.4523
#     mAP: 0.3581
#   [Ours - kNN]
#     AUROC: 0.8188
#     G-mean: 0.5216
#     MCC: 0.3951
#     F1-score: 0.3880
#     mAP: 0.4067
#   [Ours - MLP]
#     AUROC: 0.9065
#     G-mean: 0.6320
#     MCC: 0.4388
#     F1-score: 0.4664
#     mAP: 0.5456
#   [Ours - RandomForest]
#     AUROC: 0.9231
#     G-mean: 0.6286
#     MCC: 0.4819
#     F1-score: 0.4941
#     mAP: 0.5824
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9181
#     G-mean: 0.6524
#     MCC: 0.4666
#     F1-score: 0.4905
#     mAP: 0.5434
#   [Ours - DecisionTree]
#     AUROC: 0.7797
#     G-mean: 0.6529
#     MCC: 0.4155
#     F1-score: 0.4550
#     mAP: 0.3596
#   [Ours - kNN]
#     AUROC: 0.8181
#     G-mean: 0.5223
#     MCC: 0.3950
#     F1-score: 0.3880
#     mAP: 0.4055
#   [Ours - MLP]
#     AUROC: 0.9068
#     G-mean: 0.6326
#     MCC: 0.4393
#     F1-score: 0.4664
#     mAP: 0.5448
#   [Ours - RandomForest]
#     AUROC: 0.9234
#     G-mean: 0.6280
#     MCC: 0.4800
#     F1-score: 0.4925
#     mAP: 0.5843
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/kernel/us_crime_results_laplacian_beta_0.01.csv
