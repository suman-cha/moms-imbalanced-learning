# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

# Save path 
save_path = "/data4/oldrain123/oldrain123/results/ablation_results/classifiers"
data_path = "/data4/oldrain123/oldrain123/dataset"

# %%
import os
import warnings
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from experiment import run_exp
from imblearn.datasets import fetch_datasets

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "7"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
data = fetch_datasets()
methods = ["Original", "SMOTE", "ADASYN", "bSMOTE", "ROS", "MWMOTE", "CTGAN"]
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}

# %%
data_name = 'sick_euthyroid'
maj_target_name = -1

n_epochs = 2000
hidden_dims = [64, 128, 256]
latent_dim = 512
lr = 0.01
run_exp(
    data=data, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models,  
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=0.0,
    seed=1203, 
    data_name=data_name, 
    maj_target_name=maj_target_name,    
    save_path=save_path
)
# Out:
# Dataset loaded: sick_euthyroid
# X shape : (3163, 42)
# target : Counter({0: 2870, 1: 293})
# IR: 9.8
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Original - SVM]
#     AUROC: 0.9418
#     G-mean: 0.3578
#     MCC: 0.2800
#     F1-score: 0.2213
#     mAP: 0.7000
#   [Original - DecisionTree]
#     AUROC: 0.9443
#     G-mean: 0.9171
#     MCC: 0.8498
#     F1-score: 0.8626
#     mAP: 0.8095
#   [Original - kNN]
#     AUROC: 0.8907
#     G-mean: 0.6711
#     MCC: 0.5536
#     F1-score: 0.5666
#     mAP: 0.5769
#   [Original - MLP]
#     AUROC: 0.8972
#     G-mean: 0.5064
#     MCC: 0.4278
#     F1-score: 0.4194
#     mAP: 0.6246
#   [Original - RandomForest]
#     AUROC: 0.9842
#     G-mean: 0.9160
#     MCC: 0.8620
#     F1-score: 0.8723
#     mAP: 0.9114
#   [SMOTE - SVM]
#     AUROC: 0.9489
#     G-mean: 0.8965
#     MCC: 0.6090
#     F1-score: 0.6234
#     mAP: 0.7379
#   [SMOTE - DecisionTree]
#     AUROC: 0.9668
#     G-mean: 0.9380
#     MCC: 0.7731
#     F1-score: 0.7841
#     mAP: 0.8469
#   [SMOTE - kNN]
#     AUROC: 0.9015
#     G-mean: 0.8445
#     MCC: 0.5368
#     F1-score: 0.5652
#     mAP: 0.5510
#   [SMOTE - MLP]
#     AUROC: 0.9599
#     G-mean: 0.9146
#     MCC: 0.6887
#     F1-score: 0.7055
#     mAP: 0.7810
#   [SMOTE - RandomForest]
#     AUROC: 0.9856
#     G-mean: 0.9340
#     MCC: 0.8459
#     F1-score: 0.8589
#     mAP: 0.9040
#   [ADASYN - SVM]
#     AUROC: 0.9478
#     G-mean: 0.8945
#     MCC: 0.5883
#     F1-score: 0.5997
#     mAP: 0.7170
#   [ADASYN - DecisionTree]
#     AUROC: 0.9636
#     G-mean: 0.9432
#     MCC: 0.7718
#     F1-score: 0.7838
#     mAP: 0.8481
#   [ADASYN - kNN]
#     AUROC: 0.8991
#     G-mean: 0.8510
#     MCC: 0.5392
#     F1-score: 0.5651
#     mAP: 0.5215
#   [ADASYN - MLP]
#     AUROC: 0.9590
#     G-mean: 0.9152
#     MCC: 0.6800
#     F1-score: 0.6953
#     mAP: 0.7708
#   [ADASYN - RandomForest]
#     AUROC: 0.9859
#     G-mean: 0.9309
#     MCC: 0.8323
#     F1-score: 0.8464
#     mAP: 0.9002
#   [bSMOTE - SVM]
#     AUROC: 0.9426
#     G-mean: 0.8820
#     MCC: 0.5882
#     F1-score: 0.6068
#     mAP: 0.7193
#   [bSMOTE - DecisionTree]
#     AUROC: 0.9606
#     G-mean: 0.9344
#     MCC: 0.7813
#     F1-score: 0.7946
#     mAP: 0.8417
#   [bSMOTE - kNN]
#     AUROC: 0.8948
#     G-mean: 0.8391
#     MCC: 0.5403
#     F1-score: 0.5715
#     mAP: 0.5357
#   [bSMOTE - MLP]
#     AUROC: 0.9559
#     G-mean: 0.9079
#     MCC: 0.6978
#     F1-score: 0.7176
#     mAP: 0.7751
#   [bSMOTE - RandomForest]
#     AUROC: 0.9858
#     G-mean: 0.9298
#     MCC: 0.8495
#     F1-score: 0.8622
#     mAP: 0.9025
#   [ROS - SVM]
#     AUROC: 0.9488
#     G-mean: 0.8985
#     MCC: 0.5987
#     F1-score: 0.6100
#     mAP: 0.7301
#   [ROS - DecisionTree]
#     AUROC: 0.9626
#     G-mean: 0.9524
#     MCC: 0.8099
#     F1-score: 0.8216
#     mAP: 0.8404
#   [ROS - kNN]
#     AUROC: 0.8882
#     G-mean: 0.8375
#     MCC: 0.5377
#     F1-score: 0.5695
#     mAP: 0.5163
#   [ROS - MLP]
#     AUROC: 0.9599
#     G-mean: 0.9153
#     MCC: 0.6854
#     F1-score: 0.7015
#     mAP: 0.7709
#   [ROS - RandomForest]
#     AUROC: 0.9872
#     G-mean: 0.9268
#     MCC: 0.8681
#     F1-score: 0.8790
#     mAP: 0.9179
#   [MWMOTE - SVM]
#     AUROC: 0.9425
#     G-mean: 0.8773
#     MCC: 0.5952
#     F1-score: 0.6169
#     mAP: 0.7496
#   [MWMOTE - DecisionTree]
#     AUROC: 0.9508
#     G-mean: 0.9229
#     MCC: 0.7829
#     F1-score: 0.7983
#     mAP: 0.8265
#   [MWMOTE - kNN]
#     AUROC: 0.9092
#     G-mean: 0.8441
#     MCC: 0.5393
#     F1-score: 0.5686
#     mAP: 0.5657
#   [MWMOTE - MLP]
#     AUROC: 0.9548
#     G-mean: 0.9002
#     MCC: 0.6575
#     F1-score: 0.6763
#     mAP: 0.7890
#   [MWMOTE - RandomForest]
#     AUROC: 0.9840
#     G-mean: 0.9282
#     MCC: 0.8335
#     F1-score: 0.8480
#     mAP: 0.8963
#   [CTGAN - SVM]
#     AUROC: 0.9294
#     G-mean: 0.7646
#     MCC: 0.5867
#     F1-score: 0.6225
#     mAP: 0.6471
#   [CTGAN - DecisionTree]
#     AUROC: 0.9663
#     G-mean: 0.9272
#     MCC: 0.8544
#     F1-score: 0.8668
#     mAP: 0.8166
#   [CTGAN - kNN]
#     AUROC: 0.8951
#     G-mean: 0.6922
#     MCC: 0.5564
#     F1-score: 0.5793
#     mAP: 0.5671
#   [CTGAN - MLP]
#     AUROC: 0.9502
#     G-mean: 0.8339
#     MCC: 0.6931
#     F1-score: 0.7199
#     mAP: 0.7420
#   [CTGAN - RandomForest]
#     AUROC: 0.9847
#     G-mean: 0.9218
#     MCC: 0.8669
#     F1-score: 0.8775
#     mAP: 0.9185
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Original - SVM]
#     AUROC: 0.9415
#     G-mean: 0.3518
#     MCC: 0.2779
#     F1-score: 0.2189
#     mAP: 0.7030
#   [Original - DecisionTree]
#     AUROC: 0.9510
#     G-mean: 0.9175
#     MCC: 0.8520
#     F1-score: 0.8647
#     mAP: 0.8175
#   [Original - kNN]
#     AUROC: 0.8889
#     G-mean: 0.6726
#     MCC: 0.5588
#     F1-score: 0.5704
#     mAP: 0.5720
#   [Original - MLP]
#     AUROC: 0.8778
#     G-mean: 0.4325
#     MCC: 0.3704
#     F1-score: 0.3485
#     mAP: 0.5772
#   [Original - RandomForest]
#     AUROC: 0.9851
#     G-mean: 0.9172
#     MCC: 0.8621
#     F1-score: 0.8728
#     mAP: 0.9083
#   [SMOTE - SVM]
#     AUROC: 0.9496
#     G-mean: 0.8969
#     MCC: 0.6139
#     F1-score: 0.6287
#     mAP: 0.7450
#   [SMOTE - DecisionTree]
#     AUROC: 0.9647
#     G-mean: 0.9412
#     MCC: 0.7839
#     F1-score: 0.7959
#     mAP: 0.8440
#   [SMOTE - kNN]
#     AUROC: 0.8992
#     G-mean: 0.8466
#     MCC: 0.5429
#     F1-score: 0.5713
#     mAP: 0.5394
#   [SMOTE - MLP]
#     AUROC: 0.9596
#     G-mean: 0.9144
#     MCC: 0.6956
#     F1-score: 0.7128
#     mAP: 0.7814
#   [SMOTE - RandomForest]
#     AUROC: 0.9862
#     G-mean: 0.9347
#     MCC: 0.8488
#     F1-score: 0.8620
#     mAP: 0.9043
#   [ADASYN - SVM]
#     AUROC: 0.9489
#     G-mean: 0.8935
#     MCC: 0.5865
#     F1-score: 0.5981
#     mAP: 0.7229
#   [ADASYN - DecisionTree]
#     AUROC: 0.9616
#     G-mean: 0.9431
#     MCC: 0.7669
#     F1-score: 0.7783
#     mAP: 0.8455
#   [ADASYN - kNN]
#     AUROC: 0.8982
#     G-mean: 0.8486
#     MCC: 0.5343
#     F1-score: 0.5608
#     mAP: 0.5226
#   [ADASYN - MLP]
#     AUROC: 0.9586
#     G-mean: 0.9140
#     MCC: 0.6842
#     F1-score: 0.7001
#     mAP: 0.7629
#   [ADASYN - RandomForest]
#     AUROC: 0.9862
#     G-mean: 0.9341
#     MCC: 0.8360
#     F1-score: 0.8502
#     mAP: 0.9017
#   [bSMOTE - SVM]
#     AUROC: 0.9435
#     G-mean: 0.8815
#     MCC: 0.5895
#     F1-score: 0.6084
#     mAP: 0.7275
#   [bSMOTE - DecisionTree]
#     AUROC: 0.9567
#     G-mean: 0.9363
#     MCC: 0.7805
#     F1-score: 0.7942
#     mAP: 0.8365
#   [bSMOTE - kNN]
#     AUROC: 0.8936
#     G-mean: 0.8405
#     MCC: 0.5413
#     F1-score: 0.5719
#     mAP: 0.5307
#   [bSMOTE - MLP]
#     AUROC: 0.9562
#     G-mean: 0.9062
#     MCC: 0.6932
#     F1-score: 0.7128
#     mAP: 0.7739
#   [bSMOTE - RandomForest]
#     AUROC: 0.9857
#     G-mean: 0.9309
#     MCC: 0.8500
#     F1-score: 0.8631
#     mAP: 0.9038
#   [ROS - SVM]
#     AUROC: 0.9500
#     G-mean: 0.8969
#     MCC: 0.5972
#     F1-score: 0.6091
#     mAP: 0.7344
#   [ROS - DecisionTree]
#     AUROC: 0.9576
#     G-mean: 0.9461
#     MCC: 0.8132
#     F1-score: 0.8257
#     mAP: 0.8397
#   [ROS - kNN]
#     AUROC: 0.8864
#     G-mean: 0.8427
#     MCC: 0.5474
#     F1-score: 0.5779
#     mAP: 0.5158
#   [ROS - MLP]
#     AUROC: 0.9597
#     G-mean: 0.9131
#     MCC: 0.6851
#     F1-score: 0.7019
#     mAP: 0.7645
#   [ROS - RandomForest]
#     AUROC: 0.9870
#     G-mean: 0.9249
#     MCC: 0.8631
#     F1-score: 0.8748
#     mAP: 0.9152
#   [MWMOTE - SVM]
#     AUROC: 0.9430
#     G-mean: 0.8763
#     MCC: 0.5943
#     F1-score: 0.6163
#     mAP: 0.7507
#   [MWMOTE - DecisionTree]
#     AUROC: 0.9582
#     G-mean: 0.9299
#     MCC: 0.7836
#     F1-score: 0.7985
#     mAP: 0.8357
#   [MWMOTE - kNN]
#     AUROC: 0.9071
#     G-mean: 0.8433
#     MCC: 0.5374
#     F1-score: 0.5665
#     mAP: 0.5632
#   [MWMOTE - MLP]
#     AUROC: 0.9545
#     G-mean: 0.8987
#     MCC: 0.6535
#     F1-score: 0.6722
#     mAP: 0.7802
#   [MWMOTE - RandomForest]
#     AUROC: 0.9842
#     G-mean: 0.9244
#     MCC: 0.8267
#     F1-score: 0.8420
#     mAP: 0.8966
#   [CTGAN - SVM]
#     AUROC: 0.9302
#     G-mean: 0.7550
#     MCC: 0.5868
#     F1-score: 0.6179
#     mAP: 0.6463
#   [CTGAN - DecisionTree]
#     AUROC: 0.9650
#     G-mean: 0.9251
#     MCC: 0.8492
#     F1-score: 0.8621
#     mAP: 0.8171
#   [CTGAN - kNN]
#     AUROC: 0.8960
#     G-mean: 0.6909
#     MCC: 0.5574
#     F1-score: 0.5790
#     mAP: 0.5644
#   [CTGAN - MLP]
#     AUROC: 0.9486
#     G-mean: 0.8196
#     MCC: 0.6825
#     F1-score: 0.7085
#     mAP: 0.7255
#   [CTGAN - RandomForest]
#     AUROC: 0.9857
#     G-mean: 0.9221
#     MCC: 0.8666
#     F1-score: 0.8776
#     mAP: 0.9153
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Original - SVM]
#     AUROC: 0.9416
#     G-mean: 0.3490
#     MCC: 0.2717
#     F1-score: 0.2149
#     mAP: 0.7017
#   [Original - DecisionTree]
#     AUROC: 0.9554
#     G-mean: 0.9223
#     MCC: 0.8573
#     F1-score: 0.8695
#     mAP: 0.8222
#   [Original - kNN]
#     AUROC: 0.8848
#     G-mean: 0.6690
#     MCC: 0.5504
#     F1-score: 0.5637
#     mAP: 0.5622
#   [Original - MLP]
#     AUROC: 0.8871
#     G-mean: 0.4617
#     MCC: 0.3958
#     F1-score: 0.3799
#     mAP: 0.5912
#   [Original - RandomForest]
#     AUROC: 0.9847
#     G-mean: 0.9163
#     MCC: 0.8617
#     F1-score: 0.8725
#     mAP: 0.9099
#   [SMOTE - SVM]
#     AUROC: 0.9495
#     G-mean: 0.8965
#     MCC: 0.6128
#     F1-score: 0.6277
#     mAP: 0.7422
#   [SMOTE - DecisionTree]
#     AUROC: 0.9642
#     G-mean: 0.9435
#     MCC: 0.7829
#     F1-score: 0.7948
#     mAP: 0.8448
#   [SMOTE - kNN]
#     AUROC: 0.8951
#     G-mean: 0.8464
#     MCC: 0.5437
#     F1-score: 0.5722
#     mAP: 0.5273
#   [SMOTE - MLP]
#     AUROC: 0.9591
#     G-mean: 0.9127
#     MCC: 0.6930
#     F1-score: 0.7106
#     mAP: 0.7776
#   [SMOTE - RandomForest]
#     AUROC: 0.9866
#     G-mean: 0.9355
#     MCC: 0.8513
#     F1-score: 0.8642
#     mAP: 0.9054
#   [ADASYN - SVM]
#     AUROC: 0.9491
#     G-mean: 0.8932
#     MCC: 0.5848
#     F1-score: 0.5963
#     mAP: 0.7218
#   [ADASYN - DecisionTree]
#     AUROC: 0.9574
#     G-mean: 0.9403
#     MCC: 0.7587
#     F1-score: 0.7705
#     mAP: 0.8410
#   [ADASYN - kNN]
#     AUROC: 0.8949
#     G-mean: 0.8472
#     MCC: 0.5313
#     F1-score: 0.5577
#     mAP: 0.5132
#   [ADASYN - MLP]
#     AUROC: 0.9587
#     G-mean: 0.9127
#     MCC: 0.6806
#     F1-score: 0.6966
#     mAP: 0.7628
#   [ADASYN - RandomForest]
#     AUROC: 0.9862
#     G-mean: 0.9352
#     MCC: 0.8386
#     F1-score: 0.8525
#     mAP: 0.9038
#   [bSMOTE - SVM]
#     AUROC: 0.9441
#     G-mean: 0.8812
#     MCC: 0.5881
#     F1-score: 0.6068
#     mAP: 0.7237
#   [bSMOTE - DecisionTree]
#     AUROC: 0.9583
#     G-mean: 0.9399
#     MCC: 0.7852
#     F1-score: 0.7984
#     mAP: 0.8370
#   [bSMOTE - kNN]
#     AUROC: 0.8902
#     G-mean: 0.8335
#     MCC: 0.5328
#     F1-score: 0.5648
#     mAP: 0.5204
#   [bSMOTE - MLP]
#     AUROC: 0.9562
#     G-mean: 0.9048
#     MCC: 0.6931
#     F1-score: 0.7133
#     mAP: 0.7691
#   [bSMOTE - RandomForest]
#     AUROC: 0.9857
#     G-mean: 0.9316
#     MCC: 0.8493
#     F1-score: 0.8622
#     mAP: 0.9057
#   [ROS - SVM]
#     AUROC: 0.9504
#     G-mean: 0.8957
#     MCC: 0.5954
#     F1-score: 0.6076
#     mAP: 0.7339
#   [ROS - DecisionTree]
#     AUROC: 0.9573
#     G-mean: 0.9469
#     MCC: 0.8071
#     F1-score: 0.8193
#     mAP: 0.8405
#   [ROS - kNN]
#     AUROC: 0.8823
#     G-mean: 0.8394
#     MCC: 0.5441
#     F1-score: 0.5751
#     mAP: 0.5068
#   [ROS - MLP]
#     AUROC: 0.9586
#     G-mean: 0.9121
#     MCC: 0.6763
#     F1-score: 0.6925
#     mAP: 0.7634
#   [ROS - RandomForest]
#     AUROC: 0.9873
#     G-mean: 0.9268
#     MCC: 0.8670
#     F1-score: 0.8782
#     mAP: 0.9165
#   [MWMOTE - SVM]
#     AUROC: 0.9436
#     G-mean: 0.8765
#     MCC: 0.5943
#     F1-score: 0.6161
#     mAP: 0.7493
#   [MWMOTE - DecisionTree]
#     AUROC: 0.9598
#     G-mean: 0.9314
#     MCC: 0.7891
#     F1-score: 0.8038
#     mAP: 0.8311
#   [MWMOTE - kNN]
#     AUROC: 0.9038
#     G-mean: 0.8444
#     MCC: 0.5410
#     F1-score: 0.5696
#     mAP: 0.5546
#   [MWMOTE - MLP]
#     AUROC: 0.9539
#     G-mean: 0.8983
#     MCC: 0.6493
#     F1-score: 0.6679
#     mAP: 0.7770
#   [MWMOTE - RandomForest]
#     AUROC: 0.9840
#     G-mean: 0.9251
#     MCC: 0.8248
#     F1-score: 0.8398
#     mAP: 0.8959
#   [CTGAN - SVM]
#     AUROC: 0.9282
#     G-mean: 0.7563
#     MCC: 0.5862
#     F1-score: 0.6181
#     mAP: 0.6429
#   [CTGAN - DecisionTree]
#     AUROC: 0.9687
#     G-mean: 0.9241
#     MCC: 0.8501
#     F1-score: 0.8630
#     mAP: 0.8222
#   [CTGAN - kNN]
#     AUROC: 0.8927
#     G-mean: 0.6936
#     MCC: 0.5566
#     F1-score: 0.5795
#     mAP: 0.5586
#   [CTGAN - MLP]
#     AUROC: 0.9470
#     G-mean: 0.8189
#     MCC: 0.6820
#     F1-score: 0.7077
#     mAP: 0.7231
#   [CTGAN - RandomForest]
#     AUROC: 0.9860
#     G-mean: 0.9225
#     MCC: 0.8676
#     F1-score: 0.8783
#     mAP: 0.9144
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Original - SVM]
#     AUROC: 0.9416
#     G-mean: 0.3505
#     MCC: 0.2732
#     F1-score: 0.2169
#     mAP: 0.7003
#   [Original - DecisionTree]
#     AUROC: 0.9584
#     G-mean: 0.9246
#     MCC: 0.8588
#     F1-score: 0.8709
#     mAP: 0.8233
#   [Original - kNN]
#     AUROC: 0.8857
#     G-mean: 0.6725
#     MCC: 0.5535
#     F1-score: 0.5673
#     mAP: 0.5665
#   [Original - MLP]
#     AUROC: 0.8930
#     G-mean: 0.4523
#     MCC: 0.3910
#     F1-score: 0.3770
#     mAP: 0.6078
#   [Original - RandomForest]
#     AUROC: 0.9849
#     G-mean: 0.9175
#     MCC: 0.8634
#     F1-score: 0.8743
#     mAP: 0.9097
#   [SMOTE - SVM]
#     AUROC: 0.9497
#     G-mean: 0.8973
#     MCC: 0.6129
#     F1-score: 0.6273
#     mAP: 0.7460
#   [SMOTE - DecisionTree]
#     AUROC: 0.9623
#     G-mean: 0.9434
#     MCC: 0.7817
#     F1-score: 0.7939
#     mAP: 0.8396
#   [SMOTE - kNN]
#     AUROC: 0.8975
#     G-mean: 0.8463
#     MCC: 0.5431
#     F1-score: 0.5716
#     mAP: 0.5275
#   [SMOTE - MLP]
#     AUROC: 0.9598
#     G-mean: 0.9129
#     MCC: 0.6945
#     F1-score: 0.7119
#     mAP: 0.7789
#   [SMOTE - RandomForest]
#     AUROC: 0.9866
#     G-mean: 0.9362
#     MCC: 0.8544
#     F1-score: 0.8671
#     mAP: 0.9057
#   [ADASYN - SVM]
#     AUROC: 0.9494
#     G-mean: 0.8930
#     MCC: 0.5847
#     F1-score: 0.5961
#     mAP: 0.7243
#   [ADASYN - DecisionTree]
#     AUROC: 0.9603
#     G-mean: 0.9429
#     MCC: 0.7635
#     F1-score: 0.7751
#     mAP: 0.8423
#   [ADASYN - kNN]
#     AUROC: 0.8987
#     G-mean: 0.8478
#     MCC: 0.5320
#     F1-score: 0.5584
#     mAP: 0.5176
#   [ADASYN - MLP]
#     AUROC: 0.9590
#     G-mean: 0.9126
#     MCC: 0.6793
#     F1-score: 0.6953
#     mAP: 0.7651
#   [ADASYN - RandomForest]
#     AUROC: 0.9864
#     G-mean: 0.9367
#     MCC: 0.8419
#     F1-score: 0.8554
#     mAP: 0.9028
#   [bSMOTE - SVM]
#     AUROC: 0.9443
#     G-mean: 0.8817
#     MCC: 0.5884
#     F1-score: 0.6068
#     mAP: 0.7268
#   [bSMOTE - DecisionTree]
#     AUROC: 0.9560
#     G-mean: 0.9388
#     MCC: 0.7842
#     F1-score: 0.7979
#     mAP: 0.8335
#   [bSMOTE - kNN]
#     AUROC: 0.8925
#     G-mean: 0.8337
#     MCC: 0.5325
#     F1-score: 0.5645
#     mAP: 0.5239
#   [bSMOTE - MLP]
#     AUROC: 0.9562
#     G-mean: 0.9042
#     MCC: 0.6878
#     F1-score: 0.7076
#     mAP: 0.7706
#   [bSMOTE - RandomForest]
#     AUROC: 0.9861
#     G-mean: 0.9312
#     MCC: 0.8494
#     F1-score: 0.8623
#     mAP: 0.9053
#   [ROS - SVM]
#     AUROC: 0.9508
#     G-mean: 0.8962
#     MCC: 0.5955
#     F1-score: 0.6073
#     mAP: 0.7387
#   [ROS - DecisionTree]
#     AUROC: 0.9577
#     G-mean: 0.9473
#     MCC: 0.8061
#     F1-score: 0.8185
#     mAP: 0.8389
#   [ROS - kNN]
#     AUROC: 0.8832
#     G-mean: 0.8409
#     MCC: 0.5450
#     F1-score: 0.5756
#     mAP: 0.5095
#   [ROS - MLP]
#     AUROC: 0.9593
#     G-mean: 0.9124
#     MCC: 0.6773
#     F1-score: 0.6934
#     mAP: 0.7656
#   [ROS - RandomForest]
#     AUROC: 0.9870
#     G-mean: 0.9278
#     MCC: 0.8672
#     F1-score: 0.8785
#     mAP: 0.9153
#   [MWMOTE - SVM]
#     AUROC: 0.9442
#     G-mean: 0.8785
#     MCC: 0.5965
#     F1-score: 0.6177
#     mAP: 0.7530
#   [MWMOTE - DecisionTree]
#     AUROC: 0.9631
#     G-mean: 0.9337
#     MCC: 0.7909
#     F1-score: 0.8054
#     mAP: 0.8367
#   [MWMOTE - kNN]
#     AUROC: 0.9050
#     G-mean: 0.8459
#     MCC: 0.5406
#     F1-score: 0.5687
#     mAP: 0.5595
#   [MWMOTE - MLP]
#     AUROC: 0.9546
#     G-mean: 0.8980
#     MCC: 0.6500
#     F1-score: 0.6687
#     mAP: 0.7782
#   [MWMOTE - RandomForest]
#     AUROC: 0.9844
#     G-mean: 0.9259
#     MCC: 0.8267
#     F1-score: 0.8416
#     mAP: 0.8969
#   [CTGAN - SVM]
#     AUROC: 0.9297
#     G-mean: 0.7632
#     MCC: 0.5967
#     F1-score: 0.6278
#     mAP: 0.6505
#   [CTGAN - DecisionTree]
#     AUROC: 0.9687
#     G-mean: 0.9248
#     MCC: 0.8486
#     F1-score: 0.8618
#     mAP: 0.8214
#   [CTGAN - kNN]
#     AUROC: 0.8922
#     G-mean: 0.6969
#     MCC: 0.5586
#     F1-score: 0.5818
#     mAP: 0.5612
#   [CTGAN - MLP]
#     AUROC: 0.9475
#     G-mean: 0.8208
#     MCC: 0.6867
#     F1-score: 0.7115
#     mAP: 0.7248
#   [CTGAN - RandomForest]
#     AUROC: 0.9860
#     G-mean: 0.9234
#     MCC: 0.8682
#     F1-score: 0.8790
#     mAP: 0.9140
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Original - SVM]
#     AUROC: 0.9413
#     G-mean: 0.3522
#     MCC: 0.2738
#     F1-score: 0.2172
#     mAP: 0.6998
#   [Original - DecisionTree]
#     AUROC: 0.9579
#     G-mean: 0.9249
#     MCC: 0.8584
#     F1-score: 0.8707
#     mAP: 0.8220
#   [Original - kNN]
#     AUROC: 0.8865
#     G-mean: 0.6747
#     MCC: 0.5567
#     F1-score: 0.5704
#     mAP: 0.5669
#   [Original - MLP]
#     AUROC: 0.9021
#     G-mean: 0.4837
#     MCC: 0.4191
#     F1-score: 0.4072
#     mAP: 0.6277
#   [Original - RandomForest]
#     AUROC: 0.9849
#     G-mean: 0.9184
#     MCC: 0.8648
#     F1-score: 0.8756
#     mAP: 0.9089
#   [SMOTE - SVM]
#     AUROC: 0.9493
#     G-mean: 0.8967
#     MCC: 0.6121
#     F1-score: 0.6265
#     mAP: 0.7438
#   [SMOTE - DecisionTree]
#     AUROC: 0.9624
#     G-mean: 0.9442
#     MCC: 0.7845
#     F1-score: 0.7966
#     mAP: 0.8394
#   [SMOTE - kNN]
#     AUROC: 0.8993
#     G-mean: 0.8462
#     MCC: 0.5433
#     F1-score: 0.5713
#     mAP: 0.5295
#   [SMOTE - MLP]
#     AUROC: 0.9601
#     G-mean: 0.9116
#     MCC: 0.6907
#     F1-score: 0.7077
#     mAP: 0.7784
#   [SMOTE - RandomForest]
#     AUROC: 0.9865
#     G-mean: 0.9368
#     MCC: 0.8560
#     F1-score: 0.8686
#     mAP: 0.9054
#   [ADASYN - SVM]
#     AUROC: 0.9494
#     G-mean: 0.8938
#     MCC: 0.5863
#     F1-score: 0.5975
#     mAP: 0.7221
#   [ADASYN - DecisionTree]
#     AUROC: 0.9601
#     G-mean: 0.9423
#     MCC: 0.7639
#     F1-score: 0.7758
#     mAP: 0.8405
#   [ADASYN - kNN]
#     AUROC: 0.9003
#     G-mean: 0.8493
#     MCC: 0.5344
#     F1-score: 0.5600
#     mAP: 0.5191
#   [ADASYN - MLP]
#     AUROC: 0.9590
#     G-mean: 0.9126
#     MCC: 0.6800
#     F1-score: 0.6960
#     mAP: 0.7662
#   [ADASYN - RandomForest]
#     AUROC: 0.9864
#     G-mean: 0.9379
#     MCC: 0.8433
#     F1-score: 0.8567
#     mAP: 0.9035
#   [bSMOTE - SVM]
#     AUROC: 0.9449
#     G-mean: 0.8820
#     MCC: 0.5891
#     F1-score: 0.6075
#     mAP: 0.7274
#   [bSMOTE - DecisionTree]
#     AUROC: 0.9560
#     G-mean: 0.9379
#     MCC: 0.7825
#     F1-score: 0.7965
#     mAP: 0.8314
#   [bSMOTE - kNN]
#     AUROC: 0.8948
#     G-mean: 0.8353
#     MCC: 0.5356
#     F1-score: 0.5670
#     mAP: 0.5272
#   [bSMOTE - MLP]
#     AUROC: 0.9571
#     G-mean: 0.9055
#     MCC: 0.6891
#     F1-score: 0.7083
#     mAP: 0.7742
#   [bSMOTE - RandomForest]
#     AUROC: 0.9862
#     G-mean: 0.9315
#     MCC: 0.8516
#     F1-score: 0.8643
#     mAP: 0.9061
#   [ROS - SVM]
#     AUROC: 0.9506
#     G-mean: 0.8970
#     MCC: 0.5968
#     F1-score: 0.6085
#     mAP: 0.7359
#   [ROS - DecisionTree]
#     AUROC: 0.9585
#     G-mean: 0.9480
#     MCC: 0.8048
#     F1-score: 0.8169
#     mAP: 0.8398
#   [ROS - kNN]
#     AUROC: 0.8839
#     G-mean: 0.8407
#     MCC: 0.5454
#     F1-score: 0.5757
#     mAP: 0.5105
#   [ROS - MLP]
#     AUROC: 0.9591
#     G-mean: 0.9120
#     MCC: 0.6765
#     F1-score: 0.6925
#     mAP: 0.7645
#   [ROS - RandomForest]
#     AUROC: 0.9871
#     G-mean: 0.9283
#     MCC: 0.8682
#     F1-score: 0.8794
#     mAP: 0.9154
#   [MWMOTE - SVM]
#     AUROC: 0.9444
#     G-mean: 0.8788
#     MCC: 0.5971
#     F1-score: 0.6181
#     mAP: 0.7535
#   [MWMOTE - DecisionTree]
#     AUROC: 0.9645
#     G-mean: 0.9349
#     MCC: 0.7910
#     F1-score: 0.8056
#     mAP: 0.8383
#   [MWMOTE - kNN]
#     AUROC: 0.9054
#     G-mean: 0.8455
#     MCC: 0.5401
#     F1-score: 0.5682
#     mAP: 0.5557
#   [MWMOTE - MLP]
#     AUROC: 0.9552
#     G-mean: 0.8990
#     MCC: 0.6524
#     F1-score: 0.6709
#     mAP: 0.7799
#   [MWMOTE - RandomForest]
#     AUROC: 0.9845
#     G-mean: 0.9266
#     MCC: 0.8276
#     F1-score: 0.8424
#     mAP: 0.8985
#   [CTGAN - SVM]
#     AUROC: 0.9300
#     G-mean: 0.7671
#     MCC: 0.6007
#     F1-score: 0.6321
#     mAP: 0.6548
#   [CTGAN - DecisionTree]
#     AUROC: 0.9694
#     G-mean: 0.9261
#     MCC: 0.8510
#     F1-score: 0.8639
#     mAP: 0.8256
#   [CTGAN - kNN]
#     AUROC: 0.8929
#     G-mean: 0.6985
#     MCC: 0.5611
#     F1-score: 0.5841
#     mAP: 0.5609
#   [CTGAN - MLP]
#     AUROC: 0.9483
#     G-mean: 0.8263
#     MCC: 0.6940
#     F1-score: 0.7184
#     mAP: 0.7290
#   [CTGAN - RandomForest]
#     AUROC: 0.9862
#     G-mean: 0.9249
#     MCC: 0.8702
#     F1-score: 0.8808
#     mAP: 0.9146
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Original - SVM]
#     AUROC: 0.9415
#     G-mean: 0.3558
#     MCC: 0.2776
#     F1-score: 0.2210
#     mAP: 0.6981
#   [Original - DecisionTree]
#     AUROC: 0.9590
#     G-mean: 0.9241
#     MCC: 0.8566
#     F1-score: 0.8690
#     mAP: 0.8230
#   [Original - kNN]
#     AUROC: 0.8875
#     G-mean: 0.6747
#     MCC: 0.5553
#     F1-score: 0.5695
#     mAP: 0.5663
#   [Original - MLP]
#     AUROC: 0.9005
#     G-mean: 0.4801
#     MCC: 0.4161
#     F1-score: 0.4007
#     mAP: 0.6230
#   [Original - RandomForest]
#     AUROC: 0.9848
#     G-mean: 0.9185
#     MCC: 0.8650
#     F1-score: 0.8759
#     mAP: 0.9083
#   [SMOTE - SVM]
#     AUROC: 0.9496
#     G-mean: 0.8973
#     MCC: 0.6126
#     F1-score: 0.6269
#     mAP: 0.7439
#   [SMOTE - DecisionTree]
#     AUROC: 0.9629
#     G-mean: 0.9445
#     MCC: 0.7875
#     F1-score: 0.7998
#     mAP: 0.8403
#   [SMOTE - kNN]
#     AUROC: 0.9014
#     G-mean: 0.8468
#     MCC: 0.5436
#     F1-score: 0.5715
#     mAP: 0.5330
#   [SMOTE - MLP]
#     AUROC: 0.9605
#     G-mean: 0.9117
#     MCC: 0.6907
#     F1-score: 0.7078
#     mAP: 0.7798
#   [SMOTE - RandomForest]
#     AUROC: 0.9866
#     G-mean: 0.9372
#     MCC: 0.8572
#     F1-score: 0.8697
#     mAP: 0.9063
#   [ADASYN - SVM]
#     AUROC: 0.9496
#     G-mean: 0.8947
#     MCC: 0.5871
#     F1-score: 0.5980
#     mAP: 0.7214
#   [ADASYN - DecisionTree]
#     AUROC: 0.9627
#     G-mean: 0.9438
#     MCC: 0.7663
#     F1-score: 0.7778
#     mAP: 0.8433
#   [ADASYN - kNN]
#     AUROC: 0.9012
#     G-mean: 0.8507
#     MCC: 0.5360
#     F1-score: 0.5613
#     mAP: 0.5172
#   [ADASYN - MLP]
#     AUROC: 0.9590
#     G-mean: 0.9127
#     MCC: 0.6789
#     F1-score: 0.6948
#     mAP: 0.7656
#   [ADASYN - RandomForest]
#     AUROC: 0.9863
#     G-mean: 0.9383
#     MCC: 0.8449
#     F1-score: 0.8582
#     mAP: 0.9047
#   [bSMOTE - SVM]
#     AUROC: 0.9450
#     G-mean: 0.8823
#     MCC: 0.5890
#     F1-score: 0.6073
#     mAP: 0.7280
#   [bSMOTE - DecisionTree]
#     AUROC: 0.9581
#     G-mean: 0.9390
#     MCC: 0.7832
#     F1-score: 0.7969
#     mAP: 0.8327
#   [bSMOTE - kNN]
#     AUROC: 0.8962
#     G-mean: 0.8354
#     MCC: 0.5350
#     F1-score: 0.5664
#     mAP: 0.5262
#   [bSMOTE - MLP]
#     AUROC: 0.9577
#     G-mean: 0.9056
#     MCC: 0.6896
#     F1-score: 0.7089
#     mAP: 0.7775
#   [bSMOTE - RandomForest]
#     AUROC: 0.9863
#     G-mean: 0.9314
#     MCC: 0.8523
#     F1-score: 0.8651
#     mAP: 0.9068
#   [ROS - SVM]
#     AUROC: 0.9507
#     G-mean: 0.8978
#     MCC: 0.5982
#     F1-score: 0.6097
#     mAP: 0.7369
#   [ROS - DecisionTree]
#     AUROC: 0.9585
#     G-mean: 0.9480
#     MCC: 0.8052
#     F1-score: 0.8175
#     mAP: 0.8393
#   [ROS - kNN]
#     AUROC: 0.8850
#     G-mean: 0.8425
#     MCC: 0.5469
#     F1-score: 0.5767
#     mAP: 0.5104
#   [ROS - MLP]
#     AUROC: 0.9593
#     G-mean: 0.9123
#     MCC: 0.6751
#     F1-score: 0.6908
#     mAP: 0.7641
#   [ROS - RandomForest]
#     AUROC: 0.9873
#     G-mean: 0.9275
#     MCC: 0.8672
#     F1-score: 0.8785
#     mAP: 0.9159
#   [MWMOTE - SVM]
#     AUROC: 0.9446
#     G-mean: 0.8803
#     MCC: 0.5987
#     F1-score: 0.6193
#     mAP: 0.7530
#   [MWMOTE - DecisionTree]
#     AUROC: 0.9637
#     G-mean: 0.9355
#     MCC: 0.7885
#     F1-score: 0.8029
#     mAP: 0.8382
#   [MWMOTE - kNN]
#     AUROC: 0.9061
#     G-mean: 0.8469
#     MCC: 0.5408
#     F1-score: 0.5684
#     mAP: 0.5537
#   [MWMOTE - MLP]
#     AUROC: 0.9552
#     G-mean: 0.8989
#     MCC: 0.6508
#     F1-score: 0.6691
#     mAP: 0.7785
#   [MWMOTE - RandomForest]
#     AUROC: 0.9847
#     G-mean: 0.9273
#     MCC: 0.8291
#     F1-score: 0.8438
#     mAP: 0.8998
#   [CTGAN - SVM]
#     AUROC: 0.9310
#     G-mean: 0.7723
#     MCC: 0.6066
#     F1-score: 0.6378
#     mAP: 0.6611
#   [CTGAN - DecisionTree]
#     AUROC: 0.9683
#     G-mean: 0.9255
#     MCC: 0.8490
#     F1-score: 0.8621
#     mAP: 0.8227
#   [CTGAN - kNN]
#     AUROC: 0.8937
#     G-mean: 0.6989
#     MCC: 0.5599
#     F1-score: 0.5834
#     mAP: 0.5609
#   [CTGAN - MLP]
#     AUROC: 0.9487
#     G-mean: 0.8316
#     MCC: 0.6992
#     F1-score: 0.7236
#     mAP: 0.7335
#   [CTGAN - RandomForest]
#     AUROC: 0.9862
#     G-mean: 0.9247
#     MCC: 0.8693
#     F1-score: 0.8802
#     mAP: 0.9146
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Original - SVM]
#     AUROC: 0.9417
#     G-mean: 0.3599
#     MCC: 0.2820
#     F1-score: 0.2253
#     mAP: 0.6986
#   [Original - DecisionTree]
#     AUROC: 0.9598
#     G-mean: 0.9251
#     MCC: 0.8571
#     F1-score: 0.8695
#     mAP: 0.8240
#   [Original - kNN]
#     AUROC: 0.8879
#     G-mean: 0.6749
#     MCC: 0.5563
#     F1-score: 0.5703
#     mAP: 0.5682
#   [Original - MLP]
#     AUROC: 0.9010
#     G-mean: 0.4786
#     MCC: 0.4131
#     F1-score: 0.3961
#     mAP: 0.6197
#   [Original - RandomForest]
#     AUROC: 0.9848
#     G-mean: 0.9188
#     MCC: 0.8650
#     F1-score: 0.8759
#     mAP: 0.9087
#   [SMOTE - SVM]
#     AUROC: 0.9499
#     G-mean: 0.8978
#     MCC: 0.6136
#     F1-score: 0.6279
#     mAP: 0.7460
#   [SMOTE - DecisionTree]
#     AUROC: 0.9646
#     G-mean: 0.9448
#     MCC: 0.7882
#     F1-score: 0.8005
#     mAP: 0.8423
#   [SMOTE - kNN]
#     AUROC: 0.9020
#     G-mean: 0.8479
#     MCC: 0.5449
#     F1-score: 0.5726
#     mAP: 0.5342
#   [SMOTE - MLP]
#     AUROC: 0.9607
#     G-mean: 0.9121
#     MCC: 0.6882
#     F1-score: 0.7050
#     mAP: 0.7812
#   [SMOTE - RandomForest]
#     AUROC: 0.9868
#     G-mean: 0.9378
#     MCC: 0.8583
#     F1-score: 0.8706
#     mAP: 0.9073
#   [ADASYN - SVM]
#     AUROC: 0.9500
#     G-mean: 0.8948
#     MCC: 0.5874
#     F1-score: 0.5983
#     mAP: 0.7235
#   [ADASYN - DecisionTree]
#     AUROC: 0.9630
#     G-mean: 0.9432
#     MCC: 0.7652
#     F1-score: 0.7770
#     mAP: 0.8436
#   [ADASYN - kNN]
#     AUROC: 0.9015
#     G-mean: 0.8507
#     MCC: 0.5355
#     F1-score: 0.5607
#     mAP: 0.5178
#   [ADASYN - MLP]
#     AUROC: 0.9591
#     G-mean: 0.9128
#     MCC: 0.6786
#     F1-score: 0.6944
#     mAP: 0.7657
#   [ADASYN - RandomForest]
#     AUROC: 0.9864
#     G-mean: 0.9387
#     MCC: 0.8458
#     F1-score: 0.8590
#     mAP: 0.9058
#   [bSMOTE - SVM]
#     AUROC: 0.9450
#     G-mean: 0.8818
#     MCC: 0.5878
#     F1-score: 0.6061
#     mAP: 0.7278
#   [bSMOTE - DecisionTree]
#     AUROC: 0.9583
#     G-mean: 0.9395
#     MCC: 0.7828
#     F1-score: 0.7965
#     mAP: 0.8319
#   [bSMOTE - kNN]
#     AUROC: 0.8964
#     G-mean: 0.8366
#     MCC: 0.5363
#     F1-score: 0.5674
#     mAP: 0.5254
#   [bSMOTE - MLP]
#     AUROC: 0.9577
#     G-mean: 0.9055
#     MCC: 0.6886
#     F1-score: 0.7079
#     mAP: 0.7756
#   [bSMOTE - RandomForest]
#     AUROC: 0.9866
#     G-mean: 0.9320
#     MCC: 0.8530
#     F1-score: 0.8657
#     mAP: 0.9076
#   [ROS - SVM]
#     AUROC: 0.9511
#     G-mean: 0.8983
#     MCC: 0.5988
#     F1-score: 0.6101
#     mAP: 0.7393
#   [ROS - DecisionTree]
#     AUROC: 0.9598
#     G-mean: 0.9485
#     MCC: 0.8038
#     F1-score: 0.8160
#     mAP: 0.8403
#   [ROS - kNN]
#     AUROC: 0.8853
#     G-mean: 0.8429
#     MCC: 0.5468
#     F1-score: 0.5765
#     mAP: 0.5106
#   [ROS - MLP]
#     AUROC: 0.9593
#     G-mean: 0.9125
#     MCC: 0.6759
#     F1-score: 0.6915
#     mAP: 0.7642
#   [ROS - RandomForest]
#     AUROC: 0.9873
#     G-mean: 0.9281
#     MCC: 0.8680
#     F1-score: 0.8792
#     mAP: 0.9165
#   [MWMOTE - SVM]
#     AUROC: 0.9450
#     G-mean: 0.8807
#     MCC: 0.5993
#     F1-score: 0.6199
#     mAP: 0.7535
#   [MWMOTE - DecisionTree]
#     AUROC: 0.9649
#     G-mean: 0.9362
#     MCC: 0.7908
#     F1-score: 0.8050
#     mAP: 0.8390
#   [MWMOTE - kNN]
#     AUROC: 0.9064
#     G-mean: 0.8476
#     MCC: 0.5409
#     F1-score: 0.5683
#     mAP: 0.5536
#   [MWMOTE - MLP]
#     AUROC: 0.9555
#     G-mean: 0.8995
#     MCC: 0.6517
#     F1-score: 0.6700
#     mAP: 0.7777
#   [MWMOTE - RandomForest]
#     AUROC: 0.9850
#     G-mean: 0.9274
#     MCC: 0.8291
#     F1-score: 0.8438
#     mAP: 0.9008
#   [CTGAN - SVM]
#     AUROC: 0.9312
#     G-mean: 0.7745
#     MCC: 0.6110
#     F1-score: 0.6419
#     mAP: 0.6631
#   [CTGAN - DecisionTree]
#     AUROC: 0.9686
#     G-mean: 0.9262
#     MCC: 0.8490
#     F1-score: 0.8622
#     mAP: 0.8209
#   [CTGAN - kNN]
#     AUROC: 0.8938
#     G-mean: 0.6989
#     MCC: 0.5598
#     F1-score: 0.5834
#     mAP: 0.5619
#   [CTGAN - MLP]
#     AUROC: 0.9490
#     G-mean: 0.8327
#     MCC: 0.7014
#     F1-score: 0.7257
#     mAP: 0.7349
#   [CTGAN - RandomForest]
#     AUROC: 0.9861
#     G-mean: 0.9245
#     MCC: 0.8688
#     F1-score: 0.8797
#     mAP: 0.9148
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Original - SVM]
#     AUROC: 0.9417
#     G-mean: 0.3558
#     MCC: 0.2777
#     F1-score: 0.2233
#     mAP: 0.6987
#   [Original - DecisionTree]
#     AUROC: 0.9603
#     G-mean: 0.9256
#     MCC: 0.8572
#     F1-score: 0.8696
#     mAP: 0.8234
#   [Original - kNN]
#     AUROC: 0.8881
#     G-mean: 0.6755
#     MCC: 0.5558
#     F1-score: 0.5704
#     mAP: 0.5676
#   [Original - MLP]
#     AUROC: 0.9063
#     G-mean: 0.5052
#     MCC: 0.4373
#     F1-score: 0.4223
#     mAP: 0.6330
#   [Original - RandomForest]
#     AUROC: 0.9848
#     G-mean: 0.9192
#     MCC: 0.8653
#     F1-score: 0.8762
#     mAP: 0.9086
#   [SMOTE - SVM]
#     AUROC: 0.9498
#     G-mean: 0.8975
#     MCC: 0.6136
#     F1-score: 0.6279
#     mAP: 0.7462
#   [SMOTE - DecisionTree]
#     AUROC: 0.9650
#     G-mean: 0.9435
#     MCC: 0.7863
#     F1-score: 0.7988
#     mAP: 0.8429
#   [SMOTE - kNN]
#     AUROC: 0.9021
#     G-mean: 0.8474
#     MCC: 0.5445
#     F1-score: 0.5723
#     mAP: 0.5347
#   [SMOTE - MLP]
#     AUROC: 0.9607
#     G-mean: 0.9112
#     MCC: 0.6867
#     F1-score: 0.7037
#     mAP: 0.7814
#   [SMOTE - RandomForest]
#     AUROC: 0.9865
#     G-mean: 0.9383
#     MCC: 0.8590
#     F1-score: 0.8714
#     mAP: 0.9071
#   [ADASYN - SVM]
#     AUROC: 0.9501
#     G-mean: 0.8952
#     MCC: 0.5883
#     F1-score: 0.5990
#     mAP: 0.7240
#   [ADASYN - DecisionTree]
#     AUROC: 0.9628
#     G-mean: 0.9426
#     MCC: 0.7648
#     F1-score: 0.7767
#     mAP: 0.8419
#   [ADASYN - kNN]
#     AUROC: 0.9015
#     G-mean: 0.8508
#     MCC: 0.5357
#     F1-score: 0.5609
#     mAP: 0.5176
#   [ADASYN - MLP]
#     AUROC: 0.9592
#     G-mean: 0.9123
#     MCC: 0.6775
#     F1-score: 0.6933
#     mAP: 0.7656
#   [ADASYN - RandomForest]
#     AUROC: 0.9864
#     G-mean: 0.9393
#     MCC: 0.8469
#     F1-score: 0.8601
#     mAP: 0.9059
#   [bSMOTE - SVM]
#     AUROC: 0.9449
#     G-mean: 0.8807
#     MCC: 0.5866
#     F1-score: 0.6052
#     mAP: 0.7300
#   [bSMOTE - DecisionTree]
#     AUROC: 0.9602
#     G-mean: 0.9394
#     MCC: 0.7851
#     F1-score: 0.7989
#     mAP: 0.8338
#   [bSMOTE - kNN]
#     AUROC: 0.8961
#     G-mean: 0.8352
#     MCC: 0.5347
#     F1-score: 0.5661
#     mAP: 0.5262
#   [bSMOTE - MLP]
#     AUROC: 0.9578
#     G-mean: 0.9055
#     MCC: 0.6885
#     F1-score: 0.7079
#     mAP: 0.7768
#   [bSMOTE - RandomForest]
#     AUROC: 0.9866
#     G-mean: 0.9325
#     MCC: 0.8533
#     F1-score: 0.8661
#     mAP: 0.9074
#   [ROS - SVM]
#     AUROC: 0.9509
#     G-mean: 0.8983
#     MCC: 0.5991
#     F1-score: 0.6103
#     mAP: 0.7401
#   [ROS - DecisionTree]
#     AUROC: 0.9605
#     G-mean: 0.9489
#     MCC: 0.8048
#     F1-score: 0.8170
#     mAP: 0.8408
#   [ROS - kNN]
#     AUROC: 0.8857
#     G-mean: 0.8433
#     MCC: 0.5471
#     F1-score: 0.5768
#     mAP: 0.5105
#   [ROS - MLP]
#     AUROC: 0.9595
#     G-mean: 0.9120
#     MCC: 0.6750
#     F1-score: 0.6908
#     mAP: 0.7664
#   [ROS - RandomForest]
#     AUROC: 0.9869
#     G-mean: 0.9285
#     MCC: 0.8684
#     F1-score: 0.8796
#     mAP: 0.9161
#   [MWMOTE - SVM]
#     AUROC: 0.9451
#     G-mean: 0.8810
#     MCC: 0.5996
#     F1-score: 0.6200
#     mAP: 0.7534
#   [MWMOTE - DecisionTree]
#     AUROC: 0.9642
#     G-mean: 0.9357
#     MCC: 0.7897
#     F1-score: 0.8040
#     mAP: 0.8392
#   [MWMOTE - kNN]
#     AUROC: 0.9058
#     G-mean: 0.8476
#     MCC: 0.5406
#     F1-score: 0.5680
#     mAP: 0.5499
#   [MWMOTE - MLP]
#     AUROC: 0.9556
#     G-mean: 0.8992
#     MCC: 0.6519
#     F1-score: 0.6702
#     mAP: 0.7788
#   [MWMOTE - RandomForest]
#     AUROC: 0.9850
#     G-mean: 0.9283
#     MCC: 0.8292
#     F1-score: 0.8440
#     mAP: 0.9009
#   [CTGAN - SVM]
#     AUROC: 0.9307
#     G-mean: 0.7744
#     MCC: 0.6105
#     F1-score: 0.6418
#     mAP: 0.6626
#   [CTGAN - DecisionTree]
#     AUROC: 0.9685
#     G-mean: 0.9260
#     MCC: 0.8486
#     F1-score: 0.8618
#     mAP: 0.8211
#   [CTGAN - kNN]
#     AUROC: 0.8936
#     G-mean: 0.6994
#     MCC: 0.5590
#     F1-score: 0.5831
#     mAP: 0.5588
#   [CTGAN - MLP]
#     AUROC: 0.9495
#     G-mean: 0.8341
#     MCC: 0.7028
#     F1-score: 0.7268
#     mAP: 0.7371
#   [CTGAN - RandomForest]
#     AUROC: 0.9860
#     G-mean: 0.9247
#     MCC: 0.8694
#     F1-score: 0.8803
#     mAP: 0.9141
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Original - SVM]
#     AUROC: 0.9418
#     G-mean: 0.3554
#     MCC: 0.2776
#     F1-score: 0.2226
#     mAP: 0.6990
#   [Original - DecisionTree]
#     AUROC: 0.9609
#     G-mean: 0.9249
#     MCC: 0.8569
#     F1-score: 0.8692
#     mAP: 0.8244
#   [Original - kNN]
#     AUROC: 0.8879
#     G-mean: 0.6739
#     MCC: 0.5548
#     F1-score: 0.5689
#     mAP: 0.5665
#   [Original - MLP]
#     AUROC: 0.9057
#     G-mean: 0.4974
#     MCC: 0.4293
#     F1-score: 0.4128
#     mAP: 0.6305
#   [Original - RandomForest]
#     AUROC: 0.9848
#     G-mean: 0.9195
#     MCC: 0.8653
#     F1-score: 0.8762
#     mAP: 0.9090
#   [SMOTE - SVM]
#     AUROC: 0.9500
#     G-mean: 0.8974
#     MCC: 0.6134
#     F1-score: 0.6277
#     mAP: 0.7469
#   [SMOTE - DecisionTree]
#     AUROC: 0.9649
#     G-mean: 0.9432
#     MCC: 0.7852
#     F1-score: 0.7978
#     mAP: 0.8428
#   [SMOTE - kNN]
#     AUROC: 0.9017
#     G-mean: 0.8453
#     MCC: 0.5417
#     F1-score: 0.5699
#     mAP: 0.5344
#   [SMOTE - MLP]
#     AUROC: 0.9607
#     G-mean: 0.9103
#     MCC: 0.6857
#     F1-score: 0.7030
#     mAP: 0.7823
#   [SMOTE - RandomForest]
#     AUROC: 0.9864
#     G-mean: 0.9385
#     MCC: 0.8594
#     F1-score: 0.8716
#     mAP: 0.9071
#   [ADASYN - SVM]
#     AUROC: 0.9502
#     G-mean: 0.8950
#     MCC: 0.5878
#     F1-score: 0.5985
#     mAP: 0.7246
#   [ADASYN - DecisionTree]
#     AUROC: 0.9636
#     G-mean: 0.9428
#     MCC: 0.7645
#     F1-score: 0.7764
#     mAP: 0.8432
#   [ADASYN - kNN]
#     AUROC: 0.9005
#     G-mean: 0.8492
#     MCC: 0.5338
#     F1-score: 0.5593
#     mAP: 0.5164
#   [ADASYN - MLP]
#     AUROC: 0.9590
#     G-mean: 0.9120
#     MCC: 0.6761
#     F1-score: 0.6919
#     mAP: 0.7649
#   [ADASYN - RandomForest]
#     AUROC: 0.9864
#     G-mean: 0.9399
#     MCC: 0.8479
#     F1-score: 0.8609
#     mAP: 0.9065
#   [bSMOTE - SVM]
#     AUROC: 0.9449
#     G-mean: 0.8803
#     MCC: 0.5860
#     F1-score: 0.6046
#     mAP: 0.7302
#   [bSMOTE - DecisionTree]
#     AUROC: 0.9612
#     G-mean: 0.9401
#     MCC: 0.7850
#     F1-score: 0.7987
#     mAP: 0.8339
#   [bSMOTE - kNN]
#     AUROC: 0.8957
#     G-mean: 0.8329
#     MCC: 0.5317
#     F1-score: 0.5637
#     mAP: 0.5245
#   [bSMOTE - MLP]
#     AUROC: 0.9579
#     G-mean: 0.9049
#     MCC: 0.6874
#     F1-score: 0.7068
#     mAP: 0.7767
#   [bSMOTE - RandomForest]
#     AUROC: 0.9868
#     G-mean: 0.9329
#     MCC: 0.8538
#     F1-score: 0.8665
#     mAP: 0.9086
#   [ROS - SVM]
#     AUROC: 0.9510
#     G-mean: 0.8980
#     MCC: 0.5987
#     F1-score: 0.6100
#     mAP: 0.7406
#   [ROS - DecisionTree]
#     AUROC: 0.9604
#     G-mean: 0.9487
#     MCC: 0.8043
#     F1-score: 0.8166
#     mAP: 0.8418
#   [ROS - kNN]
#     AUROC: 0.8855
#     G-mean: 0.8415
#     MCC: 0.5450
#     F1-score: 0.5750
#     mAP: 0.5113
#   [ROS - MLP]
#     AUROC: 0.9596
#     G-mean: 0.9117
#     MCC: 0.6749
#     F1-score: 0.6908
#     mAP: 0.7675
#   [ROS - RandomForest]
#     AUROC: 0.9869
#     G-mean: 0.9285
#     MCC: 0.8683
#     F1-score: 0.8795
#     mAP: 0.9168
#   [MWMOTE - SVM]
#     AUROC: 0.9451
#     G-mean: 0.8816
#     MCC: 0.6004
#     F1-score: 0.6206
#     mAP: 0.7538
#   [MWMOTE - DecisionTree]
#     AUROC: 0.9649
#     G-mean: 0.9360
#     MCC: 0.7897
#     F1-score: 0.8039
#     mAP: 0.8399
#   [MWMOTE - kNN]
#     AUROC: 0.9057
#     G-mean: 0.8478
#     MCC: 0.5411
#     F1-score: 0.5684
#     mAP: 0.5509
#   [MWMOTE - MLP]
#     AUROC: 0.9556
#     G-mean: 0.8995
#     MCC: 0.6531
#     F1-score: 0.6714
#     mAP: 0.7786
#   [MWMOTE - RandomForest]
#     AUROC: 0.9849
#     G-mean: 0.9288
#     MCC: 0.8297
#     F1-score: 0.8443
#     mAP: 0.9008
#   [CTGAN - SVM]
#     AUROC: 0.9311
#     G-mean: 0.7786
#     MCC: 0.6162
#     F1-score: 0.6473
#     mAP: 0.6649
#   [CTGAN - DecisionTree]
#     AUROC: 0.9682
#     G-mean: 0.9258
#     MCC: 0.8476
#     F1-score: 0.8609
#     mAP: 0.8191
#   [CTGAN - kNN]
#     AUROC: 0.8936
#     G-mean: 0.6974
#     MCC: 0.5561
#     F1-score: 0.5804
#     mAP: 0.5570
#   [CTGAN - MLP]
#     AUROC: 0.9497
#     G-mean: 0.8346
#     MCC: 0.7042
#     F1-score: 0.7282
#     mAP: 0.7392
#   [CTGAN - RandomForest]
#     AUROC: 0.9860
#     G-mean: 0.9250
#     MCC: 0.8693
#     F1-score: 0.8802
#     mAP: 0.9143
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Original - SVM]
#     AUROC: 0.9418
#     G-mean: 0.3563
#     MCC: 0.2784
#     F1-score: 0.2232
#     mAP: 0.6990
#   [Original - DecisionTree]
#     AUROC: 0.9604
#     G-mean: 0.9254
#     MCC: 0.8573
#     F1-score: 0.8696
#     mAP: 0.8237
#   [Original - kNN]
#     AUROC: 0.8879
#     G-mean: 0.6732
#     MCC: 0.5541
#     F1-score: 0.5681
#     mAP: 0.5672
#   [Original - MLP]
#     AUROC: 0.9068
#     G-mean: 0.5089
#     MCC: 0.4404
#     F1-score: 0.4250
#     mAP: 0.6356
#   [Original - RandomForest]
#     AUROC: 0.9848
#     G-mean: 0.9192
#     MCC: 0.8649
#     F1-score: 0.8759
#     mAP: 0.9088
#   [SMOTE - SVM]
#     AUROC: 0.9495
#     G-mean: 0.8971
#     MCC: 0.6128
#     F1-score: 0.6272
#     mAP: 0.7454
#   [SMOTE - DecisionTree]
#     AUROC: 0.9649
#     G-mean: 0.9432
#     MCC: 0.7853
#     F1-score: 0.7980
#     mAP: 0.8444
#   [SMOTE - kNN]
#     AUROC: 0.9016
#     G-mean: 0.8457
#     MCC: 0.5427
#     F1-score: 0.5709
#     mAP: 0.5347
#   [SMOTE - MLP]
#     AUROC: 0.9603
#     G-mean: 0.9104
#     MCC: 0.6861
#     F1-score: 0.7034
#     mAP: 0.7809
#   [SMOTE - RandomForest]
#     AUROC: 0.9865
#     G-mean: 0.9379
#     MCC: 0.8590
#     F1-score: 0.8713
#     mAP: 0.9069
#   [ADASYN - SVM]
#     AUROC: 0.9498
#     G-mean: 0.8950
#     MCC: 0.5877
#     F1-score: 0.5985
#     mAP: 0.7230
#   [ADASYN - DecisionTree]
#     AUROC: 0.9629
#     G-mean: 0.9422
#     MCC: 0.7628
#     F1-score: 0.7748
#     mAP: 0.8436
#   [ADASYN - kNN]
#     AUROC: 0.9005
#     G-mean: 0.8500
#     MCC: 0.5353
#     F1-score: 0.5607
#     mAP: 0.5178
#   [ADASYN - MLP]
#     AUROC: 0.9590
#     G-mean: 0.9122
#     MCC: 0.6778
#     F1-score: 0.6938
#     mAP: 0.7651
#   [ADASYN - RandomForest]
#     AUROC: 0.9864
#     G-mean: 0.9395
#     MCC: 0.8475
#     F1-score: 0.8606
#     mAP: 0.9059
#   [bSMOTE - SVM]
#     AUROC: 0.9445
#     G-mean: 0.8804
#     MCC: 0.5861
#     F1-score: 0.6047
#     mAP: 0.7291
#   [bSMOTE - DecisionTree]
#     AUROC: 0.9605
#     G-mean: 0.9397
#     MCC: 0.7856
#     F1-score: 0.7993
#     mAP: 0.8333
#   [bSMOTE - kNN]
#     AUROC: 0.8955
#     G-mean: 0.8337
#     MCC: 0.5325
#     F1-score: 0.5643
#     mAP: 0.5264
#   [bSMOTE - MLP]
#     AUROC: 0.9579
#     G-mean: 0.9054
#     MCC: 0.6889
#     F1-score: 0.7082
#     mAP: 0.7767
#   [bSMOTE - RandomForest]
#     AUROC: 0.9867
#     G-mean: 0.9326
#     MCC: 0.8539
#     F1-score: 0.8666
#     mAP: 0.9076
#   [ROS - SVM]
#     AUROC: 0.9505
#     G-mean: 0.8981
#     MCC: 0.5988
#     F1-score: 0.6101
#     mAP: 0.7392
#   [ROS - DecisionTree]
#     AUROC: 0.9601
#     G-mean: 0.9483
#     MCC: 0.8035
#     F1-score: 0.8159
#     mAP: 0.8423
#   [ROS - kNN]
#     AUROC: 0.8857
#     G-mean: 0.8418
#     MCC: 0.5456
#     F1-score: 0.5757
#     mAP: 0.5133
#   [ROS - MLP]
#     AUROC: 0.9594
#     G-mean: 0.9117
#     MCC: 0.6745
#     F1-score: 0.6904
#     mAP: 0.7672
#   [ROS - RandomForest]
#     AUROC: 0.9870
#     G-mean: 0.9284
#     MCC: 0.8682
#     F1-score: 0.8794
#     mAP: 0.9162
#   [MWMOTE - SVM]
#     AUROC: 0.9448
#     G-mean: 0.8810
#     MCC: 0.5999
#     F1-score: 0.6202
#     mAP: 0.7529
#   [MWMOTE - DecisionTree]
#     AUROC: 0.9655
#     G-mean: 0.9359
#     MCC: 0.7892
#     F1-score: 0.8034
#     mAP: 0.8395
#   [MWMOTE - kNN]
#     AUROC: 0.9055
#     G-mean: 0.8480
#     MCC: 0.5415
#     F1-score: 0.5687
#     mAP: 0.5512
#   [MWMOTE - MLP]
#     AUROC: 0.9554
#     G-mean: 0.8992
#     MCC: 0.6536
#     F1-score: 0.6722
#     mAP: 0.7783
#   [MWMOTE - RandomForest]
#     AUROC: 0.9849
#     G-mean: 0.9284
#     MCC: 0.8296
#     F1-score: 0.8444
#     mAP: 0.9003
#   [CTGAN - SVM]
#     AUROC: 0.9311
#     G-mean: 0.7786
#     MCC: 0.6186
#     F1-score: 0.6490
#     mAP: 0.6637
#   [CTGAN - DecisionTree]
#     AUROC: 0.9678
#     G-mean: 0.9255
#     MCC: 0.8470
#     F1-score: 0.8603
#     mAP: 0.8177
#   [CTGAN - kNN]
#     AUROC: 0.8936
#     G-mean: 0.6977
#     MCC: 0.5560
#     F1-score: 0.5803
#     mAP: 0.5575
#   [CTGAN - MLP]
#     AUROC: 0.9494
#     G-mean: 0.8353
#     MCC: 0.7044
#     F1-score: 0.7284
#     mAP: 0.7387
#   [CTGAN - RandomForest]
#     AUROC: 0.9861
#     G-mean: 0.9245
#     MCC: 0.8689
#     F1-score: 0.8797
#     mAP: 0.9136
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results
#    0.8051]},
#  'CTGAN - kNN': {'AUROC': [0.8951,
#    0.8968,
#    0.8863,
#    0.8908,
#    0.8955,
#    0.8976,
#    0.8948,
#    0.8916,
#    0.8937,
#    0.8938],
#   'G-mean': [0.6922,
#    0.6896,
#    0.699,
#    0.7067,
#    0.7051,
#    0.7011,
#    0.6984,
#    0.7032,
#    0.6815,
#    0.7006],
#   'MCC': [0.5564,
#    0.5583,
#    0.555,
#    0.5648,
#    0.571,
#    0.554,
#    0.5591,
#    0.5533,
#    0.5333,
#    0.5546],
#   'F1-score': [0.5793,
#    0.5786,
#    0.5806,
#    0.5888,
#    0.593,
#    0.5798,
#    0.5838,
#    0.5805,
#    0.5588,
#    0.5794],
#   'mAP': [0.5671,
#    0.5616,
#    0.5472,
#    0.5688,
#    0.5597,
#    0.561,
#    0.5676,
#    0.5375,
#    0.5423,
#    0.5624]},
#  'CTGAN - MLP': {'AUROC': [0.9502,
#    0.9469,
#    0.944,
#    0.9487,
#    0.9518,
#    0.9505,
#    0.9512,
#    0.9523,
#    0.9514,
#    0.9473],
#   'G-mean': [0.8339,
#    0.8054,
#    0.8174,
#    0.8264,
#    0.8483,
#    0.8579,
#    0.8394,
#    0.8441,
#    0.8389,
#    0.8411],
#   'MCC': [0.6931,
#    0.6719,
#    0.6811,
#    0.7007,
#    0.7234,
#    0.7252,
#    0.7142,
#    0.7129,
#    0.7151,
#    0.7059],
#   'F1-score': [0.7199,
#    0.697,
#    0.7063,
#    0.7226,
#    0.7463,
#    0.7492,
#    0.7386,
#    0.7348,
#    0.7393,
#    0.7298],
#   'mAP': [0.742,
#    0.709,
#    0.7183,
#    0.73,
#    0.7459,
#    0.7557,
#    0.7433,
#    0.7527,
#    0.7555,
#    0.7343]},
#  'CTGAN - RandomForest': {'AUROC': [0.9847,
#    0.9866,
#    0.9866,
#    0.986,
#    0.9873,
#    0.9858,
#    0.986,
#    0.9846,
#    0.9865,
#    0.9866],
#   'G-mean': [0.9218,
#    0.9223,
#    0.9234,
#    0.926,
#    0.9309,
#    0.9238,
#    0.9234,
#    0.9262,
#    0.927,
#    0.9204],
#   'MCC': [0.8669,
#    0.8664,
#    0.8694,
#    0.8703,
#    0.8778,
#    0.8652,
#    0.8659,
#    0.8737,
#    0.8684,
#    0.8647],
#   'F1-score': [0.8775,
#    0.8777,
#    0.8796,
#    0.8813,
#    0.8881,
#    0.8768,
#    0.8767,
#    0.8845,
#    0.8794,
#    0.8758],
#   'mAP': [0.9185,
#    0.912,
#    0.9126,
#    0.9128,
#    0.9169,
#    0.9146,
#    0.9163,
#    0.9088,
#    0.916,
#    0.9078]}}

# %%
# data_name = 'solar_flare_m0'
# maj_target_name = -1

# n_epochs = 2000
# hidden_dims = [64, 128, 256]
# latent_dim = 512
# lr = 0.01
# run_exp(
#     data=data, 
#     cat_idx=[], 
#     methods=methods, 
#     base_model=base_models,  
#     device=device,
#     n_epochs=n_epochs, 
#     hidden_dims=hidden_dims, 
#     latent_dim=latent_dim, 
#     lr=lr, 
#     beta=0.0,
#     seed=1203, 
#     data_name=data_name, 
#     maj_target_name=maj_target_name,    
#     save_path=save_path
# )

# %%
# data_name = 'cleveland-0_vs_4'

# n_epochs = 2000
# hidden_dims = [16, 32, 64, 128]
# latent_dim = 256
# lr = 0.001
# beta = 0.01

# # Load dataset
# cleveland_0_vs_4 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# # Run experiment
# final_results = run_exp(
#     data=cleveland_0_vs_4, 
#     cat_idx=[], 
#     methods=methods, 
#     base_model=base_models,   # base_model is now a dict of classifiers
#     device=device,
#     n_epochs=n_epochs, 
#     hidden_dims=hidden_dims, 
#     latent_dim=latent_dim, 
#     lr=lr, 
#     beta=beta,
#     data_name=data_name, 
#     seed=1203, 
#     visualize=True, 
#     save_path=save_path
# )

# # Process the final_results.
# # Expecting keys like "Original - DecisionTree", "SMOTE - kNN", etc.
# res_data = {
#     "Classifier": [],
#     "Method": [],
#     "Metric": [],
#     "Value": [],
# }

# for key, metrics in final_results.items():
#     # Split the key into oversampling method and classifier if possible
#     if " - " in key:
#         method_name, clf_name = key.split(" - ", 1)
#     else:
#         method_name, clf_name = key, "Default"
#     for metric, values in metrics.items():
#         avg_val = np.mean(values) if values else "N/A"
#         res_data["Classifier"].append(clf_name)
#         res_data["Method"].append(method_name)
#         res_data["Metric"].append(metric)
#         res_data["Value"].append(avg_val)

# res_df = pd.DataFrame(res_data)

# # Save the final results with classifier information
# os.makedirs(save_path, exist_ok=True)
# save_file = os.path.join(save_path, f"{data_name}_results.csv")
# res_df.to_csv(save_file, index=False)
# print(f"\n[Saved] Final results are saved to {save_file}")

# %%
# data_name = 'pima'

# # 실험 파라미터 설정
# n_epochs = 2000
# hidden_dims = [16, 32, 64, 128, 256]
# latent_dim = 512
# lr = 0.001
# beta = 0.001

# # 데이터 불러오기
# pima = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# # Run experiment
# final_results = run_exp(
#     data=pima, 
#     cat_idx=[], 
#     methods=methods, 
#     base_model=base_models,   # base_model is now a dict of classifiers
#     device=device,
#     n_epochs=n_epochs, 
#     hidden_dims=hidden_dims, 
#     latent_dim=latent_dim, 
#     lr=lr, 
#     beta=beta,
#     data_name=data_name, 
#     seed=1203, 
#     visualize=True, 
#     save_path=save_path
# )

# # Process the final_results.
# # Expecting keys like "Original - DecisionTree", "SMOTE - kNN", etc.
# res_data = {
#     "Classifier": [],
#     "Method": [],
#     "Metric": [],
#     "Value": [],
# }

# for key, metrics in final_results.items():
#     # Split the key into oversampling method and classifier if possible
#     if " - " in key:
#         method_name, clf_name = key.split(" - ", 1)
#     else:
#         method_name, clf_name = key, "Default"
#     for metric, values in metrics.items():
#         avg_val = np.mean(values) if values else "N/A"
#         res_data["Classifier"].append(clf_name)
#         res_data["Method"].append(method_name)
#         res_data["Metric"].append(metric)
#         res_data["Value"].append(avg_val)

# res_df = pd.DataFrame(res_data)

# # Save the final results with classifier information
# os.makedirs(save_path, exist_ok=True)
# save_file = os.path.join(save_path, f"{data_name}_results.csv")
# res_df.to_csv(save_file, index=False)
# print(f"\n[Saved] Final results are saved to {save_file}")
