# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

# Save path 
save_path = "/data4/oldrain123/oldrain123/results/ablation_results/beta8"
data_path = "/data4/oldrain123/oldrain123/dataset"

# %%
import os
import warnings
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from experiment import run_ablation
from imblearn.datasets import fetch_datasets

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
data = fetch_datasets()
methods = ["Ours"]
betas = [1e-1, 5e-2, 1e-2, 5e-3, 1e-3, 0.0]
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}

# %%
data_name = 'satimage'
maj_target_name = -1

n_epochs = 2000
hidden_dims = [32, 16, 8]
latent_dim = 4
lr = 0.001
for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        fetch_data_func=fetch_datasets,
        maj_target_name=maj_target_name,
        methods=methods,
        base_models=base_models,
        device=device,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )
# Out:
# beta: 0.1
# Dataset loaded: satimage
# X shape : (6435, 36)
# target : Counter({0: 5809, 1: 626})
# IR: 9.28
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9446
#     G-mean: 0.8851
#     MCC: 0.5647
#     F1-score: 0.5778
#     mAP: 0.6311
#   [Ours - DecisionTree]
#     AUROC: 0.8898
#     G-mean: 0.8257
#     MCC: 0.4814
#     F1-score: 0.5130
#     mAP: 0.4175
#   [Ours - kNN]
#     AUROC: 0.9288
#     G-mean: 0.8670
#     MCC: 0.5313
#     F1-score: 0.5485
#     mAP: 0.5144
#   [Ours - MLP]
#     AUROC: 0.9505
#     G-mean: 0.8507
#     MCC: 0.6082
#     F1-score: 0.6416
#     mAP: 0.6926
#   [Ours - RandomForest]
#     AUROC: 0.9600
#     G-mean: 0.8119
#     MCC: 0.6327
#     F1-score: 0.6677
#     mAP: 0.7741
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9451
#     G-mean: 0.8843
#     MCC: 0.5637
#     F1-score: 0.5770
#     mAP: 0.6331
#   [Ours - DecisionTree]
#     AUROC: 0.8964
#     G-mean: 0.8256
#     MCC: 0.4897
#     F1-score: 0.5226
#     mAP: 0.4284
#   [Ours - kNN]
#     AUROC: 0.9296
#     G-mean: 0.8712
#     MCC: 0.5360
#     F1-score: 0.5513
#     mAP: 0.5118
#   [Ours - MLP]
#     AUROC: 0.9527
#     G-mean: 0.8494
#     MCC: 0.6172
#     F1-score: 0.6512
#     mAP: 0.7077
#   [Ours - RandomForest]
#     AUROC: 0.9603
#     G-mean: 0.8122
#     MCC: 0.6355
#     F1-score: 0.6705
#     mAP: 0.7731
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9441
#     G-mean: 0.8823
#     MCC: 0.5606
#     F1-score: 0.5746
#     mAP: 0.6267
#   [Ours - DecisionTree]
#     AUROC: 0.8985
#     G-mean: 0.8283
#     MCC: 0.4926
#     F1-score: 0.5246
#     mAP: 0.4322
#   [Ours - kNN]
#     AUROC: 0.9300
#     G-mean: 0.8763
#     MCC: 0.5434
#     F1-score: 0.5571
#     mAP: 0.5142
#   [Ours - MLP]
#     AUROC: 0.9517
#     G-mean: 0.8497
#     MCC: 0.6168
#     F1-score: 0.6506
#     mAP: 0.7051
#   [Ours - RandomForest]
#     AUROC: 0.9596
#     G-mean: 0.8104
#     MCC: 0.6350
#     F1-score: 0.6701
#     mAP: 0.7704
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9438
#     G-mean: 0.8823
#     MCC: 0.5598
#     F1-score: 0.5736
#     mAP: 0.6268
#   [Ours - DecisionTree]
#     AUROC: 0.8985
#     G-mean: 0.8257
#     MCC: 0.4929
#     F1-score: 0.5261
#     mAP: 0.4367
#   [Ours - kNN]
#     AUROC: 0.9299
#     G-mean: 0.8760
#     MCC: 0.5428
#     F1-score: 0.5563
#     mAP: 0.5108
#   [Ours - MLP]
#     AUROC: 0.9520
#     G-mean: 0.8464
#     MCC: 0.6122
#     F1-score: 0.6465
#     mAP: 0.7055
#   [Ours - RandomForest]
#     AUROC: 0.9595
#     G-mean: 0.8082
#     MCC: 0.6347
#     F1-score: 0.6696
#     mAP: 0.7707
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9437
#     G-mean: 0.8821
#     MCC: 0.5591
#     F1-score: 0.5728
#     mAP: 0.6245
#   [Ours - DecisionTree]
#     AUROC: 0.8984
#     G-mean: 0.8237
#     MCC: 0.4889
#     F1-score: 0.5226
#     mAP: 0.4363
#   [Ours - kNN]
#     AUROC: 0.9316
#     G-mean: 0.8773
#     MCC: 0.5456
#     F1-score: 0.5590
#     mAP: 0.5159
#   [Ours - MLP]
#     AUROC: 0.9523
#     G-mean: 0.8464
#     MCC: 0.6147
#     F1-score: 0.6489
#     mAP: 0.7072
#   [Ours - RandomForest]
#     AUROC: 0.9595
#     G-mean: 0.8080
#     MCC: 0.6339
#     F1-score: 0.6689
#     mAP: 0.7709
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9440
#     G-mean: 0.8809
#     MCC: 0.5574
#     F1-score: 0.5716
#     mAP: 0.6280
#   [Ours - DecisionTree]
#     AUROC: 0.8982
#     G-mean: 0.8240
#     MCC: 0.4888
#     F1-score: 0.5223
#     mAP: 0.4355
#   [Ours - kNN]
#     AUROC: 0.9316
#     G-mean: 0.8765
#     MCC: 0.5449
#     F1-score: 0.5587
#     mAP: 0.5158
#   [Ours - MLP]
#     AUROC: 0.9527
#     G-mean: 0.8476
#     MCC: 0.6152
#     F1-score: 0.6492
#     mAP: 0.7089
#   [Ours - RandomForest]
#     AUROC: 0.9598
#     G-mean: 0.8088
#     MCC: 0.6349
#     F1-score: 0.6697
#     mAP: 0.7719
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9439
#     G-mean: 0.8813
#     MCC: 0.5579
#     F1-score: 0.5719
#     mAP: 0.6257
#   [Ours - DecisionTree]
#     AUROC: 0.8976
#     G-mean: 0.8256
#     MCC: 0.4904
#     F1-score: 0.5233
#     mAP: 0.4358
#   [Ours - kNN]
#     AUROC: 0.9316
#     G-mean: 0.8766
#     MCC: 0.5442
#     F1-score: 0.5578
#     mAP: 0.5149
#   [Ours - MLP]
#     AUROC: 0.9524
#     G-mean: 0.8479
#     MCC: 0.6144
#     F1-score: 0.6484
#     mAP: 0.7070
#   [Ours - RandomForest]
#     AUROC: 0.9596
#     G-mean: 0.8091
#     MCC: 0.6347
#     F1-score: 0.6697
#     mAP: 0.7715
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9442
#     G-mean: 0.8822
#     MCC: 0.5589
#     F1-score: 0.5726
#     mAP: 0.6260
#   [Ours - DecisionTree]
#     AUROC: 0.8966
#     G-mean: 0.8247
#     MCC: 0.4911
#     F1-score: 0.5245
#     mAP: 0.4337
#   [Ours - kNN]
#     AUROC: 0.9308
#     G-mean: 0.8767
#     MCC: 0.5434
#     F1-score: 0.5568
#     mAP: 0.5117
#   [Ours - MLP]
#     AUROC: 0.9525
#     G-mean: 0.8486
#     MCC: 0.6155
#     F1-score: 0.6493
#     mAP: 0.7065
#   [Ours - RandomForest]
#     AUROC: 0.9598
#     G-mean: 0.8095
#     MCC: 0.6357
#     F1-score: 0.6705
#     mAP: 0.7716
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9442
#     G-mean: 0.8817
#     MCC: 0.5582
#     F1-score: 0.5721
#     mAP: 0.6272
#   [Ours - DecisionTree]
#     AUROC: 0.8965
#     G-mean: 0.8246
#     MCC: 0.4920
#     F1-score: 0.5257
#     mAP: 0.4360
#   [Ours - kNN]
#     AUROC: 0.9306
#     G-mean: 0.8760
#     MCC: 0.5425
#     F1-score: 0.5561
#     mAP: 0.5114
#   [Ours - MLP]
#     AUROC: 0.9522
#     G-mean: 0.8487
#     MCC: 0.6161
#     F1-score: 0.6497
#     mAP: 0.7056
#   [Ours - RandomForest]
#     AUROC: 0.9597
#     G-mean: 0.8078
#     MCC: 0.6336
#     F1-score: 0.6686
#     mAP: 0.7705
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9442
#     G-mean: 0.8820
#     MCC: 0.5588
#     F1-score: 0.5727
#     mAP: 0.6271
#   [Ours - DecisionTree]
#     AUROC: 0.8963
#     G-mean: 0.8245
#     MCC: 0.4920
#     F1-score: 0.5256
#     mAP: 0.4359
#   [Ours - kNN]
#     AUROC: 0.9305
#     G-mean: 0.8762
#     MCC: 0.5424
#     F1-score: 0.5559
#     mAP: 0.5103
#   [Ours - MLP]
#     AUROC: 0.9523
#     G-mean: 0.8492
#     MCC: 0.6169
#     F1-score: 0.6504
#     mAP: 0.7058
#   [Ours - RandomForest]
#     AUROC: 0.9596
#     G-mean: 0.8073
#     MCC: 0.6326
#     F1-score: 0.6677
#     mAP: 0.7704
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/satimage_results_gaussian_beta_0.1.csv
# beta: 0.05
# Dataset loaded: satimage
# X shape : (6435, 36)
# target : Counter({0: 5809, 1: 626})
# IR: 9.28
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9444
#     G-mean: 0.8851
#     MCC: 0.5666
#     F1-score: 0.5801
#     mAP: 0.6382
#   [Ours - DecisionTree]
#     AUROC: 0.8984
#     G-mean: 0.8177
#     MCC: 0.4898
#     F1-score: 0.5258
#     mAP: 0.4470
#   [Ours - kNN]
#     AUROC: 0.9295
#     G-mean: 0.8814
#     MCC: 0.5590
#     F1-score: 0.5731
#     mAP: 0.5183
#   [Ours - MLP]
#     AUROC: 0.9509
#     G-mean: 0.8476
#     MCC: 0.6087
#     F1-score: 0.6431
#     mAP: 0.6945
#   [Ours - RandomForest]
#     AUROC: 0.9602
#     G-mean: 0.8104
#     MCC: 0.6286
#     F1-score: 0.6635
#     mAP: 0.7785
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9456
#     G-mean: 0.8850
#     MCC: 0.5657
#     F1-score: 0.5791
#     mAP: 0.6372
#   [Ours - DecisionTree]
#     AUROC: 0.8961
#     G-mean: 0.8181
#     MCC: 0.4899
#     F1-score: 0.5262
#     mAP: 0.4367
#   [Ours - kNN]
#     AUROC: 0.9313
#     G-mean: 0.8822
#     MCC: 0.5595
#     F1-score: 0.5731
#     mAP: 0.5192
#   [Ours - MLP]
#     AUROC: 0.9522
#     G-mean: 0.8496
#     MCC: 0.6223
#     F1-score: 0.6562
#     mAP: 0.7066
#   [Ours - RandomForest]
#     AUROC: 0.9595
#     G-mean: 0.8145
#     MCC: 0.6351
#     F1-score: 0.6701
#     mAP: 0.7741
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9447
#     G-mean: 0.8836
#     MCC: 0.5626
#     F1-score: 0.5763
#     mAP: 0.6294
#   [Ours - DecisionTree]
#     AUROC: 0.8955
#     G-mean: 0.8170
#     MCC: 0.4887
#     F1-score: 0.5254
#     mAP: 0.4379
#   [Ours - kNN]
#     AUROC: 0.9314
#     G-mean: 0.8813
#     MCC: 0.5578
#     F1-score: 0.5719
#     mAP: 0.5212
#   [Ours - MLP]
#     AUROC: 0.9513
#     G-mean: 0.8514
#     MCC: 0.6202
#     F1-score: 0.6537
#     mAP: 0.7013
#   [Ours - RandomForest]
#     AUROC: 0.9593
#     G-mean: 0.8127
#     MCC: 0.6334
#     F1-score: 0.6687
#     mAP: 0.7695
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9444
#     G-mean: 0.8826
#     MCC: 0.5621
#     F1-score: 0.5763
#     mAP: 0.6312
#   [Ours - DecisionTree]
#     AUROC: 0.8952
#     G-mean: 0.8174
#     MCC: 0.4878
#     F1-score: 0.5243
#     mAP: 0.4367
#   [Ours - kNN]
#     AUROC: 0.9320
#     G-mean: 0.8809
#     MCC: 0.5581
#     F1-score: 0.5722
#     mAP: 0.5210
#   [Ours - MLP]
#     AUROC: 0.9514
#     G-mean: 0.8490
#     MCC: 0.6172
#     F1-score: 0.6510
#     mAP: 0.7047
#   [Ours - RandomForest]
#     AUROC: 0.9596
#     G-mean: 0.8130
#     MCC: 0.6351
#     F1-score: 0.6702
#     mAP: 0.7711
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9443
#     G-mean: 0.8828
#     MCC: 0.5623
#     F1-score: 0.5765
#     mAP: 0.6322
#   [Ours - DecisionTree]
#     AUROC: 0.8973
#     G-mean: 0.8203
#     MCC: 0.4925
#     F1-score: 0.5282
#     mAP: 0.4404
#   [Ours - kNN]
#     AUROC: 0.9322
#     G-mean: 0.8792
#     MCC: 0.5563
#     F1-score: 0.5712
#     mAP: 0.5216
#   [Ours - MLP]
#     AUROC: 0.9516
#     G-mean: 0.8481
#     MCC: 0.6172
#     F1-score: 0.6512
#     mAP: 0.7063
#   [Ours - RandomForest]
#     AUROC: 0.9597
#     G-mean: 0.8147
#     MCC: 0.6367
#     F1-score: 0.6717
#     mAP: 0.7716
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9445
#     G-mean: 0.8831
#     MCC: 0.5632
#     F1-score: 0.5773
#     mAP: 0.6324
#   [Ours - DecisionTree]
#     AUROC: 0.8976
#     G-mean: 0.8200
#     MCC: 0.4916
#     F1-score: 0.5273
#     mAP: 0.4393
#   [Ours - kNN]
#     AUROC: 0.9321
#     G-mean: 0.8787
#     MCC: 0.5561
#     F1-score: 0.5713
#     mAP: 0.5218
#   [Ours - MLP]
#     AUROC: 0.9517
#     G-mean: 0.8488
#     MCC: 0.6177
#     F1-score: 0.6515
#     mAP: 0.7076
#   [Ours - RandomForest]
#     AUROC: 0.9599
#     G-mean: 0.8143
#     MCC: 0.6356
#     F1-score: 0.6707
#     mAP: 0.7721
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9441
#     G-mean: 0.8828
#     MCC: 0.5619
#     F1-score: 0.5759
#     mAP: 0.6315
#   [Ours - DecisionTree]
#     AUROC: 0.8983
#     G-mean: 0.8200
#     MCC: 0.4908
#     F1-score: 0.5264
#     mAP: 0.4401
#   [Ours - kNN]
#     AUROC: 0.9319
#     G-mean: 0.8778
#     MCC: 0.5527
#     F1-score: 0.5676
#     mAP: 0.5173
#   [Ours - MLP]
#     AUROC: 0.9515
#     G-mean: 0.8450
#     MCC: 0.6140
#     F1-score: 0.6486
#     mAP: 0.7052
#   [Ours - RandomForest]
#     AUROC: 0.9597
#     G-mean: 0.8134
#     MCC: 0.6347
#     F1-score: 0.6699
#     mAP: 0.7713
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9442
#     G-mean: 0.8830
#     MCC: 0.5620
#     F1-score: 0.5760
#     mAP: 0.6322
#   [Ours - DecisionTree]
#     AUROC: 0.8982
#     G-mean: 0.8201
#     MCC: 0.4898
#     F1-score: 0.5251
#     mAP: 0.4399
#   [Ours - kNN]
#     AUROC: 0.9315
#     G-mean: 0.8774
#     MCC: 0.5511
#     F1-score: 0.5660
#     mAP: 0.5172
#   [Ours - MLP]
#     AUROC: 0.9518
#     G-mean: 0.8454
#     MCC: 0.6155
#     F1-score: 0.6500
#     mAP: 0.7055
#   [Ours - RandomForest]
#     AUROC: 0.9598
#     G-mean: 0.8127
#     MCC: 0.6344
#     F1-score: 0.6696
#     mAP: 0.7714
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9442
#     G-mean: 0.8833
#     MCC: 0.5619
#     F1-score: 0.5757
#     mAP: 0.6317
#   [Ours - DecisionTree]
#     AUROC: 0.8984
#     G-mean: 0.8208
#     MCC: 0.4902
#     F1-score: 0.5252
#     mAP: 0.4402
#   [Ours - kNN]
#     AUROC: 0.9316
#     G-mean: 0.8777
#     MCC: 0.5503
#     F1-score: 0.5646
#     mAP: 0.5181
#   [Ours - MLP]
#     AUROC: 0.9518
#     G-mean: 0.8456
#     MCC: 0.6146
#     F1-score: 0.6490
#     mAP: 0.7055
#   [Ours - RandomForest]
#     AUROC: 0.9598
#     G-mean: 0.8130
#     MCC: 0.6346
#     F1-score: 0.6698
#     mAP: 0.7714
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9443
#     G-mean: 0.8834
#     MCC: 0.5623
#     F1-score: 0.5760
#     mAP: 0.6307
#   [Ours - DecisionTree]
#     AUROC: 0.8991
#     G-mean: 0.8209
#     MCC: 0.4912
#     F1-score: 0.5263
#     mAP: 0.4416
#   [Ours - kNN]
#     AUROC: 0.9316
#     G-mean: 0.8774
#     MCC: 0.5498
#     F1-score: 0.5643
#     mAP: 0.5183
#   [Ours - MLP]
#     AUROC: 0.9517
#     G-mean: 0.8463
#     MCC: 0.6142
#     F1-score: 0.6484
#     mAP: 0.7054
#   [Ours - RandomForest]
#     AUROC: 0.9597
#     G-mean: 0.8134
#     MCC: 0.6356
#     F1-score: 0.6707
#     mAP: 0.7712
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/satimage_results_gaussian_beta_0.05.csv
# beta: 0.01
# Dataset loaded: satimage
# X shape : (6435, 36)
# target : Counter({0: 5809, 1: 626})
# IR: 9.28
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9445
#     G-mean: 0.8856
#     MCC: 0.5789
#     F1-score: 0.5951
#     mAP: 0.6358
#   [Ours - DecisionTree]
#     AUROC: 0.8938
#     G-mean: 0.8266
#     MCC: 0.4984
#     F1-score: 0.5326
#     mAP: 0.4364
#   [Ours - kNN]
#     AUROC: 0.9333
#     G-mean: 0.8713
#     MCC: 0.5673
#     F1-score: 0.5896
#     mAP: 0.5496
#   [Ours - MLP]
#     AUROC: 0.9501
#     G-mean: 0.8313
#     MCC: 0.6019
#     F1-score: 0.6393
#     mAP: 0.6897
#   [Ours - RandomForest]
#     AUROC: 0.9585
#     G-mean: 0.8193
#     MCC: 0.6357
#     F1-score: 0.6712
#     mAP: 0.7672
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9448
#     G-mean: 0.8850
#     MCC: 0.5746
#     F1-score: 0.5903
#     mAP: 0.6391
#   [Ours - DecisionTree]
#     AUROC: 0.8961
#     G-mean: 0.8233
#     MCC: 0.4907
#     F1-score: 0.5252
#     mAP: 0.4345
#   [Ours - kNN]
#     AUROC: 0.9321
#     G-mean: 0.8714
#     MCC: 0.5715
#     F1-score: 0.5943
#     mAP: 0.5532
#   [Ours - MLP]
#     AUROC: 0.9505
#     G-mean: 0.8407
#     MCC: 0.6072
#     F1-score: 0.6429
#     mAP: 0.6924
#   [Ours - RandomForest]
#     AUROC: 0.9592
#     G-mean: 0.8216
#     MCC: 0.6390
#     F1-score: 0.6741
#     mAP: 0.7677
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9445
#     G-mean: 0.8832
#     MCC: 0.5718
#     F1-score: 0.5880
#     mAP: 0.6406
#   [Ours - DecisionTree]
#     AUROC: 0.8966
#     G-mean: 0.8247
#     MCC: 0.4919
#     F1-score: 0.5257
#     mAP: 0.4369
#   [Ours - kNN]
#     AUROC: 0.9332
#     G-mean: 0.8728
#     MCC: 0.5685
#     F1-score: 0.5901
#     mAP: 0.5521
#   [Ours - MLP]
#     AUROC: 0.9501
#     G-mean: 0.8401
#     MCC: 0.6060
#     F1-score: 0.6417
#     mAP: 0.6937
#   [Ours - RandomForest]
#     AUROC: 0.9591
#     G-mean: 0.8204
#     MCC: 0.6393
#     F1-score: 0.6744
#     mAP: 0.7675
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9440
#     G-mean: 0.8822
#     MCC: 0.5693
#     F1-score: 0.5856
#     mAP: 0.6423
#   [Ours - DecisionTree]
#     AUROC: 0.8967
#     G-mean: 0.8252
#     MCC: 0.4936
#     F1-score: 0.5272
#     mAP: 0.4405
#   [Ours - kNN]
#     AUROC: 0.9331
#     G-mean: 0.8718
#     MCC: 0.5688
#     F1-score: 0.5908
#     mAP: 0.5500
#   [Ours - MLP]
#     AUROC: 0.9494
#     G-mean: 0.8385
#     MCC: 0.6057
#     F1-score: 0.6417
#     mAP: 0.6978
#   [Ours - RandomForest]
#     AUROC: 0.9590
#     G-mean: 0.8192
#     MCC: 0.6391
#     F1-score: 0.6740
#     mAP: 0.7670
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9444
#     G-mean: 0.8814
#     MCC: 0.5682
#     F1-score: 0.5848
#     mAP: 0.6434
#   [Ours - DecisionTree]
#     AUROC: 0.8966
#     G-mean: 0.8256
#     MCC: 0.4925
#     F1-score: 0.5258
#     mAP: 0.4398
#   [Ours - kNN]
#     AUROC: 0.9332
#     G-mean: 0.8727
#     MCC: 0.5688
#     F1-score: 0.5903
#     mAP: 0.5492
#   [Ours - MLP]
#     AUROC: 0.9500
#     G-mean: 0.8390
#     MCC: 0.6089
#     F1-score: 0.6446
#     mAP: 0.6992
#   [Ours - RandomForest]
#     AUROC: 0.9588
#     G-mean: 0.8204
#     MCC: 0.6395
#     F1-score: 0.6743
#     mAP: 0.7664
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9440
#     G-mean: 0.8807
#     MCC: 0.5668
#     F1-score: 0.5835
#     mAP: 0.6420
#   [Ours - DecisionTree]
#     AUROC: 0.8968
#     G-mean: 0.8247
#     MCC: 0.4905
#     F1-score: 0.5239
#     mAP: 0.4402
#   [Ours - kNN]
#     AUROC: 0.9327
#     G-mean: 0.8721
#     MCC: 0.5668
#     F1-score: 0.5882
#     mAP: 0.5475
#   [Ours - MLP]
#     AUROC: 0.9500
#     G-mean: 0.8405
#     MCC: 0.6092
#     F1-score: 0.6447
#     mAP: 0.6999
#   [Ours - RandomForest]
#     AUROC: 0.9590
#     G-mean: 0.8204
#     MCC: 0.6397
#     F1-score: 0.6745
#     mAP: 0.7677
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9438
#     G-mean: 0.8797
#     MCC: 0.5655
#     F1-score: 0.5827
#     mAP: 0.6402
#   [Ours - DecisionTree]
#     AUROC: 0.8966
#     G-mean: 0.8251
#     MCC: 0.4896
#     F1-score: 0.5226
#     mAP: 0.4406
#   [Ours - kNN]
#     AUROC: 0.9324
#     G-mean: 0.8716
#     MCC: 0.5648
#     F1-score: 0.5862
#     mAP: 0.5437
#   [Ours - MLP]
#     AUROC: 0.9503
#     G-mean: 0.8402
#     MCC: 0.6105
#     F1-score: 0.6460
#     mAP: 0.6997
#   [Ours - RandomForest]
#     AUROC: 0.9589
#     G-mean: 0.8212
#     MCC: 0.6404
#     F1-score: 0.6752
#     mAP: 0.7681
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9437
#     G-mean: 0.8799
#     MCC: 0.5657
#     F1-score: 0.5828
#     mAP: 0.6397
#   [Ours - DecisionTree]
#     AUROC: 0.8955
#     G-mean: 0.8246
#     MCC: 0.4880
#     F1-score: 0.5211
#     mAP: 0.4393
#   [Ours - kNN]
#     AUROC: 0.9321
#     G-mean: 0.8716
#     MCC: 0.5653
#     F1-score: 0.5868
#     mAP: 0.5435
#   [Ours - MLP]
#     AUROC: 0.9503
#     G-mean: 0.8399
#     MCC: 0.6103
#     F1-score: 0.6459
#     mAP: 0.6982
#   [Ours - RandomForest]
#     AUROC: 0.9587
#     G-mean: 0.8209
#     MCC: 0.6406
#     F1-score: 0.6754
#     mAP: 0.7676
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9438
#     G-mean: 0.8796
#     MCC: 0.5654
#     F1-score: 0.5825
#     mAP: 0.6387
#   [Ours - DecisionTree]
#     AUROC: 0.8965
#     G-mean: 0.8252
#     MCC: 0.4883
#     F1-score: 0.5210
#     mAP: 0.4419
#   [Ours - kNN]
#     AUROC: 0.9324
#     G-mean: 0.8721
#     MCC: 0.5644
#     F1-score: 0.5855
#     mAP: 0.5445
#   [Ours - MLP]
#     AUROC: 0.9504
#     G-mean: 0.8396
#     MCC: 0.6098
#     F1-score: 0.6453
#     mAP: 0.6990
#   [Ours - RandomForest]
#     AUROC: 0.9588
#     G-mean: 0.8208
#     MCC: 0.6400
#     F1-score: 0.6747
#     mAP: 0.7672
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9437
#     G-mean: 0.8796
#     MCC: 0.5650
#     F1-score: 0.5821
#     mAP: 0.6390
#   [Ours - DecisionTree]
#     AUROC: 0.8966
#     G-mean: 0.8245
#     MCC: 0.4871
#     F1-score: 0.5200
#     mAP: 0.4418
#   [Ours - kNN]
#     AUROC: 0.9326
#     G-mean: 0.8724
#     MCC: 0.5650
#     F1-score: 0.5861
#     mAP: 0.5442
#   [Ours - MLP]
#     AUROC: 0.9506
#     G-mean: 0.8410
#     MCC: 0.6118
#     F1-score: 0.6470
#     mAP: 0.7002
#   [Ours - RandomForest]
#     AUROC: 0.9587
#     G-mean: 0.8205
#     MCC: 0.6397
#     F1-score: 0.6745
#     mAP: 0.7671
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/satimage_results_gaussian_beta_0.01.csv
# beta: 0.005
# Dataset loaded: satimage
# X shape : (6435, 36)
# target : Counter({0: 5809, 1: 626})
# IR: 9.28
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9450
#     G-mean: 0.8833
#     MCC: 0.5764
#     F1-score: 0.5934
#     mAP: 0.6426
#   [Ours - DecisionTree]
#     AUROC: 0.9009
#     G-mean: 0.8136
#     MCC: 0.4789
#     F1-score: 0.5164
#     mAP: 0.4323
#   [Ours - kNN]
#     AUROC: 0.9310
#     G-mean: 0.8612
#     MCC: 0.5650
#     F1-score: 0.5908
#     mAP: 0.5525
#   [Ours - MLP]
#     AUROC: 0.9503
#     G-mean: 0.8486
#     MCC: 0.6164
#     F1-score: 0.6504
#     mAP: 0.6889
#   [Ours - RandomForest]
#     AUROC: 0.9574
#     G-mean: 0.8114
#     MCC: 0.6270
#     F1-score: 0.6628
#     mAP: 0.7654
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9450
#     G-mean: 0.8858
#     MCC: 0.5761
#     F1-score: 0.5915
#     mAP: 0.6375
#   [Ours - DecisionTree]
#     AUROC: 0.8992
#     G-mean: 0.8173
#     MCC: 0.4847
#     F1-score: 0.5212
#     mAP: 0.4384
#   [Ours - kNN]
#     AUROC: 0.9317
#     G-mean: 0.8662
#     MCC: 0.5665
#     F1-score: 0.5907
#     mAP: 0.5543
#   [Ours - MLP]
#     AUROC: 0.9516
#     G-mean: 0.8451
#     MCC: 0.6166
#     F1-score: 0.6513
#     mAP: 0.7049
#   [Ours - RandomForest]
#     AUROC: 0.9581
#     G-mean: 0.8159
#     MCC: 0.6302
#     F1-score: 0.6660
#     mAP: 0.7653
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9445
#     G-mean: 0.8833
#     MCC: 0.5729
#     F1-score: 0.5892
#     mAP: 0.6405
#   [Ours - DecisionTree]
#     AUROC: 0.8959
#     G-mean: 0.8212
#     MCC: 0.4866
#     F1-score: 0.5216
#     mAP: 0.4302
#   [Ours - kNN]
#     AUROC: 0.9317
#     G-mean: 0.8672
#     MCC: 0.5656
#     F1-score: 0.5892
#     mAP: 0.5517
#   [Ours - MLP]
#     AUROC: 0.9513
#     G-mean: 0.8429
#     MCC: 0.6114
#     F1-score: 0.6463
#     mAP: 0.7016
#   [Ours - RandomForest]
#     AUROC: 0.9581
#     G-mean: 0.8154
#     MCC: 0.6313
#     F1-score: 0.6672
#     mAP: 0.7652
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9437
#     G-mean: 0.8823
#     MCC: 0.5723
#     F1-score: 0.5891
#     mAP: 0.6416
#   [Ours - DecisionTree]
#     AUROC: 0.8949
#     G-mean: 0.8214
#     MCC: 0.4877
#     F1-score: 0.5224
#     mAP: 0.4310
#   [Ours - kNN]
#     AUROC: 0.9312
#     G-mean: 0.8679
#     MCC: 0.5678
#     F1-score: 0.5913
#     mAP: 0.5478
#   [Ours - MLP]
#     AUROC: 0.9504
#     G-mean: 0.8418
#     MCC: 0.6106
#     F1-score: 0.6458
#     mAP: 0.7032
#   [Ours - RandomForest]
#     AUROC: 0.9581
#     G-mean: 0.8149
#     MCC: 0.6321
#     F1-score: 0.6676
#     mAP: 0.7652
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9435
#     G-mean: 0.8809
#     MCC: 0.5708
#     F1-score: 0.5881
#     mAP: 0.6445
#   [Ours - DecisionTree]
#     AUROC: 0.8943
#     G-mean: 0.8209
#     MCC: 0.4862
#     F1-score: 0.5210
#     mAP: 0.4312
#   [Ours - kNN]
#     AUROC: 0.9318
#     G-mean: 0.8692
#     MCC: 0.5704
#     F1-score: 0.5938
#     mAP: 0.5498
#   [Ours - MLP]
#     AUROC: 0.9504
#     G-mean: 0.8416
#     MCC: 0.6116
#     F1-score: 0.6468
#     mAP: 0.7040
#   [Ours - RandomForest]
#     AUROC: 0.9580
#     G-mean: 0.8157
#     MCC: 0.6317
#     F1-score: 0.6673
#     mAP: 0.7647
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9430
#     G-mean: 0.8803
#     MCC: 0.5704
#     F1-score: 0.5881
#     mAP: 0.6419
#   [Ours - DecisionTree]
#     AUROC: 0.8949
#     G-mean: 0.8210
#     MCC: 0.4875
#     F1-score: 0.5222
#     mAP: 0.4336
#   [Ours - kNN]
#     AUROC: 0.9319
#     G-mean: 0.8692
#     MCC: 0.5702
#     F1-score: 0.5936
#     mAP: 0.5504
#   [Ours - MLP]
#     AUROC: 0.9501
#     G-mean: 0.8411
#     MCC: 0.6112
#     F1-score: 0.6464
#     mAP: 0.7041
#   [Ours - RandomForest]
#     AUROC: 0.9581
#     G-mean: 0.8162
#     MCC: 0.6326
#     F1-score: 0.6680
#     mAP: 0.7649
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9430
#     G-mean: 0.8793
#     MCC: 0.5693
#     F1-score: 0.5874
#     mAP: 0.6406
#   [Ours - DecisionTree]
#     AUROC: 0.8944
#     G-mean: 0.8230
#     MCC: 0.4890
#     F1-score: 0.5230
#     mAP: 0.4344
#   [Ours - kNN]
#     AUROC: 0.9318
#     G-mean: 0.8679
#     MCC: 0.5679
#     F1-score: 0.5916
#     mAP: 0.5484
#   [Ours - MLP]
#     AUROC: 0.9501
#     G-mean: 0.8406
#     MCC: 0.6106
#     F1-score: 0.6460
#     mAP: 0.7023
#   [Ours - RandomForest]
#     AUROC: 0.9582
#     G-mean: 0.8166
#     MCC: 0.6331
#     F1-score: 0.6685
#     mAP: 0.7659
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9429
#     G-mean: 0.8784
#     MCC: 0.5679
#     F1-score: 0.5863
#     mAP: 0.6407
#   [Ours - DecisionTree]
#     AUROC: 0.8948
#     G-mean: 0.8243
#     MCC: 0.4918
#     F1-score: 0.5256
#     mAP: 0.4331
#   [Ours - kNN]
#     AUROC: 0.9316
#     G-mean: 0.8673
#     MCC: 0.5683
#     F1-score: 0.5923
#     mAP: 0.5490
#   [Ours - MLP]
#     AUROC: 0.9500
#     G-mean: 0.8402
#     MCC: 0.6113
#     F1-score: 0.6468
#     mAP: 0.7029
#   [Ours - RandomForest]
#     AUROC: 0.9582
#     G-mean: 0.8158
#     MCC: 0.6329
#     F1-score: 0.6683
#     mAP: 0.7652
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9429
#     G-mean: 0.8781
#     MCC: 0.5673
#     F1-score: 0.5858
#     mAP: 0.6403
#   [Ours - DecisionTree]
#     AUROC: 0.8947
#     G-mean: 0.8239
#     MCC: 0.4901
#     F1-score: 0.5239
#     mAP: 0.4318
#   [Ours - kNN]
#     AUROC: 0.9319
#     G-mean: 0.8680
#     MCC: 0.5675
#     F1-score: 0.5911
#     mAP: 0.5494
#   [Ours - MLP]
#     AUROC: 0.9501
#     G-mean: 0.8409
#     MCC: 0.6108
#     F1-score: 0.6461
#     mAP: 0.7034
#   [Ours - RandomForest]
#     AUROC: 0.9582
#     G-mean: 0.8157
#     MCC: 0.6325
#     F1-score: 0.6679
#     mAP: 0.7652
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9428
#     G-mean: 0.8777
#     MCC: 0.5664
#     F1-score: 0.5848
#     mAP: 0.6401
#   [Ours - DecisionTree]
#     AUROC: 0.8950
#     G-mean: 0.8225
#     MCC: 0.4880
#     F1-score: 0.5222
#     mAP: 0.4311
#   [Ours - kNN]
#     AUROC: 0.9323
#     G-mean: 0.8685
#     MCC: 0.5692
#     F1-score: 0.5928
#     mAP: 0.5503
#   [Ours - MLP]
#     AUROC: 0.9503
#     G-mean: 0.8410
#     MCC: 0.6118
#     F1-score: 0.6470
#     mAP: 0.7043
#   [Ours - RandomForest]
#     AUROC: 0.9582
#     G-mean: 0.8162
#     MCC: 0.6328
#     F1-score: 0.6682
#     mAP: 0.7651
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/satimage_results_gaussian_beta_0.005.csv
# beta: 0.001
# Dataset loaded: satimage
# X shape : (6435, 36)
# target : Counter({0: 5809, 1: 626})
# IR: 9.28
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9425
#     G-mean: 0.8742
#     MCC: 0.5682
#     F1-score: 0.5888
#     mAP: 0.6430
#   [Ours - DecisionTree]
#     AUROC: 0.8934
#     G-mean: 0.8147
#     MCC: 0.4874
#     F1-score: 0.5248
#     mAP: 0.4191
#   [Ours - kNN]
#     AUROC: 0.9325
#     G-mean: 0.8650
#     MCC: 0.5787
#     F1-score: 0.6052
#     mAP: 0.5726
#   [Ours - MLP]
#     AUROC: 0.9498
#     G-mean: 0.8498
#     MCC: 0.6135
#     F1-score: 0.6476
#     mAP: 0.6899
#   [Ours - RandomForest]
#     AUROC: 0.9569
#     G-mean: 0.8088
#     MCC: 0.6269
#     F1-score: 0.6625
#     mAP: 0.7646
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9434
#     G-mean: 0.8753
#     MCC: 0.5657
#     F1-score: 0.5852
#     mAP: 0.6404
#   [Ours - DecisionTree]
#     AUROC: 0.8972
#     G-mean: 0.8217
#     MCC: 0.4967
#     F1-score: 0.5325
#     mAP: 0.4330
#   [Ours - kNN]
#     AUROC: 0.9344
#     G-mean: 0.8671
#     MCC: 0.5766
#     F1-score: 0.6018
#     mAP: 0.5717
#   [Ours - MLP]
#     AUROC: 0.9508
#     G-mean: 0.8467
#     MCC: 0.6141
#     F1-score: 0.6478
#     mAP: 0.6986
#   [Ours - RandomForest]
#     AUROC: 0.9576
#     G-mean: 0.8080
#     MCC: 0.6221
#     F1-score: 0.6584
#     mAP: 0.7649
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9427
#     G-mean: 0.8758
#     MCC: 0.5661
#     F1-score: 0.5854
#     mAP: 0.6398
#   [Ours - DecisionTree]
#     AUROC: 0.8927
#     G-mean: 0.8220
#     MCC: 0.4940
#     F1-score: 0.5294
#     mAP: 0.4284
#   [Ours - kNN]
#     AUROC: 0.9337
#     G-mean: 0.8628
#     MCC: 0.5699
#     F1-score: 0.5965
#     mAP: 0.5696
#   [Ours - MLP]
#     AUROC: 0.9506
#     G-mean: 0.8425
#     MCC: 0.6142
#     F1-score: 0.6488
#     mAP: 0.6967
#   [Ours - RandomForest]
#     AUROC: 0.9573
#     G-mean: 0.8102
#     MCC: 0.6242
#     F1-score: 0.6607
#     mAP: 0.7635
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9423
#     G-mean: 0.8762
#     MCC: 0.5667
#     F1-score: 0.5860
#     mAP: 0.6418
#   [Ours - DecisionTree]
#     AUROC: 0.8941
#     G-mean: 0.8226
#     MCC: 0.4935
#     F1-score: 0.5281
#     mAP: 0.4298
#   [Ours - kNN]
#     AUROC: 0.9332
#     G-mean: 0.8610
#     MCC: 0.5680
#     F1-score: 0.5950
#     mAP: 0.5653
#   [Ours - MLP]
#     AUROC: 0.9497
#     G-mean: 0.8385
#     MCC: 0.6093
#     F1-score: 0.6447
#     mAP: 0.6990
#   [Ours - RandomForest]
#     AUROC: 0.9573
#     G-mean: 0.8121
#     MCC: 0.6279
#     F1-score: 0.6637
#     mAP: 0.7632
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9419
#     G-mean: 0.8747
#     MCC: 0.5654
#     F1-score: 0.5854
#     mAP: 0.6432
#   [Ours - DecisionTree]
#     AUROC: 0.8932
#     G-mean: 0.8206
#     MCC: 0.4910
#     F1-score: 0.5264
#     mAP: 0.4294
#   [Ours - kNN]
#     AUROC: 0.9340
#     G-mean: 0.8629
#     MCC: 0.5716
#     F1-score: 0.5983
#     mAP: 0.5695
#   [Ours - MLP]
#     AUROC: 0.9494
#     G-mean: 0.8386
#     MCC: 0.6113
#     F1-score: 0.6466
#     mAP: 0.6982
#   [Ours - RandomForest]
#     AUROC: 0.9571
#     G-mean: 0.8120
#     MCC: 0.6268
#     F1-score: 0.6628
#     mAP: 0.7627
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9414
#     G-mean: 0.8728
#     MCC: 0.5634
#     F1-score: 0.5841
#     mAP: 0.6416
#   [Ours - DecisionTree]
#     AUROC: 0.8926
#     G-mean: 0.8212
#     MCC: 0.4909
#     F1-score: 0.5260
#     mAP: 0.4304
#   [Ours - kNN]
#     AUROC: 0.9335
#     G-mean: 0.8629
#     MCC: 0.5714
#     F1-score: 0.5981
#     mAP: 0.5672
#   [Ours - MLP]
#     AUROC: 0.9494
#     G-mean: 0.8387
#     MCC: 0.6120
#     F1-score: 0.6473
#     mAP: 0.6992
#   [Ours - RandomForest]
#     AUROC: 0.9572
#     G-mean: 0.8123
#     MCC: 0.6286
#     F1-score: 0.6642
#     mAP: 0.7631
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9416
#     G-mean: 0.8738
#     MCC: 0.5654
#     F1-score: 0.5859
#     mAP: 0.6419
#   [Ours - DecisionTree]
#     AUROC: 0.8930
#     G-mean: 0.8218
#     MCC: 0.4913
#     F1-score: 0.5263
#     mAP: 0.4307
#   [Ours - kNN]
#     AUROC: 0.9333
#     G-mean: 0.8627
#     MCC: 0.5717
#     F1-score: 0.5985
#     mAP: 0.5668
#   [Ours - MLP]
#     AUROC: 0.9492
#     G-mean: 0.8374
#     MCC: 0.6110
#     F1-score: 0.6467
#     mAP: 0.6988
#   [Ours - RandomForest]
#     AUROC: 0.9574
#     G-mean: 0.8136
#     MCC: 0.6300
#     F1-score: 0.6656
#     mAP: 0.7638
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9415
#     G-mean: 0.8733
#     MCC: 0.5648
#     F1-score: 0.5855
#     mAP: 0.6415
#   [Ours - DecisionTree]
#     AUROC: 0.8933
#     G-mean: 0.8237
#     MCC: 0.4928
#     F1-score: 0.5270
#     mAP: 0.4307
#   [Ours - kNN]
#     AUROC: 0.9331
#     G-mean: 0.8631
#     MCC: 0.5726
#     F1-score: 0.5994
#     mAP: 0.5671
#   [Ours - MLP]
#     AUROC: 0.9492
#     G-mean: 0.8376
#     MCC: 0.6099
#     F1-score: 0.6456
#     mAP: 0.6987
#   [Ours - RandomForest]
#     AUROC: 0.9574
#     G-mean: 0.8135
#     MCC: 0.6305
#     F1-score: 0.6661
#     mAP: 0.7627
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9419
#     G-mean: 0.8738
#     MCC: 0.5657
#     F1-score: 0.5863
#     mAP: 0.6415
#   [Ours - DecisionTree]
#     AUROC: 0.8941
#     G-mean: 0.8250
#     MCC: 0.4922
#     F1-score: 0.5257
#     mAP: 0.4303
#   [Ours - kNN]
#     AUROC: 0.9335
#     G-mean: 0.8645
#     MCC: 0.5736
#     F1-score: 0.5999
#     mAP: 0.5675
#   [Ours - MLP]
#     AUROC: 0.9492
#     G-mean: 0.8368
#     MCC: 0.6084
#     F1-score: 0.6443
#     mAP: 0.6981
#   [Ours - RandomForest]
#     AUROC: 0.9576
#     G-mean: 0.8138
#     MCC: 0.6308
#     F1-score: 0.6663
#     mAP: 0.7628
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9418
#     G-mean: 0.8745
#     MCC: 0.5662
#     F1-score: 0.5865
#     mAP: 0.6401
#   [Ours - DecisionTree]
#     AUROC: 0.8940
#     G-mean: 0.8248
#     MCC: 0.4913
#     F1-score: 0.5248
#     mAP: 0.4285
#   [Ours - kNN]
#     AUROC: 0.9337
#     G-mean: 0.8650
#     MCC: 0.5745
#     F1-score: 0.6006
#     mAP: 0.5677
#   [Ours - MLP]
#     AUROC: 0.9495
#     G-mean: 0.8369
#     MCC: 0.6087
#     F1-score: 0.6445
#     mAP: 0.6986
#   [Ours - RandomForest]
#     AUROC: 0.9576
#     G-mean: 0.8140
#     MCC: 0.6313
#     F1-score: 0.6668
#     mAP: 0.7630
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/satimage_results_gaussian_beta_0.001.csv
# beta: 0.0
# Dataset loaded: satimage
# X shape : (6435, 36)
# target : Counter({0: 5809, 1: 626})
# IR: 9.28
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9428
#     G-mean: 0.8796
#     MCC: 0.5786
#     F1-score: 0.5979
#     mAP: 0.6436
#   [Ours - DecisionTree]
#     AUROC: 0.8961
#     G-mean: 0.8218
#     MCC: 0.4941
#     F1-score: 0.5293
#     mAP: 0.4581
#   [Ours - kNN]
#     AUROC: 0.9336
#     G-mean: 0.8639
#     MCC: 0.5807
#     F1-score: 0.6081
#     mAP: 0.5731
#   [Ours - MLP]
#     AUROC: 0.9491
#     G-mean: 0.8388
#     MCC: 0.6063
#     F1-score: 0.6417
#     mAP: 0.6857
#   [Ours - RandomForest]
#     AUROC: 0.9563
#     G-mean: 0.8084
#     MCC: 0.6258
#     F1-score: 0.6613
#     mAP: 0.7597
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9435
#     G-mean: 0.8793
#     MCC: 0.5744
#     F1-score: 0.5930
#     mAP: 0.6402
#   [Ours - DecisionTree]
#     AUROC: 0.8922
#     G-mean: 0.8199
#     MCC: 0.4868
#     F1-score: 0.5221
#     mAP: 0.4395
#   [Ours - kNN]
#     AUROC: 0.9354
#     G-mean: 0.8726
#     MCC: 0.5892
#     F1-score: 0.6138
#     mAP: 0.5713
#   [Ours - MLP]
#     AUROC: 0.9509
#     G-mean: 0.8422
#     MCC: 0.6161
#     F1-score: 0.6504
#     mAP: 0.6976
#   [Ours - RandomForest]
#     AUROC: 0.9570
#     G-mean: 0.8145
#     MCC: 0.6303
#     F1-score: 0.6657
#     mAP: 0.7610
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9426
#     G-mean: 0.8768
#     MCC: 0.5701
#     F1-score: 0.5897
#     mAP: 0.6402
#   [Ours - DecisionTree]
#     AUROC: 0.8946
#     G-mean: 0.8237
#     MCC: 0.4923
#     F1-score: 0.5267
#     mAP: 0.4357
#   [Ours - kNN]
#     AUROC: 0.9337
#     G-mean: 0.8679
#     MCC: 0.5816
#     F1-score: 0.6074
#     mAP: 0.5665
#   [Ours - MLP]
#     AUROC: 0.9505
#     G-mean: 0.8381
#     MCC: 0.6128
#     F1-score: 0.6479
#     mAP: 0.6960
#   [Ours - RandomForest]
#     AUROC: 0.9568
#     G-mean: 0.8137
#     MCC: 0.6276
#     F1-score: 0.6636
#     mAP: 0.7605
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9420
#     G-mean: 0.8765
#     MCC: 0.5702
#     F1-score: 0.5900
#     mAP: 0.6419
#   [Ours - DecisionTree]
#     AUROC: 0.8938
#     G-mean: 0.8225
#     MCC: 0.4918
#     F1-score: 0.5265
#     mAP: 0.4341
#   [Ours - kNN]
#     AUROC: 0.9333
#     G-mean: 0.8661
#     MCC: 0.5808
#     F1-score: 0.6071
#     mAP: 0.5651
#   [Ours - MLP]
#     AUROC: 0.9496
#     G-mean: 0.8317
#     MCC: 0.6058
#     F1-score: 0.6421
#     mAP: 0.6965
#   [Ours - RandomForest]
#     AUROC: 0.9567
#     G-mean: 0.8123
#     MCC: 0.6282
#     F1-score: 0.6640
#     mAP: 0.7604
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9417
#     G-mean: 0.8750
#     MCC: 0.5683
#     F1-score: 0.5885
#     mAP: 0.6435
#   [Ours - DecisionTree]
#     AUROC: 0.8926
#     G-mean: 0.8215
#     MCC: 0.4904
#     F1-score: 0.5254
#     mAP: 0.4312
#   [Ours - kNN]
#     AUROC: 0.9339
#     G-mean: 0.8662
#     MCC: 0.5825
#     F1-score: 0.6092
#     mAP: 0.5682
#   [Ours - MLP]
#     AUROC: 0.9497
#     G-mean: 0.8294
#     MCC: 0.6077
#     F1-score: 0.6441
#     mAP: 0.6983
#   [Ours - RandomForest]
#     AUROC: 0.9566
#     G-mean: 0.8124
#     MCC: 0.6278
#     F1-score: 0.6637
#     mAP: 0.7594
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9413
#     G-mean: 0.8733
#     MCC: 0.5662
#     F1-score: 0.5871
#     mAP: 0.6417
#   [Ours - DecisionTree]
#     AUROC: 0.8926
#     G-mean: 0.8228
#     MCC: 0.4908
#     F1-score: 0.5251
#     mAP: 0.4321
#   [Ours - kNN]
#     AUROC: 0.9332
#     G-mean: 0.8650
#     MCC: 0.5801
#     F1-score: 0.6070
#     mAP: 0.5673
#   [Ours - MLP]
#     AUROC: 0.9497
#     G-mean: 0.8316
#     MCC: 0.6100
#     F1-score: 0.6462
#     mAP: 0.6995
#   [Ours - RandomForest]
#     AUROC: 0.9567
#     G-mean: 0.8129
#     MCC: 0.6296
#     F1-score: 0.6650
#     mAP: 0.7600
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9416
#     G-mean: 0.8742
#     MCC: 0.5680
#     F1-score: 0.5887
#     mAP: 0.6425
#   [Ours - DecisionTree]
#     AUROC: 0.8932
#     G-mean: 0.8242
#     MCC: 0.4916
#     F1-score: 0.5255
#     mAP: 0.4315
#   [Ours - kNN]
#     AUROC: 0.9330
#     G-mean: 0.8642
#     MCC: 0.5791
#     F1-score: 0.6063
#     mAP: 0.5677
#   [Ours - MLP]
#     AUROC: 0.9496
#     G-mean: 0.8327
#     MCC: 0.6103
#     F1-score: 0.6464
#     mAP: 0.6989
#   [Ours - RandomForest]
#     AUROC: 0.9570
#     G-mean: 0.8144
#     MCC: 0.6308
#     F1-score: 0.6662
#     mAP: 0.7612
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9414
#     G-mean: 0.8738
#     MCC: 0.5671
#     F1-score: 0.5879
#     mAP: 0.6422
#   [Ours - DecisionTree]
#     AUROC: 0.8931
#     G-mean: 0.8231
#     MCC: 0.4902
#     F1-score: 0.5244
#     mAP: 0.4293
#   [Ours - kNN]
#     AUROC: 0.9327
#     G-mean: 0.8637
#     MCC: 0.5783
#     F1-score: 0.6055
#     mAP: 0.5668
#   [Ours - MLP]
#     AUROC: 0.9495
#     G-mean: 0.8333
#     MCC: 0.6103
#     F1-score: 0.6464
#     mAP: 0.6991
#   [Ours - RandomForest]
#     AUROC: 0.9570
#     G-mean: 0.8140
#     MCC: 0.6307
#     F1-score: 0.6661
#     mAP: 0.7608
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9417
#     G-mean: 0.8742
#     MCC: 0.5677
#     F1-score: 0.5883
#     mAP: 0.6418
#   [Ours - DecisionTree]
#     AUROC: 0.8934
#     G-mean: 0.8229
#     MCC: 0.4890
#     F1-score: 0.5231
#     mAP: 0.4293
#   [Ours - kNN]
#     AUROC: 0.9332
#     G-mean: 0.8649
#     MCC: 0.5789
#     F1-score: 0.6057
#     mAP: 0.5676
#   [Ours - MLP]
#     AUROC: 0.9495
#     G-mean: 0.8338
#     MCC: 0.6089
#     F1-score: 0.6449
#     mAP: 0.6994
#   [Ours - RandomForest]
#     AUROC: 0.9572
#     G-mean: 0.8142
#     MCC: 0.6310
#     F1-score: 0.6664
#     mAP: 0.7607
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9417
#     G-mean: 0.8745
#     MCC: 0.5676
#     F1-score: 0.5880
#     mAP: 0.6406
#   [Ours - DecisionTree]
#     AUROC: 0.8946
#     G-mean: 0.8236
#     MCC: 0.4897
#     F1-score: 0.5235
#     mAP: 0.4290
#   [Ours - kNN]
#     AUROC: 0.9336
#     G-mean: 0.8649
#     MCC: 0.5790
#     F1-score: 0.6059
#     mAP: 0.5677
#   [Ours - MLP]
#     AUROC: 0.9498
#     G-mean: 0.8344
#     MCC: 0.6092
#     F1-score: 0.6452
#     mAP: 0.7003
#   [Ours - RandomForest]
#     AUROC: 0.9572
#     G-mean: 0.8142
#     MCC: 0.6312
#     F1-score: 0.6666
#     mAP: 0.7604
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/satimage_results_gaussian_beta_0.0.csv

# %%
data_name = 'optical_digits'
maj_target_name = -1

n_epochs = 2000
hidden_dims = [64, 32, 16, 8]
latent_dim = 4
lr = 0.001
for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        fetch_data_func=fetch_datasets,
        maj_target_name=maj_target_name,
        methods=methods,
        base_models=base_models,
        device=device,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'pima'
n_epochs = 2000
hidden_dims = [16, 32, 64, 128, 256]
latent_dim = 512
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'segment0'

# 실험 파라미터 설정
n_epochs = 2000
hidden_dims = [32, 64, 128, 256]
latent_dim = 512
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'cleveland-0_vs_4'

n_epochs = 2000
hidden_dims = [16, 32, 64, 128]
latent_dim = 256
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        visualize=False,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )
