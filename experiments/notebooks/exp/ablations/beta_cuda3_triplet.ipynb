# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

# Save path 
save_path = "/data4/oldrain123/oldrain123/results/ablation_results/beta8"
data_path = "/data4/oldrain123/oldrain123/dataset"

# %%
import os
import warnings
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from experiment import run_ablation
from imblearn.datasets import fetch_datasets

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "3"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
data = fetch_datasets()
methods = ["Ours"]
betas = [1e-1, 5e-2, 1e-2, 5e-3, 1e-3, 0.0]
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}

# %%
data_name = 'spectrometer'
maj_target_name = -1

n_epochs = 2000
hidden_dims = [46, 23, 12]
latent_dim = 6
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        fetch_data_func=fetch_datasets,
        maj_target_name=maj_target_name,
        methods=methods,
        base_models=base_models,
        device=device,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )
# Out:
# beta: 0.1
# Dataset loaded: spectrometer
# X shape : (531, 93)
# target : Counter({0: 486, 1: 45})
# IR: 10.8
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.8626
#     G-mean: 0.5204
#     MCC: 0.4505
#     F1-score: 0.4398
#     mAP: 0.7500
#   [Ours - DecisionTree]
#     AUROC: 0.8929
#     G-mean: 0.8814
#     MCC: 0.7666
#     F1-score: 0.7788
#     mAP: 0.6761
#   [Ours - kNN]
#     AUROC: 0.9312
#     G-mean: 0.8177
#     MCC: 0.7962
#     F1-score: 0.7853
#     mAP: 0.8426
#   [Ours - MLP]
#     AUROC: 0.9321
#     G-mean: 0.8977
#     MCC: 0.6682
#     F1-score: 0.6779
#     mAP: 0.8201
#   [Ours - RandomForest]
#     AUROC: 0.9839
#     G-mean: 0.8937
#     MCC: 0.8528
#     F1-score: 0.8579
#     mAP: 0.9169
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.8958
#     G-mean: 0.4696
#     MCC: 0.4186
#     F1-score: 0.3960
#     mAP: 0.7752
#   [Ours - DecisionTree]
#     AUROC: 0.8649
#     G-mean: 0.8492
#     MCC: 0.7211
#     F1-score: 0.7350
#     mAP: 0.6154
#   [Ours - kNN]
#     AUROC: 0.9416
#     G-mean: 0.8288
#     MCC: 0.8078
#     F1-score: 0.7986
#     mAP: 0.8621
#   [Ours - MLP]
#     AUROC: 0.9405
#     G-mean: 0.8923
#     MCC: 0.6781
#     F1-score: 0.6893
#     mAP: 0.8270
#   [Ours - RandomForest]
#     AUROC: 0.9837
#     G-mean: 0.8902
#     MCC: 0.8522
#     F1-score: 0.8544
#     mAP: 0.9161
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9170
#     G-mean: 0.5074
#     MCC: 0.4531
#     F1-score: 0.4299
#     mAP: 0.7702
#   [Ours - DecisionTree]
#     AUROC: 0.8694
#     G-mean: 0.8574
#     MCC: 0.7253
#     F1-score: 0.7405
#     mAP: 0.6183
#   [Ours - kNN]
#     AUROC: 0.9364
#     G-mean: 0.8278
#     MCC: 0.8028
#     F1-score: 0.7950
#     mAP: 0.8521
#   [Ours - MLP]
#     AUROC: 0.9381
#     G-mean: 0.8987
#     MCC: 0.6896
#     F1-score: 0.7019
#     mAP: 0.8368
#   [Ours - RandomForest]
#     AUROC: 0.9866
#     G-mean: 0.8917
#     MCC: 0.8551
#     F1-score: 0.8553
#     mAP: 0.9262
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9234
#     G-mean: 0.5152
#     MCC: 0.4518
#     F1-score: 0.4335
#     mAP: 0.7755
#   [Ours - DecisionTree]
#     AUROC: 0.8595
#     G-mean: 0.8439
#     MCC: 0.7150
#     F1-score: 0.7302
#     mAP: 0.6030
#   [Ours - kNN]
#     AUROC: 0.9346
#     G-mean: 0.8268
#     MCC: 0.8027
#     F1-score: 0.7943
#     mAP: 0.8522
#   [Ours - MLP]
#     AUROC: 0.9346
#     G-mean: 0.8965
#     MCC: 0.6792
#     F1-score: 0.6900
#     mAP: 0.8333
#   [Ours - RandomForest]
#     AUROC: 0.9854
#     G-mean: 0.8927
#     MCC: 0.8531
#     F1-score: 0.8549
#     mAP: 0.9228
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9237
#     G-mean: 0.5523
#     MCC: 0.4893
#     F1-score: 0.4720
#     mAP: 0.7762
#   [Ours - DecisionTree]
#     AUROC: 0.8688
#     G-mean: 0.8545
#     MCC: 0.7286
#     F1-score: 0.7420
#     mAP: 0.6205
#   [Ours - kNN]
#     AUROC: 0.9341
#     G-mean: 0.8286
#     MCC: 0.8046
#     F1-score: 0.7972
#     mAP: 0.8515
#   [Ours - MLP]
#     AUROC: 0.9390
#     G-mean: 0.8973
#     MCC: 0.6781
#     F1-score: 0.6873
#     mAP: 0.8357
#   [Ours - RandomForest]
#     AUROC: 0.9851
#     G-mean: 0.8921
#     MCC: 0.8543
#     F1-score: 0.8563
#     mAP: 0.9236
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9262
#     G-mean: 0.5803
#     MCC: 0.5184
#     F1-score: 0.5020
#     mAP: 0.7805
#   [Ours - DecisionTree]
#     AUROC: 0.8637
#     G-mean: 0.8424
#     MCC: 0.7086
#     F1-score: 0.7242
#     mAP: 0.6028
#   [Ours - kNN]
#     AUROC: 0.9374
#     G-mean: 0.8267
#     MCC: 0.7996
#     F1-score: 0.7922
#     mAP: 0.8560
#   [Ours - MLP]
#     AUROC: 0.9367
#     G-mean: 0.9007
#     MCC: 0.6854
#     F1-score: 0.6947
#     mAP: 0.8331
#   [Ours - RandomForest]
#     AUROC: 0.9851
#     G-mean: 0.8937
#     MCC: 0.8580
#     F1-score: 0.8596
#     mAP: 0.9245
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9175
#     G-mean: 0.5686
#     MCC: 0.5078
#     F1-score: 0.4888
#     mAP: 0.7615
#   [Ours - DecisionTree]
#     AUROC: 0.8669
#     G-mean: 0.8475
#     MCC: 0.7173
#     F1-score: 0.7326
#     mAP: 0.6086
#   [Ours - kNN]
#     AUROC: 0.9384
#     G-mean: 0.8262
#     MCC: 0.8000
#     F1-score: 0.7920
#     mAP: 0.8583
#   [Ours - MLP]
#     AUROC: 0.9377
#     G-mean: 0.8987
#     MCC: 0.6864
#     F1-score: 0.6960
#     mAP: 0.8368
#   [Ours - RandomForest]
#     AUROC: 0.9850
#     G-mean: 0.8926
#     MCC: 0.8557
#     F1-score: 0.8576
#     mAP: 0.9245
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9212
#     G-mean: 0.5757
#     MCC: 0.5136
#     F1-score: 0.4945
#     mAP: 0.7722
#   [Ours - DecisionTree]
#     AUROC: 0.8664
#     G-mean: 0.8476
#     MCC: 0.7167
#     F1-score: 0.7319
#     mAP: 0.6083
#   [Ours - kNN]
#     AUROC: 0.9377
#     G-mean: 0.8252
#     MCC: 0.7979
#     F1-score: 0.7903
#     mAP: 0.8566
#   [Ours - MLP]
#     AUROC: 0.9379
#     G-mean: 0.8997
#     MCC: 0.6846
#     F1-score: 0.6944
#     mAP: 0.8416
#   [Ours - RandomForest]
#     AUROC: 0.9848
#     G-mean: 0.8890
#     MCC: 0.8500
#     F1-score: 0.8519
#     mAP: 0.9250
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9213
#     G-mean: 0.5848
#     MCC: 0.5220
#     F1-score: 0.5011
#     mAP: 0.7726
#   [Ours - DecisionTree]
#     AUROC: 0.8648
#     G-mean: 0.8450
#     MCC: 0.7131
#     F1-score: 0.7266
#     mAP: 0.6040
#   [Ours - kNN]
#     AUROC: 0.9372
#     G-mean: 0.8209
#     MCC: 0.7945
#     F1-score: 0.7857
#     mAP: 0.8571
#   [Ours - MLP]
#     AUROC: 0.9391
#     G-mean: 0.9003
#     MCC: 0.6877
#     F1-score: 0.6981
#     mAP: 0.8454
#   [Ours - RandomForest]
#     AUROC: 0.9847
#     G-mean: 0.8874
#     MCC: 0.8491
#     F1-score: 0.8507
#     mAP: 0.9273
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9180
#     G-mean: 0.5829
#     MCC: 0.5229
#     F1-score: 0.5023
#     mAP: 0.7728
#   [Ours - DecisionTree]
#     AUROC: 0.8614
#     G-mean: 0.8427
#     MCC: 0.7107
#     F1-score: 0.7234
#     mAP: 0.5979
#   [Ours - kNN]
#     AUROC: 0.9370
#     G-mean: 0.8193
#     MCC: 0.7934
#     F1-score: 0.7838
#     mAP: 0.8572
#   [Ours - MLP]
#     AUROC: 0.9382
#     G-mean: 0.8983
#     MCC: 0.6869
#     F1-score: 0.6977
#     mAP: 0.8471
#   [Ours - RandomForest]
#     AUROC: 0.9853
#     G-mean: 0.8886
#     MCC: 0.8499
#     F1-score: 0.8510
#     mAP: 0.9297
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/spectrometer_results_gaussian_beta_0.1.csv
# beta: 0.05
# Dataset loaded: spectrometer
# X shape : (531, 93)
# target : Counter({0: 486, 1: 45})
# IR: 10.8
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9641
#     G-mean: 0.9000
#     MCC: 0.6599
#     F1-score: 0.6708
#     mAP: 0.9019
#   [Ours - DecisionTree]
#     AUROC: 0.8967
#     G-mean: 0.8869
#     MCC: 0.7164
#     F1-score: 0.7337
#     mAP: 0.6174
#   [Ours - kNN]
#     AUROC: 0.9391
#     G-mean: 0.8564
#     MCC: 0.8132
#     F1-score: 0.8159
#     mAP: 0.8192
#   [Ours - MLP]
#     AUROC: 0.9420
#     G-mean: 0.9202
#     MCC: 0.7032
#     F1-score: 0.7078
#     mAP: 0.8561
#   [Ours - RandomForest]
#     AUROC: 0.9830
#     G-mean: 0.8931
#     MCC: 0.8630
#     F1-score: 0.8659
#     mAP: 0.9309
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9635
#     G-mean: 0.8950
#     MCC: 0.6691
#     F1-score: 0.6835
#     mAP: 0.8884
#   [Ours - DecisionTree]
#     AUROC: 0.8655
#     G-mean: 0.8417
#     MCC: 0.6714
#     F1-score: 0.6861
#     mAP: 0.5569
#   [Ours - kNN]
#     AUROC: 0.9387
#     G-mean: 0.8718
#     MCC: 0.8252
#     F1-score: 0.8283
#     mAP: 0.8357
#   [Ours - MLP]
#     AUROC: 0.9480
#     G-mean: 0.9171
#     MCC: 0.7047
#     F1-score: 0.7127
#     mAP: 0.8655
#   [Ours - RandomForest]
#     AUROC: 0.9809
#     G-mean: 0.8862
#     MCC: 0.8458
#     F1-score: 0.8453
#     mAP: 0.9221
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9652
#     G-mean: 0.8965
#     MCC: 0.6708
#     F1-score: 0.6842
#     mAP: 0.8883
#   [Ours - DecisionTree]
#     AUROC: 0.8624
#     G-mean: 0.8427
#     MCC: 0.6730
#     F1-score: 0.6896
#     mAP: 0.5615
#   [Ours - kNN]
#     AUROC: 0.9386
#     G-mean: 0.8652
#     MCC: 0.8245
#     F1-score: 0.8244
#     mAP: 0.8367
#   [Ours - MLP]
#     AUROC: 0.9499
#     G-mean: 0.9142
#     MCC: 0.7026
#     F1-score: 0.7124
#     mAP: 0.8629
#   [Ours - RandomForest]
#     AUROC: 0.9824
#     G-mean: 0.8843
#     MCC: 0.8460
#     F1-score: 0.8433
#     mAP: 0.9216
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9663
#     G-mean: 0.9001
#     MCC: 0.6778
#     F1-score: 0.6909
#     mAP: 0.8911
#   [Ours - DecisionTree]
#     AUROC: 0.8661
#     G-mean: 0.8495
#     MCC: 0.6786
#     F1-score: 0.6959
#     mAP: 0.5693
#   [Ours - kNN]
#     AUROC: 0.9414
#     G-mean: 0.8697
#     MCC: 0.8273
#     F1-score: 0.8284
#     mAP: 0.8405
#   [Ours - MLP]
#     AUROC: 0.9484
#     G-mean: 0.9117
#     MCC: 0.6977
#     F1-score: 0.7064
#     mAP: 0.8564
#   [Ours - RandomForest]
#     AUROC: 0.9829
#     G-mean: 0.8905
#     MCC: 0.8508
#     F1-score: 0.8500
#     mAP: 0.9216
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9678
#     G-mean: 0.9013
#     MCC: 0.6851
#     F1-score: 0.6985
#     mAP: 0.8930
#   [Ours - DecisionTree]
#     AUROC: 0.8601
#     G-mean: 0.8438
#     MCC: 0.6659
#     F1-score: 0.6848
#     mAP: 0.5549
#   [Ours - kNN]
#     AUROC: 0.9413
#     G-mean: 0.8671
#     MCC: 0.8226
#     F1-score: 0.8244
#     mAP: 0.8402
#   [Ours - MLP]
#     AUROC: 0.9503
#     G-mean: 0.9122
#     MCC: 0.7024
#     F1-score: 0.7113
#     mAP: 0.8630
#   [Ours - RandomForest]
#     AUROC: 0.9833
#     G-mean: 0.8893
#     MCC: 0.8496
#     F1-score: 0.8499
#     mAP: 0.9180
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9660
#     G-mean: 0.9018
#     MCC: 0.6868
#     F1-score: 0.7005
#     mAP: 0.8912
#   [Ours - DecisionTree]
#     AUROC: 0.8633
#     G-mean: 0.8460
#     MCC: 0.6698
#     F1-score: 0.6883
#     mAP: 0.5653
#   [Ours - kNN]
#     AUROC: 0.9410
#     G-mean: 0.8661
#     MCC: 0.8182
#     F1-score: 0.8200
#     mAP: 0.8386
#   [Ours - MLP]
#     AUROC: 0.9490
#     G-mean: 0.9137
#     MCC: 0.7016
#     F1-score: 0.7104
#     mAP: 0.8576
#   [Ours - RandomForest]
#     AUROC: 0.9830
#     G-mean: 0.8889
#     MCC: 0.8502
#     F1-score: 0.8497
#     mAP: 0.9206
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9645
#     G-mean: 0.9045
#     MCC: 0.6974
#     F1-score: 0.7107
#     mAP: 0.8894
#   [Ours - DecisionTree]
#     AUROC: 0.8651
#     G-mean: 0.8462
#     MCC: 0.6746
#     F1-score: 0.6926
#     mAP: 0.5695
#   [Ours - kNN]
#     AUROC: 0.9426
#     G-mean: 0.8676
#     MCC: 0.8208
#     F1-score: 0.8228
#     mAP: 0.8408
#   [Ours - MLP]
#     AUROC: 0.9506
#     G-mean: 0.9157
#     MCC: 0.7089
#     F1-score: 0.7172
#     mAP: 0.8586
#   [Ours - RandomForest]
#     AUROC: 0.9836
#     G-mean: 0.8903
#     MCC: 0.8513
#     F1-score: 0.8511
#     mAP: 0.9194
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9645
#     G-mean: 0.9059
#     MCC: 0.6978
#     F1-score: 0.7111
#     mAP: 0.8908
#   [Ours - DecisionTree]
#     AUROC: 0.8614
#     G-mean: 0.8397
#     MCC: 0.6660
#     F1-score: 0.6844
#     mAP: 0.5633
#   [Ours - kNN]
#     AUROC: 0.9430
#     G-mean: 0.8703
#     MCC: 0.8255
#     F1-score: 0.8272
#     mAP: 0.8442
#   [Ours - MLP]
#     AUROC: 0.9523
#     G-mean: 0.9162
#     MCC: 0.7079
#     F1-score: 0.7162
#     mAP: 0.8633
#   [Ours - RandomForest]
#     AUROC: 0.9834
#     G-mean: 0.8904
#     MCC: 0.8503
#     F1-score: 0.8508
#     mAP: 0.9194
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9643
#     G-mean: 0.9055
#     MCC: 0.6965
#     F1-score: 0.7095
#     mAP: 0.8931
#   [Ours - DecisionTree]
#     AUROC: 0.8585
#     G-mean: 0.8367
#     MCC: 0.6626
#     F1-score: 0.6802
#     mAP: 0.5605
#   [Ours - kNN]
#     AUROC: 0.9417
#     G-mean: 0.8638
#     MCC: 0.8198
#     F1-score: 0.8198
#     mAP: 0.8447
#   [Ours - MLP]
#     AUROC: 0.9517
#     G-mean: 0.9191
#     MCC: 0.7145
#     F1-score: 0.7230
#     mAP: 0.8656
#   [Ours - RandomForest]
#     AUROC: 0.9828
#     G-mean: 0.8871
#     MCC: 0.8484
#     F1-score: 0.8484
#     mAP: 0.9220
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9652
#     G-mean: 0.9068
#     MCC: 0.7006
#     F1-score: 0.7132
#     mAP: 0.8922
#   [Ours - DecisionTree]
#     AUROC: 0.8559
#     G-mean: 0.8334
#     MCC: 0.6590
#     F1-score: 0.6775
#     mAP: 0.5555
#   [Ours - kNN]
#     AUROC: 0.9409
#     G-mean: 0.8575
#     MCC: 0.8149
#     F1-score: 0.8132
#     mAP: 0.8436
#   [Ours - MLP]
#     AUROC: 0.9509
#     G-mean: 0.9170
#     MCC: 0.7113
#     F1-score: 0.7194
#     mAP: 0.8670
#   [Ours - RandomForest]
#     AUROC: 0.9834
#     G-mean: 0.8898
#     MCC: 0.8515
#     F1-score: 0.8518
#     mAP: 0.9244
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/spectrometer_results_gaussian_beta_0.05.csv
# beta: 0.01
# Dataset loaded: spectrometer
# X shape : (531, 93)
# target : Counter({0: 486, 1: 45})
# IR: 10.8
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9775
#     G-mean: 0.9345
#     MCC: 0.7695
#     F1-score: 0.7788
#     mAP: 0.9095
#   [Ours - DecisionTree]
#     AUROC: 0.8717
#     G-mean: 0.8498
#     MCC: 0.6687
#     F1-score: 0.6924
#     mAP: 0.5446
#   [Ours - kNN]
#     AUROC: 0.9486
#     G-mean: 0.8984
#     MCC: 0.8294
#     F1-score: 0.8370
#     mAP: 0.8585
#   [Ours - MLP]
#     AUROC: 0.9590
#     G-mean: 0.9256
#     MCC: 0.7410
#     F1-score: 0.7474
#     mAP: 0.9024
#   [Ours - RandomForest]
#     AUROC: 0.9871
#     G-mean: 0.9190
#     MCC: 0.8378
#     F1-score: 0.8458
#     mAP: 0.8877
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9788
#     G-mean: 0.9384
#     MCC: 0.7738
#     F1-score: 0.7821
#     mAP: 0.9067
#   [Ours - DecisionTree]
#     AUROC: 0.8549
#     G-mean: 0.8383
#     MCC: 0.6720
#     F1-score: 0.6921
#     mAP: 0.5505
#   [Ours - kNN]
#     AUROC: 0.9429
#     G-mean: 0.9014
#     MCC: 0.8258
#     F1-score: 0.8323
#     mAP: 0.8474
#   [Ours - MLP]
#     AUROC: 0.9563
#     G-mean: 0.9171
#     MCC: 0.7126
#     F1-score: 0.7210
#     mAP: 0.8891
#   [Ours - RandomForest]
#     AUROC: 0.9830
#     G-mean: 0.9125
#     MCC: 0.8434
#     F1-score: 0.8472
#     mAP: 0.8925
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9817
#     G-mean: 0.9359
#     MCC: 0.7699
#     F1-score: 0.7785
#     mAP: 0.9143
#   [Ours - DecisionTree]
#     AUROC: 0.8502
#     G-mean: 0.8341
#     MCC: 0.6547
#     F1-score: 0.6733
#     mAP: 0.5338
#   [Ours - kNN]
#     AUROC: 0.9475
#     G-mean: 0.9019
#     MCC: 0.8261
#     F1-score: 0.8315
#     mAP: 0.8422
#   [Ours - MLP]
#     AUROC: 0.9538
#     G-mean: 0.9167
#     MCC: 0.7074
#     F1-score: 0.7160
#     mAP: 0.8890
#   [Ours - RandomForest]
#     AUROC: 0.9865
#     G-mean: 0.9151
#     MCC: 0.8522
#     F1-score: 0.8559
#     mAP: 0.9073
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9798
#     G-mean: 0.9368
#     MCC: 0.7671
#     F1-score: 0.7753
#     mAP: 0.9097
#   [Ours - DecisionTree]
#     AUROC: 0.8569
#     G-mean: 0.8314
#     MCC: 0.6468
#     F1-score: 0.6638
#     mAP: 0.5314
#   [Ours - kNN]
#     AUROC: 0.9530
#     G-mean: 0.9021
#     MCC: 0.8302
#     F1-score: 0.8354
#     mAP: 0.8461
#   [Ours - MLP]
#     AUROC: 0.9501
#     G-mean: 0.9108
#     MCC: 0.7004
#     F1-score: 0.7091
#     mAP: 0.8844
#   [Ours - RandomForest]
#     AUROC: 0.9857
#     G-mean: 0.9156
#     MCC: 0.8551
#     F1-score: 0.8590
#     mAP: 0.9103
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9791
#     G-mean: 0.9363
#     MCC: 0.7685
#     F1-score: 0.7769
#     mAP: 0.9101
#   [Ours - DecisionTree]
#     AUROC: 0.8468
#     G-mean: 0.8211
#     MCC: 0.6346
#     F1-score: 0.6536
#     mAP: 0.5158
#   [Ours - kNN]
#     AUROC: 0.9501
#     G-mean: 0.9029
#     MCC: 0.8302
#     F1-score: 0.8347
#     mAP: 0.8410
#   [Ours - MLP]
#     AUROC: 0.9492
#     G-mean: 0.9163
#     MCC: 0.7099
#     F1-score: 0.7184
#     mAP: 0.8860
#   [Ours - RandomForest]
#     AUROC: 0.9833
#     G-mean: 0.9187
#     MCC: 0.8529
#     F1-score: 0.8574
#     mAP: 0.9042
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9782
#     G-mean: 0.9362
#     MCC: 0.7694
#     F1-score: 0.7776
#     mAP: 0.9138
#   [Ours - DecisionTree]
#     AUROC: 0.8521
#     G-mean: 0.8239
#     MCC: 0.6332
#     F1-score: 0.6531
#     mAP: 0.5179
#   [Ours - kNN]
#     AUROC: 0.9508
#     G-mean: 0.9042
#     MCC: 0.8339
#     F1-score: 0.8373
#     mAP: 0.8444
#   [Ours - MLP]
#     AUROC: 0.9498
#     G-mean: 0.9187
#     MCC: 0.7168
#     F1-score: 0.7252
#     mAP: 0.8874
#   [Ours - RandomForest]
#     AUROC: 0.9827
#     G-mean: 0.9187
#     MCC: 0.8482
#     F1-score: 0.8528
#     mAP: 0.9063
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9781
#     G-mean: 0.9357
#     MCC: 0.7695
#     F1-score: 0.7774
#     mAP: 0.9119
#   [Ours - DecisionTree]
#     AUROC: 0.8549
#     G-mean: 0.8292
#     MCC: 0.6438
#     F1-score: 0.6619
#     mAP: 0.5272
#   [Ours - kNN]
#     AUROC: 0.9511
#     G-mean: 0.9072
#     MCC: 0.8408
#     F1-score: 0.8447
#     mAP: 0.8467
#   [Ours - MLP]
#     AUROC: 0.9502
#     G-mean: 0.9185
#     MCC: 0.7162
#     F1-score: 0.7251
#     mAP: 0.8850
#   [Ours - RandomForest]
#     AUROC: 0.9830
#     G-mean: 0.9175
#     MCC: 0.8458
#     F1-score: 0.8514
#     mAP: 0.9036
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9787
#     G-mean: 0.9372
#     MCC: 0.7722
#     F1-score: 0.7804
#     mAP: 0.9136
#   [Ours - DecisionTree]
#     AUROC: 0.8548
#     G-mean: 0.8317
#     MCC: 0.6510
#     F1-score: 0.6684
#     mAP: 0.5336
#   [Ours - kNN]
#     AUROC: 0.9525
#     G-mean: 0.9076
#     MCC: 0.8406
#     F1-score: 0.8453
#     mAP: 0.8489
#   [Ours - MLP]
#     AUROC: 0.9510
#     G-mean: 0.9194
#     MCC: 0.7207
#     F1-score: 0.7296
#     mAP: 0.8863
#   [Ours - RandomForest]
#     AUROC: 0.9837
#     G-mean: 0.9165
#     MCC: 0.8431
#     F1-score: 0.8492
#     mAP: 0.9048
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9777
#     G-mean: 0.9342
#     MCC: 0.7681
#     F1-score: 0.7767
#     mAP: 0.9136
#   [Ours - DecisionTree]
#     AUROC: 0.8606
#     G-mean: 0.8389
#     MCC: 0.6604
#     F1-score: 0.6776
#     mAP: 0.5475
#   [Ours - kNN]
#     AUROC: 0.9517
#     G-mean: 0.9048
#     MCC: 0.8364
#     F1-score: 0.8411
#     mAP: 0.8474
#   [Ours - MLP]
#     AUROC: 0.9501
#     G-mean: 0.9170
#     MCC: 0.7172
#     F1-score: 0.7264
#     mAP: 0.8857
#   [Ours - RandomForest]
#     AUROC: 0.9832
#     G-mean: 0.9157
#     MCC: 0.8435
#     F1-score: 0.8494
#     mAP: 0.9052
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9774
#     G-mean: 0.9327
#     MCC: 0.7649
#     F1-score: 0.7737
#     mAP: 0.9109
#   [Ours - DecisionTree]
#     AUROC: 0.8623
#     G-mean: 0.8412
#     MCC: 0.6657
#     F1-score: 0.6825
#     mAP: 0.5553
#   [Ours - kNN]
#     AUROC: 0.9515
#     G-mean: 0.9007
#     MCC: 0.8325
#     F1-score: 0.8364
#     mAP: 0.8471
#   [Ours - MLP]
#     AUROC: 0.9495
#     G-mean: 0.9155
#     MCC: 0.7165
#     F1-score: 0.7255
#     mAP: 0.8870
#   [Ours - RandomForest]
#     AUROC: 0.9834
#     G-mean: 0.9179
#     MCC: 0.8479
#     F1-score: 0.8538
#     mAP: 0.9060
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/spectrometer_results_gaussian_beta_0.01.csv
# beta: 0.005
# Dataset loaded: spectrometer
# X shape : (531, 93)
# target : Counter({0: 486, 1: 45})
# IR: 10.8
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9824
#     G-mean: 0.9465
#     MCC: 0.7920
#     F1-score: 0.8000
#     mAP: 0.9252
#   [Ours - DecisionTree]
#     AUROC: 0.8634
#     G-mean: 0.8504
#     MCC: 0.6244
#     F1-score: 0.6488
#     mAP: 0.5413
#   [Ours - kNN]
#     AUROC: 0.9592
#     G-mean: 0.9051
#     MCC: 0.8778
#     F1-score: 0.8816
#     mAP: 0.8775
#   [Ours - MLP]
#     AUROC: 0.9598
#     G-mean: 0.9186
#     MCC: 0.7405
#     F1-score: 0.7499
#     mAP: 0.8961
#   [Ours - RandomForest]
#     AUROC: 0.9851
#     G-mean: 0.9410
#     MCC: 0.8415
#     F1-score: 0.8488
#     mAP: 0.8750
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9835
#     G-mean: 0.9460
#     MCC: 0.7954
#     F1-score: 0.8034
#     mAP: 0.9210
#   [Ours - DecisionTree]
#     AUROC: 0.8712
#     G-mean: 0.8540
#     MCC: 0.6482
#     F1-score: 0.6702
#     mAP: 0.5551
#   [Ours - kNN]
#     AUROC: 0.9594
#     G-mean: 0.9087
#     MCC: 0.8721
#     F1-score: 0.8762
#     mAP: 0.8839
#   [Ours - MLP]
#     AUROC: 0.9560
#     G-mean: 0.9199
#     MCC: 0.7230
#     F1-score: 0.7323
#     mAP: 0.8876
#   [Ours - RandomForest]
#     AUROC: 0.9829
#     G-mean: 0.9402
#     MCC: 0.8455
#     F1-score: 0.8513
#     mAP: 0.8794
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9847
#     G-mean: 0.9454
#     MCC: 0.7887
#     F1-score: 0.7966
#     mAP: 0.9247
#   [Ours - DecisionTree]
#     AUROC: 0.8836
#     G-mean: 0.8593
#     MCC: 0.6620
#     F1-score: 0.6800
#     mAP: 0.5713
#   [Ours - kNN]
#     AUROC: 0.9559
#     G-mean: 0.9168
#     MCC: 0.8724
#     F1-score: 0.8773
#     mAP: 0.8781
#   [Ours - MLP]
#     AUROC: 0.9535
#     G-mean: 0.9241
#     MCC: 0.7179
#     F1-score: 0.7266
#     mAP: 0.8867
#   [Ours - RandomForest]
#     AUROC: 0.9845
#     G-mean: 0.9282
#     MCC: 0.8352
#     F1-score: 0.8414
#     mAP: 0.8925
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9844
#     G-mean: 0.9389
#     MCC: 0.7767
#     F1-score: 0.7853
#     mAP: 0.9240
#   [Ours - DecisionTree]
#     AUROC: 0.8824
#     G-mean: 0.8641
#     MCC: 0.6643
#     F1-score: 0.6811
#     mAP: 0.5768
#   [Ours - kNN]
#     AUROC: 0.9566
#     G-mean: 0.9125
#     MCC: 0.8567
#     F1-score: 0.8628
#     mAP: 0.8696
#   [Ours - MLP]
#     AUROC: 0.9518
#     G-mean: 0.9123
#     MCC: 0.7026
#     F1-score: 0.7113
#     mAP: 0.8793
#   [Ours - RandomForest]
#     AUROC: 0.9848
#     G-mean: 0.9279
#     MCC: 0.8361
#     F1-score: 0.8434
#     mAP: 0.8995
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9852
#     G-mean: 0.9402
#     MCC: 0.7780
#     F1-score: 0.7868
#     mAP: 0.9244
#   [Ours - DecisionTree]
#     AUROC: 0.8763
#     G-mean: 0.8562
#     MCC: 0.6484
#     F1-score: 0.6672
#     mAP: 0.5602
#   [Ours - kNN]
#     AUROC: 0.9548
#     G-mean: 0.9144
#     MCC: 0.8561
#     F1-score: 0.8629
#     mAP: 0.8627
#   [Ours - MLP]
#     AUROC: 0.9510
#     G-mean: 0.9141
#     MCC: 0.7066
#     F1-score: 0.7149
#     mAP: 0.8813
#   [Ours - RandomForest]
#     AUROC: 0.9850
#     G-mean: 0.9234
#     MCC: 0.8307
#     F1-score: 0.8393
#     mAP: 0.9008
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9854
#     G-mean: 0.9416
#     MCC: 0.7823
#     F1-score: 0.7908
#     mAP: 0.9265
#   [Ours - DecisionTree]
#     AUROC: 0.8863
#     G-mean: 0.8669
#     MCC: 0.6593
#     F1-score: 0.6753
#     mAP: 0.5689
#   [Ours - kNN]
#     AUROC: 0.9562
#     G-mean: 0.9053
#     MCC: 0.8455
#     F1-score: 0.8511
#     mAP: 0.8636
#   [Ours - MLP]
#     AUROC: 0.9502
#     G-mean: 0.9183
#     MCC: 0.7132
#     F1-score: 0.7210
#     mAP: 0.8813
#   [Ours - RandomForest]
#     AUROC: 0.9859
#     G-mean: 0.9223
#     MCC: 0.8267
#     F1-score: 0.8342
#     mAP: 0.9062
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9855
#     G-mean: 0.9421
#     MCC: 0.7831
#     F1-score: 0.7908
#     mAP: 0.9244
#   [Ours - DecisionTree]
#     AUROC: 0.8759
#     G-mean: 0.8577
#     MCC: 0.6468
#     F1-score: 0.6635
#     mAP: 0.5497
#   [Ours - kNN]
#     AUROC: 0.9544
#     G-mean: 0.9047
#     MCC: 0.8442
#     F1-score: 0.8501
#     mAP: 0.8627
#   [Ours - MLP]
#     AUROC: 0.9508
#     G-mean: 0.9208
#     MCC: 0.7131
#     F1-score: 0.7208
#     mAP: 0.8791
#   [Ours - RandomForest]
#     AUROC: 0.9851
#     G-mean: 0.9218
#     MCC: 0.8242
#     F1-score: 0.8323
#     mAP: 0.9026
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9851
#     G-mean: 0.9427
#     MCC: 0.7841
#     F1-score: 0.7921
#     mAP: 0.9246
#   [Ours - DecisionTree]
#     AUROC: 0.8789
#     G-mean: 0.8599
#     MCC: 0.6543
#     F1-score: 0.6712
#     mAP: 0.5600
#   [Ours - kNN]
#     AUROC: 0.9554
#     G-mean: 0.9070
#     MCC: 0.8448
#     F1-score: 0.8511
#     mAP: 0.8625
#   [Ours - MLP]
#     AUROC: 0.9515
#     G-mean: 0.9211
#     MCC: 0.7155
#     F1-score: 0.7235
#     mAP: 0.8811
#   [Ours - RandomForest]
#     AUROC: 0.9855
#     G-mean: 0.9218
#     MCC: 0.8259
#     F1-score: 0.8346
#     mAP: 0.9036
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9842
#     G-mean: 0.9428
#     MCC: 0.7834
#     F1-score: 0.7914
#     mAP: 0.9252
#   [Ours - DecisionTree]
#     AUROC: 0.8780
#     G-mean: 0.8606
#     MCC: 0.6561
#     F1-score: 0.6727
#     mAP: 0.5554
#   [Ours - kNN]
#     AUROC: 0.9558
#     G-mean: 0.9053
#     MCC: 0.8416
#     F1-score: 0.8476
#     mAP: 0.8635
#   [Ours - MLP]
#     AUROC: 0.9507
#     G-mean: 0.9196
#     MCC: 0.7122
#     F1-score: 0.7201
#     mAP: 0.8819
#   [Ours - RandomForest]
#     AUROC: 0.9849
#     G-mean: 0.9213
#     MCC: 0.8252
#     F1-score: 0.8336
#     mAP: 0.9038
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9840
#     G-mean: 0.9434
#     MCC: 0.7859
#     F1-score: 0.7940
#     mAP: 0.9254
#   [Ours - DecisionTree]
#     AUROC: 0.8751
#     G-mean: 0.8583
#     MCC: 0.6536
#     F1-score: 0.6695
#     mAP: 0.5536
#   [Ours - kNN]
#     AUROC: 0.9545
#     G-mean: 0.9049
#     MCC: 0.8419
#     F1-score: 0.8479
#     mAP: 0.8643
#   [Ours - MLP]
#     AUROC: 0.9502
#     G-mean: 0.9188
#     MCC: 0.7116
#     F1-score: 0.7195
#     mAP: 0.8831
#   [Ours - RandomForest]
#     AUROC: 0.9846
#     G-mean: 0.9222
#     MCC: 0.8255
#     F1-score: 0.8343
#     mAP: 0.9037
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/spectrometer_results_gaussian_beta_0.005.csv
# beta: 0.001
# Dataset loaded: spectrometer
# X shape : (531, 93)
# target : Counter({0: 486, 1: 45})
# IR: 10.8
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9854
#     G-mean: 0.9474
#     MCC: 0.7943
#     F1-score: 0.8024
#     mAP: 0.9400
#   [Ours - DecisionTree]
#     AUROC: 0.8374
#     G-mean: 0.8202
#     MCC: 0.5350
#     F1-score: 0.5650
#     mAP: 0.3992
#   [Ours - kNN]
#     AUROC: 0.9493
#     G-mean: 0.8893
#     MCC: 0.8224
#     F1-score: 0.8297
#     mAP: 0.8785
#   [Ours - MLP]
#     AUROC: 0.9633
#     G-mean: 0.9343
#     MCC: 0.7420
#     F1-score: 0.7446
#     mAP: 0.9003
#   [Ours - RandomForest]
#     AUROC: 0.9858
#     G-mean: 0.9263
#     MCC: 0.8023
#     F1-score: 0.8166
#     mAP: 0.8811
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9842
#     G-mean: 0.9536
#     MCC: 0.8071
#     F1-score: 0.8146
#     mAP: 0.9277
#   [Ours - DecisionTree]
#     AUROC: 0.8386
#     G-mean: 0.8322
#     MCC: 0.5699
#     F1-score: 0.5930
#     mAP: 0.4370
#   [Ours - kNN]
#     AUROC: 0.9506
#     G-mean: 0.8826
#     MCC: 0.8330
#     F1-score: 0.8375
#     mAP: 0.8790
#   [Ours - MLP]
#     AUROC: 0.9577
#     G-mean: 0.9298
#     MCC: 0.7400
#     F1-score: 0.7454
#     mAP: 0.8952
#   [Ours - RandomForest]
#     AUROC: 0.9866
#     G-mean: 0.9328
#     MCC: 0.8258
#     F1-score: 0.8352
#     mAP: 0.8973
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9853
#     G-mean: 0.9542
#     MCC: 0.8040
#     F1-score: 0.8105
#     mAP: 0.9275
#   [Ours - DecisionTree]
#     AUROC: 0.8446
#     G-mean: 0.8453
#     MCC: 0.6090
#     F1-score: 0.6304
#     mAP: 0.4798
#   [Ours - kNN]
#     AUROC: 0.9535
#     G-mean: 0.8857
#     MCC: 0.8322
#     F1-score: 0.8369
#     mAP: 0.8796
#   [Ours - MLP]
#     AUROC: 0.9538
#     G-mean: 0.9309
#     MCC: 0.7328
#     F1-score: 0.7390
#     mAP: 0.8908
#   [Ours - RandomForest]
#     AUROC: 0.9877
#     G-mean: 0.9347
#     MCC: 0.8303
#     F1-score: 0.8389
#     mAP: 0.8999
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9866
#     G-mean: 0.9492
#     MCC: 0.7981
#     F1-score: 0.8056
#     mAP: 0.9315
#   [Ours - DecisionTree]
#     AUROC: 0.8496
#     G-mean: 0.8538
#     MCC: 0.6180
#     F1-score: 0.6384
#     mAP: 0.5031
#   [Ours - kNN]
#     AUROC: 0.9542
#     G-mean: 0.8854
#     MCC: 0.8240
#     F1-score: 0.8293
#     mAP: 0.8729
#   [Ours - MLP]
#     AUROC: 0.9526
#     G-mean: 0.9238
#     MCC: 0.7232
#     F1-score: 0.7294
#     mAP: 0.8853
#   [Ours - RandomForest]
#     AUROC: 0.9881
#     G-mean: 0.9345
#     MCC: 0.8269
#     F1-score: 0.8356
#     mAP: 0.9072
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9862
#     G-mean: 0.9489
#     MCC: 0.7988
#     F1-score: 0.8068
#     mAP: 0.9300
#   [Ours - DecisionTree]
#     AUROC: 0.8411
#     G-mean: 0.8473
#     MCC: 0.6149
#     F1-score: 0.6354
#     mAP: 0.4954
#   [Ours - kNN]
#     AUROC: 0.9531
#     G-mean: 0.8898
#     MCC: 0.8251
#     F1-score: 0.8320
#     mAP: 0.8701
#   [Ours - MLP]
#     AUROC: 0.9532
#     G-mean: 0.9218
#     MCC: 0.7224
#     F1-score: 0.7295
#     mAP: 0.8861
#   [Ours - RandomForest]
#     AUROC: 0.9881
#     G-mean: 0.9366
#     MCC: 0.8311
#     F1-score: 0.8402
#     mAP: 0.9098
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9853
#     G-mean: 0.9470
#     MCC: 0.7963
#     F1-score: 0.8044
#     mAP: 0.9301
#   [Ours - DecisionTree]
#     AUROC: 0.8455
#     G-mean: 0.8463
#     MCC: 0.6069
#     F1-score: 0.6276
#     mAP: 0.4904
#   [Ours - kNN]
#     AUROC: 0.9531
#     G-mean: 0.8916
#     MCC: 0.8298
#     F1-score: 0.8352
#     mAP: 0.8723
#   [Ours - MLP]
#     AUROC: 0.9513
#     G-mean: 0.9232
#     MCC: 0.7239
#     F1-score: 0.7315
#     mAP: 0.8842
#   [Ours - RandomForest]
#     AUROC: 0.9883
#     G-mean: 0.9357
#     MCC: 0.8328
#     F1-score: 0.8412
#     mAP: 0.9139
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9855
#     G-mean: 0.9471
#     MCC: 0.7984
#     F1-score: 0.8058
#     mAP: 0.9286
#   [Ours - DecisionTree]
#     AUROC: 0.8449
#     G-mean: 0.8423
#     MCC: 0.6036
#     F1-score: 0.6238
#     mAP: 0.4888
#   [Ours - kNN]
#     AUROC: 0.9542
#     G-mean: 0.8949
#     MCC: 0.8324
#     F1-score: 0.8375
#     mAP: 0.8702
#   [Ours - MLP]
#     AUROC: 0.9518
#     G-mean: 0.9225
#     MCC: 0.7232
#     F1-score: 0.7314
#     mAP: 0.8805
#   [Ours - RandomForest]
#     AUROC: 0.9887
#     G-mean: 0.9368
#     MCC: 0.8349
#     F1-score: 0.8437
#     mAP: 0.9154
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9855
#     G-mean: 0.9483
#     MCC: 0.7974
#     F1-score: 0.8048
#     mAP: 0.9289
#   [Ours - DecisionTree]
#     AUROC: 0.8462
#     G-mean: 0.8449
#     MCC: 0.6121
#     F1-score: 0.6327
#     mAP: 0.5044
#   [Ours - kNN]
#     AUROC: 0.9552
#     G-mean: 0.8922
#     MCC: 0.8301
#     F1-score: 0.8354
#     mAP: 0.8700
#   [Ours - MLP]
#     AUROC: 0.9530
#     G-mean: 0.9244
#     MCC: 0.7265
#     F1-score: 0.7349
#     mAP: 0.8830
#   [Ours - RandomForest]
#     AUROC: 0.9885
#     G-mean: 0.9380
#     MCC: 0.8393
#     F1-score: 0.8482
#     mAP: 0.9150
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9845
#     G-mean: 0.9467
#     MCC: 0.7942
#     F1-score: 0.8019
#     mAP: 0.9285
#   [Ours - DecisionTree]
#     AUROC: 0.8486
#     G-mean: 0.8457
#     MCC: 0.6115
#     F1-score: 0.6327
#     mAP: 0.5069
#   [Ours - kNN]
#     AUROC: 0.9544
#     G-mean: 0.8893
#     MCC: 0.8283
#     F1-score: 0.8325
#     mAP: 0.8699
#   [Ours - MLP]
#     AUROC: 0.9518
#     G-mean: 0.9232
#     MCC: 0.7250
#     F1-score: 0.7335
#     mAP: 0.8845
#   [Ours - RandomForest]
#     AUROC: 0.9878
#     G-mean: 0.9367
#     MCC: 0.8342
#     F1-score: 0.8431
#     mAP: 0.9151
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9847
#     G-mean: 0.9475
#     MCC: 0.7943
#     F1-score: 0.8016
#     mAP: 0.9297
#   [Ours - DecisionTree]
#     AUROC: 0.8504
#     G-mean: 0.8467
#     MCC: 0.6169
#     F1-score: 0.6368
#     mAP: 0.5097
#   [Ours - kNN]
#     AUROC: 0.9548
#     G-mean: 0.8860
#     MCC: 0.8240
#     F1-score: 0.8282
#     mAP: 0.8690
#   [Ours - MLP]
#     AUROC: 0.9517
#     G-mean: 0.9248
#     MCC: 0.7264
#     F1-score: 0.7348
#     mAP: 0.8865
#   [Ours - RandomForest]
#     AUROC: 0.9881
#     G-mean: 0.9360
#     MCC: 0.8325
#     F1-score: 0.8418
#     mAP: 0.9173
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/spectrometer_results_gaussian_beta_0.001.csv
# beta: 0.0
# Dataset loaded: spectrometer
# X shape : (531, 93)
# target : Counter({0: 486, 1: 45})
# IR: 10.8
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9843
#     G-mean: 0.9484
#     MCC: 0.8010
#     F1-score: 0.8097
#     mAP: 0.9306
#   [Ours - DecisionTree]
#     AUROC: 0.8250
#     G-mean: 0.8012
#     MCC: 0.5453
#     F1-score: 0.5758
#     mAP: 0.4749
#   [Ours - kNN]
#     AUROC: 0.9388
#     G-mean: 0.8930
#     MCC: 0.8643
#     F1-score: 0.8655
#     mAP: 0.8688
#   [Ours - MLP]
#     AUROC: 0.9630
#     G-mean: 0.9409
#     MCC: 0.7612
#     F1-score: 0.7660
#     mAP: 0.9002
#   [Ours - RandomForest]
#     AUROC: 0.9874
#     G-mean: 0.9449
#     MCC: 0.8513
#     F1-score: 0.8580
#     mAP: 0.9109
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9852
#     G-mean: 0.9536
#     MCC: 0.8062
#     F1-score: 0.8138
#     mAP: 0.9265
#   [Ours - DecisionTree]
#     AUROC: 0.8390
#     G-mean: 0.8240
#     MCC: 0.5818
#     F1-score: 0.6030
#     mAP: 0.4666
#   [Ours - kNN]
#     AUROC: 0.9457
#     G-mean: 0.8919
#     MCC: 0.8636
#     F1-score: 0.8623
#     mAP: 0.8732
#   [Ours - MLP]
#     AUROC: 0.9590
#     G-mean: 0.9310
#     MCC: 0.7374
#     F1-score: 0.7440
#     mAP: 0.8952
#   [Ours - RandomForest]
#     AUROC: 0.9885
#     G-mean: 0.9435
#     MCC: 0.8518
#     F1-score: 0.8575
#     mAP: 0.9113
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9863
#     G-mean: 0.9563
#     MCC: 0.8170
#     F1-score: 0.8237
#     mAP: 0.9302
#   [Ours - DecisionTree]
#     AUROC: 0.8300
#     G-mean: 0.8255
#     MCC: 0.6001
#     F1-score: 0.6225
#     mAP: 0.4773
#   [Ours - kNN]
#     AUROC: 0.9501
#     G-mean: 0.8845
#     MCC: 0.8507
#     F1-score: 0.8511
#     mAP: 0.8712
#   [Ours - MLP]
#     AUROC: 0.9538
#     G-mean: 0.9232
#     MCC: 0.7193
#     F1-score: 0.7284
#     mAP: 0.8901
#   [Ours - RandomForest]
#     AUROC: 0.9892
#     G-mean: 0.9383
#     MCC: 0.8417
#     F1-score: 0.8488
#     mAP: 0.9174
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9872
#     G-mean: 0.9567
#     MCC: 0.8150
#     F1-score: 0.8215
#     mAP: 0.9365
#   [Ours - DecisionTree]
#     AUROC: 0.8532
#     G-mean: 0.8509
#     MCC: 0.6328
#     F1-score: 0.6513
#     mAP: 0.5282
#   [Ours - kNN]
#     AUROC: 0.9512
#     G-mean: 0.8810
#     MCC: 0.8317
#     F1-score: 0.8348
#     mAP: 0.8624
#   [Ours - MLP]
#     AUROC: 0.9518
#     G-mean: 0.9180
#     MCC: 0.7127
#     F1-score: 0.7210
#     mAP: 0.8858
#   [Ours - RandomForest]
#     AUROC: 0.9896
#     G-mean: 0.9340
#     MCC: 0.8309
#     F1-score: 0.8391
#     mAP: 0.9238
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9869
#     G-mean: 0.9548
#     MCC: 0.8116
#     F1-score: 0.8187
#     mAP: 0.9346
#   [Ours - DecisionTree]
#     AUROC: 0.8643
#     G-mean: 0.8578
#     MCC: 0.6440
#     F1-score: 0.6628
#     mAP: 0.5452
#   [Ours - kNN]
#     AUROC: 0.9527
#     G-mean: 0.8842
#     MCC: 0.8295
#     F1-score: 0.8341
#     mAP: 0.8639
#   [Ours - MLP]
#     AUROC: 0.9511
#     G-mean: 0.9178
#     MCC: 0.7164
#     F1-score: 0.7252
#     mAP: 0.8860
#   [Ours - RandomForest]
#     AUROC: 0.9888
#     G-mean: 0.9362
#     MCC: 0.8347
#     F1-score: 0.8433
#     mAP: 0.9206
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9861
#     G-mean: 0.9523
#     MCC: 0.8089
#     F1-score: 0.8164
#     mAP: 0.9337
#   [Ours - DecisionTree]
#     AUROC: 0.8632
#     G-mean: 0.8528
#     MCC: 0.6377
#     F1-score: 0.6578
#     mAP: 0.5390
#   [Ours - kNN]
#     AUROC: 0.9540
#     G-mean: 0.8843
#     MCC: 0.8266
#     F1-score: 0.8309
#     mAP: 0.8620
#   [Ours - MLP]
#     AUROC: 0.9499
#     G-mean: 0.9217
#     MCC: 0.7212
#     F1-score: 0.7297
#     mAP: 0.8843
#   [Ours - RandomForest]
#     AUROC: 0.9891
#     G-mean: 0.9353
#     MCC: 0.8343
#     F1-score: 0.8427
#     mAP: 0.9220
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9864
#     G-mean: 0.9516
#     MCC: 0.8071
#     F1-score: 0.8142
#     mAP: 0.9321
#   [Ours - DecisionTree]
#     AUROC: 0.8577
#     G-mean: 0.8474
#     MCC: 0.6329
#     F1-score: 0.6542
#     mAP: 0.5268
#   [Ours - kNN]
#     AUROC: 0.9553
#     G-mean: 0.8848
#     MCC: 0.8254
#     F1-score: 0.8299
#     mAP: 0.8640
#   [Ours - MLP]
#     AUROC: 0.9505
#     G-mean: 0.9229
#     MCC: 0.7263
#     F1-score: 0.7348
#     mAP: 0.8818
#   [Ours - RandomForest]
#     AUROC: 0.9893
#     G-mean: 0.9317
#     MCC: 0.8328
#     F1-score: 0.8417
#     mAP: 0.9230
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9864
#     G-mean: 0.9522
#     MCC: 0.8051
#     F1-score: 0.8121
#     mAP: 0.9332
#   [Ours - DecisionTree]
#     AUROC: 0.8569
#     G-mean: 0.8504
#     MCC: 0.6311
#     F1-score: 0.6523
#     mAP: 0.5277
#   [Ours - kNN]
#     AUROC: 0.9561
#     G-mean: 0.8850
#     MCC: 0.8255
#     F1-score: 0.8304
#     mAP: 0.8635
#   [Ours - MLP]
#     AUROC: 0.9524
#     G-mean: 0.9257
#     MCC: 0.7268
#     F1-score: 0.7350
#     mAP: 0.8856
#   [Ours - RandomForest]
#     AUROC: 0.9891
#     G-mean: 0.9334
#     MCC: 0.8366
#     F1-score: 0.8457
#     mAP: 0.9216
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9853
#     G-mean: 0.9503
#     MCC: 0.8019
#     F1-score: 0.8095
#     mAP: 0.9324
#   [Ours - DecisionTree]
#     AUROC: 0.8551
#     G-mean: 0.8449
#     MCC: 0.6247
#     F1-score: 0.6459
#     mAP: 0.5201
#   [Ours - kNN]
#     AUROC: 0.9564
#     G-mean: 0.8845
#     MCC: 0.8222
#     F1-score: 0.8272
#     mAP: 0.8658
#   [Ours - MLP]
#     AUROC: 0.9516
#     G-mean: 0.9240
#     MCC: 0.7239
#     F1-score: 0.7320
#     mAP: 0.8874
#   [Ours - RandomForest]
#     AUROC: 0.9885
#     G-mean: 0.9328
#     MCC: 0.8323
#     F1-score: 0.8417
#     mAP: 0.9216
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9855
#     G-mean: 0.9489
#     MCC: 0.8001
#     F1-score: 0.8077
#     mAP: 0.9339
#   [Ours - DecisionTree]
#     AUROC: 0.8567
#     G-mean: 0.8477
#     MCC: 0.6322
#     F1-score: 0.6530
#     mAP: 0.5249
#   [Ours - kNN]
#     AUROC: 0.9569
#     G-mean: 0.8826
#     MCC: 0.8203
#     F1-score: 0.8247
#     mAP: 0.8668
#   [Ours - MLP]
#     AUROC: 0.9514
#     G-mean: 0.9236
#     MCC: 0.7252
#     F1-score: 0.7336
#     mAP: 0.8888
#   [Ours - RandomForest]
#     AUROC: 0.9886
#     G-mean: 0.9326
#     MCC: 0.8333
#     F1-score: 0.8426
#     mAP: 0.9227
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/spectrometer_results_gaussian_beta_0.0.csv

# %%
data_name = 'thyroid_sick'
maj_target_name = -1

n_epochs = 2000
hidden_dims = [52, 16, 13]
latent_dim = 8
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        fetch_data_func=fetch_datasets,
        maj_target_name=maj_target_name,
        methods=methods,
        base_models=base_models,
        device=device,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )
# Out:
# beta: 0.1
# Dataset loaded: thyroid_sick
# X shape : (3772, 52)
# target : Counter({0: 3541, 1: 231})
# IR: 15.33
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9484
#     G-mean: 0.8728
#     MCC: 0.4910
#     F1-score: 0.4791
#     mAP: 0.6585
#   [Ours - DecisionTree]
#     AUROC: 0.9580
#     G-mean: 0.9054
#     MCC: 0.8169
#     F1-score: 0.8258
#     mAP: 0.7867
#   [Ours - kNN]
#     AUROC: 0.8634
#     G-mean: 0.6405
#     MCC: 0.5300
#     F1-score: 0.5263
#     mAP: 0.5160
#   [Ours - MLP]
#     AUROC: 0.9629
#     G-mean: 0.8699
#     MCC: 0.6901
#     F1-score: 0.7037
#     mAP: 0.7385
#   [Ours - RandomForest]
#     AUROC: 0.9968
#     G-mean: 0.8818
#     MCC: 0.8457
#     F1-score: 0.8490
#     mAP: 0.9637
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9475
#     G-mean: 0.8709
#     MCC: 0.4888
#     F1-score: 0.4778
#     mAP: 0.6500
#   [Ours - DecisionTree]
#     AUROC: 0.9588
#     G-mean: 0.9069
#     MCC: 0.8233
#     F1-score: 0.8320
#     mAP: 0.7906
#   [Ours - kNN]
#     AUROC: 0.8614
#     G-mean: 0.6385
#     MCC: 0.5271
#     F1-score: 0.5241
#     mAP: 0.5237
#   [Ours - MLP]
#     AUROC: 0.9646
#     G-mean: 0.8682
#     MCC: 0.6904
#     F1-score: 0.7056
#     mAP: 0.7373
#   [Ours - RandomForest]
#     AUROC: 0.9969
#     G-mean: 0.8883
#     MCC: 0.8527
#     F1-score: 0.8565
#     mAP: 0.9638
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9467
#     G-mean: 0.8689
#     MCC: 0.4876
#     F1-score: 0.4775
#     mAP: 0.6481
#   [Ours - DecisionTree]
#     AUROC: 0.9564
#     G-mean: 0.9059
#     MCC: 0.8237
#     F1-score: 0.8326
#     mAP: 0.7833
#   [Ours - kNN]
#     AUROC: 0.8581
#     G-mean: 0.6463
#     MCC: 0.5363
#     F1-score: 0.5347
#     mAP: 0.5245
#   [Ours - MLP]
#     AUROC: 0.9637
#     G-mean: 0.8656
#     MCC: 0.6919
#     F1-score: 0.7077
#     mAP: 0.7374
#   [Ours - RandomForest]
#     AUROC: 0.9967
#     G-mean: 0.8880
#     MCC: 0.8509
#     F1-score: 0.8550
#     mAP: 0.9629
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9466
#     G-mean: 0.8692
#     MCC: 0.4889
#     F1-score: 0.4789
#     mAP: 0.6465
#   [Ours - DecisionTree]
#     AUROC: 0.9562
#     G-mean: 0.9038
#     MCC: 0.8221
#     F1-score: 0.8311
#     mAP: 0.7821
#   [Ours - kNN]
#     AUROC: 0.8560
#     G-mean: 0.6372
#     MCC: 0.5260
#     F1-score: 0.5240
#     mAP: 0.5191
#   [Ours - MLP]
#     AUROC: 0.9636
#     G-mean: 0.8673
#     MCC: 0.6953
#     F1-score: 0.7111
#     mAP: 0.7383
#   [Ours - RandomForest]
#     AUROC: 0.9966
#     G-mean: 0.8881
#     MCC: 0.8508
#     F1-score: 0.8550
#     mAP: 0.9618
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9463
#     G-mean: 0.8688
#     MCC: 0.4879
#     F1-score: 0.4780
#     mAP: 0.6444
#   [Ours - DecisionTree]
#     AUROC: 0.9559
#     G-mean: 0.9029
#     MCC: 0.8219
#     F1-score: 0.8310
#     mAP: 0.7790
#   [Ours - kNN]
#     AUROC: 0.8566
#     G-mean: 0.6347
#     MCC: 0.5220
#     F1-score: 0.5201
#     mAP: 0.5169
#   [Ours - MLP]
#     AUROC: 0.9638
#     G-mean: 0.8658
#     MCC: 0.6933
#     F1-score: 0.7091
#     mAP: 0.7402
#   [Ours - RandomForest]
#     AUROC: 0.9966
#     G-mean: 0.8899
#     MCC: 0.8530
#     F1-score: 0.8571
#     mAP: 0.9626
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9460
#     G-mean: 0.8681
#     MCC: 0.4870
#     F1-score: 0.4774
#     mAP: 0.6446
#   [Ours - DecisionTree]
#     AUROC: 0.9540
#     G-mean: 0.9042
#     MCC: 0.8220
#     F1-score: 0.8313
#     mAP: 0.7771
#   [Ours - kNN]
#     AUROC: 0.8557
#     G-mean: 0.6353
#     MCC: 0.5203
#     F1-score: 0.5193
#     mAP: 0.5136
#   [Ours - MLP]
#     AUROC: 0.9625
#     G-mean: 0.8648
#     MCC: 0.6933
#     F1-score: 0.7089
#     mAP: 0.7370
#   [Ours - RandomForest]
#     AUROC: 0.9966
#     G-mean: 0.8895
#     MCC: 0.8525
#     F1-score: 0.8565
#     mAP: 0.9619
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9461
#     G-mean: 0.8674
#     MCC: 0.4858
#     F1-score: 0.4760
#     mAP: 0.6470
#   [Ours - DecisionTree]
#     AUROC: 0.9559
#     G-mean: 0.9046
#     MCC: 0.8219
#     F1-score: 0.8309
#     mAP: 0.7753
#   [Ours - kNN]
#     AUROC: 0.8565
#     G-mean: 0.6379
#     MCC: 0.5248
#     F1-score: 0.5233
#     mAP: 0.5147
#   [Ours - MLP]
#     AUROC: 0.9621
#     G-mean: 0.8655
#     MCC: 0.6947
#     F1-score: 0.7100
#     mAP: 0.7397
#   [Ours - RandomForest]
#     AUROC: 0.9967
#     G-mean: 0.8898
#     MCC: 0.8537
#     F1-score: 0.8573
#     mAP: 0.9627
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9465
#     G-mean: 0.8681
#     MCC: 0.4872
#     F1-score: 0.4774
#     mAP: 0.6483
#   [Ours - DecisionTree]
#     AUROC: 0.9557
#     G-mean: 0.9038
#     MCC: 0.8210
#     F1-score: 0.8301
#     mAP: 0.7768
#   [Ours - kNN]
#     AUROC: 0.8561
#     G-mean: 0.6392
#     MCC: 0.5273
#     F1-score: 0.5256
#     mAP: 0.5163
#   [Ours - MLP]
#     AUROC: 0.9619
#     G-mean: 0.8649
#     MCC: 0.6924
#     F1-score: 0.7079
#     mAP: 0.7390
#   [Ours - RandomForest]
#     AUROC: 0.9967
#     G-mean: 0.8902
#     MCC: 0.8542
#     F1-score: 0.8579
#     mAP: 0.9625
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9467
#     G-mean: 0.8691
#     MCC: 0.4886
#     F1-score: 0.4787
#     mAP: 0.6494
#   [Ours - DecisionTree]
#     AUROC: 0.9558
#     G-mean: 0.9022
#     MCC: 0.8186
#     F1-score: 0.8279
#     mAP: 0.7747
#   [Ours - kNN]
#     AUROC: 0.8572
#     G-mean: 0.6406
#     MCC: 0.5299
#     F1-score: 0.5273
#     mAP: 0.5181
#   [Ours - MLP]
#     AUROC: 0.9617
#     G-mean: 0.8656
#     MCC: 0.6916
#     F1-score: 0.7071
#     mAP: 0.7357
#   [Ours - RandomForest]
#     AUROC: 0.9967
#     G-mean: 0.8895
#     MCC: 0.8533
#     F1-score: 0.8570
#     mAP: 0.9627
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9466
#     G-mean: 0.8693
#     MCC: 0.4887
#     F1-score: 0.4787
#     mAP: 0.6480
#   [Ours - DecisionTree]
#     AUROC: 0.9568
#     G-mean: 0.9025
#     MCC: 0.8190
#     F1-score: 0.8281
#     mAP: 0.7747
#   [Ours - kNN]
#     AUROC: 0.8580
#     G-mean: 0.6392
#     MCC: 0.5291
#     F1-score: 0.5261
#     mAP: 0.5201
#   [Ours - MLP]
#     AUROC: 0.9617
#     G-mean: 0.8655
#     MCC: 0.6899
#     F1-score: 0.7055
#     mAP: 0.7339
#   [Ours - RandomForest]
#     AUROC: 0.9967
#     G-mean: 0.8892
#     MCC: 0.8530
#     F1-score: 0.8565
#     mAP: 0.9627
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/thyroid_sick_results_gaussian_beta_0.1.csv
# beta: 0.05
# Dataset loaded: thyroid_sick
# X shape : (3772, 52)
# target : Counter({0: 3541, 1: 231})
# IR: 15.33
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9514
#     G-mean: 0.8731
#     MCC: 0.5119
#     F1-score: 0.5054
#     mAP: 0.6615
#   [Ours - DecisionTree]
#     AUROC: 0.9638
#     G-mean: 0.9056
#     MCC: 0.8173
#     F1-score: 0.8268
#     mAP: 0.7875
#   [Ours - kNN]
#     AUROC: 0.8634
#     G-mean: 0.6350
#     MCC: 0.5276
#     F1-score: 0.5233
#     mAP: 0.5157
#   [Ours - MLP]
#     AUROC: 0.9648
#     G-mean: 0.8604
#     MCC: 0.6735
#     F1-score: 0.6881
#     mAP: 0.7190
#   [Ours - RandomForest]
#     AUROC: 0.9970
#     G-mean: 0.8864
#     MCC: 0.8486
#     F1-score: 0.8522
#     mAP: 0.9625
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9503
#     G-mean: 0.8710
#     MCC: 0.5061
#     F1-score: 0.4995
#     mAP: 0.6572
#   [Ours - DecisionTree]
#     AUROC: 0.9553
#     G-mean: 0.9034
#     MCC: 0.8180
#     F1-score: 0.8272
#     mAP: 0.7773
#   [Ours - kNN]
#     AUROC: 0.8595
#     G-mean: 0.6324
#     MCC: 0.5239
#     F1-score: 0.5199
#     mAP: 0.5200
#   [Ours - MLP]
#     AUROC: 0.9626
#     G-mean: 0.8529
#     MCC: 0.6643
#     F1-score: 0.6809
#     mAP: 0.7198
#   [Ours - RandomForest]
#     AUROC: 0.9970
#     G-mean: 0.8932
#     MCC: 0.8601
#     F1-score: 0.8636
#     mAP: 0.9632
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9501
#     G-mean: 0.8690
#     MCC: 0.5051
#     F1-score: 0.4995
#     mAP: 0.6592
#   [Ours - DecisionTree]
#     AUROC: 0.9550
#     G-mean: 0.9026
#     MCC: 0.8194
#     F1-score: 0.8283
#     mAP: 0.7783
#   [Ours - kNN]
#     AUROC: 0.8568
#     G-mean: 0.6407
#     MCC: 0.5319
#     F1-score: 0.5296
#     mAP: 0.5180
#   [Ours - MLP]
#     AUROC: 0.9625
#     G-mean: 0.8568
#     MCC: 0.6761
#     F1-score: 0.6922
#     mAP: 0.7251
#   [Ours - RandomForest]
#     AUROC: 0.9968
#     G-mean: 0.8921
#     MCC: 0.8584
#     F1-score: 0.8621
#     mAP: 0.9620
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9498
#     G-mean: 0.8702
#     MCC: 0.5074
#     F1-score: 0.5017
#     mAP: 0.6574
#   [Ours - DecisionTree]
#     AUROC: 0.9560
#     G-mean: 0.9022
#     MCC: 0.8156
#     F1-score: 0.8248
#     mAP: 0.7744
#   [Ours - kNN]
#     AUROC: 0.8551
#     G-mean: 0.6364
#     MCC: 0.5260
#     F1-score: 0.5239
#     mAP: 0.5159
#   [Ours - MLP]
#     AUROC: 0.9627
#     G-mean: 0.8579
#     MCC: 0.6748
#     F1-score: 0.6905
#     mAP: 0.7260
#   [Ours - RandomForest]
#     AUROC: 0.9966
#     G-mean: 0.8914
#     MCC: 0.8570
#     F1-score: 0.8609
#     mAP: 0.9609
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9496
#     G-mean: 0.8719
#     MCC: 0.5095
#     F1-score: 0.5034
#     mAP: 0.6567
#   [Ours - DecisionTree]
#     AUROC: 0.9577
#     G-mean: 0.9030
#     MCC: 0.8130
#     F1-score: 0.8223
#     mAP: 0.7742
#   [Ours - kNN]
#     AUROC: 0.8556
#     G-mean: 0.6339
#     MCC: 0.5242
#     F1-score: 0.5212
#     mAP: 0.5151
#   [Ours - MLP]
#     AUROC: 0.9626
#     G-mean: 0.8589
#     MCC: 0.6715
#     F1-score: 0.6866
#     mAP: 0.7229
#   [Ours - RandomForest]
#     AUROC: 0.9966
#     G-mean: 0.8909
#     MCC: 0.8555
#     F1-score: 0.8594
#     mAP: 0.9612
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9493
#     G-mean: 0.8713
#     MCC: 0.5095
#     F1-score: 0.5038
#     mAP: 0.6560
#   [Ours - DecisionTree]
#     AUROC: 0.9571
#     G-mean: 0.9019
#     MCC: 0.8127
#     F1-score: 0.8222
#     mAP: 0.7718
#   [Ours - kNN]
#     AUROC: 0.8550
#     G-mean: 0.6357
#     MCC: 0.5252
#     F1-score: 0.5227
#     mAP: 0.5154
#   [Ours - MLP]
#     AUROC: 0.9621
#     G-mean: 0.8587
#     MCC: 0.6752
#     F1-score: 0.6905
#     mAP: 0.7218
#   [Ours - RandomForest]
#     AUROC: 0.9966
#     G-mean: 0.8920
#     MCC: 0.8567
#     F1-score: 0.8605
#     mAP: 0.9611
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9490
#     G-mean: 0.8705
#     MCC: 0.5077
#     F1-score: 0.5019
#     mAP: 0.6561
#   [Ours - DecisionTree]
#     AUROC: 0.9590
#     G-mean: 0.9030
#     MCC: 0.8144
#     F1-score: 0.8235
#     mAP: 0.7762
#   [Ours - kNN]
#     AUROC: 0.8563
#     G-mean: 0.6373
#     MCC: 0.5282
#     F1-score: 0.5252
#     mAP: 0.5161
#   [Ours - MLP]
#     AUROC: 0.9616
#     G-mean: 0.8579
#     MCC: 0.6786
#     F1-score: 0.6939
#     mAP: 0.7249
#   [Ours - RandomForest]
#     AUROC: 0.9967
#     G-mean: 0.8919
#     MCC: 0.8570
#     F1-score: 0.8605
#     mAP: 0.9620
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9487
#     G-mean: 0.8708
#     MCC: 0.5086
#     F1-score: 0.5030
#     mAP: 0.6557
#   [Ours - DecisionTree]
#     AUROC: 0.9576
#     G-mean: 0.9022
#     MCC: 0.8141
#     F1-score: 0.8233
#     mAP: 0.7760
#   [Ours - kNN]
#     AUROC: 0.8556
#     G-mean: 0.6386
#     MCC: 0.5291
#     F1-score: 0.5266
#     mAP: 0.5154
#   [Ours - MLP]
#     AUROC: 0.9611
#     G-mean: 0.8587
#     MCC: 0.6784
#     F1-score: 0.6938
#     mAP: 0.7234
#   [Ours - RandomForest]
#     AUROC: 0.9967
#     G-mean: 0.8923
#     MCC: 0.8574
#     F1-score: 0.8610
#     mAP: 0.9618
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9485
#     G-mean: 0.8707
#     MCC: 0.5084
#     F1-score: 0.5027
#     mAP: 0.6540
#   [Ours - DecisionTree]
#     AUROC: 0.9574
#     G-mean: 0.9031
#     MCC: 0.8154
#     F1-score: 0.8247
#     mAP: 0.7742
#   [Ours - kNN]
#     AUROC: 0.8568
#     G-mean: 0.6401
#     MCC: 0.5317
#     F1-score: 0.5283
#     mAP: 0.5181
#   [Ours - MLP]
#     AUROC: 0.9610
#     G-mean: 0.8575
#     MCC: 0.6781
#     F1-score: 0.6937
#     mAP: 0.7228
#   [Ours - RandomForest]
#     AUROC: 0.9967
#     G-mean: 0.8923
#     MCC: 0.8571
#     F1-score: 0.8608
#     mAP: 0.9621
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9483
#     G-mean: 0.8706
#     MCC: 0.5081
#     F1-score: 0.5024
#     mAP: 0.6527
#   [Ours - DecisionTree]
#     AUROC: 0.9591
#     G-mean: 0.9036
#     MCC: 0.8168
#     F1-score: 0.8259
#     mAP: 0.7768
#   [Ours - kNN]
#     AUROC: 0.8574
#     G-mean: 0.6397
#     MCC: 0.5325
#     F1-score: 0.5284
#     mAP: 0.5213
#   [Ours - MLP]
#     AUROC: 0.9609
#     G-mean: 0.8574
#     MCC: 0.6778
#     F1-score: 0.6936
#     mAP: 0.7219
#   [Ours - RandomForest]
#     AUROC: 0.9968
#     G-mean: 0.8918
#     MCC: 0.8566
#     F1-score: 0.8601
#     mAP: 0.9621
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/thyroid_sick_results_gaussian_beta_0.05.csv
# beta: 0.01
# Dataset loaded: thyroid_sick
# X shape : (3772, 52)
# target : Counter({0: 3541, 1: 231})
# IR: 15.33
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9494
#     G-mean: 0.8536
#     MCC: 0.5302
#     F1-score: 0.5361
#     mAP: 0.6607
#   [Ours - DecisionTree]
#     AUROC: 0.9600
#     G-mean: 0.8981
#     MCC: 0.7898
#     F1-score: 0.7995
#     mAP: 0.7759
#   [Ours - kNN]
#     AUROC: 0.8634
#     G-mean: 0.6277
#     MCC: 0.5164
#     F1-score: 0.5115
#     mAP: 0.5229
#   [Ours - MLP]
#     AUROC: 0.9590
#     G-mean: 0.8504
#     MCC: 0.6637
#     F1-score: 0.6808
#     mAP: 0.7061
#   [Ours - RandomForest]
#     AUROC: 0.9972
#     G-mean: 0.8888
#     MCC: 0.8530
#     F1-score: 0.8563
#     mAP: 0.9652
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9502
#     G-mean: 0.8548
#     MCC: 0.5306
#     F1-score: 0.5365
#     mAP: 0.6655
#   [Ours - DecisionTree]
#     AUROC: 0.9576
#     G-mean: 0.8980
#     MCC: 0.7940
#     F1-score: 0.8043
#     mAP: 0.7666
#   [Ours - kNN]
#     AUROC: 0.8595
#     G-mean: 0.6304
#     MCC: 0.5195
#     F1-score: 0.5157
#     mAP: 0.5216
#   [Ours - MLP]
#     AUROC: 0.9589
#     G-mean: 0.8570
#     MCC: 0.6735
#     F1-score: 0.6901
#     mAP: 0.7167
#   [Ours - RandomForest]
#     AUROC: 0.9970
#     G-mean: 0.8933
#     MCC: 0.8601
#     F1-score: 0.8636
#     mAP: 0.9643
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9486
#     G-mean: 0.8561
#     MCC: 0.5348
#     F1-score: 0.5412
#     mAP: 0.6626
#   [Ours - DecisionTree]
#     AUROC: 0.9637
#     G-mean: 0.9000
#     MCC: 0.7971
#     F1-score: 0.8073
#     mAP: 0.7852
#   [Ours - kNN]
#     AUROC: 0.8588
#     G-mean: 0.6352
#     MCC: 0.5231
#     F1-score: 0.5211
#     mAP: 0.5220
#   [Ours - MLP]
#     AUROC: 0.9599
#     G-mean: 0.8558
#     MCC: 0.6785
#     F1-score: 0.6952
#     mAP: 0.7228
#   [Ours - RandomForest]
#     AUROC: 0.9965
#     G-mean: 0.8913
#     MCC: 0.8567
#     F1-score: 0.8604
#     mAP: 0.9624
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9484
#     G-mean: 0.8580
#     MCC: 0.5357
#     F1-score: 0.5415
#     mAP: 0.6610
#   [Ours - DecisionTree]
#     AUROC: 0.9633
#     G-mean: 0.8987
#     MCC: 0.7943
#     F1-score: 0.8046
#     mAP: 0.7800
#   [Ours - kNN]
#     AUROC: 0.8570
#     G-mean: 0.6296
#     MCC: 0.5161
#     F1-score: 0.5141
#     mAP: 0.5170
#   [Ours - MLP]
#     AUROC: 0.9601
#     G-mean: 0.8568
#     MCC: 0.6770
#     F1-score: 0.6937
#     mAP: 0.7238
#   [Ours - RandomForest]
#     AUROC: 0.9963
#     G-mean: 0.8912
#     MCC: 0.8564
#     F1-score: 0.8601
#     mAP: 0.9612
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9486
#     G-mean: 0.8570
#     MCC: 0.5351
#     F1-score: 0.5413
#     mAP: 0.6609
#   [Ours - DecisionTree]
#     AUROC: 0.9629
#     G-mean: 0.8974
#     MCC: 0.7928
#     F1-score: 0.8030
#     mAP: 0.7804
#   [Ours - kNN]
#     AUROC: 0.8573
#     G-mean: 0.6272
#     MCC: 0.5120
#     F1-score: 0.5100
#     mAP: 0.5143
#   [Ours - MLP]
#     AUROC: 0.9609
#     G-mean: 0.8551
#     MCC: 0.6779
#     F1-score: 0.6946
#     mAP: 0.7234
#   [Ours - RandomForest]
#     AUROC: 0.9963
#     G-mean: 0.8924
#     MCC: 0.8566
#     F1-score: 0.8606
#     mAP: 0.9616
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9484
#     G-mean: 0.8580
#     MCC: 0.5360
#     F1-score: 0.5420
#     mAP: 0.6615
#   [Ours - DecisionTree]
#     AUROC: 0.9631
#     G-mean: 0.9010
#     MCC: 0.7973
#     F1-score: 0.8076
#     mAP: 0.7817
#   [Ours - kNN]
#     AUROC: 0.8569
#     G-mean: 0.6291
#     MCC: 0.5157
#     F1-score: 0.5133
#     mAP: 0.5156
#   [Ours - MLP]
#     AUROC: 0.9598
#     G-mean: 0.8548
#     MCC: 0.6771
#     F1-score: 0.6936
#     mAP: 0.7210
#   [Ours - RandomForest]
#     AUROC: 0.9963
#     G-mean: 0.8920
#     MCC: 0.8563
#     F1-score: 0.8601
#     mAP: 0.9610
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9482
#     G-mean: 0.8581
#     MCC: 0.5371
#     F1-score: 0.5429
#     mAP: 0.6613
#   [Ours - DecisionTree]
#     AUROC: 0.9655
#     G-mean: 0.9024
#     MCC: 0.7997
#     F1-score: 0.8097
#     mAP: 0.7847
#   [Ours - kNN]
#     AUROC: 0.8578
#     G-mean: 0.6312
#     MCC: 0.5185
#     F1-score: 0.5159
#     mAP: 0.5167
#   [Ours - MLP]
#     AUROC: 0.9598
#     G-mean: 0.8566
#     MCC: 0.6789
#     F1-score: 0.6951
#     mAP: 0.7230
#   [Ours - RandomForest]
#     AUROC: 0.9965
#     G-mean: 0.8920
#     MCC: 0.8570
#     F1-score: 0.8605
#     mAP: 0.9620
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9483
#     G-mean: 0.8585
#     MCC: 0.5371
#     F1-score: 0.5429
#     mAP: 0.6611
#   [Ours - DecisionTree]
#     AUROC: 0.9640
#     G-mean: 0.9025
#     MCC: 0.7975
#     F1-score: 0.8077
#     mAP: 0.7851
#   [Ours - kNN]
#     AUROC: 0.8572
#     G-mean: 0.6348
#     MCC: 0.5225
#     F1-score: 0.5204
#     mAP: 0.5170
#   [Ours - MLP]
#     AUROC: 0.9593
#     G-mean: 0.8564
#     MCC: 0.6761
#     F1-score: 0.6925
#     mAP: 0.7220
#   [Ours - RandomForest]
#     AUROC: 0.9965
#     G-mean: 0.8924
#     MCC: 0.8571
#     F1-score: 0.8608
#     mAP: 0.9618
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9479
#     G-mean: 0.8578
#     MCC: 0.5361
#     F1-score: 0.5421
#     mAP: 0.6586
#   [Ours - DecisionTree]
#     AUROC: 0.9627
#     G-mean: 0.9025
#     MCC: 0.7951
#     F1-score: 0.8056
#     mAP: 0.7804
#   [Ours - kNN]
#     AUROC: 0.8587
#     G-mean: 0.6360
#     MCC: 0.5246
#     F1-score: 0.5217
#     mAP: 0.5206
#   [Ours - MLP]
#     AUROC: 0.9594
#     G-mean: 0.8547
#     MCC: 0.6734
#     F1-score: 0.6899
#     mAP: 0.7185
#   [Ours - RandomForest]
#     AUROC: 0.9965
#     G-mean: 0.8923
#     MCC: 0.8571
#     F1-score: 0.8608
#     mAP: 0.9617
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9480
#     G-mean: 0.8587
#     MCC: 0.5370
#     F1-score: 0.5428
#     mAP: 0.6579
#   [Ours - DecisionTree]
#     AUROC: 0.9638
#     G-mean: 0.9026
#     MCC: 0.7946
#     F1-score: 0.8051
#     mAP: 0.7810
#   [Ours - kNN]
#     AUROC: 0.8592
#     G-mean: 0.6348
#     MCC: 0.5235
#     F1-score: 0.5201
#     mAP: 0.5216
#   [Ours - MLP]
#     AUROC: 0.9600
#     G-mean: 0.8572
#     MCC: 0.6767
#     F1-score: 0.6931
#     mAP: 0.7204
#   [Ours - RandomForest]
#     AUROC: 0.9965
#     G-mean: 0.8917
#     MCC: 0.8564
#     F1-score: 0.8600
#     mAP: 0.9616
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/thyroid_sick_results_gaussian_beta_0.01.csv
# beta: 0.005
# Dataset loaded: thyroid_sick
# X shape : (3772, 52)
# target : Counter({0: 3541, 1: 231})
# IR: 15.33
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9478
#     G-mean: 0.8452
#     MCC: 0.5254
#     F1-score: 0.5341
#     mAP: 0.6564
#   [Ours - DecisionTree]
#     AUROC: 0.9554
#     G-mean: 0.8982
#     MCC: 0.7881
#     F1-score: 0.7980
#     mAP: 0.7654
#   [Ours - kNN]
#     AUROC: 0.8627
#     G-mean: 0.6236
#     MCC: 0.5173
#     F1-score: 0.5090
#     mAP: 0.5110
#   [Ours - MLP]
#     AUROC: 0.9535
#     G-mean: 0.8459
#     MCC: 0.6623
#     F1-score: 0.6796
#     mAP: 0.7028
#   [Ours - RandomForest]
#     AUROC: 0.9967
#     G-mean: 0.8819
#     MCC: 0.8479
#     F1-score: 0.8507
#     mAP: 0.9633
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9485
#     G-mean: 0.8511
#     MCC: 0.5365
#     F1-score: 0.5450
#     mAP: 0.6597
#   [Ours - DecisionTree]
#     AUROC: 0.9617
#     G-mean: 0.8962
#     MCC: 0.7978
#     F1-score: 0.8079
#     mAP: 0.7751
#   [Ours - kNN]
#     AUROC: 0.8582
#     G-mean: 0.6255
#     MCC: 0.5210
#     F1-score: 0.5135
#     mAP: 0.5204
#   [Ours - MLP]
#     AUROC: 0.9567
#     G-mean: 0.8502
#     MCC: 0.6710
#     F1-score: 0.6887
#     mAP: 0.7165
#   [Ours - RandomForest]
#     AUROC: 0.9968
#     G-mean: 0.8850
#     MCC: 0.8521
#     F1-score: 0.8554
#     mAP: 0.9625
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9474
#     G-mean: 0.8513
#     MCC: 0.5396
#     F1-score: 0.5487
#     mAP: 0.6539
#   [Ours - DecisionTree]
#     AUROC: 0.9628
#     G-mean: 0.8976
#     MCC: 0.8009
#     F1-score: 0.8112
#     mAP: 0.7808
#   [Ours - kNN]
#     AUROC: 0.8570
#     G-mean: 0.6317
#     MCC: 0.5200
#     F1-score: 0.5168
#     mAP: 0.5157
#   [Ours - MLP]
#     AUROC: 0.9580
#     G-mean: 0.8569
#     MCC: 0.6806
#     F1-score: 0.6980
#     mAP: 0.7191
#   [Ours - RandomForest]
#     AUROC: 0.9963
#     G-mean: 0.8856
#     MCC: 0.8498
#     F1-score: 0.8537
#     mAP: 0.9613
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9467
#     G-mean: 0.8513
#     MCC: 0.5377
#     F1-score: 0.5466
#     mAP: 0.6508
#   [Ours - DecisionTree]
#     AUROC: 0.9634
#     G-mean: 0.8973
#     MCC: 0.8007
#     F1-score: 0.8112
#     mAP: 0.7863
#   [Ours - kNN]
#     AUROC: 0.8560
#     G-mean: 0.6271
#     MCC: 0.5171
#     F1-score: 0.5129
#     mAP: 0.5171
#   [Ours - MLP]
#     AUROC: 0.9575
#     G-mean: 0.8577
#     MCC: 0.6767
#     F1-score: 0.6935
#     mAP: 0.7153
#   [Ours - RandomForest]
#     AUROC: 0.9961
#     G-mean: 0.8872
#     MCC: 0.8519
#     F1-score: 0.8559
#     mAP: 0.9603
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9475
#     G-mean: 0.8511
#     MCC: 0.5389
#     F1-score: 0.5480
#     mAP: 0.6546
#   [Ours - DecisionTree]
#     AUROC: 0.9619
#     G-mean: 0.8958
#     MCC: 0.7978
#     F1-score: 0.8084
#     mAP: 0.7776
#   [Ours - kNN]
#     AUROC: 0.8562
#     G-mean: 0.6237
#     MCC: 0.5139
#     F1-score: 0.5088
#     mAP: 0.5151
#   [Ours - MLP]
#     AUROC: 0.9584
#     G-mean: 0.8558
#     MCC: 0.6774
#     F1-score: 0.6943
#     mAP: 0.7160
#   [Ours - RandomForest]
#     AUROC: 0.9962
#     G-mean: 0.8892
#     MCC: 0.8539
#     F1-score: 0.8579
#     mAP: 0.9611
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9474
#     G-mean: 0.8521
#     MCC: 0.5381
#     F1-score: 0.5468
#     mAP: 0.6546
#   [Ours - DecisionTree]
#     AUROC: 0.9617
#     G-mean: 0.8989
#     MCC: 0.8001
#     F1-score: 0.8107
#     mAP: 0.7774
#   [Ours - kNN]
#     AUROC: 0.8559
#     G-mean: 0.6246
#     MCC: 0.5161
#     F1-score: 0.5106
#     mAP: 0.5164
#   [Ours - MLP]
#     AUROC: 0.9580
#     G-mean: 0.8530
#     MCC: 0.6780
#     F1-score: 0.6951
#     mAP: 0.7150
#   [Ours - RandomForest]
#     AUROC: 0.9962
#     G-mean: 0.8897
#     MCC: 0.8545
#     F1-score: 0.8584
#     mAP: 0.9607
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9472
#     G-mean: 0.8515
#     MCC: 0.5382
#     F1-score: 0.5468
#     mAP: 0.6548
#   [Ours - DecisionTree]
#     AUROC: 0.9626
#     G-mean: 0.8993
#     MCC: 0.7975
#     F1-score: 0.8080
#     mAP: 0.7771
#   [Ours - kNN]
#     AUROC: 0.8571
#     G-mean: 0.6273
#     MCC: 0.5196
#     F1-score: 0.5140
#     mAP: 0.5198
#   [Ours - MLP]
#     AUROC: 0.9581
#     G-mean: 0.8548
#     MCC: 0.6814
#     F1-score: 0.6982
#     mAP: 0.7180
#   [Ours - RandomForest]
#     AUROC: 0.9964
#     G-mean: 0.8904
#     MCC: 0.8558
#     F1-score: 0.8594
#     mAP: 0.9616
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9471
#     G-mean: 0.8513
#     MCC: 0.5382
#     F1-score: 0.5470
#     mAP: 0.6547
#   [Ours - DecisionTree]
#     AUROC: 0.9623
#     G-mean: 0.8987
#     MCC: 0.7962
#     F1-score: 0.8069
#     mAP: 0.7780
#   [Ours - kNN]
#     AUROC: 0.8563
#     G-mean: 0.6295
#     MCC: 0.5217
#     F1-score: 0.5166
#     mAP: 0.5209
#   [Ours - MLP]
#     AUROC: 0.9582
#     G-mean: 0.8536
#     MCC: 0.6793
#     F1-score: 0.6961
#     mAP: 0.7189
#   [Ours - RandomForest]
#     AUROC: 0.9964
#     G-mean: 0.8903
#     MCC: 0.8555
#     F1-score: 0.8592
#     mAP: 0.9612
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9469
#     G-mean: 0.8497
#     MCC: 0.5355
#     F1-score: 0.5446
#     mAP: 0.6528
#   [Ours - DecisionTree]
#     AUROC: 0.9634
#     G-mean: 0.8995
#     MCC: 0.7961
#     F1-score: 0.8068
#     mAP: 0.7765
#   [Ours - kNN]
#     AUROC: 0.8578
#     G-mean: 0.6306
#     MCC: 0.5232
#     F1-score: 0.5175
#     mAP: 0.5227
#   [Ours - MLP]
#     AUROC: 0.9586
#     G-mean: 0.8542
#     MCC: 0.6820
#     F1-score: 0.6988
#     mAP: 0.7186
#   [Ours - RandomForest]
#     AUROC: 0.9964
#     G-mean: 0.8902
#     MCC: 0.8548
#     F1-score: 0.8585
#     mAP: 0.9616
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9469
#     G-mean: 0.8497
#     MCC: 0.5357
#     F1-score: 0.5449
#     mAP: 0.6525
#   [Ours - DecisionTree]
#     AUROC: 0.9634
#     G-mean: 0.9004
#     MCC: 0.7966
#     F1-score: 0.8073
#     mAP: 0.7764
#   [Ours - kNN]
#     AUROC: 0.8585
#     G-mean: 0.6299
#     MCC: 0.5239
#     F1-score: 0.5173
#     mAP: 0.5253
#   [Ours - MLP]
#     AUROC: 0.9586
#     G-mean: 0.8539
#     MCC: 0.6821
#     F1-score: 0.6987
#     mAP: 0.7188
#   [Ours - RandomForest]
#     AUROC: 0.9964
#     G-mean: 0.8893
#     MCC: 0.8540
#     F1-score: 0.8575
#     mAP: 0.9616
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/thyroid_sick_results_gaussian_beta_0.005.csv
# beta: 0.001
# Dataset loaded: thyroid_sick
# X shape : (3772, 52)
# target : Counter({0: 3541, 1: 231})
# IR: 15.33
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9472
#     G-mean: 0.8464
#     MCC: 0.5524
#     F1-score: 0.5650
#     mAP: 0.6499
#   [Ours - DecisionTree]
#     AUROC: 0.9529
#     G-mean: 0.8928
#     MCC: 0.7933
#     F1-score: 0.8047
#     mAP: 0.7870
#   [Ours - kNN]
#     AUROC: 0.8604
#     G-mean: 0.6153
#     MCC: 0.5107
#     F1-score: 0.5003
#     mAP: 0.5087
#   [Ours - MLP]
#     AUROC: 0.9559
#     G-mean: 0.8483
#     MCC: 0.6931
#     F1-score: 0.7084
#     mAP: 0.7211
#   [Ours - RandomForest]
#     AUROC: 0.9969
#     G-mean: 0.8841
#     MCC: 0.8481
#     F1-score: 0.8512
#     mAP: 0.9629
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9477
#     G-mean: 0.8483
#     MCC: 0.5529
#     F1-score: 0.5649
#     mAP: 0.6524
#   [Ours - DecisionTree]
#     AUROC: 0.9618
#     G-mean: 0.8971
#     MCC: 0.7931
#     F1-score: 0.8041
#     mAP: 0.7921
#   [Ours - kNN]
#     AUROC: 0.8572
#     G-mean: 0.6208
#     MCC: 0.5206
#     F1-score: 0.5103
#     mAP: 0.5216
#   [Ours - MLP]
#     AUROC: 0.9571
#     G-mean: 0.8513
#     MCC: 0.7012
#     F1-score: 0.7170
#     mAP: 0.7198
#   [Ours - RandomForest]
#     AUROC: 0.9969
#     G-mean: 0.8885
#     MCC: 0.8562
#     F1-score: 0.8594
#     mAP: 0.9627
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9465
#     G-mean: 0.8441
#     MCC: 0.5505
#     F1-score: 0.5640
#     mAP: 0.6447
#   [Ours - DecisionTree]
#     AUROC: 0.9640
#     G-mean: 0.9012
#     MCC: 0.7919
#     F1-score: 0.8025
#     mAP: 0.7932
#   [Ours - kNN]
#     AUROC: 0.8558
#     G-mean: 0.6288
#     MCC: 0.5243
#     F1-score: 0.5177
#     mAP: 0.5183
#   [Ours - MLP]
#     AUROC: 0.9585
#     G-mean: 0.8487
#     MCC: 0.6933
#     F1-score: 0.7100
#     mAP: 0.7202
#   [Ours - RandomForest]
#     AUROC: 0.9967
#     G-mean: 0.8905
#     MCC: 0.8559
#     F1-score: 0.8596
#     mAP: 0.9624
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9460
#     G-mean: 0.8452
#     MCC: 0.5478
#     F1-score: 0.5605
#     mAP: 0.6432
#   [Ours - DecisionTree]
#     AUROC: 0.9622
#     G-mean: 0.8991
#     MCC: 0.7880
#     F1-score: 0.7992
#     mAP: 0.7868
#   [Ours - kNN]
#     AUROC: 0.8544
#     G-mean: 0.6245
#     MCC: 0.5211
#     F1-score: 0.5139
#     mAP: 0.5176
#   [Ours - MLP]
#     AUROC: 0.9577
#     G-mean: 0.8483
#     MCC: 0.6897
#     F1-score: 0.7064
#     mAP: 0.7171
#   [Ours - RandomForest]
#     AUROC: 0.9965
#     G-mean: 0.8901
#     MCC: 0.8556
#     F1-score: 0.8593
#     mAP: 0.9608
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9463
#     G-mean: 0.8466
#     MCC: 0.5487
#     F1-score: 0.5611
#     mAP: 0.6446
#   [Ours - DecisionTree]
#     AUROC: 0.9600
#     G-mean: 0.8976
#     MCC: 0.7814
#     F1-score: 0.7928
#     mAP: 0.7774
#   [Ours - kNN]
#     AUROC: 0.8548
#     G-mean: 0.6204
#     MCC: 0.5169
#     F1-score: 0.5087
#     mAP: 0.5154
#   [Ours - MLP]
#     AUROC: 0.9588
#     G-mean: 0.8476
#     MCC: 0.6894
#     F1-score: 0.7063
#     mAP: 0.7169
#   [Ours - RandomForest]
#     AUROC: 0.9965
#     G-mean: 0.8900
#     MCC: 0.8562
#     F1-score: 0.8598
#     mAP: 0.9613
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9464
#     G-mean: 0.8461
#     MCC: 0.5447
#     F1-score: 0.5567
#     mAP: 0.6469
#   [Ours - DecisionTree]
#     AUROC: 0.9614
#     G-mean: 0.9012
#     MCC: 0.7872
#     F1-score: 0.7984
#     mAP: 0.7794
#   [Ours - kNN]
#     AUROC: 0.8549
#     G-mean: 0.6218
#     MCC: 0.5196
#     F1-score: 0.5110
#     mAP: 0.5179
#   [Ours - MLP]
#     AUROC: 0.9588
#     G-mean: 0.8466
#     MCC: 0.6884
#     F1-score: 0.7054
#     mAP: 0.7184
#   [Ours - RandomForest]
#     AUROC: 0.9965
#     G-mean: 0.8896
#     MCC: 0.8552
#     F1-score: 0.8588
#     mAP: 0.9610
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9462
#     G-mean: 0.8451
#     MCC: 0.5445
#     F1-score: 0.5565
#     mAP: 0.6473
#   [Ours - DecisionTree]
#     AUROC: 0.9629
#     G-mean: 0.9021
#     MCC: 0.7891
#     F1-score: 0.7999
#     mAP: 0.7814
#   [Ours - kNN]
#     AUROC: 0.8558
#     G-mean: 0.6244
#     MCC: 0.5226
#     F1-score: 0.5142
#     mAP: 0.5207
#   [Ours - MLP]
#     AUROC: 0.9587
#     G-mean: 0.8483
#     MCC: 0.6876
#     F1-score: 0.7043
#     mAP: 0.7184
#   [Ours - RandomForest]
#     AUROC: 0.9966
#     G-mean: 0.8906
#     MCC: 0.8558
#     F1-score: 0.8593
#     mAP: 0.9619
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9461
#     G-mean: 0.8454
#     MCC: 0.5445
#     F1-score: 0.5565
#     mAP: 0.6478
#   [Ours - DecisionTree]
#     AUROC: 0.9634
#     G-mean: 0.9017
#     MCC: 0.7891
#     F1-score: 0.8001
#     mAP: 0.7784
#   [Ours - kNN]
#     AUROC: 0.8553
#     G-mean: 0.6262
#     MCC: 0.5252
#     F1-score: 0.5170
#     mAP: 0.5221
#   [Ours - MLP]
#     AUROC: 0.9583
#     G-mean: 0.8476
#     MCC: 0.6852
#     F1-score: 0.7020
#     mAP: 0.7190
#   [Ours - RandomForest]
#     AUROC: 0.9966
#     G-mean: 0.8908
#     MCC: 0.8555
#     F1-score: 0.8592
#     mAP: 0.9616
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9460
#     G-mean: 0.8447
#     MCC: 0.5425
#     F1-score: 0.5545
#     mAP: 0.6446
#   [Ours - DecisionTree]
#     AUROC: 0.9630
#     G-mean: 0.9014
#     MCC: 0.7889
#     F1-score: 0.8000
#     mAP: 0.7765
#   [Ours - kNN]
#     AUROC: 0.8573
#     G-mean: 0.6274
#     MCC: 0.5274
#     F1-score: 0.5185
#     mAP: 0.5262
#   [Ours - MLP]
#     AUROC: 0.9584
#     G-mean: 0.8476
#     MCC: 0.6848
#     F1-score: 0.7014
#     mAP: 0.7170
#   [Ours - RandomForest]
#     AUROC: 0.9966
#     G-mean: 0.8907
#     MCC: 0.8549
#     F1-score: 0.8586
#     mAP: 0.9615
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9460
#     G-mean: 0.8454
#     MCC: 0.5433
#     F1-score: 0.5552
#     mAP: 0.6439
#   [Ours - DecisionTree]
#     AUROC: 0.9632
#     G-mean: 0.9021
#     MCC: 0.7895
#     F1-score: 0.8006
#     mAP: 0.7761
#   [Ours - kNN]
#     AUROC: 0.8576
#     G-mean: 0.6270
#     MCC: 0.5279
#     F1-score: 0.5184
#     mAP: 0.5285
#   [Ours - MLP]
#     AUROC: 0.9583
#     G-mean: 0.8474
#     MCC: 0.6836
#     F1-score: 0.7004
#     mAP: 0.7163
#   [Ours - RandomForest]
#     AUROC: 0.9965
#     G-mean: 0.8900
#     MCC: 0.8541
#     F1-score: 0.8577
#     mAP: 0.9614
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/thyroid_sick_results_gaussian_beta_0.001.csv
# beta: 0.0
# Dataset loaded: thyroid_sick
# X shape : (3772, 52)
# target : Counter({0: 3541, 1: 231})
# IR: 15.33
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [Ours - SVM]
#     AUROC: 0.9464
#     G-mean: 0.8432
#     MCC: 0.5489
#     F1-score: 0.5615
#     mAP: 0.6495
#   [Ours - DecisionTree]
#     AUROC: 0.9548
#     G-mean: 0.8989
#     MCC: 0.7890
#     F1-score: 0.7991
#     mAP: 0.7829
#   [Ours - kNN]
#     AUROC: 0.8608
#     G-mean: 0.6118
#     MCC: 0.5069
#     F1-score: 0.4959
#     mAP: 0.5140
#   [Ours - MLP]
#     AUROC: 0.9553
#     G-mean: 0.8379
#     MCC: 0.6763
#     F1-score: 0.6925
#     mAP: 0.7154
#   [Ours - RandomForest]
#     AUROC: 0.9970
#     G-mean: 0.8795
#     MCC: 0.8474
#     F1-score: 0.8498
#     mAP: 0.9632
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [Ours - SVM]
#     AUROC: 0.9465
#     G-mean: 0.8459
#     MCC: 0.5529
#     F1-score: 0.5653
#     mAP: 0.6528
#   [Ours - DecisionTree]
#     AUROC: 0.9624
#     G-mean: 0.9015
#     MCC: 0.7908
#     F1-score: 0.8015
#     mAP: 0.7883
#   [Ours - kNN]
#     AUROC: 0.8574
#     G-mean: 0.6175
#     MCC: 0.5169
#     F1-score: 0.5062
#     mAP: 0.5233
#   [Ours - MLP]
#     AUROC: 0.9575
#     G-mean: 0.8438
#     MCC: 0.6900
#     F1-score: 0.7067
#     mAP: 0.7196
#   [Ours - RandomForest]
#     AUROC: 0.9970
#     G-mean: 0.8873
#     MCC: 0.8548
#     F1-score: 0.8579
#     mAP: 0.9631
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [Ours - SVM]
#     AUROC: 0.9457
#     G-mean: 0.8433
#     MCC: 0.5517
#     F1-score: 0.5652
#     mAP: 0.6451
#   [Ours - DecisionTree]
#     AUROC: 0.9649
#     G-mean: 0.9057
#     MCC: 0.7912
#     F1-score: 0.8015
#     mAP: 0.7880
#   [Ours - kNN]
#     AUROC: 0.8560
#     G-mean: 0.6253
#     MCC: 0.5198
#     F1-score: 0.5131
#     mAP: 0.5202
#   [Ours - MLP]
#     AUROC: 0.9593
#     G-mean: 0.8473
#     MCC: 0.6928
#     F1-score: 0.7097
#     mAP: 0.7235
#   [Ours - RandomForest]
#     AUROC: 0.9967
#     G-mean: 0.8889
#     MCC: 0.8558
#     F1-score: 0.8591
#     mAP: 0.9618
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [Ours - SVM]
#     AUROC: 0.9454
#     G-mean: 0.8438
#     MCC: 0.5502
#     F1-score: 0.5635
#     mAP: 0.6433
#   [Ours - DecisionTree]
#     AUROC: 0.9620
#     G-mean: 0.9006
#     MCC: 0.7876
#     F1-score: 0.7981
#     mAP: 0.7839
#   [Ours - kNN]
#     AUROC: 0.8546
#     G-mean: 0.6212
#     MCC: 0.5181
#     F1-score: 0.5101
#     mAP: 0.5209
#   [Ours - MLP]
#     AUROC: 0.9583
#     G-mean: 0.8473
#     MCC: 0.6899
#     F1-score: 0.7065
#     mAP: 0.7226
#   [Ours - RandomForest]
#     AUROC: 0.9965
#     G-mean: 0.8888
#     MCC: 0.8540
#     F1-score: 0.8576
#     mAP: 0.9605
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [Ours - SVM]
#     AUROC: 0.9457
#     G-mean: 0.8447
#     MCC: 0.5509
#     F1-score: 0.5639
#     mAP: 0.6437
#   [Ours - DecisionTree]
#     AUROC: 0.9604
#     G-mean: 0.8967
#     MCC: 0.7830
#     F1-score: 0.7936
#     mAP: 0.7756
#   [Ours - kNN]
#     AUROC: 0.8551
#     G-mean: 0.6185
#     MCC: 0.5168
#     F1-score: 0.5076
#     mAP: 0.5198
#   [Ours - MLP]
#     AUROC: 0.9592
#     G-mean: 0.8481
#     MCC: 0.6910
#     F1-score: 0.7074
#     mAP: 0.7212
#   [Ours - RandomForest]
#     AUROC: 0.9964
#     G-mean: 0.8905
#     MCC: 0.8561
#     F1-score: 0.8598
#     mAP: 0.9608
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [Ours - SVM]
#     AUROC: 0.9460
#     G-mean: 0.8449
#     MCC: 0.5485
#     F1-score: 0.5612
#     mAP: 0.6455
#   [Ours - DecisionTree]
#     AUROC: 0.9597
#     G-mean: 0.8996
#     MCC: 0.7880
#     F1-score: 0.7986
#     mAP: 0.7765
#   [Ours - kNN]
#     AUROC: 0.8551
#     G-mean: 0.6202
#     MCC: 0.5200
#     F1-score: 0.5103
#     mAP: 0.5225
#   [Ours - MLP]
#     AUROC: 0.9590
#     G-mean: 0.8489
#     MCC: 0.6905
#     F1-score: 0.7067
#     mAP: 0.7192
#   [Ours - RandomForest]
#     AUROC: 0.9964
#     G-mean: 0.8901
#     MCC: 0.8551
#     F1-score: 0.8588
#     mAP: 0.9604
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [Ours - SVM]
#     AUROC: 0.9459
#     G-mean: 0.8439
#     MCC: 0.5476
#     F1-score: 0.5604
#     mAP: 0.6468
#   [Ours - DecisionTree]
#     AUROC: 0.9607
#     G-mean: 0.9001
#     MCC: 0.7855
#     F1-score: 0.7962
#     mAP: 0.7774
#   [Ours - kNN]
#     AUROC: 0.8561
#     G-mean: 0.6227
#     MCC: 0.5228
#     F1-score: 0.5133
#     mAP: 0.5241
#   [Ours - MLP]
#     AUROC: 0.9585
#     G-mean: 0.8492
#     MCC: 0.6914
#     F1-score: 0.7073
#     mAP: 0.7204
#   [Ours - RandomForest]
#     AUROC: 0.9965
#     G-mean: 0.8906
#     MCC: 0.8562
#     F1-score: 0.8597
#     mAP: 0.9612
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [Ours - SVM]
#     AUROC: 0.9458
#     G-mean: 0.8438
#     MCC: 0.5471
#     F1-score: 0.5600
#     mAP: 0.6467
#   [Ours - DecisionTree]
#     AUROC: 0.9608
#     G-mean: 0.8999
#     MCC: 0.7845
#     F1-score: 0.7954
#     mAP: 0.7752
#   [Ours - kNN]
#     AUROC: 0.8558
#     G-mean: 0.6247
#     MCC: 0.5257
#     F1-score: 0.5163
#     mAP: 0.5267
#   [Ours - MLP]
#     AUROC: 0.9581
#     G-mean: 0.8481
#     MCC: 0.6885
#     F1-score: 0.7047
#     mAP: 0.7181
#   [Ours - RandomForest]
#     AUROC: 0.9965
#     G-mean: 0.8906
#     MCC: 0.8558
#     F1-score: 0.8594
#     mAP: 0.9609
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [Ours - SVM]
#     AUROC: 0.9457
#     G-mean: 0.8432
#     MCC: 0.5462
#     F1-score: 0.5591
#     mAP: 0.6435
#   [Ours - DecisionTree]
#     AUROC: 0.9608
#     G-mean: 0.9003
#     MCC: 0.7872
#     F1-score: 0.7982
#     mAP: 0.7745
#   [Ours - kNN]
#     AUROC: 0.8575
#     G-mean: 0.6256
#     MCC: 0.5274
#     F1-score: 0.5174
#     mAP: 0.5296
#   [Ours - MLP]
#     AUROC: 0.9586
#     G-mean: 0.8474
#     MCC: 0.6878
#     F1-score: 0.7041
#     mAP: 0.7175
#   [Ours - RandomForest]
#     AUROC: 0.9965
#     G-mean: 0.8905
#     MCC: 0.8556
#     F1-score: 0.8592
#     mAP: 0.9610
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [Ours - SVM]
#     AUROC: 0.9456
#     G-mean: 0.8444
#     MCC: 0.5475
#     F1-score: 0.5603
#     mAP: 0.6427
#   [Ours - DecisionTree]
#     AUROC: 0.9616
#     G-mean: 0.9021
#     MCC: 0.7903
#     F1-score: 0.8011
#     mAP: 0.7734
#   [Ours - kNN]
#     AUROC: 0.8580
#     G-mean: 0.6254
#     MCC: 0.5273
#     F1-score: 0.5171
#     mAP: 0.5314
#   [Ours - MLP]
#     AUROC: 0.9586
#     G-mean: 0.8468
#     MCC: 0.6873
#     F1-score: 0.7037
#     mAP: 0.7167
#   [Ours - RandomForest]
#     AUROC: 0.9965
#     G-mean: 0.8898
#     MCC: 0.8546
#     F1-score: 0.8581
#     mAP: 0.9610
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/ablation_results/beta8/thyroid_sick_results_gaussian_beta_0.0.csv

# %%
data_name = 'yeast-1-4-5-8_vs_7'

n_epochs = 2000
hidden_dims = [16, 32, 64, 128]
latent_dim = 256
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'yeast4'

n_epochs = 2000
hidden_dims = [16, 32, 64, 128]
latent_dim = 256
lr = 0.001

for beta in betas:
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )

# %%
data_name = 'winequality-red-4'

n_epochs = 2000
hidden_dims = [32, 64, 128, 256]
latent_dim = 512
lr = 0.001

for beta in betas:
    print(f"beta: {beta}")
    run_ablation(
        data_name=data_name,
        beta=beta,
        methods=methods,
        base_models=base_models,
        device=device,
        data_path=data_path,
        save_path=save_path,
        n_epochs=n_epochs,
        hidden_dims=hidden_dims,
        latent_dim=latent_dim,
        lr=lr * (1+100*beta)
    )
