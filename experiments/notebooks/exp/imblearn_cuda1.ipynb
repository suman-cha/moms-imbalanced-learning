# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

import os
import warnings
from imblearn.datasets import fetch_datasets
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from experiment import run_exp

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Save path 
save_path = "/data4/oldrain123/oldrain123/results/real_results"

# %%
data = fetch_datasets()
methods = ["GAMO", "MGVAE"]
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}

# %%
# coil_2000
data_name = 'coil_2000'
maj_target_name = -1

n_epochs = 1000
hidden_dims = [100, 64, 32]
latent_dim = 16
lr = 0.01
beta = 0.001
kernel_type = 'GAMO_MGVAE'

final_res = run_exp(
    data=data, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    kernel_type=kernel_type,
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    maj_target_name=maj_target_name,
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded: coil_2000
# X shape : (9822, 85)
# target : Counter({0: 9236, 1: 586})
# IR: 15.76
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.5986
#     G-mean: 0.1341
#     MCC: 0.0288
#     F1-score: 0.0435
#     mAP: 0.0924
#   [GAMO - DecisionTree]
#     AUROC: 0.7183
#     G-mean: 0.0521
#     MCC: 0.0169
#     F1-score: 0.0127
#     mAP: 0.1509
#   [GAMO - kNN]
#     AUROC: 0.6121
#     G-mean: 0.1267
#     MCC: 0.0545
#     F1-score: 0.0429
#     mAP: 0.0981
#   [GAMO - MLP]
#     AUROC: 0.6889
#     G-mean: 0.1617
#     MCC: 0.0545
#     F1-score: 0.0525
#     mAP: 0.1305
#   [GAMO - RandomForest]
#     AUROC: 0.6975
#     G-mean: 0.2406
#     MCC: 0.0795
#     F1-score: 0.0944
#     mAP: 0.1446
#   [MGVAE - SVM]
#     AUROC: 0.6470
#     G-mean: 0.0000
#     MCC: -0.0008
#     F1-score: 0.0000
#     mAP: 0.1271
#   [MGVAE - DecisionTree]
#     AUROC: 0.7251
#     G-mean: 0.1176
#     MCC: 0.0687
#     F1-score: 0.0438
#     mAP: 0.1548
#   [MGVAE - kNN]
#     AUROC: 0.6119
#     G-mean: 0.1267
#     MCC: 0.0540
#     F1-score: 0.0429
#     mAP: 0.0979
#   [MGVAE - MLP]
#     AUROC: 0.6916
#     G-mean: 0.1802
#     MCC: 0.0643
#     F1-score: 0.0584
#     mAP: 0.1477
#   [MGVAE - RandomForest]
#     AUROC: 0.6971
#     G-mean: 0.2391
#     MCC: 0.0785
#     F1-score: 0.0940
#     mAP: 0.1461
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.5995
#     G-mean: 0.1450
#     MCC: 0.0343
#     F1-score: 0.0479
#     mAP: 0.0923
#   [GAMO - DecisionTree]
#     AUROC: 0.7156
#     G-mean: 0.0634
#     MCC: 0.0344
#     F1-score: 0.0177
#     mAP: 0.1522
#   [GAMO - kNN]
#     AUROC: 0.6169
#     G-mean: 0.1285
#     MCC: 0.0513
#     F1-score: 0.0437
#     mAP: 0.0992
#   [GAMO - MLP]
#     AUROC: 0.6844
#     G-mean: 0.1566
#     MCC: 0.0486
#     F1-score: 0.0493
#     mAP: 0.1284
#   [GAMO - RandomForest]
#     AUROC: 0.7020
#     G-mean: 0.2434
#     MCC: 0.0793
#     F1-score: 0.0951
#     mAP: 0.1454
#   [MGVAE - SVM]
#     AUROC: 0.6463
#     G-mean: 0.0000
#     MCC: -0.0004
#     F1-score: 0.0000
#     mAP: 0.1272
#   [MGVAE - DecisionTree]
#     AUROC: 0.7235
#     G-mean: 0.1026
#     MCC: 0.0583
#     F1-score: 0.0374
#     mAP: 0.1518
#   [MGVAE - kNN]
#     AUROC: 0.6171
#     G-mean: 0.1285
#     MCC: 0.0500
#     F1-score: 0.0436
#     mAP: 0.0988
#   [MGVAE - MLP]
#     AUROC: 0.6957
#     G-mean: 0.1720
#     MCC: 0.0625
#     F1-score: 0.0566
#     mAP: 0.1493
#   [MGVAE - RandomForest]
#     AUROC: 0.6994
#     G-mean: 0.2427
#     MCC: 0.0784
#     F1-score: 0.0950
#     mAP: 0.1450
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.5978
#     G-mean: 0.1444
#     MCC: 0.0354
#     F1-score: 0.0491
#     mAP: 0.0915
#   [GAMO - DecisionTree]
#     AUROC: 0.7187
#     G-mean: 0.0676
#     MCC: 0.0371
#     F1-score: 0.0193
#     mAP: 0.1510
#   [GAMO - kNN]
#     AUROC: 0.6171
#     G-mean: 0.1358
#     MCC: 0.0521
#     F1-score: 0.0458
#     mAP: 0.0988
#   [GAMO - MLP]
#     AUROC: 0.6839
#     G-mean: 0.1568
#     MCC: 0.0467
#     F1-score: 0.0490
#     mAP: 0.1287
#   [GAMO - RandomForest]
#     AUROC: 0.7015
#     G-mean: 0.2424
#     MCC: 0.0809
#     F1-score: 0.0954
#     mAP: 0.1458
#   [MGVAE - SVM]
#     AUROC: 0.6468
#     G-mean: 0.0000
#     MCC: -0.0003
#     F1-score: 0.0000
#     mAP: 0.1265
#   [MGVAE - DecisionTree]
#     AUROC: 0.7255
#     G-mean: 0.1024
#     MCC: 0.0562
#     F1-score: 0.0345
#     mAP: 0.1513
#   [MGVAE - kNN]
#     AUROC: 0.6175
#     G-mean: 0.1357
#     MCC: 0.0508
#     F1-score: 0.0456
#     mAP: 0.0986
#   [MGVAE - MLP]
#     AUROC: 0.6953
#     G-mean: 0.1776
#     MCC: 0.0680
#     F1-score: 0.0616
#     mAP: 0.1491
#   [MGVAE - RandomForest]
#     AUROC: 0.7002
#     G-mean: 0.2429
#     MCC: 0.0804
#     F1-score: 0.0959
#     mAP: 0.1463
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.5972
#     G-mean: 0.1487
#     MCC: 0.0356
#     F1-score: 0.0490
#     mAP: 0.0911
#   [GAMO - DecisionTree]
#     AUROC: 0.7204
#     G-mean: 0.0650
#     MCC: 0.0329
#     F1-score: 0.0184
#     mAP: 0.1502
#   [GAMO - kNN]
#     AUROC: 0.6169
#     G-mean: 0.1378
#     MCC: 0.0527
#     F1-score: 0.0461
#     mAP: 0.0988
#   [GAMO - MLP]
#     AUROC: 0.6833
#     G-mean: 0.1622
#     MCC: 0.0480
#     F1-score: 0.0509
#     mAP: 0.1276
#   [GAMO - RandomForest]
#     AUROC: 0.7013
#     G-mean: 0.2347
#     MCC: 0.0764
#     F1-score: 0.0923
#     mAP: 0.1444
#   [MGVAE - SVM]
#     AUROC: 0.6461
#     G-mean: 0.0000
#     MCC: -0.0006
#     F1-score: 0.0000
#     mAP: 0.1262
#   [MGVAE - DecisionTree]
#     AUROC: 0.7250
#     G-mean: 0.0985
#     MCC: 0.0530
#     F1-score: 0.0331
#     mAP: 0.1504
#   [MGVAE - kNN]
#     AUROC: 0.6171
#     G-mean: 0.1378
#     MCC: 0.0513
#     F1-score: 0.0460
#     mAP: 0.0986
#   [MGVAE - MLP]
#     AUROC: 0.6944
#     G-mean: 0.1760
#     MCC: 0.0696
#     F1-score: 0.0612
#     mAP: 0.1487
#   [MGVAE - RandomForest]
#     AUROC: 0.6998
#     G-mean: 0.2356
#     MCC: 0.0765
#     F1-score: 0.0928
#     mAP: 0.1445
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.5963
#     G-mean: 0.1506
#     MCC: 0.0357
#     F1-score: 0.0491
#     mAP: 0.0909
#   [GAMO - DecisionTree]
#     AUROC: 0.7200
#     G-mean: 0.0662
#     MCC: 0.0330
#     F1-score: 0.0185
#     mAP: 0.1505
#   [GAMO - kNN]
#     AUROC: 0.6151
#     G-mean: 0.1345
#     MCC: 0.0519
#     F1-score: 0.0457
#     mAP: 0.0985
#   [GAMO - MLP]
#     AUROC: 0.6830
#     G-mean: 0.1632
#     MCC: 0.0487
#     F1-score: 0.0511
#     mAP: 0.1277
#   [GAMO - RandomForest]
#     AUROC: 0.7008
#     G-mean: 0.2337
#     MCC: 0.0740
#     F1-score: 0.0903
#     mAP: 0.1437
#   [MGVAE - SVM]
#     AUROC: 0.6450
#     G-mean: 0.0026
#     MCC: 0.0020
#     F1-score: 0.0007
#     mAP: 0.1255
#   [MGVAE - DecisionTree]
#     AUROC: 0.7253
#     G-mean: 0.1026
#     MCC: 0.0571
#     F1-score: 0.0345
#     mAP: 0.1514
#   [MGVAE - kNN]
#     AUROC: 0.6152
#     G-mean: 0.1344
#     MCC: 0.0506
#     F1-score: 0.0456
#     mAP: 0.0982
#   [MGVAE - MLP]
#     AUROC: 0.6939
#     G-mean: 0.1765
#     MCC: 0.0704
#     F1-score: 0.0610
#     mAP: 0.1494
#   [MGVAE - RandomForest]
#     AUROC: 0.6995
#     G-mean: 0.2365
#     MCC: 0.0758
#     F1-score: 0.0922
#     mAP: 0.1437
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.5971
#     G-mean: 0.1511
#     MCC: 0.0363
#     F1-score: 0.0492
#     mAP: 0.0911
#   [GAMO - DecisionTree]
#     AUROC: 0.7200
#     G-mean: 0.0660
#     MCC: 0.0317
#     F1-score: 0.0181
#     mAP: 0.1491
#   [GAMO - kNN]
#     AUROC: 0.6148
#     G-mean: 0.1371
#     MCC: 0.0518
#     F1-score: 0.0459
#     mAP: 0.0983
#   [GAMO - MLP]
#     AUROC: 0.6813
#     G-mean: 0.1585
#     MCC: 0.0480
#     F1-score: 0.0505
#     mAP: 0.1278
#   [GAMO - RandomForest]
#     AUROC: 0.7015
#     G-mean: 0.2340
#     MCC: 0.0744
#     F1-score: 0.0903
#     mAP: 0.1449
#   [MGVAE - SVM]
#     AUROC: 0.6460
#     G-mean: 0.0022
#     MCC: 0.0017
#     F1-score: 0.0006
#     mAP: 0.1266
#   [MGVAE - DecisionTree]
#     AUROC: 0.7261
#     G-mean: 0.1026
#     MCC: 0.0590
#     F1-score: 0.0336
#     mAP: 0.1515
#   [MGVAE - kNN]
#     AUROC: 0.6148
#     G-mean: 0.1371
#     MCC: 0.0504
#     F1-score: 0.0458
#     mAP: 0.0978
#   [MGVAE - MLP]
#     AUROC: 0.6939
#     G-mean: 0.1793
#     MCC: 0.0727
#     F1-score: 0.0634
#     mAP: 0.1484
#   [MGVAE - RandomForest]
#     AUROC: 0.7005
#     G-mean: 0.2373
#     MCC: 0.0763
#     F1-score: 0.0926
#     mAP: 0.1450
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.5971
#     G-mean: 0.1523
#     MCC: 0.0364
#     F1-score: 0.0493
#     mAP: 0.0912
#   [GAMO - DecisionTree]
#     AUROC: 0.7196
#     G-mean: 0.0640
#     MCC: 0.0308
#     F1-score: 0.0174
#     mAP: 0.1494
#   [GAMO - kNN]
#     AUROC: 0.6136
#     G-mean: 0.1406
#     MCC: 0.0527
#     F1-score: 0.0463
#     mAP: 0.0979
#   [GAMO - MLP]
#     AUROC: 0.6816
#     G-mean: 0.1583
#     MCC: 0.0481
#     F1-score: 0.0512
#     mAP: 0.1273
#   [GAMO - RandomForest]
#     AUROC: 0.7010
#     G-mean: 0.2351
#     MCC: 0.0752
#     F1-score: 0.0906
#     mAP: 0.1446
#   [MGVAE - SVM]
#     AUROC: 0.6458
#     G-mean: 0.0037
#     MCC: 0.0033
#     F1-score: 0.0009
#     mAP: 0.1260
#   [MGVAE - DecisionTree]
#     AUROC: 0.7246
#     G-mean: 0.1006
#     MCC: 0.0566
#     F1-score: 0.0325
#     mAP: 0.1513
#   [MGVAE - kNN]
#     AUROC: 0.6137
#     G-mean: 0.1406
#     MCC: 0.0513
#     F1-score: 0.0462
#     mAP: 0.0975
#   [MGVAE - MLP]
#     AUROC: 0.6957
#     G-mean: 0.1775
#     MCC: 0.0709
#     F1-score: 0.0616
#     mAP: 0.1489
#   [MGVAE - RandomForest]
#     AUROC: 0.7000
#     G-mean: 0.2386
#     MCC: 0.0771
#     F1-score: 0.0929
#     mAP: 0.1448
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.5971
#     G-mean: 0.1533
#     MCC: 0.0363
#     F1-score: 0.0493
#     mAP: 0.0912
#   [GAMO - DecisionTree]
#     AUROC: 0.7193
#     G-mean: 0.0625
#     MCC: 0.0298
#     F1-score: 0.0169
#     mAP: 0.1493
#   [GAMO - kNN]
#     AUROC: 0.6125
#     G-mean: 0.1398
#     MCC: 0.0522
#     F1-score: 0.0458
#     mAP: 0.0974
#   [GAMO - MLP]
#     AUROC: 0.6826
#     G-mean: 0.1547
#     MCC: 0.0454
#     F1-score: 0.0494
#     mAP: 0.1276
#   [GAMO - RandomForest]
#     AUROC: 0.7000
#     G-mean: 0.2320
#     MCC: 0.0735
#     F1-score: 0.0890
#     mAP: 0.1436
#   [MGVAE - SVM]
#     AUROC: 0.6459
#     G-mean: 0.0032
#     MCC: 0.0029
#     F1-score: 0.0008
#     mAP: 0.1263
#   [MGVAE - DecisionTree]
#     AUROC: 0.7247
#     G-mean: 0.1048
#     MCC: 0.0593
#     F1-score: 0.0347
#     mAP: 0.1517
#   [MGVAE - kNN]
#     AUROC: 0.6127
#     G-mean: 0.1397
#     MCC: 0.0510
#     F1-score: 0.0457
#     mAP: 0.0971
#   [MGVAE - MLP]
#     AUROC: 0.6963
#     G-mean: 0.1762
#     MCC: 0.0695
#     F1-score: 0.0611
#     mAP: 0.1488
#   [MGVAE - RandomForest]
#     AUROC: 0.6995
#     G-mean: 0.2372
#     MCC: 0.0766
#     F1-score: 0.0924
#     mAP: 0.1442
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.5966
#     G-mean: 0.1531
#     MCC: 0.0357
#     F1-score: 0.0487
#     mAP: 0.0907
#   [GAMO - DecisionTree]
#     AUROC: 0.7187
#     G-mean: 0.0649
#     MCC: 0.0320
#     F1-score: 0.0175
#     mAP: 0.1491
#   [GAMO - kNN]
#     AUROC: 0.6118
#     G-mean: 0.1391
#     MCC: 0.0517
#     F1-score: 0.0454
#     mAP: 0.0972
#   [GAMO - MLP]
#     AUROC: 0.6817
#     G-mean: 0.1494
#     MCC: 0.0425
#     F1-score: 0.0471
#     mAP: 0.1268
#   [GAMO - RandomForest]
#     AUROC: 0.7005
#     G-mean: 0.2319
#     MCC: 0.0727
#     F1-score: 0.0884
#     mAP: 0.1440
#   [MGVAE - SVM]
#     AUROC: 0.6452
#     G-mean: 0.0029
#     MCC: 0.0025
#     F1-score: 0.0007
#     mAP: 0.1256
#   [MGVAE - DecisionTree]
#     AUROC: 0.7255
#     G-mean: 0.1051
#     MCC: 0.0591
#     F1-score: 0.0343
#     mAP: 0.1519
#   [MGVAE - kNN]
#     AUROC: 0.6120
#     G-mean: 0.1391
#     MCC: 0.0504
#     F1-score: 0.0452
#     mAP: 0.0968
#   [MGVAE - MLP]
#     AUROC: 0.6954
#     G-mean: 0.1740
#     MCC: 0.0687
#     F1-score: 0.0599
#     mAP: 0.1491
#   [MGVAE - RandomForest]
#     AUROC: 0.6999
#     G-mean: 0.2378
#     MCC: 0.0766
#     F1-score: 0.0925
#     mAP: 0.1445
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.5971
#     G-mean: 0.1541
#     MCC: 0.0356
#     F1-score: 0.0486
#     mAP: 0.0906
#   [GAMO - DecisionTree]
#     AUROC: 0.7193
#     G-mean: 0.0655
#     MCC: 0.0325
#     F1-score: 0.0177
#     mAP: 0.1490
#   [GAMO - kNN]
#     AUROC: 0.6123
#     G-mean: 0.1388
#     MCC: 0.0508
#     F1-score: 0.0450
#     mAP: 0.0973
#   [GAMO - MLP]
#     AUROC: 0.6815
#     G-mean: 0.1527
#     MCC: 0.0443
#     F1-score: 0.0486
#     mAP: 0.1272
#   [GAMO - RandomForest]
#     AUROC: 0.7012
#     G-mean: 0.2329
#     MCC: 0.0735
#     F1-score: 0.0890
#     mAP: 0.1449
#   [MGVAE - SVM]
#     AUROC: 0.6447
#     G-mean: 0.0026
#     MCC: 0.0022
#     F1-score: 0.0007
#     mAP: 0.1254
#   [MGVAE - DecisionTree]
#     AUROC: 0.7258
#     G-mean: 0.1065
#     MCC: 0.0587
#     F1-score: 0.0349
#     mAP: 0.1520
#   [MGVAE - kNN]
#     AUROC: 0.6123
#     G-mean: 0.1387
#     MCC: 0.0495
#     F1-score: 0.0449
#     mAP: 0.0968
#   [MGVAE - MLP]
#     AUROC: 0.6950
#     G-mean: 0.1726
#     MCC: 0.0675
#     F1-score: 0.0592
#     mAP: 0.1487
#   [MGVAE - RandomForest]
#     AUROC: 0.7002
#     G-mean: 0.2383
#     MCC: 0.0771
#     F1-score: 0.0930
#     mAP: 0.1453
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/coil_2000_results_GAMO_MGVAE_beta_0.001.csv

# %%
# libras_move
data_name = 'libras_move'
maj_target_name = -1

n_epochs = 1000
hidden_dims = [16, 32, 64, 128]
latent_dim = 256
lr = 0.005
beta = 0.001

final_res = run_exp(
    data=data, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    kernel_type=kernel_type,
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    maj_target_name=maj_target_name,
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded: libras_move
# X shape : (360, 90)
# target : Counter({0: 336, 1: 24})
# IR: 14.0
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.9852
#     G-mean: 0.9019
#     MCC: 0.8687
#     F1-score: 0.8657
#     mAP: 0.9126
#   [GAMO - DecisionTree]
#     AUROC: 0.6783
#     G-mean: 0.6045
#     MCC: 0.4413
#     F1-score: 0.4619
#     mAP: 0.4266
#   [GAMO - kNN]
#     AUROC: 0.9778
#     G-mean: 0.7340
#     MCC: 0.7306
#     F1-score: 0.7267
#     mAP: 0.8894
#   [GAMO - MLP]
#     AUROC: 0.9848
#     G-mean: 0.9047
#     MCC: 0.7027
#     F1-score: 0.7048
#     mAP: 0.8843
#   [GAMO - RandomForest]
#     AUROC: 0.9809
#     G-mean: 0.8922
#     MCC: 0.8748
#     F1-score: 0.8657
#     mAP: 0.9258
#   [MGVAE - SVM]
#     AUROC: 0.9707
#     G-mean: 0.8754
#     MCC: 0.8700
#     F1-score: 0.8600
#     mAP: 0.9698
#   [MGVAE - DecisionTree]
#     AUROC: 0.7479
#     G-mean: 0.6267
#     MCC: 0.5308
#     F1-score: 0.5383
#     mAP: 0.4350
#   [MGVAE - kNN]
#     AUROC: 0.9752
#     G-mean: 0.7325
#     MCC: 0.7110
#     F1-score: 0.7067
#     mAP: 0.8561
#   [MGVAE - MLP]
#     AUROC: 0.9541
#     G-mean: 0.7846
#     MCC: 0.6508
#     F1-score: 0.6624
#     mAP: 0.7613
#   [MGVAE - RandomForest]
#     AUROC: 0.9901
#     G-mean: 0.7047
#     MCC: 0.7003
#     F1-score: 0.6933
#     mAP: 0.9083
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.9854
#     G-mean: 0.8679
#     MCC: 0.8497
#     F1-score: 0.8462
#     mAP: 0.9268
#   [GAMO - DecisionTree]
#     AUROC: 0.7284
#     G-mean: 0.6184
#     MCC: 0.4300
#     F1-score: 0.4497
#     mAP: 0.3922
#   [GAMO - kNN]
#     AUROC: 0.9733
#     G-mean: 0.7129
#     MCC: 0.7086
#     F1-score: 0.7017
#     mAP: 0.8878
#   [GAMO - MLP]
#     AUROC: 0.9825
#     G-mean: 0.9088
#     MCC: 0.7608
#     F1-score: 0.7591
#     mAP: 0.8830
#   [GAMO - RandomForest]
#     AUROC: 0.9834
#     G-mean: 0.8723
#     MCC: 0.8624
#     F1-score: 0.8562
#     mAP: 0.9492
#   [MGVAE - SVM]
#     AUROC: 0.9621
#     G-mean: 0.8400
#     MCC: 0.8352
#     F1-score: 0.8266
#     mAP: 0.9572
#   [MGVAE - DecisionTree]
#     AUROC: 0.7771
#     G-mean: 0.6583
#     MCC: 0.5690
#     F1-score: 0.5686
#     mAP: 0.4761
#   [MGVAE - kNN]
#     AUROC: 0.9706
#     G-mean: 0.7213
#     MCC: 0.7086
#     F1-score: 0.7017
#     mAP: 0.8627
#   [MGVAE - MLP]
#     AUROC: 0.9644
#     G-mean: 0.8052
#     MCC: 0.6746
#     F1-score: 0.6750
#     mAP: 0.8148
#   [MGVAE - RandomForest]
#     AUROC: 0.9943
#     G-mean: 0.7193
#     MCC: 0.7155
#     F1-score: 0.7100
#     mAP: 0.9458
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.9845
#     G-mean: 0.8623
#     MCC: 0.8442
#     F1-score: 0.8419
#     mAP: 0.9218
#   [GAMO - DecisionTree]
#     AUROC: 0.7526
#     G-mean: 0.6104
#     MCC: 0.4125
#     F1-score: 0.4351
#     mAP: 0.3649
#   [GAMO - kNN]
#     AUROC: 0.9623
#     G-mean: 0.7041
#     MCC: 0.6993
#     F1-score: 0.6922
#     mAP: 0.8601
#   [GAMO - MLP]
#     AUROC: 0.9808
#     G-mean: 0.8987
#     MCC: 0.7420
#     F1-score: 0.7446
#     mAP: 0.8734
#   [GAMO - RandomForest]
#     AUROC: 0.9818
#     G-mean: 0.8892
#     MCC: 0.8816
#     F1-score: 0.8752
#     mAP: 0.9450
#   [MGVAE - SVM]
#     AUROC: 0.9596
#     G-mean: 0.8222
#     MCC: 0.8170
#     F1-score: 0.8089
#     mAP: 0.9441
#   [MGVAE - DecisionTree]
#     AUROC: 0.7807
#     G-mean: 0.6632
#     MCC: 0.5639
#     F1-score: 0.5691
#     mAP: 0.4808
#   [MGVAE - kNN]
#     AUROC: 0.9587
#     G-mean: 0.7092
#     MCC: 0.6937
#     F1-score: 0.6878
#     mAP: 0.8232
#   [MGVAE - MLP]
#     AUROC: 0.9524
#     G-mean: 0.7616
#     MCC: 0.6399
#     F1-score: 0.6478
#     mAP: 0.7707
#   [MGVAE - RandomForest]
#     AUROC: 0.9942
#     G-mean: 0.6986
#     MCC: 0.6938
#     F1-score: 0.6867
#     mAP: 0.9416
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.9850
#     G-mean: 0.8669
#     MCC: 0.8521
#     F1-score: 0.8473
#     mAP: 0.9237
#   [GAMO - DecisionTree]
#     AUROC: 0.7460
#     G-mean: 0.6130
#     MCC: 0.4300
#     F1-score: 0.4444
#     mAP: 0.3676
#   [GAMO - kNN]
#     AUROC: 0.9649
#     G-mean: 0.7290
#     MCC: 0.7234
#     F1-score: 0.7133
#     mAP: 0.8597
#   [GAMO - MLP]
#     AUROC: 0.9831
#     G-mean: 0.9019
#     MCC: 0.7463
#     F1-score: 0.7475
#     mAP: 0.8874
#   [GAMO - RandomForest]
#     AUROC: 0.9845
#     G-mean: 0.8752
#     MCC: 0.8677
#     F1-score: 0.8589
#     mAP: 0.9462
#   [MGVAE - SVM]
#     AUROC: 0.9627
#     G-mean: 0.8322
#     MCC: 0.8268
#     F1-score: 0.8175
#     mAP: 0.9505
#   [MGVAE - DecisionTree]
#     AUROC: 0.8027
#     G-mean: 0.7099
#     MCC: 0.5945
#     F1-score: 0.6008
#     mAP: 0.5009
#   [MGVAE - kNN]
#     AUROC: 0.9610
#     G-mean: 0.7329
#     MCC: 0.7192
#     F1-score: 0.7100
#     mAP: 0.8220
#   [MGVAE - MLP]
#     AUROC: 0.9591
#     G-mean: 0.7921
#     MCC: 0.6778
#     F1-score: 0.6826
#     mAP: 0.8055
#   [MGVAE - RandomForest]
#     AUROC: 0.9938
#     G-mean: 0.7249
#     MCC: 0.7193
#     F1-score: 0.7092
#     mAP: 0.9412
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.9861
#     G-mean: 0.8618
#     MCC: 0.8496
#     F1-score: 0.8445
#     mAP: 0.9279
#   [GAMO - DecisionTree]
#     AUROC: 0.7587
#     G-mean: 0.6322
#     MCC: 0.4399
#     F1-score: 0.4556
#     mAP: 0.3688
#   [GAMO - kNN]
#     AUROC: 0.9678
#     G-mean: 0.7278
#     MCC: 0.7227
#     F1-score: 0.7133
#     mAP: 0.8722
#   [GAMO - MLP]
#     AUROC: 0.9846
#     G-mean: 0.8897
#     MCC: 0.7362
#     F1-score: 0.7348
#     mAP: 0.8972
#   [GAMO - RandomForest]
#     AUROC: 0.9827
#     G-mean: 0.8765
#     MCC: 0.8702
#     F1-score: 0.8631
#     mAP: 0.9399
#   [MGVAE - SVM]
#     AUROC: 0.9657
#     G-mean: 0.8258
#     MCC: 0.8215
#     F1-score: 0.8140
#     mAP: 0.9546
#   [MGVAE - DecisionTree]
#     AUROC: 0.7970
#     G-mean: 0.6913
#     MCC: 0.5869
#     F1-score: 0.5918
#     mAP: 0.5026
#   [MGVAE - kNN]
#     AUROC: 0.9643
#     G-mean: 0.7309
#     MCC: 0.7193
#     F1-score: 0.7107
#     mAP: 0.8394
#   [MGVAE - MLP]
#     AUROC: 0.9612
#     G-mean: 0.8031
#     MCC: 0.6904
#     F1-score: 0.6912
#     mAP: 0.8112
#   [MGVAE - RandomForest]
#     AUROC: 0.9932
#     G-mean: 0.7141
#     MCC: 0.7093
#     F1-score: 0.7007
#     mAP: 0.9375
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.9845
#     G-mean: 0.8672
#     MCC: 0.8562
#     F1-score: 0.8504
#     mAP: 0.9233
#   [GAMO - DecisionTree]
#     AUROC: 0.7672
#     G-mean: 0.6622
#     MCC: 0.4598
#     F1-score: 0.4758
#     mAP: 0.3768
#   [GAMO - kNN]
#     AUROC: 0.9675
#     G-mean: 0.7403
#     MCC: 0.7316
#     F1-score: 0.7206
#     mAP: 0.8737
#   [GAMO - MLP]
#     AUROC: 0.9844
#     G-mean: 0.8902
#     MCC: 0.7301
#     F1-score: 0.7297
#     mAP: 0.8987
#   [GAMO - RandomForest]
#     AUROC: 0.9792
#     G-mean: 0.8843
#     MCC: 0.8785
#     F1-score: 0.8715
#     mAP: 0.9356
#   [MGVAE - SVM]
#     AUROC: 0.9646
#     G-mean: 0.8341
#     MCC: 0.8295
#     F1-score: 0.8217
#     mAP: 0.9502
#   [MGVAE - DecisionTree]
#     AUROC: 0.7988
#     G-mean: 0.6988
#     MCC: 0.5940
#     F1-score: 0.5977
#     mAP: 0.5031
#   [MGVAE - kNN]
#     AUROC: 0.9641
#     G-mean: 0.7429
#     MCC: 0.7288
#     F1-score: 0.7184
#     mAP: 0.8450
#   [MGVAE - MLP]
#     AUROC: 0.9598
#     G-mean: 0.8091
#     MCC: 0.6885
#     F1-score: 0.6909
#     mAP: 0.8138
#   [MGVAE - RandomForest]
#     AUROC: 0.9934
#     G-mean: 0.7330
#     MCC: 0.7278
#     F1-score: 0.7184
#     mAP: 0.9401
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.9840
#     G-mean: 0.8705
#     MCC: 0.8561
#     F1-score: 0.8497
#     mAP: 0.9214
#   [GAMO - DecisionTree]
#     AUROC: 0.7585
#     G-mean: 0.6512
#     MCC: 0.4435
#     F1-score: 0.4609
#     mAP: 0.3622
#   [GAMO - kNN]
#     AUROC: 0.9676
#     G-mean: 0.7352
#     MCC: 0.7271
#     F1-score: 0.7167
#     mAP: 0.8752
#   [GAMO - MLP]
#     AUROC: 0.9851
#     G-mean: 0.8926
#     MCC: 0.7353
#     F1-score: 0.7329
#     mAP: 0.9027
#   [GAMO - RandomForest]
#     AUROC: 0.9784
#     G-mean: 0.8855
#     MCC: 0.8768
#     F1-score: 0.8703
#     mAP: 0.9317
#   [MGVAE - SVM]
#     AUROC: 0.9634
#     G-mean: 0.8400
#     MCC: 0.8353
#     F1-score: 0.8271
#     mAP: 0.9506
#   [MGVAE - DecisionTree]
#     AUROC: 0.7981
#     G-mean: 0.7008
#     MCC: 0.5932
#     F1-score: 0.5970
#     mAP: 0.4998
#   [MGVAE - kNN]
#     AUROC: 0.9642
#     G-mean: 0.7374
#     MCC: 0.7247
#     F1-score: 0.7148
#     mAP: 0.8448
#   [MGVAE - MLP]
#     AUROC: 0.9602
#     G-mean: 0.8100
#     MCC: 0.6820
#     F1-score: 0.6842
#     mAP: 0.8210
#   [MGVAE - RandomForest]
#     AUROC: 0.9926
#     G-mean: 0.7248
#     MCC: 0.7195
#     F1-score: 0.7100
#     mAP: 0.9349
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.9832
#     G-mean: 0.8767
#     MCC: 0.8601
#     F1-score: 0.8535
#     mAP: 0.9202
#   [GAMO - DecisionTree]
#     AUROC: 0.7580
#     G-mean: 0.6421
#     MCC: 0.4338
#     F1-score: 0.4520
#     mAP: 0.3618
#   [GAMO - kNN]
#     AUROC: 0.9671
#     G-mean: 0.7238
#     MCC: 0.7160
#     F1-score: 0.7042
#     mAP: 0.8691
#   [GAMO - MLP]
#     AUROC: 0.9857
#     G-mean: 0.8942
#     MCC: 0.7368
#     F1-score: 0.7337
#     mAP: 0.9066
#   [GAMO - RandomForest]
#     AUROC: 0.9793
#     G-mean: 0.8777
#     MCC: 0.8697
#     F1-score: 0.8632
#     mAP: 0.9305
#   [MGVAE - SVM]
#     AUROC: 0.9625
#     G-mean: 0.8392
#     MCC: 0.8347
#     F1-score: 0.8271
#     mAP: 0.9499
#   [MGVAE - DecisionTree]
#     AUROC: 0.8026
#     G-mean: 0.7097
#     MCC: 0.5980
#     F1-score: 0.6019
#     mAP: 0.5033
#   [MGVAE - kNN]
#     AUROC: 0.9639
#     G-mean: 0.7257
#     MCC: 0.7139
#     F1-score: 0.7025
#     mAP: 0.8424
#   [MGVAE - MLP]
#     AUROC: 0.9606
#     G-mean: 0.8119
#     MCC: 0.6832
#     F1-score: 0.6857
#     mAP: 0.8208
#   [MGVAE - RandomForest]
#     AUROC: 0.9924
#     G-mean: 0.7216
#     MCC: 0.7165
#     F1-score: 0.7067
#     mAP: 0.9347
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.9834
#     G-mean: 0.8798
#     MCC: 0.8646
#     F1-score: 0.8579
#     mAP: 0.9228
#   [GAMO - DecisionTree]
#     AUROC: 0.7612
#     G-mean: 0.6340
#     MCC: 0.4351
#     F1-score: 0.4538
#     mAP: 0.3686
#   [GAMO - kNN]
#     AUROC: 0.9678
#     G-mean: 0.7318
#     MCC: 0.7222
#     F1-score: 0.7111
#     mAP: 0.8649
#   [GAMO - MLP]
#     AUROC: 0.9860
#     G-mean: 0.8954
#     MCC: 0.7381
#     F1-score: 0.7348
#     mAP: 0.9108
#   [GAMO - RandomForest]
#     AUROC: 0.9794
#     G-mean: 0.8728
#     MCC: 0.8654
#     F1-score: 0.8591
#     mAP: 0.9298
#   [MGVAE - SVM]
#     AUROC: 0.9632
#     G-mean: 0.8339
#     MCC: 0.8294
#     F1-score: 0.8215
#     mAP: 0.9494
#   [MGVAE - DecisionTree]
#     AUROC: 0.8076
#     G-mean: 0.7225
#     MCC: 0.6112
#     F1-score: 0.6147
#     mAP: 0.5148
#   [MGVAE - kNN]
#     AUROC: 0.9647
#     G-mean: 0.7334
#     MCC: 0.7184
#     F1-score: 0.7082
#     mAP: 0.8384
#   [MGVAE - MLP]
#     AUROC: 0.9605
#     G-mean: 0.8021
#     MCC: 0.6743
#     F1-score: 0.6772
#     mAP: 0.8204
#   [MGVAE - RandomForest]
#     AUROC: 0.9920
#     G-mean: 0.7230
#     MCC: 0.7181
#     F1-score: 0.7089
#     mAP: 0.9315
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.9830
#     G-mean: 0.8771
#     MCC: 0.8631
#     F1-score: 0.8568
#     mAP: 0.9205
#   [GAMO - DecisionTree]
#     AUROC: 0.7698
#     G-mean: 0.6407
#     MCC: 0.4421
#     F1-score: 0.4600
#     mAP: 0.3734
#   [GAMO - kNN]
#     AUROC: 0.9651
#     G-mean: 0.7291
#     MCC: 0.7200
#     F1-score: 0.7093
#     mAP: 0.8580
#   [GAMO - MLP]
#     AUROC: 0.9858
#     G-mean: 0.8927
#     MCC: 0.7387
#     F1-score: 0.7364
#     mAP: 0.9105
#   [GAMO - RandomForest]
#     AUROC: 0.9792
#     G-mean: 0.8778
#     MCC: 0.8708
#     F1-score: 0.8646
#     mAP: 0.9304
#   [MGVAE - SVM]
#     AUROC: 0.9625
#     G-mean: 0.8329
#     MCC: 0.8284
#     F1-score: 0.8207
#     mAP: 0.9473
#   [MGVAE - DecisionTree]
#     AUROC: 0.8069
#     G-mean: 0.7236
#     MCC: 0.6072
#     F1-score: 0.6118
#     mAP: 0.5081
#   [MGVAE - kNN]
#     AUROC: 0.9620
#     G-mean: 0.7305
#     MCC: 0.7166
#     F1-score: 0.7067
#     mAP: 0.8330
#   [MGVAE - MLP]
#     AUROC: 0.9610
#     G-mean: 0.7957
#     MCC: 0.6690
#     F1-score: 0.6738
#     mAP: 0.8186
#   [MGVAE - RandomForest]
#     AUROC: 0.9921
#     G-mean: 0.7182
#     MCC: 0.7133
#     F1-score: 0.7040
#     mAP: 0.9300
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/libras_move_results_GAMO_MGVAE_beta_0.001.csv
