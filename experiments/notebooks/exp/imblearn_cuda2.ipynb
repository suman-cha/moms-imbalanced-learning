# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

import os
import warnings
from imblearn.datasets import fetch_datasets
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from experiment import run_exp

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Save path 
save_path = "/data4/oldrain123/oldrain123/results/real_results"

# %%
data = fetch_datasets()
methods = ["GAMO", "MGVAE"]
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}

kernel_type = 'GAMO_MGVAE'

# %%
# optical_digits
data_name = 'optical_digits'
maj_target_name = -1

n_epochs = 1000
hidden_dims = [32, 64, 128, 256]
latent_dim = 512
lr = 0.005
beta = 0.001

final_res = run_exp(
    data=data, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    kernel_type=kernel_type,
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    maj_target_name=maj_target_name,
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded: optical_digits
# X shape : (5620, 64)
# target : Counter({0: 5066, 1: 554})
# IR: 9.14
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.9985
#     G-mean: 0.9767
#     MCC: 0.9385
#     F1-score: 0.9444
#     mAP: 0.9859
#   [GAMO - DecisionTree]
#     AUROC: 0.9219
#     G-mean: 0.7663
#     MCC: 0.6361
#     F1-score: 0.6610
#     mAP: 0.6373
#   [GAMO - kNN]
#     AUROC: 0.9932
#     G-mean: 0.9734
#     MCC: 0.9615
#     F1-score: 0.9650
#     mAP: 0.9841
#   [GAMO - MLP]
#     AUROC: 0.9975
#     G-mean: 0.9688
#     MCC: 0.9328
#     F1-score: 0.9392
#     mAP: 0.9675
#   [GAMO - RandomForest]
#     AUROC: 0.9992
#     G-mean: 0.9019
#     MCC: 0.8929
#     F1-score: 0.8968
#     mAP: 0.9934
#   [MGVAE - SVM]
#     AUROC: 0.9988
#     G-mean: 0.9767
#     MCC: 0.9707
#     F1-score: 0.9732
#     mAP: 0.9939
#   [MGVAE - DecisionTree]
#     AUROC: 0.9421
#     G-mean: 0.8163
#     MCC: 0.6843
#     F1-score: 0.7125
#     mAP: 0.7230
#   [MGVAE - kNN]
#     AUROC: 0.9932
#     G-mean: 0.9736
#     MCC: 0.9636
#     F1-score: 0.9668
#     mAP: 0.9830
#   [MGVAE - MLP]
#     AUROC: 0.9981
#     G-mean: 0.9581
#     MCC: 0.9341
#     F1-score: 0.9399
#     mAP: 0.9865
#   [MGVAE - RandomForest]
#     AUROC: 0.9993
#     G-mean: 0.8987
#     MCC: 0.8895
#     F1-score: 0.8932
#     mAP: 0.9942
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.9984
#     G-mean: 0.9764
#     MCC: 0.9394
#     F1-score: 0.9451
#     mAP: 0.9850
#   [GAMO - DecisionTree]
#     AUROC: 0.9221
#     G-mean: 0.7620
#     MCC: 0.6303
#     F1-score: 0.6565
#     mAP: 0.6338
#   [GAMO - kNN]
#     AUROC: 0.9931
#     G-mean: 0.9720
#     MCC: 0.9600
#     F1-score: 0.9636
#     mAP: 0.9822
#   [GAMO - MLP]
#     AUROC: 0.9977
#     G-mean: 0.9678
#     MCC: 0.9314
#     F1-score: 0.9379
#     mAP: 0.9728
#   [GAMO - RandomForest]
#     AUROC: 0.9992
#     G-mean: 0.8999
#     MCC: 0.8907
#     F1-score: 0.8945
#     mAP: 0.9935
#   [MGVAE - SVM]
#     AUROC: 0.9987
#     G-mean: 0.9763
#     MCC: 0.9702
#     F1-score: 0.9728
#     mAP: 0.9936
#   [MGVAE - DecisionTree]
#     AUROC: 0.9388
#     G-mean: 0.8215
#     MCC: 0.6803
#     F1-score: 0.7095
#     mAP: 0.7195
#   [MGVAE - kNN]
#     AUROC: 0.9931
#     G-mean: 0.9722
#     MCC: 0.9620
#     F1-score: 0.9653
#     mAP: 0.9811
#   [MGVAE - MLP]
#     AUROC: 0.9980
#     G-mean: 0.9609
#     MCC: 0.9412
#     F1-score: 0.9464
#     mAP: 0.9878
#   [MGVAE - RandomForest]
#     AUROC: 0.9993
#     G-mean: 0.8988
#     MCC: 0.8896
#     F1-score: 0.8934
#     mAP: 0.9940
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.9984
#     G-mean: 0.9749
#     MCC: 0.9363
#     F1-score: 0.9425
#     mAP: 0.9852
#   [GAMO - DecisionTree]
#     AUROC: 0.9236
#     G-mean: 0.7619
#     MCC: 0.6256
#     F1-score: 0.6534
#     mAP: 0.6327
#   [GAMO - kNN]
#     AUROC: 0.9931
#     G-mean: 0.9715
#     MCC: 0.9595
#     F1-score: 0.9631
#     mAP: 0.9819
#   [GAMO - MLP]
#     AUROC: 0.9979
#     G-mean: 0.9704
#     MCC: 0.9355
#     F1-score: 0.9416
#     mAP: 0.9760
#   [GAMO - RandomForest]
#     AUROC: 0.9993
#     G-mean: 0.8982
#     MCC: 0.8890
#     F1-score: 0.8928
#     mAP: 0.9939
#   [MGVAE - SVM]
#     AUROC: 0.9987
#     G-mean: 0.9752
#     MCC: 0.9693
#     F1-score: 0.9719
#     mAP: 0.9937
#   [MGVAE - DecisionTree]
#     AUROC: 0.9392
#     G-mean: 0.8244
#     MCC: 0.6891
#     F1-score: 0.7172
#     mAP: 0.7267
#   [MGVAE - kNN]
#     AUROC: 0.9931
#     G-mean: 0.9717
#     MCC: 0.9615
#     F1-score: 0.9648
#     mAP: 0.9809
#   [MGVAE - MLP]
#     AUROC: 0.9981
#     G-mean: 0.9605
#     MCC: 0.9411
#     F1-score: 0.9463
#     mAP: 0.9878
#   [MGVAE - RandomForest]
#     AUROC: 0.9994
#     G-mean: 0.8962
#     MCC: 0.8868
#     F1-score: 0.8905
#     mAP: 0.9945
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.9984
#     G-mean: 0.9755
#     MCC: 0.9371
#     F1-score: 0.9432
#     mAP: 0.9856
#   [GAMO - DecisionTree]
#     AUROC: 0.9242
#     G-mean: 0.7577
#     MCC: 0.6227
#     F1-score: 0.6497
#     mAP: 0.6306
#   [GAMO - kNN]
#     AUROC: 0.9931
#     G-mean: 0.9717
#     MCC: 0.9598
#     F1-score: 0.9633
#     mAP: 0.9816
#   [GAMO - MLP]
#     AUROC: 0.9980
#     G-mean: 0.9716
#     MCC: 0.9377
#     F1-score: 0.9436
#     mAP: 0.9755
#   [GAMO - RandomForest]
#     AUROC: 0.9993
#     G-mean: 0.8977
#     MCC: 0.8883
#     F1-score: 0.8922
#     mAP: 0.9940
#   [MGVAE - SVM]
#     AUROC: 0.9987
#     G-mean: 0.9751
#     MCC: 0.9694
#     F1-score: 0.9720
#     mAP: 0.9938
#   [MGVAE - DecisionTree]
#     AUROC: 0.9392
#     G-mean: 0.8243
#     MCC: 0.6856
#     F1-score: 0.7139
#     mAP: 0.7199
#   [MGVAE - kNN]
#     AUROC: 0.9930
#     G-mean: 0.9719
#     MCC: 0.9617
#     F1-score: 0.9651
#     mAP: 0.9805
#   [MGVAE - MLP]
#     AUROC: 0.9982
#     G-mean: 0.9608
#     MCC: 0.9419
#     F1-score: 0.9470
#     mAP: 0.9887
#   [MGVAE - RandomForest]
#     AUROC: 0.9993
#     G-mean: 0.8946
#     MCC: 0.8851
#     F1-score: 0.8887
#     mAP: 0.9942
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.9985
#     G-mean: 0.9752
#     MCC: 0.9368
#     F1-score: 0.9428
#     mAP: 0.9859
#   [GAMO - DecisionTree]
#     AUROC: 0.9248
#     G-mean: 0.7607
#     MCC: 0.6257
#     F1-score: 0.6526
#     mAP: 0.6309
#   [GAMO - kNN]
#     AUROC: 0.9929
#     G-mean: 0.9720
#     MCC: 0.9599
#     F1-score: 0.9635
#     mAP: 0.9811
#   [GAMO - MLP]
#     AUROC: 0.9980
#     G-mean: 0.9714
#     MCC: 0.9380
#     F1-score: 0.9438
#     mAP: 0.9758
#   [GAMO - RandomForest]
#     AUROC: 0.9993
#     G-mean: 0.8979
#     MCC: 0.8884
#     F1-score: 0.8923
#     mAP: 0.9941
#   [MGVAE - SVM]
#     AUROC: 0.9987
#     G-mean: 0.9748
#     MCC: 0.9690
#     F1-score: 0.9716
#     mAP: 0.9937
#   [MGVAE - DecisionTree]
#     AUROC: 0.9393
#     G-mean: 0.8266
#     MCC: 0.6901
#     F1-score: 0.7180
#     mAP: 0.7223
#   [MGVAE - kNN]
#     AUROC: 0.9929
#     G-mean: 0.9722
#     MCC: 0.9619
#     F1-score: 0.9652
#     mAP: 0.9800
#   [MGVAE - MLP]
#     AUROC: 0.9982
#     G-mean: 0.9601
#     MCC: 0.9406
#     F1-score: 0.9458
#     mAP: 0.9883
#   [MGVAE - RandomForest]
#     AUROC: 0.9993
#     G-mean: 0.8956
#     MCC: 0.8862
#     F1-score: 0.8899
#     mAP: 0.9942
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.9985
#     G-mean: 0.9752
#     MCC: 0.9372
#     F1-score: 0.9432
#     mAP: 0.9857
#   [GAMO - DecisionTree]
#     AUROC: 0.9243
#     G-mean: 0.7563
#     MCC: 0.6228
#     F1-score: 0.6493
#     mAP: 0.6288
#   [GAMO - kNN]
#     AUROC: 0.9931
#     G-mean: 0.9722
#     MCC: 0.9604
#     F1-score: 0.9639
#     mAP: 0.9818
#   [GAMO - MLP]
#     AUROC: 0.9979
#     G-mean: 0.9720
#     MCC: 0.9394
#     F1-score: 0.9451
#     mAP: 0.9755
#   [GAMO - RandomForest]
#     AUROC: 0.9993
#     G-mean: 0.8974
#     MCC: 0.8879
#     F1-score: 0.8918
#     mAP: 0.9942
#   [MGVAE - SVM]
#     AUROC: 0.9987
#     G-mean: 0.9748
#     MCC: 0.9689
#     F1-score: 0.9716
#     mAP: 0.9937
#   [MGVAE - DecisionTree]
#     AUROC: 0.9370
#     G-mean: 0.8266
#     MCC: 0.6917
#     F1-score: 0.7195
#     mAP: 0.7207
#   [MGVAE - kNN]
#     AUROC: 0.9931
#     G-mean: 0.9724
#     MCC: 0.9624
#     F1-score: 0.9656
#     mAP: 0.9808
#   [MGVAE - MLP]
#     AUROC: 0.9982
#     G-mean: 0.9593
#     MCC: 0.9392
#     F1-score: 0.9446
#     mAP: 0.9880
#   [MGVAE - RandomForest]
#     AUROC: 0.9993
#     G-mean: 0.8950
#     MCC: 0.8855
#     F1-score: 0.8892
#     mAP: 0.9942
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.9984
#     G-mean: 0.9750
#     MCC: 0.9369
#     F1-score: 0.9429
#     mAP: 0.9855
#   [GAMO - DecisionTree]
#     AUROC: 0.9238
#     G-mean: 0.7556
#     MCC: 0.6235
#     F1-score: 0.6496
#     mAP: 0.6300
#   [GAMO - kNN]
#     AUROC: 0.9929
#     G-mean: 0.9721
#     MCC: 0.9604
#     F1-score: 0.9639
#     mAP: 0.9817
#   [GAMO - MLP]
#     AUROC: 0.9979
#     G-mean: 0.9714
#     MCC: 0.9382
#     F1-score: 0.9440
#     mAP: 0.9743
#   [GAMO - RandomForest]
#     AUROC: 0.9993
#     G-mean: 0.8977
#     MCC: 0.8883
#     F1-score: 0.8921
#     mAP: 0.9942
#   [MGVAE - SVM]
#     AUROC: 0.9987
#     G-mean: 0.9745
#     MCC: 0.9686
#     F1-score: 0.9712
#     mAP: 0.9938
#   [MGVAE - DecisionTree]
#     AUROC: 0.9357
#     G-mean: 0.8263
#     MCC: 0.6932
#     F1-score: 0.7207
#     mAP: 0.7199
#   [MGVAE - kNN]
#     AUROC: 0.9928
#     G-mean: 0.9724
#     MCC: 0.9625
#     F1-score: 0.9658
#     mAP: 0.9807
#   [MGVAE - MLP]
#     AUROC: 0.9982
#     G-mean: 0.9595
#     MCC: 0.9402
#     F1-score: 0.9455
#     mAP: 0.9882
#   [MGVAE - RandomForest]
#     AUROC: 0.9993
#     G-mean: 0.8953
#     MCC: 0.8859
#     F1-score: 0.8895
#     mAP: 0.9943
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.9984
#     G-mean: 0.9753
#     MCC: 0.9375
#     F1-score: 0.9434
#     mAP: 0.9854
#   [GAMO - DecisionTree]
#     AUROC: 0.9235
#     G-mean: 0.7591
#     MCC: 0.6274
#     F1-score: 0.6533
#     mAP: 0.6318
#   [GAMO - kNN]
#     AUROC: 0.9928
#     G-mean: 0.9723
#     MCC: 0.9607
#     F1-score: 0.9642
#     mAP: 0.9814
#   [GAMO - MLP]
#     AUROC: 0.9979
#     G-mean: 0.9718
#     MCC: 0.9374
#     F1-score: 0.9433
#     mAP: 0.9733
#   [GAMO - RandomForest]
#     AUROC: 0.9993
#     G-mean: 0.8975
#     MCC: 0.8880
#     F1-score: 0.8918
#     mAP: 0.9942
#   [MGVAE - SVM]
#     AUROC: 0.9987
#     G-mean: 0.9743
#     MCC: 0.9685
#     F1-score: 0.9711
#     mAP: 0.9938
#   [MGVAE - DecisionTree]
#     AUROC: 0.9353
#     G-mean: 0.8287
#     MCC: 0.6963
#     F1-score: 0.7236
#     mAP: 0.7211
#   [MGVAE - kNN]
#     AUROC: 0.9927
#     G-mean: 0.9725
#     MCC: 0.9628
#     F1-score: 0.9660
#     mAP: 0.9803
#   [MGVAE - MLP]
#     AUROC: 0.9981
#     G-mean: 0.9590
#     MCC: 0.9399
#     F1-score: 0.9451
#     mAP: 0.9879
#   [MGVAE - RandomForest]
#     AUROC: 0.9993
#     G-mean: 0.8959
#     MCC: 0.8865
#     F1-score: 0.8901
#     mAP: 0.9942
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.9984
#     G-mean: 0.9752
#     MCC: 0.9370
#     F1-score: 0.9430
#     mAP: 0.9853
#   [GAMO - DecisionTree]
#     AUROC: 0.9232
#     G-mean: 0.7592
#     MCC: 0.6282
#     F1-score: 0.6537
#     mAP: 0.6328
#   [GAMO - kNN]
#     AUROC: 0.9928
#     G-mean: 0.9722
#     MCC: 0.9603
#     F1-score: 0.9639
#     mAP: 0.9812
#   [GAMO - MLP]
#     AUROC: 0.9978
#     G-mean: 0.9721
#     MCC: 0.9382
#     F1-score: 0.9440
#     mAP: 0.9718
#   [GAMO - RandomForest]
#     AUROC: 0.9993
#     G-mean: 0.8976
#     MCC: 0.8882
#     F1-score: 0.8919
#     mAP: 0.9941
#   [MGVAE - SVM]
#     AUROC: 0.9987
#     G-mean: 0.9743
#     MCC: 0.9685
#     F1-score: 0.9711
#     mAP: 0.9938
#   [MGVAE - DecisionTree]
#     AUROC: 0.9346
#     G-mean: 0.8289
#     MCC: 0.6963
#     F1-score: 0.7237
#     mAP: 0.7218
#   [MGVAE - kNN]
#     AUROC: 0.9928
#     G-mean: 0.9723
#     MCC: 0.9623
#     F1-score: 0.9656
#     mAP: 0.9801
#   [MGVAE - MLP]
#     AUROC: 0.9980
#     G-mean: 0.9582
#     MCC: 0.9390
#     F1-score: 0.9442
#     mAP: 0.9873
#   [MGVAE - RandomForest]
#     AUROC: 0.9993
#     G-mean: 0.8960
#     MCC: 0.8867
#     F1-score: 0.8903
#     mAP: 0.9943
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.9984
#     G-mean: 0.9752
#     MCC: 0.9372
#     F1-score: 0.9432
#     mAP: 0.9854
#   [GAMO - DecisionTree]
#     AUROC: 0.9235
#     G-mean: 0.7569
#     MCC: 0.6267
#     F1-score: 0.6519
#     mAP: 0.6336
#   [GAMO - kNN]
#     AUROC: 0.9928
#     G-mean: 0.9722
#     MCC: 0.9602
#     F1-score: 0.9637
#     mAP: 0.9811
#   [GAMO - MLP]
#     AUROC: 0.9979
#     G-mean: 0.9723
#     MCC: 0.9382
#     F1-score: 0.9440
#     mAP: 0.9720
#   [GAMO - RandomForest]
#     AUROC: 0.9993
#     G-mean: 0.8977
#     MCC: 0.8883
#     F1-score: 0.8920
#     mAP: 0.9940
#   [MGVAE - SVM]
#     AUROC: 0.9987
#     G-mean: 0.9739
#     MCC: 0.9680
#     F1-score: 0.9707
#     mAP: 0.9938
#   [MGVAE - DecisionTree]
#     AUROC: 0.9342
#     G-mean: 0.8296
#     MCC: 0.6962
#     F1-score: 0.7238
#     mAP: 0.7204
#   [MGVAE - kNN]
#     AUROC: 0.9928
#     G-mean: 0.9723
#     MCC: 0.9623
#     F1-score: 0.9656
#     mAP: 0.9800
#   [MGVAE - MLP]
#     AUROC: 0.9980
#     G-mean: 0.9587
#     MCC: 0.9396
#     F1-score: 0.9448
#     mAP: 0.9875
#   [MGVAE - RandomForest]
#     AUROC: 0.9993
#     G-mean: 0.8964
#     MCC: 0.8871
#     F1-score: 0.8907
#     mAP: 0.9943
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/optical_digits_results_GAMO_MGVAE_beta_0.001.csv

# %%
# ozone_level
data_name = 'ozone_level'
maj_target_name = -1

n_epochs = 1000
hidden_dims = [32, 64, 128, 256]
latent_dim = 512
lr = 0.005
beta = 0.001

final_res = run_exp(
    data=data, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    kernel_type=kernel_type,
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    maj_target_name=maj_target_name,
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded: ozone_level
# X shape : (2536, 72)
# target : Counter({0: 2463, 1: 73})
# IR: 33.74
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.7147
#     G-mean: 0.1084
#     MCC: -0.0125
#     F1-score: 0.0207
#     mAP: 0.0720
#   [GAMO - DecisionTree]
#     AUROC: 0.5913
#     G-mean: 0.0362
#     MCC: -0.0290
#     F1-score: 0.0069
#     mAP: 0.0442
#   [GAMO - kNN]
#     AUROC: 0.7195
#     G-mean: 0.2395
#     MCC: 0.1783
#     F1-score: 0.1521
#     mAP: 0.1873
#   [GAMO - MLP]
#     AUROC: 0.7642
#     G-mean: 0.2360
#     MCC: 0.0616
#     F1-score: 0.0876
#     mAP: 0.1182
#   [GAMO - RandomForest]
#     AUROC: 0.8143
#     G-mean: 0.0376
#     MCC: 0.0003
#     F1-score: 0.0182
#     mAP: 0.1112
#   [MGVAE - SVM]
#     AUROC: 0.8779
#     G-mean: 0.1486
#     MCC: 0.1195
#     F1-score: 0.0922
#     mAP: 0.3427
#   [MGVAE - DecisionTree]
#     AUROC: 0.7093
#     G-mean: 0.3994
#     MCC: 0.2128
#     F1-score: 0.2292
#     mAP: 0.1563
#   [MGVAE - kNN]
#     AUROC: 0.7329
#     G-mean: 0.3266
#     MCC: 0.1592
#     F1-score: 0.1705
#     mAP: 0.1498
#   [MGVAE - MLP]
#     AUROC: 0.8841
#     G-mean: 0.5816
#     MCC: 0.3413
#     F1-score: 0.3555
#     mAP: 0.3554
#   [MGVAE - RandomForest]
#     AUROC: 0.8977
#     G-mean: 0.0378
#     MCC: 0.0348
#     F1-score: 0.0250
#     mAP: 0.3624
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.7199
#     G-mean: 0.0988
#     MCC: -0.0088
#     F1-score: 0.0259
#     mAP: 0.0710
#   [GAMO - DecisionTree]
#     AUROC: 0.6052
#     G-mean: 0.0525
#     MCC: -0.0230
#     F1-score: 0.0140
#     mAP: 0.0507
#   [GAMO - kNN]
#     AUROC: 0.7159
#     G-mean: 0.2782
#     MCC: 0.2031
#     F1-score: 0.1785
#     mAP: 0.1844
#   [GAMO - MLP]
#     AUROC: 0.7756
#     G-mean: 0.2375
#     MCC: 0.0698
#     F1-score: 0.0966
#     mAP: 0.1237
#   [GAMO - RandomForest]
#     AUROC: 0.8208
#     G-mean: 0.0376
#     MCC: -0.0010
#     F1-score: 0.0175
#     mAP: 0.1107
#   [MGVAE - SVM]
#     AUROC: 0.8757
#     G-mean: 0.1625
#     MCC: 0.1312
#     F1-score: 0.1075
#     mAP: 0.3377
#   [MGVAE - DecisionTree]
#     AUROC: 0.6976
#     G-mean: 0.3743
#     MCC: 0.2125
#     F1-score: 0.2283
#     mAP: 0.1604
#   [MGVAE - kNN]
#     AUROC: 0.7292
#     G-mean: 0.3400
#     MCC: 0.1780
#     F1-score: 0.1885
#     mAP: 0.1503
#   [MGVAE - MLP]
#     AUROC: 0.8885
#     G-mean: 0.5580
#     MCC: 0.3271
#     F1-score: 0.3399
#     mAP: 0.3569
#   [MGVAE - RandomForest]
#     AUROC: 0.8975
#     G-mean: 0.0378
#     MCC: 0.0350
#     F1-score: 0.0250
#     mAP: 0.3423
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.7204
#     G-mean: 0.0903
#     MCC: -0.0118
#     F1-score: 0.0230
#     mAP: 0.0682
#   [GAMO - DecisionTree]
#     AUROC: 0.6057
#     G-mean: 0.0631
#     MCC: -0.0214
#     F1-score: 0.0173
#     mAP: 0.0524
#   [GAMO - kNN]
#     AUROC: 0.7146
#     G-mean: 0.2718
#     MCC: 0.1952
#     F1-score: 0.1684
#     mAP: 0.1790
#   [GAMO - MLP]
#     AUROC: 0.7785
#     G-mean: 0.2575
#     MCC: 0.0735
#     F1-score: 0.1003
#     mAP: 0.1212
#   [GAMO - RandomForest]
#     AUROC: 0.8113
#     G-mean: 0.0250
#     MCC: -0.0081
#     F1-score: 0.0116
#     mAP: 0.1068
#   [MGVAE - SVM]
#     AUROC: 0.8722
#     G-mean: 0.2043
#     MCC: 0.1671
#     F1-score: 0.1348
#     mAP: 0.3410
#   [MGVAE - DecisionTree]
#     AUROC: 0.7028
#     G-mean: 0.3078
#     MCC: 0.1743
#     F1-score: 0.1903
#     mAP: 0.1523
#   [MGVAE - kNN]
#     AUROC: 0.7276
#     G-mean: 0.3421
#     MCC: 0.1717
#     F1-score: 0.1821
#     mAP: 0.1438
#   [MGVAE - MLP]
#     AUROC: 0.8873
#     G-mean: 0.5857
#     MCC: 0.3465
#     F1-score: 0.3593
#     mAP: 0.3713
#   [MGVAE - RandomForest]
#     AUROC: 0.8990
#     G-mean: 0.0252
#     MCC: 0.0221
#     F1-score: 0.0167
#     mAP: 0.3442
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.7197
#     G-mean: 0.0861
#     MCC: -0.0133
#     F1-score: 0.0218
#     mAP: 0.0693
#   [GAMO - DecisionTree]
#     AUROC: 0.6175
#     G-mean: 0.0829
#     MCC: -0.0159
#     F1-score: 0.0223
#     mAP: 0.0558
#   [GAMO - kNN]
#     AUROC: 0.7062
#     G-mean: 0.2670
#     MCC: 0.1918
#     F1-score: 0.1663
#     mAP: 0.1745
#   [GAMO - MLP]
#     AUROC: 0.7772
#     G-mean: 0.2543
#     MCC: 0.0703
#     F1-score: 0.0972
#     mAP: 0.1202
#   [GAMO - RandomForest]
#     AUROC: 0.8080
#     G-mean: 0.0319
#     MCC: -0.0056
#     F1-score: 0.0146
#     mAP: 0.1045
#   [MGVAE - SVM]
#     AUROC: 0.8721
#     G-mean: 0.1978
#     MCC: 0.1570
#     F1-score: 0.1299
#     mAP: 0.3286
#   [MGVAE - DecisionTree]
#     AUROC: 0.7077
#     G-mean: 0.3229
#     MCC: 0.1804
#     F1-score: 0.1971
#     mAP: 0.1540
#   [MGVAE - kNN]
#     AUROC: 0.7190
#     G-mean: 0.3415
#     MCC: 0.1703
#     F1-score: 0.1816
#     mAP: 0.1370
#   [MGVAE - MLP]
#     AUROC: 0.8874
#     G-mean: 0.5712
#     MCC: 0.3372
#     F1-score: 0.3510
#     mAP: 0.3655
#   [MGVAE - RandomForest]
#     AUROC: 0.8986
#     G-mean: 0.0189
#     MCC: 0.0159
#     F1-score: 0.0125
#     mAP: 0.3416
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.7209
#     G-mean: 0.0907
#     MCC: -0.0104
#     F1-score: 0.0248
#     mAP: 0.0715
#   [GAMO - DecisionTree]
#     AUROC: 0.6267
#     G-mean: 0.0804
#     MCC: -0.0174
#     F1-score: 0.0209
#     mAP: 0.0571
#   [GAMO - kNN]
#     AUROC: 0.7065
#     G-mean: 0.2685
#     MCC: 0.1914
#     F1-score: 0.1660
#     mAP: 0.1773
#   [GAMO - MLP]
#     AUROC: 0.7782
#     G-mean: 0.2603
#     MCC: 0.0746
#     F1-score: 0.1012
#     mAP: 0.1227
#   [GAMO - RandomForest]
#     AUROC: 0.8076
#     G-mean: 0.0401
#     MCC: -0.0019
#     F1-score: 0.0181
#     mAP: 0.1047
#   [MGVAE - SVM]
#     AUROC: 0.8717
#     G-mean: 0.1860
#     MCC: 0.1506
#     F1-score: 0.1243
#     mAP: 0.3283
#   [MGVAE - DecisionTree]
#     AUROC: 0.7170
#     G-mean: 0.3240
#     MCC: 0.1828
#     F1-score: 0.1987
#     mAP: 0.1584
#   [MGVAE - kNN]
#     AUROC: 0.7183
#     G-mean: 0.3393
#     MCC: 0.1739
#     F1-score: 0.1843
#     mAP: 0.1431
#   [MGVAE - MLP]
#     AUROC: 0.8876
#     G-mean: 0.5651
#     MCC: 0.3306
#     F1-score: 0.3434
#     mAP: 0.3626
#   [MGVAE - RandomForest]
#     AUROC: 0.8965
#     G-mean: 0.0151
#     MCC: 0.0118
#     F1-score: 0.0100
#     mAP: 0.3384
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.7226
#     G-mean: 0.0880
#     MCC: -0.0103
#     F1-score: 0.0250
#     mAP: 0.0712
#   [GAMO - DecisionTree]
#     AUROC: 0.6277
#     G-mean: 0.0789
#     MCC: -0.0158
#     F1-score: 0.0220
#     mAP: 0.0562
#   [GAMO - kNN]
#     AUROC: 0.7072
#     G-mean: 0.2509
#     MCC: 0.1790
#     F1-score: 0.1556
#     mAP: 0.1769
#   [GAMO - MLP]
#     AUROC: 0.7766
#     G-mean: 0.2556
#     MCC: 0.0716
#     F1-score: 0.0983
#     mAP: 0.1195
#   [GAMO - RandomForest]
#     AUROC: 0.8113
#     G-mean: 0.0334
#     MCC: -0.0049
#     F1-score: 0.0151
#     mAP: 0.1082
#   [MGVAE - SVM]
#     AUROC: 0.8717
#     G-mean: 0.1781
#     MCC: 0.1464
#     F1-score: 0.1206
#     mAP: 0.3341
#   [MGVAE - DecisionTree]
#     AUROC: 0.7180
#     G-mean: 0.3503
#     MCC: 0.2008
#     F1-score: 0.2160
#     mAP: 0.1653
#   [MGVAE - kNN]
#     AUROC: 0.7181
#     G-mean: 0.3213
#     MCC: 0.1670
#     F1-score: 0.1768
#     mAP: 0.1434
#   [MGVAE - MLP]
#     AUROC: 0.8860
#     G-mean: 0.5628
#     MCC: 0.3303
#     F1-score: 0.3405
#     mAP: 0.3595
#   [MGVAE - RandomForest]
#     AUROC: 0.8956
#     G-mean: 0.0126
#     MCC: 0.0095
#     F1-score: 0.0083
#     mAP: 0.3435
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.7213
#     G-mean: 0.0857
#     MCC: -0.0104
#     F1-score: 0.0250
#     mAP: 0.0701
#   [GAMO - DecisionTree]
#     AUROC: 0.6275
#     G-mean: 0.0729
#     MCC: -0.0176
#     F1-score: 0.0201
#     mAP: 0.0552
#   [GAMO - kNN]
#     AUROC: 0.7072
#     G-mean: 0.2381
#     MCC: 0.1696
#     F1-score: 0.1479
#     mAP: 0.1744
#   [GAMO - MLP]
#     AUROC: 0.7741
#     G-mean: 0.2515
#     MCC: 0.0712
#     F1-score: 0.0983
#     mAP: 0.1183
#   [GAMO - RandomForest]
#     AUROC: 0.8137
#     G-mean: 0.0339
#     MCC: -0.0055
#     F1-score: 0.0150
#     mAP: 0.1090
#   [MGVAE - SVM]
#     AUROC: 0.8726
#     G-mean: 0.1815
#     MCC: 0.1487
#     F1-score: 0.1222
#     mAP: 0.3329
#   [MGVAE - DecisionTree]
#     AUROC: 0.7166
#     G-mean: 0.3544
#     MCC: 0.2066
#     F1-score: 0.2204
#     mAP: 0.1680
#   [MGVAE - kNN]
#     AUROC: 0.7175
#     G-mean: 0.3105
#     MCC: 0.1612
#     F1-score: 0.1710
#     mAP: 0.1453
#   [MGVAE - MLP]
#     AUROC: 0.8853
#     G-mean: 0.5607
#     MCC: 0.3267
#     F1-score: 0.3367
#     mAP: 0.3582
#   [MGVAE - RandomForest]
#     AUROC: 0.8965
#     G-mean: 0.0108
#     MCC: 0.0077
#     F1-score: 0.0071
#     mAP: 0.3454
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.7211
#     G-mean: 0.0856
#     MCC: -0.0102
#     F1-score: 0.0252
#     mAP: 0.0693
#   [GAMO - DecisionTree]
#     AUROC: 0.6274
#     G-mean: 0.0724
#     MCC: -0.0181
#     F1-score: 0.0199
#     mAP: 0.0550
#   [GAMO - kNN]
#     AUROC: 0.7069
#     G-mean: 0.2435
#     MCC: 0.1711
#     F1-score: 0.1516
#     mAP: 0.1721
#   [GAMO - MLP]
#     AUROC: 0.7719
#     G-mean: 0.2573
#     MCC: 0.0719
#     F1-score: 0.0993
#     mAP: 0.1170
#   [GAMO - RandomForest]
#     AUROC: 0.8125
#     G-mean: 0.0344
#     MCC: -0.0063
#     F1-score: 0.0146
#     mAP: 0.1081
#   [MGVAE - SVM]
#     AUROC: 0.8719
#     G-mean: 0.1774
#     MCC: 0.1437
#     F1-score: 0.1181
#     mAP: 0.3316
#   [MGVAE - DecisionTree]
#     AUROC: 0.7094
#     G-mean: 0.3463
#     MCC: 0.2012
#     F1-score: 0.2151
#     mAP: 0.1636
#   [MGVAE - kNN]
#     AUROC: 0.7175
#     G-mean: 0.3114
#     MCC: 0.1634
#     F1-score: 0.1733
#     mAP: 0.1466
#   [MGVAE - MLP]
#     AUROC: 0.8854
#     G-mean: 0.5651
#     MCC: 0.3245
#     F1-score: 0.3354
#     mAP: 0.3543
#   [MGVAE - RandomForest]
#     AUROC: 0.8967
#     G-mean: 0.0095
#     MCC: 0.0064
#     F1-score: 0.0063
#     mAP: 0.3441
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.7209
#     G-mean: 0.0884
#     MCC: -0.0095
#     F1-score: 0.0258
#     mAP: 0.0685
#   [GAMO - DecisionTree]
#     AUROC: 0.6297
#     G-mean: 0.0817
#     MCC: -0.0149
#     F1-score: 0.0229
#     mAP: 0.0555
#   [GAMO - kNN]
#     AUROC: 0.7081
#     G-mean: 0.2443
#     MCC: 0.1706
#     F1-score: 0.1536
#     mAP: 0.1715
#   [GAMO - MLP]
#     AUROC: 0.7742
#     G-mean: 0.2642
#     MCC: 0.0728
#     F1-score: 0.1002
#     mAP: 0.1164
#   [GAMO - RandomForest]
#     AUROC: 0.8128
#     G-mean: 0.0305
#     MCC: -0.0071
#     F1-score: 0.0130
#     mAP: 0.1083
#   [MGVAE - SVM]
#     AUROC: 0.8716
#     G-mean: 0.1694
#     MCC: 0.1365
#     F1-score: 0.1119
#     mAP: 0.3276
#   [MGVAE - DecisionTree]
#     AUROC: 0.7087
#     G-mean: 0.3532
#     MCC: 0.2006
#     F1-score: 0.2151
#     mAP: 0.1609
#   [MGVAE - kNN]
#     AUROC: 0.7197
#     G-mean: 0.3108
#     MCC: 0.1646
#     F1-score: 0.1749
#     mAP: 0.1477
#   [MGVAE - MLP]
#     AUROC: 0.8858
#     G-mean: 0.5592
#     MCC: 0.3217
#     F1-score: 0.3327
#     mAP: 0.3560
#   [MGVAE - RandomForest]
#     AUROC: 0.8969
#     G-mean: 0.0165
#     MCC: 0.0116
#     F1-score: 0.0102
#     mAP: 0.3453
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.7211
#     G-mean: 0.0833
#     MCC: -0.0108
#     F1-score: 0.0244
#     mAP: 0.0678
#   [GAMO - DecisionTree]
#     AUROC: 0.6360
#     G-mean: 0.0820
#     MCC: -0.0142
#     F1-score: 0.0230
#     mAP: 0.0585
#   [GAMO - kNN]
#     AUROC: 0.7098
#     G-mean: 0.2438
#     MCC: 0.1726
#     F1-score: 0.1557
#     mAP: 0.1730
#   [GAMO - MLP]
#     AUROC: 0.7726
#     G-mean: 0.2610
#     MCC: 0.0713
#     F1-score: 0.0989
#     mAP: 0.1160
#   [GAMO - RandomForest]
#     AUROC: 0.8117
#     G-mean: 0.0275
#     MCC: -0.0084
#     F1-score: 0.0117
#     mAP: 0.1082
#   [MGVAE - SVM]
#     AUROC: 0.8720
#     G-mean: 0.1676
#     MCC: 0.1351
#     F1-score: 0.1101
#     mAP: 0.3260
#   [MGVAE - DecisionTree]
#     AUROC: 0.7092
#     G-mean: 0.3619
#     MCC: 0.2049
#     F1-score: 0.2191
#     mAP: 0.1608
#   [MGVAE - kNN]
#     AUROC: 0.7223
#     G-mean: 0.3149
#     MCC: 0.1669
#     F1-score: 0.1771
#     mAP: 0.1489
#   [MGVAE - MLP]
#     AUROC: 0.8860
#     G-mean: 0.5603
#     MCC: 0.3219
#     F1-score: 0.3330
#     mAP: 0.3554
#   [MGVAE - RandomForest]
#     AUROC: 0.8968
#     G-mean: 0.0149
#     MCC: 0.0100
#     F1-score: 0.0092
#     mAP: 0.3460
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/ozone_level_results_GAMO_MGVAE_beta_0.001.csv

# %%
# satimage
data_name = 'satimage'
maj_target_name = -1

n_epochs = 1000
hidden_dims = [32, 64, 128, 256]
latent_dim = 512
lr = 0.005
beta = 0.001

final_res = run_exp(
    data=data, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    kernel_type=kernel_type,
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    maj_target_name=maj_target_name,
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded: satimage
# X shape : (6435, 36)
# target : Counter({0: 5809, 1: 626})
# IR: 9.28
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.9165
#     G-mean: 0.6588
#     MCC: 0.5260
#     F1-score: 0.5452
#     mAP: 0.6715
#   [GAMO - DecisionTree]
#     AUROC: 0.6470
#     G-mean: 0.2348
#     MCC: 0.0291
#     F1-score: 0.0877
#     mAP: 0.1530
#   [GAMO - kNN]
#     AUROC: 0.9392
#     G-mean: 0.8098
#     MCC: 0.6701
#     F1-score: 0.6990
#     mAP: 0.7359
#   [GAMO - MLP]
#     AUROC: 0.9438
#     G-mean: 0.7170
#     MCC: 0.5751
#     F1-score: 0.6014
#     mAP: 0.6969
#   [GAMO - RandomForest]
#     AUROC: 0.9476
#     G-mean: 0.7810
#     MCC: 0.6550
#     F1-score: 0.6818
#     mAP: 0.7657
#   [MGVAE - SVM]
#     AUROC: 0.9373
#     G-mean: 0.7041
#     MCC: 0.5684
#     F1-score: 0.5930
#     mAP: 0.7141
#   [MGVAE - DecisionTree]
#     AUROC: 0.8791
#     G-mean: 0.7023
#     MCC: 0.5179
#     F1-score: 0.5574
#     mAP: 0.5466
#   [MGVAE - kNN]
#     AUROC: 0.9391
#     G-mean: 0.8105
#     MCC: 0.6697
#     F1-score: 0.6988
#     mAP: 0.7338
#   [MGVAE - MLP]
#     AUROC: 0.9440
#     G-mean: 0.7597
#     MCC: 0.5948
#     F1-score: 0.6302
#     mAP: 0.7005
#   [MGVAE - RandomForest]
#     AUROC: 0.9633
#     G-mean: 0.7299
#     MCC: 0.6506
#     F1-score: 0.6580
#     mAP: 0.7999
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.9164
#     G-mean: 0.6596
#     MCC: 0.5278
#     F1-score: 0.5463
#     mAP: 0.6707
#   [GAMO - DecisionTree]
#     AUROC: 0.6895
#     G-mean: 0.3167
#     MCC: 0.0986
#     F1-score: 0.1589
#     mAP: 0.1875
#   [GAMO - kNN]
#     AUROC: 0.9373
#     G-mean: 0.8123
#     MCC: 0.6687
#     F1-score: 0.6987
#     mAP: 0.7314
#   [GAMO - MLP]
#     AUROC: 0.9446
#     G-mean: 0.7134
#     MCC: 0.5769
#     F1-score: 0.6017
#     mAP: 0.7005
#   [GAMO - RandomForest]
#     AUROC: 0.9468
#     G-mean: 0.7797
#     MCC: 0.6494
#     F1-score: 0.6771
#     mAP: 0.7631
#   [MGVAE - SVM]
#     AUROC: 0.9373
#     G-mean: 0.7019
#     MCC: 0.5666
#     F1-score: 0.5909
#     mAP: 0.7164
#   [MGVAE - DecisionTree]
#     AUROC: 0.8767
#     G-mean: 0.6984
#     MCC: 0.5159
#     F1-score: 0.5544
#     mAP: 0.5405
#   [MGVAE - kNN]
#     AUROC: 0.9373
#     G-mean: 0.8136
#     MCC: 0.6693
#     F1-score: 0.6993
#     mAP: 0.7298
#   [MGVAE - MLP]
#     AUROC: 0.9455
#     G-mean: 0.7567
#     MCC: 0.5943
#     F1-score: 0.6290
#     mAP: 0.7075
#   [MGVAE - RandomForest]
#     AUROC: 0.9635
#     G-mean: 0.7264
#     MCC: 0.6470
#     F1-score: 0.6541
#     mAP: 0.7989
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.9167
#     G-mean: 0.6603
#     MCC: 0.5295
#     F1-score: 0.5477
#     mAP: 0.6702
#   [GAMO - DecisionTree]
#     AUROC: 0.6976
#     G-mean: 0.3825
#     MCC: 0.1366
#     F1-score: 0.1952
#     mAP: 0.1946
#   [GAMO - kNN]
#     AUROC: 0.9384
#     G-mean: 0.8120
#     MCC: 0.6674
#     F1-score: 0.6978
#     mAP: 0.7341
#   [GAMO - MLP]
#     AUROC: 0.9441
#     G-mean: 0.7053
#     MCC: 0.5732
#     F1-score: 0.5958
#     mAP: 0.6980
#   [GAMO - RandomForest]
#     AUROC: 0.9464
#     G-mean: 0.7803
#     MCC: 0.6477
#     F1-score: 0.6760
#     mAP: 0.7609
#   [MGVAE - SVM]
#     AUROC: 0.9370
#     G-mean: 0.7028
#     MCC: 0.5682
#     F1-score: 0.5924
#     mAP: 0.7147
#   [MGVAE - DecisionTree]
#     AUROC: 0.8768
#     G-mean: 0.7020
#     MCC: 0.5168
#     F1-score: 0.5560
#     mAP: 0.5425
#   [MGVAE - kNN]
#     AUROC: 0.9384
#     G-mean: 0.8135
#     MCC: 0.6684
#     F1-score: 0.6988
#     mAP: 0.7325
#   [MGVAE - MLP]
#     AUROC: 0.9468
#     G-mean: 0.7583
#     MCC: 0.5974
#     F1-score: 0.6318
#     mAP: 0.7079
#   [MGVAE - RandomForest]
#     AUROC: 0.9635
#     G-mean: 0.7267
#     MCC: 0.6472
#     F1-score: 0.6546
#     mAP: 0.7984
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.9162
#     G-mean: 0.6595
#     MCC: 0.5292
#     F1-score: 0.5470
#     mAP: 0.6704
#   [GAMO - DecisionTree]
#     AUROC: 0.7034
#     G-mean: 0.3761
#     MCC: 0.1342
#     F1-score: 0.1944
#     mAP: 0.1996
#   [GAMO - kNN]
#     AUROC: 0.9384
#     G-mean: 0.8100
#     MCC: 0.6655
#     F1-score: 0.6958
#     mAP: 0.7319
#   [GAMO - MLP]
#     AUROC: 0.9441
#     G-mean: 0.7102
#     MCC: 0.5775
#     F1-score: 0.6008
#     mAP: 0.6997
#   [GAMO - RandomForest]
#     AUROC: 0.9464
#     G-mean: 0.7806
#     MCC: 0.6499
#     F1-score: 0.6774
#     mAP: 0.7610
#   [MGVAE - SVM]
#     AUROC: 0.9368
#     G-mean: 0.7047
#     MCC: 0.5710
#     F1-score: 0.5948
#     mAP: 0.7161
#   [MGVAE - DecisionTree]
#     AUROC: 0.8753
#     G-mean: 0.6996
#     MCC: 0.5142
#     F1-score: 0.5532
#     mAP: 0.5401
#   [MGVAE - kNN]
#     AUROC: 0.9384
#     G-mean: 0.8118
#     MCC: 0.6667
#     F1-score: 0.6970
#     mAP: 0.7310
#   [MGVAE - MLP]
#     AUROC: 0.9452
#     G-mean: 0.7590
#     MCC: 0.5978
#     F1-score: 0.6321
#     mAP: 0.7056
#   [MGVAE - RandomForest]
#     AUROC: 0.9635
#     G-mean: 0.7270
#     MCC: 0.6471
#     F1-score: 0.6543
#     mAP: 0.7988
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.9163
#     G-mean: 0.6592
#     MCC: 0.5292
#     F1-score: 0.5468
#     mAP: 0.6703
#   [GAMO - DecisionTree]
#     AUROC: 0.7102
#     G-mean: 0.3838
#     MCC: 0.1408
#     F1-score: 0.1986
#     mAP: 0.2075
#   [GAMO - kNN]
#     AUROC: 0.9386
#     G-mean: 0.8107
#     MCC: 0.6667
#     F1-score: 0.6969
#     mAP: 0.7329
#   [GAMO - MLP]
#     AUROC: 0.9440
#     G-mean: 0.7071
#     MCC: 0.5750
#     F1-score: 0.5973
#     mAP: 0.6988
#   [GAMO - RandomForest]
#     AUROC: 0.9465
#     G-mean: 0.7798
#     MCC: 0.6499
#     F1-score: 0.6769
#     mAP: 0.7605
#   [MGVAE - SVM]
#     AUROC: 0.9368
#     G-mean: 0.7044
#     MCC: 0.5703
#     F1-score: 0.5943
#     mAP: 0.7152
#   [MGVAE - DecisionTree]
#     AUROC: 0.8745
#     G-mean: 0.6935
#     MCC: 0.5087
#     F1-score: 0.5472
#     mAP: 0.5383
#   [MGVAE - kNN]
#     AUROC: 0.9386
#     G-mean: 0.8125
#     MCC: 0.6682
#     F1-score: 0.6984
#     mAP: 0.7319
#   [MGVAE - MLP]
#     AUROC: 0.9451
#     G-mean: 0.7586
#     MCC: 0.5937
#     F1-score: 0.6289
#     mAP: 0.7042
#   [MGVAE - RandomForest]
#     AUROC: 0.9635
#     G-mean: 0.7272
#     MCC: 0.6481
#     F1-score: 0.6550
#     mAP: 0.7989
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.9162
#     G-mean: 0.6586
#     MCC: 0.5285
#     F1-score: 0.5461
#     mAP: 0.6705
#   [GAMO - DecisionTree]
#     AUROC: 0.7122
#     G-mean: 0.3766
#     MCC: 0.1373
#     F1-score: 0.1949
#     mAP: 0.2078
#   [GAMO - kNN]
#     AUROC: 0.9388
#     G-mean: 0.8098
#     MCC: 0.6651
#     F1-score: 0.6954
#     mAP: 0.7321
#   [GAMO - MLP]
#     AUROC: 0.9445
#     G-mean: 0.7092
#     MCC: 0.5760
#     F1-score: 0.5987
#     mAP: 0.7001
#   [GAMO - RandomForest]
#     AUROC: 0.9466
#     G-mean: 0.7793
#     MCC: 0.6490
#     F1-score: 0.6761
#     mAP: 0.7607
#   [MGVAE - SVM]
#     AUROC: 0.9367
#     G-mean: 0.7054
#     MCC: 0.5717
#     F1-score: 0.5955
#     mAP: 0.7155
#   [MGVAE - DecisionTree]
#     AUROC: 0.8765
#     G-mean: 0.6934
#     MCC: 0.5084
#     F1-score: 0.5468
#     mAP: 0.5386
#   [MGVAE - kNN]
#     AUROC: 0.9387
#     G-mean: 0.8116
#     MCC: 0.6665
#     F1-score: 0.6967
#     mAP: 0.7309
#   [MGVAE - MLP]
#     AUROC: 0.9456
#     G-mean: 0.7590
#     MCC: 0.5958
#     F1-score: 0.6301
#     mAP: 0.7058
#   [MGVAE - RandomForest]
#     AUROC: 0.9635
#     G-mean: 0.7274
#     MCC: 0.6485
#     F1-score: 0.6554
#     mAP: 0.7992
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.9162
#     G-mean: 0.6582
#     MCC: 0.5279
#     F1-score: 0.5456
#     mAP: 0.6703
#   [GAMO - DecisionTree]
#     AUROC: 0.7120
#     G-mean: 0.3698
#     MCC: 0.1335
#     F1-score: 0.1909
#     mAP: 0.2070
#   [GAMO - kNN]
#     AUROC: 0.9392
#     G-mean: 0.8090
#     MCC: 0.6634
#     F1-score: 0.6939
#     mAP: 0.7314
#   [GAMO - MLP]
#     AUROC: 0.9439
#     G-mean: 0.7077
#     MCC: 0.5731
#     F1-score: 0.5961
#     mAP: 0.6980
#   [GAMO - RandomForest]
#     AUROC: 0.9467
#     G-mean: 0.7797
#     MCC: 0.6484
#     F1-score: 0.6758
#     mAP: 0.7603
#   [MGVAE - SVM]
#     AUROC: 0.9366
#     G-mean: 0.7061
#     MCC: 0.5725
#     F1-score: 0.5964
#     mAP: 0.7155
#   [MGVAE - DecisionTree]
#     AUROC: 0.8773
#     G-mean: 0.6915
#     MCC: 0.5072
#     F1-score: 0.5454
#     mAP: 0.5387
#   [MGVAE - kNN]
#     AUROC: 0.9392
#     G-mean: 0.8109
#     MCC: 0.6649
#     F1-score: 0.6954
#     mAP: 0.7301
#   [MGVAE - MLP]
#     AUROC: 0.9460
#     G-mean: 0.7596
#     MCC: 0.5983
#     F1-score: 0.6323
#     mAP: 0.7066
#   [MGVAE - RandomForest]
#     AUROC: 0.9635
#     G-mean: 0.7258
#     MCC: 0.6463
#     F1-score: 0.6533
#     mAP: 0.7988
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.9163
#     G-mean: 0.6583
#     MCC: 0.5281
#     F1-score: 0.5457
#     mAP: 0.6706
#   [GAMO - DecisionTree]
#     AUROC: 0.7080
#     G-mean: 0.3480
#     MCC: 0.1176
#     F1-score: 0.1749
#     mAP: 0.2026
#   [GAMO - kNN]
#     AUROC: 0.9388
#     G-mean: 0.8083
#     MCC: 0.6620
#     F1-score: 0.6926
#     mAP: 0.7311
#   [GAMO - MLP]
#     AUROC: 0.9437
#     G-mean: 0.7053
#     MCC: 0.5703
#     F1-score: 0.5935
#     mAP: 0.6969
#   [GAMO - RandomForest]
#     AUROC: 0.9467
#     G-mean: 0.7795
#     MCC: 0.6482
#     F1-score: 0.6757
#     mAP: 0.7602
#   [MGVAE - SVM]
#     AUROC: 0.9367
#     G-mean: 0.7071
#     MCC: 0.5737
#     F1-score: 0.5977
#     mAP: 0.7160
#   [MGVAE - DecisionTree]
#     AUROC: 0.8788
#     G-mean: 0.6918
#     MCC: 0.5081
#     F1-score: 0.5463
#     mAP: 0.5427
#   [MGVAE - kNN]
#     AUROC: 0.9388
#     G-mean: 0.8104
#     MCC: 0.6635
#     F1-score: 0.6942
#     mAP: 0.7300
#   [MGVAE - MLP]
#     AUROC: 0.9463
#     G-mean: 0.7598
#     MCC: 0.5983
#     F1-score: 0.6323
#     mAP: 0.7075
#   [MGVAE - RandomForest]
#     AUROC: 0.9637
#     G-mean: 0.7263
#     MCC: 0.6465
#     F1-score: 0.6536
#     mAP: 0.7990
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.9163
#     G-mean: 0.6578
#     MCC: 0.5278
#     F1-score: 0.5453
#     mAP: 0.6701
#   [GAMO - DecisionTree]
#     AUROC: 0.7105
#     G-mean: 0.3522
#     MCC: 0.1200
#     F1-score: 0.1770
#     mAP: 0.2039
#   [GAMO - kNN]
#     AUROC: 0.9392
#     G-mean: 0.8080
#     MCC: 0.6612
#     F1-score: 0.6920
#     mAP: 0.7311
#   [GAMO - MLP]
#     AUROC: 0.9436
#     G-mean: 0.7031
#     MCC: 0.5692
#     F1-score: 0.5918
#     mAP: 0.6970
#   [GAMO - RandomForest]
#     AUROC: 0.9467
#     G-mean: 0.7787
#     MCC: 0.6468
#     F1-score: 0.6745
#     mAP: 0.7598
#   [MGVAE - SVM]
#     AUROC: 0.9367
#     G-mean: 0.7066
#     MCC: 0.5733
#     F1-score: 0.5971
#     mAP: 0.7156
#   [MGVAE - DecisionTree]
#     AUROC: 0.8759
#     G-mean: 0.6920
#     MCC: 0.5067
#     F1-score: 0.5452
#     mAP: 0.5388
#   [MGVAE - kNN]
#     AUROC: 0.9392
#     G-mean: 0.8102
#     MCC: 0.6630
#     F1-score: 0.6938
#     mAP: 0.7302
#   [MGVAE - MLP]
#     AUROC: 0.9465
#     G-mean: 0.7593
#     MCC: 0.5983
#     F1-score: 0.6321
#     mAP: 0.7079
#   [MGVAE - RandomForest]
#     AUROC: 0.9637
#     G-mean: 0.7263
#     MCC: 0.6461
#     F1-score: 0.6534
#     mAP: 0.7989
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.9164
#     G-mean: 0.6581
#     MCC: 0.5289
#     F1-score: 0.5461
#     mAP: 0.6700
#   [GAMO - DecisionTree]
#     AUROC: 0.7133
#     G-mean: 0.3697
#     MCC: 0.1326
#     F1-score: 0.1891
#     mAP: 0.2078
#   [GAMO - kNN]
#     AUROC: 0.9395
#     G-mean: 0.8081
#     MCC: 0.6615
#     F1-score: 0.6923
#     mAP: 0.7314
#   [GAMO - MLP]
#     AUROC: 0.9437
#     G-mean: 0.7038
#     MCC: 0.5712
#     F1-score: 0.5936
#     mAP: 0.6976
#   [GAMO - RandomForest]
#     AUROC: 0.9466
#     G-mean: 0.7782
#     MCC: 0.6460
#     F1-score: 0.6737
#     mAP: 0.7594
#   [MGVAE - SVM]
#     AUROC: 0.9368
#     G-mean: 0.7065
#     MCC: 0.5733
#     F1-score: 0.5970
#     mAP: 0.7157
#   [MGVAE - DecisionTree]
#     AUROC: 0.8756
#     G-mean: 0.6903
#     MCC: 0.5044
#     F1-score: 0.5430
#     mAP: 0.5371
#   [MGVAE - kNN]
#     AUROC: 0.9395
#     G-mean: 0.8103
#     MCC: 0.6631
#     F1-score: 0.6939
#     mAP: 0.7304
#   [MGVAE - MLP]
#     AUROC: 0.9467
#     G-mean: 0.7596
#     MCC: 0.5986
#     F1-score: 0.6324
#     mAP: 0.7083
#   [MGVAE - RandomForest]
#     AUROC: 0.9636
#     G-mean: 0.7264
#     MCC: 0.6464
#     F1-score: 0.6536
#     mAP: 0.7985
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/satimage_results_GAMO_MGVAE_beta_0.001.csv
