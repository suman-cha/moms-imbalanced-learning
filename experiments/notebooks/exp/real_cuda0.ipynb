# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

import os
import warnings
import pandas as pd
from imblearn.datasets import fetch_datasets
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from experiment import run_exp

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# Save path 
save_path = "/data4/oldrain123/oldrain123/results/real_results"
data_path = "/data4/oldrain123/oldrain123/dataset"

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# methods = ["AdaBoost", "SMOTEBoost", "RUSBoost", "OUBoost", "Original", "SMOTE", "ADASYN", "bSMOTE", "ROS", "MWMOTE", "CTGAN", "Ours"]
data = fetch_datasets()
methods = ['GAMO','MGVAE']
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}

kernel_type = 'GAMO_MGVAE'

# %%
data_name = 'abalone9-18'

# 실험 파라미터 설정
n_epochs = 1000
hidden_dims = [16, 32, 64, 128]
latent_dim = 256
lr = 0.01
beta = 0.001


# 데이터 불러오기
abalone9_18 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# 실험 실행
final_res = run_exp(
    data=abalone9_18, 
    cat_idx=[0], 
    methods=methods, 
    kernel_type=kernel_type,
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (731, 8)
# target : Counter({0: 689, 1: 42})
# IR: 16.4
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.8271
#     G-mean: 0.4955
#     MCC: 0.3320
#     F1-score: 0.3352
#     mAP: 0.4374
#   [GAMO - DecisionTree]
#     AUROC: 0.6654
#     G-mean: 0.4107
#     MCC: 0.2846
#     F1-score: 0.2724
#     mAP: 0.2045
#   [GAMO - kNN]
#     AUROC: 0.6991
#     G-mean: 0.3343
#     MCC: 0.2706
#     F1-score: 0.2594
#     mAP: 0.2788
#   [GAMO - MLP]
#     AUROC: 0.7178
#     G-mean: 0.5086
#     MCC: 0.2548
#     F1-score: 0.2980
#     mAP: 0.3472
#   [GAMO - RandomForest]
#     AUROC: 0.8354
#     G-mean: 0.3350
#     MCC: 0.2900
#     F1-score: 0.2686
#     mAP: 0.5427
#   [MGVAE - SVM]
#     AUROC: 0.8593
#     G-mean: 0.5148
#     MCC: 0.3720
#     F1-score: 0.3896
#     mAP: 0.4814
#   [MGVAE - DecisionTree]
#     AUROC: 0.7162
#     G-mean: 0.5105
#     MCC: 0.3350
#     F1-score: 0.3449
#     mAP: 0.2655
#   [MGVAE - kNN]
#     AUROC: 0.7335
#     G-mean: 0.5210
#     MCC: 0.4177
#     F1-score: 0.4204
#     mAP: 0.3929
#   [MGVAE - MLP]
#     AUROC: 0.8460
#     G-mean: 0.7319
#     MCC: 0.3771
#     F1-score: 0.4002
#     mAP: 0.5811
#   [MGVAE - RandomForest]
#     AUROC: 0.8362
#     G-mean: 0.2143
#     MCC: 0.1713
#     F1-score: 0.1619
#     mAP: 0.5089
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.8392
#     G-mean: 0.4822
#     MCC: 0.3228
#     F1-score: 0.3281
#     mAP: 0.4596
#   [GAMO - DecisionTree]
#     AUROC: 0.6730
#     G-mean: 0.3865
#     MCC: 0.2787
#     F1-score: 0.2638
#     mAP: 0.2391
#   [GAMO - kNN]
#     AUROC: 0.6932
#     G-mean: 0.3247
#     MCC: 0.2777
#     F1-score: 0.2564
#     mAP: 0.2868
#   [GAMO - MLP]
#     AUROC: 0.7254
#     G-mean: 0.5389
#     MCC: 0.2802
#     F1-score: 0.3140
#     mAP: 0.3585
#   [GAMO - RandomForest]
#     AUROC: 0.8387
#     G-mean: 0.3251
#     MCC: 0.2906
#     F1-score: 0.2619
#     mAP: 0.5336
#   [MGVAE - SVM]
#     AUROC: 0.8534
#     G-mean: 0.4782
#     MCC: 0.3443
#     F1-score: 0.3601
#     mAP: 0.4697
#   [MGVAE - DecisionTree]
#     AUROC: 0.7044
#     G-mean: 0.4892
#     MCC: 0.3523
#     F1-score: 0.3535
#     mAP: 0.2786
#   [MGVAE - kNN]
#     AUROC: 0.7284
#     G-mean: 0.5396
#     MCC: 0.4369
#     F1-score: 0.4347
#     mAP: 0.3914
#   [MGVAE - MLP]
#     AUROC: 0.8353
#     G-mean: 0.7287
#     MCC: 0.3754
#     F1-score: 0.3961
#     mAP: 0.5605
#   [MGVAE - RandomForest]
#     AUROC: 0.8366
#     G-mean: 0.2778
#     MCC: 0.2502
#     F1-score: 0.2276
#     mAP: 0.5247
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.8404
#     G-mean: 0.4591
#     MCC: 0.3125
#     F1-score: 0.3237
#     mAP: 0.4604
#   [GAMO - DecisionTree]
#     AUROC: 0.6801
#     G-mean: 0.3733
#     MCC: 0.2852
#     F1-score: 0.2692
#     mAP: 0.2479
#   [GAMO - kNN]
#     AUROC: 0.6877
#     G-mean: 0.3226
#     MCC: 0.2834
#     F1-score: 0.2648
#     mAP: 0.2934
#   [GAMO - MLP]
#     AUROC: 0.7337
#     G-mean: 0.5219
#     MCC: 0.2848
#     F1-score: 0.3170
#     mAP: 0.3599
#   [GAMO - RandomForest]
#     AUROC: 0.8377
#     G-mean: 0.3092
#     MCC: 0.2835
#     F1-score: 0.2529
#     mAP: 0.5173
#   [MGVAE - SVM]
#     AUROC: 0.8527
#     G-mean: 0.5022
#     MCC: 0.3657
#     F1-score: 0.3763
#     mAP: 0.4821
#   [MGVAE - DecisionTree]
#     AUROC: 0.7236
#     G-mean: 0.4868
#     MCC: 0.3560
#     F1-score: 0.3587
#     mAP: 0.2997
#   [MGVAE - kNN]
#     AUROC: 0.7243
#     G-mean: 0.5428
#     MCC: 0.4415
#     F1-score: 0.4388
#     mAP: 0.3965
#   [MGVAE - MLP]
#     AUROC: 0.8395
#     G-mean: 0.7283
#     MCC: 0.3724
#     F1-score: 0.3934
#     mAP: 0.5551
#   [MGVAE - RandomForest]
#     AUROC: 0.8364
#     G-mean: 0.2846
#     MCC: 0.2635
#     F1-score: 0.2390
#     mAP: 0.5230
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.8393
#     G-mean: 0.4605
#     MCC: 0.3213
#     F1-score: 0.3293
#     mAP: 0.4577
#   [GAMO - DecisionTree]
#     AUROC: 0.6870
#     G-mean: 0.3520
#     MCC: 0.2717
#     F1-score: 0.2536
#     mAP: 0.2462
#   [GAMO - kNN]
#     AUROC: 0.6899
#     G-mean: 0.3360
#     MCC: 0.2926
#     F1-score: 0.2719
#     mAP: 0.2950
#   [GAMO - MLP]
#     AUROC: 0.7292
#     G-mean: 0.5161
#     MCC: 0.2870
#     F1-score: 0.3177
#     mAP: 0.3500
#   [GAMO - RandomForest]
#     AUROC: 0.8350
#     G-mean: 0.3261
#     MCC: 0.2971
#     F1-score: 0.2651
#     mAP: 0.5170
#   [MGVAE - SVM]
#     AUROC: 0.8524
#     G-mean: 0.5212
#     MCC: 0.3766
#     F1-score: 0.3866
#     mAP: 0.4804
#   [MGVAE - DecisionTree]
#     AUROC: 0.7242
#     G-mean: 0.5193
#     MCC: 0.3842
#     F1-score: 0.3854
#     mAP: 0.3076
#   [MGVAE - kNN]
#     AUROC: 0.7240
#     G-mean: 0.5512
#     MCC: 0.4429
#     F1-score: 0.4429
#     mAP: 0.3968
#   [MGVAE - MLP]
#     AUROC: 0.8350
#     G-mean: 0.7275
#     MCC: 0.3679
#     F1-score: 0.3895
#     mAP: 0.5527
#   [MGVAE - RandomForest]
#     AUROC: 0.8344
#     G-mean: 0.2879
#     MCC: 0.2661
#     F1-score: 0.2430
#     mAP: 0.5253
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.8411
#     G-mean: 0.4554
#     MCC: 0.3213
#     F1-score: 0.3300
#     mAP: 0.4650
#   [GAMO - DecisionTree]
#     AUROC: 0.6911
#     G-mean: 0.3475
#     MCC: 0.2747
#     F1-score: 0.2539
#     mAP: 0.2539
#   [GAMO - kNN]
#     AUROC: 0.6952
#     G-mean: 0.3300
#     MCC: 0.2890
#     F1-score: 0.2682
#     mAP: 0.3024
#   [GAMO - MLP]
#     AUROC: 0.7325
#     G-mean: 0.5186
#     MCC: 0.2953
#     F1-score: 0.3226
#     mAP: 0.3600
#   [GAMO - RandomForest]
#     AUROC: 0.8346
#     G-mean: 0.3239
#     MCC: 0.2988
#     F1-score: 0.2641
#     mAP: 0.5172
#   [MGVAE - SVM]
#     AUROC: 0.8538
#     G-mean: 0.5054
#     MCC: 0.3666
#     F1-score: 0.3755
#     mAP: 0.4813
#   [MGVAE - DecisionTree]
#     AUROC: 0.7237
#     G-mean: 0.5119
#     MCC: 0.3843
#     F1-score: 0.3823
#     mAP: 0.3074
#   [MGVAE - kNN]
#     AUROC: 0.7258
#     G-mean: 0.5478
#     MCC: 0.4450
#     F1-score: 0.4450
#     mAP: 0.4048
#   [MGVAE - MLP]
#     AUROC: 0.8337
#     G-mean: 0.7251
#     MCC: 0.3630
#     F1-score: 0.3840
#     mAP: 0.5516
#   [MGVAE - RandomForest]
#     AUROC: 0.8355
#     G-mean: 0.2934
#     MCC: 0.2703
#     F1-score: 0.2450
#     mAP: 0.5261
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.8371
#     G-mean: 0.4617
#     MCC: 0.3185
#     F1-score: 0.3300
#     mAP: 0.4621
#   [GAMO - DecisionTree]
#     AUROC: 0.6919
#     G-mean: 0.3331
#     MCC: 0.2689
#     F1-score: 0.2502
#     mAP: 0.2538
#   [GAMO - kNN]
#     AUROC: 0.6949
#     G-mean: 0.3300
#     MCC: 0.2841
#     F1-score: 0.2664
#     mAP: 0.2989
#   [GAMO - MLP]
#     AUROC: 0.7320
#     G-mean: 0.5294
#     MCC: 0.2993
#     F1-score: 0.3281
#     mAP: 0.3626
#   [GAMO - RandomForest]
#     AUROC: 0.8350
#     G-mean: 0.3300
#     MCC: 0.3068
#     F1-score: 0.2690
#     mAP: 0.5080
#   [MGVAE - SVM]
#     AUROC: 0.8532
#     G-mean: 0.5110
#     MCC: 0.3673
#     F1-score: 0.3762
#     mAP: 0.4793
#   [MGVAE - DecisionTree]
#     AUROC: 0.7208
#     G-mean: 0.5261
#     MCC: 0.3905
#     F1-score: 0.3911
#     mAP: 0.3144
#   [MGVAE - kNN]
#     AUROC: 0.7268
#     G-mean: 0.5574
#     MCC: 0.4506
#     F1-score: 0.4496
#     mAP: 0.4012
#   [MGVAE - MLP]
#     AUROC: 0.8312
#     G-mean: 0.7240
#     MCC: 0.3611
#     F1-score: 0.3821
#     mAP: 0.5470
#   [MGVAE - RandomForest]
#     AUROC: 0.8341
#     G-mean: 0.2970
#     MCC: 0.2758
#     F1-score: 0.2475
#     mAP: 0.5179
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.8371
#     G-mean: 0.4666
#     MCC: 0.3217
#     F1-score: 0.3313
#     mAP: 0.4599
#   [GAMO - DecisionTree]
#     AUROC: 0.6949
#     G-mean: 0.3489
#     MCC: 0.2784
#     F1-score: 0.2615
#     mAP: 0.2560
#   [GAMO - kNN]
#     AUROC: 0.6914
#     G-mean: 0.3369
#     MCC: 0.2894
#     F1-score: 0.2693
#     mAP: 0.3027
#   [GAMO - MLP]
#     AUROC: 0.7306
#     G-mean: 0.5385
#     MCC: 0.3015
#     F1-score: 0.3317
#     mAP: 0.3639
#   [GAMO - RandomForest]
#     AUROC: 0.8364
#     G-mean: 0.3443
#     MCC: 0.3190
#     F1-score: 0.2797
#     mAP: 0.5117
#   [MGVAE - SVM]
#     AUROC: 0.8545
#     G-mean: 0.5167
#     MCC: 0.3741
#     F1-score: 0.3810
#     mAP: 0.4834
#   [MGVAE - DecisionTree]
#     AUROC: 0.7206
#     G-mean: 0.5311
#     MCC: 0.3916
#     F1-score: 0.3930
#     mAP: 0.3142
#   [MGVAE - kNN]
#     AUROC: 0.7236
#     G-mean: 0.5672
#     MCC: 0.4625
#     F1-score: 0.4582
#     mAP: 0.4027
#   [MGVAE - MLP]
#     AUROC: 0.8338
#     G-mean: 0.7221
#     MCC: 0.3590
#     F1-score: 0.3807
#     mAP: 0.5497
#   [MGVAE - RandomForest]
#     AUROC: 0.8345
#     G-mean: 0.3089
#     MCC: 0.2857
#     F1-score: 0.2552
#     mAP: 0.5231
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.8371
#     G-mean: 0.4614
#     MCC: 0.3192
#     F1-score: 0.3297
#     mAP: 0.4574
#   [GAMO - DecisionTree]
#     AUROC: 0.7014
#     G-mean: 0.3491
#     MCC: 0.2812
#     F1-score: 0.2639
#     mAP: 0.2626
#   [GAMO - kNN]
#     AUROC: 0.6860
#     G-mean: 0.3311
#     MCC: 0.2848
#     F1-score: 0.2649
#     mAP: 0.2937
#   [GAMO - MLP]
#     AUROC: 0.7293
#     G-mean: 0.5246
#     MCC: 0.2916
#     F1-score: 0.3220
#     mAP: 0.3622
#   [GAMO - RandomForest]
#     AUROC: 0.8333
#     G-mean: 0.3376
#     MCC: 0.3125
#     F1-score: 0.2755
#     mAP: 0.5019
#   [MGVAE - SVM]
#     AUROC: 0.8527
#     G-mean: 0.5185
#     MCC: 0.3748
#     F1-score: 0.3818
#     mAP: 0.4842
#   [MGVAE - DecisionTree]
#     AUROC: 0.7171
#     G-mean: 0.5238
#     MCC: 0.3822
#     F1-score: 0.3839
#     mAP: 0.3085
#   [MGVAE - kNN]
#     AUROC: 0.7228
#     G-mean: 0.5622
#     MCC: 0.4582
#     F1-score: 0.4544
#     mAP: 0.4019
#   [MGVAE - MLP]
#     AUROC: 0.8358
#     G-mean: 0.7233
#     MCC: 0.3627
#     F1-score: 0.3832
#     mAP: 0.5555
#   [MGVAE - RandomForest]
#     AUROC: 0.8340
#     G-mean: 0.3040
#     MCC: 0.2802
#     F1-score: 0.2502
#     mAP: 0.5196
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.8365
#     G-mean: 0.4653
#     MCC: 0.3208
#     F1-score: 0.3323
#     mAP: 0.4561
#   [GAMO - DecisionTree]
#     AUROC: 0.7031
#     G-mean: 0.3519
#     MCC: 0.2870
#     F1-score: 0.2705
#     mAP: 0.2669
#   [GAMO - kNN]
#     AUROC: 0.6845
#     G-mean: 0.3316
#     MCC: 0.2873
#     F1-score: 0.2666
#     mAP: 0.2922
#   [GAMO - MLP]
#     AUROC: 0.7281
#     G-mean: 0.5292
#     MCC: 0.2929
#     F1-score: 0.3245
#     mAP: 0.3638
#   [GAMO - RandomForest]
#     AUROC: 0.8340
#     G-mean: 0.3430
#     MCC: 0.3179
#     F1-score: 0.2802
#     mAP: 0.5021
#   [MGVAE - SVM]
#     AUROC: 0.8545
#     G-mean: 0.5187
#     MCC: 0.3738
#     F1-score: 0.3816
#     mAP: 0.4842
#   [MGVAE - DecisionTree]
#     AUROC: 0.7184
#     G-mean: 0.5154
#     MCC: 0.3792
#     F1-score: 0.3816
#     mAP: 0.3114
#   [MGVAE - kNN]
#     AUROC: 0.7240
#     G-mean: 0.5573
#     MCC: 0.4530
#     F1-score: 0.4493
#     mAP: 0.3972
#   [MGVAE - MLP]
#     AUROC: 0.8362
#     G-mean: 0.7187
#     MCC: 0.3559
#     F1-score: 0.3765
#     mAP: 0.5502
#   [MGVAE - RandomForest]
#     AUROC: 0.8334
#     G-mean: 0.2941
#     MCC: 0.2707
#     F1-score: 0.2413
#     mAP: 0.5200
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.8380
#     G-mean: 0.4622
#     MCC: 0.3192
#     F1-score: 0.3319
#     mAP: 0.4557
#   [GAMO - DecisionTree]
#     AUROC: 0.7012
#     G-mean: 0.3452
#     MCC: 0.2814
#     F1-score: 0.2660
#     mAP: 0.2664
#   [GAMO - kNN]
#     AUROC: 0.6857
#     G-mean: 0.3290
#     MCC: 0.2851
#     F1-score: 0.2656
#     mAP: 0.2946
#   [GAMO - MLP]
#     AUROC: 0.7267
#     G-mean: 0.5277
#     MCC: 0.2892
#     F1-score: 0.3212
#     mAP: 0.3608
#   [GAMO - RandomForest]
#     AUROC: 0.8333
#     G-mean: 0.3352
#     MCC: 0.3102
#     F1-score: 0.2735
#     mAP: 0.5026
#   [MGVAE - SVM]
#     AUROC: 0.8531
#     G-mean: 0.5219
#     MCC: 0.3757
#     F1-score: 0.3836
#     mAP: 0.4836
#   [MGVAE - DecisionTree]
#     AUROC: 0.7172
#     G-mean: 0.5226
#     MCC: 0.3814
#     F1-score: 0.3857
#     mAP: 0.3094
#   [MGVAE - kNN]
#     AUROC: 0.7242
#     G-mean: 0.5587
#     MCC: 0.4526
#     F1-score: 0.4497
#     mAP: 0.3962
#   [MGVAE - MLP]
#     AUROC: 0.8348
#     G-mean: 0.7169
#     MCC: 0.3528
#     F1-score: 0.3733
#     mAP: 0.5464
#   [MGVAE - RandomForest]
#     AUROC: 0.8333
#     G-mean: 0.2883
#     MCC: 0.2649
#     F1-score: 0.2372
#     mAP: 0.5210
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/abalone9-18_results_GAMO_MGVAE_beta_0.001.csv

# %%
data_name = 'abalone19'

# 실험 파라미터 설정
n_epochs = 1000
hidden_dims = [16, 32, 64, 128]
latent_dim = 256
lr = 0.01
beta = 0.001


# 데이터 불러오기
abalone19 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# 실험 실행
final_res = run_exp(
    data=abalone19, 
    cat_idx=[0], 
    methods=methods, 
    kernel_type=kernel_type,
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (4174, 8)
# target : Counter({0: 4142, 1: 32})
# IR: 129.44
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.5557
#     G-mean: 0.0000
#     MCC: -0.0057
#     F1-score: 0.0000
#     mAP: 0.0175
#   [GAMO - DecisionTree]
#     AUROC: 0.6786
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0146
#   [GAMO - kNN]
#     AUROC: 0.5586
#     G-mean: 0.0000
#     MCC: -0.0012
#     F1-score: 0.0000
#     mAP: 0.0158
#   [GAMO - MLP]
#     AUROC: 0.6208
#     G-mean: 0.0000
#     MCC: -0.0082
#     F1-score: 0.0000
#     mAP: 0.0216
#   [GAMO - RandomForest]
#     AUROC: 0.7015
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0376
#   [MGVAE - SVM]
#     AUROC: 0.7359
#     G-mean: 0.0000
#     MCC: -0.0018
#     F1-score: 0.0000
#     mAP: 0.0587
#   [MGVAE - DecisionTree]
#     AUROC: 0.6737
#     G-mean: 0.0000
#     MCC: -0.0045
#     F1-score: 0.0000
#     mAP: 0.0244
#   [MGVAE - kNN]
#     AUROC: 0.5619
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0183
#   [MGVAE - MLP]
#     AUROC: 0.7310
#     G-mean: 0.0000
#     MCC: -0.0060
#     F1-score: 0.0000
#     mAP: 0.0426
#   [MGVAE - RandomForest]
#     AUROC: 0.7153
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0576
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.5618
#     G-mean: 0.0000
#     MCC: -0.0059
#     F1-score: 0.0000
#     mAP: 0.0173
#   [GAMO - DecisionTree]
#     AUROC: 0.6707
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0135
#   [GAMO - kNN]
#     AUROC: 0.5734
#     G-mean: 0.0000
#     MCC: -0.0013
#     F1-score: 0.0000
#     mAP: 0.0171
#   [GAMO - MLP]
#     AUROC: 0.6320
#     G-mean: 0.0000
#     MCC: -0.0078
#     F1-score: 0.0000
#     mAP: 0.0215
#   [GAMO - RandomForest]
#     AUROC: 0.7110
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0418
#   [MGVAE - SVM]
#     AUROC: 0.7426
#     G-mean: 0.0000
#     MCC: -0.0014
#     F1-score: 0.0000
#     mAP: 0.0571
#   [MGVAE - DecisionTree]
#     AUROC: 0.6613
#     G-mean: 0.0000
#     MCC: -0.0046
#     F1-score: 0.0000
#     mAP: 0.0215
#   [MGVAE - kNN]
#     AUROC: 0.5686
#     G-mean: 0.0000
#     MCC: -0.0004
#     F1-score: 0.0000
#     mAP: 0.0188
#   [MGVAE - MLP]
#     AUROC: 0.7317
#     G-mean: 0.0000
#     MCC: -0.0059
#     F1-score: 0.0000
#     mAP: 0.0420
#   [MGVAE - RandomForest]
#     AUROC: 0.7221
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0567
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.5533
#     G-mean: 0.0000
#     MCC: -0.0058
#     F1-score: 0.0000
#     mAP: 0.0167
#   [GAMO - DecisionTree]
#     AUROC: 0.6743
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0138
#   [GAMO - kNN]
#     AUROC: 0.5644
#     G-mean: 0.0000
#     MCC: -0.0014
#     F1-score: 0.0000
#     mAP: 0.0165
#   [GAMO - MLP]
#     AUROC: 0.6205
#     G-mean: 0.0000
#     MCC: -0.0077
#     F1-score: 0.0000
#     mAP: 0.0215
#   [GAMO - RandomForest]
#     AUROC: 0.7047
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0512
#   [MGVAE - SVM]
#     AUROC: 0.7426
#     G-mean: 0.0000
#     MCC: -0.0015
#     F1-score: 0.0000
#     mAP: 0.0566
#   [MGVAE - DecisionTree]
#     AUROC: 0.6776
#     G-mean: 0.0000
#     MCC: -0.0040
#     F1-score: 0.0000
#     mAP: 0.0339
#   [MGVAE - kNN]
#     AUROC: 0.5664
#     G-mean: 0.0000
#     MCC: -0.0003
#     F1-score: 0.0000
#     mAP: 0.0193
#   [MGVAE - MLP]
#     AUROC: 0.7281
#     G-mean: 0.0000
#     MCC: -0.0060
#     F1-score: 0.0000
#     mAP: 0.0446
#   [MGVAE - RandomForest]
#     AUROC: 0.7290
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0724
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.5568
#     G-mean: 0.0000
#     MCC: -0.0058
#     F1-score: 0.0000
#     mAP: 0.0166
#   [GAMO - DecisionTree]
#     AUROC: 0.6757
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0147
#   [GAMO - kNN]
#     AUROC: 0.5630
#     G-mean: 0.0000
#     MCC: -0.0014
#     F1-score: 0.0000
#     mAP: 0.0172
#   [GAMO - MLP]
#     AUROC: 0.6196
#     G-mean: 0.0000
#     MCC: -0.0077
#     F1-score: 0.0000
#     mAP: 0.0211
#   [GAMO - RandomForest]
#     AUROC: 0.7087
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0473
#   [MGVAE - SVM]
#     AUROC: 0.7436
#     G-mean: 0.0000
#     MCC: -0.0014
#     F1-score: 0.0000
#     mAP: 0.0549
#   [MGVAE - DecisionTree]
#     AUROC: 0.6652
#     G-mean: 0.0000
#     MCC: -0.0040
#     F1-score: 0.0000
#     mAP: 0.0352
#   [MGVAE - kNN]
#     AUROC: 0.5652
#     G-mean: 0.0000
#     MCC: -0.0002
#     F1-score: 0.0000
#     mAP: 0.0200
#   [MGVAE - MLP]
#     AUROC: 0.7302
#     G-mean: 0.0000
#     MCC: -0.0056
#     F1-score: 0.0000
#     mAP: 0.0429
#   [MGVAE - RandomForest]
#     AUROC: 0.7239
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0644
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.5575
#     G-mean: 0.0000
#     MCC: -0.0058
#     F1-score: 0.0000
#     mAP: 0.0168
#   [GAMO - DecisionTree]
#     AUROC: 0.6712
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0142
#   [GAMO - kNN]
#     AUROC: 0.5597
#     G-mean: 0.0000
#     MCC: -0.0014
#     F1-score: 0.0000
#     mAP: 0.0175
#   [GAMO - MLP]
#     AUROC: 0.6182
#     G-mean: 0.0000
#     MCC: -0.0077
#     F1-score: 0.0000
#     mAP: 0.0214
#   [GAMO - RandomForest]
#     AUROC: 0.6992
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0437
#   [MGVAE - SVM]
#     AUROC: 0.7431
#     G-mean: 0.0000
#     MCC: -0.0014
#     F1-score: 0.0000
#     mAP: 0.0558
#   [MGVAE - DecisionTree]
#     AUROC: 0.6668
#     G-mean: 0.0000
#     MCC: -0.0040
#     F1-score: 0.0000
#     mAP: 0.0333
#   [MGVAE - kNN]
#     AUROC: 0.5620
#     G-mean: 0.0000
#     MCC: -0.0002
#     F1-score: 0.0000
#     mAP: 0.0199
#   [MGVAE - MLP]
#     AUROC: 0.7294
#     G-mean: 0.0000
#     MCC: -0.0053
#     F1-score: 0.0000
#     mAP: 0.0456
#   [MGVAE - RandomForest]
#     AUROC: 0.7186
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0595
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.5577
#     G-mean: 0.0000
#     MCC: -0.0058
#     F1-score: 0.0000
#     mAP: 0.0170
#   [GAMO - DecisionTree]
#     AUROC: 0.6680
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0141
#   [GAMO - kNN]
#     AUROC: 0.5623
#     G-mean: 0.0000
#     MCC: -0.0014
#     F1-score: 0.0000
#     mAP: 0.0175
#   [GAMO - MLP]
#     AUROC: 0.6133
#     G-mean: 0.0000
#     MCC: -0.0077
#     F1-score: 0.0000
#     mAP: 0.0211
#   [GAMO - RandomForest]
#     AUROC: 0.6956
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0429
#   [MGVAE - SVM]
#     AUROC: 0.7436
#     G-mean: 0.0000
#     MCC: -0.0014
#     F1-score: 0.0000
#     mAP: 0.0550
#   [MGVAE - DecisionTree]
#     AUROC: 0.6673
#     G-mean: 0.0000
#     MCC: -0.0039
#     F1-score: 0.0000
#     mAP: 0.0311
#   [MGVAE - kNN]
#     AUROC: 0.5648
#     G-mean: 0.0000
#     MCC: -0.0001
#     F1-score: 0.0000
#     mAP: 0.0200
#   [MGVAE - MLP]
#     AUROC: 0.7274
#     G-mean: 0.0191
#     MCC: 0.0017
#     F1-score: 0.0067
#     mAP: 0.0454
#   [MGVAE - RandomForest]
#     AUROC: 0.7210
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0598
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.5623
#     G-mean: 0.0000
#     MCC: -0.0058
#     F1-score: 0.0000
#     mAP: 0.0172
#   [GAMO - DecisionTree]
#     AUROC: 0.6705
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0142
#   [GAMO - kNN]
#     AUROC: 0.5598
#     G-mean: 0.0000
#     MCC: -0.0014
#     F1-score: 0.0000
#     mAP: 0.0170
#   [GAMO - MLP]
#     AUROC: 0.6153
#     G-mean: 0.0000
#     MCC: -0.0077
#     F1-score: 0.0000
#     mAP: 0.0211
#   [GAMO - RandomForest]
#     AUROC: 0.7028
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0432
#   [MGVAE - SVM]
#     AUROC: 0.7420
#     G-mean: 0.0000
#     MCC: -0.0013
#     F1-score: 0.0000
#     mAP: 0.0541
#   [MGVAE - DecisionTree]
#     AUROC: 0.6634
#     G-mean: 0.0000
#     MCC: -0.0040
#     F1-score: 0.0000
#     mAP: 0.0294
#   [MGVAE - kNN]
#     AUROC: 0.5626
#     G-mean: 0.0000
#     MCC: -0.0002
#     F1-score: 0.0000
#     mAP: 0.0193
#   [MGVAE - MLP]
#     AUROC: 0.7259
#     G-mean: 0.0164
#     MCC: 0.0006
#     F1-score: 0.0058
#     mAP: 0.0451
#   [MGVAE - RandomForest]
#     AUROC: 0.7224
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0611
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.5635
#     G-mean: 0.0000
#     MCC: -0.0059
#     F1-score: 0.0000
#     mAP: 0.0172
#   [GAMO - DecisionTree]
#     AUROC: 0.6736
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0144
#   [GAMO - kNN]
#     AUROC: 0.5581
#     G-mean: 0.0000
#     MCC: -0.0013
#     F1-score: 0.0000
#     mAP: 0.0167
#   [GAMO - MLP]
#     AUROC: 0.6144
#     G-mean: 0.0000
#     MCC: -0.0077
#     F1-score: 0.0000
#     mAP: 0.0212
#   [GAMO - RandomForest]
#     AUROC: 0.7018
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0432
#   [MGVAE - SVM]
#     AUROC: 0.7423
#     G-mean: 0.0000
#     MCC: -0.0014
#     F1-score: 0.0000
#     mAP: 0.0562
#   [MGVAE - DecisionTree]
#     AUROC: 0.6636
#     G-mean: 0.0000
#     MCC: -0.0040
#     F1-score: 0.0000
#     mAP: 0.0287
#   [MGVAE - kNN]
#     AUROC: 0.5610
#     G-mean: 0.0000
#     MCC: -0.0002
#     F1-score: 0.0000
#     mAP: 0.0190
#   [MGVAE - MLP]
#     AUROC: 0.7269
#     G-mean: 0.0143
#     MCC: 0.0001
#     F1-score: 0.0050
#     mAP: 0.0463
#   [MGVAE - RandomForest]
#     AUROC: 0.7187
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0608
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.5615
#     G-mean: 0.0000
#     MCC: -0.0059
#     F1-score: 0.0000
#     mAP: 0.0171
#   [GAMO - DecisionTree]
#     AUROC: 0.6744
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0147
#   [GAMO - kNN]
#     AUROC: 0.5563
#     G-mean: 0.0000
#     MCC: -0.0013
#     F1-score: 0.0000
#     mAP: 0.0164
#   [GAMO - MLP]
#     AUROC: 0.6134
#     G-mean: 0.0000
#     MCC: -0.0078
#     F1-score: 0.0000
#     mAP: 0.0209
#   [GAMO - RandomForest]
#     AUROC: 0.6994
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0420
#   [MGVAE - SVM]
#     AUROC: 0.7429
#     G-mean: 0.0000
#     MCC: -0.0015
#     F1-score: 0.0000
#     mAP: 0.0583
#   [MGVAE - DecisionTree]
#     AUROC: 0.6645
#     G-mean: 0.0000
#     MCC: -0.0040
#     F1-score: 0.0000
#     mAP: 0.0274
#   [MGVAE - kNN]
#     AUROC: 0.5592
#     G-mean: 0.0000
#     MCC: -0.0001
#     F1-score: 0.0000
#     mAP: 0.0185
#   [MGVAE - MLP]
#     AUROC: 0.7272
#     G-mean: 0.0127
#     MCC: -0.0007
#     F1-score: 0.0045
#     mAP: 0.0458
#   [MGVAE - RandomForest]
#     AUROC: 0.7211
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0616
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.5608
#     G-mean: 0.0000
#     MCC: -0.0059
#     F1-score: 0.0000
#     mAP: 0.0170
#   [GAMO - DecisionTree]
#     AUROC: 0.6713
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0145
#   [GAMO - kNN]
#     AUROC: 0.5561
#     G-mean: 0.0000
#     MCC: -0.0012
#     F1-score: 0.0000
#     mAP: 0.0170
#   [GAMO - MLP]
#     AUROC: 0.6130
#     G-mean: 0.0000
#     MCC: -0.0077
#     F1-score: 0.0000
#     mAP: 0.0209
#   [GAMO - RandomForest]
#     AUROC: 0.7008
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0422
#   [MGVAE - SVM]
#     AUROC: 0.7439
#     G-mean: 0.0000
#     MCC: -0.0015
#     F1-score: 0.0000
#     mAP: 0.0589
#   [MGVAE - DecisionTree]
#     AUROC: 0.6673
#     G-mean: 0.0000
#     MCC: -0.0039
#     F1-score: 0.0000
#     mAP: 0.0283
#   [MGVAE - kNN]
#     AUROC: 0.5591
#     G-mean: 0.0000
#     MCC: -0.0001
#     F1-score: 0.0000
#     mAP: 0.0191
#   [MGVAE - MLP]
#     AUROC: 0.7278
#     G-mean: 0.0115
#     MCC: -0.0010
#     F1-score: 0.0040
#     mAP: 0.0460
#   [MGVAE - RandomForest]
#     AUROC: 0.7248
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.0612
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/abalone19_results_GAMO_MGVAE_beta_0.001.csv

# %%
# arrhythmia
data_name = 'arrhythmia'
maj_target_name = -1

n_epochs = 1000
hidden_dims = [256, 128, 64, 32]
latent_dim = 32
lr = 0.01
beta = 0.0

final_res = run_exp(
    data=data, 
    cat_idx=[], 
    kernel_type=kernel_type,
    methods=methods, 
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    maj_target_name=maj_target_name,
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded: arrhythmia
# X shape : (452, 278)
# target : Counter({0: 427, 1: 25})
# IR: 17.08
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.7042
#     G-mean: 0.1178
#     MCC: -0.0614
#     F1-score: 0.0404
#     mAP: 0.1311
#   [GAMO - DecisionTree]
#     AUROC: 0.8531
#     G-mean: 0.8335
#     MCC: 0.6766
#     F1-score: 0.6805
#     mAP: 0.5449
#   [GAMO - kNN]
#     AUROC: 0.6828
#     G-mean: 0.0000
#     MCC: -0.0185
#     F1-score: 0.0000
#     mAP: 0.1404
#   [GAMO - MLP]
#     AUROC: 0.7096
#     G-mean: 0.1354
#     MCC: 0.0101
#     F1-score: 0.0857
#     mAP: 0.1686
#   [GAMO - RandomForest]
#     AUROC: 0.9776
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.8558
#   [MGVAE - SVM]
#     AUROC: 0.8266
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.3626
#   [MGVAE - DecisionTree]
#     AUROC: 0.9062
#     G-mean: 0.8947
#     MCC: 0.7638
#     F1-score: 0.7586
#     mAP: 0.6350
#   [MGVAE - kNN]
#     AUROC: 0.7590
#     G-mean: 0.5500
#     MCC: 0.2052
#     F1-score: 0.2359
#     mAP: 0.2470
#   [MGVAE - MLP]
#     AUROC: 0.7921
#     G-mean: 0.3285
#     MCC: 0.1620
#     F1-score: 0.2082
#     mAP: 0.2811
#   [MGVAE - RandomForest]
#     AUROC: 0.9581
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.7519
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.7027
#     G-mean: 0.1135
#     MCC: -0.0653
#     F1-score: 0.0341
#     mAP: 0.1287
#   [GAMO - DecisionTree]
#     AUROC: 0.8606
#     G-mean: 0.8455
#     MCC: 0.6564
#     F1-score: 0.6614
#     mAP: 0.5111
#   [GAMO - kNN]
#     AUROC: 0.6870
#     G-mean: 0.0000
#     MCC: -0.0217
#     F1-score: 0.0000
#     mAP: 0.1438
#   [GAMO - MLP]
#     AUROC: 0.6949
#     G-mean: 0.1022
#     MCC: -0.0127
#     F1-score: 0.0629
#     mAP: 0.1588
#   [GAMO - RandomForest]
#     AUROC: 0.9651
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.8059
#   [MGVAE - SVM]
#     AUROC: 0.8126
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.3487
#   [MGVAE - DecisionTree]
#     AUROC: 0.8990
#     G-mean: 0.8867
#     MCC: 0.7677
#     F1-score: 0.7636
#     mAP: 0.6369
#   [MGVAE - kNN]
#     AUROC: 0.7636
#     G-mean: 0.5364
#     MCC: 0.2041
#     F1-score: 0.2344
#     mAP: 0.2442
#   [MGVAE - MLP]
#     AUROC: 0.7751
#     G-mean: 0.2688
#     MCC: 0.1229
#     F1-score: 0.1717
#     mAP: 0.2745
#   [MGVAE - RandomForest]
#     AUROC: 0.9537
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.7167
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.7009
#     G-mean: 0.1108
#     MCC: -0.0660
#     F1-score: 0.0353
#     mAP: 0.1272
#   [GAMO - DecisionTree]
#     AUROC: 0.8774
#     G-mean: 0.8625
#     MCC: 0.6823
#     F1-score: 0.6814
#     mAP: 0.5398
#   [GAMO - kNN]
#     AUROC: 0.6908
#     G-mean: 0.0190
#     MCC: -0.0082
#     F1-score: 0.0133
#     mAP: 0.1470
#   [GAMO - MLP]
#     AUROC: 0.6834
#     G-mean: 0.1293
#     MCC: -0.0087
#     F1-score: 0.0630
#     mAP: 0.1555
#   [GAMO - RandomForest]
#     AUROC: 0.9696
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.8138
#   [MGVAE - SVM]
#     AUROC: 0.8133
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.3414
#   [MGVAE - DecisionTree]
#     AUROC: 0.8767
#     G-mean: 0.8603
#     MCC: 0.7409
#     F1-score: 0.7380
#     mAP: 0.6124
#   [MGVAE - kNN]
#     AUROC: 0.7588
#     G-mean: 0.5399
#     MCC: 0.2008
#     F1-score: 0.2320
#     mAP: 0.2224
#   [MGVAE - MLP]
#     AUROC: 0.7861
#     G-mean: 0.2576
#     MCC: 0.1293
#     F1-score: 0.1735
#     mAP: 0.3004
#   [MGVAE - RandomForest]
#     AUROC: 0.9584
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.7427
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.6955
#     G-mean: 0.1126
#     MCC: -0.0663
#     F1-score: 0.0372
#     mAP: 0.1265
#   [GAMO - DecisionTree]
#     AUROC: 0.8733
#     G-mean: 0.8469
#     MCC: 0.6710
#     F1-score: 0.6712
#     mAP: 0.5331
#   [GAMO - kNN]
#     AUROC: 0.6809
#     G-mean: 0.0143
#     MCC: -0.0110
#     F1-score: 0.0100
#     mAP: 0.1502
#   [GAMO - MLP]
#     AUROC: 0.6828
#     G-mean: 0.1243
#     MCC: -0.0120
#     F1-score: 0.0601
#     mAP: 0.1590
#   [GAMO - RandomForest]
#     AUROC: 0.9688
#     G-mean: 0.0177
#     MCC: 0.0175
#     F1-score: 0.0167
#     mAP: 0.8146
#   [MGVAE - SVM]
#     AUROC: 0.8121
#     G-mean: 0.0000
#     MCC: -0.0010
#     F1-score: 0.0000
#     mAP: 0.3551
#   [MGVAE - DecisionTree]
#     AUROC: 0.8737
#     G-mean: 0.8559
#     MCC: 0.7292
#     F1-score: 0.7286
#     mAP: 0.5988
#   [MGVAE - kNN]
#     AUROC: 0.7512
#     G-mean: 0.5409
#     MCC: 0.1954
#     F1-score: 0.2281
#     mAP: 0.2256
#   [MGVAE - MLP]
#     AUROC: 0.7851
#     G-mean: 0.2622
#     MCC: 0.1385
#     F1-score: 0.1801
#     mAP: 0.2891
#   [MGVAE - RandomForest]
#     AUROC: 0.9576
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.7396
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.6956
#     G-mean: 0.1227
#     MCC: -0.0625
#     F1-score: 0.0387
#     mAP: 0.1262
#   [GAMO - DecisionTree]
#     AUROC: 0.8635
#     G-mean: 0.8294
#     MCC: 0.6510
#     F1-score: 0.6526
#     mAP: 0.5152
#   [GAMO - kNN]
#     AUROC: 0.6753
#     G-mean: 0.0114
#     MCC: -0.0125
#     F1-score: 0.0080
#     mAP: 0.1563
#   [GAMO - MLP]
#     AUROC: 0.6843
#     G-mean: 0.1371
#     MCC: -0.0041
#     F1-score: 0.0651
#     mAP: 0.1651
#   [GAMO - RandomForest]
#     AUROC: 0.9686
#     G-mean: 0.0141
#     MCC: 0.0140
#     F1-score: 0.0133
#     mAP: 0.8146
#   [MGVAE - SVM]
#     AUROC: 0.8029
#     G-mean: 0.0000
#     MCC: -0.0008
#     F1-score: 0.0000
#     mAP: 0.3476
#   [MGVAE - DecisionTree]
#     AUROC: 0.8611
#     G-mean: 0.8417
#     MCC: 0.7044
#     F1-score: 0.7050
#     mAP: 0.5672
#   [MGVAE - kNN]
#     AUROC: 0.7431
#     G-mean: 0.5203
#     MCC: 0.1882
#     F1-score: 0.2257
#     mAP: 0.2231
#   [MGVAE - MLP]
#     AUROC: 0.7732
#     G-mean: 0.2554
#     MCC: 0.1362
#     F1-score: 0.1777
#     mAP: 0.2865
#   [MGVAE - RandomForest]
#     AUROC: 0.9580
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.7431
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.6961
#     G-mean: 0.1189
#     MCC: -0.0647
#     F1-score: 0.0368
#     mAP: 0.1255
#   [GAMO - DecisionTree]
#     AUROC: 0.8601
#     G-mean: 0.8280
#     MCC: 0.6502
#     F1-score: 0.6529
#     mAP: 0.5144
#   [GAMO - kNN]
#     AUROC: 0.6740
#     G-mean: 0.0095
#     MCC: -0.0132
#     F1-score: 0.0067
#     mAP: 0.1596
#   [GAMO - MLP]
#     AUROC: 0.6830
#     G-mean: 0.1411
#     MCC: -0.0051
#     F1-score: 0.0651
#     mAP: 0.1616
#   [GAMO - RandomForest]
#     AUROC: 0.9686
#     G-mean: 0.0236
#     MCC: 0.0233
#     F1-score: 0.0222
#     mAP: 0.8147
#   [MGVAE - SVM]
#     AUROC: 0.8027
#     G-mean: 0.0000
#     MCC: -0.0007
#     F1-score: 0.0000
#     mAP: 0.3490
#   [MGVAE - DecisionTree]
#     AUROC: 0.8504
#     G-mean: 0.8152
#     MCC: 0.6832
#     F1-score: 0.6830
#     mAP: 0.5524
#   [MGVAE - kNN]
#     AUROC: 0.7409
#     G-mean: 0.5302
#     MCC: 0.1937
#     F1-score: 0.2293
#     mAP: 0.2217
#   [MGVAE - MLP]
#     AUROC: 0.7664
#     G-mean: 0.2858
#     MCC: 0.1498
#     F1-score: 0.1918
#     mAP: 0.2841
#   [MGVAE - RandomForest]
#     AUROC: 0.9575
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.7463
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.6971
#     G-mean: 0.1179
#     MCC: -0.0654
#     F1-score: 0.0357
#     mAP: 0.1250
#   [GAMO - DecisionTree]
#     AUROC: 0.8611
#     G-mean: 0.8309
#     MCC: 0.6554
#     F1-score: 0.6563
#     mAP: 0.5182
#   [GAMO - kNN]
#     AUROC: 0.6766
#     G-mean: 0.0082
#     MCC: -0.0134
#     F1-score: 0.0057
#     mAP: 0.1681
#   [GAMO - MLP]
#     AUROC: 0.6881
#     G-mean: 0.1289
#     MCC: -0.0099
#     F1-score: 0.0599
#     mAP: 0.1769
#   [GAMO - RandomForest]
#     AUROC: 0.9676
#     G-mean: 0.0284
#     MCC: 0.0280
#     F1-score: 0.0262
#     mAP: 0.8160
#   [MGVAE - SVM]
#     AUROC: 0.8084
#     G-mean: 0.0000
#     MCC: -0.0006
#     F1-score: 0.0000
#     mAP: 0.3514
#   [MGVAE - DecisionTree]
#     AUROC: 0.8474
#     G-mean: 0.8139
#     MCC: 0.6794
#     F1-score: 0.6804
#     mAP: 0.5482
#   [MGVAE - kNN]
#     AUROC: 0.7471
#     G-mean: 0.5332
#     MCC: 0.1928
#     F1-score: 0.2279
#     mAP: 0.2237
#   [MGVAE - MLP]
#     AUROC: 0.7680
#     G-mean: 0.2987
#     MCC: 0.1610
#     F1-score: 0.2002
#     mAP: 0.2900
#   [MGVAE - RandomForest]
#     AUROC: 0.9568
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.7533
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.6973
#     G-mean: 0.1175
#     MCC: -0.0656
#     F1-score: 0.0360
#     mAP: 0.1255
#   [GAMO - DecisionTree]
#     AUROC: 0.8615
#     G-mean: 0.8324
#     MCC: 0.6567
#     F1-score: 0.6578
#     mAP: 0.5219
#   [GAMO - kNN]
#     AUROC: 0.6754
#     G-mean: 0.0071
#     MCC: -0.0138
#     F1-score: 0.0050
#     mAP: 0.1668
#   [GAMO - MLP]
#     AUROC: 0.6892
#     G-mean: 0.1341
#     MCC: -0.0088
#     F1-score: 0.0599
#     mAP: 0.1738
#   [GAMO - RandomForest]
#     AUROC: 0.9678
#     G-mean: 0.0249
#     MCC: 0.0245
#     F1-score: 0.0229
#     mAP: 0.8127
#   [MGVAE - SVM]
#     AUROC: 0.8060
#     G-mean: 0.0000
#     MCC: -0.0005
#     F1-score: 0.0000
#     mAP: 0.3560
#   [MGVAE - DecisionTree]
#     AUROC: 0.8484
#     G-mean: 0.8165
#     MCC: 0.6795
#     F1-score: 0.6815
#     mAP: 0.5484
#   [MGVAE - kNN]
#     AUROC: 0.7464
#     G-mean: 0.5281
#     MCC: 0.1910
#     F1-score: 0.2270
#     mAP: 0.2217
#   [MGVAE - MLP]
#     AUROC: 0.7602
#     G-mean: 0.2996
#     MCC: 0.1563
#     F1-score: 0.1971
#     mAP: 0.2893
#   [MGVAE - RandomForest]
#     AUROC: 0.9581
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.7566
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.7001
#     G-mean: 0.1244
#     MCC: -0.0630
#     F1-score: 0.0380
#     mAP: 0.1261
#   [GAMO - DecisionTree]
#     AUROC: 0.8648
#     G-mean: 0.8380
#     MCC: 0.6627
#     F1-score: 0.6638
#     mAP: 0.5285
#   [GAMO - kNN]
#     AUROC: 0.6767
#     G-mean: 0.0142
#     MCC: -0.0059
#     F1-score: 0.0119
#     mAP: 0.1699
#   [GAMO - MLP]
#     AUROC: 0.6922
#     G-mean: 0.1339
#     MCC: -0.0111
#     F1-score: 0.0585
#     mAP: 0.1724
#   [GAMO - RandomForest]
#     AUROC: 0.9680
#     G-mean: 0.0300
#     MCC: 0.0296
#     F1-score: 0.0278
#     mAP: 0.8177
#   [MGVAE - SVM]
#     AUROC: 0.8097
#     G-mean: 0.0000
#     MCC: -0.0004
#     F1-score: 0.0000
#     mAP: 0.3616
#   [MGVAE - DecisionTree]
#     AUROC: 0.8502
#     G-mean: 0.8148
#     MCC: 0.6798
#     F1-score: 0.6810
#     mAP: 0.5521
#   [MGVAE - kNN]
#     AUROC: 0.7513
#     G-mean: 0.5368
#     MCC: 0.1959
#     F1-score: 0.2299
#     mAP: 0.2310
#   [MGVAE - MLP]
#     AUROC: 0.7670
#     G-mean: 0.3084
#     MCC: 0.1651
#     F1-score: 0.2047
#     mAP: 0.2989
#   [MGVAE - RandomForest]
#     AUROC: 0.9591
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.7637
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.7006
#     G-mean: 0.1223
#     MCC: -0.0640
#     F1-score: 0.0375
#     mAP: 0.1263
#   [GAMO - DecisionTree]
#     AUROC: 0.8679
#     G-mean: 0.8383
#     MCC: 0.6665
#     F1-score: 0.6670
#     mAP: 0.5362
#   [GAMO - kNN]
#     AUROC: 0.6746
#     G-mean: 0.0128
#     MCC: -0.0069
#     F1-score: 0.0107
#     mAP: 0.1680
#   [GAMO - MLP]
#     AUROC: 0.6901
#     G-mean: 0.1259
#     MCC: -0.0161
#     F1-score: 0.0549
#     mAP: 0.1696
#   [GAMO - RandomForest]
#     AUROC: 0.9688
#     G-mean: 0.0340
#     MCC: 0.0336
#     F1-score: 0.0317
#     mAP: 0.8211
#   [MGVAE - SVM]
#     AUROC: 0.8099
#     G-mean: 0.0000
#     MCC: -0.0004
#     F1-score: 0.0000
#     mAP: 0.3553
#   [MGVAE - DecisionTree]
#     AUROC: 0.8534
#     G-mean: 0.8160
#     MCC: 0.6839
#     F1-score: 0.6852
#     mAP: 0.5597
#   [MGVAE - kNN]
#     AUROC: 0.7515
#     G-mean: 0.5369
#     MCC: 0.1946
#     F1-score: 0.2298
#     mAP: 0.2280
#   [MGVAE - MLP]
#     AUROC: 0.7667
#     G-mean: 0.3041
#     MCC: 0.1608
#     F1-score: 0.2015
#     mAP: 0.2981
#   [MGVAE - RandomForest]
#     AUROC: 0.9583
#     G-mean: 0.0000
#     MCC: 0.0000
#     F1-score: 0.0000
#     mAP: 0.7653
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/arrhythmia_results_GAMO_MGVAE_beta_0.0.csv

# %%
data_name = 'cleveland-0_vs_4'

# 실험 파라미터 설정
n_epochs = 1000
hidden_dims = [32, 64, 128, 256]
latent_dim = 512
lr = 0.01
beta = 0.1 

# 데이터 불러오기
cleveland_0_vs_4 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# 실험 실행
final_res = run_exp(
    data=cleveland_0_vs_4, 
    cat_idx=[], 
    methods=methods, 
    kernel_type=kernel_type,
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (173, 13)
# target : Counter({0: 160, 1: 13})
# IR: 12.31
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.9000
#     G-mean: 0.6233
#     MCC: 0.3158
#     F1-score: 0.3278
#     mAP: 0.5833
#   [GAMO - DecisionTree]
#     AUROC: 0.7000
#     G-mean: 0.4620
#     MCC: 0.3703
#     F1-score: 0.4000
#     mAP: 0.4037
#   [GAMO - kNN]
#     AUROC: 0.9578
#     G-mean: 0.9170
#     MCC: 0.5599
#     F1-score: 0.5372
#     mAP: 0.7150
#   [GAMO - MLP]
#     AUROC: 0.8125
#     G-mean: 0.7917
#     MCC: 0.3396
#     F1-score: 0.3090
#     mAP: 0.4435
#   [GAMO - RandomForest]
#     AUROC: 0.9438
#     G-mean: 0.5675
#     MCC: 0.5477
#     F1-score: 0.5467
#     mAP: 0.7700
#   [MGVAE - SVM]
#     AUROC: 0.9875
#     G-mean: 0.1707
#     MCC: 0.1600
#     F1-score: 0.1667
#     mAP: 0.9083
#   [MGVAE - DecisionTree]
#     AUROC: 0.7219
#     G-mean: 0.5230
#     MCC: 0.3756
#     F1-score: 0.3900
#     mAP: 0.3399
#   [MGVAE - kNN]
#     AUROC: 0.9859
#     G-mean: 0.8580
#     MCC: 0.7531
#     F1-score: 0.7467
#     mAP: 0.8583
#   [MGVAE - MLP]
#     AUROC: 0.9656
#     G-mean: 0.8459
#     MCC: 0.4186
#     F1-score: 0.3978
#     mAP: 0.8708
#   [MGVAE - RandomForest]
#     AUROC: 0.9812
#     G-mean: 0.3707
#     MCC: 0.3600
#     F1-score: 0.3667
#     mAP: 0.9000
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.8719
#     G-mean: 0.6541
#     MCC: 0.3300
#     F1-score: 0.3446
#     mAP: 0.5171
#   [GAMO - DecisionTree]
#     AUROC: 0.6656
#     G-mean: 0.4031
#     MCC: 0.2746
#     F1-score: 0.3017
#     mAP: 0.3019
#   [GAMO - kNN]
#     AUROC: 0.9437
#     G-mean: 0.9103
#     MCC: 0.5374
#     F1-score: 0.5118
#     mAP: 0.6117
#   [GAMO - MLP]
#     AUROC: 0.7515
#     G-mean: 0.6524
#     MCC: 0.2334
#     F1-score: 0.2543
#     mAP: 0.3949
#   [GAMO - RandomForest]
#     AUROC: 0.9516
#     G-mean: 0.5837
#     MCC: 0.5707
#     F1-score: 0.5734
#     mAP: 0.7992
#   [MGVAE - SVM]
#     AUROC: 0.9828
#     G-mean: 0.2207
#     MCC: 0.2112
#     F1-score: 0.2167
#     mAP: 0.9083
#   [MGVAE - DecisionTree]
#     AUROC: 0.6719
#     G-mean: 0.4263
#     MCC: 0.2896
#     F1-score: 0.3116
#     mAP: 0.2749
#   [MGVAE - kNN]
#     AUROC: 0.9734
#     G-mean: 0.8612
#     MCC: 0.7815
#     F1-score: 0.7800
#     mAP: 0.8402
#   [MGVAE - MLP]
#     AUROC: 0.9563
#     G-mean: 0.8417
#     MCC: 0.4835
#     F1-score: 0.4697
#     mAP: 0.8708
#   [MGVAE - RandomForest]
#     AUROC: 0.9828
#     G-mean: 0.3707
#     MCC: 0.3643
#     F1-score: 0.3667
#     mAP: 0.9083
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.8844
#     G-mean: 0.6711
#     MCC: 0.3543
#     F1-score: 0.3640
#     mAP: 0.5343
#   [GAMO - DecisionTree]
#     AUROC: 0.6927
#     G-mean: 0.4558
#     MCC: 0.3392
#     F1-score: 0.3678
#     mAP: 0.3627
#   [GAMO - kNN]
#     AUROC: 0.9448
#     G-mean: 0.8790
#     MCC: 0.5268
#     F1-score: 0.5023
#     mAP: 0.6214
#   [GAMO - MLP]
#     AUROC: 0.7750
#     G-mean: 0.6705
#     MCC: 0.2539
#     F1-score: 0.2673
#     mAP: 0.4324
#   [GAMO - RandomForest]
#     AUROC: 0.9573
#     G-mean: 0.6258
#     MCC: 0.6075
#     F1-score: 0.6100
#     mAP: 0.8078
#   [MGVAE - SVM]
#     AUROC: 0.9865
#     G-mean: 0.2374
#     MCC: 0.2274
#     F1-score: 0.2334
#     mAP: 0.9250
#   [MGVAE - DecisionTree]
#     AUROC: 0.6719
#     G-mean: 0.4284
#     MCC: 0.2981
#     F1-score: 0.3244
#     mAP: 0.2902
#   [MGVAE - kNN]
#     AUROC: 0.9791
#     G-mean: 0.8365
#     MCC: 0.7651
#     F1-score: 0.7644
#     mAP: 0.8685
#   [MGVAE - MLP]
#     AUROC: 0.9469
#     G-mean: 0.8195
#     MCC: 0.4665
#     F1-score: 0.4543
#     mAP: 0.8470
#   [MGVAE - RandomForest]
#     AUROC: 0.9781
#     G-mean: 0.4040
#     MCC: 0.3962
#     F1-score: 0.4000
#     mAP: 0.8831
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.8836
#     G-mean: 0.6562
#     MCC: 0.3574
#     F1-score: 0.3730
#     mAP: 0.5483
#   [GAMO - DecisionTree]
#     AUROC: 0.6813
#     G-mean: 0.4404
#     MCC: 0.3131
#     F1-score: 0.3417
#     mAP: 0.3231
#   [GAMO - kNN]
#     AUROC: 0.9391
#     G-mean: 0.8532
#     MCC: 0.5048
#     F1-score: 0.4850
#     mAP: 0.6021
#   [GAMO - MLP]
#     AUROC: 0.7672
#     G-mean: 0.6586
#     MCC: 0.2416
#     F1-score: 0.2587
#     mAP: 0.4344
#   [GAMO - RandomForest]
#     AUROC: 0.9610
#     G-mean: 0.6185
#     MCC: 0.5977
#     F1-score: 0.5992
#     mAP: 0.8204
#   [MGVAE - SVM]
#     AUROC: 0.9851
#     G-mean: 0.2530
#     MCC: 0.2440
#     F1-score: 0.2500
#     mAP: 0.9083
#   [MGVAE - DecisionTree]
#     AUROC: 0.6469
#     G-mean: 0.3798
#     MCC: 0.2572
#     F1-score: 0.2866
#     mAP: 0.2612
#   [MGVAE - kNN]
#     AUROC: 0.9805
#     G-mean: 0.8419
#     MCC: 0.7648
#     F1-score: 0.7633
#     mAP: 0.8514
#   [MGVAE - MLP]
#     AUROC: 0.9383
#     G-mean: 0.8228
#     MCC: 0.4718
#     F1-score: 0.4558
#     mAP: 0.8035
#   [MGVAE - RandomForest]
#     AUROC: 0.9766
#     G-mean: 0.4134
#     MCC: 0.4049
#     F1-score: 0.4083
#     mAP: 0.8644
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.8875
#     G-mean: 0.6634
#     MCC: 0.3624
#     F1-score: 0.3748
#     mAP: 0.5616
#   [GAMO - DecisionTree]
#     AUROC: 0.6925
#     G-mean: 0.4586
#     MCC: 0.3426
#     F1-score: 0.3667
#     mAP: 0.3490
#   [GAMO - kNN]
#     AUROC: 0.9406
#     G-mean: 0.8479
#     MCC: 0.5061
#     F1-score: 0.4890
#     mAP: 0.5984
#   [GAMO - MLP]
#     AUROC: 0.7688
#     G-mean: 0.6544
#     MCC: 0.2341
#     F1-score: 0.2527
#     mAP: 0.4330
#   [GAMO - RandomForest]
#     AUROC: 0.9644
#     G-mean: 0.6283
#     MCC: 0.6077
#     F1-score: 0.6087
#     mAP: 0.8337
#   [MGVAE - SVM]
#     AUROC: 0.9856
#     G-mean: 0.2759
#     MCC: 0.2626
#     F1-score: 0.2667
#     mAP: 0.9100
#   [MGVAE - DecisionTree]
#     AUROC: 0.6675
#     G-mean: 0.4234
#     MCC: 0.2978
#     F1-score: 0.3260
#     mAP: 0.2925
#   [MGVAE - kNN]
#     AUROC: 0.9819
#     G-mean: 0.8309
#     MCC: 0.7524
#     F1-score: 0.7507
#     mAP: 0.8528
#   [MGVAE - MLP]
#     AUROC: 0.9269
#     G-mean: 0.8111
#     MCC: 0.4616
#     F1-score: 0.4556
#     mAP: 0.7856
#   [MGVAE - RandomForest]
#     AUROC: 0.9769
#     G-mean: 0.4248
#     MCC: 0.4176
#     F1-score: 0.4200
#     mAP: 0.8688
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.8927
#     G-mean: 0.6671
#     MCC: 0.3604
#     F1-score: 0.3707
#     mAP: 0.5724
#   [GAMO - DecisionTree]
#     AUROC: 0.6943
#     G-mean: 0.4588
#     MCC: 0.3435
#     F1-score: 0.3678
#     mAP: 0.3512
#   [GAMO - kNN]
#     AUROC: 0.9362
#     G-mean: 0.8363
#     MCC: 0.4879
#     F1-score: 0.4724
#     mAP: 0.5827
#   [GAMO - MLP]
#     AUROC: 0.7708
#     G-mean: 0.6332
#     MCC: 0.2235
#     F1-score: 0.2468
#     mAP: 0.4415
#   [GAMO - RandomForest]
#     AUROC: 0.9656
#     G-mean: 0.6182
#     MCC: 0.5977
#     F1-score: 0.5984
#     mAP: 0.8294
#   [MGVAE - SVM]
#     AUROC: 0.9854
#     G-mean: 0.2698
#     MCC: 0.2543
#     F1-score: 0.2584
#     mAP: 0.9083
#   [MGVAE - DecisionTree]
#     AUROC: 0.6766
#     G-mean: 0.4419
#     MCC: 0.3218
#     F1-score: 0.3533
#     mAP: 0.3240
#   [MGVAE - kNN]
#     AUROC: 0.9836
#     G-mean: 0.8306
#     MCC: 0.7504
#     F1-score: 0.7478
#     mAP: 0.8606
#   [MGVAE - MLP]
#     AUROC: 0.9266
#     G-mean: 0.8106
#     MCC: 0.4627
#     F1-score: 0.4553
#     mAP: 0.7732
#   [MGVAE - RandomForest]
#     AUROC: 0.9781
#     G-mean: 0.4325
#     MCC: 0.4251
#     F1-score: 0.4278
#     mAP: 0.8754
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.8969
#     G-mean: 0.6738
#     MCC: 0.3660
#     F1-score: 0.3764
#     mAP: 0.5792
#   [GAMO - DecisionTree]
#     AUROC: 0.6987
#     G-mean: 0.4633
#     MCC: 0.3478
#     F1-score: 0.3724
#     mAP: 0.3567
#   [GAMO - kNN]
#     AUROC: 0.9351
#     G-mean: 0.8336
#     MCC: 0.4842
#     F1-score: 0.4678
#     mAP: 0.5742
#   [GAMO - MLP]
#     AUROC: 0.7621
#     G-mean: 0.6260
#     MCC: 0.2228
#     F1-score: 0.2483
#     mAP: 0.4264
#   [GAMO - RandomForest]
#     AUROC: 0.9679
#     G-mean: 0.6215
#     MCC: 0.6034
#     F1-score: 0.6033
#     mAP: 0.8395
#   [MGVAE - SVM]
#     AUROC: 0.9839
#     G-mean: 0.2695
#     MCC: 0.2518
#     F1-score: 0.2548
#     mAP: 0.8976
#   [MGVAE - DecisionTree]
#     AUROC: 0.6844
#     G-mean: 0.4543
#     MCC: 0.3352
#     F1-score: 0.3624
#     mAP: 0.3310
#   [MGVAE - kNN]
#     AUROC: 0.9833
#     G-mean: 0.8345
#     MCC: 0.7532
#     F1-score: 0.7500
#     mAP: 0.8520
#   [MGVAE - MLP]
#     AUROC: 0.9290
#     G-mean: 0.8086
#     MCC: 0.4607
#     F1-score: 0.4528
#     mAP: 0.7788
#   [MGVAE - RandomForest]
#     AUROC: 0.9763
#     G-mean: 0.4338
#     MCC: 0.4268
#     F1-score: 0.4286
#     mAP: 0.8706
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.8981
#     G-mean: 0.6840
#     MCC: 0.3671
#     F1-score: 0.3762
#     mAP: 0.5728
#   [GAMO - DecisionTree]
#     AUROC: 0.7117
#     G-mean: 0.4919
#     MCC: 0.3740
#     F1-score: 0.3962
#     mAP: 0.3740
#   [GAMO - kNN]
#     AUROC: 0.9336
#     G-mean: 0.8424
#     MCC: 0.4882
#     F1-score: 0.4703
#     mAP: 0.5707
#   [GAMO - MLP]
#     AUROC: 0.7645
#     G-mean: 0.6241
#     MCC: 0.2235
#     F1-score: 0.2493
#     mAP: 0.4346
#   [GAMO - RandomForest]
#     AUROC: 0.9688
#     G-mean: 0.6313
#     MCC: 0.6154
#     F1-score: 0.6154
#     mAP: 0.8458
#   [MGVAE - SVM]
#     AUROC: 0.9836
#     G-mean: 0.2608
#     MCC: 0.2443
#     F1-score: 0.2479
#     mAP: 0.8927
#   [MGVAE - DecisionTree]
#     AUROC: 0.6848
#     G-mean: 0.4578
#     MCC: 0.3293
#     F1-score: 0.3558
#     mAP: 0.3207
#   [MGVAE - kNN]
#     AUROC: 0.9836
#     G-mean: 0.8378
#     MCC: 0.7571
#     F1-score: 0.7537
#     mAP: 0.8569
#   [MGVAE - MLP]
#     AUROC: 0.9332
#     G-mean: 0.8089
#     MCC: 0.4647
#     F1-score: 0.4571
#     mAP: 0.7861
#   [MGVAE - RandomForest]
#     AUROC: 0.9770
#     G-mean: 0.4381
#     MCC: 0.4282
#     F1-score: 0.4313
#     mAP: 0.8743
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.8979
#     G-mean: 0.6946
#     MCC: 0.3754
#     F1-score: 0.3848
#     mAP: 0.5804
#   [GAMO - DecisionTree]
#     AUROC: 0.7219
#     G-mean: 0.5104
#     MCC: 0.3941
#     F1-score: 0.4148
#     mAP: 0.3912
#   [GAMO - kNN]
#     AUROC: 0.9349
#     G-mean: 0.8499
#     MCC: 0.4945
#     F1-score: 0.4757
#     mAP: 0.5728
#   [GAMO - MLP]
#     AUROC: 0.7684
#     G-mean: 0.6334
#     MCC: 0.2301
#     F1-score: 0.2532
#     mAP: 0.4386
#   [GAMO - RandomForest]
#     AUROC: 0.9695
#     G-mean: 0.6324
#     MCC: 0.6179
#     F1-score: 0.6174
#     mAP: 0.8481
#   [MGVAE - SVM]
#     AUROC: 0.9844
#     G-mean: 0.2651
#     MCC: 0.2498
#     F1-score: 0.2537
#     mAP: 0.8972
#   [MGVAE - DecisionTree]
#     AUROC: 0.6889
#     G-mean: 0.4649
#     MCC: 0.3360
#     F1-score: 0.3596
#     mAP: 0.3238
#   [MGVAE - kNN]
#     AUROC: 0.9845
#     G-mean: 0.8433
#     MCC: 0.7602
#     F1-score: 0.7567
#     mAP: 0.8599
#   [MGVAE - MLP]
#     AUROC: 0.9354
#     G-mean: 0.8189
#     MCC: 0.4747
#     F1-score: 0.4655
#     mAP: 0.7869
#   [MGVAE - RandomForest]
#     AUROC: 0.9781
#     G-mean: 0.4496
#     MCC: 0.4403
#     F1-score: 0.4426
#     mAP: 0.8771
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.8972
#     G-mean: 0.6847
#     MCC: 0.3674
#     F1-score: 0.3773
#     mAP: 0.5806
#   [GAMO - DecisionTree]
#     AUROC: 0.7319
#     G-mean: 0.5309
#     MCC: 0.4084
#     F1-score: 0.4266
#     mAP: 0.3972
#   [GAMO - kNN]
#     AUROC: 0.9359
#     G-mean: 0.8467
#     MCC: 0.4916
#     F1-score: 0.4728
#     mAP: 0.5692
#   [GAMO - MLP]
#     AUROC: 0.7725
#     G-mean: 0.6350
#     MCC: 0.2315
#     F1-score: 0.2524
#     mAP: 0.4334
#   [GAMO - RandomForest]
#     AUROC: 0.9697
#     G-mean: 0.6333
#     MCC: 0.6198
#     F1-score: 0.6190
#     mAP: 0.8498
#   [MGVAE - SVM]
#     AUROC: 0.9841
#     G-mean: 0.2596
#     MCC: 0.2429
#     F1-score: 0.2467
#     mAP: 0.8933
#   [MGVAE - DecisionTree]
#     AUROC: 0.7122
#     G-mean: 0.5098
#     MCC: 0.3701
#     F1-score: 0.3903
#     mAP: 0.3433
#   [MGVAE - kNN]
#     AUROC: 0.9841
#     G-mean: 0.8448
#     MCC: 0.7595
#     F1-score: 0.7557
#     mAP: 0.8509
#   [MGVAE - MLP]
#     AUROC: 0.9372
#     G-mean: 0.8187
#     MCC: 0.4746
#     F1-score: 0.4647
#     mAP: 0.7929
#   [MGVAE - RandomForest]
#     AUROC: 0.9791
#     G-mean: 0.4488
#     MCC: 0.4400
#     F1-score: 0.4417
#     mAP: 0.8811
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/cleveland-0_vs_4_results_GAMO_MGVAE_beta_0.1.csv
