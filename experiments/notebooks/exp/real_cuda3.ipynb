# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

import os
import warnings
import pandas as pd
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from experiment import run_exp

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# Save path 
save_path = "/data4/oldrain123/oldrain123/results/real_results"
data_path = "/data4/oldrain123/oldrain123/dataset"

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "6"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# methods = ["AdaBoost", "SMOTEBoost", "RUSBoost", "OUBoost", "Original", "SMOTE", "ADASYN", "bSMOTE", "ROS", "MWMOTE", "CTGAN", "Ours"]
methods = ['GAMO','MGVAE']
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}# base_model = RandomForestClassifier(n_estimators=500, random_state=1203)
kernel_type = 'GAMO_MGVAE'

# %%
data_name = 'winequality-red-3_vs_5'

# 실험 파라미터 설정
n_epochs = 1000
hidden_dims = [16, 32, 64, 128]
latent_dim = 256
lr = 0.01
beta = 0.01

# 데이터 불러오기
winequality_red_3_vs_5 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# 실험 실행
final_res = run_exp(
    data=winequality_red_3_vs_5, 
    cat_idx=[], 
    methods=methods, 
    kernel_type=kernel_type,
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (691, 11)
# target : Counter({0: 681, 1: 10})
# IR: 68.1
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.7610
#     G-mean: 0.3796
#     MCC: 0.1219
#     F1-score: 0.0940
#     mAP: 0.1929
#   [GAMO - DecisionTree]
#     AUROC: 0.8001
#     G-mean: 0.5523
#     MCC: 0.1543
#     F1-score: 0.1042
#     mAP: 0.1220
#   [GAMO - kNN]
#     AUROC: 0.7406
#     G-mean: 0.1955
#     MCC: 0.0926
#     F1-score: 0.0952
#     mAP: 0.1210
#   [GAMO - MLP]
#     AUROC: 0.7401
#     G-mean: 0.4428
#     MCC: 0.0925
#     F1-score: 0.0641
#     mAP: 0.1728
#   [GAMO - RandomForest]
#     AUROC: 0.8185
#     G-mean: 0.1970
#     MCC: 0.0936
#     F1-score: 0.1067
#     mAP: 0.1567
#   [MGVAE - SVM]
#     AUROC: 0.6705
#     G-mean: 0.0000
#     MCC: -0.0036
#     F1-score: 0.0000
#     mAP: 0.1792
#   [MGVAE - DecisionTree]
#     AUROC: 0.5397
#     G-mean: 0.1000
#     MCC: 0.0873
# ...

# %%
data_name = 'winequality-red-4'

# 실험 파라미터 설정
n_epochs = 1000
hidden_dims = [16, 32, 64, 128]
latent_dim = 256
lr = 0.01
beta = 0.01

# 데이터 불러오기
winequality_red_4 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# 실험 실행
final_res = run_exp(
    data=winequality_red_4, 
    cat_idx=[], 
    methods=methods, 
    kernel_type=kernel_type,
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (1599, 11)
# target : Counter({0: 1546, 1: 53})
# IR: 29.17
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.6780
#     G-mean: 0.1730
#     MCC: 0.0109
#     F1-score: 0.0514
#     mAP: 0.0822
#   [GAMO - DecisionTree]
#     AUROC: 0.5779
#     G-mean: 0.3506
#     MCC: 0.0379
#     F1-score: 0.0792
#     mAP: 0.0783
#   [GAMO - kNN]
#     AUROC: 0.6345
#     G-mean: 0.0877
#     MCC: 0.0049
#     F1-score: 0.0336
#     mAP: 0.0685
#   [GAMO - MLP]
#     AUROC: 0.6343
#     G-mean: 0.2033
#     MCC: 0.0203
#     F1-score: 0.0643
#     mAP: 0.1336
#   [GAMO - RandomForest]
#     AUROC: 0.7574
#     G-mean: 0.2873
#     MCC: 0.0741
#     F1-score: 0.1090
#     mAP: 0.1326
#   [MGVAE - SVM]
#     AUROC: 0.5999
#     G-mean: 0.0000
#     MCC: -0.0095
#     F1-score: 0.0000
#     mAP: 0.0963
#   [MGVAE - DecisionTree]
#     AUROC: 0.5801
#     G-mean: 0.0887
#     MCC: 0.0272
# ...

# %%
data_name = 'winequality-white-3_vs_7'

# 실험 파라미터 설정
n_epochs = 1000
hidden_dims = [16, 32, 64, 128]
latent_dim = 256
lr = 0.01
beta = 0.01

# 데이터 불러오기
winequality_white_3_vs_7 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# 실험 실행
final_res = run_exp(
    data=winequality_white_3_vs_7, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (900, 11)
# target : Counter({0: 880, 1: 20})
# IR: 44.0
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.9119
#     G-mean: 0.7886
#     MCC: 0.3067
#     F1-score: 0.2403
#     mAP: 0.6002
#   [GAMO - DecisionTree]
#     AUROC: 0.5849
#     G-mean: 0.5294
#     MCC: 0.0736
#     F1-score: 0.0733
#     mAP: 0.0985
#   [GAMO - kNN]
#     AUROC: 0.7702
#     G-mean: 0.4356
#     MCC: 0.1465
#     F1-score: 0.1447
#     mAP: 0.1396
#   [GAMO - MLP]
#     AUROC: 0.8091
#     G-mean: 0.5949
#     MCC: 0.1472
#     F1-score: 0.1219
#     mAP: 0.4437
#   [GAMO - RandomForest]
#     AUROC: 0.9057
#     G-mean: 0.6563
#     MCC: 0.2068
#     F1-score: 0.1786
#     mAP: 0.2423
#   [MGVAE - SVM]
#     AUROC: 0.8307
#     G-mean: 0.0707
#     MCC: 0.0659
#     F1-score: 0.0667
#     mAP: 0.2344
#   [MGVAE - DecisionTree]
#     AUROC: 0.7006
#     G-mean: 0.4942
#     MCC: 0.4461
# ...

# %%
data_name = 'winequality-white-3-9_vs_5'

# 실험 파라미터 설정
n_epochs = 1000
hidden_dims = [16, 32, 64, 128]
latent_dim = 256
lr = 0.01
beta = 0.01

# 데이터 불러오기
winequality_white_3_9_vs_5 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# 실험 실행
final_res = run_exp(
    data=winequality_white_3_9_vs_5, 
    cat_idx=[], 
    methods=methods, 
    kernel_type=kernel_type,
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (1482, 11)
# target : Counter({0: 1457, 1: 25})
# IR: 58.28
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.7644
#     G-mean: 0.3428
#     MCC: 0.0828
#     F1-score: 0.0815
#     mAP: 0.2080
#   [GAMO - DecisionTree]
#     AUROC: 0.6009
#     G-mean: 0.4476
#     MCC: 0.0850
#     F1-score: 0.0856
#     mAP: 0.1200
#   [GAMO - kNN]
#     AUROC: 0.6871
#     G-mean: 0.1960
#     MCC: 0.0628
#     F1-score: 0.0783
#     mAP: 0.1284
#   [GAMO - MLP]
#     AUROC: 0.6228
#     G-mean: 0.4132
#     MCC: 0.1220
#     F1-score: 0.1191
#     mAP: 0.2164
#   [GAMO - RandomForest]
#     AUROC: 0.8186
#     G-mean: 0.3929
#     MCC: 0.0981
#     F1-score: 0.0984
#     mAP: 0.1356
#   [MGVAE - SVM]
#     AUROC: 0.7786
#     G-mean: 0.0000
#     MCC: -0.0024
#     F1-score: 0.0000
#     mAP: 0.1316
#   [MGVAE - DecisionTree]
#     AUROC: 0.5792
#     G-mean: 0.3266
#     MCC: 0.2808
# ...

# %%
data_name = 'yeast-0-5-6-7-9_vs_4'

# 실험 파라미터 설정
n_epochs = 1000
hidden_dims = [8, 16, 32, 64, 128, 256, 512]
latent_dim = 1024
lr = 0.005
beta = 0.1

# 데이터 불러오기
yeast_0_5_6_7_9_vs_4 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# 실험 실행
final_res = run_exp(
    data=yeast_0_5_6_7_9_vs_4, 
    cat_idx=[], 
    kernel_type=kernel_type,
    methods=methods, 
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (528, 8)
# target : Counter({0: 477, 1: 51})
# IR: 9.35
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.8119
#     G-mean: 0.7254
#     MCC: 0.3856
#     F1-score: 0.4419
#     mAP: 0.4726
#   [GAMO - DecisionTree]
#     AUROC: 0.8280
#     G-mean: 0.4973
#     MCC: 0.3650
#     F1-score: 0.3881
#     mAP: 0.4049
#   [GAMO - kNN]
#     AUROC: 0.7597
#     G-mean: 0.6835
#     MCC: 0.3693
#     F1-score: 0.4350
#     mAP: 0.3396
#   [GAMO - MLP]
#     AUROC: 0.7638
#     G-mean: 0.6878
#     MCC: 0.2550
#     F1-score: 0.3152
#     mAP: 0.5054
#   [GAMO - RandomForest]
#     AUROC: 0.9182
#     G-mean: 0.5461
#     MCC: 0.4628
#     F1-score: 0.4524
#     mAP: 0.6295
#   [MGVAE - SVM]
#     AUROC: 0.8952
#     G-mean: 0.5537
#     MCC: 0.4224
#     F1-score: 0.4413
#     mAP: 0.6233
#   [MGVAE - DecisionTree]
#     AUROC: 0.7186
#     G-mean: 0.4821
#     MCC: 0.3202
#     F1-score: 0.3617
# ...

# %%
data_name = 'yeast-1-2-8-9_vs_7'

# 실험 파라미터 설정
n_epochs = 1000
hidden_dims = [8, 16, 32, 64]
latent_dim = 128
lr = 0.005
beta = 0.001 

# 데이터 불러오기
yeast_1_2_8_9_vs_7 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# 실험 실행
final_res = run_exp(
    data=yeast_1_2_8_9_vs_7, 
    cat_idx=[], 
    methods=methods, 
    kernel_type=kernel_type,
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (947, 8)
# target : Counter({0: 917, 1: 30})
# IR: 30.57
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.6464
#     G-mean: 0.4947
#     MCC: 0.1142
#     F1-score: 0.1338
#     mAP: 0.2046
#   [GAMO - DecisionTree]
#     AUROC: 0.6874
#     G-mean: 0.3348
#     MCC: 0.2565
#     F1-score: 0.2600
#     mAP: 0.2473
#   [GAMO - kNN]
#     AUROC: 0.6133
#     G-mean: 0.2917
#     MCC: 0.0885
#     F1-score: 0.1235
#     mAP: 0.1705
#   [GAMO - MLP]
#     AUROC: 0.5436
#     G-mean: 0.1620
#     MCC: 0.1048
#     F1-score: 0.1300
#     mAP: 0.1441
#   [GAMO - RandomForest]
#     AUROC: 0.7581
#     G-mean: 0.1729
#     MCC: 0.1535
#     F1-score: 0.1400
#     mAP: 0.3088
#   [MGVAE - SVM]
#     AUROC: 0.5942
#     G-mean: 0.1139
#     MCC: 0.0384
#     F1-score: 0.0619
#     mAP: 0.1150
#   [MGVAE - DecisionTree]
#     AUROC: 0.5965
#     G-mean: 0.2537
#     MCC: 0.1976
# ...

# %%
data_name = 'yeast-1-4-5-8_vs_7'

# 실험 파라미터 설정
n_epochs = 1000
hidden_dims = [16, 32, 64, 128]
latent_dim = 256
lr = 0.002
beta = 0.01

# 데이터 불러오기
yeast_1_4_5_8_vs_7 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# 실험 실행
final_res = run_exp(
    data=yeast_1_4_5_8_vs_7, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    kernel_type=kernel_type,
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (693, 8)
# target : Counter({0: 663, 1: 30})
# IR: 22.1
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.5383
#     G-mean: 0.1054
#     MCC: -0.0420
#     F1-score: 0.0278
#     mAP: 0.0936
#   [GAMO - DecisionTree]
#     AUROC: 0.6232
#     G-mean: 0.1723
#     MCC: 0.1172
#     F1-score: 0.1300
#     mAP: 0.1659
#   [GAMO - kNN]
#     AUROC: 0.5661
#     G-mean: 0.1296
#     MCC: -0.0086
#     F1-score: 0.0440
#     mAP: 0.0729
#   [GAMO - MLP]
#     AUROC: 0.5304
#     G-mean: 0.3824
#     MCC: 0.0194
#     F1-score: 0.0769
#     mAP: 0.1077
#   [GAMO - RandomForest]
#     AUROC: 0.6966
#     G-mean: 0.0000
#     MCC: -0.0026
#     F1-score: 0.0000
#     mAP: 0.1618
#   [MGVAE - SVM]
#     AUROC: 0.6046
#     G-mean: 0.1142
#     MCC: 0.0430
#     F1-score: 0.0733
#     mAP: 0.1446
#   [MGVAE - DecisionTree]
#     AUROC: 0.5924
#     G-mean: 0.0573
#     MCC: 0.0167
# ...

# %%
data_name = 'yeast4'

# 실험 파라미터 설정
n_epochs = 1000
hidden_dims = [16, 32, 64, 128]
latent_dim = 256
lr = 0.002
beta = 0.01

# 데이터 불러오기
yeast4 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# 실험 실행
final_res = run_exp(
    data=yeast4, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    kernel_type=kernel_type,
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (1484, 8)
# target : Counter({0: 1433, 1: 51})
# IR: 28.1
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.7362
#     G-mean: 0.4646
#     MCC: 0.1575
#     F1-score: 0.1822
#     mAP: 0.2087
#   [GAMO - DecisionTree]
#     AUROC: 0.8428
#     G-mean: 0.3920
#     MCC: 0.2738
#     F1-score: 0.2730
#     mAP: 0.3513
#   [GAMO - kNN]
#     AUROC: 0.6610
#     G-mean: 0.4380
#     MCC: 0.1430
#     F1-score: 0.1718
#     mAP: 0.1226
#   [GAMO - MLP]
#     AUROC: 0.7594
#     G-mean: 0.2997
#     MCC: 0.1844
#     F1-score: 0.1966
#     mAP: 0.2529
#   [GAMO - RandomForest]
#     AUROC: 0.9024
#     G-mean: 0.2788
#     MCC: 0.2484
#     F1-score: 0.2262
#     mAP: 0.4135
#   [MGVAE - SVM]
#     AUROC: 0.8533
#     G-mean: 0.5066
#     MCC: 0.3837
#     F1-score: 0.3661
#     mAP: 0.4445
#   [MGVAE - DecisionTree]
#     AUROC: 0.7822
#     G-mean: 0.5016
#     MCC: 0.3687
# ...

# %%
data_name = 'yeast6'

# 실험 파라미터 설정
n_epochs = 1000
hidden_dims = [16, 32, 64, 128]
latent_dim = 256
lr = 0.01
beta = 0.01

# 데이터 불러오기
yeast6 = pd.read_csv(f"{data_path}/{data_name}.dat", header=None)

# 실험 실행
final_res = run_exp(
    data=yeast6, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    device=device,
    n_epochs=n_epochs, 
    kernel_type=kernel_type,
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded from DataFrame
# X shape : (1484, 8)
# target : Counter({0: 1449, 1: 35})
# IR: 41.4
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.7608
#     G-mean: 0.6209
#     MCC: 0.1853
#     F1-score: 0.1627
#     mAP: 0.2275
#   [GAMO - DecisionTree]
#     AUROC: 0.7834
#     G-mean: 0.6837
#     MCC: 0.5874
#     F1-score: 0.5710
#     mAP: 0.4858
#   [GAMO - kNN]
#     AUROC: 0.7997
#     G-mean: 0.7141
#     MCC: 0.2805
#     F1-score: 0.2606
#     mAP: 0.2481
#   [GAMO - MLP]
#     AUROC: 0.8055
#     G-mean: 0.2556
#     MCC: 0.1286
#     F1-score: 0.1444
#     mAP: 0.2102
#   [GAMO - RandomForest]
#     AUROC: 0.9064
#     G-mean: 0.5031
#     MCC: 0.4562
#     F1-score: 0.4443
#     mAP: 0.5778
#   [MGVAE - SVM]
#     AUROC: 0.9249
#     G-mean: 0.6991
#     MCC: 0.5851
#     F1-score: 0.5819
#     mAP: 0.6907
#   [MGVAE - DecisionTree]
#     AUROC: 0.7534
#     G-mean: 0.6223
#     MCC: 0.4219
# ...
