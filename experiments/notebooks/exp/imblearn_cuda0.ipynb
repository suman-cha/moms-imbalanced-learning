# %%
import sys
sys.path.append("/home/oldrain123/IMBALANCED_CLASSIFICATION/MOMs")

import os
import warnings
from imblearn.datasets import fetch_datasets
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.exceptions import ConvergenceWarning
from experiment import run_exp

warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
# Save path 
save_path = "/data4/oldrain123/oldrain123/results/real_results"

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = "cuda"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
data = fetch_datasets()
methods = ["GAMO", "MGVAE"]
base_models = {
    "SVM": SVC(kernel='rbf', probability=True, random_state=1203),
    "DecisionTree": DecisionTreeClassifier(max_depth=6, random_state=1203),
    "kNN": KNeighborsClassifier(n_neighbors=5),
    "MLP": MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, early_stopping=True, random_state=1203),
    "RandomForest": RandomForestClassifier(n_estimators=500, random_state=1203)
}

# %%
# us_crime
data_name = 'us_crime'
maj_target_name = -1

n_epochs = 1000
hidden_dims = [100, 64, 32]
latent_dim = 16
lr = 0.01
beta = 0.001
kernel_type = 'GAMO_MGVAE'

final_res = run_exp(
    data=data, 
    cat_idx=[], 
    methods=methods, 
    base_model=base_models, 
    kernel_type=kernel_type,
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    maj_target_name=maj_target_name,
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded: us_crime
# X shape : (1994, 100)
# target : Counter({0: 1844, 1: 150})
# IR: 12.29
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.8584
#     G-mean: 0.5575
#     MCC: 0.4300
#     F1-score: 0.4254
#     mAP: 0.5109
#   [GAMO - DecisionTree]
#     AUROC: 0.8248
#     G-mean: 0.5647
#     MCC: 0.3638
#     F1-score: 0.3879
#     mAP: 0.3676
#   [GAMO - kNN]
#     AUROC: 0.8214
#     G-mean: 0.5112
#     MCC: 0.3787
#     F1-score: 0.3723
#     mAP: 0.4019
#   [GAMO - MLP]
#     AUROC: 0.8823
#     G-mean: 0.5718
#     MCC: 0.3778
#     F1-score: 0.4057
#     mAP: 0.4378
#   [GAMO - RandomForest]
#     AUROC: 0.9184
#     G-mean: 0.6021
#     MCC: 0.4921
#     F1-score: 0.4869
#     mAP: 0.5888
#   [MGVAE - SVM]
#     AUROC: 0.8618
#     G-mean: 0.5314
#     MCC: 0.4483
#     F1-score: 0.4166
#     mAP: 0.5543
#   [MGVAE - DecisionTree]
#     AUROC: 0.7448
#     G-mean: 0.6107
#     MCC: 0.4219
#     F1-score: 0.4512
#     mAP: 0.3874
#   [MGVAE - kNN]
#     AUROC: 0.8290
#     G-mean: 0.5477
#     MCC: 0.4059
#     F1-score: 0.4084
#     mAP: 0.4206
#   [MGVAE - MLP]
#     AUROC: 0.8923
#     G-mean: 0.6041
#     MCC: 0.3972
#     F1-score: 0.4292
#     mAP: 0.5113
#   [MGVAE - RandomForest]
#     AUROC: 0.9182
#     G-mean: 0.5989
#     MCC: 0.4990
#     F1-score: 0.4877
#     mAP: 0.5844
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.8637
#     G-mean: 0.5606
#     MCC: 0.4331
#     F1-score: 0.4289
#     mAP: 0.5158
#   [GAMO - DecisionTree]
#     AUROC: 0.8306
#     G-mean: 0.5306
#     MCC: 0.3234
#     F1-score: 0.3548
#     mAP: 0.3532
#   [GAMO - kNN]
#     AUROC: 0.8252
#     G-mean: 0.5140
#     MCC: 0.3843
#     F1-score: 0.3770
#     mAP: 0.4084
#   [GAMO - MLP]
#     AUROC: 0.8869
#     G-mean: 0.5950
#     MCC: 0.3977
#     F1-score: 0.4276
#     mAP: 0.4587
#   [GAMO - RandomForest]
#     AUROC: 0.9185
#     G-mean: 0.5974
#     MCC: 0.4827
#     F1-score: 0.4791
#     mAP: 0.5871
#   [MGVAE - SVM]
#     AUROC: 0.8687
#     G-mean: 0.5234
#     MCC: 0.4430
#     F1-score: 0.4079
#     mAP: 0.5655
#   [MGVAE - DecisionTree]
#     AUROC: 0.7309
#     G-mean: 0.6109
#     MCC: 0.4182
#     F1-score: 0.4463
#     mAP: 0.3709
#   [MGVAE - kNN]
#     AUROC: 0.8294
#     G-mean: 0.5552
#     MCC: 0.4133
#     F1-score: 0.4167
#     mAP: 0.4207
#   [MGVAE - MLP]
#     AUROC: 0.8992
#     G-mean: 0.6056
#     MCC: 0.4123
#     F1-score: 0.4400
#     mAP: 0.5292
#   [MGVAE - RandomForest]
#     AUROC: 0.9204
#     G-mean: 0.5887
#     MCC: 0.4847
#     F1-score: 0.4734
#     mAP: 0.5986
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.8606
#     G-mean: 0.5608
#     MCC: 0.4269
#     F1-score: 0.4263
#     mAP: 0.5078
#   [GAMO - DecisionTree]
#     AUROC: 0.8371
#     G-mean: 0.5332
#     MCC: 0.3319
#     F1-score: 0.3604
#     mAP: 0.3603
#   [GAMO - kNN]
#     AUROC: 0.8210
#     G-mean: 0.5071
#     MCC: 0.3744
#     F1-score: 0.3679
#     mAP: 0.3967
#   [GAMO - MLP]
#     AUROC: 0.8823
#     G-mean: 0.5961
#     MCC: 0.3981
#     F1-score: 0.4288
#     mAP: 0.4584
#   [GAMO - RandomForest]
#     AUROC: 0.9151
#     G-mean: 0.5906
#     MCC: 0.4761
#     F1-score: 0.4716
#     mAP: 0.5799
#   [MGVAE - SVM]
#     AUROC: 0.8663
#     G-mean: 0.5200
#     MCC: 0.4332
#     F1-score: 0.4027
#     mAP: 0.5617
#   [MGVAE - DecisionTree]
#     AUROC: 0.7262
#     G-mean: 0.6028
#     MCC: 0.4004
#     F1-score: 0.4312
#     mAP: 0.3527
#   [MGVAE - kNN]
#     AUROC: 0.8264
#     G-mean: 0.5498
#     MCC: 0.4066
#     F1-score: 0.4101
#     mAP: 0.4128
#   [MGVAE - MLP]
#     AUROC: 0.9005
#     G-mean: 0.6091
#     MCC: 0.4170
#     F1-score: 0.4419
#     mAP: 0.5315
#   [MGVAE - RandomForest]
#     AUROC: 0.9207
#     G-mean: 0.5881
#     MCC: 0.4823
#     F1-score: 0.4719
#     mAP: 0.6006
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.8613
#     G-mean: 0.5629
#     MCC: 0.4273
#     F1-score: 0.4277
#     mAP: 0.5095
#   [GAMO - DecisionTree]
#     AUROC: 0.8328
#     G-mean: 0.5465
#     MCC: 0.3377
#     F1-score: 0.3681
#     mAP: 0.3546
#   [GAMO - kNN]
#     AUROC: 0.8204
#     G-mean: 0.5166
#     MCC: 0.3872
#     F1-score: 0.3801
#     mAP: 0.3993
#   [GAMO - MLP]
#     AUROC: 0.8829
#     G-mean: 0.5995
#     MCC: 0.3999
#     F1-score: 0.4304
#     mAP: 0.4645
#   [GAMO - RandomForest]
#     AUROC: 0.9152
#     G-mean: 0.5882
#     MCC: 0.4743
#     F1-score: 0.4687
#     mAP: 0.5824
#   [MGVAE - SVM]
#     AUROC: 0.8673
#     G-mean: 0.5196
#     MCC: 0.4302
#     F1-score: 0.4008
#     mAP: 0.5611
#   [MGVAE - DecisionTree]
#     AUROC: 0.7447
#     G-mean: 0.6148
#     MCC: 0.4141
#     F1-score: 0.4445
#     mAP: 0.3607
#   [MGVAE - kNN]
#     AUROC: 0.8266
#     G-mean: 0.5573
#     MCC: 0.4166
#     F1-score: 0.4199
#     mAP: 0.4150
#   [MGVAE - MLP]
#     AUROC: 0.9015
#     G-mean: 0.6052
#     MCC: 0.4161
#     F1-score: 0.4410
#     mAP: 0.5375
#   [MGVAE - RandomForest]
#     AUROC: 0.9203
#     G-mean: 0.5905
#     MCC: 0.4866
#     F1-score: 0.4757
#     mAP: 0.6029
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.8617
#     G-mean: 0.5633
#     MCC: 0.4257
#     F1-score: 0.4270
#     mAP: 0.5112
#   [GAMO - DecisionTree]
#     AUROC: 0.8326
#     G-mean: 0.5443
#     MCC: 0.3396
#     F1-score: 0.3697
#     mAP: 0.3530
#   [GAMO - kNN]
#     AUROC: 0.8194
#     G-mean: 0.5154
#     MCC: 0.3868
#     F1-score: 0.3785
#     mAP: 0.3993
#   [GAMO - MLP]
#     AUROC: 0.8824
#     G-mean: 0.5966
#     MCC: 0.3942
#     F1-score: 0.4252
#     mAP: 0.4621
#   [GAMO - RandomForest]
#     AUROC: 0.9158
#     G-mean: 0.5902
#     MCC: 0.4767
#     F1-score: 0.4709
#     mAP: 0.5879
#   [MGVAE - SVM]
#     AUROC: 0.8680
#     G-mean: 0.5208
#     MCC: 0.4292
#     F1-score: 0.4016
#     mAP: 0.5596
#   [MGVAE - DecisionTree]
#     AUROC: 0.7397
#     G-mean: 0.6064
#     MCC: 0.4043
#     F1-score: 0.4354
#     mAP: 0.3555
#   [MGVAE - kNN]
#     AUROC: 0.8258
#     G-mean: 0.5548
#     MCC: 0.4143
#     F1-score: 0.4168
#     mAP: 0.4131
#   [MGVAE - MLP]
#     AUROC: 0.9020
#     G-mean: 0.6123
#     MCC: 0.4261
#     F1-score: 0.4499
#     mAP: 0.5411
#   [MGVAE - RandomForest]
#     AUROC: 0.9204
#     G-mean: 0.5915
#     MCC: 0.4880
#     F1-score: 0.4770
#     mAP: 0.6043
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.8613
#     G-mean: 0.5640
#     MCC: 0.4285
#     F1-score: 0.4293
#     mAP: 0.5118
#   [GAMO - DecisionTree]
#     AUROC: 0.8303
#     G-mean: 0.5409
#     MCC: 0.3367
#     F1-score: 0.3670
#     mAP: 0.3526
#   [GAMO - kNN]
#     AUROC: 0.8180
#     G-mean: 0.5091
#     MCC: 0.3844
#     F1-score: 0.3756
#     mAP: 0.3991
#   [GAMO - MLP]
#     AUROC: 0.8824
#     G-mean: 0.5892
#     MCC: 0.3858
#     F1-score: 0.4163
#     mAP: 0.4631
#   [GAMO - RandomForest]
#     AUROC: 0.9164
#     G-mean: 0.5832
#     MCC: 0.4721
#     F1-score: 0.4640
#     mAP: 0.5871
#   [MGVAE - SVM]
#     AUROC: 0.8664
#     G-mean: 0.5176
#     MCC: 0.4280
#     F1-score: 0.3978
#     mAP: 0.5591
#   [MGVAE - DecisionTree]
#     AUROC: 0.7274
#     G-mean: 0.6021
#     MCC: 0.3967
#     F1-score: 0.4287
#     mAP: 0.3473
#   [MGVAE - kNN]
#     AUROC: 0.8242
#     G-mean: 0.5536
#     MCC: 0.4142
#     F1-score: 0.4159
#     mAP: 0.4138
#   [MGVAE - MLP]
#     AUROC: 0.9028
#     G-mean: 0.6154
#     MCC: 0.4293
#     F1-score: 0.4529
#     mAP: 0.5457
#   [MGVAE - RandomForest]
#     AUROC: 0.9201
#     G-mean: 0.5889
#     MCC: 0.4875
#     F1-score: 0.4750
#     mAP: 0.6028
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.8612
#     G-mean: 0.5651
#     MCC: 0.4298
#     F1-score: 0.4309
#     mAP: 0.5113
#   [GAMO - DecisionTree]
#     AUROC: 0.8313
#     G-mean: 0.5430
#     MCC: 0.3386
#     F1-score: 0.3680
#     mAP: 0.3546
#   [GAMO - kNN]
#     AUROC: 0.8185
#     G-mean: 0.5076
#     MCC: 0.3857
#     F1-score: 0.3749
#     mAP: 0.4010
#   [GAMO - MLP]
#     AUROC: 0.8821
#     G-mean: 0.5873
#     MCC: 0.3827
#     F1-score: 0.4137
#     mAP: 0.4605
#   [GAMO - RandomForest]
#     AUROC: 0.9169
#     G-mean: 0.5805
#     MCC: 0.4682
#     F1-score: 0.4605
#     mAP: 0.5864
#   [MGVAE - SVM]
#     AUROC: 0.8667
#     G-mean: 0.5189
#     MCC: 0.4297
#     F1-score: 0.3995
#     mAP: 0.5580
#   [MGVAE - DecisionTree]
#     AUROC: 0.7286
#     G-mean: 0.5960
#     MCC: 0.3867
#     F1-score: 0.4192
#     mAP: 0.3421
#   [MGVAE - kNN]
#     AUROC: 0.8253
#     G-mean: 0.5537
#     MCC: 0.4173
#     F1-score: 0.4174
#     mAP: 0.4154
#   [MGVAE - MLP]
#     AUROC: 0.9020
#     G-mean: 0.6174
#     MCC: 0.4285
#     F1-score: 0.4534
#     mAP: 0.5454
#   [MGVAE - RandomForest]
#     AUROC: 0.9205
#     G-mean: 0.5875
#     MCC: 0.4846
#     F1-score: 0.4726
#     mAP: 0.6016
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.8616
#     G-mean: 0.5676
#     MCC: 0.4335
#     F1-score: 0.4341
#     mAP: 0.5117
#   [GAMO - DecisionTree]
#     AUROC: 0.8340
#     G-mean: 0.5528
#     MCC: 0.3441
#     F1-score: 0.3749
#     mAP: 0.3551
#   [GAMO - kNN]
#     AUROC: 0.8169
#     G-mean: 0.5110
#     MCC: 0.3888
#     F1-score: 0.3782
#     mAP: 0.4023
#   [GAMO - MLP]
#     AUROC: 0.8823
#     G-mean: 0.5879
#     MCC: 0.3847
#     F1-score: 0.4151
#     mAP: 0.4618
#   [GAMO - RandomForest]
#     AUROC: 0.9172
#     G-mean: 0.5804
#     MCC: 0.4673
#     F1-score: 0.4600
#     mAP: 0.5855
#   [MGVAE - SVM]
#     AUROC: 0.8670
#     G-mean: 0.5168
#     MCC: 0.4301
#     F1-score: 0.3997
#     mAP: 0.5583
#   [MGVAE - DecisionTree]
#     AUROC: 0.7315
#     G-mean: 0.5952
#     MCC: 0.3852
#     F1-score: 0.4178
#     mAP: 0.3419
#   [MGVAE - kNN]
#     AUROC: 0.8239
#     G-mean: 0.5564
#     MCC: 0.4194
#     F1-score: 0.4201
#     mAP: 0.4173
#   [MGVAE - MLP]
#     AUROC: 0.9023
#     G-mean: 0.6191
#     MCC: 0.4327
#     F1-score: 0.4562
#     mAP: 0.5453
#   [MGVAE - RandomForest]
#     AUROC: 0.9208
#     G-mean: 0.5873
#     MCC: 0.4863
#     F1-score: 0.4735
#     mAP: 0.6024
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.8624
#     G-mean: 0.5691
#     MCC: 0.4340
#     F1-score: 0.4352
#     mAP: 0.5117
#   [GAMO - DecisionTree]
#     AUROC: 0.8304
#     G-mean: 0.5564
#     MCC: 0.3491
#     F1-score: 0.3798
#     mAP: 0.3566
#   [GAMO - kNN]
#     AUROC: 0.8173
#     G-mean: 0.5112
#     MCC: 0.3884
#     F1-score: 0.3778
#     mAP: 0.4036
#   [GAMO - MLP]
#     AUROC: 0.8819
#     G-mean: 0.5841
#     MCC: 0.3796
#     F1-score: 0.4104
#     mAP: 0.4604
#   [GAMO - RandomForest]
#     AUROC: 0.9173
#     G-mean: 0.5816
#     MCC: 0.4675
#     F1-score: 0.4607
#     mAP: 0.5867
#   [MGVAE - SVM]
#     AUROC: 0.8678
#     G-mean: 0.5184
#     MCC: 0.4309
#     F1-score: 0.4010
#     mAP: 0.5598
#   [MGVAE - DecisionTree]
#     AUROC: 0.7271
#     G-mean: 0.5942
#     MCC: 0.3880
#     F1-score: 0.4187
#     mAP: 0.3434
#   [MGVAE - kNN]
#     AUROC: 0.8248
#     G-mean: 0.5561
#     MCC: 0.4184
#     F1-score: 0.4195
#     mAP: 0.4186
#   [MGVAE - MLP]
#     AUROC: 0.9015
#     G-mean: 0.6217
#     MCC: 0.4311
#     F1-score: 0.4561
#     mAP: 0.5440
#   [MGVAE - RandomForest]
#     AUROC: 0.9212
#     G-mean: 0.5879
#     MCC: 0.4865
#     F1-score: 0.4740
#     mAP: 0.6037
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.8623
#     G-mean: 0.5686
#     MCC: 0.4336
#     F1-score: 0.4345
#     mAP: 0.5116
#   [GAMO - DecisionTree]
#     AUROC: 0.8327
#     G-mean: 0.5573
#     MCC: 0.3496
#     F1-score: 0.3805
#     mAP: 0.3584
#   [GAMO - kNN]
#     AUROC: 0.8168
#     G-mean: 0.5125
#     MCC: 0.3898
#     F1-score: 0.3788
#     mAP: 0.4030
#   [GAMO - MLP]
#     AUROC: 0.8820
#     G-mean: 0.5795
#     MCC: 0.3737
#     F1-score: 0.4042
#     mAP: 0.4592
#   [GAMO - RandomForest]
#     AUROC: 0.9178
#     G-mean: 0.5816
#     MCC: 0.4682
#     F1-score: 0.4607
#     mAP: 0.5871
#   [MGVAE - SVM]
#     AUROC: 0.8679
#     G-mean: 0.5174
#     MCC: 0.4298
#     F1-score: 0.3997
#     mAP: 0.5611
#   [MGVAE - DecisionTree]
#     AUROC: 0.7308
#     G-mean: 0.5975
#     MCC: 0.3907
#     F1-score: 0.4214
#     mAP: 0.3447
#   [MGVAE - kNN]
#     AUROC: 0.8239
#     G-mean: 0.5571
#     MCC: 0.4191
#     F1-score: 0.4205
#     mAP: 0.4173
#   [MGVAE - MLP]
#     AUROC: 0.9012
#     G-mean: 0.6224
#     MCC: 0.4310
#     F1-score: 0.4561
#     mAP: 0.5426
#   [MGVAE - RandomForest]
#     AUROC: 0.9213
#     G-mean: 0.5860
#     MCC: 0.4847
#     F1-score: 0.4716
#     mAP: 0.6044
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/us_crime_results_GAMO_MGVAE_beta_0.001.csv

# %%
# oil
data_name = 'oil'
maj_target_name = -1

n_epochs = 1000
hidden_dims = [64, 128, 256, 512]
latent_dim = 1024
lr = 0.001
beta = 0.001

# Run experiment
final_results = run_exp(
    data=data, 
    cat_idx=[], 
    methods=methods, 
    kernel_type=kernel_type,
    base_model=base_models,   # base_model is now a dict of classifiers
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    maj_target_name=maj_target_name,
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded: oil
# X shape : (937, 49)
# target : Counter({0: 896, 1: 41})
# IR: 21.85
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.8923
#     G-mean: 0.6738
#     MCC: 0.4475
#     F1-score: 0.4657
#     mAP: 0.4676
#   [GAMO - DecisionTree]
#     AUROC: 0.8205
#     G-mean: 0.5086
#     MCC: 0.3072
#     F1-score: 0.3225
#     mAP: 0.3204
#   [GAMO - kNN]
#     AUROC: 0.8174
#     G-mean: 0.3856
#     MCC: 0.3444
#     F1-score: 0.3133
#     mAP: 0.4158
#   [GAMO - MLP]
#     AUROC: 0.8788
#     G-mean: 0.6906
#     MCC: 0.4834
#     F1-score: 0.4975
#     mAP: 0.5292
#   [GAMO - RandomForest]
#     AUROC: 0.9441
#     G-mean: 0.6613
#     MCC: 0.6005
#     F1-score: 0.5740
#     mAP: 0.6536
#   [MGVAE - SVM]
#     AUROC: 0.9339
#     G-mean: 0.4747
#     MCC: 0.4404
#     F1-score: 0.4033
#     mAP: 0.6279
#   [MGVAE - DecisionTree]
#     AUROC: 0.7275
#     G-mean: 0.5233
#     MCC: 0.3783
#     F1-score: 0.3909
#     mAP: 0.2891
#   [MGVAE - kNN]
#     AUROC: 0.8201
#     G-mean: 0.3859
#     MCC: 0.3646
#     F1-score: 0.3200
#     mAP: 0.4485
#   [MGVAE - MLP]
#     AUROC: 0.8498
#     G-mean: 0.6041
#     MCC: 0.4805
#     F1-score: 0.4840
#     mAP: 0.5174
#   [MGVAE - RandomForest]
#     AUROC: 0.9215
#     G-mean: 0.4535
#     MCC: 0.3966
#     F1-score: 0.3652
#     mAP: 0.5883
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.8890
#     G-mean: 0.6318
#     MCC: 0.4133
#     F1-score: 0.4308
#     mAP: 0.4815
#   [GAMO - DecisionTree]
#     AUROC: 0.7830
#     G-mean: 0.5400
#     MCC: 0.3665
#     F1-score: 0.3659
#     mAP: 0.3435
#   [GAMO - kNN]
#     AUROC: 0.8191
#     G-mean: 0.3709
#     MCC: 0.3202
#     F1-score: 0.3004
#     mAP: 0.4161
#   [GAMO - MLP]
#     AUROC: 0.8762
#     G-mean: 0.6658
#     MCC: 0.4579
#     F1-score: 0.4718
#     mAP: 0.5096
#   [GAMO - RandomForest]
#     AUROC: 0.9373
#     G-mean: 0.6158
#     MCC: 0.5632
#     F1-score: 0.5412
#     mAP: 0.6272
#   [MGVAE - SVM]
#     AUROC: 0.9374
#     G-mean: 0.4758
#     MCC: 0.4343
#     F1-score: 0.3992
#     mAP: 0.6379
#   [MGVAE - DecisionTree]
#     AUROC: 0.7088
#     G-mean: 0.5722
#     MCC: 0.4352
#     F1-score: 0.4396
#     mAP: 0.3290
#   [MGVAE - kNN]
#     AUROC: 0.8215
#     G-mean: 0.3714
#     MCC: 0.3429
#     F1-score: 0.3095
#     mAP: 0.4393
#   [MGVAE - MLP]
#     AUROC: 0.8656
#     G-mean: 0.5887
#     MCC: 0.4668
#     F1-score: 0.4629
#     mAP: 0.5323
#   [MGVAE - RandomForest]
#     AUROC: 0.9332
#     G-mean: 0.4441
#     MCC: 0.3864
#     F1-score: 0.3599
#     mAP: 0.5847
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.8878
#     G-mean: 0.6377
#     MCC: 0.4123
#     F1-score: 0.4323
#     mAP: 0.4760
#   [GAMO - DecisionTree]
#     AUROC: 0.7853
#     G-mean: 0.5668
#     MCC: 0.3653
#     F1-score: 0.3725
#     mAP: 0.3207
#   [GAMO - kNN]
#     AUROC: 0.8176
#     G-mean: 0.3654
#     MCC: 0.3236
#     F1-score: 0.3006
#     mAP: 0.4310
#   [GAMO - MLP]
#     AUROC: 0.8749
#     G-mean: 0.6851
#     MCC: 0.4811
#     F1-score: 0.4956
#     mAP: 0.5247
#   [GAMO - RandomForest]
#     AUROC: 0.9389
#     G-mean: 0.6298
#     MCC: 0.5775
#     F1-score: 0.5536
#     mAP: 0.6413
#   [MGVAE - SVM]
#     AUROC: 0.9325
#     G-mean: 0.4825
#     MCC: 0.4473
#     F1-score: 0.4109
#     mAP: 0.6306
#   [MGVAE - DecisionTree]
#     AUROC: 0.6827
#     G-mean: 0.5486
#     MCC: 0.4143
#     F1-score: 0.4178
#     mAP: 0.3077
#   [MGVAE - kNN]
#     AUROC: 0.8201
#     G-mean: 0.3658
#     MCC: 0.3444
#     F1-score: 0.3098
#     mAP: 0.4558
#   [MGVAE - MLP]
#     AUROC: 0.8671
#     G-mean: 0.5774
#     MCC: 0.4446
#     F1-score: 0.4405
#     mAP: 0.5163
#   [MGVAE - RandomForest]
#     AUROC: 0.9363
#     G-mean: 0.4589
#     MCC: 0.4028
#     F1-score: 0.3773
#     mAP: 0.6021
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.8888
#     G-mean: 0.6442
#     MCC: 0.4153
#     F1-score: 0.4345
#     mAP: 0.4716
#   [GAMO - DecisionTree]
#     AUROC: 0.7872
#     G-mean: 0.5734
#     MCC: 0.3832
#     F1-score: 0.3903
#     mAP: 0.3305
#   [GAMO - kNN]
#     AUROC: 0.8185
#     G-mean: 0.3755
#     MCC: 0.3321
#     F1-score: 0.3067
#     mAP: 0.4460
#   [GAMO - MLP]
#     AUROC: 0.8724
#     G-mean: 0.6974
#     MCC: 0.4812
#     F1-score: 0.4961
#     mAP: 0.5380
#   [GAMO - RandomForest]
#     AUROC: 0.9376
#     G-mean: 0.6457
#     MCC: 0.5944
#     F1-score: 0.5696
#     mAP: 0.6560
#   [MGVAE - SVM]
#     AUROC: 0.9328
#     G-mean: 0.4856
#     MCC: 0.4489
#     F1-score: 0.4126
#     mAP: 0.6351
#   [MGVAE - DecisionTree]
#     AUROC: 0.6816
#     G-mean: 0.5378
#     MCC: 0.3972
#     F1-score: 0.4042
#     mAP: 0.2916
#   [MGVAE - kNN]
#     AUROC: 0.8207
#     G-mean: 0.3759
#     MCC: 0.3517
#     F1-score: 0.3160
#     mAP: 0.4667
#   [MGVAE - MLP]
#     AUROC: 0.8667
#     G-mean: 0.5565
#     MCC: 0.4201
#     F1-score: 0.4190
#     mAP: 0.5157
#   [MGVAE - RandomForest]
#     AUROC: 0.9389
#     G-mean: 0.4559
#     MCC: 0.4004
#     F1-score: 0.3747
#     mAP: 0.6217
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.8883
#     G-mean: 0.6473
#     MCC: 0.4200
#     F1-score: 0.4371
#     mAP: 0.4713
#   [GAMO - DecisionTree]
#     AUROC: 0.7899
#     G-mean: 0.5749
#     MCC: 0.3840
#     F1-score: 0.3935
#     mAP: 0.3244
#   [GAMO - kNN]
#     AUROC: 0.8161
#     G-mean: 0.3711
#     MCC: 0.3255
#     F1-score: 0.3029
#     mAP: 0.4386
#   [GAMO - MLP]
#     AUROC: 0.8736
#     G-mean: 0.7025
#     MCC: 0.4890
#     F1-score: 0.5040
#     mAP: 0.5356
#   [GAMO - RandomForest]
#     AUROC: 0.9378
#     G-mean: 0.6542
#     MCC: 0.6006
#     F1-score: 0.5770
#     mAP: 0.6568
#   [MGVAE - SVM]
#     AUROC: 0.9317
#     G-mean: 0.4992
#     MCC: 0.4589
#     F1-score: 0.4201
#     mAP: 0.6367
#   [MGVAE - DecisionTree]
#     AUROC: 0.6728
#     G-mean: 0.5488
#     MCC: 0.4087
#     F1-score: 0.4133
#     mAP: 0.2933
#   [MGVAE - kNN]
#     AUROC: 0.8182
#     G-mean: 0.3716
#     MCC: 0.3472
#     F1-score: 0.3135
#     mAP: 0.4603
#   [MGVAE - MLP]
#     AUROC: 0.8631
#     G-mean: 0.5577
#     MCC: 0.4096
#     F1-score: 0.4126
#     mAP: 0.5022
#   [MGVAE - RandomForest]
#     AUROC: 0.9374
#     G-mean: 0.4494
#     MCC: 0.3908
#     F1-score: 0.3673
#     mAP: 0.6147
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.8891
#     G-mean: 0.6400
#     MCC: 0.4157
#     F1-score: 0.4329
#     mAP: 0.4733
#   [GAMO - DecisionTree]
#     AUROC: 0.7927
#     G-mean: 0.5616
#     MCC: 0.3730
#     F1-score: 0.3814
#     mAP: 0.3205
#   [GAMO - kNN]
#     AUROC: 0.8153
#     G-mean: 0.3561
#     MCC: 0.3143
#     F1-score: 0.2904
#     mAP: 0.4399
#   [GAMO - MLP]
#     AUROC: 0.8744
#     G-mean: 0.6964
#     MCC: 0.4851
#     F1-score: 0.5003
#     mAP: 0.5424
#   [GAMO - RandomForest]
#     AUROC: 0.9385
#     G-mean: 0.6435
#     MCC: 0.5915
#     F1-score: 0.5655
#     mAP: 0.6517
#   [MGVAE - SVM]
#     AUROC: 0.9339
#     G-mean: 0.4868
#     MCC: 0.4493
#     F1-score: 0.4114
#     mAP: 0.6380
#   [MGVAE - DecisionTree]
#     AUROC: 0.6830
#     G-mean: 0.5464
#     MCC: 0.4053
#     F1-score: 0.4109
#     mAP: 0.2953
#   [MGVAE - kNN]
#     AUROC: 0.8174
#     G-mean: 0.3564
#     MCC: 0.3336
#     F1-score: 0.2993
#     mAP: 0.4630
#   [MGVAE - MLP]
#     AUROC: 0.8655
#     G-mean: 0.5467
#     MCC: 0.3993
#     F1-score: 0.4032
#     mAP: 0.4937
#   [MGVAE - RandomForest]
#     AUROC: 0.9389
#     G-mean: 0.4432
#     MCC: 0.3841
#     F1-score: 0.3603
#     mAP: 0.6093
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.8884
#     G-mean: 0.6283
#     MCC: 0.4071
#     F1-score: 0.4243
#     mAP: 0.4677
#   [GAMO - DecisionTree]
#     AUROC: 0.7961
#     G-mean: 0.5575
#     MCC: 0.3689
#     F1-score: 0.3788
#     mAP: 0.3213
#   [GAMO - kNN]
#     AUROC: 0.8145
#     G-mean: 0.3497
#     MCC: 0.3109
#     F1-score: 0.2876
#     mAP: 0.4394
#   [GAMO - MLP]
#     AUROC: 0.8709
#     G-mean: 0.6896
#     MCC: 0.4824
#     F1-score: 0.4971
#     mAP: 0.5381
#   [GAMO - RandomForest]
#     AUROC: 0.9382
#     G-mean: 0.6372
#     MCC: 0.5862
#     F1-score: 0.5592
#     mAP: 0.6451
#   [MGVAE - SVM]
#     AUROC: 0.9330
#     G-mean: 0.4842
#     MCC: 0.4463
#     F1-score: 0.4106
#     mAP: 0.6376
#   [MGVAE - DecisionTree]
#     AUROC: 0.6879
#     G-mean: 0.5533
#     MCC: 0.4101
#     F1-score: 0.4155
#     mAP: 0.2985
#   [MGVAE - kNN]
#     AUROC: 0.8167
#     G-mean: 0.3501
#     MCC: 0.3296
#     F1-score: 0.2966
#     mAP: 0.4609
#   [MGVAE - MLP]
#     AUROC: 0.8606
#     G-mean: 0.5362
#     MCC: 0.3859
#     F1-score: 0.3913
#     mAP: 0.4893
#   [MGVAE - RandomForest]
#     AUROC: 0.9393
#     G-mean: 0.4450
#     MCC: 0.3848
#     F1-score: 0.3615
#     mAP: 0.6083
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.8888
#     G-mean: 0.6264
#     MCC: 0.4070
#     F1-score: 0.4244
#     mAP: 0.4704
#   [GAMO - DecisionTree]
#     AUROC: 0.7935
#     G-mean: 0.5584
#     MCC: 0.3699
#     F1-score: 0.3810
#     mAP: 0.3239
#   [GAMO - kNN]
#     AUROC: 0.8150
#     G-mean: 0.3486
#     MCC: 0.3113
#     F1-score: 0.2903
#     mAP: 0.4401
#   [GAMO - MLP]
#     AUROC: 0.8717
#     G-mean: 0.6940
#     MCC: 0.4836
#     F1-score: 0.4982
#     mAP: 0.5348
#   [GAMO - RandomForest]
#     AUROC: 0.9380
#     G-mean: 0.6343
#     MCC: 0.5853
#     F1-score: 0.5582
#     mAP: 0.6478
#   [MGVAE - SVM]
#     AUROC: 0.9330
#     G-mean: 0.4814
#     MCC: 0.4457
#     F1-score: 0.4113
#     mAP: 0.6399
#   [MGVAE - DecisionTree]
#     AUROC: 0.6854
#     G-mean: 0.5515
#     MCC: 0.4105
#     F1-score: 0.4154
#     mAP: 0.2978
#   [MGVAE - kNN]
#     AUROC: 0.8172
#     G-mean: 0.3490
#     MCC: 0.3300
#     F1-score: 0.2990
#     mAP: 0.4602
#   [MGVAE - MLP]
#     AUROC: 0.8585
#     G-mean: 0.5450
#     MCC: 0.3920
#     F1-score: 0.3968
#     mAP: 0.4830
#   [MGVAE - RandomForest]
#     AUROC: 0.9398
#     G-mean: 0.4480
#     MCC: 0.3872
#     F1-score: 0.3637
#     mAP: 0.6071
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.8881
#     G-mean: 0.6299
#     MCC: 0.4107
#     F1-score: 0.4270
#     mAP: 0.4716
#   [GAMO - DecisionTree]
#     AUROC: 0.7949
#     G-mean: 0.5612
#     MCC: 0.3731
#     F1-score: 0.3836
#     mAP: 0.3243
#   [GAMO - kNN]
#     AUROC: 0.8155
#     G-mean: 0.3583
#     MCC: 0.3204
#     F1-score: 0.2973
#     mAP: 0.4422
#   [GAMO - MLP]
#     AUROC: 0.8734
#     G-mean: 0.6939
#     MCC: 0.4818
#     F1-score: 0.4970
#     mAP: 0.5338
#   [GAMO - RandomForest]
#     AUROC: 0.9378
#     G-mean: 0.6379
#     MCC: 0.5906
#     F1-score: 0.5623
#     mAP: 0.6491
#   [MGVAE - SVM]
#     AUROC: 0.9318
#     G-mean: 0.4879
#     MCC: 0.4523
#     F1-score: 0.4167
#     mAP: 0.6360
#   [MGVAE - DecisionTree]
#     AUROC: 0.6919
#     G-mean: 0.5614
#     MCC: 0.4192
#     F1-score: 0.4235
#     mAP: 0.3034
#   [MGVAE - kNN]
#     AUROC: 0.8177
#     G-mean: 0.3586
#     MCC: 0.3374
#     F1-score: 0.3050
#     mAP: 0.4609
#   [MGVAE - MLP]
#     AUROC: 0.8577
#     G-mean: 0.5408
#     MCC: 0.3890
#     F1-score: 0.3942
#     mAP: 0.4834
#   [MGVAE - RandomForest]
#     AUROC: 0.9397
#     G-mean: 0.4588
#     MCC: 0.3991
#     F1-score: 0.3745
#     mAP: 0.6050
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.8883
#     G-mean: 0.6303
#     MCC: 0.4158
#     F1-score: 0.4309
#     mAP: 0.4731
#   [GAMO - DecisionTree]
#     AUROC: 0.7939
#     G-mean: 0.5580
#     MCC: 0.3697
#     F1-score: 0.3803
#     mAP: 0.3228
#   [GAMO - kNN]
#     AUROC: 0.8160
#     G-mean: 0.3573
#     MCC: 0.3190
#     F1-score: 0.2959
#     mAP: 0.4461
#   [GAMO - MLP]
#     AUROC: 0.8719
#     G-mean: 0.6955
#     MCC: 0.4826
#     F1-score: 0.4975
#     mAP: 0.5320
#   [GAMO - RandomForest]
#     AUROC: 0.9382
#     G-mean: 0.6329
#     MCC: 0.5837
#     F1-score: 0.5558
#     mAP: 0.6472
#   [MGVAE - SVM]
#     AUROC: 0.9320
#     G-mean: 0.4841
#     MCC: 0.4486
#     F1-score: 0.4119
#     mAP: 0.6365
#   [MGVAE - DecisionTree]
#     AUROC: 0.6904
#     G-mean: 0.5661
#     MCC: 0.4248
#     F1-score: 0.4283
#     mAP: 0.3066
#   [MGVAE - kNN]
#     AUROC: 0.8182
#     G-mean: 0.3577
#     MCC: 0.3369
#     F1-score: 0.3041
#     mAP: 0.4651
#   [MGVAE - MLP]
#     AUROC: 0.8566
#     G-mean: 0.5380
#     MCC: 0.3908
#     F1-score: 0.3937
#     mAP: 0.4832
#   [MGVAE - RandomForest]
#     AUROC: 0.9398
#     G-mean: 0.4498
#     MCC: 0.3914
#     F1-score: 0.3675
#     mAP: 0.6065
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/oil_results_GAMO_MGVAE_beta_0.001.csv

# %%
# car_eval_34
data_name = 'car_eval_34'
maj_target_name = -1

n_epochs = 1000
hidden_dims = [64, 128, 256, 512]
latent_dim = 1024
lr = 0.001
beta = 0.001

# Run experiment
final_results = run_exp(
    data=data, 
    cat_idx=[], 
    methods=methods,
    kernel_type=kernel_type, 
    base_model=base_models,   # base_model is now a dict of classifiers
    device=device,
    n_epochs=n_epochs, 
    hidden_dims=hidden_dims, 
    latent_dim=latent_dim, 
    lr=lr, 
    beta=beta,
    data_name=data_name, 
    maj_target_name=maj_target_name,
    seed=1203, 
    visualize=False, 
    save_path=save_path
)
# Out:
# Dataset loaded: car_eval_34
# X shape : (1728, 21)
# target : Counter({0: 1594, 1: 134})
# IR: 11.9
#
# Starting experiment 1/10...
#
# [Aggregated Results after 1 runs]
#   [GAMO - SVM]
#     AUROC: 0.9965
#     G-mean: 0.9548
#     MCC: 0.8881
#     F1-score: 0.8944
#     mAP: 0.9612
#   [GAMO - DecisionTree]
#     AUROC: 0.9782
#     G-mean: 0.8132
#     MCC: 0.6955
#     F1-score: 0.7104
#     mAP: 0.7103
#   [GAMO - kNN]
#     AUROC: 0.9644
#     G-mean: 0.6891
#     MCC: 0.6028
#     F1-score: 0.5954
#     mAP: 0.6570
#   [GAMO - MLP]
#     AUROC: 0.9978
#     G-mean: 0.9601
#     MCC: 0.9004
#     F1-score: 0.9061
#     mAP: 0.9736
#   [GAMO - RandomForest]
#     AUROC: 0.9971
#     G-mean: 0.9272
#     MCC: 0.8901
#     F1-score: 0.8966
#     mAP: 0.9622
#   [MGVAE - SVM]
#     AUROC: 0.9978
#     G-mean: 0.9424
#     MCC: 0.9077
#     F1-score: 0.9127
#     mAP: 0.9731
#   [MGVAE - DecisionTree]
#     AUROC: 0.9838
#     G-mean: 0.8336
#     MCC: 0.6921
#     F1-score: 0.7112
#     mAP: 0.7945
#   [MGVAE - kNN]
#     AUROC: 0.9659
#     G-mean: 0.6621
#     MCC: 0.5814
#     F1-score: 0.5698
#     mAP: 0.6590
#   [MGVAE - MLP]
#     AUROC: 0.9941
#     G-mean: 0.8884
#     MCC: 0.8443
#     F1-score: 0.8506
#     mAP: 0.9480
#   [MGVAE - RandomForest]
#     AUROC: 0.9974
#     G-mean: 0.9149
#     MCC: 0.8772
#     F1-score: 0.8839
#     mAP: 0.9676
#
# Starting experiment 2/10...
#
# [Aggregated Results after 2 runs]
#   [GAMO - SVM]
#     AUROC: 0.9965
#     G-mean: 0.9567
#     MCC: 0.8911
#     F1-score: 0.8969
#     mAP: 0.9601
#   [GAMO - DecisionTree]
#     AUROC: 0.9798
#     G-mean: 0.8161
#     MCC: 0.7067
#     F1-score: 0.7213
#     mAP: 0.7307
#   [GAMO - kNN]
#     AUROC: 0.9635
#     G-mean: 0.6959
#     MCC: 0.6180
#     F1-score: 0.6083
#     mAP: 0.6785
#   [GAMO - MLP]
#     AUROC: 0.9981
#     G-mean: 0.9586
#     MCC: 0.9081
#     F1-score: 0.9133
#     mAP: 0.9767
#   [GAMO - RandomForest]
#     AUROC: 0.9975
#     G-mean: 0.9304
#     MCC: 0.8950
#     F1-score: 0.9008
#     mAP: 0.9674
#   [MGVAE - SVM]
#     AUROC: 0.9982
#     G-mean: 0.9509
#     MCC: 0.9212
#     F1-score: 0.9257
#     mAP: 0.9772
#   [MGVAE - DecisionTree]
#     AUROC: 0.9844
#     G-mean: 0.8127
#     MCC: 0.6765
#     F1-score: 0.6937
#     mAP: 0.8073
#   [MGVAE - kNN]
#     AUROC: 0.9646
#     G-mean: 0.6800
#     MCC: 0.6047
#     F1-score: 0.5926
#     mAP: 0.6781
#   [MGVAE - MLP]
#     AUROC: 0.9930
#     G-mean: 0.8726
#     MCC: 0.8220
#     F1-score: 0.8253
#     mAP: 0.9388
#   [MGVAE - RandomForest]
#     AUROC: 0.9976
#     G-mean: 0.9132
#     MCC: 0.8745
#     F1-score: 0.8805
#     mAP: 0.9691
#
# Starting experiment 3/10...
#
# [Aggregated Results after 3 runs]
#   [GAMO - SVM]
#     AUROC: 0.9966
#     G-mean: 0.9533
#     MCC: 0.8864
#     F1-score: 0.8932
#     mAP: 0.9622
#   [GAMO - DecisionTree]
#     AUROC: 0.9781
#     G-mean: 0.8151
#     MCC: 0.6941
#     F1-score: 0.7072
#     mAP: 0.7118
#   [GAMO - kNN]
#     AUROC: 0.9637
#     G-mean: 0.7010
#     MCC: 0.6288
#     F1-score: 0.6198
#     mAP: 0.6847
#   [GAMO - MLP]
#     AUROC: 0.9980
#     G-mean: 0.9580
#     MCC: 0.9084
#     F1-score: 0.9137
#     mAP: 0.9758
#   [GAMO - RandomForest]
#     AUROC: 0.9977
#     G-mean: 0.9260
#     MCC: 0.8897
#     F1-score: 0.8954
#     mAP: 0.9711
#   [MGVAE - SVM]
#     AUROC: 0.9982
#     G-mean: 0.9432
#     MCC: 0.9099
#     F1-score: 0.9145
#     mAP: 0.9781
#   [MGVAE - DecisionTree]
#     AUROC: 0.9826
#     G-mean: 0.8095
#     MCC: 0.6617
#     F1-score: 0.6811
#     mAP: 0.7833
#   [MGVAE - kNN]
#     AUROC: 0.9643
#     G-mean: 0.6833
#     MCC: 0.6155
#     F1-score: 0.6022
#     mAP: 0.6833
#   [MGVAE - MLP]
#     AUROC: 0.9935
#     G-mean: 0.8795
#     MCC: 0.8325
#     F1-score: 0.8366
#     mAP: 0.9428
#   [MGVAE - RandomForest]
#     AUROC: 0.9979
#     G-mean: 0.9156
#     MCC: 0.8773
#     F1-score: 0.8828
#     mAP: 0.9737
#
# Starting experiment 4/10...
#
# [Aggregated Results after 4 runs]
#   [GAMO - SVM]
#     AUROC: 0.9968
#     G-mean: 0.9537
#     MCC: 0.8872
#     F1-score: 0.8938
#     mAP: 0.9640
#   [GAMO - DecisionTree]
#     AUROC: 0.9790
#     G-mean: 0.8196
#     MCC: 0.7036
#     F1-score: 0.7174
#     mAP: 0.7228
#   [GAMO - kNN]
#     AUROC: 0.9610
#     G-mean: 0.6986
#     MCC: 0.6254
#     F1-score: 0.6172
#     mAP: 0.6801
#   [GAMO - MLP]
#     AUROC: 0.9979
#     G-mean: 0.9536
#     MCC: 0.9025
#     F1-score: 0.9083
#     mAP: 0.9751
#   [GAMO - RandomForest]
#     AUROC: 0.9977
#     G-mean: 0.9232
#     MCC: 0.8866
#     F1-score: 0.8921
#     mAP: 0.9718
#   [MGVAE - SVM]
#     AUROC: 0.9980
#     G-mean: 0.9433
#     MCC: 0.9095
#     F1-score: 0.9142
#     mAP: 0.9761
#   [MGVAE - DecisionTree]
#     AUROC: 0.9830
#     G-mean: 0.8155
#     MCC: 0.6689
#     F1-score: 0.6887
#     mAP: 0.7880
#   [MGVAE - kNN]
#     AUROC: 0.9617
#     G-mean: 0.6823
#     MCC: 0.6141
#     F1-score: 0.6017
#     mAP: 0.6801
#   [MGVAE - MLP]
#     AUROC: 0.9928
#     G-mean: 0.8731
#     MCC: 0.8236
#     F1-score: 0.8279
#     mAP: 0.9389
#   [MGVAE - RandomForest]
#     AUROC: 0.9979
#     G-mean: 0.9143
#     MCC: 0.8740
#     F1-score: 0.8798
#     mAP: 0.9733
#
# Starting experiment 5/10...
#
# [Aggregated Results after 5 runs]
#   [GAMO - SVM]
#     AUROC: 0.9969
#     G-mean: 0.9549
#     MCC: 0.8898
#     F1-score: 0.8962
#     mAP: 0.9645
#   [GAMO - DecisionTree]
#     AUROC: 0.9793
#     G-mean: 0.8184
#     MCC: 0.7057
#     F1-score: 0.7194
#     mAP: 0.7289
#   [GAMO - kNN]
#     AUROC: 0.9620
#     G-mean: 0.7010
#     MCC: 0.6301
#     F1-score: 0.6211
#     mAP: 0.6867
#   [GAMO - MLP]
#     AUROC: 0.9976
#     G-mean: 0.9566
#     MCC: 0.9057
#     F1-score: 0.9113
#     mAP: 0.9724
#   [GAMO - RandomForest]
#     AUROC: 0.9979
#     G-mean: 0.9263
#     MCC: 0.8913
#     F1-score: 0.8966
#     mAP: 0.9740
#   [MGVAE - SVM]
#     AUROC: 0.9983
#     G-mean: 0.9427
#     MCC: 0.9111
#     F1-score: 0.9156
#     mAP: 0.9787
#   [MGVAE - DecisionTree]
#     AUROC: 0.9833
#     G-mean: 0.8155
#     MCC: 0.6733
#     F1-score: 0.6919
#     mAP: 0.7911
#   [MGVAE - kNN]
#     AUROC: 0.9630
#     G-mean: 0.6851
#     MCC: 0.6197
#     F1-score: 0.6065
#     mAP: 0.6887
#   [MGVAE - MLP]
#     AUROC: 0.9926
#     G-mean: 0.8670
#     MCC: 0.8144
#     F1-score: 0.8194
#     mAP: 0.9356
#   [MGVAE - RandomForest]
#     AUROC: 0.9980
#     G-mean: 0.9141
#     MCC: 0.8758
#     F1-score: 0.8809
#     mAP: 0.9749
#
# Starting experiment 6/10...
#
# [Aggregated Results after 6 runs]
#   [GAMO - SVM]
#     AUROC: 0.9970
#     G-mean: 0.9557
#     MCC: 0.8912
#     F1-score: 0.8973
#     mAP: 0.9659
#   [GAMO - DecisionTree]
#     AUROC: 0.9794
#     G-mean: 0.8204
#     MCC: 0.7100
#     F1-score: 0.7232
#     mAP: 0.7302
#   [GAMO - kNN]
#     AUROC: 0.9619
#     G-mean: 0.7053
#     MCC: 0.6378
#     F1-score: 0.6290
#     mAP: 0.6898
#   [GAMO - MLP]
#     AUROC: 0.9977
#     G-mean: 0.9550
#     MCC: 0.9065
#     F1-score: 0.9120
#     mAP: 0.9733
#   [GAMO - RandomForest]
#     AUROC: 0.9979
#     G-mean: 0.9243
#     MCC: 0.8879
#     F1-score: 0.8934
#     mAP: 0.9745
#   [MGVAE - SVM]
#     AUROC: 0.9983
#     G-mean: 0.9408
#     MCC: 0.9087
#     F1-score: 0.9134
#     mAP: 0.9792
#   [MGVAE - DecisionTree]
#     AUROC: 0.9831
#     G-mean: 0.8090
#     MCC: 0.6650
#     F1-score: 0.6840
#     mAP: 0.7900
#   [MGVAE - kNN]
#     AUROC: 0.9628
#     G-mean: 0.6877
#     MCC: 0.6244
#     F1-score: 0.6113
#     mAP: 0.6896
#   [MGVAE - MLP]
#     AUROC: 0.9928
#     G-mean: 0.8673
#     MCC: 0.8180
#     F1-score: 0.8228
#     mAP: 0.9374
#   [MGVAE - RandomForest]
#     AUROC: 0.9980
#     G-mean: 0.9135
#     MCC: 0.8749
#     F1-score: 0.8801
#     mAP: 0.9759
#
# Starting experiment 7/10...
#
# [Aggregated Results after 7 runs]
#   [GAMO - SVM]
#     AUROC: 0.9970
#     G-mean: 0.9575
#     MCC: 0.8934
#     F1-score: 0.8994
#     mAP: 0.9657
#   [GAMO - DecisionTree]
#     AUROC: 0.9795
#     G-mean: 0.8218
#     MCC: 0.7123
#     F1-score: 0.7259
#     mAP: 0.7315
#   [GAMO - kNN]
#     AUROC: 0.9616
#     G-mean: 0.7009
#     MCC: 0.6293
#     F1-score: 0.6219
#     mAP: 0.6837
#   [GAMO - MLP]
#     AUROC: 0.9977
#     G-mean: 0.9547
#     MCC: 0.9066
#     F1-score: 0.9122
#     mAP: 0.9729
#   [GAMO - RandomForest]
#     AUROC: 0.9979
#     G-mean: 0.9235
#     MCC: 0.8866
#     F1-score: 0.8923
#     mAP: 0.9737
#   [MGVAE - SVM]
#     AUROC: 0.9982
#     G-mean: 0.9387
#     MCC: 0.9055
#     F1-score: 0.9105
#     mAP: 0.9780
#   [MGVAE - DecisionTree]
#     AUROC: 0.9830
#     G-mean: 0.8051
#     MCC: 0.6612
#     F1-score: 0.6795
#     mAP: 0.7896
#   [MGVAE - kNN]
#     AUROC: 0.9627
#     G-mean: 0.6844
#     MCC: 0.6180
#     F1-score: 0.6060
#     mAP: 0.6854
#   [MGVAE - MLP]
#     AUROC: 0.9931
#     G-mean: 0.8714
#     MCC: 0.8238
#     F1-score: 0.8287
#     mAP: 0.9395
#   [MGVAE - RandomForest]
#     AUROC: 0.9980
#     G-mean: 0.9123
#     MCC: 0.8739
#     F1-score: 0.8792
#     mAP: 0.9745
#
# Starting experiment 8/10...
#
# [Aggregated Results after 8 runs]
#   [GAMO - SVM]
#     AUROC: 0.9968
#     G-mean: 0.9540
#     MCC: 0.8872
#     F1-score: 0.8938
#     mAP: 0.9632
#   [GAMO - DecisionTree]
#     AUROC: 0.9793
#     G-mean: 0.8204
#     MCC: 0.7107
#     F1-score: 0.7244
#     mAP: 0.7311
#   [GAMO - kNN]
#     AUROC: 0.9611
#     G-mean: 0.7034
#     MCC: 0.6322
#     F1-score: 0.6253
#     mAP: 0.6840
#   [GAMO - MLP]
#     AUROC: 0.9976
#     G-mean: 0.9521
#     MCC: 0.9050
#     F1-score: 0.9106
#     mAP: 0.9724
#   [GAMO - RandomForest]
#     AUROC: 0.9978
#     G-mean: 0.9207
#     MCC: 0.8821
#     F1-score: 0.8878
#     mAP: 0.9725
#   [MGVAE - SVM]
#     AUROC: 0.9982
#     G-mean: 0.9374
#     MCC: 0.9041
#     F1-score: 0.9089
#     mAP: 0.9773
#   [MGVAE - DecisionTree]
#     AUROC: 0.9832
#     G-mean: 0.8016
#     MCC: 0.6570
#     F1-score: 0.6757
#     mAP: 0.7905
#   [MGVAE - kNN]
#     AUROC: 0.9623
#     G-mean: 0.6878
#     MCC: 0.6222
#     F1-score: 0.6107
#     mAP: 0.6863
#   [MGVAE - MLP]
#     AUROC: 0.9936
#     G-mean: 0.8731
#     MCC: 0.8266
#     F1-score: 0.8315
#     mAP: 0.9432
#   [MGVAE - RandomForest]
#     AUROC: 0.9979
#     G-mean: 0.9105
#     MCC: 0.8716
#     F1-score: 0.8770
#     mAP: 0.9740
#
# Starting experiment 9/10...
#
# [Aggregated Results after 9 runs]
#   [GAMO - SVM]
#     AUROC: 0.9968
#     G-mean: 0.9519
#     MCC: 0.8851
#     F1-score: 0.8917
#     mAP: 0.9629
#   [GAMO - DecisionTree]
#     AUROC: 0.9796
#     G-mean: 0.8209
#     MCC: 0.7122
#     F1-score: 0.7261
#     mAP: 0.7346
#   [GAMO - kNN]
#     AUROC: 0.9611
#     G-mean: 0.7034
#     MCC: 0.6312
#     F1-score: 0.6249
#     mAP: 0.6830
#   [GAMO - MLP]
#     AUROC: 0.9976
#     G-mean: 0.9519
#     MCC: 0.9051
#     F1-score: 0.9108
#     mAP: 0.9726
#   [GAMO - RandomForest]
#     AUROC: 0.9979
#     G-mean: 0.9223
#     MCC: 0.8846
#     F1-score: 0.8902
#     mAP: 0.9730
#   [MGVAE - SVM]
#     AUROC: 0.9982
#     G-mean: 0.9371
#     MCC: 0.9045
#     F1-score: 0.9092
#     mAP: 0.9773
#   [MGVAE - DecisionTree]
#     AUROC: 0.9833
#     G-mean: 0.8030
#     MCC: 0.6606
#     F1-score: 0.6788
#     mAP: 0.7925
#   [MGVAE - kNN]
#     AUROC: 0.9625
#     G-mean: 0.6890
#     MCC: 0.6231
#     F1-score: 0.6122
#     mAP: 0.6870
#   [MGVAE - MLP]
#     AUROC: 0.9941
#     G-mean: 0.8752
#     MCC: 0.8295
#     F1-score: 0.8342
#     mAP: 0.9467
#   [MGVAE - RandomForest]
#     AUROC: 0.9979
#     G-mean: 0.9119
#     MCC: 0.8738
#     F1-score: 0.8791
#     mAP: 0.9740
#
# Starting experiment 10/10...
#
# [Aggregated Results after 10 runs]
#   [GAMO - SVM]
#     AUROC: 0.9968
#     G-mean: 0.9523
#     MCC: 0.8858
#     F1-score: 0.8925
#     mAP: 0.9636
#   [GAMO - DecisionTree]
#     AUROC: 0.9798
#     G-mean: 0.8221
#     MCC: 0.7138
#     F1-score: 0.7279
#     mAP: 0.7345
#   [GAMO - kNN]
#     AUROC: 0.9613
#     G-mean: 0.7027
#     MCC: 0.6311
#     F1-score: 0.6243
#     mAP: 0.6827
#   [GAMO - MLP]
#     AUROC: 0.9977
#     G-mean: 0.9521
#     MCC: 0.9067
#     F1-score: 0.9123
#     mAP: 0.9736
#   [GAMO - RandomForest]
#     AUROC: 0.9979
#     G-mean: 0.9222
#     MCC: 0.8839
#     F1-score: 0.8895
#     mAP: 0.9730
#   [MGVAE - SVM]
#     AUROC: 0.9982
#     G-mean: 0.9373
#     MCC: 0.9050
#     F1-score: 0.9098
#     mAP: 0.9778
#   [MGVAE - DecisionTree]
#     AUROC: 0.9836
#     G-mean: 0.8016
#     MCC: 0.6601
#     F1-score: 0.6783
#     mAP: 0.7958
#   [MGVAE - kNN]
#     AUROC: 0.9626
#     G-mean: 0.6880
#     MCC: 0.6220
#     F1-score: 0.6106
#     mAP: 0.6861
#   [MGVAE - MLP]
#     AUROC: 0.9944
#     G-mean: 0.8746
#     MCC: 0.8294
#     F1-score: 0.8344
#     mAP: 0.9486
#   [MGVAE - RandomForest]
#     AUROC: 0.9979
#     G-mean: 0.9113
#     MCC: 0.8738
#     F1-score: 0.8791
#     mAP: 0.9739
#
# [Saved] Final results are saved to /data4/oldrain123/oldrain123/results/real_results/car_eval_34_results_GAMO_MGVAE_beta_0.001.csv
